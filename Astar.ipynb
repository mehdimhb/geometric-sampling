# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
import graphical_sampling as gs
import pandas as pd
import numpy as np
import itertools
from tqdm import tqdm
from package_sampling.utils import inclusion_probabilities
# Out:
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "XPC_SERVICE_NAME" redefined by R and overriding existing variable. Current: "application.com.jetbrains.pycharm.1003326.4172874", R: "0"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpX9vEvJ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmpp97hRa"
#   warnings.warn(

# %% [markdown]
# # Loading and Determining Population

# %%
DATA_DIR = "populations"
csv_paths = glob.glob(os.path.join(DATA_DIR, "*.csv"))

coords_dict = {}
probs_dict = {}

for fp in csv_paths:
    name = os.path.splitext(os.path.basename(fp))[0]
    data = np.loadtxt(fp, delimiter=",", skiprows=1)
    coords = data[:, :2]
    probs  = data[:, -1]

    coord_name, prob_name, *rest = name.split("_")
    coord_name = 'cluster' if coord_name == 'clust' else coord_name
    prob_name = 'equal' if prob_name == 'eq' else 'unequal'

    coords_dict[coord_name] = coords
    probs_dict[coord_name] = probs_dict.get(coord_name, {})
    probs_dict[coord_name][prob_name] = probs

print(coords_dict.keys())
print(probs_dict.keys())
print(probs_dict['random'].keys())
# Out:
# dict_keys(['swiss', 'cluster', 'meuse', 'random', 'grid'])
# dict_keys(['swiss', 'cluster', 'meuse', 'random', 'grid'])
# dict_keys(['equal', 'unequal'])

# %%
N = 100
n = 8
coords = coords_dict['random']
probs = probs_dict['random']['equal']
modified_probs = inclusion_probabilities(probs, n=n)
pop = gs.Population(coords, modified_probs)

# %% [markdown]
# # Building Initial Designs

# %%
orders = [
    "lexico-yx",
    "lexico-xy",
    "random",
    "angle_0",
    "distance_0",
    "projection",
    "center",
    "spiral",
    "max",
    "snake",
    "hilbert",
]

# %%
initial_designs = []
combines = list(itertools.product(orders, orders))
num_trials = 5
for units_order, zones_order in tqdm(combines, desc="Generating initial designs", total=len(combines), unit="orders"):
    best = None
    best_score = np.inf
    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=(2, 2),
            zone_builder='sweep',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))

    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=4,
            zone_builder='cluster',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))
# Out:
# Generating initial designs: 100%|██████████| 121/121 [11:51<00:00,  5.88s/orders]

# %% [markdown]
# # Run

# %%
moran_criteria = gs.criteria.MoranCriteria()

# %%
astar = gs.search.AStar(
    initial_designs,
    moran_criteria
)
# Out:
# best initial criteria value -0.32535592415203857

# %%
astar.run(
    max_iterations = 1000,
    num_new_nodes = 5,
    max_open_set_size = 1000,
    n_clusters_to_change_order_zone = 'None',
    n_clusters_to_change_order_units = 'all',
    n_zones_to_change_order_units = 'all',
    n_changes_in_order_of_units = 1,
    n_changes_in_order_of_zones = 1,
)
# Out:
# Criteria of current node: -0.32535592415203857
#
# ==============================================
# New best criteria value: -0.3316931945159151
#
# ==============================================
# New best criteria value: -0.33344992986895167
# Criteria of current node: -0.33344992986895167
# Criteria of current node: -0.3316931945159151
# Criteria of current node: -0.32535592415203857
# Criteria of current node: -0.3210586564780824
# Criteria of current node: -0.3210586564780824
# Criteria of current node: -0.3183134272018159
# Criteria of current node: -0.31743199685281154
# Criteria of current node: -0.31743199685281154
# Criteria of current node: -0.330943574148691
# Criteria of current node: -0.323545439385002
# Criteria of current node: -0.31829298078432594
# Criteria of current node: -0.31450180722488164
# Criteria of current node: -0.31450180722488164
# Criteria of current node: -0.3322427619948967
# Criteria of current node: -0.32570320030533506
# Criteria of current node: -0.311146885984879
# Criteria of current node: -0.30863330212043727
# Criteria of current node: -0.30829040692874854
# Criteria of current node: -0.30720054021953896
# Criteria of current node: -0.30621986488209496
# Criteria of current node: -0.318867115248439
# Criteria of current node: -0.30581452252320174
# Criteria of current node: -0.303354909489783
# Criteria of current node: -0.30884860744302955
# Criteria of current node: -0.3193281830853043
#
# ==============================================
# New best criteria value: -0.3418489821307384
# Criteria of current node: -0.3418489821307384
# Criteria of current node: -0.32110325625179076
# Criteria of current node: -0.31989227106801604
# Criteria of current node: -0.31819712826897495
# Criteria of current node: -0.31567405156749395
# Criteria of current node: -0.30295025718595003
# Criteria of current node: -0.30295025718595003
# Criteria of current node: -0.3023259476571467
# Criteria of current node: -0.304918061456745
# Criteria of current node: -0.30314718948197794
# Criteria of current node: -0.30177940880570564
# Criteria of current node: -0.30177940880570564
# Criteria of current node: -0.31500966558033383
# Criteria of current node: -0.31081898341581615
# Criteria of current node: -0.3018393516649963
# Criteria of current node: -0.3252340229830718
# Criteria of current node: -0.3381988164577219
# Criteria of current node: -0.33489677294995035
# Criteria of current node: -0.3273622737449567
# Criteria of current node: -0.3248218518813425
# Criteria of current node: -0.318116109162463
# Criteria of current node: -0.3128292883865853
# Criteria of current node: -0.305058661011199
# Criteria of current node: -0.3030338535389482
# Criteria of current node: -0.3216291458204684
# Criteria of current node: -0.3028296337080252
# Criteria of current node: -0.30150152708261485
# Criteria of current node: -0.30150152708261485
# Criteria of current node: -0.3006811811260149
# Criteria of current node: -0.3003893020730799
# Criteria of current node: -0.30196577568819793
# Criteria of current node: -0.300380404561265
# Criteria of current node: -0.30824570146482955
# Criteria of current node: -0.300380404561265
# Criteria of current node: -0.2992028649260768
# Criteria of current node: -0.29851640003693003
# Criteria of current node: -0.32062897723108297
#
# ==============================================
# New best criteria value: -0.40223063284406996
# Criteria of current node: -0.40223063284406996
# Criteria of current node: -0.3035448863915986
# Criteria of current node: -0.31223269191226677
# Criteria of current node: -0.3009681218227173
# Criteria of current node: -0.29844313720436993
# Criteria of current node: -0.29844313720436993
# Criteria of current node: -0.29992590560569266
# Criteria of current node: -0.2984272420024329
# Criteria of current node: -0.31328915930528684
# Criteria of current node: -0.2983943971550312
# Criteria of current node: -0.32405679762706996
# Criteria of current node: -0.3175419202659802
# Criteria of current node: -0.2980711134174937
# Criteria of current node: -0.29741811173008875
# Criteria of current node: -0.3147731408890726
# Criteria of current node: -0.305611030925806
# Criteria of current node: -0.33155316219948006
# Criteria of current node: -0.3208433204890044
# Criteria of current node: -0.33253296226493145
# Criteria of current node: -0.31581252355702055
# Criteria of current node: -0.3076080597279137
# Criteria of current node: -0.31297787741158595
# Criteria of current node: -0.32687595927961005
# Criteria of current node: -0.30751978596663015
# Criteria of current node: -0.30667821391314715
# Criteria of current node: -0.29710194178016464
# Criteria of current node: -0.29702276930776766
# Criteria of current node: -0.31002913254296305
# Criteria of current node: -0.3183290036410962
# Criteria of current node: -0.31611184460732
# Criteria of current node: -0.2968308617557603
# Criteria of current node: -0.29681755239793023
# Criteria of current node: -0.29650537629018425
# Criteria of current node: -0.30629901281362437
# Criteria of current node: -0.2960545873091832
# Criteria of current node: -0.307787962077355
# Criteria of current node: -0.2999349503261205
# Criteria of current node: -0.2956945455088815
# Criteria of current node: -0.35099209829363265
# Criteria of current node: -0.31295474781697497
# Criteria of current node: -0.29609002085765646
# Criteria of current node: -0.2999496057264869
# Criteria of current node: -0.3114961401846444
# Criteria of current node: -0.3082751026369158
# Criteria of current node: -0.2966599371538958
# Criteria of current node: -0.29562955900734855
# Criteria of current node: -0.29560419414030575
# Criteria of current node: -0.2949925957394197
# Criteria of current node: -0.3132948909858002
# Criteria of current node: -0.31188331111546874
# Criteria of current node: -0.3450947155460267
# Criteria of current node: -0.33294880921918196
# Criteria of current node: -0.3459200379971192
# Criteria of current node: -0.31058564526209087
# Criteria of current node: -0.31022488521434627
# Criteria of current node: -0.30491286428104686
# Criteria of current node: -0.3054024455481149
# Criteria of current node: -0.29780057194578646
# Criteria of current node: -0.29596877962807416
# Criteria of current node: -0.30449062722850573
# Criteria of current node: -0.303628074742712
# Criteria of current node: -0.3009071232744396
# Criteria of current node: -0.3110483360631208
# Criteria of current node: -0.3126188260734551
# Criteria of current node: -0.3070535852846647
# Criteria of current node: -0.34100055820643677
# Criteria of current node: -0.3188218664977306
# Criteria of current node: -0.3184813226270876
# Criteria of current node: -0.3158214079989776
# Criteria of current node: -0.31355615547176324
# Criteria of current node: -0.30002616245396624
# Criteria of current node: -0.2977213279154872
# Criteria of current node: -0.3092440735377811
# Criteria of current node: -0.3340668580398239
# Criteria of current node: -0.30109855820981585
# Criteria of current node: -0.29766271029966473
# Criteria of current node: -0.2974745292109804
# Criteria of current node: -0.2960942789897727
# Criteria of current node: -0.30367083494779873
# Criteria of current node: -0.30099807386900007
# Criteria of current node: -0.2962608027904426
# Criteria of current node: -0.29468369846449394
# Criteria of current node: -0.3203490133954179
# Criteria of current node: -0.30483913790923406
# Criteria of current node: -0.32094221460455463
# Criteria of current node: -0.33036800009787476
# Criteria of current node: -0.31609515545671885
# Criteria of current node: -0.29460332178306653
# Criteria of current node: -0.33434916067333
# Criteria of current node: -0.29451684506004716
# Criteria of current node: -0.2943679195251077
# Criteria of current node: -0.3003947355837956
# Criteria of current node: -0.29428066815192644
# Criteria of current node: -0.3337184137527707
# Criteria of current node: -0.3074541102485296
# Criteria of current node: -0.3120525388928288
# Criteria of current node: -0.32414834742993165
# Criteria of current node: -0.3147077832444032
# Criteria of current node: -0.31803890288408615
# Criteria of current node: -0.31737087926644886
# Criteria of current node: -0.3405147437148968
# Criteria of current node: -0.303932807441142
# Criteria of current node: -0.30254317892178373
# Criteria of current node: -0.3017511947107904
# Criteria of current node: -0.3008086175049922
# Criteria of current node: -0.3204903837057021
# Criteria of current node: -0.2982189720357674
# Criteria of current node: -0.30402258761267437
# Criteria of current node: -0.3378373941485532
# Criteria of current node: -0.3021634254974674
# Criteria of current node: -0.31858683038429964
# Criteria of current node: -0.3134215373713465
# Criteria of current node: -0.29717729829528544
# Criteria of current node: -0.29663067675378196
# Criteria of current node: -0.2962967592906128
# Criteria of current node: -0.2957638772230611
# Criteria of current node: -0.29508799964434745
# Criteria of current node: -0.32678533762492606
# Criteria of current node: -0.3223916096008839
# Criteria of current node: -0.30091667926029836
# Criteria of current node: -0.295083160361319
# Criteria of current node: -0.29496723723772245
# Criteria of current node: -0.3262148241236996
# Criteria of current node: -0.3276476089957759
# Criteria of current node: -0.29883846100119976
# Criteria of current node: -0.296004020359388
# Criteria of current node: -0.2941073626449071
# Criteria of current node: -0.31148831049891057
# Criteria of current node: -0.2938937418511614
# Criteria of current node: -0.29384058039790084
# Criteria of current node: -0.30567606620808924
# Criteria of current node: -0.29384058039790084
# Criteria of current node: -0.2937822216422714
# Criteria of current node: -0.3285037017064222
# Criteria of current node: -0.33129281883921924
# Criteria of current node: -0.30639345887638886
# Criteria of current node: -0.3000904097261178
# Criteria of current node: -0.2937809995245485
# Criteria of current node: -0.30466482512753773
# Criteria of current node: -0.2936147095574173
# Criteria of current node: -0.31863868873511825
# Criteria of current node: -0.3110785921103715
# Criteria of current node: -0.31128925747665626
# Criteria of current node: -0.30445653876545015
# Criteria of current node: -0.3146728523085535
# Criteria of current node: -0.3031470369358563
# Criteria of current node: -0.2964670516243695
# Criteria of current node: -0.30674258481701555
# Criteria of current node: -0.2934880376087517
# Criteria of current node: -0.2982998939364963
# Criteria of current node: -0.31075653867097547
# Criteria of current node: -0.2993376787661121
# Criteria of current node: -0.3120510130098396
# Criteria of current node: -0.2950201852950081
# Criteria of current node: -0.2933517851832309
# Criteria of current node: -0.29312267720259555
# Criteria of current node: -0.3353729822188898
# Criteria of current node: -0.3093186851929548
# Criteria of current node: -0.31236670756246576
# Criteria of current node: -0.3048343767674767
# Criteria of current node: -0.2994189542267325
# Criteria of current node: -0.3222782703294299
# Criteria of current node: -0.30358738460448786
# Criteria of current node: -0.30882115901607987
# Criteria of current node: -0.3083577941282049
# Criteria of current node: -0.29890901796940406
# Criteria of current node: -0.29766963206438407
# Criteria of current node: -0.30596927654601247
# Criteria of current node: -0.3020795510739563
# Criteria of current node: -0.29588118537488284
# Criteria of current node: -0.33783651211296595
# Criteria of current node: -0.308808676763716
# Criteria of current node: -0.29426214466969636
# Criteria of current node: -0.29921473280721944
# Criteria of current node: -0.2961849538666349
# Criteria of current node: -0.30975907249585083
# Criteria of current node: -0.30052330105157726
# Criteria of current node: -0.30332318219464516
# Criteria of current node: -0.3044339744700444
# Criteria of current node: -0.2991732875036107
# Criteria of current node: -0.29615316235858863
# Criteria of current node: -0.29510626413481483
# Criteria of current node: -0.29377962074831726
# Criteria of current node: -0.2931059405368199
# Criteria of current node: -0.29485411262903066
# Criteria of current node: -0.301851855961621
# Criteria of current node: -0.2983384381821806
# Criteria of current node: -0.2945666782731586
# Criteria of current node: -0.29309984339035744
# Criteria of current node: -0.30033273143998973
# Criteria of current node: -0.29574109551188277
# Criteria of current node: -0.2930389453397713
# Criteria of current node: -0.29294708624674215
# Criteria of current node: -0.2943897255528572
# Criteria of current node: -0.2929205526398738
# Criteria of current node: -0.292848468516995
# Criteria of current node: -0.3059142352972108
# Criteria of current node: -0.29848286937860913
# Criteria of current node: -0.2928468528106064
# Criteria of current node: -0.292815486200405
# Criteria of current node: -0.29257006170684635
# Criteria of current node: -0.29644280115374955
# Criteria of current node: -0.33163537305995583
# Criteria of current node: -0.29610661827722723
# Criteria of current node: -0.2925276616993958
# Criteria of current node: -0.3318781783454934
# Criteria of current node: -0.3053213094901864
# Criteria of current node: -0.3128950574046501
# Criteria of current node: -0.32458794356831133
# Criteria of current node: -0.3440426650911454
# Criteria of current node: -0.31806800314129086
# Criteria of current node: -0.3134264077040104
# Criteria of current node: -0.3071789432680259
# Criteria of current node: -0.3049965868529507
# Criteria of current node: -0.29868824200053684
# Criteria of current node: -0.29818011922235205
# Criteria of current node: -0.29499881424188656
# Criteria of current node: -0.3097057208582335
# Criteria of current node: -0.2922710521205744
# Criteria of current node: -0.3183072032467982
# Criteria of current node: -0.32434479936395255
# Criteria of current node: -0.30450215742788017
# Criteria of current node: -0.3021493114722058
# Criteria of current node: -0.34631626371505236
# Criteria of current node: -0.3313851206037203
# Criteria of current node: -0.3305802388928167
# Criteria of current node: -0.3077807251189766
# Criteria of current node: -0.2996037162547792
# Criteria of current node: -0.2975479895685545
# Criteria of current node: -0.2966767236563582
# Criteria of current node: -0.2960626230179667
# Criteria of current node: -0.3423121280204214
# Criteria of current node: -0.3035933223023257
# Criteria of current node: -0.3146362100741797
# Criteria of current node: -0.29875937394317437
# Criteria of current node: -0.29980436347090417
# Criteria of current node: -0.306403872511375
# Criteria of current node: -0.30222146692101315
# Criteria of current node: -0.29650686785441804
# Criteria of current node: -0.29563189917543065
# Criteria of current node: -0.2922441701346391
# Criteria of current node: -0.30321790306412905
# Criteria of current node: -0.29610832045531665
# Criteria of current node: -0.292186109111287
# Criteria of current node: -0.2925871757149446
# Criteria of current node: -0.2921418934423382
# Criteria of current node: -0.29212188961327235
# Criteria of current node: -0.3005084864125617
# Criteria of current node: -0.2934115478087513
# Criteria of current node: -0.2920865366188001
# Criteria of current node: -0.2920762979492918
# Criteria of current node: -0.3119766188517975
# Criteria of current node: -0.3118564215476805
# Criteria of current node: -0.30499175657690447
# Criteria of current node: -0.30126502434894525
# Criteria of current node: -0.29206055758833266
# Criteria of current node: -0.29204037867476973
# Criteria of current node: -0.32240800662572017
# Criteria of current node: -0.2948251190956602
# Criteria of current node: -0.30208183865411636
# Criteria of current node: -0.32807188209296745
# Criteria of current node: -0.3055381880830059
# Criteria of current node: -0.3019420468696763
# Criteria of current node: -0.31808822024158706
# Criteria of current node: -0.29893101667645017
# Criteria of current node: -0.33429714737467725
# Criteria of current node: -0.29846399391189876
# Criteria of current node: -0.2959976448115568
# Criteria of current node: -0.3120208169788046
# Criteria of current node: -0.2992885561333847
# Criteria of current node: -0.30402590374418004
# Criteria of current node: -0.29887192932990797
# Criteria of current node: -0.2964023286452041
# Criteria of current node: -0.2971500334302369
# Criteria of current node: -0.29557388384499583
# Criteria of current node: -0.29514632420614645
# Criteria of current node: -0.2991354795814152
# Criteria of current node: -0.31318326928280243
# Criteria of current node: -0.29255589099249574
# Criteria of current node: -0.2918469782683396
# Criteria of current node: -0.31558024637460347
# Criteria of current node: -0.3173593692536716
# Criteria of current node: -0.3007399455535823
# Criteria of current node: -0.2917709168237588
# Criteria of current node: -0.31618291019060923
# Criteria of current node: -0.3375940804345913
# Criteria of current node: -0.31029537092152454
# Criteria of current node: -0.30947502740923477
# Criteria of current node: -0.304483626840288
# Criteria of current node: -0.3041730258290301
# Criteria of current node: -0.2994547230159761
# Criteria of current node: -0.294350837320704
# Criteria of current node: -0.2915241566603579
# Criteria of current node: -0.2949054677525394
# Criteria of current node: -0.29144104234650536
# Criteria of current node: -0.31150613320722137
# Criteria of current node: -0.31631285749556515
# Criteria of current node: -0.337641278773996
# Criteria of current node: -0.2913585610275974
# Criteria of current node: -0.291118766576083
# Criteria of current node: -0.2922406015852045
# Criteria of current node: -0.3170850915942019
# Criteria of current node: -0.29617179646120717
# Criteria of current node: -0.2909759552742765
# Criteria of current node: -0.2945652887964946
# Criteria of current node: -0.29088625190740425
# Criteria of current node: -0.3223992111526921
# Criteria of current node: -0.2908309721053005
# Criteria of current node: -0.3310877031451701
# Criteria of current node: -0.30595924930845986
# Criteria of current node: -0.3060555192693596
# Criteria of current node: -0.2983085084323458
# Criteria of current node: -0.307749155581604
# Criteria of current node: -0.3200009661949627
# Criteria of current node: -0.29410572235607507
# Criteria of current node: -0.3157932461831433
# Criteria of current node: -0.3093149661816635
# Criteria of current node: -0.30404747914547947
# Criteria of current node: -0.3407037339210412
# Criteria of current node: -0.3524571150452702
# Criteria of current node: -0.32892421550106055
# Criteria of current node: -0.3205690860736254
# Criteria of current node: -0.32491755514453446
# Criteria of current node: -0.32050819489943344
# Criteria of current node: -0.3009745466439407
# Criteria of current node: -0.32316674842481496
# Criteria of current node: -0.31784815526321036
# Criteria of current node: -0.34906165808890144
# Criteria of current node: -0.3308376974586714
# Criteria of current node: -0.31854640962233655
# Criteria of current node: -0.30322677339977977
# Criteria of current node: -0.33028393169531045
# Criteria of current node: -0.3019206182494226
# Criteria of current node: -0.3014843390070339
# Criteria of current node: -0.2977429205980891
# Criteria of current node: -0.31619437804489947
# Criteria of current node: -0.3094696299743667
# Criteria of current node: -0.3002601855183322
# Criteria of current node: -0.3326172027027893
# Criteria of current node: -0.29826553298538894
# Criteria of current node: -0.2951918341662245
# Criteria of current node: -0.2950582882596586
# Criteria of current node: -0.29491768786439326
# Criteria of current node: -0.294170496296968
# Criteria of current node: -0.2975129681639457
# Criteria of current node: -0.2934900796956687
# Criteria of current node: -0.2920496341859152
# Criteria of current node: -0.2914664303417439
# Criteria of current node: -0.291394658951643
# Criteria of current node: -0.30449742919370576
# Criteria of current node: -0.3130291556608138
# Criteria of current node: -0.31367625243142905
# Criteria of current node: -0.2978130108535689
# Criteria of current node: -0.3102236930928317
# Criteria of current node: -0.34125188713567794
# Criteria of current node: -0.33314848656449153
# Criteria of current node: -0.34663318037777574
# Criteria of current node: -0.33302302318965316
# Criteria of current node: -0.32489540051826526
# Criteria of current node: -0.3143020017514697
# Criteria of current node: -0.3139399177752315
# Criteria of current node: -0.3054518803639893
# Criteria of current node: -0.31136313675847055
# Criteria of current node: -0.30773416693920924
# Criteria of current node: -0.31572470775901146
# Criteria of current node: -0.3009705876737599
# Criteria of current node: -0.3009288806778669
# Criteria of current node: -0.2970482874960387
# Criteria of current node: -0.3230222487025427
# Criteria of current node: -0.2961443235605194
# Criteria of current node: -0.2974131907723333
# Criteria of current node: -0.2954829875400229
# Criteria of current node: -0.29419356197751695
# Criteria of current node: -0.3251109237192557
# Criteria of current node: -0.316930001487994
# Criteria of current node: -0.29841155372845357
# Criteria of current node: -0.2933014704193888
# Criteria of current node: -0.29304014157410846
# Criteria of current node: -0.2922615891808671
# Criteria of current node: -0.2970689300208599
# Criteria of current node: -0.29130559499147207
# Criteria of current node: -0.29129210926631327
# Criteria of current node: -0.2912255042904768
# Criteria of current node: -0.29352430831228465
# Criteria of current node: -0.3035630628761149
# Criteria of current node: -0.29116921313910654
# Criteria of current node: -0.3254275649593582
# Criteria of current node: -0.3413805800912523
# Criteria of current node: -0.33361951919041855
# Criteria of current node: -0.33035151442215405
# Criteria of current node: -0.32034266689614893
# Criteria of current node: -0.31500113868026675
# Criteria of current node: -0.32690889201165396
# Criteria of current node: -0.308004906086672
# Criteria of current node: -0.3004585875368929
# Criteria of current node: -0.31010121835095217
# Criteria of current node: -0.293433511958382
# Criteria of current node: -0.29338926301889795
# Criteria of current node: -0.29077927597245823
# Criteria of current node: -0.2905829428958856
# Criteria of current node: -0.2950548343482212
# Criteria of current node: -0.29054486757310133
# Criteria of current node: -0.3046755009140597
# Criteria of current node: -0.34520470762445166
# Criteria of current node: -0.29812916939940154
# Criteria of current node: -0.2904149216099403
# Criteria of current node: -0.29031849984768543
# Criteria of current node: -0.290304124919552
# Criteria of current node: -0.32087053309096997
# Criteria of current node: -0.3038853860345927
# Criteria of current node: -0.31912397767262546
# Criteria of current node: -0.2984883818950174
# Criteria of current node: -0.2973684275845866
# Criteria of current node: -0.29561215187442025
# Criteria of current node: -0.31103334690175144
# Criteria of current node: -0.2996355204910848
# Criteria of current node: -0.30463337543072055
# Criteria of current node: -0.3360064690987512
# Criteria of current node: -0.320057563531761
# Criteria of current node: -0.30094369880819444
# Criteria of current node: -0.29498595450553644
# Criteria of current node: -0.31413453331727575
# Criteria of current node: -0.3012742875567792
# Criteria of current node: -0.2958819749939262
# Criteria of current node: -0.33948417783637874
# Criteria of current node: -0.3263274933164299
# Criteria of current node: -0.31961509237975466
# Criteria of current node: -0.3174373393748884
# Criteria of current node: -0.30898166455743875
# Criteria of current node: -0.32274019911712437
# Criteria of current node: -0.3095244235480143
# Criteria of current node: -0.31433399758085057
# Criteria of current node: -0.3261939179650273
# Criteria of current node: -0.3235557376942169
# Criteria of current node: -0.3107056138186223
# Criteria of current node: -0.35533947812116773
# Criteria of current node: -0.3053932589955177
# Criteria of current node: -0.3036214601359764
# Criteria of current node: -0.3028113090775393
# Criteria of current node: -0.30071462123435005
# Criteria of current node: -0.3000899960877576
# Criteria of current node: -0.29973232031257485
# Criteria of current node: -0.299725664559366
# Criteria of current node: -0.29874546526026907
# Criteria of current node: -0.29847267291251706
# Criteria of current node: -0.2941791442733239
# Criteria of current node: -0.2939726424897267
# Criteria of current node: -0.3449462538053739
# Criteria of current node: -0.3280895795452415
# Criteria of current node: -0.3233142329185969
# Criteria of current node: -0.3143199682030618
# Criteria of current node: -0.2970327862411338
# Criteria of current node: -0.2938764569470651
# Criteria of current node: -0.2937739981038321
# Criteria of current node: -0.3438065025153115
# Criteria of current node: -0.3209514075778317
# Criteria of current node: -0.2935847547091975
# Criteria of current node: -0.2931737514174145
# Criteria of current node: -0.2929164193928569
# Criteria of current node: -0.3066113515156487
# Criteria of current node: -0.2954173410650054
# Criteria of current node: -0.3055054160140282
# Criteria of current node: -0.29513399641324906
# Criteria of current node: -0.2942858310195024
# Criteria of current node: -0.29212585938377567
# Criteria of current node: -0.2972259972653687
# Criteria of current node: -0.29349052029119826
# Criteria of current node: -0.3149712229468782
# Criteria of current node: -0.31256444396085786
# Criteria of current node: -0.31941440919673375
# Criteria of current node: -0.30439467515758734
# Criteria of current node: -0.3038759779958794
# Criteria of current node: -0.33217608786410047
# Criteria of current node: -0.3076313637276814
# Criteria of current node: -0.30734377729047396
# Criteria of current node: -0.30369485383373596
# Criteria of current node: -0.3031853558256009
# Criteria of current node: -0.2980515453118694
# Criteria of current node: -0.3052174149848766
# Criteria of current node: -0.313444295628555
# Criteria of current node: -0.3041313327720079
# Criteria of current node: -0.2992973495641729
# Criteria of current node: -0.2976298548359585
# Criteria of current node: -0.30393186193469285
# Criteria of current node: -0.3019713248345458
# Criteria of current node: -0.29993506680324716
# Criteria of current node: -0.2954723764026856
# Criteria of current node: -0.36120271554755884
# Criteria of current node: -0.32697089261274537
# Criteria of current node: -0.308363615456529
# Criteria of current node: -0.30621809358985674
# Criteria of current node: -0.30979487179549087
# Criteria of current node: -0.32242629981931836
# Criteria of current node: -0.31604287115120827
# Criteria of current node: -0.3219007553111891
# Criteria of current node: -0.32028052297722626
# Criteria of current node: -0.3143853521626815
# Criteria of current node: -0.3141837409564209
# Criteria of current node: -0.3083791187196925
# Criteria of current node: -0.3116647563426513
# Criteria of current node: -0.3039828958570474
# Criteria of current node: -0.3075910267138309
# Criteria of current node: -0.303483685747741
# Criteria of current node: -0.3023409058833247
# Criteria of current node: -0.3019481820545993
# Criteria of current node: -0.30122317011363126
# Criteria of current node: -0.3039723026612606
# Criteria of current node: -0.29911386470385354
# Criteria of current node: -0.2989621681836265
# Criteria of current node: -0.29830633293671915
# Criteria of current node: -0.3125334625425688
# Criteria of current node: -0.3252202930305396
# Criteria of current node: -0.30428398380617483
# Criteria of current node: -0.3044190939410181
# Criteria of current node: -0.31981085936807163
# Criteria of current node: -0.31084266527304816
# Criteria of current node: -0.30007623599040933
# Criteria of current node: -0.29982042499182276
# Criteria of current node: -0.2978114344602001
# Criteria of current node: -0.33209326517941334
# Criteria of current node: -0.32380060074810757
# Criteria of current node: -0.31432975161005156
# Criteria of current node: -0.3044735165977007
# Criteria of current node: -0.3012259384809697
# Criteria of current node: -0.3009217494145572
# Criteria of current node: -0.31343977807151946
# Criteria of current node: -0.3326387142595949
# Criteria of current node: -0.30006385128572666
# Criteria of current node: -0.29927664845517266
# Criteria of current node: -0.320135474832502
# Criteria of current node: -0.3131300199644431
# Criteria of current node: -0.3027732165113939
# Criteria of current node: -0.29882705723402936
# Criteria of current node: -0.297732276345352
# Criteria of current node: -0.3123665996162155
# Criteria of current node: -0.3016614854089985
# Criteria of current node: -0.30135770385694016
# Criteria of current node: -0.29720760947487845
# Criteria of current node: -0.3022831175793578
# Criteria of current node: -0.296728410078654
# Criteria of current node: -0.3044730690726572
# Criteria of current node: -0.29663889092326684
# Criteria of current node: -0.29562182341172805
# Criteria of current node: -0.29549181569891464
# Criteria of current node: -0.2952923658333095
# Criteria of current node: -0.30243306714356144
# Criteria of current node: -0.31566311504932515
# Criteria of current node: -0.3021508825202478
# Criteria of current node: -0.32020499974113203
# Criteria of current node: -0.29554886656727775
# Criteria of current node: -0.32366123785943846
# Criteria of current node: -0.29482894051410036
# Criteria of current node: -0.2947165728422785
# Criteria of current node: -0.29463964831059686
# Criteria of current node: -0.29405243789348123
# Criteria of current node: -0.35030283224573733
# Criteria of current node: -0.3102404305903136
# Criteria of current node: -0.29600691283939207
# Criteria of current node: -0.3108803839360477
# Criteria of current node: -0.30778123146764563
# Criteria of current node: -0.30305621606345046
# Criteria of current node: -0.3025642643992148
# Criteria of current node: -0.297521078967642
# Criteria of current node: -0.296964537613933
# Criteria of current node: -0.29349912692940616
# Criteria of current node: -0.30344650593641426
# Criteria of current node: -0.3272973363684846
# Criteria of current node: -0.3112625191578225
# Criteria of current node: -0.30913150199737155
# Criteria of current node: -0.3077490269364526
# Criteria of current node: -0.29326874965168187
# Criteria of current node: -0.29294911421135017
# Criteria of current node: -0.2995591716445987
# Criteria of current node: -0.31174484005503406
# Criteria of current node: -0.30095210184472676
# Criteria of current node: -0.3108836817844379
# Criteria of current node: -0.306436785471739
# Criteria of current node: -0.2935665672844547
# Criteria of current node: -0.3114031655600487
# Criteria of current node: -0.292648991643568
# Criteria of current node: -0.2922521976228459
# Criteria of current node: -0.292161112752056
# Criteria of current node: -0.29201862176147286
# Criteria of current node: -0.3039480048872862
# Criteria of current node: -0.2918858237109463
# Criteria of current node: -0.2912363840920282
# Criteria of current node: -0.2911811816729171
# Criteria of current node: -0.29111082488478746
# Criteria of current node: -0.2909533374650076
# Criteria of current node: -0.29089515893177614
# Criteria of current node: -0.2907994590605441
# Criteria of current node: -0.30037286114568745
# Criteria of current node: -0.2907483271650885
# Criteria of current node: -0.29985438837274575
# Criteria of current node: -0.29048202134198053
# Criteria of current node: -0.2904038616106695
# Criteria of current node: -0.2927414741736374
# Criteria of current node: -0.29038641390621495
# Criteria of current node: -0.2902780591599018
# Criteria of current node: -0.3059283678592847
# Criteria of current node: -0.3165617026897196
# Criteria of current node: -0.30795809390429235
# Criteria of current node: -0.3059488941879762
# Criteria of current node: -0.3036325116221026
# Criteria of current node: -0.30524264808355267
# Criteria of current node: -0.32647001837871903
# Criteria of current node: -0.32720119956930044
# Criteria of current node: -0.3136835527793052
# Criteria of current node: -0.31204650359377595
# Criteria of current node: -0.3214018662557773
# Criteria of current node: -0.3286059324907876
# Criteria of current node: -0.32128969038213934
# Criteria of current node: -0.3091442486158208
# Criteria of current node: -0.30676514577376496
# Criteria of current node: -0.3068465089169314
# Criteria of current node: -0.31089739844566355
# Criteria of current node: -0.30253865275715575
# Criteria of current node: -0.3019245047604867
# Criteria of current node: -0.31450630635719495
# Criteria of current node: -0.32119615196133433
# Criteria of current node: -0.315526570814832
# Criteria of current node: -0.30024736848803113
# Criteria of current node: -0.2997057604953169
# Criteria of current node: -0.2991134509477892
# Criteria of current node: -0.2984252638042865
# Criteria of current node: -0.34653395231214223
# Criteria of current node: -0.30539826191724706
# Criteria of current node: -0.30478856015549427
# Criteria of current node: -0.302689179317517
# Criteria of current node: -0.3317607444570165
# Criteria of current node: -0.30106992966064194
# Criteria of current node: -0.3391118383076572
# Criteria of current node: -0.32965121246933193
# Criteria of current node: -0.32935302911838127
# Criteria of current node: -0.3151897576045509
# Criteria of current node: -0.30877953861810037
# Criteria of current node: -0.3015233034917102
# Criteria of current node: -0.29986652990621515
# Criteria of current node: -0.2968963562628466
# Criteria of current node: -0.3075213086009134
# Criteria of current node: -0.3087821052474143
# Criteria of current node: -0.295656465716486
# Criteria of current node: -0.3263272411577766
# Criteria of current node: -0.30250535244673593
# Criteria of current node: -0.2949217551838547
# Criteria of current node: -0.3152384755205947
# Criteria of current node: -0.30361586034043875
# Criteria of current node: -0.29484803739400905
# Criteria of current node: -0.3044238043614096
# Criteria of current node: -0.3284896317259542
# Criteria of current node: -0.3151454550290218
# Criteria of current node: -0.3088057979951918
# Criteria of current node: -0.30714484036918244
# Criteria of current node: -0.29719410804099633
# Criteria of current node: -0.2946538072267937
# Criteria of current node: -0.29766986672618256
# Criteria of current node: -0.2967759451648327
# Criteria of current node: -0.29459106996137796
# Criteria of current node: -0.3566639951720125
# Criteria of current node: -0.3441739768835971
# Criteria of current node: -0.313035724047834
# Criteria of current node: -0.3070001567703988
# Criteria of current node: -0.3348891345571789
# Criteria of current node: -0.31630169415035947
# Criteria of current node: -0.3146460065950675
# Criteria of current node: -0.3132929717336184
# Criteria of current node: -0.31733131431171724
# Criteria of current node: -0.31133179043402415
# Criteria of current node: -0.30163651993983526
# Criteria of current node: -0.2982079890203035
# Criteria of current node: -0.2980655457716755
# Criteria of current node: -0.29583952948361025
# Criteria of current node: -0.3334929563702562
# Criteria of current node: -0.32919586132993905
# Criteria of current node: -0.3243506817792755
# Criteria of current node: -0.3105240436722895
# Criteria of current node: -0.30976722785697725
# Criteria of current node: -0.30708814500638737
# Criteria of current node: -0.30636853319653873
# Criteria of current node: -0.3038755694140086
# Criteria of current node: -0.3026791912755744
# Criteria of current node: -0.302603731856514
# Criteria of current node: -0.3007831524722824
# Criteria of current node: -0.3218959309261997
# Criteria of current node: -0.3372180489861553
# Criteria of current node: -0.3226801432700964
# Criteria of current node: -0.31619770439060035
# Criteria of current node: -0.30019466167845144
# Criteria of current node: -0.29833274167453727
# Criteria of current node: -0.29603428423255507
# Criteria of current node: -0.2954533513132819
# Criteria of current node: -0.31562436571524366
# Criteria of current node: -0.29551205918470697
# Criteria of current node: -0.3097626938121451
# Criteria of current node: -0.29829990776405646
# Criteria of current node: -0.29510649167712216
# Criteria of current node: -0.2949196529882956
# Criteria of current node: -0.3043192475823515
# Criteria of current node: -0.30061647180501333
# Criteria of current node: -0.2948957235219898
# Criteria of current node: -0.2947467532886653
# Criteria of current node: -0.2944904977353868
# Criteria of current node: -0.30030976738783716
# Criteria of current node: -0.3057701007922321
# Criteria of current node: -0.2967707813890069
# Criteria of current node: -0.2944665244587882
# Criteria of current node: -0.31719685954241966
# Criteria of current node: -0.2950433820644529
# Criteria of current node: -0.29415233689096987
# Criteria of current node: -0.3551586349043673
# Criteria of current node: -0.33437421517863664
# Criteria of current node: -0.3259699052256828
# Criteria of current node: -0.3182850959274369
# Criteria of current node: -0.3142984797948066
# Criteria of current node: -0.32101920294720576
# Criteria of current node: -0.3080963534790932
# Criteria of current node: -0.30788962960649796
# Criteria of current node: -0.3028513825369462
# Criteria of current node: -0.2990873411692131
# Criteria of current node: -0.29853668121052973
# Criteria of current node: -0.2941044326891049
# Criteria of current node: -0.29371430881817234
# Criteria of current node: -0.31374897229213145
# Criteria of current node: -0.31042941771486
# Criteria of current node: -0.2979177972329931
# Criteria of current node: -0.2935134623681275
# Criteria of current node: -0.29292215562501683
# Criteria of current node: -0.2946900130024599
# Criteria of current node: -0.31217622464787326
# Criteria of current node: -0.30007244521855503
# Criteria of current node: -0.3263873482253371
# Criteria of current node: -0.3185444820388055
# Criteria of current node: -0.303567888844417
# Criteria of current node: -0.30483931796891967
# Criteria of current node: -0.298892019926806
# Criteria of current node: -0.2986683387232369
# Criteria of current node: -0.29772723984341987
# Criteria of current node: -0.2972107871681279
# Criteria of current node: -0.2967266822160172
# Criteria of current node: -0.2961748561574492
# Criteria of current node: -0.2961359352883925
# Criteria of current node: -0.30141172625290885
# Criteria of current node: -0.30885625668991
# Criteria of current node: -0.2941432424185868
# Criteria of current node: -0.3155383713148698
# Criteria of current node: -0.2945479523348295
# Criteria of current node: -0.2931867209011972
# Criteria of current node: -0.34420574295255263
# Criteria of current node: -0.33527259612478577
# Criteria of current node: -0.3343239794513169
# Criteria of current node: -0.32916683602136865
# Criteria of current node: -0.31923099869783966
# Criteria of current node: -0.3126674298381164
# Criteria of current node: -0.31220805813070945
# Criteria of current node: -0.30789315549654434
# Criteria of current node: -0.31676734083306796
# Criteria of current node: -0.31357539228649733
# Criteria of current node: -0.30585616728777226
# Criteria of current node: -0.2993659090746079
# Criteria of current node: -0.2970523457162072
# Criteria of current node: -0.3136816563639509
# Criteria of current node: -0.3066653805881785
# Criteria of current node: -0.3321718009638833
# Criteria of current node: -0.29606688819031307
# Criteria of current node: -0.29497544749094196
# Criteria of current node: -0.29317227608030827
# Criteria of current node: -0.29284940426069556
# Criteria of current node: -0.29282115612646714
# Criteria of current node: -0.29262811268832645
# Criteria of current node: -0.29262648847990813
# Criteria of current node: -0.296250921925742
# Criteria of current node: -0.2925152689024523
# Criteria of current node: -0.31675097231865634
# Criteria of current node: -0.2923530304670889
# Criteria of current node: -0.3315647488121636
# Criteria of current node: -0.31477081170713644
# Criteria of current node: -0.31767259714595775
# Criteria of current node: -0.31348386785824617
# Criteria of current node: -0.31150676279470435
# Criteria of current node: -0.30171546326791154
# Criteria of current node: -0.3191995677412454
# Criteria of current node: -0.3146349319027372
# Criteria of current node: -0.32863824585248963
# Criteria of current node: -0.33688096878513607
# Criteria of current node: -0.3407993636466893
# Criteria of current node: -0.31557106253617023
# Criteria of current node: -0.3045387897766113
# Criteria of current node: -0.3010041888069934
# Criteria of current node: -0.3004899635608906
# Criteria of current node: -0.3043756926017496
# Criteria of current node: -0.2995708405744175
# Criteria of current node: -0.3053561133245971
# Criteria of current node: -0.31660112233103826
# Criteria of current node: -0.3058714798949099
# Criteria of current node: -0.3066282827424764
# Criteria of current node: -0.3063964144061068
# Criteria of current node: -0.2950746945552148
# Criteria of current node: -0.2943775834304862
# Criteria of current node: -0.31103663392141306
# Criteria of current node: -0.3187185520418085
# Criteria of current node: -0.3103516172622367
# Criteria of current node: -0.30358714285379634
# Criteria of current node: -0.30080999425839094
# Criteria of current node: -0.30841722004668176
# Criteria of current node: -0.29421135286969824
# Criteria of current node: -0.29392910404591643
# Criteria of current node: -0.29386904458068186
# Criteria of current node: -0.2931500122603026
# Criteria of current node: -0.2931214976234551
# Criteria of current node: -0.2926504127541693
# Criteria of current node: -0.2923400797344609
# Criteria of current node: -0.2922806687021309
# Criteria of current node: -0.3218492812104907
# Criteria of current node: -0.31946734430195356
# Criteria of current node: -0.315608535639702
# Criteria of current node: -0.309641270025528
# Criteria of current node: -0.30940149322592764
# Criteria of current node: -0.3041458280828206
# Criteria of current node: -0.2986733324239012
# Criteria of current node: -0.30147408571032563
# Criteria of current node: -0.29589759243541885
# Criteria of current node: -0.29411447566279975
# Criteria of current node: -0.2955208095214789
# Criteria of current node: -0.3001339713373467
# Criteria of current node: -0.30514707359661447
# Criteria of current node: -0.31027298997096764
# Criteria of current node: -0.2946999624967157
# Criteria of current node: -0.2925774466130792
# Criteria of current node: -0.29227284220310523
# Criteria of current node: -0.29227081271645233
# Criteria of current node: -0.29209463319191803
# Criteria of current node: -0.31085192779505266
# Criteria of current node: -0.300240306650907
# Criteria of current node: -0.29200951792432367
# Criteria of current node: -0.2919281531571037
# Criteria of current node: -0.29162252884626916
# Criteria of current node: -0.31199830174499205
# Criteria of current node: -0.3046633164334096
# Criteria of current node: -0.3620557354566119
# Criteria of current node: -0.32635499469027346
# Criteria of current node: -0.3221369533386172
# Criteria of current node: -0.301335592873185
# Criteria of current node: -0.30067371322070297
# Criteria of current node: -0.31969866138073105
# Criteria of current node: -0.3656752445260574
# Criteria of current node: -0.3495841635236834
# Criteria of current node: -0.33131465252805625
# Criteria of current node: -0.32636795205571134
# Criteria of current node: -0.3169916522936272
# Criteria of current node: -0.3121447299191067
# Criteria of current node: -0.3177366800191808
# Criteria of current node: -0.31175871987637493
# Criteria of current node: -0.308140552287505
# Criteria of current node: -0.307720320045079
# Criteria of current node: -0.3059981146285011
# Criteria of current node: -0.3048144827442325
# Criteria of current node: -0.297923082967794
# Criteria of current node: -0.30247377340237
# Criteria of current node: -0.30844070505864934
# Criteria of current node: -0.3007445167372914
# Criteria of current node: -0.2966780072670421
# Criteria of current node: -0.2965468501610516
# Criteria of current node: -0.2955612171334261
# Criteria of current node: -0.304825272203741
# Criteria of current node: -0.29505527046753605
# Criteria of current node: -0.29430321405542614
# Criteria of current node: -0.33214346566276576
# Criteria of current node: -0.2997034423697178
# Criteria of current node: -0.3117194203696135
# Criteria of current node: -0.33121451162631166
# Criteria of current node: -0.32674362427558856
# Criteria of current node: -0.31749057813692133
# Criteria of current node: -0.31560064132291954
# Criteria of current node: -0.30541490606957217
# Criteria of current node: -0.29836791124307405
# Criteria of current node: -0.2978737198123771
# Criteria of current node: -0.30991165650853597
# Criteria of current node: -0.29847561248062315
# Criteria of current node: -0.30194736488967916
# Criteria of current node: -0.3005442480218749
# Criteria of current node: -0.3147821147580977
# Criteria of current node: -0.29520450901598355
# Criteria of current node: -0.2938243527030281
# Criteria of current node: -0.3131478510332381
# Criteria of current node: -0.3484670538726747
# Criteria of current node: -0.3396948016559159
# Criteria of current node: -0.3324977031668774
# Criteria of current node: -0.3203935527229302
# Criteria of current node: -0.30518386064338326
# Criteria of current node: -0.3041567182559603
# Criteria of current node: -0.3003401443179538
# Criteria of current node: -0.33162618076071143
# Criteria of current node: -0.32866865892198743
# Criteria of current node: -0.3131780610927845
# Criteria of current node: -0.3335131295307068
# Criteria of current node: -0.3192303873334851
# Criteria of current node: -0.3209996765534042
# Criteria of current node: -0.30089803370731855
# Criteria of current node: -0.30008229359039684
# Criteria of current node: -0.2973781058823499
# Criteria of current node: -0.3171949673585134
# Criteria of current node: -0.29728059191908596
# Criteria of current node: -0.3446658237113173
# Criteria of current node: -0.3126834772791029
# Criteria of current node: -0.33421740631147295
# Criteria of current node: -0.3260570040225602
# Criteria of current node: -0.31269276141484353
# Criteria of current node: -0.3118310398661981
# Criteria of current node: -0.3100610582251065
# Criteria of current node: -0.34415829507494317
# Criteria of current node: -0.32273352359473745
# Criteria of current node: -0.31907471913270535
# Criteria of current node: -0.3063621064140333
# Criteria of current node: -0.30428492579946875
# Criteria of current node: -0.33991045130531444
# Criteria of current node: -0.32039852124455964
# Criteria of current node: -0.33090009029160206
# Criteria of current node: -0.32024906912122675
# Criteria of current node: -0.3435965783946088
# Criteria of current node: -0.3416076108843405
# Criteria of current node: -0.33430326513174347
# Criteria of current node: -0.31691356822948435
# Criteria of current node: -0.34187221745431423
# Criteria of current node: -0.31633957326838685
# Criteria of current node: -0.31421472747109297
# Criteria of current node: -0.30858008811065846
# Criteria of current node: -0.3079535569632847
# Criteria of current node: -0.326043212574165
# Criteria of current node: -0.3203922335816567
# Criteria of current node: -0.30342072513594504
# Criteria of current node: -0.3090730164331821
# Criteria of current node: -0.30258172648766385
# Criteria of current node: -0.302055635405614
# Criteria of current node: -0.30186736982196394
# Criteria of current node: -0.30166178639061625
# Criteria of current node: -0.31470941829019955
# Criteria of current node: -0.31047495448528223
# 1000

# %%
astar.best_criteria_value
# Out:
# -0.40223063284406996
