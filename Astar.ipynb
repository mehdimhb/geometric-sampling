# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
import graphical_sampling as gs
import pandas as pd
import numpy as np
import itertools
from tqdm import tqdm
from package_sampling.utils import inclusion_probabilities
# Out:
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "XPC_SERVICE_NAME" redefined by R and overriding existing variable. Current: "application.com.jetbrains.pycharm.1003326.4172874", R: "0"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmplpaba5", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ"
#   warnings.warn(

# %% [markdown]
# # Loading and Determining Population

# %%
DATA_DIR = "populations"
csv_paths = glob.glob(os.path.join(DATA_DIR, "*.csv"))

coords_dict = {}
probs_dict = {}

for fp in csv_paths:
    name = os.path.splitext(os.path.basename(fp))[0]
    data = np.loadtxt(fp, delimiter=",", skiprows=1)
    coords = data[:, :2]
    probs  = data[:, -1]

    coord_name, prob_name, *rest = name.split("_")
    coord_name = 'cluster' if coord_name == 'clust' else coord_name
    prob_name = 'equal' if prob_name == 'eq' else 'unequal'

    coords_dict[coord_name] = coords
    probs_dict[coord_name] = probs_dict.get(coord_name, {})
    probs_dict[coord_name][prob_name] = probs

print(coords_dict.keys())
print(probs_dict.keys())
print(probs_dict['random'].keys())
# Out:
# dict_keys(['swiss', 'cluster', 'meuse', 'random', 'grid'])
# dict_keys(['swiss', 'cluster', 'meuse', 'random', 'grid'])
# dict_keys(['equal', 'unequal'])

# %%
N = 100
n = 15
coords = coords_dict['meuse']
probs = probs_dict['meuse']['equal']
modified_probs = inclusion_probabilities(probs, n=n)
pop = gs.Population(coords, modified_probs)

# %% [markdown]
# # Building Initial Designs

# %%
orders = [
    # "lexico-yx",
    "lexico-xy",
    # "random",
    # "angle_0",
    "distance_0",
    "projection",
    # "center",
    "spiral",
    "max",
    "snake",
    "hilbert",
]

# %%
initial_designs = []
combines = list(itertools.product(orders, orders))
num_trials = 2
for units_order, zones_order in tqdm(combines, desc="Generating initial designs", total=len(combines), unit="orders"):
    best = None
    best_score = np.inf
    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=(2, 2),
            zone_builder='sweep',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))

    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=4,
            zone_builder='cluster',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=(1, 1),
            zone_builder='sweep',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))

    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=3,
            zone_builder='cluster',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))
# Out:
# Generating initial designs:   0%|          | 0/49 [00:00<?, ?orders/s]/Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmp5WgeSf"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpX5A93E"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpksTKOn"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpFbNV1Z"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpbhJphv"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmphLIq8q"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpFzzAuI"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmpi88JP5"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmp5evj2Y"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpXJkBKQ", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmppG6F0w"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmp5WgeSf", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpmZf61q"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpX5A93E", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpHaWlqn"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpksTKOn", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpAlDahv"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpbhJphv", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpoFH7QW"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmphLIq8q", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpchHarr"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpFbNV1Z", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpP8NQVF"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpFzzAuI", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpAX1OOw"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmpi88JP5", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpA4uwYb"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//Rtmp5evj2Y", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpoxCVH2"
#   warnings.warn(
# /Users/mehdi/Documents/Projects/graphical_sampling/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmppG6F0w", R: "/var/folders/tw/x1njhbdj7q19p65g47mw5dqm0000gn/T//RtmpfjqQag"
#   warnings.warn(
# Generating initial designs:   2%|▏         | 1/49 [00:15<12:14, 15.30s/orders]

# %%
for design in initial_designs:
    print(design.kmeans.all_samples.shape, design.kmeans.expected_moran_score())
# Out:
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (10, 15) -0.3557123143767697
# (8, 15) -0.36751426386191205
# (8, 15) -0.36751426386191205
# (8, 15) -0.29755027097419867
# (8, 15) -0.3730747089819494
# (8, 15) -0.3730747089819494
# (9, 15) -0.3929755333256541
# (9, 15) -0.3929755333256541
# (9, 15) -0.3929755333256541
# (6, 15) -0.24211979291518318
# (8, 15) -0.37280822807561403
# (8, 15) -0.37280822807561403
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (8, 15) -0.27007561498221755
# (8, 15) -0.33923474783055985
# (8, 15) -0.33923474783055985
# (10, 15) -0.40645880331091766
# (10, 15) -0.40645880331091766
# (10, 15) -0.40645880331091766
# (10, 15) -0.35803559126953166
# (9, 15) -0.36035021935386685
# (9, 15) -0.36035021935386685
# (11, 15) -0.38887723440056926
# (11, 15) -0.38887723440056926
# (11, 15) -0.38887723440056926
# (9, 15) -0.3949806730318942
# (9, 15) -0.3949806730318942
# (9, 15) -0.3949806730318942
# (10, 15) -0.3429148581118533
# (8, 15) -0.3638272252073207
# (8, 15) -0.3638272252073207
# (10, 15) -0.40645880331091766
# (10, 15) -0.40645880331091766
# (10, 15) -0.40645880331091766
# (11, 15) -0.3608416929874313
# (11, 15) -0.3608416929874313
# (11, 15) -0.3608416929874313
# (10, 15) -0.38759789614681533
# (10, 15) -0.38759789614681533
# (10, 15) -0.38759789614681533
# (9, 15) -0.3694602986307177
# (9, 15) -0.3694602986307177
# (9, 15) -0.3694602986307177
# (10, 15) -0.398913660843564
# (10, 15) -0.398913660843564
# (10, 15) -0.398913660843564
# (9, 15) -0.3888668975141806
# (9, 15) -0.3888668975141806
# (9, 15) -0.3888668975141806
# (10, 15) -0.3064689700035303
# (8, 15) -0.3445243623718991
# (8, 15) -0.3445243623718991
# (10, 15) -0.38759789614681533
# (10, 15) -0.38759789614681533
# (10, 15) -0.38759789614681533
# (10, 15) -0.32537629205153645
# (6, 15) -0.3391930413200878
# (6, 15) -0.3391930413200878
# (7, 15) -0.3779527408729577
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (8, 15) -0.3789720196444035
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (9, 15) -0.3533341249302945
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (8, 15) -0.3981705451231995
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (7, 15) -0.30652786082039973
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (7, 15) -0.3779527408729577
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (9, 15) -0.31738658094795574
# (2, 15) -0.5175787246740949
# (2, 15) -0.5175787246740949
# (12, 15) -0.4008997543001729
# (12, 15) -0.4008997543001729
# (12, 15) -0.4008997543001729
# (14, 15) -0.31936437000048673
# (14, 15) -0.31936437000048673
# (14, 15) -0.31936437000048673
# (13, 15) -0.3240932532058098
# (13, 15) -0.3240932532058098
# (13, 15) -0.3240932532058098
# (11, 15) -0.40273262276132643
# (11, 15) -0.40273262276132643
# (11, 15) -0.40273262276132643
# (12, 15) -0.3168925061817569
# (10, 15) -0.3226518500285387
# (10, 15) -0.3226518500285387
# (12, 15) -0.4008997543001729
# (12, 15) -0.4008997543001729
# (12, 15) -0.4008997543001729
# (13, 15) -0.31648811797834714
# (13, 15) -0.31648811797834714
# (13, 15) -0.31648811797834714
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (10, 15) -0.3557123143767697
# (8, 15) -0.36751426386191205
# (8, 15) -0.36751426386191205
# (8, 15) -0.29755027097419867
# (8, 15) -0.3730747089819494
# (8, 15) -0.3730747089819494
# (9, 15) -0.3929755333256541
# (9, 15) -0.3929755333256541
# (9, 15) -0.3929755333256541
# (6, 15) -0.24211979291518318
# (8, 15) -0.372808228075614
# (8, 15) -0.372808228075614
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (8, 15) -0.39707465639616435
# (8, 15) -0.27007561498221755
# (8, 15) -0.3392347478305599
# (8, 15) -0.3392347478305599
# (12, 15) -0.37404376775646536
# (12, 15) -0.37404376775646536
# (9, 15) -0.3923745688500893
# (12, 15) -0.3350485205395125
# (8, 15) -0.3626082775604614
# (8, 15) -0.3626082775604614
# (13, 15) -0.36844018959737457
# (13, 15) -0.36844018959737457
# (13, 15) -0.36844018959737457
# (11, 15) -0.38499278433610645
# (11, 15) -0.38499278433610645
# (11, 15) -0.38499278433610645
# (12, 15) -0.31917294362909726
# (9, 15) -0.34373672595884275
# (9, 15) -0.34373672595884275
# (12, 15) -0.37404376775646536
# (12, 15) -0.37404376775646536
# (9, 15) -0.3923745688500893
# (12, 15) -0.3453605833373934
# (12, 15) -0.3453605833373934
# (12, 15) -0.3453605833373934

# %%
ks: gs.sampling.KMeansSampler = initial_designs[-1].kmeans
ks.all_samples
# Out:
# array([[128,  97,  34, 101,  38, 104, 137,  11, 110,  46, 147, 115, 122,
#          91,  94],
#        [129, 153,   1,   5, 136,  40,  74, 107, 140,  79,  48, 114,  52,
#         121,  27],
#        [ 96,  34, 105,  10,  74, 110, 142,  15, 145,  92,  19, 154, 124,
#          61, 126],
#        [102,   7,  73,  10,  42, 111,  82, 116, 149,  22, 119,  54, 152,
#          94,  31],
#        [ 96,  34, 105,  74, 110, 142,  15, 145,  29,  19,  92, 154, 124,
#          61, 126],
#        [ 32, 128,  97,  68, 101,  38, 104, 137,  11,  46, 147, 115, 122,
#          91,  94],
#        [102,   7,  73,  10,  42, 111,  49,  82, 116, 149,  20,  54, 152,
#          94,  31],
#        [102,   7,  73,  10,  42, 111,  82, 116, 149,  20, 119,  54, 152,
#          94,  31],
#        [129, 153,   1,   5, 136,  40,  74, 107, 140,  79,  48,  84, 121,
#          27, 124],
#        [102,   7,  73,  42,  11, 111,  49,  82, 116, 149,  20,  54, 152,
#          94,  31],
#        [129, 153,   1,   5, 136,  40,  74, 107, 140,  79,  48,  52,  84,
#         121,  27],
#        [129, 153,   1,   5, 136,  40,  74, 107, 140,  79,  48, 114,  52,
#         121,  26]])

# %%
x = 1
for s, p in zip(ks.all_samples, ks.all_samples_probs):
# Out:
# [128  97  34 101  38 104 137  11 110  46 147 115 122  91  94] 0.16162288000000002
# [129 153   1   5 136  40  74 107 140  79  48 114  52 121  27] 0.16062520800000005
# [ 96  34 105  10  74 110 142  15 145  92  19 154 124  61 126] 0.16162288
# [102   7  73  10  42 111  82 116 149  22 119  54 152  94  31] 0.080894579
# [ 96  34 105  74 110 142  15 145  29  19  92 154 124  61 126] 0.08837711999999999
# [ 32 128  97  68 101  38 104 137  11  46 147 115 122  91  94] 0.08837711999999999
# [102   7  73  10  42 111  49  82 116 149  20  54 152  94  31] 0.015962754
# [102   7  73  10  42 111  82 116 149  20 119  54 152  94  31] 0.08081144000000001
# [129 153   1   5 136  40  74 107 140  79  48  84 121  27 124] 0.08081144000000001
# [102   7  73  42  11 111  49  82 116 149  20  54 152  94  31] 0.072331227
# [129 153   1   5 136  40  74 107 140  79  48  52  84 121  27] 0.008480213
# [129 153   1   5 136  40  74 107 140  79  48 114  52 121  26] 8.3139e-05

# %% [markdown]
# # Run

# %%
moran_criteria = gs.criteria.MoranCriteria()

# %%
astar = gs.search.AStar(
    initial_designs,
    moran_criteria
)
# Out:
# best initial criteria value -0.5175787246740949

# %%
astar.run(
    max_iterations = 1000,
    num_new_nodes = 10,
    max_open_set_size = 1000,
    n_clusters_to_change_order_zone = 'None',
    n_clusters_to_change_order_units = 'all',
    n_zones_to_change_order_units = 'all',
    n_changes_in_order_of_units = 1,
    n_changes_in_order_of_zones = 1,
)
# Out:
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
#
# ==============================================
# New best criteria value: -0.5252990012754026
# Criteria of current node: -0.5252990012754026
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.5175787246740949
# Criteria of current node: -0.502300616098327
# Criteria of current node: -0.48401532242622414
# Criteria of current node: -0.4733015224859966
# Criteria of current node: -0.47131112712576895
# Criteria of current node: -0.4659844674194494
# Criteria of current node: -0.4659465051587057
# Criteria of current node: -0.4659465051587057
# Criteria of current node: -0.4656405505499098
# Criteria of current node: -0.46688853111513706
# Criteria of current node: -0.4630086730887602
# Criteria of current node: -0.46263702712593585
# Criteria of current node: -0.45868672410434047
# Criteria of current node: -0.4585114445499785
# Criteria of current node: -0.4536176130125571
# Criteria of current node: -0.45021316912611997
# Criteria of current node: -0.4459018500030128
# Criteria of current node: -0.44485512448892445
# Criteria of current node: -0.4387627032874153
# Criteria of current node: -0.42992703978747
# Criteria of current node: -0.4291199847575545
# Criteria of current node: -0.42760894294171875
# Criteria of current node: -0.4212236356505693
# Criteria of current node: -0.41648324325096464
# Criteria of current node: -0.4129617557749821
# Criteria of current node: -0.4073436276889914
# Criteria of current node: -0.40761284809523973
# Criteria of current node: -0.5061651495120322
# Criteria of current node: -0.4708903884714285
# Criteria of current node: -0.4560393370060305
# Criteria of current node: -0.4429993460119974
# Criteria of current node: -0.43745955118047714
# Criteria of current node: -0.4250984499810477
# Criteria of current node: -0.424892458440209
# Criteria of current node: -0.42104596175102027
# Criteria of current node: -0.41315784593812366
# Criteria of current node: -0.4143166507651473
# Criteria of current node: -0.40773221231064827
# Criteria of current node: -0.40645880331091766
# Criteria of current node: -0.4119450878289457
# Criteria of current node: -0.40749521749216755
# Criteria of current node: -0.44166805939763787
# Criteria of current node: -0.41422037005405027
# Criteria of current node: -0.40645880331091766
# Criteria of current node: -0.43644339215556116
# Criteria of current node: -0.408947491384394
# Criteria of current node: -0.40645880331091766
# Criteria of current node: -0.4109074527063157
# Criteria of current node: -0.40645880331091766
# Criteria of current node: -0.40645880331091766
# Criteria of current node: -0.40645880331091766
# Criteria of current node: -0.4060864562567889
# Criteria of current node: -0.40729357284138906
# Criteria of current node: -0.40473783086341897
# Criteria of current node: -0.40425162573905304
# Criteria of current node: -0.40414139818611894
# Criteria of current node: -0.4344888282231028
# Criteria of current node: -0.45713031437594515
# Criteria of current node: -0.4527962327510146
# Criteria of current node: -0.43940759788995415
# Criteria of current node: -0.43937538079909955
# Criteria of current node: -0.45925812933740595
# Criteria of current node: -0.43802517537405905
# Criteria of current node: -0.43585258511019304
#
# ==============================================
# New best criteria value: -0.5261627262670661
# Criteria of current node: -0.5261627262670661
# Criteria of current node: -0.522914368076029
# Criteria of current node: -0.48687871659329945
# Criteria of current node: -0.48651005763446986
# Criteria of current node: -0.4616526901214761
# Criteria of current node: -0.4398419428268813
# Criteria of current node: -0.4276350350289647
# Criteria of current node: -0.4210795942638841
# Criteria of current node: -0.421079594263884
# Criteria of current node: -0.4200578042996858
# Criteria of current node: -0.4147786920259545
# Criteria of current node: -0.4145191341693826
# Criteria of current node: -0.41335412497865254
# Criteria of current node: -0.4126180781156539
# Criteria of current node: -0.4207122906474492
# Criteria of current node: -0.41260209188706976
# Criteria of current node: -0.4103722868182806
# Criteria of current node: -0.40748267993063714
# Criteria of current node: -0.4924230984655263
# Criteria of current node: -0.417031948696648
# Criteria of current node: -0.4115955995786477
# Criteria of current node: -0.4036063628750365
# Criteria of current node: -0.4035749495897025
# Criteria of current node: -0.4032397199110342
# Criteria of current node: -0.40273262276132643
# Criteria of current node: -0.40273262276132643
# Criteria of current node: -0.42315157620629484
# Criteria of current node: -0.4149616435841875
# Criteria of current node: -0.43574129340849843
# Criteria of current node: -0.42585519780416625
# Criteria of current node: -0.4114123941479007
# Criteria of current node: -0.4253282517841139
# Criteria of current node: -0.4223213949206206
# Criteria of current node: -0.4236480560308425
# Criteria of current node: -0.4466244680027147
# Criteria of current node: -0.42074430678851155
# Criteria of current node: -0.42446544735133285
# Criteria of current node: -0.41393132819076944
# Criteria of current node: -0.43361807181890355
# Criteria of current node: -0.413317178169083
# Criteria of current node: -0.4448165576244418
# Criteria of current node: -0.4133411258821663
# Criteria of current node: -0.4442737470501991
# Criteria of current node: -0.4137130733251416
# Criteria of current node: -0.4129038785276526
# Criteria of current node: -0.41272926570925234
# Criteria of current node: -0.4115364350152877
# Criteria of current node: -0.40801054507355267
# Criteria of current node: -0.4621886059231223
# Criteria of current node: -0.4481508828838663
# Criteria of current node: -0.44467875294183445
# Criteria of current node: -0.4374987964440247
# Criteria of current node: -0.43657881889876793
# Criteria of current node: -0.46325434675199223
# Criteria of current node: -0.4271041480104045
# Criteria of current node: -0.4216401580263324
# Criteria of current node: -0.41964997422244565
# Criteria of current node: -0.42446836395648574
# Criteria of current node: -0.42405669456326966
# Criteria of current node: -0.41783666737430086
# Criteria of current node: -0.4098868446921028
# Criteria of current node: -0.411392603665813
# Criteria of current node: -0.4104158779112327
# Criteria of current node: -0.4085487689680292
# Criteria of current node: -0.4133025514959623
# Criteria of current node: -0.4078588162874283
# Criteria of current node: -0.4078489774457961
# Criteria of current node: -0.4073481603833388
# Criteria of current node: -0.4180954252088822
# Criteria of current node: -0.4179196764778881
# Criteria of current node: -0.43283741919502977
# Criteria of current node: -0.41944232787929625
# Criteria of current node: -0.40953200660087863
# Criteria of current node: -0.4185730424816814
# Criteria of current node: -0.4086806926445989
# Criteria of current node: -0.40764013176117664
# Criteria of current node: -0.4073359045202582
# Criteria of current node: -0.4328260680116422
# Criteria of current node: -0.4108016211230117
# Criteria of current node: -0.43821682158781733
# Criteria of current node: -0.4309048590382836
# Criteria of current node: -0.41082528853099676
# Criteria of current node: -0.41051952155284926
# Criteria of current node: -0.4190806911172549
# Criteria of current node: -0.44785020628211075
# Criteria of current node: -0.41983274347793964
# Criteria of current node: -0.41076080018789396
# Criteria of current node: -0.41506800297894375
# Criteria of current node: -0.45160261551179604
# Criteria of current node: -0.43704130446796696
# Criteria of current node: -0.42602138236696724
# Criteria of current node: -0.4552263860302981
# Criteria of current node: -0.4253332208047385
# Criteria of current node: -0.4124044137711368
# Criteria of current node: -0.4115554237992993
# Criteria of current node: -0.40866706611025844
# Criteria of current node: -0.4074841247650467
# Criteria of current node: -0.4288799992602103
# Criteria of current node: -0.4459021494373304
# Criteria of current node: -0.41307282486359526
# Criteria of current node: -0.4153997281244994
# Criteria of current node: -0.4327509595471696
# Criteria of current node: -0.41291328370149244
# Criteria of current node: -0.439715146596507
# Criteria of current node: -0.42246831191916057
# Criteria of current node: -0.4213987348455253
# Criteria of current node: -0.42265350134175805
# Criteria of current node: -0.41097633392972444
# Criteria of current node: -0.41030430035052273
# Criteria of current node: -0.4089001525369227
# Criteria of current node: -0.4111557129088904
# Criteria of current node: -0.4270230003355712
# Criteria of current node: -0.4088978528811523
# Criteria of current node: -0.4073182880394286
# Criteria of current node: -0.45250107132334416
# Criteria of current node: -0.41409341742134165
# Criteria of current node: -0.40923196776503207
# Criteria of current node: -0.42490562139091587
# Criteria of current node: -0.42612182879640936
# Criteria of current node: -0.41894194432685367
# Criteria of current node: -0.4185687616432653
# Criteria of current node: -0.4147828227812329
# Criteria of current node: -0.4243498765458649
# Criteria of current node: -0.42481619383995384
# Criteria of current node: -0.41288299881628626
# Criteria of current node: -0.4125407299318264
# Criteria of current node: -0.41940935710607113
# Criteria of current node: -0.4129008472178757
# Criteria of current node: -0.41086873586230616
# Criteria of current node: -0.40922787171140973
# Criteria of current node: -0.4102855628423054
# Criteria of current node: -0.412297617180416
# Criteria of current node: -0.44870143369539456
# Criteria of current node: -0.433337414319971
# Criteria of current node: -0.41963491508932654
# Criteria of current node: -0.41912336713295695
# Criteria of current node: -0.41512178415315837
# Criteria of current node: -0.4141263359181369
# Criteria of current node: -0.4258958985072301
# Criteria of current node: -0.44687525367394604
# Criteria of current node: -0.4132435506117527
# Criteria of current node: -0.41711736736302607
# Criteria of current node: -0.4091402252972207
# Criteria of current node: -0.4083706477724637
# Criteria of current node: -0.4081746075593673
# Criteria of current node: -0.4590818390906847
# Criteria of current node: -0.41157010161477975
# Criteria of current node: -0.4327328590638941
# Criteria of current node: -0.40953866000487826
# Criteria of current node: -0.4086064585625736
# Criteria of current node: -0.43588899027249417
# Criteria of current node: -0.4315904863340551
# Criteria of current node: -0.4150841676295833
# Criteria of current node: -0.40872666037800615
# Criteria of current node: -0.46826262993830375
# Criteria of current node: -0.4446856480068415
# Criteria of current node: -0.4104493473667096
# Criteria of current node: -0.41352923526847096
# Criteria of current node: -0.43846393016025764
# Criteria of current node: -0.41926247929947147
# Criteria of current node: -0.4266030908358278
# Criteria of current node: -0.4236587156986677
# Criteria of current node: -0.4166835354833096
# Criteria of current node: -0.4141472490328725
# Criteria of current node: -0.41031862227772653
# Criteria of current node: -0.40871829599746334
# Criteria of current node: -0.4086383029692282
# Criteria of current node: -0.40805899208486246
# Criteria of current node: -0.41607564534762315
# Criteria of current node: -0.41366544700305613
# Criteria of current node: -0.42658333222906936
# Criteria of current node: -0.41874312977057326
# Criteria of current node: -0.41364978316618284
# Criteria of current node: -0.40895021017923655
# Criteria of current node: -0.42927816692248494
# Criteria of current node: -0.4346060863285918
# Criteria of current node: -0.4290248446246577
# Criteria of current node: -0.4195052397515855
# Criteria of current node: -0.41235793262632003
# Criteria of current node: -0.408188944980397
# Criteria of current node: -0.40761433324798374
# Criteria of current node: -0.4086930545394373
# Criteria of current node: -0.4309345579254781
# Criteria of current node: -0.4376303884343365
# Criteria of current node: -0.4514400174301135
# Criteria of current node: -0.42227726580354863
# Criteria of current node: -0.4305177422715464
# Criteria of current node: -0.4165473657709219
# Criteria of current node: -0.40885678864607555
# Criteria of current node: -0.42739488317190893
# Criteria of current node: -0.4076033882179424
# Criteria of current node: -0.4071592314473341
# Criteria of current node: -0.40702883209713514
# Criteria of current node: -0.4710944177562699
# Criteria of current node: -0.4424261251437981
# Criteria of current node: -0.43176254004799564
# Criteria of current node: -0.4175967545617927
# Criteria of current node: -0.4164447382978769
# Criteria of current node: -0.41282862258140607
# Criteria of current node: -0.4119997224607895
# Criteria of current node: -0.4166303962036213
# Criteria of current node: -0.40671050726027375
# Criteria of current node: -0.4149331533246921
# Criteria of current node: -0.4067956479662547
# Criteria of current node: -0.42451672106616894
# Criteria of current node: -0.45127866332354916
# Criteria of current node: -0.42031731156863344
# Criteria of current node: -0.4107193840120537
# Criteria of current node: -0.43629547111387834
# Criteria of current node: -0.4299828786026916
# Criteria of current node: -0.4102968771871156
# Criteria of current node: -0.4066988748176681
# Criteria of current node: -0.41498079038304353
# Criteria of current node: -0.4398540595181136
# Criteria of current node: -0.44506051752702697
# Criteria of current node: -0.4183718659999364
# Criteria of current node: -0.41512773604938313
# Criteria of current node: -0.4085725003649445
# Criteria of current node: -0.4118905639172664
# Criteria of current node: -0.42682695566950657
# Criteria of current node: -0.4328116264500879
# Criteria of current node: -0.41610190493261684
# Criteria of current node: -0.42258862647113454
# Criteria of current node: -0.4103589790496259
# Criteria of current node: -0.43385154150381244
# Criteria of current node: -0.44156963179354275
# Criteria of current node: -0.4338937563177953
# Criteria of current node: -0.44659738802060783
# Criteria of current node: -0.43410003229649835
# Criteria of current node: -0.4216902801381701
# Criteria of current node: -0.435224715402836
# Criteria of current node: -0.4229654410422771
# Criteria of current node: -0.415608893375658
# Criteria of current node: -0.4116355428502608
# Criteria of current node: -0.4114149234949436
# Criteria of current node: -0.42351881346950404
# Criteria of current node: -0.4204160835067025
# Criteria of current node: -0.4102570601856257
# Criteria of current node: -0.42463216051369673
# Criteria of current node: -0.4170983559434017
# Criteria of current node: -0.416485731683889
# Criteria of current node: -0.40993488521651533
# Criteria of current node: -0.40910912305083347
# Criteria of current node: -0.41211155820937273
# Criteria of current node: -0.4132754412412891
# Criteria of current node: -0.40844202462993295
# Criteria of current node: -0.4272482170963225
# Criteria of current node: -0.4196123766123448
# Criteria of current node: -0.4155466215753719
# Criteria of current node: -0.407773016890924
# Criteria of current node: -0.41446078330305897
# Criteria of current node: -0.40656532518363486
# Criteria of current node: -0.44470468374583605
# Criteria of current node: -0.4601870978337927
# Criteria of current node: -0.4135798935024861
# Criteria of current node: -0.4065581470917152
# Criteria of current node: -0.4064192660144439
# Criteria of current node: -0.40775065303989194
# Criteria of current node: -0.42035760633865205
# Criteria of current node: -0.40631914741837843
# Criteria of current node: -0.40626336084171316
# Criteria of current node: -0.44378099500933227
# Criteria of current node: -0.4062356270600194
# Criteria of current node: -0.4062209346521508
# Criteria of current node: -0.4061486797032923
# Criteria of current node: -0.40607879626869287
# Criteria of current node: -0.4060585956604938
# Criteria of current node: -0.40598750089253255
# Criteria of current node: -0.40593898225225133
# Criteria of current node: -0.4288416538039127
# Criteria of current node: -0.41107191657305425
# Criteria of current node: -0.4114841254339545
# Criteria of current node: -0.4081983487338436
# Criteria of current node: -0.40813170323679926
# Criteria of current node: -0.41275247845225344
# Criteria of current node: -0.4058866345114295
# Criteria of current node: -0.40582449715275026
# Criteria of current node: -0.4056253505042511
# Criteria of current node: -0.4080670708445452
# Criteria of current node: -0.40558011443822717
# Criteria of current node: -0.4055364348655269
# Criteria of current node: -0.4395461868239596
# Criteria of current node: -0.41608942519269204
# Criteria of current node: -0.4054356275745997
# Criteria of current node: -0.4054299487168499
# Criteria of current node: -0.4589024517533006
# Criteria of current node: -0.4571474391509203
# Criteria of current node: -0.44780128972999317
# Criteria of current node: -0.42653804105908993
# Criteria of current node: -0.4236652929591724
# Criteria of current node: -0.4223991577303931
# Criteria of current node: -0.41094554523388865
# Criteria of current node: -0.4214099202151137
# Criteria of current node: -0.4783250141797608
# Criteria of current node: -0.4123671709114191
# Criteria of current node: -0.40828122035509773
# Criteria of current node: -0.4121142908959635
# Criteria of current node: -0.40801845010003795
# Criteria of current node: -0.4092984381120286
# Criteria of current node: -0.40794553153447244
# Criteria of current node: -0.43977348319364284
# Criteria of current node: -0.40705180999549934
# Criteria of current node: -0.4190620304373026
# Criteria of current node: -0.454011280793556
# Criteria of current node: -0.4452160424203877
# Criteria of current node: -0.44059101910002807
# Criteria of current node: -0.4340151189713247
# Criteria of current node: -0.4450458037364054
# Criteria of current node: -0.4335600250048653
# Criteria of current node: -0.44432528181097386
# Criteria of current node: -0.4363135773970575
# Criteria of current node: -0.43115686942154857
# Criteria of current node: -0.42883589653817716
# Criteria of current node: -0.4243683126022194
# Criteria of current node: -0.4176156873005004
# Criteria of current node: -0.4165377881121673
# Criteria of current node: -0.41635850612208847
# Criteria of current node: -0.4253472307838794
# Criteria of current node: -0.41663340302066854
# Criteria of current node: -0.40958594877065874
# Criteria of current node: -0.4094985623242583
# Criteria of current node: -0.40933145074014776
# Criteria of current node: -0.4089286355851869
# Criteria of current node: -0.40890896750505795
# Criteria of current node: -0.41489012483971405
# Criteria of current node: -0.40890478571363464
# Criteria of current node: -0.40920384510365554
# Criteria of current node: -0.407559904312698
# Criteria of current node: -0.4068257817926875
# Criteria of current node: -0.4274278010368483
# Criteria of current node: -0.42664407391172493
# Criteria of current node: -0.4230674976003886
# Criteria of current node: -0.41937808762882767
# Criteria of current node: -0.4534255782893957
# Criteria of current node: -0.4187964207524317
# Criteria of current node: -0.4526848945225607
# Criteria of current node: -0.4253080420440134
# Criteria of current node: -0.4166816990115205
# Criteria of current node: -0.4159708734369275
# Criteria of current node: -0.43738073775547626
# Criteria of current node: -0.4153871140793545
# Criteria of current node: -0.41317570758234895
# Criteria of current node: -0.4128820738041468
# Criteria of current node: -0.41134233001729664
# Criteria of current node: -0.40936748737510964
# Criteria of current node: -0.40879686945095695
# Criteria of current node: -0.42354001828827
# Criteria of current node: -0.40651562056500995
# Criteria of current node: -0.40631875447747146
# Criteria of current node: -0.4061100704150787
# Criteria of current node: -0.44645753578368186
# Criteria of current node: -0.40576246123372683
# Criteria of current node: -0.4344450577055877
# Criteria of current node: -0.4174760259426628
# Criteria of current node: -0.40547344615338193
# Criteria of current node: -0.40527039010597615
# Criteria of current node: -0.41515808430678514
# Criteria of current node: -0.43437397742704664
# Criteria of current node: -0.4339122528324818
# Criteria of current node: -0.4256296629935045
# Criteria of current node: -0.4216983036506695
# Criteria of current node: -0.4206554702834242
# Criteria of current node: -0.4150897101743476
# Criteria of current node: -0.40751549297386036
# Criteria of current node: -0.4056563358413567
# Criteria of current node: -0.40639730920732153
# Criteria of current node: -0.43135042301047427
# Criteria of current node: -0.40886666757960416
# Criteria of current node: -0.40618128072910603
# Criteria of current node: -0.40554133880056775
# Criteria of current node: -0.43333809439170184
# Criteria of current node: -0.41633082549239053
# Criteria of current node: -0.4095549305841056
# Criteria of current node: -0.406185273080934
# Criteria of current node: -0.4098807742385721
# Criteria of current node: -0.46024359426255834
# Criteria of current node: -0.42879543712708046
# Criteria of current node: -0.41338998597017795
# Criteria of current node: -0.44738748649206983
# Criteria of current node: -0.4124403953984214
# Criteria of current node: -0.41104865425422826
# Criteria of current node: -0.4142320845517129
# Criteria of current node: -0.4441314239736083
# Criteria of current node: -0.4171949900896065
# Criteria of current node: -0.4119427352738221
# Criteria of current node: -0.4118649434270904
# Criteria of current node: -0.4100557790231696
# Criteria of current node: -0.45553961676065013
# Criteria of current node: -0.4223195615769278
# Criteria of current node: -0.4212159519536968
# Criteria of current node: -0.41030690809086906
# Criteria of current node: -0.4347351648401226
# Criteria of current node: -0.4271029203884722
# Criteria of current node: -0.4155819327078577
# Criteria of current node: -0.40943506234788235
# Criteria of current node: -0.4597723940612101
# Criteria of current node: -0.40900641929221127
# Criteria of current node: -0.44525947132384686
# Criteria of current node: -0.40818774439464534
# Criteria of current node: -0.41096327614377637
# Criteria of current node: -0.4067928180519321
# Criteria of current node: -0.4063267158974808
# Criteria of current node: -0.45677682436636013
# Criteria of current node: -0.4118352672513781
# Criteria of current node: -0.4085927919390813
# Criteria of current node: -0.4052503736128218
# Criteria of current node: -0.40508031992870935
# Criteria of current node: -0.4050731989718195
# Criteria of current node: -0.42814947696028527
# Criteria of current node: -0.4235405328030365
# Criteria of current node: -0.42320514273779286
# Criteria of current node: -0.4050240190572028
# Criteria of current node: -0.42073491049632383
# Criteria of current node: -0.42218396862707375
# Criteria of current node: -0.41655861590138915
# Criteria of current node: -0.4174697716151516
# Criteria of current node: -0.41710561868094326
# Criteria of current node: -0.4136455423060231
# Criteria of current node: -0.41904198569016865
# Criteria of current node: -0.41344865315854074
# Criteria of current node: -0.43667146447849065
# Criteria of current node: -0.4157521930371909
# Criteria of current node: -0.42916692947398793
# Criteria of current node: -0.41485151740076087
# Criteria of current node: -0.40962512415799796
# Criteria of current node: -0.40861940192088303
# Criteria of current node: -0.4092883144871357
# Criteria of current node: -0.4192728952630246
# Criteria of current node: -0.40499974011890466
# Criteria of current node: -0.41358674404815066
# Criteria of current node: -0.42076316704305483
# Criteria of current node: -0.4049957868666721
# Criteria of current node: -0.428976941812523
# Criteria of current node: -0.42251083918219257
# Criteria of current node: -0.46939918526970603
# Criteria of current node: -0.44085721552756957
# Criteria of current node: -0.4348445848506553
# Criteria of current node: -0.42139308271051973
# Criteria of current node: -0.4299080608351792
# Criteria of current node: -0.42076177347106786
# Criteria of current node: -0.41931709456663147
# Criteria of current node: -0.4215926415212466
# Criteria of current node: -0.42691481171053397
# Criteria of current node: -0.4241238109236558
# Criteria of current node: -0.4225217446635486
# Criteria of current node: -0.4188989551178275
# Criteria of current node: -0.4160851846935419
# Criteria of current node: -0.4134384432467118
# Criteria of current node: -0.4131766622205806
# Criteria of current node: -0.4115480020342859
# Criteria of current node: -0.4208886540065289
# Criteria of current node: -0.41129477065441283
# Criteria of current node: -0.4109327388590177
# Criteria of current node: -0.4174017488306899
# Criteria of current node: -0.42453810981123546
# Criteria of current node: -0.41064320242064645
# Criteria of current node: -0.46194069434413776
# Criteria of current node: -0.41078978492638907
# Criteria of current node: -0.4103825582808322
# Criteria of current node: -0.4118333100335722
# Criteria of current node: -0.40804767265849196
# Criteria of current node: -0.40736684316636707
# Criteria of current node: -0.4168457630802231
# Criteria of current node: -0.44073025976865826
# Criteria of current node: -0.41397403749230505
# Criteria of current node: -0.4226606723489913
# Criteria of current node: -0.4109036474805173
# Criteria of current node: -0.42788757610974126
# Criteria of current node: -0.4497161553288601
# Criteria of current node: -0.42727848086625614
# Criteria of current node: -0.4229941956378528
# Criteria of current node: -0.4133126411814702
# Criteria of current node: -0.41082865835950694
# Criteria of current node: -0.410370248469919
# Criteria of current node: -0.40886923837955086
# Criteria of current node: -0.4136916642796691
# Criteria of current node: -0.41244126666508013
# Criteria of current node: -0.4122738617987007
# Criteria of current node: -0.40723005853376476
# Criteria of current node: -0.4071807995627861
# Criteria of current node: -0.4248982615400156
# Criteria of current node: -0.41618461210730867
# Criteria of current node: -0.4536232282550414
# Criteria of current node: -0.4442897905217094
# Criteria of current node: -0.43630963589923083
# Criteria of current node: -0.4272929638450312
# Criteria of current node: -0.4222527304162233
# Criteria of current node: -0.42024974003293064
# Criteria of current node: -0.41603067225224455
# Criteria of current node: -0.42404699794741507
# Criteria of current node: -0.43473404596360726
# Criteria of current node: -0.42773085567856417
# Criteria of current node: -0.4144598996895245
# Criteria of current node: -0.4251595582559992
# Criteria of current node: -0.41340245734163217
# Criteria of current node: -0.41124218026146897
# Criteria of current node: -0.41106424946307596
# Criteria of current node: -0.40745535724211285
# Criteria of current node: -0.4066989899404889
# Criteria of current node: -0.4141770278366378
# Criteria of current node: -0.40645199932151177
# Criteria of current node: -0.44784777394391306
# Criteria of current node: -0.4220535268005038
# Criteria of current node: -0.42661607983221234
# Criteria of current node: -0.449868081035554
# Criteria of current node: -0.464385989117514
# Criteria of current node: -0.43710456975353373
# Criteria of current node: -0.43230959157792226
# Criteria of current node: -0.4192692727563584
# Criteria of current node: -0.4359489185251067
# Criteria of current node: -0.42362295599145705
# Criteria of current node: -0.42816772162960726
# Criteria of current node: -0.42316171245463036
# Criteria of current node: -0.4531927096206573
# Criteria of current node: -0.4283939489412534
# Criteria of current node: -0.4208168513055351
# Criteria of current node: -0.42025968835051625
# Criteria of current node: -0.42002743878147036
# Criteria of current node: -0.4198063003545514
# Criteria of current node: -0.4161143709926091
# Criteria of current node: -0.4158389176621198
# Criteria of current node: -0.41561582443807693
# Criteria of current node: -0.41484516244778924
# Criteria of current node: -0.4230399320775412
# Criteria of current node: -0.42183297394920505
# Criteria of current node: -0.4241759933528543
# Criteria of current node: -0.4192209769133917
# Criteria of current node: -0.41813373318811875
# Criteria of current node: -0.41480604911434094
# Criteria of current node: -0.4179818373521288
# Criteria of current node: -0.42511411297794033
# Criteria of current node: -0.42986215835579616
# Criteria of current node: -0.4127506918774069
# Criteria of current node: -0.42055979774163005
# Criteria of current node: -0.41166057354249663
# Criteria of current node: -0.4230837547866489
# Criteria of current node: -0.4288308972605597
# Criteria of current node: -0.4107207514918315
# Criteria of current node: -0.4092933286557777
# Criteria of current node: -0.41038839277864525
# Criteria of current node: -0.40884171005229725
# Criteria of current node: -0.40802882357484455
# Criteria of current node: -0.43851696718397476
# Criteria of current node: -0.43358397537146837
# Criteria of current node: -0.4207574986436915
# Criteria of current node: -0.4167619822743187
# Criteria of current node: -0.4160842071411273
# Criteria of current node: -0.415430531914957
# Criteria of current node: -0.4392806456459625
# Criteria of current node: -0.4280575684109557
# Criteria of current node: -0.40742168046786487
# Criteria of current node: -0.4070356406508315
# Criteria of current node: -0.44162622220780917
# Criteria of current node: -0.4159608293337671
# Criteria of current node: -0.412974005358689
# Criteria of current node: -0.4065339155453529
# Criteria of current node: -0.40641668371866824
# Criteria of current node: -0.40907076112841084
# Criteria of current node: -0.4317891678083832
# Criteria of current node: -0.4368926647931024
# Criteria of current node: -0.44466405653865393
# Criteria of current node: -0.42497081597504177
# Criteria of current node: -0.40976775192257997
# Criteria of current node: -0.4280622297066705
# Criteria of current node: -0.4186116939876793
# Criteria of current node: -0.4154142336718215
# Criteria of current node: -0.4299431294874897
# Criteria of current node: -0.4426748579287678
# Criteria of current node: -0.45772912629621193
# Criteria of current node: -0.42237521093670904
# Criteria of current node: -0.4217896942344934
# Criteria of current node: -0.4187863905403026
# Criteria of current node: -0.44139178611125796
# Criteria of current node: -0.4344493088227613
# Criteria of current node: -0.4333650934127078
# Criteria of current node: -0.42590572699605234
# Criteria of current node: -0.42443272632814094
# Criteria of current node: -0.42770149007727043
# Criteria of current node: -0.42842169862540563
# Criteria of current node: -0.42478430624231955
# Criteria of current node: -0.424382330937935
# Criteria of current node: -0.42146165024709425
# Criteria of current node: -0.42125967007088616
# Criteria of current node: -0.4198095210998895
# Criteria of current node: -0.4197683235636694
# Criteria of current node: -0.42898063625073696
# Criteria of current node: -0.4162293875433763
# Criteria of current node: -0.4162118215798021
# Criteria of current node: -0.41534634851681607
# Criteria of current node: -0.4289435726103933
# Criteria of current node: -0.4184067473064853
# Criteria of current node: -0.41854470724167725
# Criteria of current node: -0.41400410936510446
# Criteria of current node: -0.4380133522389058
# Criteria of current node: -0.42480453691508646
# Criteria of current node: -0.4210878476443019
# Criteria of current node: -0.41946065677120997
# Criteria of current node: -0.4165059828345327
# Criteria of current node: -0.41607762349133764
# Criteria of current node: -0.4139929546981905
# Criteria of current node: -0.4114996955252484
# Criteria of current node: -0.42336537237025773
# Criteria of current node: -0.4213621056313894
# Criteria of current node: -0.42014405466197513
# Criteria of current node: -0.4142425043485854
# Criteria of current node: -0.42482527065580866
# Criteria of current node: -0.43750157853491184
# Criteria of current node: -0.4105766022381125
# Criteria of current node: -0.4101807968438927
# Criteria of current node: -0.45395133568453344
# Criteria of current node: -0.4374435280767884
# Criteria of current node: -0.4289372904569737
# Criteria of current node: -0.44358602504833705
# Criteria of current node: -0.4291655117222724
# Criteria of current node: -0.4259200469234837
# Criteria of current node: -0.42332640010079725
# Criteria of current node: -0.41347732228797524
# Criteria of current node: -0.4117779272683756
# Criteria of current node: -0.40995236694593196
# Criteria of current node: -0.40926952032471686
# Criteria of current node: -0.40846696456337755
# Criteria of current node: -0.4261632706395201
# Criteria of current node: -0.41390838763989707
# Criteria of current node: -0.40832650679597743
# Criteria of current node: -0.4246220783606863
# Criteria of current node: -0.4083080293432626
# Criteria of current node: -0.4081589301319347
# Criteria of current node: -0.4077937043824715
# Criteria of current node: -0.4077827580616987
# Criteria of current node: -0.40736016300664135
# Criteria of current node: -0.4324817633990624
# Criteria of current node: -0.4071773107326518
# Criteria of current node: -0.436528411707289
# Criteria of current node: -0.4762220255792933
# Criteria of current node: -0.46117102889101164
# Criteria of current node: -0.4127011592306657
# Criteria of current node: -0.4083987088966593
# Criteria of current node: -0.4168469190551214
# Criteria of current node: -0.4145722312893149
# Criteria of current node: -0.4091142345023996
# Criteria of current node: -0.4232664076836548
# Criteria of current node: -0.4071125776803179
# Criteria of current node: -0.40704629264061326
# Criteria of current node: -0.4199153654224869
# Criteria of current node: -0.4437906723464838
# Criteria of current node: -0.4094077504392583
# Criteria of current node: -0.4194291192608307
# Criteria of current node: -0.4155505277703371
# Criteria of current node: -0.4347180245267599
# Criteria of current node: -0.41448446230836783
# Criteria of current node: -0.4222050264083565
# Criteria of current node: -0.4176339684398439
# Criteria of current node: -0.4126408510348681
# Criteria of current node: -0.408058391148725
# Criteria of current node: -0.40687864865029444
# Criteria of current node: -0.4068317986067108
# Criteria of current node: -0.4523745496134446
# Criteria of current node: -0.45009081613012325
# Criteria of current node: -0.4163856867189227
# Criteria of current node: -0.41698013306109827
# Criteria of current node: -0.4184103613590904
# Criteria of current node: -0.41078966884622925
# Criteria of current node: -0.4282603444972764
# Criteria of current node: -0.409548334682269
# Criteria of current node: -0.45159382141155463
# Criteria of current node: -0.43242630201023724
# Criteria of current node: -0.40795505006030075
# Criteria of current node: -0.40679261164386094
# Criteria of current node: -0.40669352082376237
# Criteria of current node: -0.43024783275075273
# Criteria of current node: -0.4121292611056168
# Criteria of current node: -0.40637678842148767
# Criteria of current node: -0.41896169157546076
# Criteria of current node: -0.4187292539145788
# Criteria of current node: -0.40637209944421854
# Criteria of current node: -0.4154357242238776
# Criteria of current node: -0.41108247779368967
# Criteria of current node: -0.4159064758551996
# Criteria of current node: -0.40664021872360817
# Criteria of current node: -0.4063022904915123
# Criteria of current node: -0.4062801050412568
# Criteria of current node: -0.4103141632415833
# Criteria of current node: -0.41634240921381843
# Criteria of current node: -0.4062605417891876
# Criteria of current node: -0.4062281899187826
# Criteria of current node: -0.44128123290120447
# Criteria of current node: -0.45994500674527555
# Criteria of current node: -0.42923734663945423
# Criteria of current node: -0.42438659944714263
# Criteria of current node: -0.43276732563450027
# Criteria of current node: -0.44131913024055924
# Criteria of current node: -0.41720363082517126
# Criteria of current node: -0.4165797381712558
# Criteria of current node: -0.42464528266767904
# Criteria of current node: -0.4182017483263555
# Criteria of current node: -0.4217890693123783
# Criteria of current node: -0.41877438146277957
# Criteria of current node: -0.41647671995353885
# Criteria of current node: -0.41493541103833886
# Criteria of current node: -0.43134790241899396
# Criteria of current node: -0.4160249272408337
# Criteria of current node: -0.43013663388240203
# Criteria of current node: -0.42372185806518525
# Criteria of current node: -0.4137983868889058
# Criteria of current node: -0.41350459192522393
# Criteria of current node: -0.4381607999401479
# Criteria of current node: -0.4300567399546981
# Criteria of current node: -0.41321997667364707
# Criteria of current node: -0.432241209242818
# Criteria of current node: -0.4253035524355787
# Criteria of current node: -0.41403555363484607
# Criteria of current node: -0.42127889078277814
# Criteria of current node: -0.41263773108408786
# Criteria of current node: -0.4178094142355079
# Criteria of current node: -0.41235686956708595
# Criteria of current node: -0.42699598212307877
# Criteria of current node: -0.4284306023459627
# Criteria of current node: -0.4101094683983393
# Criteria of current node: -0.4095465165378862
# Criteria of current node: -0.408754865823108
# Criteria of current node: -0.42273636544614324
# Criteria of current node: -0.4085685898202282
# Criteria of current node: -0.4075487053648428
# Criteria of current node: -0.40788793917595056
# Criteria of current node: -0.4066704242757946
# Criteria of current node: -0.4157632175102492
# Criteria of current node: -0.4061741421458808
# Criteria of current node: -0.4203633624054993
# Criteria of current node: -0.43475337610153064
# Criteria of current node: -0.42370934758582957
# Criteria of current node: -0.41166176068169935
# Criteria of current node: -0.4075019145943291
# Criteria of current node: -0.40657219413109347
# Criteria of current node: -0.44084274497599346
# Criteria of current node: -0.4375768252832627
# Criteria of current node: -0.43692019756668843
# Criteria of current node: -0.43611343247842216
# Criteria of current node: -0.4191061652394442
# Criteria of current node: -0.4323052043386363
# Criteria of current node: -0.42431495869054275
# Criteria of current node: -0.41718147660171606
# Criteria of current node: -0.41399825420179676
# Criteria of current node: -0.41073153659393735
# Criteria of current node: -0.40675879849012764
# Criteria of current node: -0.4269584860899417
# Criteria of current node: -0.43065378699212054
# Criteria of current node: -0.42861727045706455
# Criteria of current node: -0.4248007656984347
# Criteria of current node: -0.4457881627091405
# Criteria of current node: -0.4258122140318571
# Criteria of current node: -0.4173747818557989
# Criteria of current node: -0.4170317405839354
# Criteria of current node: -0.41486461867098723
# Criteria of current node: -0.4117871447579976
# Criteria of current node: -0.41102997690374626
# Criteria of current node: -0.4139920215681286
# Criteria of current node: -0.4461855320645928
# Criteria of current node: -0.4103470421876434
# Criteria of current node: -0.4085605590731657
# Criteria of current node: -0.4063972375885835
# Criteria of current node: -0.45528848158352736
# Criteria of current node: -0.41185373294528516
# Criteria of current node: -0.40612671814093987
# Criteria of current node: -0.41887472518271707
# Criteria of current node: -0.4060727857381406
# Criteria of current node: -0.4245282722470102
# Criteria of current node: -0.4084489139542118
# Criteria of current node: -0.43550702889687826
# Criteria of current node: -0.40606519747153313
# Criteria of current node: -0.40597809438506904
# Criteria of current node: -0.4058761707660245
# Criteria of current node: -0.4116479237734471
# Criteria of current node: -0.41112277561419697
# Criteria of current node: -0.40581428308068224
# Criteria of current node: -0.41245315127713983
# Criteria of current node: -0.4242199357665285
# Criteria of current node: -0.45058668054287593
# Criteria of current node: -0.42490093784433125
# Criteria of current node: -0.42053666710232485
# Criteria of current node: -0.4411003413074181
# Criteria of current node: -0.4148993579414846
# Criteria of current node: -0.4519174498887965
# Criteria of current node: -0.42962134433217797
# Criteria of current node: -0.4229305997184253
# Criteria of current node: -0.42092312116451663
# Criteria of current node: -0.41702610751810704
# Criteria of current node: -0.41450343471389406
# Criteria of current node: -0.413410479571179
# Criteria of current node: -0.4194572979866981
# Criteria of current node: -0.42991937072273484
# Criteria of current node: -0.41595667630005745
# Criteria of current node: -0.4126773522634792
# Criteria of current node: -0.41171023076556684
# Criteria of current node: -0.43002427549770056
# Criteria of current node: -0.4153814573157214
# Criteria of current node: -0.41102639585609857
# Criteria of current node: -0.41050069412957546
# Criteria of current node: -0.42515482173799873
# Criteria of current node: -0.41233476537452934
# Criteria of current node: -0.41035564116545664
# Criteria of current node: -0.4141680264545885
# Criteria of current node: -0.41721395073407747
# Criteria of current node: -0.4109864864573226
# Criteria of current node: -0.4111757114173872
# Criteria of current node: -0.430467517396004
# Criteria of current node: -0.4167629232827419
# Criteria of current node: -0.40977321178590786
# Criteria of current node: -0.4397237760830953
# Criteria of current node: -0.42774764052547065
# Criteria of current node: -0.4101243975692034
# Criteria of current node: -0.4160819755501398
# Criteria of current node: -0.4112888935049827
# Criteria of current node: -0.4091730706248501
# Criteria of current node: -0.4087376631554417
# Criteria of current node: -0.4115883490200648
# Criteria of current node: -0.408498370950798
# Criteria of current node: -0.4530316885669713
# Criteria of current node: -0.42326133590191833
# Criteria of current node: -0.4107156183196302
# Criteria of current node: -0.4311665337171059
# Criteria of current node: -0.4157578941054783
# Criteria of current node: -0.42975883708710844
# Criteria of current node: -0.4458589174634268
# Criteria of current node: -0.44414791843350127
# Criteria of current node: -0.44120488625611115
# Criteria of current node: -0.4265475146534829
# Criteria of current node: -0.4080038623856641
# Criteria of current node: -0.4113375259152064
# Criteria of current node: -0.4074468840412315
# Criteria of current node: -0.416236053207993
# Criteria of current node: -0.40728203898378196
# Criteria of current node: -0.40672521346457297
# Criteria of current node: -0.40661530082508296
# Criteria of current node: -0.4140005985641922
# Criteria of current node: -0.429914344571984
# Criteria of current node: -0.42369376749749615
# Criteria of current node: -0.4358510709387289
# Criteria of current node: -0.42237806055463223
# Criteria of current node: -0.4526734680616937
# Criteria of current node: -0.4214214328551215
# Criteria of current node: -0.45840054790593376
# Criteria of current node: -0.45174084085102095
# Criteria of current node: -0.4497485544998542
# Criteria of current node: -0.4187207808869958
# Criteria of current node: -0.4166541856808171
# Criteria of current node: -0.41347282471736796
# Criteria of current node: -0.40908934751845105
# Criteria of current node: -0.41221200956652093
# Criteria of current node: -0.406390473380261
# Criteria of current node: -0.42669052772064753
# Criteria of current node: -0.4137368853290382
# Criteria of current node: -0.4748549974605032
# Criteria of current node: -0.45899266343523065
# Criteria of current node: -0.43552318975386844
# Criteria of current node: -0.4402053605836376
# Criteria of current node: -0.4319760802314728
# Criteria of current node: -0.431592624926673
# Criteria of current node: -0.42462199413216023
# Criteria of current node: -0.4149736806762584
# Criteria of current node: -0.411813386851814
# Criteria of current node: -0.41079726442723963
# Criteria of current node: -0.409769991265344
# Criteria of current node: -0.40890436451177903
# Criteria of current node: -0.4082872828734655
# Criteria of current node: -0.43156469113026263
# Criteria of current node: -0.43651673173130623
# Criteria of current node: -0.4247023540475653
# Criteria of current node: -0.4203047238875499
# Criteria of current node: -0.4190480672348474
# Criteria of current node: -0.4080898147676754
# Criteria of current node: -0.45382192080859524
# Criteria of current node: -0.4263442384247572
# Criteria of current node: -0.4253418652377213
# Criteria of current node: -0.411401659506535
# Criteria of current node: -0.43363466029854797
# Criteria of current node: -0.412261581702339
# Criteria of current node: -0.41131853565922044
# Criteria of current node: -0.42615938680114535
# Criteria of current node: -0.42514423603588575
# Criteria of current node: -0.4113335166620014
# Criteria of current node: -0.4270590006454722
# Criteria of current node: -0.4234913508110579
# Criteria of current node: -0.40731171610023614
# Criteria of current node: -0.4197602781461004
# Criteria of current node: -0.44674362302237325
# Criteria of current node: -0.440408096300746
# Criteria of current node: -0.40646350859276165
# Criteria of current node: -0.4125293342807398
# Criteria of current node: -0.42243505886365934
# Criteria of current node: -0.4119229183172313
# Criteria of current node: -0.42473450439664817
# Criteria of current node: -0.40669033743295996
# Criteria of current node: -0.40634564599083856
# Criteria of current node: -0.4060067818404682
# Criteria of current node: -0.45885560065381803
# Criteria of current node: -0.4307288322939054
# Criteria of current node: -0.4061402609171323
# Criteria of current node: -0.4260148687653574
# Criteria of current node: -0.4141953581286655
# Criteria of current node: -0.4369399995610842
# Criteria of current node: -0.42083473715595254
# Criteria of current node: -0.43250418779213057
# Criteria of current node: -0.4231258550641536
# Criteria of current node: -0.42508008834482913
# Criteria of current node: -0.4563967878382902
# Criteria of current node: -0.41647676356064967
# Criteria of current node: -0.41375592913522213
# Criteria of current node: -0.4131269837542108
# Criteria of current node: -0.40904340427621894
# Criteria of current node: -0.4085405999121715
# Criteria of current node: -0.4058565841165064
# Criteria of current node: -0.438533314823768
# Criteria of current node: -0.4203340230729502
# Criteria of current node: -0.4178556848136253
# Criteria of current node: -0.4257030521049282
# Criteria of current node: -0.4113717543182851
# Criteria of current node: -0.4174335210700806
# Criteria of current node: -0.416670933057082
# Criteria of current node: -0.4150953476136021
# Criteria of current node: -0.41420185857025654
# Criteria of current node: -0.4119509079166671
# Criteria of current node: -0.41081871416036353
# 1000

# %%
astar.best_criteria_value
# Out:
# -0.5261627262670661

# %%
astar.best_design.kmeans.all_samples
# Out:
# array([[132, 134,   9,  41, 139, 108,  13, 144,  18, 114,  86, 121, 123,
#          92, 127]])

# %%
astar.best_design.kmeans.all_samples_probs
# Out:
# array([1.])
