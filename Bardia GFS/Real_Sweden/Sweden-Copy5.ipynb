# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Real_Sweden"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmpDokcOl", R: "/tmp/RtmpRVfqIx"
#   warnings.warn(

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 15

# %%
num_new_nodes          = 30

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.05338078
# [1] 199550387.9    106912.2

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 1511.2806 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0679 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0256 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.03389852
# Variance of HT estimator via DSD formula_z:  27608.92
# Variance of HT estimator via DSD formula:  88384256
# Here is the Vincent Efficiency y:
#   DSD_y:  1.14641
#   DSD_z: 3.87238
# Monte Carlo variance of HT estimator for y:
#   DSD:  85971369.17998
#   Cube: 93391724.32965
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.17859
#   Cube: 1.08494
# Monte Carlo mean of HT estimator for y:
#   DSD:  53546.92758
#   Cube: 53113.46378
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  26307.99858
#   Cube: 39229.78326
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  4.06387
#   Cube: 2.72528
# Monte Carlo mean of HT estimator for z:
#   DSD:  2505.55578
#   Cube: 2506.39929
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        2.73        3.87        1.97        2.14        2.26

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_6094/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639387
# [281] [15.] adsfa
# 4000 30 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 18.28it/s]
# Initial design 0: method = Original, efficiency z = 0.5137, y=0.4868
# New best at idx=0: method = Original, efficiency z = 0.5137 and efficiency y = 0.4868
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53351.76
#   Best Cost (y):       181780545.324
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.476
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5175→ cube 0.7353
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4862→ cube 0.5138
#   Efficiency z (srs):  1.982 → 0.514 → 1.9968
#   Efficiency y (srs):  1.095 → 0.487 → 1.0938
#   Alpha:               0.8583741427049777
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       3
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53346.12
#   Best Cost (y):       181549200.4942
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.473
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5175→ cube 0.7354
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4868→ cube 0.5144
#   Efficiency z (srs):  1.982 → 0.514 → 1.997
#   Efficiency y (srs):  1.095 → 0.487 → 1.0952
#   Alpha:               0.8113420153777133
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       10
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53354.8
#   Best Cost (y):       176801770.9899
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.46
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5175→ cube 0.7353
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4999→ cube 0.5282
#   Efficiency z (srs):  1.982 → 0.514 → 1.9967
#   Efficiency y (srs):  1.095 → 0.487 → 1.1247
#   Alpha:               0.7890369756582828
#   Num changes:         3
#   Design Depth:        3
#   Design Size (|D|):   287
#   Open set size:       18
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       49938.092
#   Best Cost (y):       176328414.428
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      21.086
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5529→ cube 0.7856
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5012→ cube 0.5296
#   Efficiency z (srs):  1.982 → 0.514 → 2.1333
#   Efficiency y (srs):  1.095 → 0.487 → 1.1277
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        5
#   Design Size (|D|):   291
#   Open set size:       59
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       43818.285
#   Best Cost (y):       156468722.7447
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.612
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6301→ cube 0.8953
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5649→ cube 0.5969
#   Efficiency z (srs):  1.982 → 0.514 → 2.4312
#   Efficiency y (srs):  1.095 → 0.487 → 1.2708
#   Alpha:               0.7185806363872881
#   Num changes:         3
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       293
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       43772.534
#   Best Cost (y):       158116800.9429
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.583
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6307→ cube 0.8962
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.559→ cube 0.5907
#   Efficiency z (srs):  1.982 → 0.514 → 2.4338
#   Efficiency y (srs):  1.095 → 0.487 → 1.2576
#   Alpha:               0.7371235552907934
#   Num changes:         1
#   Design Depth:        23
#   Design Size (|D|):   327
#   Open set size:       300
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       43716.993
#   Best Cost (y):       156590714.623
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.551
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6315→ cube 0.8974
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5644→ cube 0.5964
#   Efficiency z (srs):  1.982 → 0.514 → 2.4369
#   Efficiency y (srs):  1.095 → 0.487 → 1.2698
#   Alpha:               0.8239902034401562
#   Num changes:         1
#   Design Depth:        23
#   Design Size (|D|):   327
#   Open set size:       301
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       43545.623
#   Best Cost (y):       156867765.7135
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.495
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.634→ cube 0.9009
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5634→ cube 0.5954
#   Efficiency z (srs):  1.982 → 0.514 → 2.4464
#   Efficiency y (srs):  1.095 → 0.487 → 1.2676
#   Alpha:               0.7928027636942483
#   Num changes:         2
#   Design Depth:        24
#   Design Size (|D|):   329
#   Open set size:       303
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       43199.881
#   Best Cost (y):       155507382.1323
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.342
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6391→ cube 0.9081
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5684→ cube 0.6006
#   Efficiency z (srs):  1.982 → 0.514 → 2.466
#   Efficiency y (srs):  1.095 → 0.487 → 1.2787
#   Alpha:               0.8817183859412996
#   Num changes:         2
#   Design Depth:        24
#   Design Size (|D|):   329
#   Open set size:       308
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       43080.41
#   Best Cost (y):       156572506.4986
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.299
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6409→ cube 0.9106
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5645→ cube 0.5965
#   Efficiency z (srs):  1.982 → 0.514 → 2.4729
#   Efficiency y (srs):  1.095 → 0.487 → 1.27
#   Alpha:               0.8557387544273951
#   Num changes:         2
#   Design Depth:        24
#   Design Size (|D|):   329
#   Open set size:       313
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       42382.821
#   Best Cost (y):       154634044.6704
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.989
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6514→ cube 0.9256
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5716→ cube 0.604
#   Efficiency z (srs):  1.982 → 0.514 → 2.5136
#   Efficiency y (srs):  1.095 → 0.487 → 1.2859
#   Alpha:               0.7642253063496925
#   Num changes:         1
#   Design Depth:        42
#   Design Size (|D|):   365
#   Open set size:       604
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41809.959
#   Best Cost (y):       148593169.2654
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.729
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6603→ cube 0.9383
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5948→ cube 0.6285
#   Efficiency z (srs):  1.982 → 0.514 → 2.548
#   Efficiency y (srs):  1.095 → 0.487 → 1.3382
#   Alpha:               0.8609874158778424
#   Num changes:         2
#   Design Depth:        62
#   Design Size (|D|):   405
#   Open set size:       874
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41822.789
#   Best Cost (y):       148382141.558
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.72
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6601→ cube 0.938
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5957→ cube 0.6294
#   Efficiency z (srs):  1.982 → 0.514 → 2.5472
#   Efficiency y (srs):  1.095 → 0.487 → 1.3401
#   Alpha:               0.8299154134756259
#   Num changes:         3
#   Design Depth:        63
#   Design Size (|D|):   407
#   Open set size:       881
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41084.5
#   Best Cost (y):       145899455.7211
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.412
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.672→ cube 0.9549
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6058→ cube 0.6401
#   Efficiency z (srs):  1.982 → 0.514 → 2.593
#   Efficiency y (srs):  1.095 → 0.487 → 1.3629
#   Alpha:               0.845387990486419
#   Num changes:         2
#   Design Depth:        81
#   Design Size (|D|):   443
#   Open set size:       1179
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41135.466
#   Best Cost (y):       144456622.3039
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.41
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6712→ cube 0.9537
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6118→ cube 0.6465
#   Efficiency z (srs):  1.982 → 0.514 → 2.5898
#   Efficiency y (srs):  1.095 → 0.487 → 1.3765
#   Alpha:               0.7795526155642767
#   Num changes:         2
#   Design Depth:        81
#   Design Size (|D|):   443
#   Open set size:       1185
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41095.97
#   Best Cost (y):       145243536.6719
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.402
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6718→ cube 0.9546
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6085→ cube 0.643
#   Efficiency z (srs):  1.982 → 0.514 → 2.5923
#   Efficiency y (srs):  1.095 → 0.487 → 1.369
#   Alpha:               0.8874675288505126
#   Num changes:         2
#   Design Depth:        81
#   Design Size (|D|):   443
#   Open set size:       1189
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       39863.166
#   Best Cost (y):       143947461.8894
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.897
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6926→ cube 0.9841
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.614→ cube 0.6488
#   Efficiency z (srs):  1.982 → 0.514 → 2.6724
#   Efficiency y (srs):  1.095 → 0.487 → 1.3813
#   Alpha:               0.7701877171531737
#   Num changes:         1
#   Design Depth:        102
#   Design Size (|D|):   485
#   Open set size:       1454
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       38869.716
#   Best Cost (y):       142790690.349
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.499
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7103→ cube 1.0093
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.619→ cube 0.654
#   Efficiency z (srs):  1.982 → 0.514 → 2.7407
#   Efficiency y (srs):  1.095 → 0.487 → 1.3925
#   Alpha:               0.8449844063860191
#   Num changes:         2
#   Design Depth:        128
#   Design Size (|D|):   537
#   Open set size:       1745
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       38845.694
#   Best Cost (y):       143033576.3542
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.497
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7107→ cube 1.0099
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6179→ cube 0.6529
#   Efficiency z (srs):  1.982 → 0.514 → 2.7424
#   Efficiency y (srs):  1.095 → 0.487 → 1.3902
#   Alpha:               0.7846240898239285
#   Num changes:         2
#   Design Depth:        128
#   Design Size (|D|):   537
#   Open set size:       1760
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       38847.624
#   Best Cost (y):       143012837.055
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.497
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7107→ cube 1.0098
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.618→ cube 0.653
#   Efficiency z (srs):  1.982 → 0.514 → 2.7423
#   Efficiency y (srs):  1.095 → 0.487 → 1.3904
#   Alpha:               0.7828748249908077
#   Num changes:         2
#   Design Depth:        128
#   Design Size (|D|):   537
#   Open set size:       1761
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       38859.426
#   Best Cost (y):       142522926.2619
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.491
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7105→ cube 1.0095
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6201→ cube 0.6553
#   Efficiency z (srs):  1.982 → 0.514 → 2.7415
#   Efficiency y (srs):  1.095 → 0.487 → 1.3951
#   Alpha:               0.8656184451055199
#   Num changes:         2
#   Design Depth:        128
#   Design Size (|D|):   537
#   Open set size:       1768
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       37625.438
#   Best Cost (y):       138963371.0759
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.981
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7338→ cube 1.0426
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.636→ cube 0.6721
#   Efficiency z (srs):  1.982 → 0.514 → 2.8314
#   Efficiency y (srs):  1.095 → 0.487 → 1.4309
#   Alpha:               0.8577278179609739
#   Num changes:         3
#   Design Depth:        148
#   Design Size (|D|):   577
#   Open set size:       2033
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       37542.891
#   Best Cost (y):       139184569.5238
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.948
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7354→ cube 1.0449
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.635→ cube 0.671
#   Efficiency z (srs):  1.982 → 0.514 → 2.8376
#   Efficiency y (srs):  1.095 → 0.487 → 1.4286
#   Alpha:               0.713120910720619
#   Num changes:         3
#   Design Depth:        148
#   Design Size (|D|):   577
#   Open set size:       2050
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36155.761
#   Best Cost (y):       137824365.6727
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.413
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7636→ cube 1.085
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6413→ cube 0.6776
#   Efficiency z (srs):  1.982 → 0.514 → 2.9465
#   Efficiency y (srs):  1.095 → 0.487 → 1.4427
#   Alpha:               0.8317406262385858
#   Num changes:         1
#   Design Depth:        166
#   Design Size (|D|):   613
#   Open set size:       2329
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34852.799
#   Best Cost (y):       137555335.4762
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.887
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7922→ cube 1.1256
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6425→ cube 0.6789
#   Efficiency z (srs):  1.982 → 0.514 → 3.0566
#   Efficiency y (srs):  1.095 → 0.487 → 1.4455
#   Alpha:               0.8330532046518503
#   Num changes:         1
#   Design Depth:        187
#   Design Size (|D|):   655
#   Open set size:       2613
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34835.661
#   Best Cost (y):       138051023.6754
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.884
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7925→ cube 1.1261
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6402→ cube 0.6765
#   Efficiency z (srs):  1.982 → 0.514 → 3.0581
#   Efficiency y (srs):  1.095 → 0.487 → 1.4403
#   Alpha:               0.8922677902047276
#   Num changes:         3
#   Design Depth:        189
#   Design Size (|D|):   659
#   Open set size:       2614
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34783.337
#   Best Cost (y):       137554593.8313
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.858
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7937→ cube 1.1278
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6425→ cube 0.6789
#   Efficiency z (srs):  1.982 → 0.514 → 3.0627
#   Efficiency y (srs):  1.095 → 0.487 → 1.4455
#   Alpha:               0.8002232331415227
#   Num changes:         1
#   Design Depth:        187
#   Design Size (|D|):   655
#   Open set size:       2619
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34663.27
#   Best Cost (y):       138070920.1328
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.812
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7965→ cube 1.1317
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6401→ cube 0.6764
#   Efficiency z (srs):  1.982 → 0.514 → 3.0733
#   Efficiency y (srs):  1.095 → 0.487 → 1.4401
#   Alpha:               0.8454992875155483
#   Num changes:         2
#   Design Depth:        188
#   Design Size (|D|):   657
#   Open set size:       2621
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34288.848
#   Best Cost (y):       136980218.2067
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.659
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8052→ cube 1.1441
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6452→ cube 0.6818
#   Efficiency z (srs):  1.982 → 0.514 → 3.1069
#   Efficiency y (srs):  1.095 → 0.487 → 1.4516
#   Alpha:               0.7592470082155938
#   Num changes:         1
#   Design Depth:        206
#   Design Size (|D|):   693
#   Open set size:       2929
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33476.228
#   Best Cost (y):       135124647.7125
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.323
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8247→ cube 1.1719
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6541→ cube 0.6912
#   Efficiency z (srs):  1.982 → 0.514 → 3.1823
#   Efficiency y (srs):  1.095 → 0.487 → 1.4715
#   Alpha:               0.896314052458081
#   Num changes:         2
#   Design Depth:        240
#   Design Size (|D|):   761
#   Open set size:       3481
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33473.298
#   Best Cost (y):       135215972.2205
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.32
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8248→ cube 1.172
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6537→ cube 0.6907
#   Efficiency z (srs):  1.982 → 0.514 → 3.1826
#   Efficiency y (srs):  1.095 → 0.487 → 1.4705
#   Alpha:               0.743625533133828
#   Num changes:         1
#   Design Depth:        239
#   Design Size (|D|):   759
#   Open set size:       3483
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33471.7
#   Best Cost (y):       135143744.6
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.319
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8248→ cube 1.172
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.654→ cube 0.6911
#   Efficiency z (srs):  1.982 → 0.514 → 3.1827
#   Efficiency y (srs):  1.095 → 0.487 → 1.4713
#   Alpha:               0.8222903482343611
#   Num changes:         1
#   Design Depth:        239
#   Design Size (|D|):   759
#   Open set size:       3502
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33309.061
#   Best Cost (y):       135160950.8591
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.247
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8289→ cube 1.1778
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6539→ cube 0.691
#   Efficiency z (srs):  1.982 → 0.514 → 3.1983
#   Efficiency y (srs):  1.095 → 0.487 → 1.4711
#   Alpha:               0.8600482356880773
#   Num changes:         1
#   Design Depth:        256
#   Design Size (|D|):   793
#   Open set size:       4061
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33097.472
#   Best Cost (y):       135235983.2895
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.166
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8342→ cube 1.1853
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6536→ cube 0.6906
#   Efficiency z (srs):  1.982 → 0.514 → 3.2187
#   Efficiency y (srs):  1.095 → 0.487 → 1.4703
#   Alpha:               0.7133069121568721
#   Num changes:         2
#   Design Depth:        257
#   Design Size (|D|):   795
#   Open set size:       4062
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32627.789
#   Best Cost (y):       134696825.4794
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.981
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8462→ cube 1.2023
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6562→ cube 0.6933
#   Efficiency z (srs):  1.982 → 0.514 → 3.2651
#   Efficiency y (srs):  1.095 → 0.487 → 1.4762
#   Alpha:               0.8991317112472674
#   Num changes:         1
#   Design Depth:        275
#   Design Size (|D|):   831
#   Open set size:       4362
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31672.959
#   Best Cost (y):       133744565.5916
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.602
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8717→ cube 1.2386
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6608→ cube 0.6983
#   Efficiency z (srs):  1.982 → 0.514 → 3.3635
#   Efficiency y (srs):  1.095 → 0.487 → 1.4867
#   Alpha:               0.839042868113101
#   Num changes:         1
#   Design Depth:        305
#   Design Size (|D|):   891
#   Open set size:       4940
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31668.817
#   Best Cost (y):       133737215.9521
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.6
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8718→ cube 1.2388
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6609→ cube 0.6983
#   Efficiency z (srs):  1.982 → 0.514 → 3.3639
#   Efficiency y (srs):  1.095 → 0.487 → 1.4868
#   Alpha:               0.7034654388537527
#   Num changes:         1
#   Design Depth:        305
#   Design Size (|D|):   891
#   Open set size:       4944
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31664.117
#   Best Cost (y):       133813782.194
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.599
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8719→ cube 1.2389
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6605→ cube 0.6979
#   Efficiency z (srs):  1.982 → 0.514 → 3.3644
#   Efficiency y (srs):  1.095 → 0.487 → 1.4859
#   Alpha:               0.7856180630489333
#   Num changes:         2
#   Design Depth:        306
#   Design Size (|D|):   893
#   Open set size:       4950
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31112.541
#   Best Cost (y):       132732208.52
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.366
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8874→ cube 1.2609
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6659→ cube 0.7036
#   Efficiency z (srs):  1.982 → 0.514 → 3.4241
#   Efficiency y (srs):  1.095 → 0.487 → 1.4981
#   Alpha:               0.8037592057818879
#   Num changes:         3
#   Design Depth:        357
#   Design Size (|D|):   995
#   Open set size:       5816
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30244.436
#   Best Cost (y):       132963168.177
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.03
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9129→ cube 1.2971
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6647→ cube 0.7024
#   Efficiency z (srs):  1.982 → 0.514 → 3.5224
#   Efficiency y (srs):  1.095 → 0.487 → 1.4955
#   Alpha:               0.7675779337304033
#   Num changes:         2
#   Design Depth:        381
#   Design Size (|D|):   1043
#   Open set size:       6098
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30234.253
#   Best Cost (y):       133145978.2647
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.026
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9132→ cube 1.2975
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6638→ cube 0.7014
#   Efficiency z (srs):  1.982 → 0.514 → 3.5235
#   Efficiency y (srs):  1.095 → 0.487 → 1.4934
#   Alpha:               0.7434584705060965
#   Num changes:         2
#   Design Depth:        381
#   Design Size (|D|):   1043
#   Open set size:       6116
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29718.066
#   Best Cost (y):       130048928.3271
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.797
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.929→ cube 1.3201
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6796→ cube 0.7181
#   Efficiency z (srs):  1.982 → 0.514 → 3.5847
#   Efficiency y (srs):  1.095 → 0.487 → 1.529
#   Alpha:               0.8546756892834899
#   Num changes:         2
#   Design Depth:        423
#   Design Size (|D|):   1127
#   Open set size:       6964
#
#
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29714.395
#   Best Cost (y):       129902810.4606
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.793
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9291→ cube 1.3202
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6804→ cube 0.7189
#   Efficiency z (srs):  1.982 → 0.514 → 3.5852
#   Efficiency y (srs):  1.095 → 0.487 → 1.5307
#   Alpha:               0.86149587923542
#   Num changes:         3
#   Design Depth:        424
#   Design Size (|D|):   1129
#   Open set size:       6973
#
# Progress: 6.5%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29488.777
#   Best Cost (y):       128485280.9086
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.694
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9363→ cube 1.3303
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6879→ cube 0.7269
#   Efficiency z (srs):  1.982 → 0.514 → 3.6126
#   Efficiency y (srs):  1.095 → 0.487 → 1.5476
#   Alpha:               0.8895054607049718
#   Num changes:         1
#   Design Depth:        456
#   Design Size (|D|):   1193
#   Open set size:       7552
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29410.004
#   Best Cost (y):       128482429.9664
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.65
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9388→ cube 1.3339
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6879→ cube 0.7269
#   Efficiency z (srs):  1.982 → 0.514 → 3.6223
#   Efficiency y (srs):  1.095 → 0.487 → 1.5476
#   Alpha:               0.7474875586554666
#   Num changes:         1
#   Design Depth:        472
#   Design Size (|D|):   1225
#   Open set size:       7841
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29410.02
#   Best Cost (y):       128373257.4462
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.65
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9388→ cube 1.3339
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6885→ cube 0.7275
#   Efficiency z (srs):  1.982 → 0.514 → 3.6223
#   Efficiency y (srs):  1.095 → 0.487 → 1.5489
#   Alpha:               0.7500354319604429
#   Num changes:         1
#   Design Depth:        472
#   Design Size (|D|):   1225
#   Open set size:       7860
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28689.936
#   Best Cost (y):       127189481.1993
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.371
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9623→ cube 1.3674
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6949→ cube 0.7343
#   Efficiency z (srs):  1.982 → 0.514 → 3.7132
#   Efficiency y (srs):  1.095 → 0.487 → 1.5633
#   Alpha:               0.8248953577225367
#   Num changes:         1
#   Design Depth:        496
#   Design Size (|D|):   1273
#   Open set size:       8121
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28686.198
#   Best Cost (y):       127101201.449
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.371
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9624→ cube 1.3675
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6954→ cube 0.7348
#   Efficiency z (srs):  1.982 → 0.514 → 3.7137
#   Efficiency y (srs):  1.095 → 0.487 → 1.5644
#   Alpha:               0.7290316258838787
#   Num changes:         2
#   Design Depth:        497
#   Design Size (|D|):   1275
#   Open set size:       8126
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28669.702
#   Best Cost (y):       127129049.2835
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.364
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.963→ cube 1.3683
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6952→ cube 0.7346
#   Efficiency z (srs):  1.982 → 0.514 → 3.7158
#   Efficiency y (srs):  1.095 → 0.487 → 1.5641
#   Alpha:               0.8600914132540779
#   Num changes:         3
#   Design Depth:        498
#   Design Size (|D|):   1277
#   Open set size:       8131
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28512.312
#   Best Cost (y):       127315541.8459
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.296
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9683→ cube 1.3759
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6942→ cube 0.7335
#   Efficiency z (srs):  1.982 → 0.514 → 3.7363
#   Efficiency y (srs):  1.095 → 0.487 → 1.5618
#   Alpha:               0.801898395088876
#   Num changes:         2
#   Design Depth:        519
#   Design Size (|D|):   1319
#   Open set size:       8411
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28499.733
#   Best Cost (y):       127306539.3349
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.294
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9687→ cube 1.3765
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6943→ cube 0.7336
#   Efficiency z (srs):  1.982 → 0.514 → 3.738
#   Efficiency y (srs):  1.095 → 0.487 → 1.5619
#   Alpha:               0.737251658984486
#   Num changes:         3
#   Design Depth:        520
#   Design Size (|D|):   1321
#   Open set size:       8414
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28506.822
#   Best Cost (y):       127353796.3836
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.291
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9685→ cube 1.3762
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.694→ cube 0.7333
#   Efficiency z (srs):  1.982 → 0.514 → 3.7371
#   Efficiency y (srs):  1.095 → 0.487 → 1.5613
#   Alpha:               0.7597440279417146
#   Num changes:         2
#   Design Depth:        519
#   Design Size (|D|):   1319
#   Open set size:       8418
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28445.405
#   Best Cost (y):       127377852.8318
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.268
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9706→ cube 1.3791
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6939→ cube 0.7332
#   Efficiency z (srs):  1.982 → 0.514 → 3.7451
#   Efficiency y (srs):  1.095 → 0.487 → 1.561
#   Alpha:               0.8383624720497697
#   Num changes:         3
#   Design Depth:        520
#   Design Size (|D|):   1321
#   Open set size:       8419
#
# Progress: 7.5%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28255.674
#   Best Cost (y):       127147292.0699
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.199
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9771→ cube 1.3884
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6951→ cube 0.7345
#   Efficiency z (srs):  1.982 → 0.514 → 3.7703
#   Efficiency y (srs):  1.095 → 0.487 → 1.5639
#   Alpha:               0.8126387121035175
#   Num changes:         1
#   Design Depth:        539
#   Design Size (|D|):   1359
#   Open set size:       8701
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27870.665
#   Best Cost (y):       125277507.2918
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.043
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9906→ cube 1.4076
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7055→ cube 0.7455
#   Efficiency z (srs):  1.982 → 0.514 → 3.8224
#   Efficiency y (srs):  1.095 → 0.487 → 1.5872
#   Alpha:               0.701789801406619
#   Num changes:         1
#   Design Depth:        560
#   Design Size (|D|):   1401
#   Open set size:       8991
#
#
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27862.652
#   Best Cost (y):       125160312.4247
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.039
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9909→ cube 1.408
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7062→ cube 0.7462
#   Efficiency z (srs):  1.982 → 0.514 → 3.8235
#   Efficiency y (srs):  1.095 → 0.487 → 1.5887
#   Alpha:               0.8874650700056336
#   Num changes:         2
#   Design Depth:        561
#   Design Size (|D|):   1403
#   Open set size:       9002
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27251.085
#   Best Cost (y):       123487109.7167
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.795
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0131→ cube 1.4396
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7157→ cube 0.7563
#   Efficiency z (srs):  1.982 → 0.514 → 3.9093
#   Efficiency y (srs):  1.095 → 0.487 → 1.6102
#   Alpha:               0.8005157733198737
#   Num changes:         1
#   Design Depth:        583
#   Design Size (|D|):   1447
#   Open set size:       9288
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27171.777
#   Best Cost (y):       122527682.7589
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.757
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0161→ cube 1.4438
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7213→ cube 0.7622
#   Efficiency z (srs):  1.982 → 0.514 → 3.9207
#   Efficiency y (srs):  1.095 → 0.487 → 1.6228
#   Alpha:               0.8950862310295422
#   Num changes:         1
#   Design Depth:        599
#   Design Size (|D|):   1479
#   Open set size:       9590
#
# Progress: 8.5%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27135.993
#   Best Cost (y):       122690638.6273
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.737
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0174→ cube 1.4457
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7204→ cube 0.7612
#   Efficiency z (srs):  1.982 → 0.514 → 3.9258
#   Efficiency y (srs):  1.095 → 0.487 → 1.6207
#   Alpha:               0.7716996574997315
#   Num changes:         1
#   Design Depth:        613
#   Design Size (|D|):   1507
#   Open set size:       9877
#
# Progress: 8.8%
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27092.809
#   Best Cost (y):       122664644.2867
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.715
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.019→ cube 1.448
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7205→ cube 0.7614
#   Efficiency z (srs):  1.982 → 0.514 → 3.9321
#   Efficiency y (srs):  1.095 → 0.487 → 1.621
#   Alpha:               0.810177419899864
#   Num changes:         3
#   Design Depth:        628
#   Design Size (|D|):   1537
#   Open set size:       10155
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26622.866
#   Best Cost (y):       120612252.8361
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.518
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.037→ cube 1.4735
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7328→ cube 0.7743
#   Efficiency z (srs):  1.982 → 0.514 → 4.0015
#   Efficiency y (srs):  1.095 → 0.487 → 1.6486
#   Alpha:               0.7204041456650802
#   Num changes:         1
#   Design Depth:        651
#   Design Size (|D|):   1583
#   Open set size:       10445
#
#
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26619.085
#   Best Cost (y):       120622877.3266
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.518
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0372→ cube 1.4737
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7327→ cube 0.7742
#   Efficiency z (srs):  1.982 → 0.514 → 4.0021
#   Efficiency y (srs):  1.095 → 0.487 → 1.6484
#   Alpha:               0.8977255351807137
#   Num changes:         3
#   Design Depth:        653
#   Design Size (|D|):   1587
#   Open set size:       10446
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25935.506
#   Best Cost (y):       120144844.0519
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.247
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0645→ cube 1.5126
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7356→ cube 0.7773
#   Efficiency z (srs):  1.982 → 0.514 → 4.1076
#   Efficiency y (srs):  1.095 → 0.487 → 1.655
#   Alpha:               0.8122448873112832
#   Num changes:         3
#   Design Depth:        679
#   Design Size (|D|):   1639
#   Open set size:       10737
#
#
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25938.107
#   Best Cost (y):       120163310.7624
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.247
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0644→ cube 1.5124
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7355→ cube 0.7772
#   Efficiency z (srs):  1.982 → 0.514 → 4.1072
#   Efficiency y (srs):  1.095 → 0.487 → 1.6548
#   Alpha:               0.86206878581005
#   Num changes:         2
#   Design Depth:        678
#   Design Size (|D|):   1637
#   Open set size:       10741
#
# Progress: 9.5%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25678.234
#   Best Cost (y):       119029628.8009
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.14
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0752→ cube 1.5277
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7425→ cube 0.7846
#   Efficiency z (srs):  1.982 → 0.514 → 4.1487
#   Efficiency y (srs):  1.095 → 0.487 → 1.6705
#   Alpha:               0.811061407231986
#   Num changes:         1
#   Design Depth:        696
#   Design Size (|D|):   1673
#   Open set size:       11039
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25675.434
#   Best Cost (y):       119160870.1948
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.139
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0753→ cube 1.5279
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7417→ cube 0.7837
#   Efficiency z (srs):  1.982 → 0.514 → 4.1492
#   Efficiency y (srs):  1.095 → 0.487 → 1.6687
#   Alpha:               0.8582852050883855
#   Num changes:         3
#   Design Depth:        698
#   Design Size (|D|):   1677
#   Open set size:       11041
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
# ...
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0306→ cube 2.8853
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9717→ cube 1.0267
#   Efficiency z (srs):  1.982 → 0.514 → 7.8352
#   Efficiency y (srs):  1.095 → 0.487 → 2.1859
#   Alpha:               0.8669093851483568
#   Num changes:         1
#   Design Depth:        5026
#   Design Size (|D|):   10333
#   Open set size:       92521
#
#
# === Best Solution Updated at Iteration 3190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13593.881
#   Best Cost (y):       90948467.6145
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.093
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.031→ cube 2.8858
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9718→ cube 1.0269
#   Efficiency z (srs):  1.982 → 0.514 → 7.8367
#   Efficiency y (srs):  1.095 → 0.487 → 2.1863
#   Alpha:               0.8779212260697538
#   Num changes:         3
#   Design Depth:        5028
#   Design Size (|D|):   10337
#   Open set size:       92531
#
# Progress: 80.2%
# === Best Solution Updated at Iteration 3210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13569.28
#   Best Cost (y):       90890368.0234
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.082
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0347→ cube 2.8911
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9724→ cube 1.0275
#   Efficiency z (srs):  1.982 → 0.514 → 7.851
#   Efficiency y (srs):  1.095 → 0.487 → 2.1877
#   Alpha:               0.8430662554211021
#   Num changes:         2
#   Design Depth:        5059
#   Design Size (|D|):   10399
#   Open set size:       93092
#
#
# === Best Solution Updated at Iteration 3210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13568.945
#   Best Cost (y):       90895906.374
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.082
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0347→ cube 2.8911
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9724→ cube 1.0275
#   Efficiency z (srs):  1.982 → 0.514 → 7.8511
#   Efficiency y (srs):  1.095 → 0.487 → 2.1876
#   Alpha:               0.7938197218295102
#   Num changes:         2
#   Design Depth:        5059
#   Design Size (|D|):   10399
#   Open set size:       93101
#
#
# === Best Solution Updated at Iteration 3210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13564.038
#   Best Cost (y):       90915308.1585
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.08
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0354→ cube 2.8922
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9722→ cube 1.0272
#   Efficiency z (srs):  1.982 → 0.514 → 7.854
#   Efficiency y (srs):  1.095 → 0.487 → 2.1871
#   Alpha:               0.7742859659743995
#   Num changes:         3
#   Design Depth:        5060
#   Design Size (|D|):   10401
#   Open set size:       93102
#
#
# === Best Solution Updated at Iteration 3210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13562.988
#   Best Cost (y):       90947126.9129
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.079
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0356→ cube 2.8924
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9718→ cube 1.0269
#   Efficiency z (srs):  1.982 → 0.514 → 7.8546
#   Efficiency y (srs):  1.095 → 0.487 → 2.1863
#   Alpha:               0.8662448239458371
#   Num changes:         1
#   Design Depth:        5058
#   Design Size (|D|):   10397
#   Open set size:       93104
#
# Progress: 80.5%
# === Best Solution Updated at Iteration 3220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13536.029
#   Best Cost (y):       90899195.0425
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.069
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0397→ cube 2.8982
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9723→ cube 1.0274
#   Efficiency z (srs):  1.982 → 0.514 → 7.8702
#   Efficiency y (srs):  1.095 → 0.487 → 2.1875
#   Alpha:               0.8813615456522121
#   Num changes:         1
#   Design Depth:        5074
#   Design Size (|D|):   10429
#   Open set size:       93388
#
#
# === Best Solution Updated at Iteration 3220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13535.936
#   Best Cost (y):       90904213.6987
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.069
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0397→ cube 2.8982
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9723→ cube 1.0274
#   Efficiency z (srs):  1.982 → 0.514 → 7.8703
#   Efficiency y (srs):  1.095 → 0.487 → 2.1874
#   Alpha:               0.8427593331353453
#   Num changes:         1
#   Design Depth:        5074
#   Design Size (|D|):   10429
#   Open set size:       93402
#
# Progress: 80.8%
# === Best Solution Updated at Iteration 3230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13530.226
#   Best Cost (y):       90926895.1509
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.067
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0405→ cube 2.8994
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.972→ cube 1.0271
#   Efficiency z (srs):  1.982 → 0.514 → 7.8736
#   Efficiency y (srs):  1.095 → 0.487 → 2.1868
#   Alpha:               0.8378098013014157
#   Num changes:         1
#   Design Depth:        5084
#   Design Size (|D|):   10449
#   Open set size:       93698
#
# Progress: 81.0%
# === Best Solution Updated at Iteration 3240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13511.211
#   Best Cost (y):       90852677.1488
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.058
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0434→ cube 2.9035
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9728→ cube 1.0279
#   Efficiency z (srs):  1.982 → 0.514 → 7.8847
#   Efficiency y (srs):  1.095 → 0.487 → 2.1886
#   Alpha:               0.76228430051469
#   Num changes:         1
#   Design Depth:        5099
#   Design Size (|D|):   10479
#   Open set size:       93964
#
#
# === Best Solution Updated at Iteration 3240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13509.924
#   Best Cost (y):       90850285.9008
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.058
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0436→ cube 2.9038
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9729→ cube 1.028
#   Efficiency z (srs):  1.982 → 0.514 → 7.8854
#   Efficiency y (srs):  1.095 → 0.487 → 2.1887
#   Alpha:               0.7288777579811763
#   Num changes:         2
#   Design Depth:        5100
#   Design Size (|D|):   10481
#   Open set size:       93966
#
#
# === Best Solution Updated at Iteration 3240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13509.918
#   Best Cost (y):       90779963.6043
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.058
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0436→ cube 2.9038
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9736→ cube 1.0288
#   Efficiency z (srs):  1.982 → 0.514 → 7.8854
#   Efficiency y (srs):  1.095 → 0.487 → 2.1904
#   Alpha:               0.8543830465995387
#   Num changes:         3
#   Design Depth:        5101
#   Design Size (|D|):   10483
#   Open set size:       93976
#
# Progress: 81.2%
# === Best Solution Updated at Iteration 3250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13465.648
#   Best Cost (y):       90804038.372
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.04
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0503→ cube 2.9133
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9734→ cube 1.0285
#   Efficiency z (srs):  1.982 → 0.514 → 7.9114
#   Efficiency y (srs):  1.095 → 0.487 → 2.1898
#   Alpha:               0.8080029515933433
#   Num changes:         3
#   Design Depth:        5123
#   Design Size (|D|):   10527
#   Open set size:       94255
#
# Progress: 81.5%
# === Best Solution Updated at Iteration 3260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13456.635
#   Best Cost (y):       90794090.8004
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.036
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0517→ cube 2.9153
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9735→ cube 1.0286
#   Efficiency z (srs):  1.982 → 0.514 → 7.9167
#   Efficiency y (srs):  1.095 → 0.487 → 2.19
#   Alpha:               0.8874131839967078
#   Num changes:         1
#   Design Depth:        5138
#   Design Size (|D|):   10557
#   Open set size:       94541
#
# Progress: 81.8%
# === Best Solution Updated at Iteration 3270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13452.121
#   Best Cost (y):       90699422.3373
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.034
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0524→ cube 2.9163
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9745→ cube 1.0297
#   Efficiency z (srs):  1.982 → 0.514 → 7.9193
#   Efficiency y (srs):  1.095 → 0.487 → 2.1923
#   Alpha:               0.7736157837940205
#   Num changes:         1
#   Design Depth:        5155
#   Design Size (|D|):   10591
#   Open set size:       94832
#
#
# === Best Solution Updated at Iteration 3270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13451.739
#   Best Cost (y):       90700313.7483
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.034
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0524→ cube 2.9163
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9745→ cube 1.0297
#   Efficiency z (srs):  1.982 → 0.514 → 7.9196
#   Efficiency y (srs):  1.095 → 0.487 → 2.1923
#   Alpha:               0.7598756166089236
#   Num changes:         1
#   Design Depth:        5155
#   Design Size (|D|):   10591
#   Open set size:       94835
#
#
# === Best Solution Updated at Iteration 3270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13451.683
#   Best Cost (y):       90754521.0522
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.034
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0525→ cube 2.9163
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9739→ cube 1.0291
#   Efficiency z (srs):  1.982 → 0.514 → 7.9196
#   Efficiency y (srs):  1.095 → 0.487 → 2.191
#   Alpha:               0.7479703851247349
#   Num changes:         1
#   Design Depth:        5155
#   Design Size (|D|):   10591
#   Open set size:       94859
#
# Progress: 82.0%
# === Best Solution Updated at Iteration 3280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       13442.038
#   Best Cost (y):       90708811.22
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.03
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.0539→ cube 2.9184
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.9744→ cube 1.0296
#   Efficiency z (srs):  1.982 → 0.514 → 7.9253
#   Efficiency y (srs):  1.095 → 0.487 → 2.1921
#   Alpha:               0.7491555439171632
#   Num changes:         3
#   Design Depth:        5177
#   Design Size (|D|):   10635
#   Open set size:       95123
#
# Progress: 82.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 93
#      65 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      66                    inclusion_probability=inclusions, balance_method='linear')
#      68 astar = AStar(
#      69     inclusions              = inclusions,
#      70     num_initial_nodes       = num_initial_nodes,
#    (...)     90     # delta                   = 0.01,
#      91 )
# ---> 93 result = astar.run(
#      94     max_iterations             = max_iterations,
#      95     num_new_nodes              = num_new_nodes,
#      96     max_open_set_size          = max_open_set_size,
#      97     random_restart_period      = random_restart_period,
#      98     random_injection_count     = random_injection_count,
#      99     prune_fraction             = prune_fraction,
#     100     num_top_restart_nodes      = num_top_restart_nodes,
#     101     stuck_fraction             = stuck_fraction,
#     102
#     103 )
#     105 print("Best criteria value:", astar.best_criteria_value)
#     106 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:29, in VarNHT.__call__(self, design)
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
# ---> 29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#      33 samples_probabilities = np.array([sample.probability for sample in design])
#      34 var_NHT_z = np.sum((NHT_estimator_z - np.sum(self.auxiliary_variable)) ** 2 * samples_probabilities)
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2333, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2327         raise ValueError("Passing `min` or `max` keyword argument when "
#    2328                          "`a_min` and `a_max` are provided is forbidden.")
#    2330     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2333 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2334                     initial=None, where=None):
#    2335     return (a, out)
#    2338 @array_function_dispatch(_sum_dispatcher)
#    2339 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2340         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
