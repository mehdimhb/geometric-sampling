# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Real_Sweden"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/Rtmpk1AdnY", R: "/tmp/RtmpzeabIr"
#   warnings.warn(

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 15

# %%
num_new_nodes          = 50

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.05338078
# [1] 199550387.9    106912.2

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 1511.2806 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0679 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0256 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.03389852
# Variance of HT estimator via DSD formula_z:  27608.92
# Variance of HT estimator via DSD formula:  88384256
# Here is the Vincent Efficiency y:
#   DSD_y:  1.14641
#   DSD_z: 3.87238
# Monte Carlo variance of HT estimator for y:
#   DSD:  85971369.17998
#   Cube: 93391724.32965
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.17859
#   Cube: 1.08494
# Monte Carlo mean of HT estimator for y:
#   DSD:  53546.92758
#   Cube: 53113.46378
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  26307.99858
#   Cube: 39229.78326
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  4.06387
#   Cube: 2.72528
# Monte Carlo mean of HT estimator for z:
#   DSD:  2505.55578
#   Cube: 2506.39929
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        2.73        3.87        1.97        2.14        2.26

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_6199/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639387
# [281] [15.] adsfa
# 4000 50 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 21.47it/s]
# Initial design 0: method = Original, efficiency z = 0.5137, y=0.4868
# New best at idx=0: method = Original, efficiency z = 0.5137 and efficiency y = 0.4868
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53553.772
#   Best Cost (y):       181560666.9423
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.563
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5155→ cube 0.7325
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4868→ cube 0.5144
#   Efficiency z (srs):  1.982 → 0.514 → 1.9892
#   Efficiency y (srs):  1.095 → 0.487 → 1.0952
#   Alpha:               0.7000277178713414
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       6
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53486.108
#   Best Cost (y):       181572524.308
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.529
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5162→ cube 0.7335
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4868→ cube 0.5143
#   Efficiency z (srs):  1.982 → 0.514 → 1.9918
#   Efficiency y (srs):  1.095 → 0.487 → 1.0951
#   Alpha:               0.7011689367608881
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       17
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53361.851
#   Best Cost (y):       181553671.1826
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.481
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5174→ cube 0.7352
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4868→ cube 0.5144
#   Efficiency z (srs):  1.982 → 0.514 → 1.9964
#   Efficiency y (srs):  1.095 → 0.487 → 1.0952
#   Alpha:               0.8612016540142015
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       25
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53311.011
#   Best Cost (y):       181550811.3041
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.472
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5179→ cube 0.7359
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4868→ cube 0.5144
#   Efficiency z (srs):  1.982 → 0.514 → 1.9983
#   Efficiency y (srs):  1.095 → 0.487 → 1.0952
#   Alpha:               0.8278271725239315
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       45
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53073.515
#   Best Cost (y):       182529172.9739
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.391
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5202→ cube 0.7392
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4842→ cube 0.5117
#   Efficiency z (srs):  1.982 → 0.514 → 2.0072
#   Efficiency y (srs):  1.095 → 0.487 → 1.0894
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4
#   Design Size (|D|):   289
#   Open set size:       99
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       42231.857
#   Best Cost (y):       161949822.5145
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.052
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6537→ cube 0.9289
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5458→ cube 0.5767
#   Efficiency z (srs):  1.982 → 0.514 → 2.5225
#   Efficiency y (srs):  1.095 → 0.487 → 1.2278
#   Alpha:               0.7821590046835688
#   Num changes:         2
#   Design Depth:        27
#   Design Size (|D|):   335
#   Open set size:       496
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       42096.841
#   Best Cost (y):       161761301.7457
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.003
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6558→ cube 0.9319
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5464→ cube 0.5773
#   Efficiency z (srs):  1.982 → 0.514 → 2.5306
#   Efficiency y (srs):  1.095 → 0.487 → 1.2292
#   Alpha:               0.8969518200168478
#   Num changes:         1
#   Design Depth:        26
#   Design Size (|D|):   333
#   Open set size:       497
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       42000.097
#   Best Cost (y):       160579063.1459
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.966
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6574→ cube 0.934
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5504→ cube 0.5816
#   Efficiency z (srs):  1.982 → 0.514 → 2.5365
#   Efficiency y (srs):  1.095 → 0.487 → 1.2383
#   Alpha:               0.7771774295704325
#   Num changes:         1
#   Design Depth:        26
#   Design Size (|D|):   333
#   Open set size:       505
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41779.924
#   Best Cost (y):       161052432.7706
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.873
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6608→ cube 0.939
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5488→ cube 0.5799
#   Efficiency z (srs):  1.982 → 0.514 → 2.5498
#   Efficiency y (srs):  1.095 → 0.487 → 1.2346
#   Alpha:               0.8827950386551953
#   Num changes:         3
#   Design Depth:        28
#   Design Size (|D|):   337
#   Open set size:       522
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       41025.574
#   Best Cost (y):       154149062.9441
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.478
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.673→ cube 0.9562
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5734→ cube 0.6059
#   Efficiency z (srs):  1.982 → 0.514 → 2.5967
#   Efficiency y (srs):  1.095 → 0.487 → 1.2899
#   Alpha:               0.8240334728960198
#   Num changes:         1
#   Design Depth:        47
#   Design Size (|D|):   375
#   Open set size:       983
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       40953.059
#   Best Cost (y):       154582803.1679
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.447
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6742→ cube 0.9579
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5718→ cube 0.6042
#   Efficiency z (srs):  1.982 → 0.514 → 2.6013
#   Efficiency y (srs):  1.095 → 0.487 → 1.2863
#   Alpha:               0.7465302589547841
#   Num changes:         2
#   Design Depth:        48
#   Design Size (|D|):   377
#   Open set size:       990
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       40666.847
#   Best Cost (y):       153491676.874
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.379
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6789→ cube 0.9647
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5758→ cube 0.6084
#   Efficiency z (srs):  1.982 → 0.514 → 2.6196
#   Efficiency y (srs):  1.095 → 0.487 → 1.2954
#   Alpha:               0.8802654545242417
#   Num changes:         3
#   Design Depth:        49
#   Design Size (|D|):   379
#   Open set size:       1002
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       39054.064
#   Best Cost (y):       149161116.9599
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.713
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7069→ cube 1.0045
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5925→ cube 0.6261
#   Efficiency z (srs):  1.982 → 0.514 → 2.7278
#   Efficiency y (srs):  1.095 → 0.487 → 1.3331
#   Alpha:               0.7666885040918455
#   Num changes:         1
#   Design Depth:        70
#   Design Size (|D|):   421
#   Open set size:       1479
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       39054.582
#   Best Cost (y):       149161056.0708
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.712
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7069→ cube 1.0045
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5925→ cube 0.6261
#   Efficiency z (srs):  1.982 → 0.514 → 2.7278
#   Efficiency y (srs):  1.095 → 0.487 → 1.3331
#   Alpha:               0.7819799141255618
#   Num changes:         1
#   Design Depth:        70
#   Design Size (|D|):   421
#   Open set size:       1493
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       39041.962
#   Best Cost (y):       149255537.4902
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.705
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7072→ cube 1.0048
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5922→ cube 0.6257
#   Efficiency z (srs):  1.982 → 0.514 → 2.7286
#   Efficiency y (srs):  1.095 → 0.487 → 1.3322
#   Alpha:               0.8987460679768451
#   Num changes:         1
#   Design Depth:        70
#   Design Size (|D|):   421
#   Open set size:       1501
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       37875.848
#   Best Cost (y):       146854022.6924
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.207
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7289→ cube 1.0357
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6019→ cube 0.6359
#   Efficiency z (srs):  1.982 → 0.514 → 2.8127
#   Efficiency y (srs):  1.095 → 0.487 → 1.354
#   Alpha:               0.8630636801977503
#   Num changes:         1
#   Design Depth:        89
#   Design Size (|D|):   459
#   Open set size:       1973
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       37867.409
#   Best Cost (y):       146832333.0733
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.201
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7291→ cube 1.036
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6019→ cube 0.636
#   Efficiency z (srs):  1.982 → 0.514 → 2.8133
#   Efficiency y (srs):  1.095 → 0.487 → 1.3542
#   Alpha:               0.8575038221792896
#   Num changes:         1
#   Design Depth:        89
#   Design Size (|D|):   459
#   Open set size:       1977
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36903.531
#   Best Cost (y):       144673993.1542
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.804
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7481→ cube 1.063
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6109→ cube 0.6455
#   Efficiency z (srs):  1.982 → 0.514 → 2.8868
#   Efficiency y (srs):  1.095 → 0.487 → 1.3744
#   Alpha:               0.7170556736891328
#   Num changes:         3
#   Design Depth:        112
#   Design Size (|D|):   505
#   Open set size:       2457
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36876.357
#   Best Cost (y):       145047911.6298
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.792
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7487→ cube 1.0638
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6093→ cube 0.6439
#   Efficiency z (srs):  1.982 → 0.514 → 2.8889
#   Efficiency y (srs):  1.095 → 0.487 → 1.3709
#   Alpha:               0.7036094327089752
#   Num changes:         1
#   Design Depth:        110
#   Design Size (|D|):   501
#   Open set size:       2459
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36863.366
#   Best Cost (y):       145010230.0928
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.786
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.749→ cube 1.0642
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6095→ cube 0.644
#   Efficiency z (srs):  1.982 → 0.514 → 2.8899
#   Efficiency y (srs):  1.095 → 0.487 → 1.3712
#   Alpha:               0.7921389406400677
#   Num changes:         1
#   Design Depth:        110
#   Design Size (|D|):   501
#   Open set size:       2489
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36048.478
#   Best Cost (y):       143945359.7403
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.475
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7659→ cube 1.0883
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.614→ cube 0.6488
#   Efficiency z (srs):  1.982 → 0.514 → 2.9552
#   Efficiency y (srs):  1.095 → 0.487 → 1.3814
#   Alpha:               0.7653006630273268
#   Num changes:         3
#   Design Depth:        127
#   Design Size (|D|):   535
#   Open set size:       2944
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36037.425
#   Best Cost (y):       143878762.0287
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.465
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7661→ cube 1.0886
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6143→ cube 0.6491
#   Efficiency z (srs):  1.982 → 0.514 → 2.9561
#   Efficiency y (srs):  1.095 → 0.487 → 1.382
#   Alpha:               0.7682138763780119
#   Num changes:         2
#   Design Depth:        126
#   Design Size (|D|):   533
#   Open set size:       2957
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36037.755
#   Best Cost (y):       143694682.12
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.465
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7661→ cube 1.0886
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6151→ cube 0.6499
#   Efficiency z (srs):  1.982 → 0.514 → 2.9561
#   Efficiency y (srs):  1.095 → 0.487 → 1.3838
#   Alpha:               0.7724977780484211
#   Num changes:         2
#   Design Depth:        126
#   Design Size (|D|):   533
#   Open set size:       2961
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       36029.886
#   Best Cost (y):       144078931.261
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.465
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7663→ cube 1.0888
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6134→ cube 0.6482
#   Efficiency z (srs):  1.982 → 0.514 → 2.9568
#   Efficiency y (srs):  1.095 → 0.487 → 1.3801
#   Alpha:               0.8946182392523245
#   Num changes:         3
#   Design Depth:        127
#   Design Size (|D|):   535
#   Open set size:       2970
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34747.309
#   Best Cost (y):       140294620.4006
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.963
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7946→ cube 1.129
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.63→ cube 0.6657
#   Efficiency z (srs):  1.982 → 0.514 → 3.0659
#   Efficiency y (srs):  1.095 → 0.487 → 1.4173
#   Alpha:               0.7946592748416078
#   Num changes:         3
#   Design Depth:        145
#   Design Size (|D|):   571
#   Open set size:       3432
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34826.702
#   Best Cost (y):       138554371.6896
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.96
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7928→ cube 1.1264
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6379→ cube 0.674
#   Efficiency z (srs):  1.982 → 0.514 → 3.0589
#   Efficiency y (srs):  1.095 → 0.487 → 1.4351
#   Alpha:               0.7151789756112044
#   Num changes:         3
#   Design Depth:        145
#   Design Size (|D|):   571
#   Open set size:       3441
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34803.219
#   Best Cost (y):       139846899.226
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.954
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7933→ cube 1.1272
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.632→ cube 0.6678
#   Efficiency z (srs):  1.982 → 0.514 → 3.061
#   Efficiency y (srs):  1.095 → 0.487 → 1.4218
#   Alpha:               0.7745316043230701
#   Num changes:         3
#   Design Depth:        145
#   Design Size (|D|):   571
#   Open set size:       3460
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33204.812
#   Best Cost (y):       139132074.2406
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.339
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8315→ cube 1.1814
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6353→ cube 0.6712
#   Efficiency z (srs):  1.982 → 0.514 → 3.2083
#   Efficiency y (srs):  1.095 → 0.487 → 1.4291
#   Alpha:               0.7667389587858056
#   Num changes:         3
#   Design Depth:        168
#   Design Size (|D|):   617
#   Open set size:       3921
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32965.6
#   Best Cost (y):       137004979.4073
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.223
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8375→ cube 1.19
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6451→ cube 0.6817
#   Efficiency z (srs):  1.982 → 0.514 → 3.2316
#   Efficiency y (srs):  1.095 → 0.487 → 1.4513
#   Alpha:               0.8603015528061912
#   Num changes:         3
#   Design Depth:        186
#   Design Size (|D|):   653
#   Open set size:       4435
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32879.235
#   Best Cost (y):       135710681.939
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.174
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8397→ cube 1.1931
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6513→ cube 0.6882
#   Efficiency z (srs):  1.982 → 0.514 → 3.2401
#   Efficiency y (srs):  1.095 → 0.487 → 1.4652
#   Alpha:               0.7275751697032676
#   Num changes:         1
#   Design Depth:        200
#   Design Size (|D|):   681
#   Open set size:       4905
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32874.853
#   Best Cost (y):       135755340.4648
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.172
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8398→ cube 1.1933
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6511→ cube 0.6879
#   Efficiency z (srs):  1.982 → 0.514 → 3.2405
#   Efficiency y (srs):  1.095 → 0.487 → 1.4647
#   Alpha:               0.735751997336291
#   Num changes:         1
#   Design Depth:        200
#   Design Size (|D|):   681
#   Open set size:       4907
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32821.81
#   Best Cost (y):       136555803.9467
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.158
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8412→ cube 1.1952
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6472→ cube 0.6839
#   Efficiency z (srs):  1.982 → 0.514 → 3.2458
#   Efficiency y (srs):  1.095 → 0.487 → 1.4561
#   Alpha:               0.8523814547735616
#   Num changes:         3
#   Design Depth:        202
#   Design Size (|D|):   685
#   Open set size:       4939
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32362.065
#   Best Cost (y):       135910762.3959
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.937
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8531→ cube 1.2122
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6503→ cube 0.6872
#   Efficiency z (srs):  1.982 → 0.514 → 3.2919
#   Efficiency y (srs):  1.095 → 0.487 → 1.463
#   Alpha:               0.7536234943766802
#   Num changes:         2
#   Design Depth:        222
#   Design Size (|D|):   725
#   Open set size:       5407
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32346.708
#   Best Cost (y):       135683980.3909
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.928
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8535→ cube 1.2128
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6514→ cube 0.6883
#   Efficiency z (srs):  1.982 → 0.514 → 3.2934
#   Efficiency y (srs):  1.095 → 0.487 → 1.4655
#   Alpha:               0.8038145071944178
#   Num changes:         2
#   Design Depth:        222
#   Design Size (|D|):   725
#   Open set size:       5421
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32065.62
#   Best Cost (y):       133804200.3964
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.797
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.861→ cube 1.2234
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6605→ cube 0.698
#   Efficiency z (srs):  1.982 → 0.514 → 3.3223
#   Efficiency y (srs):  1.095 → 0.487 → 1.4861
#   Alpha:               0.8447760944484621
#   Num changes:         2
#   Design Depth:        241
#   Design Size (|D|):   763
#   Open set size:       5900
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30721.982
#   Best Cost (y):       130717279.3998
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.23
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8987→ cube 1.2769
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6761→ cube 0.7145
#   Efficiency z (srs):  1.982 → 0.514 → 3.4676
#   Efficiency y (srs):  1.095 → 0.487 → 1.5211
#   Alpha:               0.8441081189787543
#   Num changes:         1
#   Design Depth:        267
#   Design Size (|D|):   815
#   Open set size:       6372
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30730.068
#   Best Cost (y):       130481790.2908
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.226
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8984→ cube 1.2766
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6774→ cube 0.7157
#   Efficiency z (srs):  1.982 → 0.514 → 3.4667
#   Efficiency y (srs):  1.095 → 0.487 → 1.5239
#   Alpha:               0.8955877484744552
#   Num changes:         3
#   Design Depth:        269
#   Design Size (|D|):   819
#   Open set size:       6390
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30719.088
#   Best Cost (y):       130304564.896
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.218
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8988→ cube 1.277
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6783→ cube 0.7167
#   Efficiency z (srs):  1.982 → 0.514 → 3.4679
#   Efficiency y (srs):  1.095 → 0.487 → 1.526
#   Alpha:               0.8622827737660222
#   Num changes:         3
#   Design Depth:        269
#   Design Size (|D|):   819
#   Open set size:       6419
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29785.346
#   Best Cost (y):       129793743.5097
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.847
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9269→ cube 1.3171
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.681→ cube 0.7195
#   Efficiency z (srs):  1.982 → 0.514 → 3.5767
#   Efficiency y (srs):  1.095 → 0.487 → 1.532
#   Alpha:               0.8946443627406726
#   Num changes:         1
#   Design Depth:        292
#   Design Size (|D|):   865
#   Open set size:       6884
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28893.171
#   Best Cost (y):       129509674.5052
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.49
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9556→ cube 1.3578
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6825→ cube 0.7211
#   Efficiency z (srs):  1.982 → 0.514 → 3.6871
#   Efficiency y (srs):  1.095 → 0.487 → 1.5353
#   Alpha:               0.7018242082659243
#   Num changes:         1
#   Design Depth:        308
#   Design Size (|D|):   897
#   Open set size:       7391
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28800.433
#   Best Cost (y):       128280605.4974
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.439
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9586→ cube 1.3621
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.689→ cube 0.728
#   Efficiency z (srs):  1.982 → 0.514 → 3.699
#   Efficiency y (srs):  1.095 → 0.487 → 1.55
#   Alpha:               0.7789908364334721
#   Num changes:         1
#   Design Depth:        333
#   Design Size (|D|):   947
#   Open set size:       8340
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28795.048
#   Best Cost (y):       128182618.6134
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.437
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9588→ cube 1.3624
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6895→ cube 0.7286
#   Efficiency z (srs):  1.982 → 0.514 → 3.6997
#   Efficiency y (srs):  1.095 → 0.487 → 1.5512
#   Alpha:               0.7808103890036711
#   Num changes:         1
#   Design Depth:        333
#   Design Size (|D|):   947
#   Open set size:       8345
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28787.073
#   Best Cost (y):       128433287.5373
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.437
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9591→ cube 1.3628
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6882→ cube 0.7272
#   Efficiency z (srs):  1.982 → 0.514 → 3.7007
#   Efficiency y (srs):  1.095 → 0.487 → 1.5482
#   Alpha:               0.8873288470449088
#   Num changes:         2
#   Design Depth:        334
#   Design Size (|D|):   949
#   Open set size:       8346
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27941.534
#   Best Cost (y):       127282435.102
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.079
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9881→ cube 1.404
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6944→ cube 0.7337
#   Efficiency z (srs):  1.982 → 0.514 → 3.8127
#   Efficiency y (srs):  1.095 → 0.487 → 1.5622
#   Alpha:               0.7148255801496156
#   Num changes:         2
#   Design Depth:        358
#   Design Size (|D|):   997
#   Open set size:       8823
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27880.223
#   Best Cost (y):       127455555.4293
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.05
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9903→ cube 1.4071
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6935→ cube 0.7327
#   Efficiency z (srs):  1.982 → 0.514 → 3.8211
#   Efficiency y (srs):  1.095 → 0.487 → 1.5601
#   Alpha:               0.875932212747128
#   Num changes:         2
#   Design Depth:        358
#   Design Size (|D|):   997
#   Open set size:       8824
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27878.95
#   Best Cost (y):       127225940.9315
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.05
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9903→ cube 1.4071
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6947→ cube 0.7341
#   Efficiency z (srs):  1.982 → 0.514 → 3.8212
#   Efficiency y (srs):  1.095 → 0.487 → 1.5629
#   Alpha:               0.7417334749417969
#   Num changes:         2
#   Design Depth:        358
#   Design Size (|D|):   997
#   Open set size:       8825
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27743.803
#   Best Cost (y):       127100706.7087
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.995
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9951→ cube 1.414
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6954→ cube 0.7348
#   Efficiency z (srs):  1.982 → 0.514 → 3.8398
#   Efficiency y (srs):  1.095 → 0.487 → 1.5644
#   Alpha:               0.7478256260988375
#   Num changes:         3
#   Design Depth:        359
#   Design Size (|D|):   999
#   Open set size:       8848
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27568.443
#   Best Cost (y):       127091596.3299
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.931
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0015→ cube 1.423
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6954→ cube 0.7348
#   Efficiency z (srs):  1.982 → 0.514 → 3.8643
#   Efficiency y (srs):  1.095 → 0.487 → 1.5645
#   Alpha:               0.7438057177664715
#   Num changes:         3
#   Design Depth:        359
#   Design Size (|D|):   999
#   Open set size:       8850
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27251.0
#   Best Cost (y):       126209662.7212
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.787
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0131→ cube 1.4396
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7003→ cube 0.74
#   Efficiency z (srs):  1.982 → 0.514 → 3.9093
#   Efficiency y (srs):  1.095 → 0.487 → 1.5755
#   Alpha:               0.706103733620874
#   Num changes:         1
#   Design Depth:        378
#   Design Size (|D|):   1037
#   Open set size:       9311
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27233.665
#   Best Cost (y):       126141435.7832
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.781
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0138→ cube 1.4405
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7007→ cube 0.7404
#   Efficiency z (srs):  1.982 → 0.514 → 3.9118
#   Efficiency y (srs):  1.095 → 0.487 → 1.5763
#   Alpha:               0.8789883202531948
#   Num changes:         3
#   Design Depth:        380
#   Design Size (|D|):   1041
#   Open set size:       9324
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27101.247
#   Best Cost (y):       125275099.6349
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.728
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0187→ cube 1.4475
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7055→ cube 0.7455
#   Efficiency z (srs):  1.982 → 0.514 → 3.9309
#   Efficiency y (srs):  1.095 → 0.487 → 1.5872
#   Alpha:               0.7004110346197967
#   Num changes:         2
#   Design Depth:        397
#   Design Size (|D|):   1075
#   Open set size:       9813
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27104.107
#   Best Cost (y):       125247502.1825
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.728
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0186→ cube 1.4474
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7057→ cube 0.7457
#   Efficiency z (srs):  1.982 → 0.514 → 3.9305
#   Efficiency y (srs):  1.095 → 0.487 → 1.5876
#   Alpha:               0.8190687244350592
#   Num changes:         3
#   Design Depth:        398
#   Design Size (|D|):   1077
#   Open set size:       9814
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27100.526
#   Best Cost (y):       125292132.2204
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.728
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0188→ cube 1.4476
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7054→ cube 0.7454
#   Efficiency z (srs):  1.982 → 0.514 → 3.931
#   Efficiency y (srs):  1.095 → 0.487 → 1.587
#   Alpha:               0.81734483629627
#   Num changes:         2
#   Design Depth:        397
#   Design Size (|D|):   1075
#   Open set size:       9845
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26757.312
#   Best Cost (y):       124563268.8553
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.591
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0318→ cube 1.4661
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7096→ cube 0.7498
#   Efficiency z (srs):  1.982 → 0.514 → 3.9814
#   Efficiency y (srs):  1.095 → 0.487 → 1.5963
#   Alpha:               0.7063879263287948
#   Num changes:         2
#   Design Depth:        419
#   Design Size (|D|):   1119
#   Open set size:       10293
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26701.428
#   Best Cost (y):       124690984.9343
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.574
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.034→ cube 1.4692
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7088→ cube 0.749
#   Efficiency z (srs):  1.982 → 0.514 → 3.9897
#   Efficiency y (srs):  1.095 → 0.487 → 1.5947
#   Alpha:               0.7675229122627902
#   Num changes:         3
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       10298
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26650.48
#   Best Cost (y):       124127773.9332
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.548
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.036→ cube 1.472
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.712→ cube 0.7524
#   Efficiency z (srs):  1.982 → 0.514 → 3.9974
#   Efficiency y (srs):  1.095 → 0.487 → 1.6019
#   Alpha:               0.8103741264149098
#   Num changes:         3
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       10302
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26637.176
#   Best Cost (y):       124735466.6619
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.543
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0365→ cube 1.4727
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7086→ cube 0.7487
#   Efficiency z (srs):  1.982 → 0.514 → 3.9994
#   Efficiency y (srs):  1.095 → 0.487 → 1.5941
#   Alpha:               0.8831824108846735
#   Num changes:         3
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       10331
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26570.732
#   Best Cost (y):       124134076.906
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.518
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0391→ cube 1.4764
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.712→ cube 0.7523
#   Efficiency z (srs):  1.982 → 0.514 → 4.0094
#   Efficiency y (srs):  1.095 → 0.487 → 1.6018
#   Alpha:               0.8122201892118006
#   Num changes:         3
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       10335
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26468.722
#   Best Cost (y):       124284259.8752
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.473
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0431→ cube 1.4821
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7111→ cube 0.7514
#   Efficiency z (srs):  1.982 → 0.514 → 4.0248
#   Efficiency y (srs):  1.095 → 0.487 → 1.5999
#   Alpha:               0.750727483516229
#   Num changes:         3
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       10338
#
# Progress: 5.5%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25978.457
#   Best Cost (y):       121963573.3663
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.268
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0628→ cube 1.5101
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7247→ cube 0.7657
#   Efficiency z (srs):  1.982 → 0.514 → 4.1008
#   Efficiency y (srs):  1.095 → 0.487 → 1.6303
#   Alpha:               0.7026297039946141
#   Num changes:         1
#   Design Depth:        443
#   Design Size (|D|):   1167
#   Open set size:       10792
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25496.711
#   Best Cost (y):       120835989.0273
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.07
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0828→ cube 1.5386
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7314→ cube 0.7729
#   Efficiency z (srs):  1.982 → 0.514 → 4.1783
#   Efficiency y (srs):  1.095 → 0.487 → 1.6455
#   Alpha:               0.765093773658147
#   Num changes:         3
#   Design Depth:        466
#   Design Size (|D|):   1213
#   Open set size:       11277
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25496.917
#   Best Cost (y):       120864672.488
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.07
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0828→ cube 1.5386
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7313→ cube 0.7727
#   Efficiency z (srs):  1.982 → 0.514 → 4.1782
#   Efficiency y (srs):  1.095 → 0.487 → 1.6451
#   Alpha:               0.8155999411791282
#   Num changes:         1
#   Design Depth:        464
#   Design Size (|D|):   1209
#   Open set size:       11279
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25494.296
#   Best Cost (y):       120838049.2185
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.069
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0829→ cube 1.5388
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7314→ cube 0.7729
#   Efficiency z (srs):  1.982 → 0.514 → 4.1787
#   Efficiency y (srs):  1.095 → 0.487 → 1.6455
#   Alpha:               0.7617253241462962
#   Num changes:         3
#   Design Depth:        466
#   Design Size (|D|):   1213
#   Open set size:       11280
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25491.793
#   Best Cost (y):       120842139.5479
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.069
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0831→ cube 1.5389
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7314→ cube 0.7728
#   Efficiency z (srs):  1.982 → 0.514 → 4.1791
#   Efficiency y (srs):  1.095 → 0.487 → 1.6455
#   Alpha:               0.7133857399097139
#   Num changes:         2
#   Design Depth:        465
#   Design Size (|D|):   1211
#   Open set size:       11281
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25477.307
#   Best Cost (y):       120844358.383
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.062
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0837→ cube 1.5398
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7314→ cube 0.7728
#   Efficiency z (srs):  1.982 → 0.514 → 4.1814
#   Efficiency y (srs):  1.095 → 0.487 → 1.6454
#   Alpha:               0.8795952147202728
#   Num changes:         3
#   Design Depth:        466
#   Design Size (|D|):   1213
#   Open set size:       11292
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25185.621
#   Best Cost (y):       120860140.9904
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.942
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0962→ cube 1.5576
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7313→ cube 0.7727
#   Efficiency z (srs):  1.982 → 0.514 → 4.2299
#   Efficiency y (srs):  1.095 → 0.487 → 1.6452
#   Alpha:               0.7731441164846135
#   Num changes:         3
#   Design Depth:        482
#   Design Size (|D|):   1245
#   Open set size:       11761
#
#
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25162.812
# ...
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.423
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.2961→ cube 3.2625
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0196→ cube 1.0773
#   Efficiency z (srs):  1.982 → 0.514 → 8.8596
#   Efficiency y (srs):  1.095 → 0.487 → 2.2938
#   Alpha:               0.7747881349554528
#   Num changes:         3
#   Design Depth:        3958
#   Design Size (|D|):   8197
#   Open set size:       115665
#
# Progress: 59.2%
# === Best Solution Updated at Iteration 2370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       12021.127
#   Best Cost (y):       86626345.5057
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.421
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.2967→ cube 3.2634
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0203→ cube 1.0781
#   Efficiency z (srs):  1.982 → 0.514 → 8.862
#   Efficiency y (srs):  1.095 → 0.487 → 2.2954
#   Alpha:               0.882770914510453
#   Num changes:         2
#   Design Depth:        3973
#   Design Size (|D|):   8227
#   Open set size:       116175
#
# Progress: 59.5%
# === Best Solution Updated at Iteration 2380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       12008.835
#   Best Cost (y):       86717558.308
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.415
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.2991→ cube 3.2667
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0192→ cube 1.077
#   Efficiency z (srs):  1.982 → 0.514 → 8.8711
#   Efficiency y (srs):  1.095 → 0.487 → 2.293
#   Alpha:               0.8781690081673682
#   Num changes:         2
#   Design Depth:        3992
#   Design Size (|D|):   8265
#   Open set size:       116653
#
# Progress: 59.8%
# === Best Solution Updated at Iteration 2390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11990.188
#   Best Cost (y):       86638114.5123
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.408
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3026→ cube 3.2718
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0202→ cube 1.078
#   Efficiency z (srs):  1.982 → 0.514 → 8.8849
#   Efficiency y (srs):  1.095 → 0.487 → 2.2951
#   Alpha:               0.8405068340453703
#   Num changes:         1
#   Design Depth:        4009
#   Design Size (|D|):   8299
#   Open set size:       117121
#
# Progress: 60.2%
# === Best Solution Updated at Iteration 2410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11947.05
#   Best Cost (y):       86604784.3971
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.392
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3109→ cube 3.2836
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0205→ cube 1.0784
#   Efficiency z (srs):  1.982 → 0.514 → 8.917
#   Efficiency y (srs):  1.095 → 0.487 → 2.2959
#   Alpha:               0.8265416648555879
#   Num changes:         2
#   Design Depth:        4040
#   Design Size (|D|):   8361
#   Open set size:       118111
#
# Progress: 60.5%
# === Best Solution Updated at Iteration 2420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11929.369
#   Best Cost (y):       86662670.8162
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.384
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3144→ cube 3.2885
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0199→ cube 1.0776
#   Efficiency z (srs):  1.982 → 0.514 → 8.9302
#   Efficiency y (srs):  1.095 → 0.487 → 2.2944
#   Alpha:               0.778063683203128
#   Num changes:         3
#   Design Depth:        4061
#   Design Size (|D|):   8403
#   Open set size:       118584
#
#
# === Best Solution Updated at Iteration 2420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11928.91
#   Best Cost (y):       86671031.2262
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.384
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3145→ cube 3.2886
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0198→ cube 1.0775
#   Efficiency z (srs):  1.982 → 0.514 → 8.9306
#   Efficiency y (srs):  1.095 → 0.487 → 2.2942
#   Alpha:               0.8057461847281384
#   Num changes:         1
#   Design Depth:        4059
#   Design Size (|D|):   8399
#   Open set size:       118590
#
#
# === Best Solution Updated at Iteration 2420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11928.961
#   Best Cost (y):       86650972.3649
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.384
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3144→ cube 3.2886
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.02→ cube 1.0778
#   Efficiency z (srs):  1.982 → 0.514 → 8.9305
#   Efficiency y (srs):  1.095 → 0.487 → 2.2947
#   Alpha:               0.7514857938353288
#   Num changes:         2
#   Design Depth:        4060
#   Design Size (|D|):   8401
#   Open set size:       118591
#
#
# === Best Solution Updated at Iteration 2420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11928.921
#   Best Cost (y):       86641040.9781
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.384
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3145→ cube 3.2886
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0201→ cube 1.0779
#   Efficiency z (srs):  1.982 → 0.514 → 8.9305
#   Efficiency y (srs):  1.095 → 0.487 → 2.295
#   Alpha:               0.795966956705498
#   Num changes:         2
#   Design Depth:        4060
#   Design Size (|D|):   8401
#   Open set size:       118592
#
#
# === Best Solution Updated at Iteration 2420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11927.995
#   Best Cost (y):       86664787.9689
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.384
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3146→ cube 3.2889
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0198→ cube 1.0776
#   Efficiency z (srs):  1.982 → 0.514 → 8.9312
#   Efficiency y (srs):  1.095 → 0.487 → 2.2944
#   Alpha:               0.8443803197374601
#   Num changes:         3
#   Design Depth:        4061
#   Design Size (|D|):   8403
#   Open set size:       118605
#
# Progress: 61.0%
# === Best Solution Updated at Iteration 2440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11924.516
#   Best Cost (y):       86594561.1066
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.383
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3153→ cube 3.2898
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0207→ cube 1.0785
#   Efficiency z (srs):  1.982 → 0.514 → 8.9338
#   Efficiency y (srs):  1.095 → 0.487 → 2.2962
#   Alpha:               0.7948048416351997
#   Num changes:         1
#   Design Depth:        4075
#   Design Size (|D|):   8431
#   Open set size:       119592
#
# Progress: 61.5%
# === Best Solution Updated at Iteration 2460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11918.338
#   Best Cost (y):       86500440.7177
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.378
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3165→ cube 3.2915
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0218→ cube 1.0797
#   Efficiency z (srs):  1.982 → 0.514 → 8.9385
#   Efficiency y (srs):  1.095 → 0.487 → 2.2987
#   Alpha:               0.8478790173106113
#   Num changes:         1
#   Design Depth:        4102
#   Design Size (|D|):   8485
#   Open set size:       120542
#
#
# === Best Solution Updated at Iteration 2460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11917.607
#   Best Cost (y):       86511692.3439
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.378
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3166→ cube 3.2917
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0216→ cube 1.0795
#   Efficiency z (srs):  1.982 → 0.514 → 8.939
#   Efficiency y (srs):  1.095 → 0.487 → 2.2984
#   Alpha:               0.7230010626630448
#   Num changes:         2
#   Design Depth:        4103
#   Design Size (|D|):   8487
#   Open set size:       120547
#
#
# === Best Solution Updated at Iteration 2460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11908.298
#   Best Cost (y):       86408425.3533
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.374
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3185→ cube 3.2943
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0229→ cube 1.0808
#   Efficiency z (srs):  1.982 → 0.514 → 8.946
#   Efficiency y (srs):  1.095 → 0.487 → 2.3012
#   Alpha:               0.7263067894660078
#   Num changes:         3
#   Design Depth:        4104
#   Design Size (|D|):   8489
#   Open set size:       120562
#
# Progress: 62.5%
# === Best Solution Updated at Iteration 2500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11872.31
#   Best Cost (y):       86052776.1261
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.358
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3255→ cube 3.3043
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0271→ cube 1.0853
#   Efficiency z (srs):  1.982 → 0.514 → 8.9731
#   Efficiency y (srs):  1.095 → 0.487 → 2.3107
#   Alpha:               0.8396730073778425
#   Num changes:         2
#   Design Depth:        4150
#   Design Size (|D|):   8581
#   Open set size:       122516
#
# Progress: 63.0%
# === Best Solution Updated at Iteration 2520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11862.955
#   Best Cost (y):       86047350.8544
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.354
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3273→ cube 3.3069
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0272→ cube 1.0854
#   Efficiency z (srs):  1.982 → 0.514 → 8.9802
#   Efficiency y (srs):  1.095 → 0.487 → 2.3108
#   Alpha:               0.7175927302838261
#   Num changes:         1
#   Design Depth:        4173
#   Design Size (|D|):   8627
#   Open set size:       123498
#
#
# === Best Solution Updated at Iteration 2520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11862.857
#   Best Cost (y):       86047385.2492
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.354
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3273→ cube 3.3069
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0272→ cube 1.0854
#   Efficiency z (srs):  1.982 → 0.514 → 8.9803
#   Efficiency y (srs):  1.095 → 0.487 → 2.3108
#   Alpha:               0.82727553185543
#   Num changes:         1
#   Design Depth:        4173
#   Design Size (|D|):   8627
#   Open set size:       123501
#
#
# === Best Solution Updated at Iteration 2520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11862.734
#   Best Cost (y):       86047292.3182
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.354
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3274→ cube 3.307
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0272→ cube 1.0854
#   Efficiency z (srs):  1.982 → 0.514 → 8.9804
#   Efficiency y (srs):  1.095 → 0.487 → 2.3108
#   Alpha:               0.7743389301527411
#   Num changes:         1
#   Design Depth:        4173
#   Design Size (|D|):   8627
#   Open set size:       123514
#
# Progress: 63.2%
# === Best Solution Updated at Iteration 2530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       11861.194
#   Best Cost (y):       86013061.2834
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      5.353
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 2.3277→ cube 3.3074
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 1.0276→ cube 1.0858
#   Efficiency z (srs):  1.982 → 0.514 → 8.9815
#   Efficiency y (srs):  1.095 → 0.487 → 2.3117
#   Alpha:               0.8983533456820643
#   Num changes:         3
#   Design Depth:        4186
#   Design Size (|D|):   8653
#   Open set size:       124015
#
# Progress: 63.4%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 93
#      65 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      66                    inclusion_probability=inclusions, balance_method='linear')
#      68 astar = AStar(
#      69     inclusions              = inclusions,
#      70     num_initial_nodes       = num_initial_nodes,
#    (...)     90     # delta                   = 0.01,
#      91 )
# ---> 93 result = astar.run(
#      94     max_iterations             = max_iterations,
#      95     num_new_nodes              = num_new_nodes,
#      96     max_open_set_size          = max_open_set_size,
#      97     random_restart_period      = random_restart_period,
#      98     random_injection_count     = random_injection_count,
#      99     prune_fraction             = prune_fraction,
#     100     num_top_restart_nodes      = num_top_restart_nodes,
#     101     stuck_fraction             = stuck_fraction,
#     102
#     103 )
#     105 print("Best criteria value:", astar.best_criteria_value)
#     106 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:14, in VarNHT.__call__(self, design)
#      11 # Calculate estimators
#      12 ones = np.ones(N)
#      13 NHT_estimator_z = np.array([
# ---> 14     np.sum(self.auxiliary_variable[list(sample.ids)] /
#      15            self.inclusion_probability[list(sample.ids)])
#      16     for sample in design
#      17 ])
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#
# KeyboardInterrupt:

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
# Out:
# size of init design 281
# size of best design 8671
# 22.632928227085532
# 5.352534662697933
# /tmp/ipykernel_6199/1240027416.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# 1.000000006000005
