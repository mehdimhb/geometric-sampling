# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Real_Sweden"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmphnWFEC", R: "/tmp/RtmpXLLjFn"
#   warnings.warn(

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 10

# %%
num_new_nodes          = 50

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.03558719
# [1] 304952002.5    163382.8

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 2266.9209 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0453 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0170 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.1130297
# Variance of HT estimator via DSD formula_z:  54558.62
# Variance of HT estimator via DSD formula:  132393477
# Here is the Vincent Efficiency y:
#   DSD_y:  1.18125
#   DSD_z: 2.99463
# Monte Carlo variance of HT estimator for y:
#   DSD:  132317295.52917
#   Cube: 138365354.80914
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.18193
#   Cube: 1.13027
# Monte Carlo mean of HT estimator for y:
#   DSD:  53412.62333
#   Cube: 53387.76893
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  55805.96348
#   Cube: 77330.21460
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  2.92769
#   Cube: 2.11279
# Monte Carlo mean of HT estimator for z:
#   DSD:  2503.38578
#   Cube: 2514.21828
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        2.11        2.99        1.95        2.20        2.30

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_5808/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639386
# [281] [10.] adsfa
# 4000 50 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 19.57it/s]
# Initial design 0: method = Original, efficiency z = 0.5269, y=1.1044
# New best at idx=0: method = Original, efficiency z = 0.5269 and efficiency y = 1.1044
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       103585.604
#   Best Cost (y):       117940765.7111
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      43.141
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5267→ cube 0.7465
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1225→ cube 1.1732
#   Efficiency z (srs):  1.572 → 0.527 → 1.5717
#   Efficiency y (srs):  2.535 → 1.104 → 2.5764
#   Alpha:               0.7707467262595649
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       4
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       103584.274
#   Best Cost (y):       118865244.6267
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      43.133
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5267→ cube 0.7465
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1138→ cube 1.1641
#   Efficiency z (srs):  1.572 → 0.527 → 1.5717
#   Efficiency y (srs):  2.535 → 1.104 → 2.5564
#   Alpha:               0.8316936932236985
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       28
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       99842.022
#   Best Cost (y):       113149745.3827
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      41.671
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5464→ cube 0.7745
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1701→ cube 1.2229
#   Efficiency z (srs):  1.572 → 0.527 → 1.6306
#   Efficiency y (srs):  2.535 → 1.104 → 2.6855
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        5
#   Design Size (|D|):   291
#   Open set size:       99
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       96891.788
#   Best Cost (y):       115903315.3117
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      40.439
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5631→ cube 0.7981
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1423→ cube 1.1938
#   Efficiency z (srs):  1.572 → 0.527 → 1.6802
#   Efficiency y (srs):  2.535 → 1.104 → 2.6217
#   Alpha:               0.8095666333922753
#   Num changes:         3
#   Design Depth:        24
#   Design Size (|D|):   329
#   Open set size:       493
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       96670.886
#   Best Cost (y):       116713323.7901
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      40.381
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5644→ cube 0.7999
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1343→ cube 1.1855
#   Efficiency z (srs):  1.572 → 0.527 → 1.6841
#   Efficiency y (srs):  2.535 → 1.104 → 2.6035
#   Alpha:               0.8248476406130214
#   Num changes:         2
#   Design Depth:        23
#   Design Size (|D|):   327
#   Open set size:       502
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       96573.347
#   Best Cost (y):       117367584.0612
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      40.349
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5649→ cube 0.8007
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.128→ cube 1.1789
#   Efficiency z (srs):  1.572 → 0.527 → 1.6858
#   Efficiency y (srs):  2.535 → 1.104 → 2.589
#   Alpha:               0.8200109363215843
#   Num changes:         3
#   Design Depth:        24
#   Design Size (|D|):   329
#   Open set size:       520
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       93508.594
#   Best Cost (y):       111525895.26
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      39.053
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5835→ cube 0.827
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1871→ cube 1.2407
#   Efficiency z (srs):  1.572 → 0.527 → 1.741
#   Efficiency y (srs):  2.535 → 1.104 → 2.7246
#   Alpha:               0.8164177242866429
#   Num changes:         1
#   Design Depth:        46
#   Design Size (|D|):   373
#   Open set size:       985
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       93430.258
#   Best Cost (y):       111620139.6411
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      39.032
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.584→ cube 0.8277
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1861→ cube 1.2396
#   Efficiency z (srs):  1.572 → 0.527 → 1.7425
#   Efficiency y (srs):  2.535 → 1.104 → 2.7223
#   Alpha:               0.8280858353277576
#   Num changes:         2
#   Design Depth:        47
#   Design Size (|D|):   375
#   Open set size:       988
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       93397.39
#   Best Cost (y):       111307693.3176
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      39.012
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5842→ cube 0.828
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1894→ cube 1.2431
#   Efficiency z (srs):  1.572 → 0.527 → 1.7431
#   Efficiency y (srs):  2.535 → 1.104 → 2.73
#   Alpha:               0.8499168823577397
#   Num changes:         2
#   Design Depth:        47
#   Design Size (|D|):   375
#   Open set size:       1014
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       86996.162
#   Best Cost (y):       109478903.909
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.44
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6271→ cube 0.8889
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2093→ cube 1.2639
#   Efficiency z (srs):  1.572 → 0.527 → 1.8714
#   Efficiency y (srs):  2.535 → 1.104 → 2.7756
#   Alpha:               0.8342235971322698
#   Num changes:         1
#   Design Depth:        66
#   Design Size (|D|):   413
#   Open set size:       1472
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       86875.701
#   Best Cost (y):       108608428.0415
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.386
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.628→ cube 0.8901
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.219→ cube 1.274
#   Efficiency z (srs):  1.572 → 0.527 → 1.874
#   Efficiency y (srs):  2.535 → 1.104 → 2.7978
#   Alpha:               0.8909598299241085
#   Num changes:         1
#   Design Depth:        66
#   Design Size (|D|):   413
#   Open set size:       1473
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       86771.823
#   Best Cost (y):       108735949.7503
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.36
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6288→ cube 0.8912
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2176→ cube 1.2725
#   Efficiency z (srs):  1.572 → 0.527 → 1.8762
#   Efficiency y (srs):  2.535 → 1.104 → 2.7945
#   Alpha:               0.7642097073021579
#   Num changes:         2
#   Design Depth:        67
#   Design Size (|D|):   415
#   Open set size:       1476
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       86769.393
#   Best Cost (y):       108620527.6484
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.345
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6288→ cube 0.8912
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2189→ cube 1.2738
#   Efficiency z (srs):  1.572 → 0.527 → 1.8763
#   Efficiency y (srs):  2.535 → 1.104 → 2.7975
#   Alpha:               0.7464651617579866
#   Num changes:         2
#   Design Depth:        67
#   Design Size (|D|):   415
#   Open set size:       1512
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       85130.909
#   Best Cost (y):       107937737.179
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      35.63
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6409→ cube 0.9084
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2266→ cube 1.2819
#   Efficiency z (srs):  1.572 → 0.527 → 1.9124
#   Efficiency y (srs):  2.535 → 1.104 → 2.8152
#   Alpha:               0.8595683157789908
#   Num changes:         1
#   Design Depth:        87
#   Design Size (|D|):   455
#   Open set size:       1962
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       85131.872
#   Best Cost (y):       106956236.6156
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      35.604
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6409→ cube 0.9084
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2378→ cube 1.2937
#   Efficiency z (srs):  1.572 → 0.527 → 1.9123
#   Efficiency y (srs):  2.535 → 1.104 → 2.841
#   Alpha:               0.7430046109911936
#   Num changes:         3
#   Design Depth:        89
#   Design Size (|D|):   459
#   Open set size:       2000
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       83180.503
#   Best Cost (y):       107839873.6826
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      34.789
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6559→ cube 0.9297
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2277→ cube 1.2831
#   Efficiency z (srs):  1.572 → 0.527 → 1.9572
#   Efficiency y (srs):  2.535 → 1.104 → 2.8178
#   Alpha:               0.8567356215195879
#   Num changes:         1
#   Design Depth:        109
#   Design Size (|D|):   499
#   Open set size:       2456
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       83154.496
#   Best Cost (y):       107947734.5654
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      34.786
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6561→ cube 0.93
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2265→ cube 1.2818
#   Efficiency z (srs):  1.572 → 0.527 → 1.9578
#   Efficiency y (srs):  2.535 → 1.104 → 2.8149
#   Alpha:               0.7813700309908197
#   Num changes:         2
#   Design Depth:        110
#   Design Size (|D|):   501
#   Open set size:       2464
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       83137.138
#   Best Cost (y):       109095266.4375
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      34.783
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6562→ cube 0.9302
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2136→ cube 1.2683
#   Efficiency z (srs):  1.572 → 0.527 → 1.9582
#   Efficiency y (srs):  2.535 → 1.104 → 2.7853
#   Alpha:               0.7576947528417626
#   Num changes:         2
#   Design Depth:        110
#   Design Size (|D|):   501
#   Open set size:       2500
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       79255.887
#   Best Cost (y):       108865960.307
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      33.323
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6884→ cube 0.9757
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2161→ cube 1.271
#   Efficiency z (srs):  1.572 → 0.527 → 2.0541
#   Efficiency y (srs):  2.535 → 1.104 → 2.7912
#   Alpha:               0.7335108153478771
#   Num changes:         1
#   Design Depth:        137
#   Design Size (|D|):   555
#   Open set size:       3438
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       79249.586
#   Best Cost (y):       109713694.4655
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      33.318
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6884→ cube 0.9758
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2067→ cube 1.2611
#   Efficiency z (srs):  1.572 → 0.527 → 2.0543
#   Efficiency y (srs):  2.535 → 1.104 → 2.7696
#   Alpha:               0.7267154499723913
#   Num changes:         2
#   Design Depth:        138
#   Design Size (|D|):   557
#   Open set size:       3450
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       77785.708
#   Best Cost (y):       108179061.2668
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.73
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7014→ cube 0.9941
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2238→ cube 1.279
#   Efficiency z (srs):  1.572 → 0.527 → 2.0929
#   Efficiency y (srs):  2.535 → 1.104 → 2.8089
#   Alpha:               0.8488500102197115
#   Num changes:         3
#   Design Depth:        159
#   Design Size (|D|):   599
#   Open set size:       3929
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       77753.578
#   Best Cost (y):       107416598.1079
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.719
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7017→ cube 0.9946
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2325→ cube 1.2881
#   Efficiency z (srs):  1.572 → 0.527 → 2.0938
#   Efficiency y (srs):  2.535 → 1.104 → 2.8289
#   Alpha:               0.736124706943765
#   Num changes:         3
#   Design Depth:        159
#   Design Size (|D|):   599
#   Open set size:       3955
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76225.982
#   Best Cost (y):       106930316.3757
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.071
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7157→ cube 1.0145
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2381→ cube 1.294
#   Efficiency z (srs):  1.572 → 0.527 → 2.1358
#   Efficiency y (srs):  2.535 → 1.104 → 2.8417
#   Alpha:               0.7837793040034808
#   Num changes:         1
#   Design Depth:        176
#   Design Size (|D|):   633
#   Open set size:       4412
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76225.913
#   Best Cost (y):       107032448.8906
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.07
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7157→ cube 1.0145
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2369→ cube 1.2927
#   Efficiency z (srs):  1.572 → 0.527 → 2.1358
#   Efficiency y (srs):  2.535 → 1.104 → 2.839
#   Alpha:               0.8238534003548971
#   Num changes:         1
#   Design Depth:        176
#   Design Size (|D|):   633
#   Open set size:       4425
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76151.765
#   Best Cost (y):       107229793.251
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.048
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7164→ cube 1.0155
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2347→ cube 1.2904
#   Efficiency z (srs):  1.572 → 0.527 → 2.1379
#   Efficiency y (srs):  2.535 → 1.104 → 2.8338
#   Alpha:               0.7346977550898522
#   Num changes:         3
#   Design Depth:        178
#   Design Size (|D|):   637
#   Open set size:       4427
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76098.863
#   Best Cost (y):       107788020.8799
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.036
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7169→ cube 1.0162
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2283→ cube 1.2837
#   Efficiency z (srs):  1.572 → 0.527 → 2.1393
#   Efficiency y (srs):  2.535 → 1.104 → 2.8191
#   Alpha:               0.74069298514062
#   Num changes:         3
#   Design Depth:        178
#   Design Size (|D|):   637
#   Open set size:       4428
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76117.352
#   Best Cost (y):       106944579.7592
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.035
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7168→ cube 1.0159
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.238→ cube 1.2938
#   Efficiency z (srs):  1.572 → 0.527 → 2.1388
#   Efficiency y (srs):  2.535 → 1.104 → 2.8413
#   Alpha:               0.7094425877406502
#   Num changes:         2
#   Design Depth:        177
#   Design Size (|D|):   635
#   Open set size:       4456
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       74214.225
#   Best Cost (y):       105378491.1193
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.223
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7352→ cube 1.042
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2564→ cube 1.313
#   Efficiency z (srs):  1.572 → 0.527 → 2.1937
#   Efficiency y (srs):  2.535 → 1.104 → 2.8836
#   Alpha:               0.7793500676052417
#   Num changes:         2
#   Design Depth:        198
#   Design Size (|D|):   677
#   Open set size:       4932
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       74208.008
#   Best Cost (y):       105378867.7458
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.221
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7352→ cube 1.0421
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2564→ cube 1.313
#   Efficiency z (srs):  1.572 → 0.527 → 2.1939
#   Efficiency y (srs):  2.535 → 1.104 → 2.8836
#   Alpha:               0.8531459272618022
#   Num changes:         1
#   Design Depth:        197
#   Design Size (|D|):   675
#   Open set size:       4948
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73356.816
#   Best Cost (y):       105098561.8538
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.873
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7437→ cube 1.0542
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2597→ cube 1.3165
#   Efficiency z (srs):  1.572 → 0.527 → 2.2193
#   Efficiency y (srs):  2.535 → 1.104 → 2.8913
#   Alpha:               0.881991106639018
#   Num changes:         2
#   Design Depth:        209
#   Design Size (|D|):   699
#   Open set size:       5391
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73267.529
#   Best Cost (y):       105007546.5435
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.845
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7446→ cube 1.0555
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2608→ cube 1.3177
#   Efficiency z (srs):  1.572 → 0.527 → 2.222
#   Efficiency y (srs):  2.535 → 1.104 → 2.8938
#   Alpha:               0.7241921076669989
#   Num changes:         2
#   Design Depth:        209
#   Design Size (|D|):   699
#   Open set size:       5392
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73099.969
#   Best Cost (y):       104807916.2051
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.77
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7464→ cube 1.0579
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2632→ cube 1.3202
#   Efficiency z (srs):  1.572 → 0.527 → 2.2271
#   Efficiency y (srs):  2.535 → 1.104 → 2.8993
#   Alpha:               0.8844320862783042
#   Num changes:         3
#   Design Depth:        210
#   Design Size (|D|):   701
#   Open set size:       5403
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       71015.687
#   Best Cost (y):       104427297.0719
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.938
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7683→ cube 1.0889
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2678→ cube 1.325
#   Efficiency z (srs):  1.572 → 0.527 → 2.2925
#   Efficiency y (srs):  2.535 → 1.104 → 2.9098
#   Alpha:               0.8592280603073567
#   Num changes:         1
#   Design Depth:        236
#   Design Size (|D|):   753
#   Open set size:       5881
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       70280.899
#   Best Cost (y):       103485767.0425
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.645
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7763→ cube 1.1003
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2793→ cube 1.337
#   Efficiency z (srs):  1.572 → 0.527 → 2.3164
#   Efficiency y (srs):  2.535 → 1.104 → 2.9363
#   Alpha:               0.8881625301704847
#   Num changes:         2
#   Design Depth:        237
#   Design Size (|D|):   755
#   Open set size:       5886
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       70048.159
#   Best Cost (y):       103799176.7591
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.564
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7789→ cube 1.104
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2755→ cube 1.333
#   Efficiency z (srs):  1.572 → 0.527 → 2.3241
#   Efficiency y (srs):  2.535 → 1.104 → 2.9274
#   Alpha:               0.8773316320637975
#   Num changes:         3
#   Design Depth:        238
#   Design Size (|D|):   757
#   Open set size:       5922
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       68742.246
#   Best Cost (y):       104178168.6946
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.052
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7937→ cube 1.1249
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2708→ cube 1.3282
#   Efficiency z (srs):  1.572 → 0.527 → 2.3683
#   Efficiency y (srs):  2.535 → 1.104 → 2.9168
#   Alpha:               0.8204640650159892
#   Num changes:         2
#   Design Depth:        261
#   Design Size (|D|):   803
#   Open set size:       6372
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       68750.849
#   Best Cost (y):       103758289.4387
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.045
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7936→ cube 1.1248
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.276→ cube 1.3335
#   Efficiency z (srs):  1.572 → 0.527 → 2.368
#   Efficiency y (srs):  2.535 → 1.104 → 2.9286
#   Alpha:               0.7333622733276943
#   Num changes:         2
#   Design Depth:        261
#   Design Size (|D|):   803
#   Open set size:       6385
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       68750.574
#   Best Cost (y):       103724906.6307
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.045
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7936→ cube 1.1248
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2764→ cube 1.334
#   Efficiency z (srs):  1.572 → 0.527 → 2.368
#   Efficiency y (srs):  2.535 → 1.104 → 2.9295
#   Alpha:               0.8419461963019779
#   Num changes:         2
#   Design Depth:        261
#   Design Size (|D|):   803
#   Open set size:       6407
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       66930.755
#   Best Cost (y):       103911764.1585
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      28.324
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8152→ cube 1.1554
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2741→ cube 1.3316
#   Efficiency z (srs):  1.572 → 0.527 → 2.4324
#   Efficiency y (srs):  2.535 → 1.104 → 2.9243
#   Alpha:               0.8833560557683702
#   Num changes:         2
#   Design Depth:        284
#   Design Size (|D|):   849
#   Open set size:       6867
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65145.393
#   Best Cost (y):       102782376.7707
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.577
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8375→ cube 1.187
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2881→ cube 1.3462
#   Efficiency z (srs):  1.572 → 0.527 → 2.499
#   Efficiency y (srs):  2.535 → 1.104 → 2.9564
#   Alpha:               0.859879776283444
#   Num changes:         2
#   Design Depth:        305
#   Design Size (|D|):   891
#   Open set size:       7352
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63927.058
#   Best Cost (y):       102229852.7679
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.107
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8535→ cube 1.2097
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2951→ cube 1.3535
#   Efficiency z (srs):  1.572 → 0.527 → 2.5467
#   Efficiency y (srs):  2.535 → 1.104 → 2.9724
#   Alpha:               0.8252385009656962
#   Num changes:         1
#   Design Depth:        323
#   Design Size (|D|):   927
#   Open set size:       7845
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63465.106
#   Best Cost (y):       102254894.1333
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.913
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8597→ cube 1.2185
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2947→ cube 1.3531
#   Efficiency z (srs):  1.572 → 0.527 → 2.5652
#   Efficiency y (srs):  2.535 → 1.104 → 2.9717
#   Alpha:               0.8562159626800734
#   Num changes:         1
#   Design Depth:        339
#   Design Size (|D|):   959
#   Open set size:       8332
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63439.585
#   Best Cost (y):       101792313.4634
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.899
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.86→ cube 1.219
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3006→ cube 1.3593
#   Efficiency z (srs):  1.572 → 0.527 → 2.5662
#   Efficiency y (srs):  2.535 → 1.104 → 2.9852
#   Alpha:               0.8187186934383581
#   Num changes:         2
#   Design Depth:        340
#   Design Size (|D|):   961
#   Open set size:       8336
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63395.46
#   Best Cost (y):       102227495.4832
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.882
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8606→ cube 1.2198
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2951→ cube 1.3535
#   Efficiency z (srs):  1.572 → 0.527 → 2.568
#   Efficiency y (srs):  2.535 → 1.104 → 2.9725
#   Alpha:               0.795508573681567
#   Num changes:         2
#   Design Depth:        340
#   Design Size (|D|):   961
#   Open set size:       8350
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63389.442
#   Best Cost (y):       101954176.7494
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.877
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8607→ cube 1.2199
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2986→ cube 1.3571
#   Efficiency z (srs):  1.572 → 0.527 → 2.5683
#   Efficiency y (srs):  2.535 → 1.104 → 2.9804
#   Alpha:               0.8936408599920168
#   Num changes:         3
#   Design Depth:        341
#   Design Size (|D|):   963
#   Open set size:       8358
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61288.251
#   Best Cost (y):       101739410.7688
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.009
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8902→ cube 1.2617
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3013→ cube 1.36
#   Efficiency z (srs):  1.572 → 0.527 → 2.6563
#   Efficiency y (srs):  2.535 → 1.104 → 2.9867
#   Alpha:               0.8913081481421959
#   Num changes:         2
#   Design Depth:        375
#   Design Size (|D|):   1031
#   Open set size:       9313
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61280.909
#   Best Cost (y):       101798316.1776
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.998
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8903→ cube 1.2619
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3005→ cube 1.3592
#   Efficiency z (srs):  1.572 → 0.527 → 2.6566
#   Efficiency y (srs):  2.535 → 1.104 → 2.985
#   Alpha:               0.8965647491215045
#   Num changes:         2
#   Design Depth:        375
#   Design Size (|D|):   1031
#   Open set size:       9315
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61151.592
#   Best Cost (y):       101789108.0672
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.974
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8922→ cube 1.2646
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3007→ cube 1.3593
#   Efficiency z (srs):  1.572 → 0.527 → 2.6623
#   Efficiency y (srs):  2.535 → 1.104 → 2.9853
#   Alpha:               0.8605920597667523
#   Num changes:         3
#   Design Depth:        376
#   Design Size (|D|):   1033
#   Open set size:       9329
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60146.481
#   Best Cost (y):       102455454.1328
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.601
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9071→ cube 1.2857
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2922→ cube 1.3505
#   Efficiency z (srs):  1.572 → 0.527 → 2.7067
#   Efficiency y (srs):  2.535 → 1.104 → 2.9658
#   Alpha:               0.7483833013059222
#   Num changes:         3
#   Design Depth:        399
#   Design Size (|D|):   1079
#   Open set size:       9810
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59979.862
#   Best Cost (y):       101403413.893
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.502
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9096→ cube 1.2893
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3056→ cube 1.3645
#   Efficiency z (srs):  1.572 → 0.527 → 2.7143
#   Efficiency y (srs):  2.535 → 1.104 → 2.9966
#   Alpha:               0.8562780014184014
#   Num changes:         2
#   Design Depth:        417
#   Design Size (|D|):   1115
#   Open set size:       10294
#
# Progress: 5.5%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59572.516
#   Best Cost (y):       101292220.7655
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.321
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9158→ cube 1.2981
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.307→ cube 1.366
#   Efficiency z (srs):  1.572 → 0.527 → 2.7328
#   Efficiency y (srs):  2.535 → 1.104 → 2.9999
#   Alpha:               0.8465895885208897
#   Num changes:         2
#   Design Depth:        439
#   Design Size (|D|):   1159
#   Open set size:       10790
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59546.129
#   Best Cost (y):       101569669.0732
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.313
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9162→ cube 1.2987
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3035→ cube 1.3623
#   Efficiency z (srs):  1.572 → 0.527 → 2.734
#   Efficiency y (srs):  2.535 → 1.104 → 2.9917
#   Alpha:               0.7871087338074064
#   Num changes:         2
#   Design Depth:        439
#   Design Size (|D|):   1159
#   Open set size:       10810
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       58400.856
#   Best Cost (y):       100551986.3274
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.797
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9342→ cube 1.3241
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3167→ cube 1.3761
#   Efficiency z (srs):  1.572 → 0.527 → 2.7877
#   Efficiency y (srs):  2.535 → 1.104 → 3.022
#   Alpha:               0.7882930603930419
#   Num changes:         2
#   Design Depth:        475
#   Design Size (|D|):   1231
#   Open set size:       11777
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56342.459
#   Best Cost (y):       101136683.5001
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.978
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9683→ cube 1.3725
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3091→ cube 1.3681
#   Efficiency z (srs):  1.572 → 0.527 → 2.8895
#   Efficiency y (srs):  2.535 → 1.104 → 3.0045
#   Alpha:               0.8834279320690755
#   Num changes:         1
#   Design Depth:        490
#   Design Size (|D|):   1261
#   Open set size:       12262
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56333.19
#   Best Cost (y):       101158642.1001
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.975
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9685→ cube 1.3727
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3088→ cube 1.3678
#   Efficiency z (srs):  1.572 → 0.527 → 2.89
#   Efficiency y (srs):  2.535 → 1.104 → 3.0039
#   Alpha:               0.8540273686975302
#   Num changes:         1
#   Design Depth:        490
#   Design Size (|D|):   1261
#   Open set size:       12285
#
# Progress: 6.5%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56199.416
#   Best Cost (y):       101919696.1763
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.908
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9708→ cube 1.376
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.299→ cube 1.3576
#   Efficiency z (srs):  1.572 → 0.527 → 2.8969
#   Efficiency y (srs):  2.535 → 1.104 → 2.9814
#   Alpha:               0.7052504385714408
#   Num changes:         1
#   Design Depth:        504
#   Design Size (|D|):   1289
#   Open set size:       12758
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56157.504
#   Best Cost (y):       101671241.8407
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.882
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9715→ cube 1.377
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3022→ cube 1.3609
#   Efficiency z (srs):  1.572 → 0.527 → 2.899
#   Efficiency y (srs):  2.535 → 1.104 → 2.9887
#   Alpha:               0.7428641019080207
#   Num changes:         3
#   Design Depth:        520
#   Design Size (|D|):   1321
#   Open set size:       13236
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55766.035
#   Best Cost (y):       101691448.3118
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.73
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9783→ cube 1.3867
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3019→ cube 1.3606
#   Efficiency z (srs):  1.572 → 0.527 → 2.9194
#   Efficiency y (srs):  2.535 → 1.104 → 2.9881
#   Alpha:               0.8726642049000095
#   Num changes:         2
#   Design Depth:        535
#   Design Size (|D|):   1351
#   Open set size:       13729
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55765.882
#   Best Cost (y):       101307794.6147
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.726
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9784→ cube 1.3867
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3068→ cube 1.3658
#   Efficiency z (srs):  1.572 → 0.527 → 2.9194
#   Efficiency y (srs):  2.535 → 1.104 → 2.9994
#   Alpha:               0.8440055299257084
#   Num changes:         2
#   Design Depth:        535
#   Design Size (|D|):   1351
#   Open set size:       13738
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55201.095
#   Best Cost (y):       101454378.1442
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.501
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9884→ cube 1.4009
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.305→ cube 1.3638
#   Efficiency z (srs):  1.572 → 0.527 → 2.9492
#   Efficiency y (srs):  2.535 → 1.104 → 2.9951
#   Alpha:               0.7909575817395256
#   Num changes:         1
#   Design Depth:        552
#   Design Size (|D|):   1385
#   Open set size:       14251
#
# Progress: 7.5%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55148.502
#   Best Cost (y):       100279664.0887
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.479
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9893→ cube 1.4022
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3202→ cube 1.3798
#   Efficiency z (srs):  1.572 → 0.527 → 2.9521
#   Efficiency y (srs):  2.535 → 1.104 → 3.0302
#   Alpha:               0.8520405263167753
#   Num changes:         3
#   Design Depth:        570
#   Design Size (|D|):   1421
#   Open set size:       14712
#
#
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55150.644
#   Best Cost (y):       100396338.3998
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.478
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9893→ cube 1.4022
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3187→ cube 1.3782
#   Efficiency z (srs):  1.572 → 0.527 → 2.9519
#   Efficiency y (srs):  2.535 → 1.104 → 3.0267
#   Alpha:               0.77084551791343
#   Num changes:         1
#   Design Depth:        568
#   Design Size (|D|):   1417
#   Open set size:       14721
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54785.96
#   Best Cost (y):       100510952.4017
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.3
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9959→ cube 1.4115
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3172→ cube 1.3766
#   Efficiency z (srs):  1.572 → 0.527 → 2.9716
#   Efficiency y (srs):  2.535 → 1.104 → 3.0232
#   Alpha:               0.841880734179928
#   Num changes:         1
#   Design Depth:        598
#   Design Size (|D|):   1477
#   Open set size:       15691
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54753.356
#   Best Cost (y):       100591635.1241
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.286
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9964→ cube 1.4123
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3161→ cube 1.3755
#   Efficiency z (srs):  1.572 → 0.527 → 2.9734
#   Efficiency y (srs):  2.535 → 1.104 → 3.0208
#   Alpha:               0.7324559469642485
#   Num changes:         2
#   Design Depth:        599
#   Design Size (|D|):   1479
#   Open set size:       15692
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54697.506
#   Best Cost (y):       100501759.6181
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.265
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9975→ cube 1.4138
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3173→ cube 1.3767
#   Efficiency z (srs):  1.572 → 0.527 → 2.9764
#   Efficiency y (srs):  2.535 → 1.104 → 3.0235
#   Alpha:               0.7611614179400414
#   Num changes:         1
#   Design Depth:        598
#   Design Size (|D|):   1477
#   Open set size:       15698
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54696.107
#   Best Cost (y):       100517352.9235
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.265
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9975→ cube 1.4138
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3171→ cube 1.3765
#   Efficiency z (srs):  1.572 → 0.527 → 2.9765
#   Efficiency y (srs):  2.535 → 1.104 → 3.023
#   Alpha:               0.8951518487579302
#   Num changes:         1
#   Design Depth:        598
#   Design Size (|D|):   1477
#   Open set size:       15707
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
# ...
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.371
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9303→ cube 2.7359
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3902→ cube 1.4529
#   Efficiency z (srs):  1.572 → 0.527 → 5.7599
#   Efficiency y (srs):  2.535 → 1.104 → 3.1908
#   Alpha:               0.7672231011890547
#   Num changes:         2
#   Design Depth:        4144
#   Design Size (|D|):   8569
#   Open set size:       122048
#
# Progress: 62.5%
# === Best Solution Updated at Iteration 2500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28217.454
#   Best Cost (y):       95129606.6195
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.352
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9335→ cube 2.7405
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3917→ cube 1.4545
#   Efficiency z (srs):  1.572 → 0.527 → 5.7695
#   Efficiency y (srs):  2.535 → 1.104 → 3.1942
#   Alpha:               0.8899554500759423
#   Num changes:         1
#   Design Depth:        4163
#   Design Size (|D|):   8607
#   Open set size:       122510
#
#
# === Best Solution Updated at Iteration 2500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28216.178
#   Best Cost (y):       95075602.9616
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.351
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9336→ cube 2.7406
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3925→ cube 1.4553
#   Efficiency z (srs):  1.572 → 0.527 → 5.7698
#   Efficiency y (srs):  2.535 → 1.104 → 3.1961
#   Alpha:               0.7480448645557759
#   Num changes:         2
#   Design Depth:        4164
#   Design Size (|D|):   8609
#   Open set size:       122519
#
# Progress: 62.7%
# === Best Solution Updated at Iteration 2510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28206.186
#   Best Cost (y):       94992275.9703
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.346
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9343→ cube 2.7416
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3937→ cube 1.4566
#   Efficiency z (srs):  1.572 → 0.527 → 5.7718
#   Efficiency y (srs):  2.535 → 1.104 → 3.1989
#   Alpha:               0.7343073910960374
#   Num changes:         1
#   Design Depth:        4178
#   Design Size (|D|):   8637
#   Open set size:       123000
#
#
# === Best Solution Updated at Iteration 2510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28206.175
#   Best Cost (y):       94979046.4331
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.346
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9343→ cube 2.7416
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3939→ cube 1.4568
#   Efficiency z (srs):  1.572 → 0.527 → 5.7718
#   Efficiency y (srs):  2.535 → 1.104 → 3.1993
#   Alpha:               0.7436681951527603
#   Num changes:         1
#   Design Depth:        4178
#   Design Size (|D|):   8637
#   Open set size:       123019
#
#
# === Best Solution Updated at Iteration 2510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28205.415
#   Best Cost (y):       95084140.3981
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.346
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9343→ cube 2.7417
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3924→ cube 1.4552
#   Efficiency z (srs):  1.572 → 0.527 → 5.772
#   Efficiency y (srs):  2.535 → 1.104 → 3.1958
#   Alpha:               0.8644915618076138
#   Num changes:         2
#   Design Depth:        4179
#   Design Size (|D|):   8639
#   Open set size:       123026
#
# Progress: 63.0%
# === Best Solution Updated at Iteration 2520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28169.879
#   Best Cost (y):       95080482.3394
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.333
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9368→ cube 2.7451
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3924→ cube 1.4552
#   Efficiency z (srs):  1.572 → 0.527 → 5.7793
#   Efficiency y (srs):  2.535 → 1.104 → 3.1959
#   Alpha:               0.8922187550471437
#   Num changes:         2
#   Design Depth:        4198
#   Design Size (|D|):   8677
#   Open set size:       123509
#
#
# === Best Solution Updated at Iteration 2520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28170.231
#   Best Cost (y):       95054702.3852
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.332
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9367→ cube 2.7451
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3928→ cube 1.4556
#   Efficiency z (srs):  1.572 → 0.527 → 5.7792
#   Efficiency y (srs):  2.535 → 1.104 → 3.1968
#   Alpha:               0.7222552437277898
#   Num changes:         2
#   Design Depth:        4198
#   Design Size (|D|):   8677
#   Open set size:       123526
#
# Progress: 63.2%
# === Best Solution Updated at Iteration 2530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28152.016
#   Best Cost (y):       95216510.0203
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.327
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.938→ cube 2.7469
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3904→ cube 1.4532
#   Efficiency z (srs):  1.572 → 0.527 → 5.7829
#   Efficiency y (srs):  2.535 → 1.104 → 3.1913
#   Alpha:               0.810523954462228
#   Num changes:         1
#   Design Depth:        4215
#   Design Size (|D|):   8711
#   Open set size:       123987
#
#
# === Best Solution Updated at Iteration 2530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28152.162
#   Best Cost (y):       95219790.0393
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.327
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.938→ cube 2.7469
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3904→ cube 1.4531
#   Efficiency z (srs):  1.572 → 0.527 → 5.7829
#   Efficiency y (srs):  2.535 → 1.104 → 3.1912
#   Alpha:               0.731628884071277
#   Num changes:         1
#   Design Depth:        4215
#   Design Size (|D|):   8711
#   Open set size:       124014
#
# Progress: 63.7%
# === Best Solution Updated at Iteration 2550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28046.198
#   Best Cost (y):       95268171.4743
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.284
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9453→ cube 2.7572
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3897→ cube 1.4524
#   Efficiency z (srs):  1.572 → 0.527 → 5.8048
#   Efficiency y (srs):  2.535 → 1.104 → 3.1896
#   Alpha:               0.7724490108406666
#   Num changes:         3
#   Design Depth:        4254
#   Design Size (|D|):   8789
#   Open set size:       124952
#
#
# === Best Solution Updated at Iteration 2550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28046.423
#   Best Cost (y):       95289351.7934
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.284
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9453→ cube 2.7572
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3894→ cube 1.4521
#   Efficiency z (srs):  1.572 → 0.527 → 5.8047
#   Efficiency y (srs):  2.535 → 1.104 → 3.1889
#   Alpha:               0.8037963806111867
#   Num changes:         3
#   Design Depth:        4254
#   Design Size (|D|):   8789
#   Open set size:       124973
#
#
# === Best Solution Updated at Iteration 2550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28044.793
#   Best Cost (y):       95288229.1357
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.283
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9454→ cube 2.7574
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3894→ cube 1.4521
#   Efficiency z (srs):  1.572 → 0.527 → 5.805
#   Efficiency y (srs):  2.535 → 1.104 → 3.1889
#   Alpha:               0.8011702918670722
#   Num changes:         3
#   Design Depth:        4254
#   Design Size (|D|):   8789
#   Open set size:       124996
#
# Progress: 64.0%
# === Best Solution Updated at Iteration 2560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28042.061
#   Best Cost (y):       95387515.3093
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.282
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9456→ cube 2.7577
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.388→ cube 1.4506
#   Efficiency z (srs):  1.572 → 0.527 → 5.8056
#   Efficiency y (srs):  2.535 → 1.104 → 3.1856
#   Alpha:               0.7824418323003849
#   Num changes:         2
#   Design Depth:        4269
#   Design Size (|D|):   8819
#   Open set size:       125465
#
# Progress: 64.2%
# === Best Solution Updated at Iteration 2570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28004.918
#   Best Cost (y):       95417885.1692
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.267
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9482→ cube 2.7613
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3875→ cube 1.4501
#   Efficiency z (srs):  1.572 → 0.527 → 5.8133
#   Efficiency y (srs):  2.535 → 1.104 → 3.1846
#   Alpha:               0.7060188810292881
#   Num changes:         1
#   Design Depth:        4285
#   Design Size (|D|):   8851
#   Open set size:       125975
#
# Progress: 64.5%
# === Best Solution Updated at Iteration 2580 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27992.735
#   Best Cost (y):       95319258.6539
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.261
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.949→ cube 2.7625
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3889→ cube 1.4516
#   Efficiency z (srs):  1.572 → 0.527 → 5.8158
#   Efficiency y (srs):  2.535 → 1.104 → 3.1879
#   Alpha:               0.8847987831026372
#   Num changes:         1
#   Design Depth:        4301
#   Design Size (|D|):   8883
#   Open set size:       126460
#
# Progress: 64.8%
# === Best Solution Updated at Iteration 2590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27974.428
#   Best Cost (y):       95215035.4215
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.253
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9503→ cube 2.7643
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3905→ cube 1.4532
#   Efficiency z (srs):  1.572 → 0.527 → 5.8196
#   Efficiency y (srs):  2.535 → 1.104 → 3.1914
#   Alpha:               0.8905360294154172
#   Num changes:         1
#   Design Depth:        4316
#   Design Size (|D|):   8913
#   Open set size:       126954
#
# Progress: 65.8%
# === Best Solution Updated at Iteration 2630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27880.018
#   Best Cost (y):       95341842.612
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.214
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.9569→ cube 2.7737
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3886→ cube 1.4513
#   Efficiency z (srs):  1.572 → 0.527 → 5.8394
#   Efficiency y (srs):  2.535 → 1.104 → 3.1871
#   Alpha:               0.7773387888679438
#   Num changes:         2
#   Design Depth:        4375
#   Design Size (|D|):   9031
#   Open set size:       128895
#
# Progress: 66.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 93
#      65 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      66                    inclusion_probability=inclusions, balance_method='linear')
#      68 astar = AStar(
#      69     inclusions              = inclusions,
#      70     num_initial_nodes       = num_initial_nodes,
#    (...)     90     # delta                   = 0.01,
#      91 )
# ---> 93 result = astar.run(
#      94     max_iterations             = max_iterations,
#      95     num_new_nodes              = num_new_nodes,
#      96     max_open_set_size          = max_open_set_size,
#      97     random_restart_period      = random_restart_period,
#      98     random_injection_count     = random_injection_count,
#      99     prune_fraction             = prune_fraction,
#     100     num_top_restart_nodes      = num_top_restart_nodes,
#     101     stuck_fraction             = stuck_fraction,
#     102
#     103 )
#     105 print("Best criteria value:", astar.best_criteria_value)
#     106 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:14, in VarNHT.__call__(self, design)
#      11 # Calculate estimators
#      12 ones = np.ones(N)
#      13 NHT_estimator_z = np.array([
# ---> 14     np.sum(self.auxiliary_variable[list(sample.ids)] /
#      15            self.inclusion_probability[list(sample.ids)])
#      16     for sample in design
#      17 ])
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
