# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Real_Sweden"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmpmMgqNN", R: "/tmp/RtmpR1EjU6"
#   warnings.warn(

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 10

# %%
num_new_nodes          = 30

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.03558719
# [1] 304952002.5    163382.8

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 2266.9209 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0453 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0170 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.1130297
# Variance of HT estimator via DSD formula_z:  54558.62
# Variance of HT estimator via DSD formula:  132393477
# Here is the Vincent Efficiency y:
#   DSD_y:  1.18125
#   DSD_z: 2.99463
# Monte Carlo variance of HT estimator for y:
#   DSD:  132317295.52917
#   Cube: 138365354.80914
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.18193
#   Cube: 1.13027
# Monte Carlo mean of HT estimator for y:
#   DSD:  53412.62333
#   Cube: 53387.76893
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  55805.96348
#   Cube: 77330.21460
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  2.92769
#   Cube: 2.11279
# Monte Carlo mean of HT estimator for z:
#   DSD:  2503.38578
#   Cube: 2514.21828
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        2.11        2.99        1.95        2.20        2.30

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_5993/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639386
# [281] [10.] adsfa
# 4000 30 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 27.34it/s]
# Initial design 0: method = Original, efficiency z = 0.5269, y=1.1044
# New best at idx=0: method = Original, efficiency z = 0.5269 and efficiency y = 1.1044
#
# Progress: 0.0%
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       103512.448
#   Best Cost (y):       119076624.2949
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      43.11
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5271→ cube 0.7471
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1118→ cube 1.162
#   Efficiency z (srs):  1.572 → 0.527 → 1.5728
#   Efficiency y (srs):  2.535 → 1.104 → 2.5519
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       59
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       88372.859
#   Best Cost (y):       115462195.3389
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.931
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6174→ cube 0.875
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1466→ cube 1.1984
#   Efficiency z (srs):  1.572 → 0.527 → 1.8422
#   Efficiency y (srs):  2.535 → 1.104 → 2.6317
#   Alpha:               0.8883034898354107
#   Num changes:         2
#   Design Depth:        56
#   Design Size (|D|):   393
#   Open set size:       871
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       88077.325
#   Best Cost (y):       114961626.1846
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.815
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6194→ cube 0.878
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1516→ cube 1.2036
#   Efficiency z (srs):  1.572 → 0.527 → 1.8484
#   Efficiency y (srs):  2.535 → 1.104 → 2.6432
#   Alpha:               0.7468354481778064
#   Num changes:         2
#   Design Depth:        56
#   Design Size (|D|):   393
#   Open set size:       889
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       87884.13
#   Best Cost (y):       115485360.8235
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.754
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6208→ cube 0.8799
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1464→ cube 1.1981
#   Efficiency z (srs):  1.572 → 0.527 → 1.8525
#   Efficiency y (srs):  2.535 → 1.104 → 2.6312
#   Alpha:               0.7554154302793341
#   Num changes:         3
#   Design Depth:        57
#   Design Size (|D|):   395
#   Open set size:       897
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       84145.904
#   Best Cost (y):       113448126.5223
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      35.205
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6484→ cube 0.919
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.167→ cube 1.2196
#   Efficiency z (srs):  1.572 → 0.527 → 1.9348
#   Efficiency y (srs):  2.535 → 1.104 → 2.6785
#   Alpha:               0.8639414387829308
#   Num changes:         2
#   Design Depth:        80
#   Design Size (|D|):   441
#   Open set size:       1164
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       79215.361
#   Best Cost (y):       115426729.1082
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      33.277
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6887→ cube 0.9762
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.147→ cube 1.1987
#   Efficiency z (srs):  1.572 → 0.527 → 2.0552
#   Efficiency y (srs):  2.535 → 1.104 → 2.6326
#   Alpha:               0.7374812789425228
#   Num changes:         2
#   Design Depth:        104
#   Design Size (|D|):   489
#   Open set size:       1462
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76137.189
#   Best Cost (y):       114474024.3643
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.089
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7166→ cube 1.0157
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1565→ cube 1.2087
#   Efficiency z (srs):  1.572 → 0.527 → 2.1383
#   Efficiency y (srs):  2.535 → 1.104 → 2.6545
#   Alpha:               0.8175691892842403
#   Num changes:         1
#   Design Depth:        124
#   Design Size (|D|):   529
#   Open set size:       1741
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       75350.193
#   Best Cost (y):       114568768.9751
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.774
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7241→ cube 1.0263
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1556→ cube 1.2077
#   Efficiency z (srs):  1.572 → 0.527 → 2.1606
#   Efficiency y (srs):  2.535 → 1.104 → 2.6523
#   Alpha:               0.8564741195947145
#   Num changes:         2
#   Design Depth:        125
#   Design Size (|D|):   531
#   Open set size:       1742
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       75138.788
#   Best Cost (y):       114548291.538
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.693
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7261→ cube 1.0292
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1558→ cube 1.2079
#   Efficiency z (srs):  1.572 → 0.527 → 2.1667
#   Efficiency y (srs):  2.535 → 1.104 → 2.6527
#   Alpha:               0.8527570185032796
#   Num changes:         1
#   Design Depth:        124
#   Design Size (|D|):   529
#   Open set size:       1752
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       75084.172
#   Best Cost (y):       114550900.4004
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.671
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7266→ cube 1.0299
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1558→ cube 1.2079
#   Efficiency z (srs):  1.572 → 0.527 → 2.1683
#   Efficiency y (srs):  2.535 → 1.104 → 2.6527
#   Alpha:               0.886763897701285
#   Num changes:         1
#   Design Depth:        124
#   Design Size (|D|):   529
#   Open set size:       1754
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73763.481
#   Best Cost (y):       114034355.3492
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.103
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7396→ cube 1.0484
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.161→ cube 1.2134
#   Efficiency z (srs):  1.572 → 0.527 → 2.2071
#   Efficiency y (srs):  2.535 → 1.104 → 2.6647
#   Alpha:               0.7383931710950846
#   Num changes:         1
#   Design Depth:        144
#   Design Size (|D|):   569
#   Open set size:       2039
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73738.913
#   Best Cost (y):       115131289.8972
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.102
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7399→ cube 1.0487
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1499→ cube 1.2018
#   Efficiency z (srs):  1.572 → 0.527 → 2.2078
#   Efficiency y (srs):  2.535 → 1.104 → 2.6393
#   Alpha:               0.8688732909480125
#   Num changes:         1
#   Design Depth:        144
#   Design Size (|D|):   569
#   Open set size:       2045
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73753.644
#   Best Cost (y):       113638045.0154
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.094
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7397→ cube 1.0485
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.165→ cube 1.2176
#   Efficiency z (srs):  1.572 → 0.527 → 2.2074
#   Efficiency y (srs):  2.535 → 1.104 → 2.674
#   Alpha:               0.8922645054580314
#   Num changes:         1
#   Design Depth:        144
#   Design Size (|D|):   569
#   Open set size:       2054
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73387.722
#   Best Cost (y):       113894523.5417
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.914
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7434→ cube 1.0537
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1624→ cube 1.2149
#   Efficiency z (srs):  1.572 → 0.527 → 2.2184
#   Efficiency y (srs):  2.535 → 1.104 → 2.668
#   Alpha:               0.7486654173185836
#   Num changes:         1
#   Design Depth:        163
#   Design Size (|D|):   607
#   Open set size:       2323
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73343.147
#   Best Cost (y):       114294303.7519
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.887
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7439→ cube 1.0544
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1584→ cube 1.2106
#   Efficiency z (srs):  1.572 → 0.527 → 2.2197
#   Efficiency y (srs):  2.535 → 1.104 → 2.6586
#   Alpha:               0.7051278989623624
#   Num changes:         3
#   Design Depth:        165
#   Design Size (|D|):   611
#   Open set size:       2324
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       71460.955
#   Best Cost (y):       113105145.8708
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.156
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7635→ cube 1.0821
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1705→ cube 1.2233
#   Efficiency z (srs):  1.572 → 0.527 → 2.2782
#   Efficiency y (srs):  2.535 → 1.104 → 2.6866
#   Alpha:               0.7696667031550678
#   Num changes:         3
#   Design Depth:        186
#   Design Size (|D|):   653
#   Open set size:       2629
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       70796.157
#   Best Cost (y):       113255891.1587
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.881
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7706→ cube 1.0923
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.169→ cube 1.2217
#   Efficiency z (srs):  1.572 → 0.527 → 2.2996
#   Efficiency y (srs):  2.535 → 1.104 → 2.683
#   Alpha:               0.728952355766776
#   Num changes:         1
#   Design Depth:        207
#   Design Size (|D|):   695
#   Open set size:       2907
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       69755.272
#   Best Cost (y):       112294360.364
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.486
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7821→ cube 1.1086
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.179→ cube 1.2322
#   Efficiency z (srs):  1.572 → 0.527 → 2.3339
#   Efficiency y (srs):  2.535 → 1.104 → 2.706
#   Alpha:               0.7240358415670699
#   Num changes:         1
#   Design Depth:        225
#   Design Size (|D|):   731
#   Open set size:       3191
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       69730.051
#   Best Cost (y):       112652431.942
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.483
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7824→ cube 1.109
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1752→ cube 1.2283
#   Efficiency z (srs):  1.572 → 0.527 → 2.3347
#   Efficiency y (srs):  2.535 → 1.104 → 2.6974
#   Alpha:               0.7309627186898796
#   Num changes:         3
#   Design Depth:        227
#   Design Size (|D|):   735
#   Open set size:       3212
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       67077.181
#   Best Cost (y):       109633358.2801
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      28.373
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8134→ cube 1.1529
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2076→ cube 1.2621
#   Efficiency z (srs):  1.572 → 0.527 → 2.4271
#   Efficiency y (srs):  2.535 → 1.104 → 2.7717
#   Alpha:               0.7075299887693507
#   Num changes:         3
#   Design Depth:        250
#   Design Size (|D|):   781
#   Open set size:       3487
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       67090.604
#   Best Cost (y):       109697620.3051
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      28.37
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8132→ cube 1.1526
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2069→ cube 1.2613
#   Efficiency z (srs):  1.572 → 0.527 → 2.4266
#   Efficiency y (srs):  2.535 → 1.104 → 2.77
#   Alpha:               0.8000694257963216
#   Num changes:         3
#   Design Depth:        250
#   Design Size (|D|):   781
#   Open set size:       3490
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       67002.388
#   Best Cost (y):       109682231.6692
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      28.347
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8143→ cube 1.1541
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2071→ cube 1.2615
#   Efficiency z (srs):  1.572 → 0.527 → 2.4298
#   Efficiency y (srs):  2.535 → 1.104 → 2.7704
#   Alpha:               0.7660831634086532
#   Num changes:         3
#   Design Depth:        250
#   Design Size (|D|):   781
#   Open set size:       3498
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65681.758
#   Best Cost (y):       108554475.3675
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.768
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8307→ cube 1.1773
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2196→ cube 1.2746
#   Efficiency z (srs):  1.572 → 0.527 → 2.4786
#   Efficiency y (srs):  2.535 → 1.104 → 2.7992
#   Alpha:               0.882011173643071
#   Num changes:         3
#   Design Depth:        278
#   Design Size (|D|):   837
#   Open set size:       3771
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65559.1
#   Best Cost (y):       108707435.6463
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.73
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8322→ cube 1.1795
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2179→ cube 1.2728
#   Efficiency z (srs):  1.572 → 0.527 → 2.4833
#   Efficiency y (srs):  2.535 → 1.104 → 2.7953
#   Alpha:               0.8828216874006102
#   Num changes:         2
#   Design Depth:        277
#   Design Size (|D|):   835
#   Open set size:       3774
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65564.4
#   Best Cost (y):       108960298.0424
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.728
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8321→ cube 1.1795
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2151→ cube 1.2699
#   Efficiency z (srs):  1.572 → 0.527 → 2.4831
#   Efficiency y (srs):  2.535 → 1.104 → 2.7888
#   Alpha:               0.8134448206937475
#   Num changes:         3
#   Design Depth:        278
#   Design Size (|D|):   837
#   Open set size:       3788
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65450.496
#   Best Cost (y):       108911162.321
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.693
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8336→ cube 1.1815
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2156→ cube 1.2704
#   Efficiency z (srs):  1.572 → 0.527 → 2.4874
#   Efficiency y (srs):  2.535 → 1.104 → 2.79
#   Alpha:               0.7132371736809889
#   Num changes:         2
#   Design Depth:        277
#   Design Size (|D|):   835
#   Open set size:       3790
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65265.371
#   Best Cost (y):       109237911.1213
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.611
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.836→ cube 1.1849
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.212→ cube 1.2666
#   Efficiency z (srs):  1.572 → 0.527 → 2.4945
#   Efficiency y (srs):  2.535 → 1.104 → 2.7817
#   Alpha:               0.8816518297591647
#   Num changes:         2
#   Design Depth:        277
#   Design Size (|D|):   835
#   Open set size:       3796
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       64913.425
#   Best Cost (y):       107707845.7458
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.453
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8405→ cube 1.1913
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2292→ cube 1.2846
#   Efficiency z (srs):  1.572 → 0.527 → 2.508
#   Efficiency y (srs):  2.535 → 1.104 → 2.8212
#   Alpha:               0.8156972314257661
#   Num changes:         2
#   Design Depth:        294
#   Design Size (|D|):   869
#   Open set size:       4075
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       62479.153
#   Best Cost (y):       105565298.7126
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.499
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8732→ cube 1.2377
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2541→ cube 1.3107
#   Efficiency z (srs):  1.572 → 0.527 → 2.6057
#   Efficiency y (srs):  2.535 → 1.104 → 2.8785
#   Alpha:               0.8063937537885317
#   Num changes:         1
#   Design Depth:        314
#   Design Size (|D|):   909
#   Open set size:       4359
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       62477.859
#   Best Cost (y):       105855648.9904
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.499
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8732→ cube 1.2377
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2507→ cube 1.3071
#   Efficiency z (srs):  1.572 → 0.527 → 2.6057
#   Efficiency y (srs):  2.535 → 1.104 → 2.8706
#   Alpha:               0.7225108531601149
#   Num changes:         1
#   Design Depth:        314
#   Design Size (|D|):   909
#   Open set size:       4365
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       62402.545
#   Best Cost (y):       105861710.0792
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.471
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8743→ cube 1.2392
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2506→ cube 1.307
#   Efficiency z (srs):  1.572 → 0.527 → 2.6089
#   Efficiency y (srs):  2.535 → 1.104 → 2.8704
#   Alpha:               0.767856323614066
#   Num changes:         3
#   Design Depth:        316
#   Design Size (|D|):   913
#   Open set size:       4372
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60576.1
#   Best Cost (y):       105583330.002
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.733
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9007→ cube 1.2766
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2539→ cube 1.3105
#   Efficiency z (srs):  1.572 → 0.527 → 2.6876
#   Efficiency y (srs):  2.535 → 1.104 → 2.878
#   Alpha:               0.7814531022919026
#   Num changes:         2
#   Design Depth:        339
#   Design Size (|D|):   959
#   Open set size:       4641
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60597.784
#   Best Cost (y):       105366973.4032
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.73
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9003→ cube 1.2761
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2565→ cube 1.3132
#   Efficiency z (srs):  1.572 → 0.527 → 2.6866
#   Efficiency y (srs):  2.535 → 1.104 → 2.8839
#   Alpha:               0.7955572618393119
#   Num changes:         2
#   Design Depth:        339
#   Design Size (|D|):   959
#   Open set size:       4650
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60577.091
#   Best Cost (y):       105240651.8285
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.72
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9006→ cube 1.2766
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.258→ cube 1.3148
#   Efficiency z (srs):  1.572 → 0.527 → 2.6875
#   Efficiency y (srs):  2.535 → 1.104 → 2.8874
#   Alpha:               0.8489835870980439
#   Num changes:         2
#   Design Depth:        339
#   Design Size (|D|):   959
#   Open set size:       4666
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60267.45
#   Best Cost (y):       105522161.9787
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.596
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9053→ cube 1.2831
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2547→ cube 1.3112
#   Efficiency z (srs):  1.572 → 0.527 → 2.7013
#   Efficiency y (srs):  2.535 → 1.104 → 2.8796
#   Alpha:               0.7820518024188263
#   Num changes:         3
#   Design Depth:        360
#   Design Size (|D|):   1001
#   Open set size:       4931
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60136.623
#   Best Cost (y):       105241063.111
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.534
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9072→ cube 1.2859
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.258→ cube 1.3147
#   Efficiency z (srs):  1.572 → 0.527 → 2.7072
#   Efficiency y (srs):  2.535 → 1.104 → 2.8873
#   Alpha:               0.8740634498003885
#   Num changes:         1
#   Design Depth:        376
#   Design Size (|D|):   1033
#   Open set size:       5222
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60110.783
#   Best Cost (y):       105347444.4634
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.521
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9076→ cube 1.2865
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2567→ cube 1.3134
#   Efficiency z (srs):  1.572 → 0.527 → 2.7084
#   Efficiency y (srs):  2.535 → 1.104 → 2.8844
#   Alpha:               0.8735188650126282
#   Num changes:         2
#   Design Depth:        377
#   Design Size (|D|):   1035
#   Open set size:       5223
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60069.746
#   Best Cost (y):       105392838.3669
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.508
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9083→ cube 1.2873
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2562→ cube 1.3129
#   Efficiency z (srs):  1.572 → 0.527 → 2.7102
#   Efficiency y (srs):  2.535 → 1.104 → 2.8832
#   Alpha:               0.8343245065649334
#   Num changes:         2
#   Design Depth:        377
#   Design Size (|D|):   1035
#   Open set size:       5229
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60064.212
#   Best Cost (y):       105184516.004
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.503
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9083→ cube 1.2875
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2587→ cube 1.3155
#   Efficiency z (srs):  1.572 → 0.527 → 2.7105
#   Efficiency y (srs):  2.535 → 1.104 → 2.8889
#   Alpha:               0.7680049796706576
#   Num changes:         2
#   Design Depth:        377
#   Design Size (|D|):   1035
#   Open set size:       5234
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       60062.504
#   Best Cost (y):       105384398.8012
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.502
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9084→ cube 1.2875
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2563→ cube 1.313
#   Efficiency z (srs):  1.572 → 0.527 → 2.7105
#   Efficiency y (srs):  2.535 → 1.104 → 2.8834
#   Alpha:               0.8073287923228278
#   Num changes:         2
#   Design Depth:        377
#   Design Size (|D|):   1035
#   Open set size:       5247
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59304.753
#   Best Cost (y):       104544920.0029
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.173
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.92→ cube 1.3039
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2664→ cube 1.3235
#   Efficiency z (srs):  1.572 → 0.527 → 2.7452
#   Efficiency y (srs):  2.535 → 1.104 → 2.9066
#   Alpha:               0.7415500038802979
#   Num changes:         3
#   Design Depth:        396
#   Design Size (|D|):   1073
#   Open set size:       5511
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59273.814
#   Best Cost (y):       104500154.3915
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.155
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9205→ cube 1.3046
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2669→ cube 1.3241
#   Efficiency z (srs):  1.572 → 0.527 → 2.7466
#   Efficiency y (srs):  2.535 → 1.104 → 2.9078
#   Alpha:               0.8836180368812149
#   Num changes:         1
#   Design Depth:        394
#   Design Size (|D|):   1069
#   Open set size:       5517
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59193.43
#   Best Cost (y):       104755302.152
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.126
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9217→ cube 1.3064
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2638→ cube 1.3208
#   Efficiency z (srs):  1.572 → 0.527 → 2.7503
#   Efficiency y (srs):  2.535 → 1.104 → 2.9007
#   Alpha:               0.7858369992779907
#   Num changes:         3
#   Design Depth:        396
#   Design Size (|D|):   1073
#   Open set size:       5518
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       58517.211
#   Best Cost (y):       105597723.7325
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.852
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9324→ cube 1.3215
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2538→ cube 1.3103
#   Efficiency z (srs):  1.572 → 0.527 → 2.7821
#   Efficiency y (srs):  2.535 → 1.104 → 2.8776
#   Alpha:               0.7000846435000441
#   Num changes:         2
#   Design Depth:        415
#   Design Size (|D|):   1111
#   Open set size:       5804
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       58517.621
#   Best Cost (y):       105632737.9548
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.85
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9323→ cube 1.3215
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2533→ cube 1.3099
#   Efficiency z (srs):  1.572 → 0.527 → 2.7821
#   Efficiency y (srs):  2.535 → 1.104 → 2.8766
#   Alpha:               0.7920921407317041
#   Num changes:         2
#   Design Depth:        415
#   Design Size (|D|):   1111
#   Open set size:       5820
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57091.075
#   Best Cost (y):       105731345.2649
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.283
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9556→ cube 1.3545
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2522→ cube 1.3087
#   Efficiency z (srs):  1.572 → 0.527 → 2.8516
#   Efficiency y (srs):  2.535 → 1.104 → 2.874
#   Alpha:               0.7671220783207344
#   Num changes:         3
#   Design Depth:        458
#   Design Size (|D|):   1197
#   Open set size:       6681
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55214.839
#   Best Cost (y):       107589189.7748
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.538
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9881→ cube 1.4005
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2305→ cube 1.2861
#   Efficiency z (srs):  1.572 → 0.527 → 2.9485
#   Efficiency y (srs):  2.535 → 1.104 → 2.8243
#   Alpha:               0.8234884014950452
#   Num changes:         2
#   Design Depth:        477
#   Design Size (|D|):   1235
#   Open set size:       6965
#
#
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55206.457
#   Best Cost (y):       107018057.2367
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.527
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9883→ cube 1.4007
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2371→ cube 1.2929
#   Efficiency z (srs):  1.572 → 0.527 → 2.949
#   Efficiency y (srs):  2.535 → 1.104 → 2.8394
#   Alpha:               0.8914252820988885
#   Num changes:         2
#   Design Depth:        477
#   Design Size (|D|):   1235
#   Open set size:       6970
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54853.741
#   Best Cost (y):       107049111.8646
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.378
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9946→ cube 1.4098
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2368→ cube 1.2925
#   Efficiency z (srs):  1.572 → 0.527 → 2.9679
#   Efficiency y (srs):  2.535 → 1.104 → 2.8386
#   Alpha:               0.7505078987787615
#   Num changes:         2
#   Design Depth:        496
#   Design Size (|D|):   1273
#   Open set size:       7255
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54847.995
#   Best Cost (y):       106940149.0969
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.374
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9947→ cube 1.4099
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.238→ cube 1.2939
#   Efficiency z (srs):  1.572 → 0.527 → 2.9682
#   Efficiency y (srs):  2.535 → 1.104 → 2.8415
#   Alpha:               0.8343327851831791
#   Num changes:         1
#   Design Depth:        495
#   Design Size (|D|):   1271
#   Open set size:       7263
#
# Progress: 6.5%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54102.591
#   Best Cost (y):       106387450.3229
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.053
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0084→ cube 1.4293
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2444→ cube 1.3006
#   Efficiency z (srs):  1.572 → 0.527 → 3.0091
#   Efficiency y (srs):  2.535 → 1.104 → 2.8562
#   Alpha:               0.8298547570456555
#   Num changes:         1
#   Design Depth:        514
#   Design Size (|D|):   1309
#   Open set size:       7548
#
#
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54089.433
#   Best Cost (y):       106217457.2029
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.047
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0087→ cube 1.4297
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2464→ cube 1.3027
#   Efficiency z (srs):  1.572 → 0.527 → 3.0099
#   Efficiency y (srs):  2.535 → 1.104 → 2.8608
#   Alpha:               0.8792267887350959
#   Num changes:         1
#   Design Depth:        514
#   Design Size (|D|):   1309
#   Open set size:       7558
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53809.257
#   Best Cost (y):       106871380.8653
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.925
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0139→ cube 1.4371
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2388→ cube 1.2947
#   Efficiency z (srs):  1.572 → 0.527 → 3.0255
#   Efficiency y (srs):  2.535 → 1.104 → 2.8433
#   Alpha:               0.7130792720579011
#   Num changes:         2
#   Design Depth:        530
#   Design Size (|D|):   1341
#   Open set size:       7837
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53809.531
#   Best Cost (y):       106660886.2834
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.924
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0139→ cube 1.4371
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2413→ cube 1.2972
#   Efficiency z (srs):  1.572 → 0.527 → 3.0255
#   Efficiency y (srs):  2.535 → 1.104 → 2.8489
#   Alpha:               0.7165960050033002
#   Num changes:         2
#   Design Depth:        530
#   Design Size (|D|):   1341
#   Open set size:       7844
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53606.898
#   Best Cost (y):       107002040.0329
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.842
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0178→ cube 1.4425
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2373→ cube 1.2931
#   Efficiency z (srs):  1.572 → 0.527 → 3.0369
#   Efficiency y (srs):  2.535 → 1.104 → 2.8398
#   Alpha:               0.7124477325306506
#   Num changes:         1
#   Design Depth:        545
#   Design Size (|D|):   1371
#   Open set size:       8134
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53597.681
#   Best Cost (y):       106952113.7817
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.837
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0179→ cube 1.4428
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2379→ cube 1.2937
#   Efficiency z (srs):  1.572 → 0.527 → 3.0375
#   Efficiency y (srs):  2.535 → 1.104 → 2.8411
#   Alpha:               0.7242001771102017
#   Num changes:         3
#   Design Depth:        547
#   Design Size (|D|):   1375
#   Open set size:       8140
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53596.16
#   Best Cost (y):       106949418.0868
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.835
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.018→ cube 1.4428
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2379→ cube 1.2937
#   Efficiency z (srs):  1.572 → 0.527 → 3.0376
#   Efficiency y (srs):  2.535 → 1.104 → 2.8412
#   Alpha:               0.7299340161081286
#   Num changes:         3
#   Design Depth:        547
#   Design Size (|D|):   1375
#   Open set size:       8141
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53442.804
#   Best Cost (y):       105750212.2315
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.763
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0209→ cube 1.447
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2519→ cube 1.3084
#   Efficiency z (srs):  1.572 → 0.527 → 3.0463
#   Efficiency y (srs):  2.535 → 1.104 → 2.8734
#   Alpha:               0.7496211519903128
#   Num changes:         1
#   Design Depth:        563
#   Design Size (|D|):   1407
#   Open set size:       8434
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53437.925
#   Best Cost (y):       105741867.6708
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.76
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.021→ cube 1.4471
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.252→ cube 1.3085
#   Efficiency z (srs):  1.572 → 0.527 → 3.0466
#   Efficiency y (srs):  2.535 → 1.104 → 2.8737
#   Alpha:               0.8076694158943228
#   Num changes:         2
#   Design Depth:        564
#   Design Size (|D|):   1409
#   Open set size:       8437
#
# Progress: 7.5%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53109.071
#   Best Cost (y):       105526226.1052
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.626
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0273→ cube 1.4561
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2546→ cube 1.3112
#   Efficiency z (srs):  1.572 → 0.527 → 3.0654
#   Efficiency y (srs):  2.535 → 1.104 → 2.8795
#   Alpha:               0.7198399962426751
#   Num changes:         1
#   Design Depth:        579
#   Design Size (|D|):   1439
#   Open set size:       8701
#
#
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53047.331
#   Best Cost (y):       105602341.9316
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.602
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0285→ cube 1.4578
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2537→ cube 1.3102
#   Efficiency z (srs):  1.572 → 0.527 → 3.069
#   Efficiency y (srs):  2.535 → 1.104 → 2.8775
#   Alpha:               0.7323563348099392
#   Num changes:         1
#   Design Depth:        579
#   Design Size (|D|):   1439
#   Open set size:       8708
#
#
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53056.139
#   Best Cost (y):       105452218.0306
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.602
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0283→ cube 1.4575
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2555→ cube 1.3121
#   Efficiency z (srs):  1.572 → 0.527 → 3.0685
#   Efficiency y (srs):  2.535 → 1.104 → 2.8816
#   Alpha:               0.8030368119355861
#   Num changes:         3
#   Design Depth:        581
#   Design Size (|D|):   1443
#   Open set size:       8729
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       52129.117
#   Best Cost (y):       105861642.3002
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.23
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0466→ cube 1.4834
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2506→ cube 1.307
#   Efficiency z (srs):  1.572 → 0.527 → 3.123
#   Efficiency y (srs):  2.535 → 1.104 → 2.8704
#   Alpha:               0.7749835768277934
#   Num changes:         3
#   Design Depth:        618
#   Design Size (|D|):   1517
#   Open set size:       9281
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       52040.2
#   Best Cost (y):       105956129.2094
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.196
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0484→ cube 1.486
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2495→ cube 1.3059
#   Efficiency z (srs):  1.572 → 0.527 → 3.1284
#   Efficiency y (srs):  2.535 → 1.104 → 2.8679
#   Alpha:               0.7551231346571873
#   Num changes:         3
#   Design Depth:        618
#   Design Size (|D|):   1517
#   Open set size:       9299
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       51782.355
#   Best Cost (y):       104668000.8846
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.083
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0536→ cube 1.4934
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2649→ cube 1.3219
#   Efficiency z (srs):  1.572 → 0.527 → 3.144
#   Efficiency y (srs):  2.535 → 1.104 → 2.9031
#   Alpha:               0.7202038598152232
#   Num changes:         1
#   Design Depth:        641
#   Design Size (|D|):   1563
#   Open set size:       9573
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       51774.981
#   Best Cost (y):       104553756.1775
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.08
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0538→ cube 1.4936
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2663→ cube 1.3234
#   Efficiency z (srs):  1.572 → 0.527 → 3.1444
#   Efficiency y (srs):  2.535 → 1.104 → 2.9063
#   Alpha:               0.774003692398844
#   Num changes:         1
#   Design Depth:        641
#   Design Size (|D|):   1563
#   Open set size:       9576
#
#
# === Best Solution Updated at Iteration 330 ===
# ...
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.768
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0443→ cube 2.8975
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4452→ cube 1.5103
#   Efficiency z (srs):  1.572 → 0.527 → 6.1
#   Efficiency y (srs):  2.535 → 1.104 → 3.3169
#   Alpha:               0.730185040954986
#   Num changes:         1
#   Design Depth:        5118
#   Design Size (|D|):   10517
#   Open set size:       100643
#
#
# === Best Solution Updated at Iteration 3470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26688.594
#   Best Cost (y):       91620619.3729
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.768
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0443→ cube 2.8975
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.445→ cube 1.5102
#   Efficiency z (srs):  1.572 → 0.527 → 6.1
#   Efficiency y (srs):  2.535 → 1.104 → 3.3166
#   Alpha:               0.7234467767901973
#   Num changes:         1
#   Design Depth:        5118
#   Design Size (|D|):   10517
#   Open set size:       100652
#
# Progress: 88.0%
# === Best Solution Updated at Iteration 3520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26657.597
#   Best Cost (y):       91530786.9838
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.754
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0466→ cube 2.9009
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4464→ cube 1.5117
#   Efficiency z (srs):  1.572 → 0.527 → 6.1071
#   Efficiency y (srs):  2.535 → 1.104 → 3.3198
#   Alpha:               0.8954899699194426
#   Num changes:         1
#   Design Depth:        5157
#   Design Size (|D|):   10595
#   Open set size:       102087
#
#
# === Best Solution Updated at Iteration 3520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26658.665
#   Best Cost (y):       91482368.0195
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.754
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0466→ cube 2.9008
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4472→ cube 1.5125
#   Efficiency z (srs):  1.572 → 0.527 → 6.1069
#   Efficiency y (srs):  2.535 → 1.104 → 3.3216
#   Alpha:               0.8758923407804227
#   Num changes:         1
#   Design Depth:        5157
#   Design Size (|D|):   10595
#   Open set size:       102093
#
#
# === Best Solution Updated at Iteration 3520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26655.351
#   Best Cost (y):       91550632.708
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.752
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0468→ cube 2.9011
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4461→ cube 1.5114
#   Efficiency z (srs):  1.572 → 0.527 → 6.1076
#   Efficiency y (srs):  2.535 → 1.104 → 3.3191
#   Alpha:               0.8256825395250568
#   Num changes:         2
#   Design Depth:        5158
#   Design Size (|D|):   10597
#   Open set size:       102096
#
# Progress: 88.2%
# === Best Solution Updated at Iteration 3530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26644.667
#   Best Cost (y):       91541366.078
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.747
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0476→ cube 2.9023
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4463→ cube 1.5115
#   Efficiency z (srs):  1.572 → 0.527 → 6.1101
#   Efficiency y (srs):  2.535 → 1.104 → 3.3194
#   Alpha:               0.8090336540918365
#   Num changes:         3
#   Design Depth:        5175
#   Design Size (|D|):   10631
#   Open set size:       102374
#
#
# === Best Solution Updated at Iteration 3530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26643.014
#   Best Cost (y):       91534206.8306
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.747
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0478→ cube 2.9025
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4464→ cube 1.5116
#   Efficiency z (srs):  1.572 → 0.527 → 6.1105
#   Efficiency y (srs):  2.535 → 1.104 → 3.3197
#   Alpha:               0.8575428299361755
#   Num changes:         3
#   Design Depth:        5175
#   Design Size (|D|):   10631
#   Open set size:       102375
#
# Progress: 88.5%
# === Best Solution Updated at Iteration 3540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26582.565
#   Best Cost (y):       91637216.741
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.724
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0524→ cube 2.9091
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4448→ cube 1.5099
#   Efficiency z (srs):  1.572 → 0.527 → 6.1244
#   Efficiency y (srs):  2.535 → 1.104 → 3.316
#   Alpha:               0.8247728454200643
#   Num changes:         2
#   Design Depth:        5194
#   Design Size (|D|):   10669
#   Open set size:       102667
#
# Progress: 88.8%
# === Best Solution Updated at Iteration 3550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26576.444
#   Best Cost (y):       91563738.824
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.721
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0529→ cube 2.9097
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4459→ cube 1.5111
#   Efficiency z (srs):  1.572 → 0.527 → 6.1258
#   Efficiency y (srs):  2.535 → 1.104 → 3.3186
#   Alpha:               0.7644992057334766
#   Num changes:         2
#   Design Depth:        5207
#   Design Size (|D|):   10695
#   Open set size:       102972
#
# Progress: 89.0%
# === Best Solution Updated at Iteration 3560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26556.921
#   Best Cost (y):       91524686.5149
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.713
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0544→ cube 2.9119
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4465→ cube 1.5118
#   Efficiency z (srs):  1.572 → 0.527 → 6.1303
#   Efficiency y (srs):  2.535 → 1.104 → 3.3201
#   Alpha:               0.7302002715711843
#   Num changes:         1
#   Design Depth:        5221
#   Design Size (|D|):   10723
#   Open set size:       103245
#
# Progress: 89.2%
# === Best Solution Updated at Iteration 3570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26553.135
#   Best Cost (y):       91498514.3042
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.711
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0547→ cube 2.9123
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4469→ cube 1.5122
#   Efficiency z (srs):  1.572 → 0.527 → 6.1312
#   Efficiency y (srs):  2.535 → 1.104 → 3.321
#   Alpha:               0.8941929896854125
#   Num changes:         1
#   Design Depth:        5231
#   Design Size (|D|):   10743
#   Open set size:       103535
#
#
# === Best Solution Updated at Iteration 3570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26553.461
#   Best Cost (y):       91509906.3344
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.711
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0547→ cube 2.9122
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4468→ cube 1.512
#   Efficiency z (srs):  1.572 → 0.527 → 6.1311
#   Efficiency y (srs):  2.535 → 1.104 → 3.3206
#   Alpha:               0.8418975129372427
#   Num changes:         2
#   Design Depth:        5232
#   Design Size (|D|):   10745
#   Open set size:       103552
#
# Progress: 89.8%
# === Best Solution Updated at Iteration 3590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26536.345
#   Best Cost (y):       91499090.8511
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.704
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.056→ cube 2.9141
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4469→ cube 1.5122
#   Efficiency z (srs):  1.572 → 0.527 → 6.135
#   Efficiency y (srs):  2.535 → 1.104 → 3.321
#   Alpha:               0.7803287240228844
#   Num changes:         1
#   Design Depth:        5250
#   Design Size (|D|):   10781
#   Open set size:       104118
#
# Progress: 90.8%
# === Best Solution Updated at Iteration 3630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26525.028
#   Best Cost (y):       91401301.8998
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.699
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0569→ cube 2.9154
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4485→ cube 1.5138
#   Efficiency z (srs):  1.572 → 0.527 → 6.1377
#   Efficiency y (srs):  2.535 → 1.104 → 3.3245
#   Alpha:               0.8617262988804067
#   Num changes:         1
#   Design Depth:        5289
#   Design Size (|D|):   10859
#   Open set size:       105279
#
#
# === Best Solution Updated at Iteration 3630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26524.475
#   Best Cost (y):       91400372.9758
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.699
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0569→ cube 2.9154
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4485→ cube 1.5138
#   Efficiency z (srs):  1.572 → 0.527 → 6.1378
#   Efficiency y (srs):  2.535 → 1.104 → 3.3246
#   Alpha:               0.8652837789754069
#   Num changes:         1
#   Design Depth:        5289
#   Design Size (|D|):   10859
#   Open set size:       105288
#
# Progress: 91.2%
# === Best Solution Updated at Iteration 3650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26403.92
#   Best Cost (y):       91489693.5346
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.649
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0663→ cube 2.9287
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4471→ cube 1.5124
#   Efficiency z (srs):  1.572 → 0.527 → 6.1658
#   Efficiency y (srs):  2.535 → 1.104 → 3.3213
#   Alpha:               0.7725116296868646
#   Num changes:         1
#   Design Depth:        5330
#   Design Size (|D|):   10941
#   Open set size:       105863
#
#
# === Best Solution Updated at Iteration 3650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26403.581
#   Best Cost (y):       91492606.7608
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.648
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0663→ cube 2.9288
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.447→ cube 1.5123
#   Efficiency z (srs):  1.572 → 0.527 → 6.1659
#   Efficiency y (srs):  2.535 → 1.104 → 3.3212
#   Alpha:               0.8015816929346928
#   Num changes:         1
#   Design Depth:        5330
#   Design Size (|D|):   10941
#   Open set size:       105867
#
#
# === Best Solution Updated at Iteration 3650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26402.747
#   Best Cost (y):       91489828.9955
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.648
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0664→ cube 2.9289
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4471→ cube 1.5124
#   Efficiency z (srs):  1.572 → 0.527 → 6.1661
#   Efficiency y (srs):  2.535 → 1.104 → 3.3213
#   Alpha:               0.7193904513262869
#   Num changes:         2
#   Design Depth:        5331
#   Design Size (|D|):   10943
#   Open set size:       105876
#
# Progress: 92.0%
# === Best Solution Updated at Iteration 3680 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26370.719
#   Best Cost (y):       91463418.4466
#   number of new noded: 30
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.634
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 2.0689→ cube 2.9324
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.4475→ cube 1.5128
#   Efficiency z (srs):  1.572 → 0.527 → 6.1736
#   Efficiency y (srs):  2.535 → 1.104 → 3.3223
#   Alpha:               0.776491557077375
#   Num changes:         2
#   Design Depth:        5364
#   Design Size (|D|):   11009
#   Open set size:       106724
#
# Progress: 92.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 93
#      65 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      66                    inclusion_probability=inclusions, balance_method='linear')
#      68 astar = AStar(
#      69     inclusions              = inclusions,
#      70     num_initial_nodes       = num_initial_nodes,
#    (...)     90     # delta                   = 0.01,
#      91 )
# ---> 93 result = astar.run(
#      94     max_iterations             = max_iterations,
#      95     num_new_nodes              = num_new_nodes,
#      96     max_open_set_size          = max_open_set_size,
#      97     random_restart_period      = random_restart_period,
#      98     random_injection_count     = random_injection_count,
#      99     prune_fraction             = prune_fraction,
#     100     num_top_restart_nodes      = num_top_restart_nodes,
#     101     stuck_fraction             = stuck_fraction,
#     102
#     103 )
#     105 print("Best criteria value:", astar.best_criteria_value)
#     106 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:15, in VarNHT.__call__(self, design)
#      11 # Calculate estimators
#      12 ones = np.ones(N)
#      13 NHT_estimator_z = np.array([
#      14     np.sum(self.auxiliary_variable[list(sample.ids)] /
# ---> 15            self.inclusion_probability[list(sample.ids)])
#      16     for sample in design
#      17 ])
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#
# KeyboardInterrupt:

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
