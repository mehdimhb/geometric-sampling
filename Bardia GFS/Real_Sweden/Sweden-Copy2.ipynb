# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 15

# %%
num_new_nodes          = 10

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.05338078
# [1] 199550387.9    106912.2

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 1511.2806 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0679 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0256 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.03389852
# Variance of HT estimator via DSD formula_z:  27608.92
# Variance of HT estimator via DSD formula:  88384256
# Here is the Vincent Efficiency y:
#   DSD_y:  1.14641
#   DSD_z: 3.87238
# Monte Carlo variance of HT estimator for y:
#   DSD:  85971369.17998
#   Cube: 93391724.32965
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.17859
#   Cube: 1.08494
# Monte Carlo mean of HT estimator for y:
#   DSD:  53546.92758
#   Cube: 53113.46378
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  26307.99858
#   Cube: 39229.78326
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  4.06387
#   Cube: 2.72528
# Monte Carlo mean of HT estimator for z:
#   DSD:  2505.55578
#   Cube: 2506.39929
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        2.73        3.87        1.97        2.14        2.26

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639387
# /tmp/ipykernel_852886/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# [281] [15.] adsfa
# 4000 10 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 36.11it/s]
# Initial design 0: method = Original, efficiency z = 0.5137, y=0.4868
# New best at idx=0: method = Original, efficiency z = 0.5137 and efficiency y = 0.4868
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53558.678
#   Best Cost (y):       181897871.3208
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.565
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.5155→ cube 0.7325
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4859→ cube 0.5134
#   Efficiency z (srs):  1.982 → 0.514 → 1.9891
#   Efficiency y (srs):  1.095 → 0.487 → 1.0931
#   Alpha:               0.773812307293049
#   Num changes:         3
#   Design Depth:        3
#   Design Size (|D|):   287
#   Open set size:       4
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       50195.717
#   Best Cost (y):       178479112.1425
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      21.23
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.55→ cube 0.7815
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.4952→ cube 0.5233
#   Efficiency z (srs):  1.982 → 0.514 → 2.1223
#   Efficiency y (srs):  1.095 → 0.487 → 1.1141
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4
#   Design Size (|D|):   289
#   Open set size:       19
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       45390.061
#   Best Cost (y):       164090474.6518
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      19.352
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6083→ cube 0.8643
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5386→ cube 0.5691
#   Efficiency z (srs):  1.982 → 0.514 → 2.347
#   Efficiency y (srs):  1.095 → 0.487 → 1.2118
#   Alpha:               0.7045965820749553
#   Num changes:         2
#   Design Depth:        26
#   Design Size (|D|):   333
#   Open set size:       93
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       45215.617
#   Best Cost (y):       165127912.3868
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      19.28
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6106→ cube 0.8676
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5352→ cube 0.5656
#   Efficiency z (srs):  1.982 → 0.514 → 2.3561
#   Efficiency y (srs):  1.095 → 0.487 → 1.2042
#   Alpha:               0.8923674486706552
#   Num changes:         1
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       94
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       44155.229
#   Best Cost (y):       160065138.6716
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.807
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6253→ cube 0.8885
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5522→ cube 0.5835
#   Efficiency z (srs):  1.982 → 0.514 → 2.4127
#   Efficiency y (srs):  1.095 → 0.487 → 1.2422
#   Alpha:               0.7845801553458647
#   Num changes:         2
#   Design Depth:        39
#   Design Size (|D|):   359
#   Open set size:       182
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       44085.053
#   Best Cost (y):       160398246.9447
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.793
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6263→ cube 0.8899
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.551→ cube 0.5822
#   Efficiency z (srs):  1.982 → 0.514 → 2.4165
#   Efficiency y (srs):  1.095 → 0.487 → 1.2397
#   Alpha:               0.7903220766109256
#   Num changes:         2
#   Design Depth:        39
#   Design Size (|D|):   359
#   Open set size:       190
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       42356.057
#   Best Cost (y):       154899702.2489
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      18.084
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6518→ cube 0.9262
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5706→ cube 0.6029
#   Efficiency z (srs):  1.982 → 0.514 → 2.5151
#   Efficiency y (srs):  1.095 → 0.487 → 1.2837
#   Alpha:               0.8475109713316293
#   Num changes:         1
#   Design Depth:        59
#   Design Size (|D|):   399
#   Open set size:       274
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       40142.42
#   Best Cost (y):       148830057.3063
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      17.204
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.6878→ cube 0.9773
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5939→ cube 0.6275
#   Efficiency z (srs):  1.982 → 0.514 → 2.6538
#   Efficiency y (srs):  1.095 → 0.487 → 1.336
#   Alpha:               0.8886371946052932
#   Num changes:         2
#   Design Depth:        98
#   Design Size (|D|):   477
#   Open set size:       452
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       38502.669
#   Best Cost (y):       147963975.3072
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.542
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7171→ cube 1.0189
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.5973→ cube 0.6312
#   Efficiency z (srs):  1.982 → 0.514 → 2.7669
#   Efficiency y (srs):  1.095 → 0.487 → 1.3438
#   Alpha:               0.8524405814100815
#   Num changes:         2
#   Design Depth:        125
#   Design Size (|D|):   531
#   Open set size:       632
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       37586.073
#   Best Cost (y):       145287944.667
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.16
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7346→ cube 1.0437
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6083→ cube 0.6428
#   Efficiency z (srs):  1.982 → 0.514 → 2.8343
#   Efficiency y (srs):  1.095 → 0.487 → 1.3686
#   Alpha:               0.7107476329313661
#   Num changes:         1
#   Design Depth:        154
#   Design Size (|D|):   589
#   Open set size:       811
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       37545.586
#   Best Cost (y):       145177750.2926
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      16.15
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7353→ cube 1.0449
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6088→ cube 0.6433
#   Efficiency z (srs):  1.982 → 0.514 → 2.8374
#   Efficiency y (srs):  1.095 → 0.487 → 1.3696
#   Alpha:               0.8412876817642052
#   Num changes:         1
#   Design Depth:        154
#   Design Size (|D|):   589
#   Open set size:       815
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35906.554
#   Best Cost (y):       144514247.0276
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.523
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7689→ cube 1.0926
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6116→ cube 0.6462
#   Efficiency z (srs):  1.982 → 0.514 → 2.9669
#   Efficiency y (srs):  1.095 → 0.487 → 1.3759
#   Alpha:               0.7754546413599567
#   Num changes:         1
#   Design Depth:        172
#   Design Size (|D|):   625
#   Open set size:       906
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35896.57
#   Best Cost (y):       145851485.4228
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.522
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7691→ cube 1.0929
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.606→ cube 0.6403
#   Efficiency z (srs):  1.982 → 0.514 → 2.9677
#   Efficiency y (srs):  1.095 → 0.487 → 1.3633
#   Alpha:               0.775080051143381
#   Num changes:         3
#   Design Depth:        174
#   Design Size (|D|):   629
#   Open set size:       909
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35323.56
#   Best Cost (y):       143433733.753
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.282
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7816→ cube 1.1106
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6162→ cube 0.6511
#   Efficiency z (srs):  1.982 → 0.514 → 3.0159
#   Efficiency y (srs):  1.095 → 0.487 → 1.3863
#   Alpha:               0.7708811833423191
#   Num changes:         3
#   Design Depth:        193
#   Design Size (|D|):   667
#   Open set size:       992
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34956.982
#   Best Cost (y):       142687344.4395
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.132
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7898→ cube 1.1222
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6194→ cube 0.6545
#   Efficiency z (srs):  1.982 → 0.514 → 3.0475
#   Efficiency y (srs):  1.095 → 0.487 → 1.3935
#   Alpha:               0.8395392631330496
#   Num changes:         2
#   Design Depth:        224
#   Design Size (|D|):   729
#   Open set size:       1171
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34939.646
#   Best Cost (y):       142195199.3148
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.13
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7902→ cube 1.1228
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6216→ cube 0.6568
#   Efficiency z (srs):  1.982 → 0.514 → 3.049
#   Efficiency y (srs):  1.095 → 0.487 → 1.3984
#   Alpha:               0.8389174236100281
#   Num changes:         2
#   Design Depth:        224
#   Design Size (|D|):   729
#   Open set size:       1172
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34899.292
#   Best Cost (y):       142187112.065
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.105
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7911→ cube 1.1241
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6216→ cube 0.6568
#   Efficiency z (srs):  1.982 → 0.514 → 3.0525
#   Efficiency y (srs):  1.095 → 0.487 → 1.3984
#   Alpha:               0.7475669390719485
#   Num changes:         3
#   Design Depth:        225
#   Design Size (|D|):   731
#   Open set size:       1176
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34891.011
#   Best Cost (y):       141932175.2079
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.104
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.7913→ cube 1.1244
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6227→ cube 0.658
#   Efficiency z (srs):  1.982 → 0.514 → 3.0533
#   Efficiency y (srs):  1.095 → 0.487 → 1.401
#   Alpha:               0.709109442850449
#   Num changes:         2
#   Design Depth:        224
#   Design Size (|D|):   729
#   Open set size:       1177
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34236.71
#   Best Cost (y):       138301733.526
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.803
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8064→ cube 1.1458
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6391→ cube 0.6753
#   Efficiency z (srs):  1.982 → 0.514 → 3.1116
#   Efficiency y (srs):  1.095 → 0.487 → 1.4377
#   Alpha:               0.7660338223273566
#   Num changes:         3
#   Design Depth:        244
#   Design Size (|D|):   769
#   Open set size:       1263
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33724.492
#   Best Cost (y):       138382271.4403
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.587
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8187→ cube 1.1632
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6387→ cube 0.6749
#   Efficiency z (srs):  1.982 → 0.514 → 3.1589
#   Efficiency y (srs):  1.095 → 0.487 → 1.4369
#   Alpha:               0.8591044197114286
#   Num changes:         1
#   Design Depth:        264
#   Design Size (|D|):   809
#   Open set size:       1354
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33719.172
#   Best Cost (y):       138130101.3736
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.584
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8188→ cube 1.1634
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6399→ cube 0.6761
#   Efficiency z (srs):  1.982 → 0.514 → 3.1594
#   Efficiency y (srs):  1.095 → 0.487 → 1.4395
#   Alpha:               0.8303208778006581
#   Num changes:         1
#   Design Depth:        264
#   Design Size (|D|):   809
#   Open set size:       1355
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33604.778
#   Best Cost (y):       137825007.0435
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.531
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8216→ cube 1.1674
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6413→ cube 0.6776
#   Efficiency z (srs):  1.982 → 0.514 → 3.1701
#   Efficiency y (srs):  1.095 → 0.487 → 1.4427
#   Alpha:               0.7834500503432795
#   Num changes:         1
#   Design Depth:        276
#   Design Size (|D|):   833
#   Open set size:       1445
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33513.158
#   Best Cost (y):       137820871.8138
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.499
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8238→ cube 1.1706
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6413→ cube 0.6776
#   Efficiency z (srs):  1.982 → 0.514 → 3.1788
#   Efficiency y (srs):  1.095 → 0.487 → 1.4427
#   Alpha:               0.7648920109326148
#   Num changes:         3
#   Design Depth:        278
#   Design Size (|D|):   837
#   Open set size:       1448
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       33509.915
#   Best Cost (y):       137862010.4852
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      14.49
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8239→ cube 1.1707
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6411→ cube 0.6774
#   Efficiency z (srs):  1.982 → 0.514 → 3.1791
#   Efficiency y (srs):  1.095 → 0.487 → 1.4423
#   Alpha:               0.8746853748349558
#   Num changes:         2
#   Design Depth:        277
#   Design Size (|D|):   835
#   Open set size:       1450
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       32199.942
#   Best Cost (y):       136584900.5856
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.971
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8574→ cube 1.2183
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6471→ cube 0.6838
#   Efficiency z (srs):  1.982 → 0.514 → 3.3084
#   Efficiency y (srs):  1.095 → 0.487 → 1.4558
#   Alpha:               0.7715094191536135
#   Num changes:         1
#   Design Depth:        313
#   Design Size (|D|):   907
#   Open set size:       1623
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31942.325
#   Best Cost (y):       135704200.8727
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.866
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.8643→ cube 1.2281
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6513→ cube 0.6882
#   Efficiency z (srs):  1.982 → 0.514 → 3.3351
#   Efficiency y (srs):  1.095 → 0.487 → 1.4652
#   Alpha:               0.8381222193966669
#   Num changes:         1
#   Design Depth:        329
#   Design Size (|D|):   939
#   Open set size:       1717
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31916.434
#   Best Cost (y):       135703575.0368
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.839
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.865→ cube 1.2291
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6513→ cube 0.6882
#   Efficiency z (srs):  1.982 → 0.514 → 3.3378
#   Efficiency y (srs):  1.095 → 0.487 → 1.4653
#   Alpha:               0.7814913998415058
#   Num changes:         2
#   Design Depth:        345
#   Design Size (|D|):   971
#   Open set size:       1809
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       31338.391
#   Best Cost (y):       135895044.6771
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.595
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.881→ cube 1.2518
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6504→ cube 0.6872
#   Efficiency z (srs):  1.982 → 0.514 → 3.3994
#   Efficiency y (srs):  1.095 → 0.487 → 1.4632
#   Alpha:               0.7456971898633133
#   Num changes:         3
#   Design Depth:        364
#   Design Size (|D|):   1009
#   Open set size:       1895
#
# Progress: 5.5%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30647.181
#   Best Cost (y):       136001820.1734
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.326
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9009→ cube 1.28
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6499→ cube 0.6867
#   Efficiency z (srs):  1.982 → 0.514 → 3.4761
#   Efficiency y (srs):  1.095 → 0.487 → 1.462
#   Alpha:               0.8494336973085236
#   Num changes:         1
#   Design Depth:        374
#   Design Size (|D|):   1029
#   Open set size:       1987
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       30319.957
#   Best Cost (y):       134635768.6842
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.189
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9106→ cube 1.2939
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6565→ cube 0.6937
#   Efficiency z (srs):  1.982 → 0.514 → 3.5136
#   Efficiency y (srs):  1.095 → 0.487 → 1.4769
#   Alpha:               0.8762236957388378
#   Num changes:         3
#   Design Depth:        394
#   Design Size (|D|):   1069
#   Open set size:       2072
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29863.259
#   Best Cost (y):       133532373.8049
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      13.008
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9245→ cube 1.3136
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6619→ cube 0.6994
#   Efficiency z (srs):  1.982 → 0.514 → 3.5673
#   Efficiency y (srs):  1.095 → 0.487 → 1.4891
#   Alpha:               0.8458712391430498
#   Num changes:         2
#   Design Depth:        407
#   Design Size (|D|):   1095
#   Open set size:       2161
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29025.329
#   Best Cost (y):       132793553.6131
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.677
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9512→ cube 1.3516
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6656→ cube 0.7033
#   Efficiency z (srs):  1.982 → 0.514 → 3.6703
#   Efficiency y (srs):  1.095 → 0.487 → 1.4974
#   Alpha:               0.7299000945102199
#   Num changes:         1
#   Design Depth:        451
#   Design Size (|D|):   1183
#   Open set size:       2525
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       29020.706
#   Best Cost (y):       132765927.8038
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.675
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9514→ cube 1.3518
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6657→ cube 0.7034
#   Efficiency z (srs):  1.982 → 0.514 → 3.6709
#   Efficiency y (srs):  1.095 → 0.487 → 1.4977
#   Alpha:               0.7319580431169165
#   Num changes:         1
#   Design Depth:        451
#   Design Size (|D|):   1183
#   Open set size:       2528
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28740.034
#   Best Cost (y):       131584131.1556
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.563
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9606→ cube 1.365
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6717→ cube 0.7097
#   Efficiency z (srs):  1.982 → 0.514 → 3.7067
#   Efficiency y (srs):  1.095 → 0.487 → 1.5111
#   Alpha:               0.7940066225356952
#   Num changes:         1
#   Design Depth:        470
#   Design Size (|D|):   1221
#   Open set size:       2615
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28719.464
#   Best Cost (y):       131629126.7448
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.554
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9613→ cube 1.366
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6715→ cube 0.7095
#   Efficiency z (srs):  1.982 → 0.514 → 3.7094
#   Efficiency y (srs):  1.095 → 0.487 → 1.5106
#   Alpha:               0.8037075860420435
#   Num changes:         3
#   Design Depth:        472
#   Design Size (|D|):   1225
#   Open set size:       2616
#
# Progress: 7.5%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       28288.824
#   Best Cost (y):       130170632.1256
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.374
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.976→ cube 1.3868
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.679→ cube 0.7175
#   Efficiency z (srs):  1.982 → 0.514 → 3.7659
#   Efficiency y (srs):  1.095 → 0.487 → 1.5275
#   Alpha:               0.7167096607083515
#   Num changes:         1
#   Design Depth:        490
#   Design Size (|D|):   1261
#   Open set size:       2701
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27624.383
#   Best Cost (y):       128675469.0685
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.102
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 0.9994→ cube 1.4201
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6869→ cube 0.7258
#   Efficiency z (srs):  1.982 → 0.514 → 3.8564
#   Efficiency y (srs):  1.095 → 0.487 → 1.5453
#   Alpha:               0.8933251309230531
#   Num changes:         1
#   Design Depth:        526
#   Design Size (|D|):   1333
#   Open set size:       2884
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27589.76
#   Best Cost (y):       128807688.7393
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      12.09
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0007→ cube 1.4219
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6862→ cube 0.725
#   Efficiency z (srs):  1.982 → 0.514 → 3.8613
#   Efficiency y (srs):  1.095 → 0.487 → 1.5437
#   Alpha:               0.8960628217906803
#   Num changes:         1
#   Design Depth:        526
#   Design Size (|D|):   1333
#   Open set size:       2885
#
# Progress: 8.5%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27158.582
#   Best Cost (y):       127776056.7875
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.916
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0166→ cube 1.4445
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6917→ cube 0.7309
#   Efficiency z (srs):  1.982 → 0.514 → 3.9226
#   Efficiency y (srs):  1.095 → 0.487 → 1.5562
#   Alpha:               0.8779943442303046
#   Num changes:         1
#   Design Depth:        557
#   Design Size (|D|):   1395
#   Open set size:       3062
#
#
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       27118.608
#   Best Cost (y):       127672387.3105
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.898
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0181→ cube 1.4466
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.6923→ cube 0.7315
#   Efficiency z (srs):  1.982 → 0.514 → 3.9284
#   Efficiency y (srs):  1.095 → 0.487 → 1.5574
#   Alpha:               0.7148286756631421
#   Num changes:         3
#   Design Depth:        559
#   Design Size (|D|):   1399
#   Open set size:       3067
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26494.343
#   Best Cost (y):       126047385.0293
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.64
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0421→ cube 1.4807
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7012→ cube 0.7409
#   Efficiency z (srs):  1.982 → 0.514 → 4.0209
#   Efficiency y (srs):  1.095 → 0.487 → 1.5775
#   Alpha:               0.7648876426417688
#   Num changes:         3
#   Design Depth:        596
#   Design Size (|D|):   1473
#   Open set size:       3248
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       26166.759
#   Best Cost (y):       126160249.54
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.501
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0551→ cube 1.4992
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7006→ cube 0.7403
#   Efficiency z (srs):  1.982 → 0.514 → 4.0713
#   Efficiency y (srs):  1.095 → 0.487 → 1.5761
#   Alpha:               0.823097451879006
#   Num changes:         1
#   Design Depth:        639
#   Design Size (|D|):   1559
#   Open set size:       3601
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25909.154
#   Best Cost (y):       125492140.7695
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.389
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0656→ cube 1.5141
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7043→ cube 0.7442
#   Efficiency z (srs):  1.982 → 0.514 → 4.1117
#   Efficiency y (srs):  1.095 → 0.487 → 1.5845
#   Alpha:               0.7505322618395306
#   Num changes:         1
#   Design Depth:        658
#   Design Size (|D|):   1597
#   Open set size:       3691
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25894.989
#   Best Cost (y):       125136233.7167
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.385
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.0662→ cube 1.515
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7063→ cube 0.7463
#   Efficiency z (srs):  1.982 → 0.514 → 4.114
#   Efficiency y (srs):  1.095 → 0.487 → 1.589
#   Alpha:               0.8924179660095781
#   Num changes:         3
#   Design Depth:        660
#   Design Size (|D|):   1601
#   Open set size:       3692
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       25874.226
#   Best Cost (y):       125550899.9022
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      11.38
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.067→ cube 1.5162
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.704→ cube 0.7439
#   Efficiency z (srs):  1.982 → 0.514 → 4.1173
#   Efficiency y (srs):  1.095 → 0.487 → 1.5837
#   Alpha:               0.8653934794187566
#   Num changes:         3
#   Design Depth:        660
#   Design Size (|D|):   1601
#   Open set size:       3694
#
# Progress: 11.5%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       24648.63
#   Best Cost (y):       122921073.4129
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.892
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1201→ cube 1.5916
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.719→ cube 0.7598
#   Efficiency z (srs):  1.982 → 0.514 → 4.322
#   Efficiency y (srs):  1.095 → 0.487 → 1.6176
#   Alpha:               0.7512160532030523
#   Num changes:         1
#   Design Depth:        747
#   Design Size (|D|):   1775
#   Open set size:       4149
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       24580.747
#   Best Cost (y):       122466726.4633
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.862
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1232→ cube 1.596
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7217→ cube 0.7626
#   Efficiency z (srs):  1.982 → 0.514 → 4.334
#   Efficiency y (srs):  1.095 → 0.487 → 1.6236
#   Alpha:               0.7977313559511847
#   Num changes:         1
#   Design Depth:        769
#   Design Size (|D|):   1819
#   Open set size:       4328
#
#
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       24555.103
#   Best Cost (y):       122682795.6943
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.855
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1244→ cube 1.5976
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7204→ cube 0.7612
#   Efficiency z (srs):  1.982 → 0.514 → 4.3385
#   Efficiency y (srs):  1.095 → 0.487 → 1.6208
#   Alpha:               0.7413294784422275
#   Num changes:         1
#   Design Depth:        769
#   Design Size (|D|):   1819
#   Open set size:       4330
#
# Progress: 12.8%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       24228.97
#   Best Cost (y):       121882916.9581
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.728
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1395→ cube 1.6191
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7252→ cube 0.7662
#   Efficiency z (srs):  1.982 → 0.514 → 4.3969
#   Efficiency y (srs):  1.095 → 0.487 → 1.6314
#   Alpha:               0.8572064030203961
#   Num changes:         2
#   Design Depth:        816
#   Design Size (|D|):   1913
#   Open set size:       4593
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       24144.23
#   Best Cost (y):       121279328.0531
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.694
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1435→ cube 1.6248
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7288→ cube 0.7701
#   Efficiency z (srs):  1.982 → 0.514 → 4.4123
#   Efficiency y (srs):  1.095 → 0.487 → 1.6395
#   Alpha:               0.8544559551587125
#   Num changes:         3
#   Design Depth:        836
#   Design Size (|D|):   1953
#   Open set size:       4689
#
# Progress: 13.2%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23978.528
#   Best Cost (y):       120497973.1457
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.63
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1514→ cube 1.636
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7335→ cube 0.775
#   Efficiency z (srs):  1.982 → 0.514 → 4.4428
#   Efficiency y (srs):  1.095 → 0.487 → 1.6502
#   Alpha:               0.7699110616640236
#   Num changes:         1
#   Design Depth:        858
#   Design Size (|D|):   1997
#   Open set size:       4776
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23976.578
#   Best Cost (y):       120456942.7756
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.629
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1515→ cube 1.6362
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7337→ cube 0.7753
#   Efficiency z (srs):  1.982 → 0.514 → 4.4432
#   Efficiency y (srs):  1.095 → 0.487 → 1.6507
#   Alpha:               0.7050832748844563
#   Num changes:         1
#   Design Depth:        858
#   Design Size (|D|):   1997
#   Open set size:       4780
#
# Progress: 13.5%
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23916.022
#   Best Cost (y):       120365878.3556
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.601
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1544→ cube 1.6403
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7343→ cube 0.7759
#   Efficiency z (srs):  1.982 → 0.514 → 4.4544
#   Efficiency y (srs):  1.095 → 0.487 → 1.652
#   Alpha:               0.7951472828182526
#   Num changes:         1
#   Design Depth:        866
#   Design Size (|D|):   2013
#   Open set size:       4866
#
#
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23907.385
#   Best Cost (y):       120324454.2454
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.598
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1548→ cube 1.6409
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7345→ cube 0.7762
#   Efficiency z (srs):  1.982 → 0.514 → 4.456
#   Efficiency y (srs):  1.095 → 0.487 → 1.6525
#   Alpha:               0.7473558868327995
#   Num changes:         1
#   Design Depth:        866
#   Design Size (|D|):   2013
#   Open set size:       4867
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23861.181
#   Best Cost (y):       120151020.554
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.581
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1571→ cube 1.6441
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7356→ cube 0.7773
#   Efficiency z (srs):  1.982 → 0.514 → 4.4646
#   Efficiency y (srs):  1.095 → 0.487 → 1.6549
#   Alpha:               0.7481647961845518
#   Num changes:         2
#   Design Depth:        895
#   Design Size (|D|):   2071
#   Open set size:       5041
#
# Progress: 14.2%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23853.42
#   Best Cost (y):       120016440.726
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.577
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1574→ cube 1.6446
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7364→ cube 0.7782
#   Efficiency z (srs):  1.982 → 0.514 → 4.4661
#   Efficiency y (srs):  1.095 → 0.487 → 1.6568
#   Alpha:               0.8144958792369611
#   Num changes:         1
#   Design Depth:        901
#   Design Size (|D|):   2083
#   Open set size:       5131
#
#
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23844.438
#   Best Cost (y):       120104193.5565
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.571
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1579→ cube 1.6452
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7359→ cube 0.7776
#   Efficiency z (srs):  1.982 → 0.514 → 4.4678
#   Efficiency y (srs):  1.095 → 0.487 → 1.6556
#   Alpha:               0.7530650892928086
#   Num changes:         3
#   Design Depth:        903
#   Design Size (|D|):   2087
#   Open set size:       5139
#
# Progress: 14.8%
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23454.672
#   Best Cost (y):       117874063.6242
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.412
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1771→ cube 1.6726
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7498→ cube 0.7923
#   Efficiency z (srs):  1.982 → 0.514 → 4.542
#   Efficiency y (srs):  1.095 → 0.487 → 1.6869
#   Alpha:               0.810796843265714
#   Num changes:         2
#   Design Depth:        938
#   Design Size (|D|):   2157
#   Open set size:       5318
#
#
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23437.112
#   Best Cost (y):       117950456.1852
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.405
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.178→ cube 1.6738
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7493→ cube 0.7918
#   Efficiency z (srs):  1.982 → 0.514 → 4.5454
#   Efficiency y (srs):  1.095 → 0.487 → 1.6858
#   Alpha:               0.7508722838319384
#   Num changes:         2
#   Design Depth:        938
#   Design Size (|D|):   2157
#   Open set size:       5319
#
# Progress: 15.0%
# === Best Solution Updated at Iteration 600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23434.098
#   Best Cost (y):       117986055.5375
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.401
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1782→ cube 1.674
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7491→ cube 0.7915
#   Efficiency z (srs):  1.982 → 0.514 → 4.546
#   Efficiency y (srs):  1.095 → 0.487 → 1.6853
#   Alpha:               0.8399895413034775
#   Num changes:         3
#   Design Depth:        947
#   Design Size (|D|):   2175
#   Open set size:       5402
#
# Progress: 15.5%
# === Best Solution Updated at Iteration 620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       23036.716
#   Best Cost (y):       117583763.5375
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.239
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.1985→ cube 1.7029
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7517→ cube 0.7943
#   Efficiency z (srs):  1.982 → 0.514 → 4.6244
#   Efficiency y (srs):  1.095 → 0.487 → 1.6911
#   Alpha:               0.8720416905791754
#   Num changes:         1
#   Design Depth:        977
#   Design Size (|D|):   2235
#   Open set size:       5582
#
# Progress: 15.8%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       22884.738
#   Best Cost (y):       117684419.8764
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.186
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.2064→ cube 1.7142
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.751→ cube 0.7936
#   Efficiency z (srs):  1.982 → 0.514 → 4.6551
#   Efficiency y (srs):  1.095 → 0.487 → 1.6896
#   Alpha:               0.7099306382109116
#   Num changes:         2
#   Design Depth:        996
#   Design Size (|D|):   2273
#   Open set size:       5673
#
# Progress: 16.0%
# === Best Solution Updated at Iteration 640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       22732.862
#   Best Cost (y):       117537305.9351
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.127
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.2145→ cube 1.7257
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.752→ cube 0.7946
#   Efficiency z (srs):  1.982 → 0.514 → 4.6862
#   Efficiency y (srs):  1.095 → 0.487 → 1.6917
#   Alpha:               0.882874874702966
#   Num changes:         2
#   Design Depth:        1012
#   Design Size (|D|):   2305
#   Open set size:       5764
#
#
# === Best Solution Updated at Iteration 640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       22735.615
#   Best Cost (y):       117547372.0566
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.124
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.2143→ cube 1.7255
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7519→ cube 0.7945
#   Efficiency z (srs):  1.982 → 0.514 → 4.6857
#   Efficiency y (srs):  1.095 → 0.487 → 1.6916
#   Alpha:               0.7932089235890394
#   Num changes:         3
#   Design Depth:        1013
#   Design Size (|D|):   2307
#   Open set size:       5769
#
# Progress: 16.2%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       22632.31
#   Best Cost (y):       117032007.1305
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.076
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.2199→ cube 1.7334
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7552→ cube 0.798
#   Efficiency z (srs):  1.982 → 0.514 → 4.7071
#   Efficiency y (srs):  1.095 → 0.487 → 1.699
#   Alpha:               0.8629915679480222
#   Num changes:         1
#   Design Depth:        1025
#   Design Size (|D|):   2331
#   Open set size:       5858
#
# Progress: 16.8%
# === Best Solution Updated at Iteration 670 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       22564.02
#   Best Cost (y):       116920378.537
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      10.048
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.2236→ cube 1.7386
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.7559→ cube 0.7988
#   Efficiency z (srs):  1.982 → 0.514 → 4.7213
# ...
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14700.066
#   Best Cost (y):       99272493.0583
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.765
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8781→ cube 2.6687
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8903→ cube 0.9408
#   Efficiency z (srs):  1.982 → 0.514 → 7.247
#   Efficiency y (srs):  1.095 → 0.487 → 2.003
#   Alpha:               0.7580139279928656
#   Num changes:         3
#   Design Depth:        4943
#   Design Size (|D|):   10167
#   Open set size:       33841
#
# Progress: 94.5%
# === Best Solution Updated at Iteration 3780 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14684.024
#   Best Cost (y):       99190117.0696
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.758
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8802→ cube 2.6716
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8911→ cube 0.9415
#   Efficiency z (srs):  1.982 → 0.514 → 7.2549
#   Efficiency y (srs):  1.095 → 0.487 → 2.0046
#   Alpha:               0.8225155104763542
#   Num changes:         2
#   Design Depth:        4965
#   Design Size (|D|):   10211
#   Open set size:       34030
#
# Progress: 94.8%
# === Best Solution Updated at Iteration 3790 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14665.342
#   Best Cost (y):       99199596.2461
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.751
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8826→ cube 2.675
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.891→ cube 0.9415
#   Efficiency z (srs):  1.982 → 0.514 → 7.2642
#   Efficiency y (srs):  1.095 → 0.487 → 2.0044
#   Alpha:               0.7014919569202586
#   Num changes:         2
#   Design Depth:        4986
#   Design Size (|D|):   10253
#   Open set size:       34117
#
#
# === Best Solution Updated at Iteration 3790 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14664.146
#   Best Cost (y):       99183387.4229
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.75
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8827→ cube 2.6752
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8911→ cube 0.9416
#   Efficiency z (srs):  1.982 → 0.514 → 7.2648
#   Efficiency y (srs):  1.095 → 0.487 → 2.0048
#   Alpha:               0.7294344519220265
#   Num changes:         2
#   Design Depth:        4986
#   Design Size (|D|):   10253
#   Open set size:       34118
#
# Progress: 95.0%
# === Best Solution Updated at Iteration 3800 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14656.37
#   Best Cost (y):       99236158.3644
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.747
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8837→ cube 2.6766
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8906→ cube 0.9411
#   Efficiency z (srs):  1.982 → 0.514 → 7.2686
#   Efficiency y (srs):  1.095 → 0.487 → 2.0037
#   Alpha:               0.7733389787306227
#   Num changes:         3
#   Design Depth:        5006
#   Design Size (|D|):   10293
#   Open set size:       34209
#
# Progress: 95.2%
# === Best Solution Updated at Iteration 3810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14647.386
#   Best Cost (y):       99175882.6481
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.742
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8849→ cube 2.6783
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8912→ cube 0.9417
#   Efficiency z (srs):  1.982 → 0.514 → 7.2731
#   Efficiency y (srs):  1.095 → 0.487 → 2.0049
#   Alpha:               0.8778584532962279
#   Num changes:         2
#   Design Depth:        5020
#   Design Size (|D|):   10321
#   Open set size:       34293
#
# Progress: 95.5%
# === Best Solution Updated at Iteration 3820 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14631.373
#   Best Cost (y):       99109601.0184
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.735
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.887→ cube 2.6812
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8918→ cube 0.9423
#   Efficiency z (srs):  1.982 → 0.514 → 7.2811
#   Efficiency y (srs):  1.095 → 0.487 → 2.0063
#   Alpha:               0.8975407580286653
#   Num changes:         1
#   Design Depth:        5034
#   Design Size (|D|):   10349
#   Open set size:       34387
#
#
# === Best Solution Updated at Iteration 3820 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14630.547
#   Best Cost (y):       99119802.2728
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.735
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8871→ cube 2.6814
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8917→ cube 0.9422
#   Efficiency z (srs):  1.982 → 0.514 → 7.2815
#   Efficiency y (srs):  1.095 → 0.487 → 2.0061
#   Alpha:               0.7140776269284266
#   Num changes:         2
#   Design Depth:        5035
#   Design Size (|D|):   10351
#   Open set size:       34388
#
# Progress: 95.8%
# === Best Solution Updated at Iteration 3830 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14611.192
#   Best Cost (y):       99002524.1004
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.727
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8896→ cube 2.6849
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8927→ cube 0.9433
#   Efficiency z (srs):  1.982 → 0.514 → 7.2911
#   Efficiency y (srs):  1.095 → 0.487 → 2.0084
#   Alpha:               0.7449185918550981
#   Num changes:         1
#   Design Depth:        5051
#   Design Size (|D|):   10383
#   Open set size:       34472
#
#
# === Best Solution Updated at Iteration 3830 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14611.355
#   Best Cost (y):       99002154.4609
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.726
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8896→ cube 2.6849
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8928→ cube 0.9433
#   Efficiency z (srs):  1.982 → 0.514 → 7.291
#   Efficiency y (srs):  1.095 → 0.487 → 2.0084
#   Alpha:               0.7068069047455384
#   Num changes:         1
#   Design Depth:        5051
#   Design Size (|D|):   10383
#   Open set size:       34474
#
# Progress: 96.0%
# === Best Solution Updated at Iteration 3840 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14585.451
#   Best Cost (y):       98927092.5206
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.714
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8929→ cube 2.6897
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8934→ cube 0.944
#   Efficiency z (srs):  1.982 → 0.514 → 7.304
#   Efficiency y (srs):  1.095 → 0.487 → 2.01
#   Alpha:               0.7506404894987323
#   Num changes:         2
#   Design Depth:        5068
#   Design Size (|D|):   10417
#   Open set size:       34563
#
# Progress: 96.2%
# === Best Solution Updated at Iteration 3850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14583.457
#   Best Cost (y):       98906475.5524
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.713
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8932→ cube 2.69
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8936→ cube 0.9442
#   Efficiency z (srs):  1.982 → 0.514 → 7.305
#   Efficiency y (srs):  1.095 → 0.487 → 2.0104
#   Alpha:               0.7593413610877326
#   Num changes:         3
#   Design Depth:        5076
#   Design Size (|D|):   10433
#   Open set size:       34655
#
#
# === Best Solution Updated at Iteration 3850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14580.437
#   Best Cost (y):       98898230.5487
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.712
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8936→ cube 2.6906
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8937→ cube 0.9443
#   Efficiency z (srs):  1.982 → 0.514 → 7.3065
#   Efficiency y (srs):  1.095 → 0.487 → 2.0106
#   Alpha:               0.898778241010301
#   Num changes:         2
#   Design Depth:        5075
#   Design Size (|D|):   10431
#   Open set size:       34656
#
#
# === Best Solution Updated at Iteration 3850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14574.395
#   Best Cost (y):       98904295.9471
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.71
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.8943→ cube 2.6917
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8936→ cube 0.9443
#   Efficiency z (srs):  1.982 → 0.514 → 7.3095
#   Efficiency y (srs):  1.095 → 0.487 → 2.0104
#   Alpha:               0.8217383098040256
#   Num changes:         3
#   Design Depth:        5076
#   Design Size (|D|):   10433
#   Open set size:       34657
#
# Progress: 97.0%
# === Best Solution Updated at Iteration 3880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14511.371
#   Best Cost (y):       98649089.4633
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.684
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9026→ cube 2.7034
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8959→ cube 0.9467
#   Efficiency z (srs):  1.982 → 0.514 → 7.3413
#   Efficiency y (srs):  1.095 → 0.487 → 2.0156
#   Alpha:               0.7710747149727727
#   Num changes:         2
#   Design Depth:        5126
#   Design Size (|D|):   10533
#   Open set size:       34923
#
# Progress: 98.2%
# === Best Solution Updated at Iteration 3930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14475.374
#   Best Cost (y):       98675612.7468
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.668
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9073→ cube 2.7101
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8957→ cube 0.9465
#   Efficiency z (srs):  1.982 → 0.514 → 7.3595
#   Efficiency y (srs):  1.095 → 0.487 → 2.0151
#   Alpha:               0.7003892742734898
#   Num changes:         3
#   Design Depth:        5181
#   Design Size (|D|):   10643
#   Open set size:       35378
#
# Progress: 98.8%
# === Best Solution Updated at Iteration 3950 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14467.276
#   Best Cost (y):       98496271.8313
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.665
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9084→ cube 2.7116
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8973→ cube 0.9482
#   Efficiency z (srs):  1.982 → 0.514 → 7.3636
#   Efficiency y (srs):  1.095 → 0.487 → 2.0188
#   Alpha:               0.8085732537059858
#   Num changes:         2
#   Design Depth:        5200
#   Design Size (|D|):   10681
#   Open set size:       35559
#
# Progress: 99.0%
# === Best Solution Updated at Iteration 3960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14455.136
#   Best Cost (y):       98351520.2845
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.659
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.91→ cube 2.7139
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8987→ cube 0.9496
#   Efficiency z (srs):  1.982 → 0.514 → 7.3698
#   Efficiency y (srs):  1.095 → 0.487 → 2.0217
#   Alpha:               0.8947660778025301
#   Num changes:         3
#   Design Depth:        5214
#   Design Size (|D|):   10709
#   Open set size:       35645
#
#
# === Best Solution Updated at Iteration 3960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14443.322
#   Best Cost (y):       98344614.9499
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.655
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9115→ cube 2.7161
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8987→ cube 0.9496
#   Efficiency z (srs):  1.982 → 0.514 → 7.3758
#   Efficiency y (srs):  1.095 → 0.487 → 2.0219
#   Alpha:               0.8940774229214896
#   Num changes:         2
#   Design Depth:        5213
#   Design Size (|D|):   10707
#   Open set size:       35648
#
# Progress: 99.2%
# === Best Solution Updated at Iteration 3970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14428.514
#   Best Cost (y):       98341422.0164
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.649
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9135→ cube 2.7189
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8987→ cube 0.9497
#   Efficiency z (srs):  1.982 → 0.514 → 7.3834
#   Efficiency y (srs):  1.095 → 0.487 → 2.0219
#   Alpha:               0.8276914490398096
#   Num changes:         1
#   Design Depth:        5226
#   Design Size (|D|):   10733
#   Open set size:       35732
#
#
# === Best Solution Updated at Iteration 3970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14428.51
#   Best Cost (y):       98343443.2125
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.649
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9135→ cube 2.7189
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8987→ cube 0.9496
#   Efficiency z (srs):  1.982 → 0.514 → 7.3834
#   Efficiency y (srs):  1.095 → 0.487 → 2.0219
#   Alpha:               0.8446677364977505
#   Num changes:         1
#   Design Depth:        5226
#   Design Size (|D|):   10733
#   Open set size:       35734
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       14419.399
#   Best Cost (y):       98362082.9492
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      6.645
#   Efficiency z (0→f):  0.514 → 0.514 → dsd 1.9147→ cube 2.7206
#   Efficiency y (0→f):  0.487 → 0.487 → dsd 0.8986→ cube 0.9495
#   Efficiency z (srs):  1.982 → 0.514 → 7.3881
#   Efficiency y (srs):  1.095 → 0.487 → 2.0215
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        5253
#   Design Size (|D|):   10787
#   Open set size:       36001
#
# Best criteria value: 6.645052943300091
# Iterations run: 4000
# Best criteria value: 6.645052943300091
# Iterations run: 4000

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
# Out:
# size of init design 281
# size of best design 10787
# 22.632928227085532
# 6.645052943300091
# /tmp/ipykernel_852886/1240027416.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# 1.0000000060000018
