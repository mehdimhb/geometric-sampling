# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 5

# %%
num_new_nodes          = 50

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.01779359
# [1] 621156846.5    332794.5

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 4533.8417 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0226 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0085 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.1130297
# Variance of HT estimator via DSD formula_z:  162900.1
# Variance of HT estimator via DSD formula:  272413389
# Here is the Vincent Efficiency y:
#   DSD_y:  1.19547
#   DSD_z: 2.04294
# Monte Carlo variance of HT estimator for y:
#   DSD:  272275770.55787
#   Cube: 290920025.40021
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.19608
#   Cube: 1.11942
# Monte Carlo mean of HT estimator for y:
#   DSD:  53161.52019
#   Cube: 53278.89515
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  175463.75804
#   Cube: 236720.78184
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  1.89666
#   Cube: 1.40585
# Monte Carlo mean of HT estimator for z:
#   DSD:  2503.37940
#   Cube: 2523.39653
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        1.41        2.04        1.91        2.14        2.28

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_5903/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639386
# [281] [5.] adsfa
# 4000 50 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 48.19it/s]
# Initial design 0: method = Original, efficiency z = 0.5762, y=0.9353
# New best at idx=0: method = Original, efficiency z = 0.5762 and efficiency y = 0.9353
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       282641.402
#   Best Cost (y):       289055620.129
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      117.123
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.5763→ cube 0.8375
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9424→ cube 1.0064
#   Efficiency z (srs):  1.173 → 0.576 → 1.1733
#   Efficiency y (srs):  2.125 → 0.935 → 2.1413
#   Alpha:               0.7639047056932852
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       16
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       282677.28
#   Best Cost (y):       289185634.259
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      117.107
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.5763→ cube 0.8374
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.942→ cube 1.006
#   Efficiency z (srs):  1.173 → 0.576 → 1.1731
#   Efficiency y (srs):  2.125 → 0.935 → 2.1403
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4
#   Design Size (|D|):   289
#   Open set size:       99
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       261686.148
#   Best Cost (y):       287384147.198
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      108.634
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6225→ cube 0.9046
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9479→ cube 1.0123
#   Efficiency z (srs):  1.173 → 0.576 → 1.2672
#   Efficiency y (srs):  2.125 → 0.935 → 2.1537
#   Alpha:               0.8378874664437366
#   Num changes:         1
#   Design Depth:        24
#   Design Size (|D|):   329
#   Open set size:       493
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       261614.489
#   Best Cost (y):       284815529.9067
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      108.623
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6227→ cube 0.9048
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9565→ cube 1.0214
#   Efficiency z (srs):  1.173 → 0.576 → 1.2676
#   Efficiency y (srs):  2.125 → 0.935 → 2.1731
#   Alpha:               0.7025465793769022
#   Num changes:         2
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       521
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       261588.555
#   Best Cost (y):       287438186.0416
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      108.59
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6227→ cube 0.9049
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9477→ cube 1.0121
#   Efficiency z (srs):  1.173 → 0.576 → 1.2677
#   Efficiency y (srs):  2.125 → 0.935 → 2.1533
#   Alpha:               0.8265322912857103
#   Num changes:         2
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       535
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       252213.492
#   Best Cost (y):       280509767.3923
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      104.743
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6459→ cube 0.9386
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9711→ cube 1.0371
#   Efficiency z (srs):  1.173 → 0.576 → 1.3148
#   Efficiency y (srs):  2.125 → 0.935 → 2.2065
#   Alpha:               0.7154320307942655
#   Num changes:         1
#   Design Depth:        44
#   Design Size (|D|):   369
#   Open set size:       981
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       251719.565
#   Best Cost (y):       281480952.7649
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      104.537
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6471→ cube 0.9404
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9678→ cube 1.0335
#   Efficiency z (srs):  1.173 → 0.576 → 1.3174
#   Efficiency y (srs):  2.125 → 0.935 → 2.1989
#   Alpha:               0.8775545254223527
#   Num changes:         2
#   Design Depth:        45
#   Design Size (|D|):   371
#   Open set size:       983
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       251236.089
#   Best Cost (y):       278835453.3409
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      104.373
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6484→ cube 0.9422
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.977→ cube 1.0433
#   Efficiency z (srs):  1.173 → 0.576 → 1.3199
#   Efficiency y (srs):  2.125 → 0.935 → 2.2198
#   Alpha:               0.857767432857232
#   Num changes:         2
#   Design Depth:        45
#   Design Size (|D|):   371
#   Open set size:       990
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       251037.12
#   Best Cost (y):       277653716.7049
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      104.294
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6489→ cube 0.943
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9811→ cube 1.0478
#   Efficiency z (srs):  1.173 → 0.576 → 1.321
#   Efficiency y (srs):  2.125 → 0.935 → 2.2292
#   Alpha:               0.7939819958268275
#   Num changes:         3
#   Design Depth:        46
#   Design Size (|D|):   373
#   Open set size:       1020
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       236374.158
#   Best Cost (y):       283337892.8009
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      98.319
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6892→ cube 1.0015
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9614→ cube 1.0268
#   Efficiency z (srs):  1.173 → 0.576 → 1.4029
#   Efficiency y (srs):  2.125 → 0.935 → 2.1845
#   Alpha:               0.7359576192946196
#   Num changes:         3
#   Design Depth:        69
#   Design Size (|D|):   419
#   Open set size:       1471
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       235493.514
#   Best Cost (y):       275613616.9656
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      97.883
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6917→ cube 1.0052
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9884→ cube 1.0555
#   Efficiency z (srs):  1.173 → 0.576 → 1.4081
#   Efficiency y (srs):  2.125 → 0.935 → 2.2457
#   Alpha:               0.884898539849234
#   Num changes:         2
#   Design Depth:        68
#   Design Size (|D|):   417
#   Open set size:       1474
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       234775.115
#   Best Cost (y):       278695104.5302
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      97.607
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6939→ cube 1.0083
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9775→ cube 1.0439
#   Efficiency z (srs):  1.173 → 0.576 → 1.4125
#   Efficiency y (srs):  2.125 → 0.935 → 2.2209
#   Alpha:               0.8250306991536402
#   Num changes:         2
#   Design Depth:        68
#   Design Size (|D|):   417
#   Open set size:       1485
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       229048.547
#   Best Cost (y):       269932544.6854
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      95.218
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7112→ cube 1.0335
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0092→ cube 1.0778
#   Efficiency z (srs):  1.173 → 0.576 → 1.4478
#   Efficiency y (srs):  2.125 → 0.935 → 2.293
#   Alpha:               0.7476891021221448
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       1981
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       228724.347
#   Best Cost (y):       275017486.5261
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      95.113
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7122→ cube 1.035
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9905→ cube 1.0578
#   Efficiency z (srs):  1.173 → 0.576 → 1.4498
#   Efficiency y (srs):  2.125 → 0.935 → 2.2506
#   Alpha:               0.7235016671640828
#   Num changes:         2
#   Design Depth:        86
#   Design Size (|D|):   453
#   Open set size:       1988
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       228759.207
#   Best Cost (y):       270597019.394
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      95.088
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7121→ cube 1.0348
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0067→ cube 1.0751
#   Efficiency z (srs):  1.173 → 0.576 → 1.4496
#   Efficiency y (srs):  2.125 → 0.935 → 2.2873
#   Alpha:               0.8352853801437197
#   Num changes:         2
#   Design Depth:        86
#   Design Size (|D|):   453
#   Open set size:       2009
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       227754.196
#   Best Cost (y):       269133713.3964
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      94.71
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7152→ cube 1.0394
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0122→ cube 1.0809
#   Efficiency z (srs):  1.173 → 0.576 → 1.456
#   Efficiency y (srs):  2.125 → 0.935 → 2.2998
#   Alpha:               0.7986665662852547
#   Num changes:         3
#   Design Depth:        87
#   Design Size (|D|):   455
#   Open set size:       2010
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       222949.565
#   Best Cost (y):       273827826.5955
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      92.842
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7307→ cube 1.0618
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9948→ cube 1.0624
#   Efficiency z (srs):  1.173 → 0.576 → 1.4874
#   Efficiency y (srs):  2.125 → 0.935 → 2.2603
#   Alpha:               0.8203402677314803
#   Num changes:         2
#   Design Depth:        110
#   Design Size (|D|):   501
#   Open set size:       15692
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       219996.802
#   Best Cost (y):       259932902.4581
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      91.517
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7405→ cube 1.076
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.048→ cube 1.1192
#   Efficiency z (srs):  1.173 → 0.576 → 1.5073
#   Efficiency y (srs):  2.125 → 0.935 → 2.3812
#   Alpha:               0.7487772468399527
#   Num changes:         1
#   Design Depth:        128
#   Design Size (|D|):   537
#   Open set size:       16183
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       219971.42
#   Best Cost (y):       256807820.527
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      91.471
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7406→ cube 1.0761
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0608→ cube 1.1328
#   Efficiency z (srs):  1.173 → 0.576 → 1.5075
#   Efficiency y (srs):  2.125 → 0.935 → 2.4102
#   Alpha:               0.8517680556815882
#   Num changes:         3
#   Design Depth:        130
#   Design Size (|D|):   541
#   Open set size:       16192
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       219915.843
#   Best Cost (y):       259112321.4567
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      91.429
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7407→ cube 1.0764
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0513→ cube 1.1228
#   Efficiency z (srs):  1.173 → 0.576 → 1.5079
#   Efficiency y (srs):  2.125 → 0.935 → 2.3887
#   Alpha:               0.8782822161105124
#   Num changes:         3
#   Design Depth:        130
#   Design Size (|D|):   541
#   Open set size:       16197
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       213971.846
#   Best Cost (y):       262467159.7034
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      89.063
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7613→ cube 1.1063
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0379→ cube 1.1084
#   Efficiency z (srs):  1.173 → 0.576 → 1.5498
#   Efficiency y (srs):  2.125 → 0.935 → 2.3582
#   Alpha:               0.7672561969253859
#   Num changes:         1
#   Design Depth:        159
#   Design Size (|D|):   599
#   Open set size:       17655
#
#
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       213933.869
#   Best Cost (y):       263827106.0449
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      89.034
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7615→ cube 1.1065
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0325→ cube 1.1027
#   Efficiency z (srs):  1.173 → 0.576 → 1.5501
#   Efficiency y (srs):  2.125 → 0.935 → 2.346
#   Alpha:               0.8591399879112976
#   Num changes:         2
#   Design Depth:        160
#   Design Size (|D|):   601
#   Open set size:       17656
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       212204.425
#   Best Cost (y):       262801468.5137
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      88.276
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7677→ cube 1.1155
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0366→ cube 1.107
#   Efficiency z (srs):  1.173 → 0.576 → 1.5627
#   Efficiency y (srs):  2.125 → 0.935 → 2.3552
#   Alpha:               0.826565691413077
#   Num changes:         2
#   Design Depth:        178
#   Design Size (|D|):   637
#   Open set size:       18132
#
#
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       211894.235
#   Best Cost (y):       262549090.5506
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      88.163
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7688→ cube 1.1172
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0376→ cube 1.1081
#   Efficiency z (srs):  1.173 → 0.576 → 1.565
#   Efficiency y (srs):  2.125 → 0.935 → 2.3574
#   Alpha:               0.7444697667921409
#   Num changes:         2
#   Design Depth:        178
#   Design Size (|D|):   637
#   Open set size:       18135
#
# Progress: 9.5%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       210775.603
#   Best Cost (y):       263113592.6925
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.75
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7729→ cube 1.1231
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0353→ cube 1.1057
#   Efficiency z (srs):  1.173 → 0.576 → 1.5733
#   Efficiency y (srs):  2.125 → 0.935 → 2.3524
#   Alpha:               0.8837626666406188
#   Num changes:         1
#   Design Depth:        192
#   Design Size (|D|):   665
#   Open set size:       18623
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       210717.465
#   Best Cost (y):       264375446.4887
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.748
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7731→ cube 1.1234
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0304→ cube 1.1004
#   Efficiency z (srs):  1.173 → 0.576 → 1.5737
#   Efficiency y (srs):  2.125 → 0.935 → 2.3412
#   Alpha:               0.8560352443449274
#   Num changes:         2
#   Design Depth:        193
#   Design Size (|D|):   667
#   Open set size:       18640
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       210729.191
#   Best Cost (y):       263048828.1219
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.741
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.773→ cube 1.1233
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0356→ cube 1.106
#   Efficiency z (srs):  1.173 → 0.576 → 1.5736
#   Efficiency y (srs):  2.125 → 0.935 → 2.353
#   Alpha:               0.8911820711587141
#   Num changes:         1
#   Design Depth:        192
#   Design Size (|D|):   665
#   Open set size:       18662
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       210720.77
#   Best Cost (y):       263042670.2455
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.729
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7731→ cube 1.1234
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0356→ cube 1.106
#   Efficiency z (srs):  1.173 → 0.576 → 1.5737
#   Efficiency y (srs):  2.125 → 0.935 → 2.353
#   Alpha:               0.756396544501144
#   Num changes:         1
#   Design Depth:        192
#   Design Size (|D|):   665
#   Open set size:       18669
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       209954.89
#   Best Cost (y):       268021271.9421
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.39
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7759→ cube 1.1275
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0164→ cube 1.0854
#   Efficiency z (srs):  1.173 → 0.576 → 1.5794
#   Efficiency y (srs):  2.125 → 0.935 → 2.3093
#   Alpha:               0.8650346078108158
#   Num changes:         1
#   Design Depth:        213
#   Design Size (|D|):   707
#   Open set size:       19601
#
#
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       209943.719
#   Best Cost (y):       267671370.1174
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.386
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7759→ cube 1.1275
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0177→ cube 1.0869
#   Efficiency z (srs):  1.173 → 0.576 → 1.5795
#   Efficiency y (srs):  2.125 → 0.935 → 2.3123
#   Alpha:               0.7726560837107928
#   Num changes:         1
#   Design Depth:        213
#   Design Size (|D|):   707
#   Open set size:       19629
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       208188.446
#   Best Cost (y):       268521781.1758
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      86.644
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7825→ cube 1.1371
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0145→ cube 1.0834
#   Efficiency z (srs):  1.173 → 0.576 → 1.5928
#   Efficiency y (srs):  2.125 → 0.935 → 2.305
#   Alpha:               0.7668970786738851
#   Num changes:         2
#   Design Depth:        226
#   Design Size (|D|):   733
#   Open set size:       20100
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       208178.264
#   Best Cost (y):       268409530.5719
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      86.637
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7825→ cube 1.1371
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0149→ cube 1.0839
#   Efficiency z (srs):  1.173 → 0.576 → 1.5929
#   Efficiency y (srs):  2.125 → 0.935 → 2.306
#   Alpha:               0.8225346349610843
#   Num changes:         2
#   Design Depth:        226
#   Design Size (|D|):   733
#   Open set size:       20107
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       207962.021
#   Best Cost (y):       268377387.8672
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      86.562
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7833→ cube 1.1383
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.015→ cube 1.084
#   Efficiency z (srs):  1.173 → 0.576 → 1.5946
#   Efficiency y (srs):  2.125 → 0.935 → 2.3063
#   Alpha:               0.7341568318180443
#   Num changes:         3
#   Design Depth:        227
#   Design Size (|D|):   735
#   Open set size:       20140
#
# Progress: 10.8%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       202386.526
#   Best Cost (y):       265827477.2217
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      84.272
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8049→ cube 1.1696
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0248→ cube 1.0944
#   Efficiency z (srs):  1.173 → 0.576 → 1.6385
#   Efficiency y (srs):  2.125 → 0.935 → 2.3284
#   Alpha:               0.8445272710239571
#   Num changes:         2
#   Design Depth:        245
#   Design Size (|D|):   771
#   Open set size:       21071
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       201734.852
#   Best Cost (y):       266038211.6292
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      84.035
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8075→ cube 1.1734
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.024→ cube 1.0935
#   Efficiency z (srs):  1.173 → 0.576 → 1.6438
#   Efficiency y (srs):  2.125 → 0.935 → 2.3265
#   Alpha:               0.807348595526916
#   Num changes:         1
#   Design Depth:        244
#   Design Size (|D|):   769
#   Open set size:       21073
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       201417.416
#   Best Cost (y):       265836618.1558
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      83.875
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8088→ cube 1.1753
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0247→ cube 1.0944
#   Efficiency z (srs):  1.173 → 0.576 → 1.6464
#   Efficiency y (srs):  2.125 → 0.935 → 2.3283
#   Alpha:               0.8132846444535429
#   Num changes:         2
#   Design Depth:        245
#   Design Size (|D|):   771
#   Open set size:       21077
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       194905.037
#   Best Cost (y):       265586667.7387
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      81.286
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8358→ cube 1.2145
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0257→ cube 1.0954
#   Efficiency z (srs):  1.173 → 0.576 → 1.7014
#   Efficiency y (srs):  2.125 → 0.935 → 2.3305
#   Alpha:               0.7490423964619369
#   Num changes:         1
#   Design Depth:        261
#   Design Size (|D|):   803
#   Open set size:       21563
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       194654.49
#   Best Cost (y):       264447589.9309
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      81.207
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8369→ cube 1.2161
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0301→ cube 1.1001
#   Efficiency z (srs):  1.173 → 0.576 → 1.7036
#   Efficiency y (srs):  2.125 → 0.935 → 2.3405
#   Alpha:               0.8369974779486109
#   Num changes:         2
#   Design Depth:        262
#   Design Size (|D|):   805
#   Open set size:       21571
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       194234.085
#   Best Cost (y):       264843790.7844
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      81.019
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8387→ cube 1.2187
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0286→ cube 1.0985
#   Efficiency z (srs):  1.173 → 0.576 → 1.7073
#   Efficiency y (srs):  2.125 → 0.935 → 2.337
#   Alpha:               0.781735224053677
#   Num changes:         2
#   Design Depth:        262
#   Design Size (|D|):   805
#   Open set size:       21580
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       194299.051
#   Best Cost (y):       265717711.7072
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      81.018
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8384→ cube 1.2183
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0252→ cube 1.0948
#   Efficiency z (srs):  1.173 → 0.576 → 1.7067
#   Efficiency y (srs):  2.125 → 0.935 → 2.3293
#   Alpha:               0.8459658760335105
#   Num changes:         3
#   Design Depth:        263
#   Design Size (|D|):   807
#   Open set size:       21592
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       194087.603
#   Best Cost (y):       264270259.7481
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      80.954
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8393→ cube 1.2197
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0308→ cube 1.1008
#   Efficiency z (srs):  1.173 → 0.576 → 1.7086
#   Efficiency y (srs):  2.125 → 0.935 → 2.3421
#   Alpha:               0.7723791038781342
#   Num changes:         3
#   Design Depth:        263
#   Design Size (|D|):   807
#   Open set size:       21593
#
# Progress: 11.2%
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       192723.539
#   Best Cost (y):       268367645.4455
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      80.456
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8453→ cube 1.2283
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0151→ cube 1.084
#   Efficiency z (srs):  1.173 → 0.576 → 1.7207
#   Efficiency y (srs):  2.125 → 0.935 → 2.3063
#   Alpha:               0.8629296708731242
#   Num changes:         3
#   Design Depth:        279
#   Design Size (|D|):   839
#   Open set size:       22058
#
# Progress: 11.8%
# === Best Solution Updated at Iteration 470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       191818.913
#   Best Cost (y):       271252500.5579
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      79.999
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8492→ cube 1.2341
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0043→ cube 1.0725
#   Efficiency z (srs):  1.173 → 0.576 → 1.7288
#   Efficiency y (srs):  2.125 → 0.935 → 2.2818
#   Alpha:               0.7147748452049179
#   Num changes:         1
#   Design Depth:        306
#   Design Size (|D|):   893
#   Open set size:       23062
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       190514.664
#   Best Cost (y):       268644787.4179
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      79.48
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8551→ cube 1.2425
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.014→ cube 1.0829
#   Efficiency z (srs):  1.173 → 0.576 → 1.7406
#   Efficiency y (srs):  2.125 → 0.935 → 2.304
#   Alpha:               0.7204346514967617
#   Num changes:         3
#   Design Depth:        326
#   Design Size (|D|):   933
#   Open set size:       23526
#
#
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       190432.355
#   Best Cost (y):       268505524.5131
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      79.468
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8554→ cube 1.2431
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0146→ cube 1.0835
#   Efficiency z (srs):  1.173 → 0.576 → 1.7414
#   Efficiency y (srs):  2.125 → 0.935 → 2.3052
#   Alpha:               0.7244603984588475
#   Num changes:         3
#   Design Depth:        326
#   Design Size (|D|):   933
#   Open set size:       23545
#
#
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       190469.248
#   Best Cost (y):       268907401.1088
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      79.467
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8553→ cube 1.2428
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.013→ cube 1.0819
#   Efficiency z (srs):  1.173 → 0.576 → 1.741
#   Efficiency y (srs):  2.125 → 0.935 → 2.3017
#   Alpha:               0.7984364753081701
#   Num changes:         3
#   Design Depth:        326
#   Design Size (|D|):   933
#   Open set size:       23546
#
# Progress: 12.5%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       185808.749
#   Best Cost (y):       268193241.4615
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      77.618
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8767→ cube 1.274
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0157→ cube 1.0847
#   Efficiency z (srs):  1.173 → 0.576 → 1.7847
#   Efficiency y (srs):  2.125 → 0.935 → 2.3078
#   Alpha:               0.8987979021455359
#   Num changes:         2
#   Design Depth:        346
#   Design Size (|D|):   973
#   Open set size:       24523
#
# Progress: 13.2%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       181495.28
#   Best Cost (y):       259190310.9634
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      75.856
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8975→ cube 1.3043
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.051→ cube 1.1224
#   Efficiency z (srs):  1.173 → 0.576 → 1.8271
#   Efficiency y (srs):  2.125 → 0.935 → 2.388
#   Alpha:               0.8042479189867149
#   Num changes:         1
#   Design Depth:        370
#   Design Size (|D|):   1021
#   Open set size:       25973
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       179636.727
#   Best Cost (y):       258962923.766
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      75.116
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9068→ cube 1.3178
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0519→ cube 1.1234
#   Efficiency z (srs):  1.173 → 0.576 → 1.846
#   Efficiency y (srs):  2.125 → 0.935 → 2.3901
#   Alpha:               0.8876974326063881
#   Num changes:         3
#   Design Depth:        372
#   Design Size (|D|):   1025
#   Open set size:       25982
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       179574.645
#   Best Cost (y):       259350004.268
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      75.111
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9071→ cube 1.3182
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0504→ cube 1.1217
#   Efficiency z (srs):  1.173 → 0.576 → 1.8466
#   Efficiency y (srs):  2.125 → 0.935 → 2.3865
#   Alpha:               0.7076693747619621
#   Num changes:         3
#   Design Depth:        372
#   Design Size (|D|):   1025
#   Open set size:       25984
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       179526.107
#   Best Cost (y):       258834089.6954
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      75.07
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9074→ cube 1.3186
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0525→ cube 1.124
#   Efficiency z (srs):  1.173 → 0.576 → 1.8471
#   Efficiency y (srs):  2.125 → 0.935 → 2.3913
#   Alpha:               0.7985971344624537
#   Num changes:         3
#   Design Depth:        372
#   Design Size (|D|):   1025
#   Open set size:       26015
#
# Progress: 13.5%
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       178553.945
#   Best Cost (y):       257565347.1181
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.62
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9123→ cube 1.3258
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0576→ cube 1.1295
#   Efficiency z (srs):  1.173 → 0.576 → 1.8572
#   Efficiency y (srs):  2.125 → 0.935 → 2.4031
#   Alpha:               0.7247118380432848
#   Num changes:         2
#   Design Depth:        391
#   Design Size (|D|):   1063
#   Open set size:       26493
#
#
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       178546.931
#   Best Cost (y):       257520691.776
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.617
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9124→ cube 1.3258
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0578→ cube 1.1297
#   Efficiency z (srs):  1.173 → 0.576 → 1.8573
#   Efficiency y (srs):  2.125 → 0.935 → 2.4035
#   Alpha:               0.8278225156949334
#   Num changes:         2
#   Design Depth:        391
#   Design Size (|D|):   1063
#   Open set size:       26499
#
# Progress: 13.8%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       177735.335
#   Best Cost (y):       258461374.3972
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.264
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9165→ cube 1.3319
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.054→ cube 1.1256
#   Efficiency z (srs):  1.173 → 0.576 → 1.8658
#   Efficiency y (srs):  2.125 → 0.935 → 2.3947
#   Alpha:               0.7130624376969712
#   Num changes:         2
#   Design Depth:        405
#   Design Size (|D|):   1091
#   Open set size:       26953
#
#
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       177748.312
#   Best Cost (y):       258498774.442
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.254
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9165→ cube 1.3318
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0538→ cube 1.1254
#   Efficiency z (srs):  1.173 → 0.576 → 1.8656
#   Efficiency y (srs):  2.125 → 0.935 → 2.3944
#   Alpha:               0.7801296077806809
#   Num changes:         2
#   Design Depth:        405
#   Design Size (|D|):   1091
#   Open set size:       26970
#
#
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       177685.564
#   Best Cost (y):       257829790.5306
#   number of new noded: 50
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.212
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9168→ cube 1.3322
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0566→ cube 1.1283
#   Efficiency z (srs):  1.173 → 0.576 → 1.8663
#   Efficiency y (srs):  2.125 → 0.935 → 2.4006
#   Alpha:               0.8836420409868472
#   Num changes:         3
#   Design Depth:        406
#   Design Size (|D|):   1093
#   Open set size:       26977
#
# Progress: 16.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 93
#      65 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      66                    inclusion_probability=inclusions, balance_method='linear')
#      68 astar = AStar(
#      69     inclusions              = inclusions,
#      70     num_initial_nodes       = num_initial_nodes,
#    (...)     90     # delta                   = 0.01,
#      91 )
# ---> 93 result = astar.run(
#      94     max_iterations             = max_iterations,
#      95     num_new_nodes              = num_new_nodes,
#      96     max_open_set_size          = max_open_set_size,
#      97     random_restart_period      = random_restart_period,
#      98     random_injection_count     = random_injection_count,
#      99     prune_fraction             = prune_fraction,
#     100     num_top_restart_nodes      = num_top_restart_nodes,
#     101     stuck_fraction             = stuck_fraction,
#     102
#     103 )
#     105 print("Best criteria value:", astar.best_criteria_value)
#     106 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:29, in VarNHT.__call__(self, design)
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
# ---> 29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#      33 samples_probabilities = np.array([sample.probability for sample in design])
#      34 var_NHT_z = np.sum((NHT_estimator_z - np.sum(self.auxiliary_variable)) ** 2 * samples_probabilities)
#
# KeyboardInterrupt:

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
