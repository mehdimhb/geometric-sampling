# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/Rtmp7G5ZPI", R: "/tmp/RtmpwqNhzd"
#   warnings.warn(

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
#
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
# #y <- RMT85; z <- ME84 ; p <- P75 # be rahe!
# # y <- RMT85; z <- ME84 ; p <- S82
# # y <- RMT85; z <- ME84 ; p <- SS82
# #  y <- RMT85; z <- ME84 ; p <- e
#
#
#
# y <- REV84; z <- P75 ; p <- ME84 # be rahe!
# # y <- REV84; z <- P75 ; p <- CS82
# # y <- REV84; z <- P75 ; p <- REG
# #  y <- REV84; z <- P75 ; p <- e
#
#
#
#
#
#
#
# # data(mtcars)
# # y <- mtcars$cyl; z <- mtcars$disp; p <- mtcars$hp # be rahe!
#
#
# N = length(y)
# n = 10
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# print(c(N, n))
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
#
#
# #################################
# ############ Plots and Prints ###
# #################################
# plot(z, y)
# plot(z/pik, y/pik)
#
# if(1==0){
#   par(mfrow=c(2,3))
#   plot(y, z)
#   plot(p, z)
#   plot(p, y)
#
#   plot(z_hat, y_hat)
#   plot(p/pik, y_hat)
#
#   plot(p/pik, z_hat)
#   par(mfrow=c(2,3))
# #cat('x,y', cor(x,y), '\n x,z', cor(z, x), '\n y,z', cor(z, y), "\n")
# plot(y, z)
# plot(p,z)
# plot(p,y)
#
# plot(z_hat,y_hat)
# plot(p/pik,y_hat)
#
# plot(p/pik,z_hat)
#
#
# cat("x_NHT, y_NHT", cor(p/pik,y/pik), "x, z", cor(p,z), "z_NHT, y_NHT", cor(z/pik,y/pik) , "\n")
#
# z_hat = z/pik
# print(var_z)
# print(var_y)
# cat("x threshold", threshold_z, "\n", "y threshold", threshold_y, "\n")
#
#
# #cat("x_NHT, y_NHT", cor(p/pik,y/pik), "x, z", cor(x,z), "z_NHT, y_NHT", cor(z/pik,y/pik))
# Final_result = cbind(y,z, y_hat, z_hat, pik, abs((y_hat- z_hat)/y_hat))
#
# print(c(N,n))
#
# }
# Out:
# [1] 284
# [1] 281
# [1] 0.03558719
# [1] 281  10

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(2,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): 445.0848 (p=1.05e-06)
#   beta  (Slope)    : 92.7218 (p=7.691e-104)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 38512.8282 (p=0.08437)
#   beta  (Slope)    : 68.7594 (p=0.02074)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): 2321.3351 (p=2.414e-16)
#   beta  (Slope)    : 0.0042 (p=0.09781)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 87.9266 (p=4.697e-22)
#   beta  (Slope)    : -0.0856 (p=2.179e-13)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# Variance of HT estimator via DSD formula_z:  6868.793
# Variance of HT estimator via DSD formula:  13240843743
# Here is the Vincent Efficiency y:
#   DSD_y:  0.97009
#   DSD_z: 9.14404
# Monte Carlo variance of HT estimator for y:
#   DSD:  12699167789.74933
#   Cube: 13250886994.56681
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.01147
#   Cube: 0.96935
# Monte Carlo mean of HT estimator for y:
#   DSD:  756378.38869
#   Cube: 759502.16750
#   Actual total of y: 757246.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  7014.77259
#   Cube: 13296.12409
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  8.95375
#   Cube: 4.72382
# Monte Carlo mean of HT estimator for z:
#   DSD:  6816.32918
#   Cube: 6816.53016
#   Actual total of z: 6818.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#       65.51      309.44      598.99        3.38        3.28        3.28

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])

inclusions = np.array(inclusions)

import numpy as np

num_new_nodes          = 30
num_changes_lower      = 1
num_changes_upper      = 1
max_open_set_size      = 200000
switch_lower           = .9
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 10000
initial_design_to_use  = 10
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.5 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = (1/eff_dsd_z) * .1  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_12453/2333408536.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.9021075017829231
# cor(y, inclusions) 0.9054582231011578
# 4000 30 200000 0.9 0.9
# Generating initial designs:   0%|        | 5/10000 [00:00<03:29, 47.68it/s]
# Initial design 0: method = Original, efficiency z = 0.2105, y=1.0411
# New best at idx=0: method = Original, efficiency z = 0.2105 and efficiency y = 1.0411
# New best at idx=2: method = z/pi, efficiency z = 0.2105 and efficiency y = 1.0411
# New best at idx=3: method = swap, efficiency z = 0.2133 and efficiency y = 0.9231
# New best at idx=4: method = swap, efficiency z = 0.2208 and efficiency y = 1.0146
# Generating initial designs:   0%|       | 29/10000 [00:00<03:03, 54.28it/s]
# New best at idx=16: method = swap, efficiency z = 0.2285 and efficiency y = 1.1817
# Generating initial designs:   1%|       | 93/10000 [00:01<03:58, 41.55it/s]
# New best at idx=86: method = swap, efficiency z = 0.2682 and efficiency y = 0.8911
# Generating initial designs:  12%|▌    | 1154/10000 [00:31<03:18, 44.62it/s]
# New best at idx=1152: method = swap, efficiency z = 0.3132 and efficiency y = 0.9088
# Generating initial designs: 100%|████| 10000/10000 [03:35<00:00, 46.49it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       31452.198
#   Best Cost (y):       12356683044.8705
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.186
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2184
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0716
#   Efficiency z (srs):  125.638 → 0.212 → 130.3471
#   Efficiency y (srs):  3.405 → 1.04 → 3.5051
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       10
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       31169.785
#   Best Cost (y):       12643088340.8466
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.114
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2204
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0473
#   Efficiency z (srs):  125.638 → 0.212 → 131.5281
#   Efficiency y (srs):  3.405 → 1.04 → 3.4257
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       12
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       31203.253
#   Best Cost (y):       12663938516.5152
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.1
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2201
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0456
#   Efficiency z (srs):  125.638 → 0.212 → 131.387
#   Efficiency y (srs):  3.405 → 1.04 → 3.42
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       53
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       27777.407
#   Best Cost (y):       11998880369.0048
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.166
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2473
#   Efficiency y (0→f):  1.041 → 1.04 → 1.1035
#   Efficiency z (srs):  125.638 → 0.212 → 147.5912
#   Efficiency y (srs):  3.405 → 1.04 → 3.6096
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        21
#   Design Size (|D|):   323
#   Open set size:       464
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       27869.416
#   Best Cost (y):       11990157747.8289
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.163
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2465
#   Efficiency y (0→f):  1.041 → 1.04 → 1.1043
#   Efficiency z (srs):  125.638 → 0.212 → 147.104
#   Efficiency y (srs):  3.405 → 1.04 → 3.6122
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        21
#   Design Size (|D|):   323
#   Open set size:       474
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       25597.961
#   Best Cost (y):       12123379127.154
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.663
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2683
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0922
#   Efficiency z (srs):  125.638 → 0.212 → 160.1574
#   Efficiency y (srs):  3.405 → 1.04 → 3.5725
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        31
#   Design Size (|D|):   343
#   Open set size:       729
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       25582.768
#   Best Cost (y):       12215104893.498
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.661
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2685
#   Efficiency y (0→f):  1.041 → 1.04 → 1.084
#   Efficiency z (srs):  125.638 → 0.212 → 160.2525
#   Efficiency y (srs):  3.405 → 1.04 → 3.5457
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        31
#   Design Size (|D|):   343
#   Open set size:       730
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       24249.713
#   Best Cost (y):       12304487159.6337
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.402
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2833
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0761
#   Efficiency z (srs):  125.638 → 0.212 → 169.0619
#   Efficiency y (srs):  3.405 → 1.04 → 3.5199
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        40
#   Design Size (|D|):   361
#   Open set size:       950
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       24146.92
#   Best Cost (y):       12437987472.9662
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.388
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2845
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0645
#   Efficiency z (srs):  125.638 → 0.212 → 169.7816
#   Efficiency y (srs):  3.405 → 1.04 → 3.4822
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        40
#   Design Size (|D|):   361
#   Open set size:       958
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       23988.101
#   Best Cost (y):       12474958978.7866
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.262
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2863
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0614
#   Efficiency z (srs):  125.638 → 0.212 → 170.9056
#   Efficiency y (srs):  3.405 → 1.04 → 3.4718
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        50
#   Design Size (|D|):   381
#   Open set size:       1196
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       23995.147
#   Best Cost (y):       12479057201.3923
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.26
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2863
#   Efficiency y (0→f):  1.041 → 1.04 → 1.061
#   Efficiency z (srs):  125.638 → 0.212 → 170.8555
#   Efficiency y (srs):  3.405 → 1.04 → 3.4707
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        50
#   Design Size (|D|):   381
#   Open set size:       1197
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       23993.217
#   Best Cost (y):       12485537417.759
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.259
#   Efficiency z (0→f):  0.21 → 0.212 → 0.2863
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0605
#   Efficiency z (srs):  125.638 → 0.212 → 170.8692
#   Efficiency y (srs):  3.405 → 1.04 → 3.4689
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        50
#   Design Size (|D|):   381
#   Open set size:       1209
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       22789.851
#   Best Cost (y):       12261506152.0842
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.566
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3014
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0799
#   Efficiency z (srs):  125.638 → 0.212 → 179.8916
#   Efficiency y (srs):  3.405 → 1.04 → 3.5323
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        60
#   Design Size (|D|):   401
#   Open set size:       1440
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       22096.214
#   Best Cost (y):       12408481462.8298
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.331
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3109
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0671
#   Efficiency z (srs):  125.638 → 0.212 → 185.5387
#   Efficiency y (srs):  3.405 → 1.04 → 3.4904
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        77
#   Design Size (|D|):   435
#   Open set size:       1923
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       22093.018
#   Best Cost (y):       12423964049.5123
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.329
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3109
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0658
#   Efficiency z (srs):  125.638 → 0.212 → 185.5655
#   Efficiency y (srs):  3.405 → 1.04 → 3.4861
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        77
#   Design Size (|D|):   435
#   Open set size:       1928
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       21224.894
#   Best Cost (y):       12446421701.9687
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.169
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3236
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0638
#   Efficiency z (srs):  125.638 → 0.212 → 193.1554
#   Efficiency y (srs):  3.405 → 1.04 → 3.4798
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        87
#   Design Size (|D|):   455
#   Open set size:       2185
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20939.828
#   Best Cost (y):       12397577751.588
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.842
#   Efficiency z (0→f):  0.21 → 0.212 → 0.328
#   Efficiency y (0→f):  1.041 → 1.04 → 1.068
#   Efficiency z (srs):  125.638 → 0.212 → 195.7849
#   Efficiency y (srs):  3.405 → 1.04 → 3.4935
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        97
#   Design Size (|D|):   475
#   Open set size:       2419
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20944.557
#   Best Cost (y):       12401460710.2847
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.824
#   Efficiency z (0→f):  0.21 → 0.212 → 0.328
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0677
#   Efficiency z (srs):  125.638 → 0.212 → 195.7407
#   Efficiency y (srs):  3.405 → 1.04 → 3.4924
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        97
#   Design Size (|D|):   475
#   Open set size:       2426
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20094.207
#   Best Cost (y):       12409954890.8542
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.619
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3418
#   Efficiency y (0→f):  1.041 → 1.04 → 1.067
#   Efficiency z (srs):  125.638 → 0.212 → 204.0241
#   Efficiency y (srs):  3.405 → 1.04 → 3.49
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        106
#   Design Size (|D|):   493
#   Open set size:       2649
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20020.665
#   Best Cost (y):       12413060705.4306
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.601
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3431
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0667
#   Efficiency z (srs):  125.638 → 0.212 → 204.7735
#   Efficiency y (srs):  3.405 → 1.04 → 3.4892
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        106
#   Design Size (|D|):   493
#   Open set size:       2651
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19982.546
#   Best Cost (y):       12414241593.9945
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.596
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3437
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0666
#   Efficiency z (srs):  125.638 → 0.212 → 205.1641
#   Efficiency y (srs):  3.405 → 1.04 → 3.4888
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        106
#   Design Size (|D|):   493
#   Open set size:       2657
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19530.306
#   Best Cost (y):       12366449679.233
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.512
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3517
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0707
#   Efficiency z (srs):  125.638 → 0.212 → 209.9149
#   Efficiency y (srs):  3.405 → 1.04 → 3.5023
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        116
#   Design Size (|D|):   513
#   Open set size:       2908
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19560.371
#   Best Cost (y):       12358847426.1096
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.511
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3512
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0714
#   Efficiency z (srs):  125.638 → 0.212 → 209.5922
#   Efficiency y (srs):  3.405 → 1.04 → 3.5045
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        116
#   Design Size (|D|):   513
#   Open set size:       2915
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19217.163
#   Best Cost (y):       12145572284.2343
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.395
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3574
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0902
#   Efficiency z (srs):  125.638 → 0.212 → 213.3354
#   Efficiency y (srs):  3.405 → 1.04 → 3.566
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        126
#   Design Size (|D|):   533
#   Open set size:       3147
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19218.643
#   Best Cost (y):       12250559165.0555
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.394
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3574
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0808
#   Efficiency z (srs):  125.638 → 0.212 → 213.319
#   Efficiency y (srs):  3.405 → 1.04 → 3.5354
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        126
#   Design Size (|D|):   533
#   Open set size:       3156
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19218.203
#   Best Cost (y):       12218293070.0236
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.394
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3574
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0837
#   Efficiency z (srs):  125.638 → 0.212 → 213.3239
#   Efficiency y (srs):  3.405 → 1.04 → 3.5448
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        126
#   Design Size (|D|):   533
#   Open set size:       3167
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18600.659
#   Best Cost (y):       12356854007.3606
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.285
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3693
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0715
#   Efficiency z (srs):  125.638 → 0.212 → 220.4063
#   Efficiency y (srs):  3.405 → 1.04 → 3.505
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        144
#   Design Size (|D|):   569
#   Open set size:       3629
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18337.789
#   Best Cost (y):       12350894670.4887
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.176
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3746
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0721
#   Efficiency z (srs):  125.638 → 0.212 → 223.5658
#   Efficiency y (srs):  3.405 → 1.04 → 3.5067
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        153
#   Design Size (|D|):   587
#   Open set size:       3875
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18163.61
#   Best Cost (y):       12212647013.5616
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.107
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3782
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0842
#   Efficiency z (srs):  125.638 → 0.212 → 225.7096
#   Efficiency y (srs):  3.405 → 1.04 → 3.5464
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        163
#   Design Size (|D|):   607
#   Open set size:       4127
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18156.513
#   Best Cost (y):       12207986917.1456
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.105
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3783
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0846
#   Efficiency z (srs):  125.638 → 0.212 → 225.7979
#   Efficiency y (srs):  3.405 → 1.04 → 3.5478
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        163
#   Design Size (|D|):   607
#   Open set size:       4136
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18150.008
#   Best Cost (y):       12210054577.5688
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.104
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3784
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0844
#   Efficiency z (srs):  125.638 → 0.212 → 225.8788
#   Efficiency y (srs):  3.405 → 1.04 → 3.5472
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        163
#   Design Size (|D|):   607
#   Open set size:       4150
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17844.903
#   Best Cost (y):       12366347215.9633
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.98
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3849
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0707
#   Efficiency z (srs):  125.638 → 0.212 → 229.7408
#   Efficiency y (srs):  3.405 → 1.04 → 3.5023
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        172
#   Design Size (|D|):   625
#   Open set size:       4388
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17846.984
#   Best Cost (y):       12227147878.1347
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.979
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3849
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0829
#   Efficiency z (srs):  125.638 → 0.212 → 229.714
#   Efficiency y (srs):  3.405 → 1.04 → 3.5422
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        172
#   Design Size (|D|):   625
#   Open set size:       4396
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17704.215
#   Best Cost (y):       12164591520.7978
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.896
#   Efficiency z (0→f):  0.21 → 0.212 → 0.388
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0885
#   Efficiency z (srs):  125.638 → 0.212 → 231.5664
#   Efficiency y (srs):  3.405 → 1.04 → 3.5604
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        181
#   Design Size (|D|):   643
#   Open set size:       4612
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17702.286
#   Best Cost (y):       12165176932.4892
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.895
#   Efficiency z (0→f):  0.21 → 0.212 → 0.388
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0884
#   Efficiency z (srs):  125.638 → 0.212 → 231.5917
#   Efficiency y (srs):  3.405 → 1.04 → 3.5603
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        181
#   Design Size (|D|):   643
#   Open set size:       4623
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17323.113
#   Best Cost (y):       12184313362.1349
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.677
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3965
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0867
#   Efficiency z (srs):  125.638 → 0.212 → 236.6608
#   Efficiency y (srs):  3.405 → 1.04 → 3.5547
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        199
#   Design Size (|D|):   679
#   Open set size:       5106
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17325.589
#   Best Cost (y):       12184497229.3136
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.676
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3965
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0867
#   Efficiency z (srs):  125.638 → 0.212 → 236.627
#   Efficiency y (srs):  3.405 → 1.04 → 3.5546
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        199
#   Design Size (|D|):   679
#   Open set size:       5109
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17177.95
#   Best Cost (y):       12311292251.5313
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.195
#   Efficiency z (0→f):  0.21 → 0.212 → 0.3999
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0755
#   Efficiency z (srs):  125.638 → 0.212 → 238.6607
#   Efficiency y (srs):  3.405 → 1.04 → 3.518
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        217
#   Design Size (|D|):   715
#   Open set size:       5587
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16935.72
#   Best Cost (y):       12358876016.7888
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.137
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4056
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0714
#   Efficiency z (srs):  125.638 → 0.212 → 242.0743
#   Efficiency y (srs):  3.405 → 1.04 → 3.5045
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        227
#   Design Size (|D|):   735
#   Open set size:       5848
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16725.313
#   Best Cost (y):       12403185892.9058
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.064
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4107
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0675
#   Efficiency z (srs):  125.638 → 0.212 → 245.1196
#   Efficiency y (srs):  3.405 → 1.04 → 3.4919
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        237
#   Design Size (|D|):   755
#   Open set size:       6069
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16629.543
#   Best Cost (y):       12416341588.58
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.049
#   Efficiency z (0→f):  0.21 → 0.212 → 0.413
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0664
#   Efficiency z (srs):  125.638 → 0.212 → 246.5312
#   Efficiency y (srs):  3.405 → 1.04 → 3.4882
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        237
#   Design Size (|D|):   755
#   Open set size:       6071
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16626.775
#   Best Cost (y):       12420878179.6726
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.044
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4131
#   Efficiency y (0→f):  1.041 → 1.04 → 1.066
#   Efficiency z (srs):  125.638 → 0.212 → 246.5723
#   Efficiency y (srs):  3.405 → 1.04 → 3.487
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        237
#   Design Size (|D|):   755
#   Open set size:       6074
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16623.76
#   Best Cost (y):       12414618116.477
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.041
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4132
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0666
#   Efficiency z (srs):  125.638 → 0.212 → 246.617
#   Efficiency y (srs):  3.405 → 1.04 → 3.4887
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        237
#   Design Size (|D|):   755
#   Open set size:       6076
#
# Progress: 6.5%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16581.645
#   Best Cost (y):       12380293544.0889
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.959
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4142
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0695
#   Efficiency z (srs):  125.638 → 0.212 → 247.2434
#   Efficiency y (srs):  3.405 → 1.04 → 3.4984
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        246
#   Design Size (|D|):   773
#   Open set size:       6316
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16540.723
#   Best Cost (y):       12424157506.4993
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.871
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4153
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0657
#   Efficiency z (srs):  125.638 → 0.212 → 247.8551
#   Efficiency y (srs):  3.405 → 1.04 → 3.486
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        263
#   Design Size (|D|):   807
#   Open set size:       6810
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15960.52
#   Best Cost (y):       12249085561.7893
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.705
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4304
#   Efficiency y (0→f):  1.041 → 1.04 → 1.081
#   Efficiency z (srs):  125.638 → 0.212 → 256.8652
#   Efficiency y (srs):  3.405 → 1.04 → 3.5359
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       7061
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16311.403
#   Best Cost (y):       12247898307.4368
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.656
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4211
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0811
#   Efficiency z (srs):  125.638 → 0.212 → 251.3396
#   Efficiency y (srs):  3.405 → 1.04 → 3.5362
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       7062
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16096.125
#   Best Cost (y):       12247972375.127
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.59
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4267
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0811
#   Efficiency z (srs):  125.638 → 0.212 → 254.7012
#   Efficiency y (srs):  3.405 → 1.04 → 3.5362
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       7063
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16157.923
#   Best Cost (y):       12256285854.1932
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.589
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4251
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0803
#   Efficiency z (srs):  125.638 → 0.212 → 253.727
#   Efficiency y (srs):  3.405 → 1.04 → 3.5338
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       7066
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15969.416
#   Best Cost (y):       12249465461.048
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.586
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4301
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0809
#   Efficiency z (srs):  125.638 → 0.212 → 256.7221
#   Efficiency y (srs):  3.405 → 1.04 → 3.5358
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       7077
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15959.789
#   Best Cost (y):       12251311422.6854
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.572
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4304
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0808
#   Efficiency z (srs):  125.638 → 0.212 → 256.877
#   Efficiency y (srs):  3.405 → 1.04 → 3.5352
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       7079
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15733.192
#   Best Cost (y):       12563833976.9865
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.443
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4366
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0539
#   Efficiency z (srs):  125.638 → 0.212 → 260.5766
#   Efficiency y (srs):  3.405 → 1.04 → 3.4473
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        288
#   Design Size (|D|):   857
#   Open set size:       7554
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15697.914
#   Best Cost (y):       12540024892.1482
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.406
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4376
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0559
#   Efficiency z (srs):  125.638 → 0.212 → 261.1622
#   Efficiency y (srs):  3.405 → 1.04 → 3.4538
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        297
#   Design Size (|D|):   875
#   Open set size:       7810
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15679.691
#   Best Cost (y):       12540238397.0726
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.404
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4381
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0559
#   Efficiency z (srs):  125.638 → 0.212 → 261.4657
#   Efficiency y (srs):  3.405 → 1.04 → 3.4538
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        297
#   Design Size (|D|):   875
#   Open set size:       7811
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15554.636
#   Best Cost (y):       12530255095.048
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.368
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4416
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0567
#   Efficiency z (srs):  125.638 → 0.212 → 263.5679
#   Efficiency y (srs):  3.405 → 1.04 → 3.4565
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        306
#   Design Size (|D|):   893
#   Open set size:       8051
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15553.666
#   Best Cost (y):       12528468051.5209
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.368
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4416
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0569
#   Efficiency z (srs):  125.638 → 0.212 → 263.5843
#   Efficiency y (srs):  3.405 → 1.04 → 3.457
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        306
#   Design Size (|D|):   893
#   Open set size:       8064
#
# Progress: 8.5%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15538.854
#   Best Cost (y):       12513706187.3334
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.361
#   Efficiency z (0→f):  0.21 → 0.212 → 0.442
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0581
#   Efficiency z (srs):  125.638 → 0.212 → 263.8355
#   Efficiency y (srs):  3.405 → 1.04 → 3.4611
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        311
#   Design Size (|D|):   903
#   Open set size:       8297
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15531.103
#   Best Cost (y):       12685226175.8528
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.083
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4423
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0438
#   Efficiency z (srs):  125.638 → 0.212 → 263.9672
#   Efficiency y (srs):  3.405 → 1.04 → 3.4143
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        328
#   Design Size (|D|):   937
#   Open set size:       8787
#
#
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15508.25
#   Best Cost (y):       12659301289.2398
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.079
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4429
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0459
#   Efficiency z (srs):  125.638 → 0.212 → 264.3562
#   Efficiency y (srs):  3.405 → 1.04 → 3.4213
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        328
#   Design Size (|D|):   937
#   Open set size:       8792
#
#
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15485.644
#   Best Cost (y):       12667743244.2402
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.075
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4436
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0452
#   Efficiency z (srs):  125.638 → 0.212 → 264.7421
#   Efficiency y (srs):  3.405 → 1.04 → 3.419
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        328
#   Design Size (|D|):   937
#   Open set size:       8793
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15433.922
#   Best Cost (y):       12464574219.6915
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.992
#   Efficiency z (0→f):  0.21 → 0.212 → 0.445
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0623
#   Efficiency z (srs):  125.638 → 0.212 → 265.6293
#   Efficiency y (srs):  3.405 → 1.04 → 3.4747
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        337
#   Design Size (|D|):   955
#   Open set size:       9015
#
#
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15431.282
#   Best Cost (y):       12457952580.4354
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.992
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4451
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0628
#   Efficiency z (srs):  125.638 → 0.212 → 265.6747
#   Efficiency y (srs):  3.405 → 1.04 → 3.4766
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        337
#   Design Size (|D|):   955
#   Open set size:       9019
#
#
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15428.718
#   Best Cost (y):       12450518149.1222
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.992
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4452
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0635
#   Efficiency z (srs):  125.638 → 0.212 → 265.7189
#   Efficiency y (srs):  3.405 → 1.04 → 3.4787
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        337
#   Design Size (|D|):   955
#   Open set size:       9021
#
# Progress: 9.5%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15219.7
#   Best Cost (y):       12371470155.2188
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.935
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4513
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0703
#   Efficiency z (srs):  125.638 → 0.212 → 269.3681
#   Efficiency y (srs):  3.405 → 1.04 → 3.5009
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        346
#   Design Size (|D|):   973
#   Open set size:       9260
#
# Progress: 9.8%
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15285.207
#   Best Cost (y):       12352965470.7232
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.916
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4494
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0719
#   Efficiency z (srs):  125.638 → 0.212 → 268.2137
#   Efficiency y (srs):  3.405 → 1.04 → 3.5061
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        350
#   Design Size (|D|):   981
#   Open set size:       9499
#
#
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15255.438
#   Best Cost (y):       12350081220.7221
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.915
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4503
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0721
#   Efficiency z (srs):  125.638 → 0.212 → 268.7371
#   Efficiency y (srs):  3.405 → 1.04 → 3.5069
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        350
#   Design Size (|D|):   981
#   Open set size:       9502
#
#
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15222.726
#   Best Cost (y):       12349794564.6142
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.912
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4512
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0722
#   Efficiency z (srs):  125.638 → 0.212 → 269.3146
#   Efficiency y (srs):  3.405 → 1.04 → 3.507
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        350
#   Design Size (|D|):   981
#   Open set size:       9503
#
#
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15236.239
#   Best Cost (y):       12350254161.6544
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.908
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4508
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0721
#   Efficiency z (srs):  125.638 → 0.212 → 269.0757
#   Efficiency y (srs):  3.405 → 1.04 → 3.5069
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        350
#   Design Size (|D|):   981
#   Open set size:       9516
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15164.141
#   Best Cost (y):       12343895883.8459
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.884
#   Efficiency z (0→f):  0.21 → 0.212 → 0.453
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0727
#   Efficiency z (srs):  125.638 → 0.212 → 270.355
#   Efficiency y (srs):  3.405 → 1.04 → 3.5087
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        359
#   Design Size (|D|):   999
#   Open set size:       9732
#
#
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15167.27
#   Best Cost (y):       12375549096.1294
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.884
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4529
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0699
#   Efficiency z (srs):  125.638 → 0.212 → 270.2993
#   Efficiency y (srs):  3.405 → 1.04 → 3.4997
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        359
#   Design Size (|D|):   999
#   Open set size:       9746
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15069.858
#   Best Cost (y):       12389616965.8798
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.75
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4558
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0687
#   Efficiency z (srs):  125.638 → 0.212 → 272.0465
#   Efficiency y (srs):  3.405 → 1.04 → 3.4958
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        392
#   Design Size (|D|):   1065
#   Open set size:       10742
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15065.808
#   Best Cost (y):       12451554993.144
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.75
#   Efficiency z (0→f):  0.21 → 0.212 → 0.4559
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0634
#   Efficiency z (srs):  125.638 → 0.212 → 272.1196
#   Efficiency y (srs):  3.405 → 1.04 → 3.4784
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        392
#   Design Size (|D|):   1065
#   Open set size:       10745
#
# Progress: 11.2%
# ...
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0534
#   Efficiency z (srs):  125.638 → 0.212 → 319.2289
#   Efficiency y (srs):  3.405 → 1.04 → 3.4457
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        624
#   Design Size (|D|):   1529
#   Open set size:       21013
#
# Progress: 22.8%
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12637.446
#   Best Cost (y):       12936402242.2074
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.248
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5435
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0235
#   Efficiency z (srs):  125.638 → 0.212 → 324.409
#   Efficiency y (srs):  3.405 → 1.04 → 3.348
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        652
#   Design Size (|D|):   1585
#   Open set size:       22221
#
#
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12633.319
#   Best Cost (y):       12941339553.1266
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.247
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5437
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0231
#   Efficiency z (srs):  125.638 → 0.212 → 324.515
#   Efficiency y (srs):  3.405 → 1.04 → 3.3467
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        652
#   Design Size (|D|):   1585
#   Open set size:       22237
#
# Progress: 23.2%
# === Best Solution Updated at Iteration 930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12529.653
#   Best Cost (y):       12931525011.484
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.198
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5482
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0239
#   Efficiency z (srs):  125.638 → 0.212 → 327.1999
#   Efficiency y (srs):  3.405 → 1.04 → 3.3493
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        665
#   Design Size (|D|):   1611
#   Open set size:       22719
#
# Progress: 23.5%
# === Best Solution Updated at Iteration 940 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12532.136
#   Best Cost (y):       13184685215.8358
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.197
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5481
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0043
#   Efficiency z (srs):  125.638 → 0.212 → 327.1351
#   Efficiency y (srs):  3.405 → 1.04 → 3.285
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        671
#   Design Size (|D|):   1623
#   Open set size:       22960
#
# Progress: 24.0%
# === Best Solution Updated at Iteration 960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12254.634
#   Best Cost (y):       13164919279.1271
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.113
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5605
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0058
#   Efficiency z (srs):  125.638 → 0.212 → 334.543
#   Efficiency y (srs):  3.405 → 1.04 → 3.2899
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        688
#   Design Size (|D|):   1657
#   Open set size:       23460
#
#
# === Best Solution Updated at Iteration 960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12256.435
#   Best Cost (y):       13166043673.3563
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.112
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5604
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0057
#   Efficiency z (srs):  125.638 → 0.212 → 334.4938
#   Efficiency y (srs):  3.405 → 1.04 → 3.2896
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        688
#   Design Size (|D|):   1657
#   Open set size:       23472
#
#
# === Best Solution Updated at Iteration 960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12255.842
#   Best Cost (y):       13164649242.9246
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.111
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5605
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0058
#   Efficiency z (srs):  125.638 → 0.212 → 334.51
#   Efficiency y (srs):  3.405 → 1.04 → 3.29
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        688
#   Design Size (|D|):   1657
#   Open set size:       23481
#
# Progress: 24.2%
# === Best Solution Updated at Iteration 970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12191.705
#   Best Cost (y):       13194429212.9074
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.065
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5634
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0035
#   Efficiency z (srs):  125.638 → 0.212 → 336.2698
#   Efficiency y (srs):  3.405 → 1.04 → 3.2825
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        697
#   Design Size (|D|):   1675
#   Open set size:       23715
#
# Progress: 24.5%
# === Best Solution Updated at Iteration 980 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12181.606
#   Best Cost (y):       13115416759.1026
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.062
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5639
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0096
#   Efficiency z (srs):  125.638 → 0.212 → 336.5485
#   Efficiency y (srs):  3.405 → 1.04 → 3.3023
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        705
#   Design Size (|D|):   1691
#   Open set size:       23973
#
# Progress: 25.8%
# === Best Solution Updated at Iteration 1030 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12137.225
#   Best Cost (y):       13139988663.0356
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.944
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5659
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0077
#   Efficiency z (srs):  125.638 → 0.212 → 337.7792
#   Efficiency y (srs):  3.405 → 1.04 → 3.2961
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        737
#   Design Size (|D|):   1755
#   Open set size:       25213
#
# Progress: 26.0%
# === Best Solution Updated at Iteration 1040 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12085.676
#   Best Cost (y):       13163630751.8274
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.923
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5683
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0059
#   Efficiency z (srs):  125.638 → 0.212 → 339.2199
#   Efficiency y (srs):  3.405 → 1.04 → 3.2902
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        747
#   Design Size (|D|):   1775
#   Open set size:       25432
#
# Progress: 26.8%
# === Best Solution Updated at Iteration 1070 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12070.158
#   Best Cost (y):       13218849498.9557
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.75
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5691
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0017
#   Efficiency z (srs):  125.638 → 0.212 → 339.656
#   Efficiency y (srs):  3.405 → 1.04 → 3.2765
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        765
#   Design Size (|D|):   1811
#   Open set size:       26178
#
#
# === Best Solution Updated at Iteration 1070 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12070.244
#   Best Cost (y):       13225821265.3935
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.749
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5691
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0011
#   Efficiency z (srs):  125.638 → 0.212 → 339.6536
#   Efficiency y (srs):  3.405 → 1.04 → 3.2747
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        765
#   Design Size (|D|):   1811
#   Open set size:       26187
#
# Progress: 27.0%
# === Best Solution Updated at Iteration 1080 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12054.403
#   Best Cost (y):       13250994672.9218
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.745
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5698
#   Efficiency y (0→f):  1.041 → 1.04 → 0.9992
#   Efficiency z (srs):  125.638 → 0.212 → 340.1
#   Efficiency y (srs):  3.405 → 1.04 → 3.2685
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        773
#   Design Size (|D|):   1827
#   Open set size:       26425
#
# Progress: 27.3%
# === Best Solution Updated at Iteration 1090 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12047.937
#   Best Cost (y):       13257879032.5613
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.722
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5701
#   Efficiency y (0→f):  1.041 → 1.04 → 0.9987
#   Efficiency z (srs):  125.638 → 0.212 → 340.2825
#   Efficiency y (srs):  3.405 → 1.04 → 3.2668
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        783
#   Design Size (|D|):   1847
#   Open set size:       26664
#
#
# === Best Solution Updated at Iteration 1090 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12042.232
#   Best Cost (y):       13255417444.2023
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.721
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5704
#   Efficiency y (0→f):  1.041 → 1.04 → 0.9989
#   Efficiency z (srs):  125.638 → 0.212 → 340.4437
#   Efficiency y (srs):  3.405 → 1.04 → 3.2674
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        783
#   Design Size (|D|):   1847
#   Open set size:       26679
#
# Progress: 27.8%
# === Best Solution Updated at Iteration 1110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12018.156
#   Best Cost (y):       13218778757.7004
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.684
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5715
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0017
#   Efficiency z (srs):  125.638 → 0.212 → 341.1257
#   Efficiency y (srs):  3.405 → 1.04 → 3.2765
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        800
#   Design Size (|D|):   1881
#   Open set size:       27152
#
# Progress: 28.0%
# === Best Solution Updated at Iteration 1120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12054.629
#   Best Cost (y):       13238845196.2337
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.632
#   Efficiency z (0→f):  0.21 → 0.212 → 0.5698
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0002
#   Efficiency z (srs):  125.638 → 0.212 → 340.0936
#   Efficiency y (srs):  3.405 → 1.04 → 3.2715
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        807
#   Design Size (|D|):   1895
#   Open set size:       27402
#
# Progress: 29.0%
# === Best Solution Updated at Iteration 1160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12049.591
#   Best Cost (y):       13219646387.6413
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.626
#   Efficiency z (0→f):  0.21 → 0.212 → 0.57
#   Efficiency y (0→f):  1.041 → 1.04 → 1.0016
#   Efficiency z (srs):  125.638 → 0.212 → 340.2358
#   Efficiency y (srs):  3.405 → 1.04 → 3.2763
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        829
#   Design Size (|D|):   1939
#   Open set size:       28357
#
# Progress: 29.8%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 85
#      59 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      60                    inclusion_probability=inclusions, balance_method='linear')
#      62 astar = AStar(
#      63     inclusions              = inclusions,
#      64     num_initial_nodes       = num_initial_nodes,
#    (...)     82     # delta                   = 0.01,
#      83 )
# ---> 85 result = astar.run(
#      86     max_iterations             = max_iterations,
#      87     num_new_nodes              = num_new_nodes,
#      88     max_open_set_size          = max_open_set_size,
#      89     random_restart_period      = random_restart_period,
#      90     random_injection_count     = random_injection_count,
#      91     prune_fraction             = prune_fraction,
#      92     num_top_restart_nodes      = num_top_restart_nodes,
#      93     stuck_fraction             = stuck_fraction,
#      94
#      95 )
#      97 print("Best criteria value:", astar.best_criteria_value)
#      98 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:269, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     266 if new_design in closed_set or new_design in open_set:
#     267     continue
# --> 269 _ = self.criteria(new_design)
#     270 new_criteria_value = self.criteria.var_NHT
#     271 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:29, in VarNHT.__call__(self, design)
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
# ---> 29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#      33 samples_probabilities = np.array([sample.probability for sample in design])
#      34 var_NHT_z = np.sum((NHT_estimator_z - np.sum(self.auxiliary_variable)) ** 2 * samples_probabilities)
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])

inclusions = np.array(inclusions)

import numpy as np

num_new_nodes          = 10
num_changes_lower      = 1
num_changes_upper      = 1
max_open_set_size      = 200000
switch_lower           = .9
switch_upper           = .9
max_iterations         = 2000
num_initial_nodes      = 3000
initial_design_to_use  = 10
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_12453/2522950465.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.9021075017829231
# cor(y, inclusions) 0.9054582231011578
# 2000 10 200000 0.9 0.9
# Generating initial designs:   0%|         | 3/3000 [00:00<01:52, 26.73it/s]
# Initial design 0: method = Original, efficiency z = 0.2105, y=1.0411
# New best at idx=0: method = Original, efficiency z = 0.2105 and efficiency y = 1.0411
# New best at idx=2: method = z/pi, efficiency z = 0.2105 and efficiency y = 1.0411
# New best at idx=3: method = swap, efficiency z = 0.2132 and efficiency y = 1.0293
# Generating initial designs:   0%|         | 6/3000 [00:00<01:56, 25.64it/s]
# New best at idx=5: method = swap, efficiency z = 0.2142 and efficiency y = 1.1458
# Generating initial designs:   1%|        | 18/3000 [00:00<01:52, 26.61it/s]
# New best at idx=12: method = swap, efficiency z = 0.2267 and efficiency y = 1.0279
# New best at idx=13: method = swap, efficiency z = 0.2334 and efficiency y = 0.7792
# Generating initial designs:  13%|▉      | 381/3000 [00:13<01:37, 26.74it/s]
# New best at idx=376: method = swap, efficiency z = 0.2555 and efficiency y = 0.8905
# Generating initial designs: 100%|██████| 3000/3000 [01:35<00:00, 31.25it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       32841.998
#   Best Cost (y):       12708532135.6826
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.355
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2091
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0419
#   Efficiency z (srs):  125.638 → 0.209 → 124.8311
#   Efficiency y (srs):  3.405 → 1.041 → 3.408
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   282
#   Open set size:       12
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       32195.673
#   Best Cost (y):       12715791054.4212
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.242
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2133
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0413
#   Efficiency z (srs):  125.638 → 0.209 → 127.337
#   Efficiency y (srs):  3.405 → 1.041 → 3.4061
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   282
#   Open set size:       13
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       32187.877
#   Best Cost (y):       12713507971.8434
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.233
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2134
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0415
#   Efficiency z (srs):  125.638 → 0.209 → 127.3679
#   Efficiency y (srs):  3.405 → 1.041 → 3.4067
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   282
#   Open set size:       18
#
# Progress: 0.1%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       31022.705
#   Best Cost (y):       12708399228.5403
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.063
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2214
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0419
#   Efficiency z (srs):  125.638 → 0.209 → 132.1517
#   Efficiency y (srs):  3.405 → 1.041 → 3.4081
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        2
#   Design Size (|D|):   284
#   Open set size:       28
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       29473.772
#   Best Cost (y):       12473779221.214
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.857
#   Efficiency z (0→f):  0.21 → 0.209 → 0.233
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0615
#   Efficiency z (srs):  125.638 → 0.209 → 139.0966
#   Efficiency y (srs):  3.405 → 1.041 → 3.4722
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        9
#   Design Size (|D|):   298
#   Open set size:       96
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       29281.361
#   Best Cost (y):       12551966864.1131
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.812
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2346
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0549
#   Efficiency z (srs):  125.638 → 0.209 → 140.0106
#   Efficiency y (srs):  3.405 → 1.041 → 3.4505
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        9
#   Design Size (|D|):   298
#   Open set size:       97
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       29311.819
#   Best Cost (y):       12564617379.3826
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.807
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2343
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0538
#   Efficiency z (srs):  125.638 → 0.209 → 139.8651
#   Efficiency y (srs):  3.405 → 1.041 → 3.4471
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        9
#   Design Size (|D|):   298
#   Open set size:       104
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       28624.754
#   Best Cost (y):       12511793667.7396
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.451
#   Efficiency z (0→f):  0.21 → 0.209 → 0.24
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0583
#   Efficiency z (srs):  125.638 → 0.209 → 143.2223
#   Efficiency y (srs):  3.405 → 1.041 → 3.4616
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        18
#   Design Size (|D|):   316
#   Open set size:       181
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       26730.737
#   Best Cost (y):       12279717977.0634
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.092
#   Efficiency z (0→f):  0.21 → 0.209 → 0.257
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0783
#   Efficiency z (srs):  125.638 → 0.209 → 153.3703
#   Efficiency y (srs):  3.405 → 1.041 → 3.527
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        34
#   Design Size (|D|):   348
#   Open set size:       349
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       26187.612
#   Best Cost (y):       12278975755.1033
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.018
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2623
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0783
#   Efficiency z (srs):  125.638 → 0.209 → 156.5512
#   Efficiency y (srs):  3.405 → 1.041 → 3.5273
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        34
#   Design Size (|D|):   348
#   Open set size:       351
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       24546.972
#   Best Cost (y):       12200803077.4585
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.577
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2798
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0852
#   Efficiency z (srs):  125.638 → 0.209 → 167.0146
#   Efficiency y (srs):  3.405 → 1.041 → 3.5499
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        44
#   Design Size (|D|):   368
#   Open set size:       436
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       24531.8
#   Best Cost (y):       12220737509.7591
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.496
#   Efficiency z (0→f):  0.21 → 0.209 → 0.28
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0835
#   Efficiency z (srs):  125.638 → 0.209 → 167.1179
#   Efficiency y (srs):  3.405 → 1.041 → 3.5441
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        54
#   Design Size (|D|):   388
#   Open set size:       520
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       23874.843
#   Best Cost (y):       12372018344.5162
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.174
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2877
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0702
#   Efficiency z (srs):  125.638 → 0.209 → 171.7164
#   Efficiency y (srs):  3.405 → 1.041 → 3.5007
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        83
#   Design Size (|D|):   446
#   Open set size:       774
#
# Progress: 5.5%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       23448.03
#   Best Cost (y):       12353042995.5284
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.994
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2929
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0719
#   Efficiency z (srs):  125.638 → 0.209 → 174.8421
#   Efficiency y (srs):  3.405 → 1.041 → 3.5061
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        98
#   Design Size (|D|):   476
#   Open set size:       940
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       23244.109
#   Best Cost (y):       12327494927.4103
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.941
#   Efficiency z (0→f):  0.21 → 0.209 → 0.2955
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0741
#   Efficiency z (srs):  125.638 → 0.209 → 176.376
#   Efficiency y (srs):  3.405 → 1.041 → 3.5134
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        98
#   Design Size (|D|):   476
#   Open set size:       942
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       22772.955
#   Best Cost (y):       12335482000.8916
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.869
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3016
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0734
#   Efficiency z (srs):  125.638 → 0.209 → 180.025
#   Efficiency y (srs):  3.405 → 1.041 → 3.5111
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        108
#   Design Size (|D|):   496
#   Open set size:       1021
#
# Progress: 6.5%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       22490.635
#   Best Cost (y):       12269755730.0382
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.66
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3054
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0791
#   Efficiency z (srs):  125.638 → 0.209 → 182.2848
#   Efficiency y (srs):  3.405 → 1.041 → 3.5299
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        118
#   Design Size (|D|):   516
#   Open set size:       1108
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       21334.609
#   Best Cost (y):       12237366508.8848
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.246
#   Efficiency z (0→f):  0.21 → 0.209 → 0.322
#   Efficiency y (0→f):  1.041 → 1.041 → 1.082
#   Efficiency z (srs):  125.638 → 0.209 → 192.162
#   Efficiency y (srs):  3.405 → 1.041 → 3.5393
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        127
#   Design Size (|D|):   534
#   Open set size:       1199
#
# Progress: 8.5%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20470.083
#   Best Cost (y):       12078568423.5181
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.952
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3356
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0962
#   Efficiency z (srs):  125.638 → 0.209 → 200.2777
#   Efficiency y (srs):  3.405 → 1.041 → 3.5858
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        150
#   Design Size (|D|):   580
#   Open set size:       1448
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20449.922
#   Best Cost (y):       12062392695.6672
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.949
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3359
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0977
#   Efficiency z (srs):  125.638 → 0.209 → 200.4752
#   Efficiency y (srs):  3.405 → 1.041 → 3.5906
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        150
#   Design Size (|D|):   580
#   Open set size:       1450
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20089.915
#   Best Cost (y):       12000707299.5341
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.846
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3419
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1033
#   Efficiency z (srs):  125.638 → 0.209 → 204.0677
#   Efficiency y (srs):  3.405 → 1.041 → 3.609
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        160
#   Design Size (|D|):   600
#   Open set size:       1528
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20084.499
#   Best Cost (y):       12000708218.5662
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.844
#   Efficiency z (0→f):  0.21 → 0.209 → 0.342
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1033
#   Efficiency z (srs):  125.638 → 0.209 → 204.1227
#   Efficiency y (srs):  3.405 → 1.041 → 3.609
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        160
#   Design Size (|D|):   600
#   Open set size:       1529
#
# Progress: 9.5%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19865.206
#   Best Cost (y):       12025506061.7025
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.737
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3458
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1011
#   Efficiency z (srs):  125.638 → 0.209 → 206.376
#   Efficiency y (srs):  3.405 → 1.041 → 3.6016
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        167
#   Design Size (|D|):   614
#   Open set size:       1612
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19856.43
#   Best Cost (y):       12015159105.4629
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.736
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3459
#   Efficiency y (0→f):  1.041 → 1.041 → 1.102
#   Efficiency z (srs):  125.638 → 0.209 → 206.4672
#   Efficiency y (srs):  3.405 → 1.041 → 3.6047
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        167
#   Design Size (|D|):   614
#   Open set size:       1615
#
# Progress: 11.5%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19027.348
#   Best Cost (y):       11919142672.5324
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.132
#   Efficiency z (0→f):  0.21 → 0.209 → 0.361
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1109
#   Efficiency z (srs):  125.638 → 0.209 → 215.4637
#   Efficiency y (srs):  3.405 → 1.041 → 3.6337
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        200
#   Design Size (|D|):   680
#   Open set size:       1953
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18995.922
#   Best Cost (y):       11925576523.497
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.127
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3616
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1103
#   Efficiency z (srs):  125.638 → 0.209 → 215.8201
#   Efficiency y (srs):  3.405 → 1.041 → 3.6318
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        200
#   Design Size (|D|):   680
#   Open set size:       1956
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18978.799
#   Best Cost (y):       11936885154.0053
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.088
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3619
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1092
#   Efficiency z (srs):  125.638 → 0.209 → 216.0148
#   Efficiency y (srs):  3.405 → 1.041 → 3.6283
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        208
#   Design Size (|D|):   696
#   Open set size:       2034
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18419.105
#   Best Cost (y):       11875979921.0989
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.688
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3729
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1149
#   Efficiency z (srs):  125.638 → 0.209 → 222.5788
#   Efficiency y (srs):  3.405 → 1.041 → 3.647
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        245
#   Design Size (|D|):   770
#   Open set size:       2370
#
# Progress: 14.5%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18524.138
#   Best Cost (y):       11859342771.7948
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.604
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3708
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1165
#   Efficiency z (srs):  125.638 → 0.209 → 221.3167
#   Efficiency y (srs):  3.405 → 1.041 → 3.6521
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        255
#   Design Size (|D|):   790
#   Open set size:       2453
#
# Progress: 15.5%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18428.352
#   Best Cost (y):       11814506872.0034
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.416
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3727
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1207
#   Efficiency z (srs):  125.638 → 0.209 → 222.4671
#   Efficiency y (srs):  3.405 → 1.041 → 3.6659
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        268
#   Design Size (|D|):   816
#   Open set size:       2630
#
# Progress: 18.0%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17958.943
#   Best Cost (y):       11938080324.6651
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.314
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3825
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1091
#   Efficiency z (srs):  125.638 → 0.209 → 228.2819
#   Efficiency y (srs):  3.405 → 1.041 → 3.628
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        303
#   Design Size (|D|):   886
#   Open set size:       3057
#
# Progress: 18.5%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17812.824
#   Best Cost (y):       11837063260.9425
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.25
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3856
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1186
#   Efficiency z (srs):  125.638 → 0.209 → 230.1545
#   Efficiency y (srs):  3.405 → 1.041 → 3.6589
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        313
#   Design Size (|D|):   906
#   Open set size:       3141
#
# Progress: 19.5%
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17634.187
#   Best Cost (y):       11903669924.8184
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.187
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3895
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1123
#   Efficiency z (srs):  125.638 → 0.209 → 232.486
#   Efficiency y (srs):  3.405 → 1.041 → 3.6385
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        323
#   Design Size (|D|):   926
#   Open set size:       3310
#
# Progress: 20.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17581.663
#   Best Cost (y):       12018334929.9675
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.133
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3907
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1017
#   Efficiency z (srs):  125.638 → 0.209 → 233.1806
#   Efficiency y (srs):  3.405 → 1.041 → 3.6038
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        332
#   Design Size (|D|):   944
#   Open set size:       3386
#
# Progress: 20.5%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17657.367
#   Best Cost (y):       12001827494.4666
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.054
#   Efficiency z (0→f):  0.21 → 0.209 → 0.389
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1032
#   Efficiency z (srs):  125.638 → 0.209 → 232.1808
#   Efficiency y (srs):  3.405 → 1.041 → 3.6087
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        340
#   Design Size (|D|):   960
#   Open set size:       3472
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17474.855
#   Best Cost (y):       11997593732.6628
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.026
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3931
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1036
#   Efficiency z (srs):  125.638 → 0.209 → 234.6058
#   Efficiency y (srs):  3.405 → 1.041 → 3.61
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        340
#   Design Size (|D|):   960
#   Open set size:       3480
#
# Progress: 22.0%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17237.894
#   Best Cost (y):       11925257917.2306
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.961
#   Efficiency z (0→f):  0.21 → 0.209 → 0.3985
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1103
#   Efficiency z (srs):  125.638 → 0.209 → 237.8308
#   Efficiency y (srs):  3.405 → 1.041 → 3.6319
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        358
#   Design Size (|D|):   996
#   Open set size:       3736
#
# Progress: 23.0%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16959.589
#   Best Cost (y):       11902532093.4185
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.837
#   Efficiency z (0→f):  0.21 → 0.209 → 0.405
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1124
#   Efficiency z (srs):  125.638 → 0.209 → 241.7336
#   Efficiency y (srs):  3.405 → 1.041 → 3.6388
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        377
#   Design Size (|D|):   1034
#   Open set size:       3905
#
# Progress: 23.5%
# === Best Solution Updated at Iteration 470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16713.278
#   Best Cost (y):       11902786639.6056
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.753
#   Efficiency z (0→f):  0.21 → 0.209 → 0.411
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1124
#   Efficiency z (srs):  125.638 → 0.209 → 245.2961
#   Efficiency y (srs):  3.405 → 1.041 → 3.6387
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        386
#   Design Size (|D|):   1052
#   Open set size:       3982
#
# Progress: 25.0%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16633.581
#   Best Cost (y):       11803328435.7211
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.643
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4129
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1218
#   Efficiency z (srs):  125.638 → 0.209 → 246.4714
#   Efficiency y (srs):  3.405 → 1.041 → 3.6694
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        413
#   Design Size (|D|):   1106
#   Open set size:       4233
#
#
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16615.973
#   Best Cost (y):       11835884851.6945
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.64
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4134
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1187
#   Efficiency z (srs):  125.638 → 0.209 → 246.7326
#   Efficiency y (srs):  3.405 → 1.041 → 3.6593
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        413
#   Design Size (|D|):   1106
#   Open set size:       4239
#
# Progress: 26.0%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16698.677
#   Best Cost (y):       11968787926.4203
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.639
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4113
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1063
#   Efficiency z (srs):  125.638 → 0.209 → 245.5106
#   Efficiency y (srs):  3.405 → 1.041 → 3.6187
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        421
#   Design Size (|D|):   1122
#   Open set size:       4400
#
#
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16705.466
#   Best Cost (y):       11968986522.5503
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.637
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4112
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1063
#   Efficiency z (srs):  125.638 → 0.209 → 245.4108
#   Efficiency y (srs):  3.405 → 1.041 → 3.6186
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        421
#   Design Size (|D|):   1122
#   Open set size:       4403
#
# Progress: 26.5%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16557.687
#   Best Cost (y):       12092292530.7125
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.613
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4148
#   Efficiency y (0→f):  1.041 → 1.041 → 1.095
#   Efficiency z (srs):  125.638 → 0.209 → 247.6011
#   Efficiency y (srs):  3.405 → 1.041 → 3.5817
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        426
#   Design Size (|D|):   1132
#   Open set size:       4486
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16565.339
#   Best Cost (y):       12090413691.811
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.612
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4146
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0952
#   Efficiency z (srs):  125.638 → 0.209 → 247.4867
#   Efficiency y (srs):  3.405 → 1.041 → 3.5823
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        426
#   Design Size (|D|):   1132
#   Open set size:       4488
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16553.777
#   Best Cost (y):       12090195543.3017
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.61
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4149
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0952
#   Efficiency z (srs):  125.638 → 0.209 → 247.6596
#   Efficiency y (srs):  3.405 → 1.041 → 3.5823
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        426
#   Design Size (|D|):   1132
#   Open set size:       4489
#
# Progress: 27.0%
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16561.839
#   Best Cost (y):       12099723358.8199
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.597
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4147
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0943
#   Efficiency z (srs):  125.638 → 0.209 → 247.539
#   Efficiency y (srs):  3.405 → 1.041 → 3.5795
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        432
#   Design Size (|D|):   1144
#   Open set size:       4568
#
# Progress: 27.5%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16323.813
#   Best Cost (y):       12122261221.7868
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.553
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4208
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0923
#   Efficiency z (srs):  125.638 → 0.209 → 251.1485
#   Efficiency y (srs):  3.405 → 1.041 → 3.5729
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        441
#   Design Size (|D|):   1162
#   Open set size:       4658
#
# Progress: 29.5%
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15935.36
#   Best Cost (y):       12175024794.7278
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.088
#   Efficiency z (0→f):  0.21 → 0.209 → 0.431
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0875
#   Efficiency z (srs):  125.638 → 0.209 → 257.2707
#   Efficiency y (srs):  3.405 → 1.041 → 3.5574
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        470
#   Design Size (|D|):   1220
#   Open set size:       5001
#
# Progress: 31.0%
# === Best Solution Updated at Iteration 620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15871.15
#   Best Cost (y):       12280645643.7801
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.005
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4328
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0782
#   Efficiency z (srs):  125.638 → 0.209 → 258.3116
#   Efficiency y (srs):  3.405 → 1.041 → 3.5268
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        487
#   Design Size (|D|):   1254
#   Open set size:       5243
#
# Progress: 31.5%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15624.821
#   Best Cost (y):       12216076350.3119
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.936
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4396
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0839
#   Efficiency z (srs):  125.638 → 0.209 → 262.3839
#   Efficiency y (srs):  3.405 → 1.041 → 3.5454
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        497
#   Design Size (|D|):   1274
#   Open set size:       5334
#
# Progress: 47.0%
# === Best Solution Updated at Iteration 940 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15597.751
#   Best Cost (y):       12311224319.9975
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.896
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4404
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0755
#   Efficiency z (srs):  125.638 → 0.209 → 262.8393
#   Efficiency y (srs):  3.405 → 1.041 → 3.518
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        542
#   Design Size (|D|):   1364
#   Open set size:       7855
#
#
# === Best Solution Updated at Iteration 940 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15587.486
#   Best Cost (y):       12328378688.7708
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.895
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4407
#   Efficiency y (0→f):  1.041 → 1.041 → 1.074
#   Efficiency z (srs):  125.638 → 0.209 → 263.0124
#   Efficiency y (srs):  3.405 → 1.041 → 3.5131
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        542
#   Design Size (|D|):   1364
#   Open set size:       7857
#
#
# === Best Solution Updated at Iteration 940 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15594.929
#   Best Cost (y):       12290568931.7361
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.895
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4405
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0773
#   Efficiency z (srs):  125.638 → 0.209 → 262.8869
#   Efficiency y (srs):  3.405 → 1.041 → 3.5239
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        542
#   Design Size (|D|):   1364
#   Open set size:       7858
#
#
# === Best Solution Updated at Iteration 940 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15594.997
#   Best Cost (y):       12330248441.812
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.895
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4404
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0739
#   Efficiency z (srs):  125.638 → 0.209 → 262.8857
#   Efficiency y (srs):  3.405 → 1.041 → 3.5126
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        542
#   Design Size (|D|):   1364
#   Open set size:       7860
#
# Progress: 48.5%
# === Best Solution Updated at Iteration 970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15482.624
#   Best Cost (y):       12225292713.5232
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.818
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4436
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0831
#   Efficiency z (srs):  125.638 → 0.209 → 264.7937
#   Efficiency y (srs):  3.405 → 1.041 → 3.5427
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        568
#   Design Size (|D|):   1416
#   Open set size:       8108
#
# Progress: 50.5%
# === Best Solution Updated at Iteration 1010 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15161.612
#   Best Cost (y):       12146312639.4413
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.761
#   Efficiency z (0→f):  0.21 → 0.209 → 0.453
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0901
#   Efficiency z (srs):  125.638 → 0.209 → 270.4001
#   Efficiency y (srs):  3.405 → 1.041 → 3.5658
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        593
#   Design Size (|D|):   1466
#   Open set size:       8447
#
# Progress: 55.0%
# === Best Solution Updated at Iteration 1100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15087.845
#   Best Cost (y):       12061029539.7019
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.48
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4553
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0978
#   Efficiency z (srs):  125.638 → 0.209 → 271.7222
#   Efficiency y (srs):  3.405 → 1.041 → 3.591
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        617
#   Design Size (|D|):   1514
#   Open set size:       9203
#
# Progress: 55.5%
# === Best Solution Updated at Iteration 1110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14921.982
#   Best Cost (y):       11889376342.161
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.375
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4603
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1137
#   Efficiency z (srs):  125.638 → 0.209 → 274.7425
#   Efficiency y (srs):  3.405 → 1.041 → 3.6428
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        626
#   Design Size (|D|):   1532
#   Open set size:       9284
#
# Progress: 56.5%
# === Best Solution Updated at Iteration 1130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14868.096
#   Best Cost (y):       11947384681.9474
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.323
#   Efficiency z (0→f):  0.21 → 0.209 → 0.462
#   Efficiency y (0→f):  1.041 → 1.041 → 1.1083
#   Efficiency z (srs):  125.638 → 0.209 → 275.7382
#   Efficiency y (srs):  3.405 → 1.041 → 3.6252
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        642
#   Design Size (|D|):   1564
#   Open set size:       9457
#
# Progress: 59.0%
# === Best Solution Updated at Iteration 1180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14450.69
#   Best Cost (y):       12064089855.3383
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.155
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4753
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0975
#   Efficiency z (srs):  125.638 → 0.209 → 283.7029
#   Efficiency y (srs):  3.405 → 1.041 → 3.5901
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        683
#   Design Size (|D|):   1646
#   Open set size:       9881
#
#
# === Best Solution Updated at Iteration 1180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14451.951
#   Best Cost (y):       12065621867.1997
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.154
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4753
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0974
#   Efficiency z (srs):  125.638 → 0.209 → 283.6781
#   Efficiency y (srs):  3.405 → 1.041 → 3.5896
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        683
#   Design Size (|D|):   1646
#   Open set size:       9883
#
# Progress: 59.5%
# === Best Solution Updated at Iteration 1190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14356.921
#   Best Cost (y):       12093112068.4795
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.123
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4784
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0949
#   Efficiency z (srs):  125.638 → 0.209 → 285.5558
#   Efficiency y (srs):  3.405 → 1.041 → 3.5815
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        692
#   Design Size (|D|):   1664
#   Open set size:       9975
#
# Progress: 62.0%
# === Best Solution Updated at Iteration 1240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14398.932
#   Best Cost (y):       12272559830.6973
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.002
#   Efficiency z (0→f):  0.21 → 0.209 → 0.477
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0789
#   Efficiency z (srs):  125.638 → 0.209 → 284.7226
#   Efficiency y (srs):  3.405 → 1.041 → 3.5291
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        718
#   Design Size (|D|):   1716
#   Open set size:       10395
#
# Progress: 70.5%
# === Best Solution Updated at Iteration 1410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14430.57
#   Best Cost (y):       12120261118.3082
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.99
#   Efficiency z (0→f):  0.21 → 0.209 → 0.476
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0925
#   Efficiency z (srs):  125.638 → 0.209 → 284.0984
#   Efficiency y (srs):  3.405 → 1.041 → 3.5734
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        736
#   Design Size (|D|):   1752
#   Open set size:       11830
#
# Progress: 71.0%
# === Best Solution Updated at Iteration 1420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14398.454
#   Best Cost (y):       12083277707.8981
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.971
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4771
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0958
#   Efficiency z (srs):  125.638 → 0.209 → 284.7321
#   Efficiency y (srs):  3.405 → 1.041 → 3.5844
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        745
#   Design Size (|D|):   1770
#   Open set size:       11915
#
#
# === Best Solution Updated at Iteration 1420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14375.236
#   Best Cost (y):       12084843173.4404
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.967
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4778
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0957
#   Efficiency z (srs):  125.638 → 0.209 → 285.192
#   Efficiency y (srs):  3.405 → 1.041 → 3.5839
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        745
#   Design Size (|D|):   1770
#   Open set size:       11923
#
# Progress: 72.0%
# === Best Solution Updated at Iteration 1440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14421.566
#   Best Cost (y):       12163352761.7563
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.954
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4763
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0886
#   Efficiency z (srs):  125.638 → 0.209 → 284.2758
#   Efficiency y (srs):  3.405 → 1.041 → 3.5608
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        760
#   Design Size (|D|):   1800
#   Open set size:       12085
#
# Progress: 72.5%
# === Best Solution Updated at Iteration 1450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14458.532
#   Best Cost (y):       12103096768.6639
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.922
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4751
#   Efficiency y (0→f):  1.041 → 1.041 → 1.094
#   Efficiency z (srs):  125.638 → 0.209 → 283.549
#   Efficiency y (srs):  3.405 → 1.041 → 3.5785
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        768
#   Design Size (|D|):   1816
#   Open set size:       12171
#
# Progress: 94.0%
# === Best Solution Updated at Iteration 1880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14380.77
#   Best Cost (y):       12119458109.6099
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.812
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4776
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0925
#   Efficiency z (srs):  125.638 → 0.209 → 285.0822
#   Efficiency y (srs):  3.405 → 1.041 → 3.5737
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        819
#   Design Size (|D|):   1918
#   Open set size:       15829
#
# Progress: 96.5%
# === Best Solution Updated at Iteration 1930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14216.258
#   Best Cost (y):       12165243080.5877
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.556
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4832
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0884
#   Efficiency z (srs):  125.638 → 0.209 → 288.3812
#   Efficiency y (srs):  3.405 → 1.041 → 3.5602
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        861
#   Design Size (|D|):   2002
#   Open set size:       16247
#
#
# === Best Solution Updated at Iteration 1930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14216.481
#   Best Cost (y):       12165747325.1204
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.556
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4832
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0884
#   Efficiency z (srs):  125.638 → 0.209 → 288.3767
#   Efficiency y (srs):  3.405 → 1.041 → 3.5601
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        861
#   Design Size (|D|):   2002
#   Open set size:       16254
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 1999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14174.406
#   Best Cost (y):       12259813436.6079
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.546
#   Efficiency z (0→f):  0.21 → 0.209 → 0.4846
#   Efficiency y (0→f):  1.041 → 1.041 → 1.08
#   Efficiency z (srs):  125.638 → 0.209 → 289.2327
#   Efficiency y (srs):  3.405 → 1.041 → 3.5328
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        881
#   Design Size (|D|):   2042
#   Open set size:       16836
#
# Best criteria value: 7.545669436870277
# Iterations run: 2000
# Best criteria value: 7.545669436870277
# Iterations run: 2000
