# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
# round(cor(MU284), 2)
# Out:
#       LABEL   P85   P75 RMT85  CS82 SS82   S82  ME84 REV84   REG    CL
# LABEL  1.00 -0.18 -0.15 -0.17 -0.56 0.11 -0.17 -0.17 -0.15  0.83  1.00
# P85   -0.18  1.00  1.00  0.99  0.67 0.65  0.87  0.99  0.91 -0.19 -0.18
# P75   -0.15  1.00  1.00  0.99  0.64 0.68  0.87  0.99  0.90 -0.17 -0.15
# RMT85 -0.17  0.99  0.99  1.00  0.66 0.65  0.85  0.99  0.91 -0.19 -0.16
# CS82  -0.56  0.67  0.64  0.66  1.00 0.15  0.62  0.65  0.61 -0.45 -0.56
# SS82   0.11  0.65  0.68  0.65  0.15 1.00  0.75  0.66  0.60  0.02  0.12
# S82   -0.17  0.87  0.87  0.85  0.62 0.75  1.00  0.85  0.80 -0.15 -0.17
# ME84  -0.17  0.99  0.99  0.99  0.65 0.66  0.85  1.00  0.91 -0.19 -0.16
# REV84 -0.15  0.91  0.90  0.91  0.61 0.60  0.80  0.91  1.00 -0.14 -0.15
# REG    0.83 -0.19 -0.17 -0.19 -0.45 0.02 -0.15 -0.19 -0.14  1.00  0.83
# CL     1.00 -0.18 -0.15 -0.16 -0.56 0.12 -0.17 -0.16 -0.15  0.83  1.00

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- REV84; p <- P75 # be rahe!
#  #y <- RMT85; z <- REV84; p <- S82
#  y <- RMT85; z <- CS82; p <- SS82
#  #y <- RMT85; z <- REV84; p <- e
#
#
#
#
#  y <- REV84; z <- S82 ; p <- ME84 # be rahe!
# y <- REV84; z <- S82 ; p <- CS82
# # y <- REV84; z <- S82 ; p <- REG
# #  y <- REV84; z <- S82 ; p <- e
# cat('cor y, z', cor(y,z))
# cat('cor y, p', cor(y,p))
#
#
# #y <- P85; z <- REV84; p <- runif(length(y))
#
# # data(mtcars)
# # y <- mtcars$cyl; z <- mtcars$disp; p <- mtcars$hp # be rahe!
#
#
# N = length(y)
# n = 10
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
# Out:
# [1] 284
# [1] 281
# cor y, z 0.8000344cor y, p 0.6054689[1] 0.03558719

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4863.1  -643.1  -207.7   284.3  8070.4
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              1.723e+04  5.097e+03   3.380 0.000830 ***
# poly(z, 3, raw = TRUE)1 -1.096e+03  3.002e+02  -3.651 0.000313 ***
# poly(z, 3, raw = TRUE)2  2.240e+01  5.705e+00   3.927 0.000109 ***
# poly(z, 3, raw = TRUE)3 -1.242e-01  3.478e-02  -3.572 0.000418 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1366 on 277 degrees of freedom
# Multiple R-squared:  0.6764,	Adjusted R-squared:  0.6729
# F-statistic:   193 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4863.1  -643.1  -207.7   284.3  8070.4
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.723e+04  5.097e+03   3.380 0.000830 ***
# z           -1.096e+03  3.002e+02  -3.651 0.000313 ***
# I(z^2)       2.240e+01  5.705e+00   3.927 0.000109 ***
# I(z^3)      -1.242e-01  3.478e-02  -3.572 0.000418 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1366 on 277 degrees of freedom
# Multiple R-squared:  0.6764,	Adjusted R-squared:  0.6729
# F-statistic:   193 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -5963.4678 (p=1.233e-37)
#   beta  (Slope)    : 183.5242 (p=7.408e-64)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 45082.1234 (p=4.634e-11)
#   beta  (Slope)    : 19.9174 (p=7.288e-09)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): 735.7176 (p=7.18e-05)
#   beta  (Slope)    : 0.0249 (p=2.252e-32)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 52.2088 (p=1.247e-130)
#   beta  (Slope)    : -0.0030 (p=6.352e-07)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        0.71        1.17        1.66        2.36        1.80

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])

inclusions = np.array(inclusions)

import numpy as np

num_new_nodes          = 30
num_changes_lower      = 1
num_changes_upper      = 5
max_open_set_size      = 200000
switch_lower           = .1
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='origin')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_5746/3927061134.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.800034362035363
# cor(y, inclusions) 0.6054688616044365
# 4000 30 200000 0.1 0.9
# Generating initial designs: 100%|████████████| 1/1 [00:00<00:00, 20.51it/s]
# Initial design 0: method = Original, efficiency z = 0.1729, y=0.9227
# New best at idx=0: method = Original, efficiency z = 0.1729 and efficiency y = 0.9227
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       4073601.54
#   Best Cost (y):       26251015971.2525
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      4073601.54
#   Efficiency z (0→f):  0.173 → 0.173 → 0.1736
#   Efficiency y (0→f):  0.923 → 0.923 → 0.9201
#   Efficiency z (srs):  0.201 → 0.173 → 0.202
#   Efficiency y (srs):  1.655 → 0.923 → 1.6499
#   Alpha:               0.4348847842729572
#   Num changes:         4
#   Design Depth:        4
#   Design Size (|D|):   274
#   Open set size:       1
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3962079.648
#   Best Cost (y):       26418210365.7823
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3962079.648
#   Efficiency z (0→f):  0.173 → 0.173 → 0.1785
#   Efficiency y (0→f):  0.923 → 0.923 → 0.9143
#   Efficiency z (srs):  0.201 → 0.173 → 0.2077
#   Efficiency y (srs):  1.655 → 0.923 → 1.6394
#   Alpha:               0.7850572156586402
#   Num changes:         5
#   Design Depth:        5
#   Design Size (|D|):   276
#   Open set size:       8
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3916002.04
#   Best Cost (y):       26444004376.417
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3916002.04
#   Efficiency z (0→f):  0.173 → 0.173 → 0.1806
#   Efficiency y (0→f):  0.923 → 0.923 → 0.9134
#   Efficiency z (srs):  0.201 → 0.173 → 0.2102
#   Efficiency y (srs):  1.655 → 0.923 → 1.6378
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        10
#   Design Size (|D|):   286
#   Open set size:       59
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3479533.844
#   Best Cost (y):       26557127011.383
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3479533.844
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2032
#   Efficiency y (0→f):  0.923 → 0.923 → 0.9095
#   Efficiency z (srs):  0.201 → 0.173 → 0.2365
#   Efficiency y (srs):  1.655 → 0.923 → 1.6309
#   Alpha:               0.8131415538152592
#   Num changes:         4
#   Design Depth:        44
#   Design Size (|D|):   354
#   Open set size:       296
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3473599.902
#   Best Cost (y):       26831131338.039
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3473599.902
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2036
#   Efficiency y (0→f):  0.923 → 0.923 → 0.9002
#   Efficiency z (srs):  0.201 → 0.173 → 0.2369
#   Efficiency y (srs):  1.655 → 0.923 → 1.6142
#   Alpha:               0.6731614401733571
#   Num changes:         4
#   Design Depth:        44
#   Design Size (|D|):   354
#   Open set size:       297
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3472455.085
#   Best Cost (y):       26776429103.9639
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3472455.085
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2036
#   Efficiency y (0→f):  0.923 → 0.923 → 0.902
#   Efficiency z (srs):  0.201 → 0.173 → 0.237
#   Efficiency y (srs):  1.655 → 0.923 → 1.6175
#   Alpha:               0.6199642704728138
#   Num changes:         1
#   Design Depth:        41
#   Design Size (|D|):   348
#   Open set size:       307
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3293962.799
#   Best Cost (y):       28943041306.8394
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3293962.799
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2147
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8345
#   Efficiency z (srs):  0.201 → 0.173 → 0.2499
#   Efficiency y (srs):  1.655 → 0.923 → 1.4964
#   Alpha:               0.760485912299422
#   Num changes:         3
#   Design Depth:        78
#   Design Size (|D|):   422
#   Open set size:       581
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3290359.824
#   Best Cost (y):       28719807945.81
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3290359.824
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2149
#   Efficiency y (0→f):  0.923 → 0.923 → 0.841
#   Efficiency z (srs):  0.201 → 0.173 → 0.2501
#   Efficiency y (srs):  1.655 → 0.923 → 1.5081
#   Alpha:               0.6062095031927444
#   Num changes:         5
#   Design Depth:        80
#   Design Size (|D|):   426
#   Open set size:       582
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3282510.525
#   Best Cost (y):       28571274237.7821
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3282510.525
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2154
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8454
#   Efficiency z (srs):  0.201 → 0.173 → 0.2507
#   Efficiency y (srs):  1.655 → 0.923 → 1.5159
#   Alpha:               0.8399942840345588
#   Num changes:         4
#   Design Depth:        79
#   Design Size (|D|):   424
#   Open set size:       592
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3135590.562
#   Best Cost (y):       28307206290.2362
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3135590.562
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2255
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8533
#   Efficiency z (srs):  0.201 → 0.173 → 0.2625
#   Efficiency y (srs):  1.655 → 0.923 → 1.53
#   Alpha:               0.7404039525073122
#   Num changes:         5
#   Design Depth:        120
#   Design Size (|D|):   506
#   Open set size:       871
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3134646.303
#   Best Cost (y):       28298051260.4883
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3134646.303
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2256
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8535
#   Efficiency z (srs):  0.201 → 0.173 → 0.2626
#   Efficiency y (srs):  1.655 → 0.923 → 1.5305
#   Alpha:               0.2762161586551537
#   Num changes:         3
#   Design Depth:        118
#   Design Size (|D|):   502
#   Open set size:       873
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3125380.025
#   Best Cost (y):       28307064741.0811
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3125380.025
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2262
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8533
#   Efficiency z (srs):  0.201 → 0.173 → 0.2633
#   Efficiency y (srs):  1.655 → 0.923 → 1.53
#   Alpha:               0.5445132932819686
#   Num changes:         3
#   Design Depth:        118
#   Design Size (|D|):   502
#   Open set size:       881
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3084301.856
#   Best Cost (y):       28620647462.7188
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3084301.856
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2292
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8439
#   Efficiency z (srs):  0.201 → 0.173 → 0.2669
#   Efficiency y (srs):  1.655 → 0.923 → 1.5133
#   Alpha:               0.6408027661272094
#   Num changes:         4
#   Design Depth:        146
#   Design Size (|D|):   558
#   Open set size:       1168
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       3011801.059
#   Best Cost (y):       28429447459.1702
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      3011801.059
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2348
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8496
#   Efficiency z (srs):  0.201 → 0.173 → 0.2733
#   Efficiency y (srs):  1.655 → 0.923 → 1.5235
#   Alpha:               0.48528460259930495
#   Num changes:         5
#   Design Depth:        184
#   Design Size (|D|):   634
#   Open set size:       1452
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2951496.725
#   Best Cost (y):       28310052706.5549
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2951496.725
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2396
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8532
#   Efficiency z (srs):  0.201 → 0.173 → 0.2789
#   Efficiency y (srs):  1.655 → 0.923 → 1.5299
#   Alpha:               0.8401470768011959
#   Num changes:         4
#   Design Depth:        223
#   Design Size (|D|):   712
#   Open set size:       1741
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2949261.477
#   Best Cost (y):       28197424219.5327
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2949261.477
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2397
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8566
#   Efficiency z (srs):  0.201 → 0.173 → 0.2791
#   Efficiency y (srs):  1.655 → 0.923 → 1.536
#   Alpha:               0.7594576994743126
#   Num changes:         2
#   Design Depth:        221
#   Design Size (|D|):   708
#   Open set size:       1743
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2944048.714
#   Best Cost (y):       28150890350.7821
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2944048.714
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2402
#   Efficiency y (0→f):  0.923 → 0.923 → 0.858
#   Efficiency z (srs):  0.201 → 0.173 → 0.2796
#   Efficiency y (srs):  1.655 → 0.923 → 1.5385
#   Alpha:               0.5917534048233494
#   Num changes:         3
#   Design Depth:        222
#   Design Size (|D|):   710
#   Open set size:       1747
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2943359.187
#   Best Cost (y):       28147943735.066
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2943359.187
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2402
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8581
#   Efficiency z (srs):  0.201 → 0.173 → 0.2796
#   Efficiency y (srs):  1.655 → 0.923 → 1.5387
#   Alpha:               0.8836524985434819
#   Num changes:         3
#   Design Depth:        222
#   Design Size (|D|):   710
#   Open set size:       1751
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2843508.323
#   Best Cost (y):       28091522354.3564
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2843508.323
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2487
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8598
#   Efficiency z (srs):  0.201 → 0.173 → 0.2895
#   Efficiency y (srs):  1.655 → 0.923 → 1.5418
#   Alpha:               0.88399158423506
#   Num changes:         4
#   Design Depth:        262
#   Design Size (|D|):   790
#   Open set size:       2034
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2836308.629
#   Best Cost (y):       28176822492.6717
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2836308.629
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2493
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8572
#   Efficiency z (srs):  0.201 → 0.173 → 0.2902
#   Efficiency y (srs):  1.655 → 0.923 → 1.5371
#   Alpha:               0.8757576686419841
#   Num changes:         3
#   Design Depth:        261
#   Design Size (|D|):   788
#   Open set size:       2039
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2798477.17
#   Best Cost (y):       28523423819.2466
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2798477.17
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2527
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8468
#   Efficiency z (srs):  0.201 → 0.173 → 0.2941
#   Efficiency y (srs):  1.655 → 0.923 → 1.5184
#   Alpha:               0.6781734305961746
#   Num changes:         1
#   Design Depth:        293
#   Design Size (|D|):   852
#   Open set size:       2321
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2796657.375
#   Best Cost (y):       28498026852.7724
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2796657.375
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2528
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8475
#   Efficiency z (srs):  0.201 → 0.173 → 0.2943
#   Efficiency y (srs):  1.655 → 0.923 → 1.5198
#   Alpha:               0.8233279769469198
#   Num changes:         1
#   Design Depth:        293
#   Design Size (|D|):   852
#   Open set size:       2327
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2785663.955
#   Best Cost (y):       28572775248.2768
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2785663.955
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2538
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8453
#   Efficiency z (srs):  0.201 → 0.173 → 0.2955
#   Efficiency y (srs):  1.655 → 0.923 → 1.5158
#   Alpha:               0.8783683643200105
#   Num changes:         1
#   Design Depth:        293
#   Design Size (|D|):   852
#   Open set size:       2336
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2738684.744
#   Best Cost (y):       28594881235.9681
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2738684.744
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2582
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8447
#   Efficiency z (srs):  0.201 → 0.173 → 0.3005
#   Efficiency y (srs):  1.655 → 0.923 → 1.5146
#   Alpha:               0.5499477341324596
#   Num changes:         2
#   Design Depth:        327
#   Design Size (|D|):   920
#   Open set size:       2626
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2738450.519
#   Best Cost (y):       28606460345.4894
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2738450.519
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2582
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8443
#   Efficiency z (srs):  0.201 → 0.173 → 0.3006
#   Efficiency y (srs):  1.655 → 0.923 → 1.514
#   Alpha:               0.5320809551583462
#   Num changes:         1
#   Design Depth:        326
#   Design Size (|D|):   918
#   Open set size:       2637
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2738070.063
#   Best Cost (y):       28568088756.5832
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2738070.063
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2582
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8455
#   Efficiency z (srs):  0.201 → 0.173 → 0.3006
#   Efficiency y (srs):  1.655 → 0.923 → 1.5161
#   Alpha:               0.2957391568745098
#   Num changes:         5
#   Design Depth:        330
#   Design Size (|D|):   926
#   Open set size:       2640
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2692776.226
#   Best Cost (y):       28308431906.89
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2692776.226
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2626
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8532
#   Efficiency z (srs):  0.201 → 0.173 → 0.3057
#   Efficiency y (srs):  1.655 → 0.923 → 1.53
#   Alpha:               0.24326738626430464
#   Num changes:         4
#   Design Depth:        361
#   Design Size (|D|):   988
#   Open set size:       2911
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2691365.2
#   Best Cost (y):       28243366073.1074
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2691365.2
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2627
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8552
#   Efficiency z (srs):  0.201 → 0.173 → 0.3058
#   Efficiency y (srs):  1.655 → 0.923 → 1.5335
#   Alpha:               0.8385913412344318
#   Num changes:         3
#   Design Depth:        360
#   Design Size (|D|):   986
#   Open set size:       2912
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2670449.427
#   Best Cost (y):       28296431800.188
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2670449.427
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2648
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8536
#   Efficiency z (srs):  0.201 → 0.173 → 0.3082
#   Efficiency y (srs):  1.655 → 0.923 → 1.5306
#   Alpha:               0.8195723973651758
#   Num changes:         5
#   Design Depth:        362
#   Design Size (|D|):   990
#   Open set size:       2921
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2643237.247
#   Best Cost (y):       28379363871.4362
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2643237.247
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2675
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8511
#   Efficiency z (srs):  0.201 → 0.173 → 0.3114
#   Efficiency y (srs):  1.655 → 0.923 → 1.5261
#   Alpha:               0.8363398786361074
#   Num changes:         5
#   Design Depth:        400
#   Design Size (|D|):   1066
#   Open set size:       3192
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2643192.431
#   Best Cost (y):       28356513542.2756
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2643192.431
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2675
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8518
#   Efficiency z (srs):  0.201 → 0.173 → 0.3114
#   Efficiency y (srs):  1.655 → 0.923 → 1.5274
#   Alpha:               0.5428379745702371
#   Num changes:         4
#   Design Depth:        399
#   Design Size (|D|):   1064
#   Open set size:       3215
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2579335.447
#   Best Cost (y):       28315592670.1115
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2579335.447
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2741
#   Efficiency y (0→f):  0.923 → 0.923 → 0.853
#   Efficiency z (srs):  0.201 → 0.173 → 0.3191
#   Efficiency y (srs):  1.655 → 0.923 → 1.5296
#   Alpha:               0.7372763417126457
#   Num changes:         5
#   Design Depth:        430
#   Design Size (|D|):   1126
#   Open set size:       3487
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2575778.61
#   Best Cost (y):       28328621349.3517
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2575778.61
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2745
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8526
#   Efficiency z (srs):  0.201 → 0.173 → 0.3195
#   Efficiency y (srs):  1.655 → 0.923 → 1.5289
#   Alpha:               0.6316329119888409
#   Num changes:         5
#   Design Depth:        430
#   Design Size (|D|):   1126
#   Open set size:       3488
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2540140.266
#   Best Cost (y):       28235919479.3324
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2540140.266
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2784
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8554
#   Efficiency z (srs):  0.201 → 0.173 → 0.324
#   Efficiency y (srs):  1.655 → 0.923 → 1.5339
#   Alpha:               0.6744433985828397
#   Num changes:         3
#   Design Depth:        463
#   Design Size (|D|):   1192
#   Open set size:       3773
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2510098.013
#   Best Cost (y):       28329641103.4909
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2510098.013
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2817
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8526
#   Efficiency z (srs):  0.201 → 0.173 → 0.3279
#   Efficiency y (srs):  1.655 → 0.923 → 1.5288
#   Alpha:               0.5692558258078734
#   Num changes:         2
#   Design Depth:        493
#   Design Size (|D|):   1252
#   Open set size:       4063
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2474741.42
#   Best Cost (y):       28357797340.7142
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2474741.42
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2857
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8517
#   Efficiency z (srs):  0.201 → 0.173 → 0.3326
#   Efficiency y (srs):  1.655 → 0.923 → 1.5273
#   Alpha:               0.7142074564767372
#   Num changes:         4
#   Design Depth:        521
#   Design Size (|D|):   1308
#   Open set size:       4352
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2460124.176
#   Best Cost (y):       28294224265.728
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2460124.176
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2874
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8536
#   Efficiency z (srs):  0.201 → 0.173 → 0.3346
#   Efficiency y (srs):  1.655 → 0.923 → 1.5307
#   Alpha:               0.32680618741063877
#   Num changes:         5
#   Design Depth:        553
#   Design Size (|D|):   1372
#   Open set size:       4641
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   13257→13257.0, 757246→757245.97
#   Best Cost (z):       2456721.902
#   Best Cost (y):       28343128285.918
#   rho (z, y):          0.8
#   rho (z_hat, y_hat):  0.336
#   rho (p, y):          0.605
#   Criteria Value:      2456721.902
#   Efficiency z (0→f):  0.173 → 0.173 → 0.2878
#   Efficiency y (0→f):  0.923 → 0.923 → 0.8522
#   Efficiency z (srs):  0.201 → 0.173 → 0.335
#   Efficiency y (srs):  1.655 → 0.923 → 1.5281
#   Alpha:               0.8795099159589349
#   Num changes:         4
#   Design Depth:        552
#   Design Size (|D|):   1370
#   Open set size:       4649
#
# Progress: 4.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 85
#      59 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      60                    inclusion_probability=inclusions, balance_method='origin')
#      62 astar = AStar(
#      63     inclusions              = inclusions,
#      64     num_initial_nodes       = num_initial_nodes,
#    (...)     82     # delta                   = 0.01,
#      83 )
# ---> 85 result = astar.run(
#      86     max_iterations             = max_iterations,
#      87     num_new_nodes              = num_new_nodes,
#      88     max_open_set_size          = max_open_set_size,
#      89     random_restart_period      = random_restart_period,
#      90     random_injection_count     = random_injection_count,
#      91     prune_fraction             = prune_fraction,
#      92     num_top_restart_nodes      = num_top_restart_nodes,
#      93     stuck_fraction             = stuck_fraction,
#      94
#      95 )
#      97 print("Best criteria value:", astar.best_criteria_value)
#      98 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:269, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     266 if new_design in closed_set or new_design in open_set:
#     267     continue
# --> 269 _ = self.criteria(new_design)
#     270 new_criteria_value = self.criteria.var_NHT
#     271 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:24, in VarNHT.__call__(self, design)
#      13 NHT_estimator_z = np.array([
#      14     np.sum(self.auxiliary_variable[list(sample.ids)] /
#      15            self.inclusion_probability[list(sample.ids)])
#      16     for sample in design
#      17 ])
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
# ---> 24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
#      29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#      33 samples_probabilities = np.array([sample.probability for sample in design])
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:69, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#      60         # class, but its signature is not identical to that of NumPy's. This
#    (...)     64         # Call _wrapit from within the except clause to ensure a potential
#      65         # exception has a traceback chain.
#      66         return _wrapit(obj, method, *args, **kwds)
# ---> 69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      73     if type(obj) is not mu.ndarray:
#
# KeyboardInterrupt:

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
