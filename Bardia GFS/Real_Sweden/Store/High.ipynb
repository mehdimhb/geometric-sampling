# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
#
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
# #y <- RMT85; z <- ME84 ; p <- P75 # be rahe!
# # y <- RMT85; z <- ME84 ; p <- S82
# # y <- RMT85; z <- ME84 ; p <- SS82
# #  y <- RMT85; z <- ME84 ; p <- e
#
#
#
# y <- REV84; z <- P75 ; p <- ME84 # be rahe!
# # y <- REV84; z <- P75 ; p <- CS82
# # y <- REV84; z <- P75 ; p <- REG
# #  y <- REV84; z <- P75 ; p <- e
#
#
#
#
#
#
#
# # data(mtcars)
# # y <- mtcars$cyl; z <- mtcars$disp; p <- mtcars$hp # be rahe!
#
#
# N = length(y)
# n = 10
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# print(c(N, n))
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
#
#
# #################################
# ############ Plots and Prints ###
# #################################
# plot(z, y)
# plot(z/pik, y/pik)
#
# if(1==0){
#   par(mfrow=c(2,3))
#   plot(y, z)
#   plot(p, z)
#   plot(p, y)
#
#   plot(z_hat, y_hat)
#   plot(p/pik, y_hat)
#
#   plot(p/pik, z_hat)
#   par(mfrow=c(2,3))
# #cat('x,y', cor(x,y), '\n x,z', cor(z, x), '\n y,z', cor(z, y), "\n")
# plot(y, z)
# plot(p,z)
# plot(p,y)
#
# plot(z_hat,y_hat)
# plot(p/pik,y_hat)
#
# plot(p/pik,z_hat)
#
#
# cat("x_NHT, y_NHT", cor(p/pik,y/pik), "x, z", cor(p,z), "z_NHT, y_NHT", cor(z/pik,y/pik) , "\n")
#
# z_hat = z/pik
# print(var_z)
# print(var_y)
# cat("x threshold", threshold_z, "\n", "y threshold", threshold_y, "\n")
#
#
# #cat("x_NHT, y_NHT", cor(p/pik,y/pik), "x, z", cor(x,z), "z_NHT, y_NHT", cor(z/pik,y/pik))
# Final_result = cbind(y,z, y_hat, z_hat, pik, abs((y_hat- z_hat)/y_hat))
#
# print(c(N,n))
#
# }
# Out:
# [1] 284
# [1] 281
# [1] 0.03558719
# [1] 281  10

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(2,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): 445.0848 (p=1.05e-06)
#   beta  (Slope)    : 92.7218 (p=7.691e-104)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 38512.8282 (p=0.08437)
#   beta  (Slope)    : 68.7594 (p=0.02074)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): 2321.3351 (p=2.414e-16)
#   beta  (Slope)    : 0.0042 (p=0.09781)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 87.9266 (p=4.697e-22)
#   beta  (Slope)    : -0.0856 (p=2.179e-13)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# Variance of HT estimator via DSD formula_z:  6868.793
# Variance of HT estimator via DSD formula:  13240843743
# Here is the Vincent Efficiency y:
#   DSD_y:  0.97009
#   DSD_z: 9.14404
# Monte Carlo variance of HT estimator for y:
#   DSD:  12699167789.74933
#   Cube: 13250886994.56681
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.01147
#   Cube: 0.96935
# Monte Carlo mean of HT estimator for y:
#   DSD:  756378.38869
#   Cube: 759502.16750
#   Actual total of y: 757246.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  7014.77259
#   Cube: 13296.12409
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  8.95375
#   Cube: 4.72382
# Monte Carlo mean of HT estimator for z:
#   DSD:  6816.32918
#   Cube: 6816.53016
#   Actual total of z: 6818.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#       65.51      309.44      598.99        3.38        3.28        3.28

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])

inclusions = np.array(inclusions)

import numpy as np

num_new_nodes          = 20
num_changes_lower      = 1
num_changes_upper      = 1
max_open_set_size      = 200000
switch_lower           = .9
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/10)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = (1/eff_dsd_z) * .1  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='origin')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_8139/2647086163.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/10)
# cor(y, z) 0.9021075017829231
# cor(y, inclusions) 0.9054582231011578
# 4000 20 200000 0.9 0.9
# Generating initial designs: 100%|████████████| 1/1 [00:00<00:00, 35.57it/s]
# Initial design 0: method = Original, efficiency z = 0.2105, y=1.0411
# New best at idx=0: method = Original, efficiency z = 0.2105 and efficiency y = 1.0411
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       31951.337
#   Best Cost (y):       12666192627.2546
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      31951.337
#   Efficiency z (0→f):  0.21 → 0.21 → 0.215
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0454
#   Efficiency z (srs):  125.638 → 0.21 → 128.3108
#   Efficiency y (srs):  3.405 → 1.041 → 3.4194
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       1
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       31747.862
#   Best Cost (y):       12669289127.2539
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      31747.862
#   Efficiency z (0→f):  0.21 → 0.21 → 0.2164
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0451
#   Efficiency z (srs):  125.638 → 0.21 → 129.1332
#   Efficiency y (srs):  3.405 → 1.041 → 3.4186
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       34
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       29126.216
#   Best Cost (y):       12589328548.3235
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      29126.216
#   Efficiency z (0→f):  0.21 → 0.21 → 0.2358
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0518
#   Efficiency z (srs):  125.638 → 0.21 → 140.7564
#   Efficiency y (srs):  3.405 → 1.041 → 3.4403
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        15
#   Design Size (|D|):   311
#   Open set size:       337
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       26186.713
#   Best Cost (y):       12432998585.7665
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      26186.713
#   Efficiency z (0→f):  0.21 → 0.21 → 0.2623
#   Efficiency y (0→f):  1.041 → 1.041 → 1.065
#   Efficiency z (srs):  125.638 → 0.21 → 156.5566
#   Efficiency y (srs):  3.405 → 1.041 → 3.4836
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       510
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       21219.917
#   Best Cost (y):       12367388911.6968
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      21219.917
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3237
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0706
#   Efficiency z (srs):  125.638 → 0.21 → 193.2007
#   Efficiency y (srs):  3.405 → 1.041 → 3.502
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        55
#   Design Size (|D|):   391
#   Open set size:       1206
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       21214.471
#   Best Cost (y):       12379289761.9731
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      21214.471
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3238
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0696
#   Efficiency z (srs):  125.638 → 0.21 → 193.2503
#   Efficiency y (srs):  3.405 → 1.041 → 3.4987
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        55
#   Design Size (|D|):   391
#   Open set size:       1207
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       20281.75
#   Best Cost (y):       12473033886.5091
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      20281.75
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3387
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0616
#   Efficiency z (srs):  125.638 → 0.21 → 202.1375
#   Efficiency y (srs):  3.405 → 1.041 → 3.4724
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        72
#   Design Size (|D|):   425
#   Open set size:       1530
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19398.996
#   Best Cost (y):       12388465323.9829
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      19398.996
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3541
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0688
#   Efficiency z (srs):  125.638 → 0.21 → 211.3358
#   Efficiency y (srs):  3.405 → 1.041 → 3.4961
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       1870
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19320.775
#   Best Cost (y):       12376276294.5798
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      19320.775
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3555
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0699
#   Efficiency z (srs):  125.638 → 0.21 → 212.1914
#   Efficiency y (srs):  3.405 → 1.041 → 3.4995
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       1872
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19310.721
#   Best Cost (y):       12366121027.7575
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      19310.721
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3557
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0707
#   Efficiency z (srs):  125.638 → 0.21 → 212.3019
#   Efficiency y (srs):  3.405 → 1.041 → 3.5024
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       1875
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19307.774
#   Best Cost (y):       12355193818.783
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      19307.774
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3558
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0717
#   Efficiency z (srs):  125.638 → 0.21 → 212.3343
#   Efficiency y (srs):  3.405 → 1.041 → 3.5055
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       1878
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19288.509
#   Best Cost (y):       12398565180.5775
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      19288.509
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3561
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0679
#   Efficiency z (srs):  125.638 → 0.21 → 212.5463
#   Efficiency y (srs):  3.405 → 1.041 → 3.4932
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        91
#   Design Size (|D|):   463
#   Open set size:       2030
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       19288.446
#   Best Cost (y):       12415450986.2486
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      19288.446
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3561
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0665
#   Efficiency z (srs):  125.638 → 0.21 → 212.547
#   Efficiency y (srs):  3.405 → 1.041 → 3.4885
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        91
#   Design Size (|D|):   463
#   Open set size:       2040
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18550.889
#   Best Cost (y):       12678561198.0746
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      18550.889
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3703
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0443
#   Efficiency z (srs):  125.638 → 0.21 → 220.9976
#   Efficiency y (srs):  3.405 → 1.041 → 3.4161
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        128
#   Design Size (|D|):   537
#   Open set size:       3042
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18161.658
#   Best Cost (y):       12559146512.9667
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      18161.658
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3782
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0543
#   Efficiency z (srs):  125.638 → 0.21 → 225.7339
#   Efficiency y (srs):  3.405 → 1.041 → 3.4486
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        138
#   Design Size (|D|):   557
#   Open set size:       3200
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18095.156
#   Best Cost (y):       12558401480.992
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      18095.156
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3796
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0543
#   Efficiency z (srs):  125.638 → 0.21 → 226.5635
#   Efficiency y (srs):  3.405 → 1.041 → 3.4488
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        138
#   Design Size (|D|):   557
#   Open set size:       3207
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18068.231
#   Best Cost (y):       12558202704.8148
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      18068.231
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3802
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0544
#   Efficiency z (srs):  125.638 → 0.21 → 226.9011
#   Efficiency y (srs):  3.405 → 1.041 → 3.4488
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        138
#   Design Size (|D|):   557
#   Open set size:       3209
#
#
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       18063.18
#   Best Cost (y):       12558534275.8815
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      18063.18
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3803
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0543
#   Efficiency z (srs):  125.638 → 0.21 → 226.9646
#   Efficiency y (srs):  3.405 → 1.041 → 3.4487
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        138
#   Design Size (|D|):   557
#   Open set size:       3215
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17757.856
#   Best Cost (y):       12515128456.4943
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      17757.856
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3868
#   Efficiency y (0→f):  1.041 → 1.041 → 1.058
#   Efficiency z (srs):  125.638 → 0.21 → 230.8669
#   Efficiency y (srs):  3.405 → 1.041 → 3.4607
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        154
#   Design Size (|D|):   589
#   Open set size:       3533
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17755.146
#   Best Cost (y):       12488909738.8612
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      17755.146
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3869
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0602
#   Efficiency z (srs):  125.638 → 0.21 → 230.9022
#   Efficiency y (srs):  3.405 → 1.041 → 3.468
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        154
#   Design Size (|D|):   589
#   Open set size:       3544
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17754.642
#   Best Cost (y):       12506113856.9155
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      17754.642
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3869
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0587
#   Efficiency z (srs):  125.638 → 0.21 → 230.9087
#   Efficiency y (srs):  3.405 → 1.041 → 3.4632
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        154
#   Design Size (|D|):   589
#   Open set size:       3545
#
# Progress: 5.5%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17511.283
#   Best Cost (y):       12532037282.4692
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      17511.283
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3922
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0566
#   Efficiency z (srs):  125.638 → 0.21 → 234.1177
#   Efficiency y (srs):  3.405 → 1.041 → 3.456
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        164
#   Design Size (|D|):   609
#   Open set size:       3706
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       17510.734
#   Best Cost (y):       12531259907.0419
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      17510.734
#   Efficiency z (0→f):  0.21 → 0.21 → 0.3923
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0566
#   Efficiency z (srs):  125.638 → 0.21 → 234.1251
#   Efficiency y (srs):  3.405 → 1.041 → 3.4562
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        164
#   Design Size (|D|):   609
#   Open set size:       3714
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16519.678
#   Best Cost (y):       12813739989.2405
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      16519.678
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4158
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0333
#   Efficiency z (srs):  125.638 → 0.21 → 248.1708
#   Efficiency y (srs):  3.405 → 1.041 → 3.3801
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        194
#   Design Size (|D|):   669
#   Open set size:       4554
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16497.872
#   Best Cost (y):       12815081616.18
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      16497.872
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4163
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0332
#   Efficiency z (srs):  125.638 → 0.21 → 248.4988
#   Efficiency y (srs):  3.405 → 1.041 → 3.3797
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        194
#   Design Size (|D|):   669
#   Open set size:       4562
#
# Progress: 7.5%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16378.932
#   Best Cost (y):       12667102832.1865
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      16378.932
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4194
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0453
#   Efficiency z (srs):  125.638 → 0.21 → 250.3034
#   Efficiency y (srs):  3.405 → 1.041 → 3.4192
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        219
#   Design Size (|D|):   719
#   Open set size:       5052
#
#
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       16371.261
#   Best Cost (y):       12680625537.936
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      16371.261
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4196
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0442
#   Efficiency z (srs):  125.638 → 0.21 → 250.4207
#   Efficiency y (srs):  3.405 → 1.041 → 3.4155
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        219
#   Design Size (|D|):   719
#   Open set size:       5059
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15778.142
#   Best Cost (y):       12800995154.4408
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15778.142
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4353
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0344
#   Efficiency z (srs):  125.638 → 0.21 → 259.8343
#   Efficiency y (srs):  3.405 → 1.041 → 3.3834
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        229
#   Design Size (|D|):   739
#   Open set size:       5225
#
#
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15776.26
#   Best Cost (y):       12804586591.9664
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15776.26
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4354
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0341
#   Efficiency z (srs):  125.638 → 0.21 → 259.8653
#   Efficiency y (srs):  3.405 → 1.041 → 3.3825
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        229
#   Design Size (|D|):   739
#   Open set size:       5234
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15594.1
#   Best Cost (y):       12692503459.6648
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15594.1
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4405
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0432
#   Efficiency z (srs):  125.638 → 0.21 → 262.9008
#   Efficiency y (srs):  3.405 → 1.041 → 3.4123
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        239
#   Design Size (|D|):   759
#   Open set size:       5409
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15594.059
#   Best Cost (y):       12862730968.714
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15594.059
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4405
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0294
#   Efficiency z (srs):  125.638 → 0.21 → 262.9015
#   Efficiency y (srs):  3.405 → 1.041 → 3.3672
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        239
#   Design Size (|D|):   759
#   Open set size:       5414
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15220.161
#   Best Cost (y):       12872367742.2902
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15220.161
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4513
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0286
#   Efficiency z (srs):  125.638 → 0.21 → 269.36
#   Efficiency y (srs):  3.405 → 1.041 → 3.3647
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       6238
#
#
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       15218.606
#   Best Cost (y):       12878681096.3634
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15218.606
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4513
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0281
#   Efficiency z (srs):  125.638 → 0.21 → 269.3875
#   Efficiency y (srs):  3.405 → 1.041 → 3.363
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        271
#   Design Size (|D|):   823
#   Open set size:       6255
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14492.126
#   Best Cost (y):       12712918035.8634
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14492.126
#   Efficiency z (0→f):  0.21 → 0.21 → 0.474
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0415
#   Efficiency z (srs):  125.638 → 0.21 → 282.8917
#   Efficiency y (srs):  3.405 → 1.041 → 3.4069
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        299
#   Design Size (|D|):   879
#   Open set size:       6750
#
#
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14492.094
#   Best Cost (y):       12711788100.5407
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14492.094
#   Efficiency z (0→f):  0.21 → 0.21 → 0.474
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0416
#   Efficiency z (srs):  125.638 → 0.21 → 282.8923
#   Efficiency y (srs):  3.405 → 1.041 → 3.4072
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        299
#   Design Size (|D|):   879
#   Open set size:       6751
#
#
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14492.074
#   Best Cost (y):       12712882080.0744
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14492.074
#   Efficiency z (0→f):  0.21 → 0.21 → 0.474
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0415
#   Efficiency z (srs):  125.638 → 0.21 → 282.8927
#   Efficiency y (srs):  3.405 → 1.041 → 3.4069
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        299
#   Design Size (|D|):   879
#   Open set size:       6762
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14340.703
#   Best Cost (y):       12667911372.5311
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14340.703
#   Efficiency z (0→f):  0.21 → 0.21 → 0.479
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0452
#   Efficiency z (srs):  125.638 → 0.21 → 285.8787
#   Efficiency y (srs):  3.405 → 1.041 → 3.419
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        309
#   Design Size (|D|):   899
#   Open set size:       6915
#
# Progress: 10.5%
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14119.746
#   Best Cost (y):       12669104600.5114
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14119.746
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4865
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0451
#   Efficiency z (srs):  125.638 → 0.21 → 290.3524
#   Efficiency y (srs):  3.405 → 1.041 → 3.4186
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        319
#   Design Size (|D|):   919
#   Open set size:       7084
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14114.729
#   Best Cost (y):       12665672693.3716
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14114.729
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4866
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0454
#   Efficiency z (srs):  125.638 → 0.21 → 290.4556
#   Efficiency y (srs):  3.405 → 1.041 → 3.4196
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        319
#   Design Size (|D|):   919
#   Open set size:       7087
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14114.526
#   Best Cost (y):       12654008537.4893
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14114.526
#   Efficiency z (0→f):  0.21 → 0.21 → 0.4866
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0464
#   Efficiency z (srs):  125.638 → 0.21 → 290.4598
#   Efficiency y (srs):  3.405 → 1.041 → 3.4227
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        319
#   Design Size (|D|):   919
#   Open set size:       7093
#
# Progress: 10.8%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14104.811
#   Best Cost (y):       12684218770.5137
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14104.811
#   Efficiency z (0→f):  0.21 → 0.21 → 0.487
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0439
#   Efficiency z (srs):  125.638 → 0.21 → 290.6598
#   Efficiency y (srs):  3.405 → 1.041 → 3.4146
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        327
#   Design Size (|D|):   935
#   Open set size:       7259
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14104.702
#   Best Cost (y):       12681439687.1312
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14104.702
#   Efficiency z (0→f):  0.21 → 0.21 → 0.487
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0441
#   Efficiency z (srs):  125.638 → 0.21 → 290.6621
#   Efficiency y (srs):  3.405 → 1.041 → 3.4153
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        327
#   Design Size (|D|):   935
#   Open set size:       7262
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       14104.446
#   Best Cost (y):       12678037281.6383
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14104.446
#   Efficiency z (0→f):  0.21 → 0.21 → 0.487
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0444
#   Efficiency z (srs):  125.638 → 0.21 → 290.6673
#   Efficiency y (srs):  3.405 → 1.041 → 3.4162
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        327
#   Design Size (|D|):   935
#   Open set size:       7263
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       13657.705
#   Best Cost (y):       12645872493.2271
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13657.705
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5029
#   Efficiency y (0→f):  1.041 → 1.041 → 1.047
#   Efficiency z (srs):  125.638 → 0.21 → 300.175
#   Efficiency y (srs):  3.405 → 1.041 → 3.4249
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        336
#   Design Size (|D|):   953
#   Open set size:       7421
#
# Progress: 11.5%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       13448.695
#   Best Cost (y):       12531469430.3174
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13448.695
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5107
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0566
#   Efficiency z (srs):  125.638 → 0.21 → 304.8401
#   Efficiency y (srs):  3.405 → 1.041 → 3.4562
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        351
#   Design Size (|D|):   983
#   Open set size:       7772
#
# Progress: 12.8%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       13114.66
#   Best Cost (y):       12647089704.2228
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13114.66
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5237
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0469
#   Efficiency z (srs):  125.638 → 0.21 → 312.6045
#   Efficiency y (srs):  3.405 → 1.041 → 3.4246
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        382
#   Design Size (|D|):   1045
#   Open set size:       8590
#
#
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       13112.857
#   Best Cost (y):       12647549424.4319
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13112.857
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5238
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0469
#   Efficiency z (srs):  125.638 → 0.21 → 312.6475
#   Efficiency y (srs):  3.405 → 1.041 → 3.4245
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        382
#   Design Size (|D|):   1045
#   Open set size:       8602
#
#
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       13112.609
#   Best Cost (y):       12647367021.2896
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13112.609
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5238
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0469
#   Efficiency z (srs):  125.638 → 0.21 → 312.6534
#   Efficiency y (srs):  3.405 → 1.041 → 3.4245
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        382
#   Design Size (|D|):   1045
#   Open set size:       8603
#
# Progress: 13.2%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       13034.499
#   Best Cost (y):       12564978849.8377
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13034.499
#   Efficiency z (0→f):  0.21 → 0.21 → 0.527
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0538
#   Efficiency z (srs):  125.638 → 0.21 → 314.527
#   Efficiency y (srs):  3.405 → 1.041 → 3.447
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        393
#   Design Size (|D|):   1067
#   Open set size:       8935
#
# Progress: 13.8%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12889.701
#   Best Cost (y):       12645722811.8336
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12889.701
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5329
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0471
#   Efficiency z (srs):  125.638 → 0.21 → 318.0603
#   Efficiency y (srs):  3.405 → 1.041 → 3.425
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        410
#   Design Size (|D|):   1101
#   Open set size:       9266
#
#
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12881.71
#   Best Cost (y):       12624526406.4277
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12881.71
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5332
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0488
#   Efficiency z (srs):  125.638 → 0.21 → 318.2576
#   Efficiency y (srs):  3.405 → 1.041 → 3.4307
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        410
#   Design Size (|D|):   1101
#   Open set size:       9272
#
#
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12877.492
#   Best Cost (y):       12600514839.3532
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12877.492
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5334
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0508
#   Efficiency z (srs):  125.638 → 0.21 → 318.3618
#   Efficiency y (srs):  3.405 → 1.041 → 3.4372
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        410
#   Design Size (|D|):   1101
#   Open set size:       9278
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12732.341
#   Best Cost (y):       12720151995.6744
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12732.341
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5395
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0409
#   Efficiency z (srs):  125.638 → 0.21 → 321.9912
#   Efficiency y (srs):  3.405 → 1.041 → 3.4049
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       9428
#
#
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12731.533
#   Best Cost (y):       12664218144.8736
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12731.533
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5395
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0455
#   Efficiency z (srs):  125.638 → 0.21 → 322.0116
#   Efficiency y (srs):  3.405 → 1.041 → 3.42
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        420
#   Design Size (|D|):   1121
#   Open set size:       9441
#
# Progress: 14.2%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12480.568
#   Best Cost (y):       12656885025.7091
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12480.568
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5504
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0461
#   Efficiency z (srs):  125.638 → 0.21 → 328.4868
#   Efficiency y (srs):  3.405 → 1.041 → 3.4219
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        429
#   Design Size (|D|):   1139
#   Open set size:       9592
#
#
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12439.319
#   Best Cost (y):       12690063599.5596
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12439.319
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5522
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0434
#   Efficiency z (srs):  125.638 → 0.21 → 329.5761
#   Efficiency y (srs):  3.405 → 1.041 → 3.413
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        429
#   Design Size (|D|):   1139
#   Open set size:       9600
#
# Progress: 14.5%
# === Best Solution Updated at Iteration 580 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       12407.315
#   Best Cost (y):       12699848496.8058
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12407.315
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5536
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0426
#   Efficiency z (srs):  125.638 → 0.21 → 330.4262
#   Efficiency y (srs):  3.405 → 1.041 → 3.4104
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        437
#   Design Size (|D|):   1155
#   Open set size:       9768
#
# Progress: 16.2%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11895.581
#   Best Cost (y):       12930446803.7781
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11895.581
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5774
#   Efficiency y (0→f):  1.041 → 1.041 → 1.024
#   Efficiency z (srs):  125.638 → 0.21 → 344.6408
#   Efficiency y (srs):  3.405 → 1.041 → 3.3495
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        491
#   Design Size (|D|):   1263
#   Open set size:       10949
#
# Progress: 20.5%
# === Best Solution Updated at Iteration 820 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11535.296
#   Best Cost (y):       13167472957.6003
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11535.296
#   Efficiency z (0→f):  0.21 → 0.21 → 0.5955
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0056
#   Efficiency z (srs):  125.638 → 0.21 → 355.405
#   Efficiency y (srs):  3.405 → 1.041 → 3.2892
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        554
#   Design Size (|D|):   1389
#   Open set size:       13797
#
# Progress: 21.2%
# === Best Solution Updated at Iteration 850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11408.076
#   Best Cost (y):       13132512975.3409
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11408.076
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6021
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0082
#   Efficiency z (srs):  125.638 → 0.21 → 359.3684
#   Efficiency y (srs):  3.405 → 1.041 → 3.298
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        569
#   Design Size (|D|):   1419
#   Open set size:       14303
#
#
# === Best Solution Updated at Iteration 850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11404.012
#   Best Cost (y):       13139574370.592
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11404.012
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6023
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0077
#   Efficiency z (srs):  125.638 → 0.21 → 359.4965
#   Efficiency y (srs):  3.405 → 1.041 → 3.2962
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        569
#   Design Size (|D|):   1419
#   Open set size:       14311
#
#
# === Best Solution Updated at Iteration 850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11403.875
#   Best Cost (y):       13132863701.7292
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11403.875
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6023
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0082
#   Efficiency z (srs):  125.638 → 0.21 → 359.5008
#   Efficiency y (srs):  3.405 → 1.041 → 3.2979
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        569
#   Design Size (|D|):   1419
#   Open set size:       14313
#
# Progress: 22.0%
# === Best Solution Updated at Iteration 880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11206.578
#   Best Cost (y):       13171064820.8568
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11206.578
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6129
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0053
#   Efficiency z (srs):  125.638 → 0.21 → 365.83
#   Efficiency y (srs):  3.405 → 1.041 → 3.2884
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        594
#   Design Size (|D|):   1469
#   Open set size:       14814
#
# Progress: 22.2%
# === Best Solution Updated at Iteration 890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11128.416
#   Best Cost (y):       13473383866.7727
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11128.416
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6172
#   Efficiency y (0→f):  1.041 → 1.041 → 0.9827
#   Efficiency z (srs):  125.638 → 0.21 → 368.3994
#   Efficiency y (srs):  3.405 → 1.041 → 3.2146
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        604
#   Design Size (|D|):   1489
#   Open set size:       14992
#
# Progress: 22.8%
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11008.189
#   Best Cost (y):       13458446674.9272
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11008.189
#   Efficiency z (0→f):  0.21 → 0.21 → 0.624
#   Efficiency y (0→f):  1.041 → 1.041 → 0.9838
#   Efficiency z (srs):  125.638 → 0.21 → 372.4229
#   Efficiency y (srs):  3.405 → 1.041 → 3.2181
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        622
#   Design Size (|D|):   1525
#   Open set size:       15316
#
#
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       11006.594
#   Best Cost (y):       13459001135.5092
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11006.594
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6241
#   Efficiency y (0→f):  1.041 → 1.041 → 0.9838
#   Efficiency z (srs):  125.638 → 0.21 → 372.4769
#   Efficiency y (srs):  3.405 → 1.041 → 3.218
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        622
#   Design Size (|D|):   1525
#   Open set size:       15317
#
# Progress: 24.5%
# === Best Solution Updated at Iteration 980 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10847.805
#   Best Cost (y):       13172541596.0918
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10847.805
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6332
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0052
#   Efficiency z (srs):  125.638 → 0.21 → 377.9292
#   Efficiency y (srs):  3.405 → 1.041 → 3.288
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        653
#   Design Size (|D|):   1587
#   Open set size:       16517
#
# Progress: 25.8%
# === Best Solution Updated at Iteration 1030 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10726.781
#   Best Cost (y):       12857697672.608
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10726.781
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6403
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0298
#   Efficiency z (srs):  125.638 → 0.21 → 382.1931
#   Efficiency y (srs):  3.405 → 1.041 → 3.3685
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        683
#   Design Size (|D|):   1647
#   Open set size:       17368
#
# Progress: 26.0%
# === Best Solution Updated at Iteration 1040 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10687.19
#   Best Cost (y):       12805908641.3038
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10687.19
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6427
#   Efficiency y (0→f):  1.041 → 1.041 → 1.034
#   Efficiency z (srs):  125.638 → 0.21 → 383.609
#   Efficiency y (srs):  3.405 → 1.041 → 3.3821
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        692
#   Design Size (|D|):   1665
#   Open set size:       17538
#
#
# === Best Solution Updated at Iteration 1040 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10687.14
#   Best Cost (y):       12804063538.7787
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10687.14
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6427
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0341
#   Efficiency z (srs):  125.638 → 0.21 → 383.6108
#   Efficiency y (srs):  3.405 → 1.041 → 3.3826
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        692
#   Design Size (|D|):   1665
#   Open set size:       17549
#
# Progress: 27.5%
# === Best Solution Updated at Iteration 1100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10635.022
#   Best Cost (y):       12916693185.6189
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10635.022
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6459
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0251
#   Efficiency z (srs):  125.638 → 0.21 → 385.4907
#   Efficiency y (srs):  3.405 → 1.041 → 3.3531
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        728
#   Design Size (|D|):   1737
#   Open set size:       18553
#
# Progress: 28.2%
# === Best Solution Updated at Iteration 1130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10466.213
#   Best Cost (y):       12892121851.1431
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10466.213
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6563
#   Efficiency y (0→f):  1.041 → 1.041 → 1.027
#   Efficiency z (srs):  125.638 → 0.21 → 391.7083
#   Efficiency y (srs):  3.405 → 1.041 → 3.3595
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        749
#   Design Size (|D|):   1779
#   Open set size:       19062
#
# Progress: 28.7%
# === Best Solution Updated at Iteration 1150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10437.163
#   Best Cost (y):       12971347895.253
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10437.163
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6581
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0208
#   Efficiency z (srs):  125.638 → 0.21 → 392.7985
#   Efficiency y (srs):  3.405 → 1.041 → 3.339
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        765
#   Design Size (|D|):   1811
#   Open set size:       19387
#
#
# === Best Solution Updated at Iteration 1150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10435.37
#   Best Cost (y):       12971921116.7074
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10435.37
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6582
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0207
#   Efficiency z (srs):  125.638 → 0.21 → 392.866
#   Efficiency y (srs):  3.405 → 1.041 → 3.3388
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        765
#   Design Size (|D|):   1811
#   Open set size:       19391
#
#
# === Best Solution Updated at Iteration 1150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10432.578
#   Best Cost (y):       12972137769.9083
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10432.578
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6584
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0207
#   Efficiency z (srs):  125.638 → 0.21 → 392.9711
#   Efficiency y (srs):  3.405 → 1.041 → 3.3388
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        765
#   Design Size (|D|):   1811
#   Open set size:       19399
#
# Progress: 29.2%
# === Best Solution Updated at Iteration 1170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10398.192
#   Best Cost (y):       12975019734.7368
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10398.192
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6606
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0205
#   Efficiency z (srs):  125.638 → 0.21 → 394.2707
#   Efficiency y (srs):  3.405 → 1.041 → 3.338
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        784
#   Design Size (|D|):   1849
#   Open set size:       19727
#
#
# === Best Solution Updated at Iteration 1170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10390.194
#   Best Cost (y):       12975268884.533
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10390.194
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6611
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0205
#   Efficiency z (srs):  125.638 → 0.21 → 394.5741
#   Efficiency y (srs):  3.405 → 1.041 → 3.338
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        784
#   Design Size (|D|):   1849
#   Open set size:       19730
#
#
# === Best Solution Updated at Iteration 1170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10389.999
#   Best Cost (y):       12977362821.8437
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10389.999
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6611
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0203
#   Efficiency z (srs):  125.638 → 0.21 → 394.5816
#   Efficiency y (srs):  3.405 → 1.041 → 3.3374
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        784
#   Design Size (|D|):   1849
#   Open set size:       19735
#
#
# === Best Solution Updated at Iteration 1170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10389.812
#   Best Cost (y):       12974777333.6933
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10389.812
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6611
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0205
#   Efficiency z (srs):  125.638 → 0.21 → 394.5886
#   Efficiency y (srs):  3.405 → 1.041 → 3.3381
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        784
#   Design Size (|D|):   1849
#   Open set size:       19738
#
# Progress: 29.5%
# === Best Solution Updated at Iteration 1180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10370.997
#   Best Cost (y):       12966460216.0877
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10370.997
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6623
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0212
#   Efficiency z (srs):  125.638 → 0.21 → 395.3045
#   Efficiency y (srs):  3.405 → 1.041 → 3.3402
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        794
#   Design Size (|D|):   1869
#   Open set size:       19893
#
#
# === Best Solution Updated at Iteration 1180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10370.279
#   Best Cost (y):       12966721371.7036
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10370.279
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6624
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0211
#   Efficiency z (srs):  125.638 → 0.21 → 395.3319
#   Efficiency y (srs):  3.405 → 1.041 → 3.3402
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        794
#   Design Size (|D|):   1869
#   Open set size:       19897
#
#
# === Best Solution Updated at Iteration 1180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       10370.111
#   Best Cost (y):       12964638240.8492
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10370.111
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6624
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0213
#   Efficiency z (srs):  125.638 → 0.21 → 395.3383
#   Efficiency y (srs):  3.405 → 1.041 → 3.3407
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        794
#   Design Size (|D|):   1869
#   Open set size:       19908
#
# Progress: 30.8%
# === Best Solution Updated at Iteration 1230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9998.722
#   Best Cost (y):       12970405109.1881
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9998.722
#   Efficiency z (0→f):  0.21 → 0.21 → 0.687
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0209
#   Efficiency z (srs):  125.638 → 0.21 → 410.0226
#   Efficiency y (srs):  3.405 → 1.041 → 3.3392
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        835
#   Design Size (|D|):   1951
#   Open set size:       20737
#
#
# === Best Solution Updated at Iteration 1230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9991.657
#   Best Cost (y):       12974013809.4355
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9991.657
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6875
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0206
#   Efficiency z (srs):  125.638 → 0.21 → 410.3125
#   Efficiency y (srs):  3.405 → 1.041 → 3.3383
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        835
#   Design Size (|D|):   1951
#   Open set size:       20746
#
#
# === Best Solution Updated at Iteration 1230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9989.132
#   Best Cost (y):       12968544146.2213
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9989.132
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6876
#   Efficiency y (0→f):  1.041 → 1.041 → 1.021
#   Efficiency z (srs):  125.638 → 0.21 → 410.4162
#   Efficiency y (srs):  3.405 → 1.041 → 3.3397
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        835
#   Design Size (|D|):   1951
#   Open set size:       20748
#
# Progress: 31.8%
# === Best Solution Updated at Iteration 1270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9978.229
#   Best Cost (y):       12948154973.4874
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9978.229
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6884
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0226
#   Efficiency z (srs):  125.638 → 0.21 → 410.8647
#   Efficiency y (srs):  3.405 → 1.041 → 3.345
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        855
#   Design Size (|D|):   1991
#   Open set size:       21412
#
#
# === Best Solution Updated at Iteration 1270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9978.172
#   Best Cost (y):       12942565235.8139
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9978.172
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6884
#   Efficiency y (0→f):  1.041 → 1.041 → 1.023
#   Efficiency z (srs):  125.638 → 0.21 → 410.867
#   Efficiency y (srs):  3.405 → 1.041 → 3.3464
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        855
#   Design Size (|D|):   1991
#   Open set size:       21413
#
# Progress: 32.0%
# === Best Solution Updated at Iteration 1280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9948.997
#   Best Cost (y):       12938642935.4393
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9948.997
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6904
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0234
#   Efficiency z (srs):  125.638 → 0.21 → 412.0719
#   Efficiency y (srs):  3.405 → 1.041 → 3.3474
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        865
#   Design Size (|D|):   2011
#   Open set size:       21581
#
#
# === Best Solution Updated at Iteration 1280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9948.113
#   Best Cost (y):       12941984578.2186
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9948.113
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6905
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0231
#   Efficiency z (srs):  125.638 → 0.21 → 412.1085
#   Efficiency y (srs):  3.405 → 1.041 → 3.3466
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        865
#   Design Size (|D|):   2011
#   Open set size:       21585
#
#
# === Best Solution Updated at Iteration 1280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9940.673
#   Best Cost (y):       12935725951.5388
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9940.673
#   Efficiency z (0→f):  0.21 → 0.21 → 0.691
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0236
#   Efficiency z (srs):  125.638 → 0.21 → 412.4169
#   Efficiency y (srs):  3.405 → 1.041 → 3.3482
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        865
#   Design Size (|D|):   2011
#   Open set size:       21586
#
#
# === Best Solution Updated at Iteration 1280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9940.476
#   Best Cost (y):       12935728164.6927
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9940.476
#   Efficiency z (0→f):  0.21 → 0.21 → 0.691
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0236
#   Efficiency z (srs):  125.638 → 0.21 → 412.4251
#   Efficiency y (srs):  3.405 → 1.041 → 3.3482
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        865
#   Design Size (|D|):   2011
#   Open set size:       21587
#
# Progress: 32.2%
# === Best Solution Updated at Iteration 1290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9932.059
#   Best Cost (y):       12984659009.073
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9932.059
#   Efficiency z (0→f):  0.21 → 0.21 → 0.6916
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0197
#   Efficiency z (srs):  125.638 → 0.21 → 412.7746
#   Efficiency y (srs):  3.405 → 1.041 → 3.3356
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        872
#   Design Size (|D|):   2025
#   Open set size:       21750
#
# Progress: 32.8%
# === Best Solution Updated at Iteration 1310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9882.853
#   Best Cost (y):       12980124724.4415
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9882.853
#   Efficiency z (0→f):  0.21 → 0.21 → 0.695
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0201
#   Efficiency z (srs):  125.638 → 0.21 → 414.8298
#   Efficiency y (srs):  3.405 → 1.041 → 3.3367
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        887
#   Design Size (|D|):   2055
#   Open set size:       22090
#
# Progress: 33.0%
# === Best Solution Updated at Iteration 1320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9826.699
#   Best Cost (y):       13179185781.0046
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9826.699
#   Efficiency z (0→f):  0.21 → 0.21 → 0.699
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0047
#   Efficiency z (srs):  125.638 → 0.21 → 417.2003
#   Efficiency y (srs):  3.405 → 1.041 → 3.2863
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        896
#   Design Size (|D|):   2073
#   Open set size:       22250
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.0
#   Best Cost (z):       9784.429
#   Best Cost (y):       13177082694.4809
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9784.429
#   Efficiency z (0→f):  0.21 → 0.21 → 0.702
#   Efficiency y (0→f):  1.041 → 1.041 → 1.0048
#   Efficiency z (srs):  125.638 → 0.21 → 419.0027
#   Efficiency y (srs):  3.405 → 1.041 → 3.2869
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        903
#   Design Size (|D|):   2087
#   Open set size:       57714
#
# Best criteria value: 9784.428536585687
# Iterations run: 4000
# Best criteria value: 9784.428536585687
# Iterations run: 4000

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])

inclusions = np.array(inclusions)

import numpy as np

num_new_nodes          = 10
num_changes_lower      = 1
num_changes_upper      = 1
max_open_set_size      = 200000
switch_lower           = .9
switch_upper           = .9
max_iterations         = 2000
num_initial_nodes      = 3000
initial_design_to_use  = 10
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_8139/2522950465.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.9021075017829231
# cor(y, inclusions) 0.9054582231011578
# 2000 10 200000 0.9 0.9
# Generating initial designs:   0%|         | 3/3000 [00:00<01:50, 27.05it/s]
# Initial design 0: method = Original, efficiency z = 0.2105, y=1.0411
# New best at idx=0: method = Original, efficiency z = 0.2105 and efficiency y = 1.0411
# New best at idx=2: method = z/pi, efficiency z = 0.2105 and efficiency y = 1.0411
# New best at idx=3: method = swap, efficiency z = 0.2118 and efficiency y = 1.0256
# New best at idx=4: method = swap, efficiency z = 0.2298 and efficiency y = 0.9044
# Generating initial designs:   0%|        | 15/3000 [00:00<01:50, 26.90it/s]
# New best at idx=10: method = swap, efficiency z = 0.2382 and efficiency y = 1.0641
# Generating initial designs:   8%|▌      | 235/3000 [00:07<00:50, 54.89it/s]
# New best at idx=227: method = swap, efficiency z = 0.2397 and efficiency y = 1.0804
# Generating initial designs:  11%|▊      | 331/3000 [00:09<00:48, 55.54it/s]
# New best at idx=324: method = swap, efficiency z = 0.2588 and efficiency y = 0.7374
# Generating initial designs:  46%|██▋   | 1369/3000 [00:39<00:43, 37.20it/s]
# New best at idx=1361: method = swap, efficiency z = 0.2632 and efficiency y = 0.7241
# Generating initial designs: 100%|██████| 3000/3000 [01:25<00:00, 35.08it/s]
# Progress: 0.1%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       32324.59
#   Best Cost (y):       12953552913.5456
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.757
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2125
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0222
#   Efficiency z (srs):  125.638 → 0.213 → 126.8292
#   Efficiency y (srs):  3.405 → 1.022 → 3.3436
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        2
#   Design Size (|D|):   285
#   Open set size:       27
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       31708.761
#   Best Cost (y):       12922468621.9348
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.587
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2166
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0246
#   Efficiency z (srs):  125.638 → 0.213 → 129.2924
#   Efficiency y (srs):  3.405 → 1.022 → 3.3516
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        10
#   Design Size (|D|):   301
#   Open set size:       93
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       31535.58
#   Best Cost (y):       12921982543.1666
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.562
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2178
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0247
#   Efficiency z (srs):  125.638 → 0.213 → 130.0024
#   Efficiency y (srs):  3.405 → 1.022 → 3.3517
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        10
#   Design Size (|D|):   301
#   Open set size:       94
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       31700.232
#   Best Cost (y):       12922976179.4939
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.546
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2167
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0246
#   Efficiency z (srs):  125.638 → 0.213 → 129.3272
#   Efficiency y (srs):  3.405 → 1.022 → 3.3515
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        10
#   Design Size (|D|):   301
#   Open set size:       95
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       31516.65
#   Best Cost (y):       12923019859.9293
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      15.51
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2179
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0246
#   Efficiency z (srs):  125.638 → 0.213 → 130.0805
#   Efficiency y (srs):  3.405 → 1.022 → 3.3515
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        10
#   Design Size (|D|):   301
#   Open set size:       96
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       27992.25
#   Best Cost (y):       12839539207.1473
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.712
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2454
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0313
#   Efficiency z (srs):  125.638 → 0.213 → 146.4585
#   Efficiency y (srs):  3.405 → 1.022 → 3.3733
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       258
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       27565.458
#   Best Cost (y):       12872005245.2979
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.646
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2492
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0287
#   Efficiency z (srs):  125.638 → 0.213 → 148.7261
#   Efficiency y (srs):  3.405 → 1.022 → 3.3648
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       259
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       27593.786
#   Best Cost (y):       12868007469.569
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.641
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2489
#   Efficiency y (0→f):  1.041 → 1.022 → 1.029
#   Efficiency z (srs):  125.638 → 0.213 → 148.5734
#   Efficiency y (srs):  3.405 → 1.022 → 3.3658
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        25
#   Design Size (|D|):   331
#   Open set size:       266
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       25224.413
#   Best Cost (y):       12700068728.74
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      14.028
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2723
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0426
#   Efficiency z (srs):  125.638 → 0.213 → 162.5291
#   Efficiency y (srs):  3.405 → 1.022 → 3.4103
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        39
#   Design Size (|D|):   359
#   Open set size:       434
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       24322.066
#   Best Cost (y):       12678169054.127
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.631
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2824
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0444
#   Efficiency z (srs):  125.638 → 0.213 → 168.5589
#   Efficiency y (srs):  3.405 → 1.022 → 3.4162
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        49
#   Design Size (|D|):   379
#   Open set size:       520
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       24351.724
#   Best Cost (y):       12673672985.2091
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.604
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2821
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0448
#   Efficiency z (srs):  125.638 → 0.213 → 168.3537
#   Efficiency y (srs):  3.405 → 1.022 → 3.4174
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        49
#   Design Size (|D|):   379
#   Open set size:       524
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       23953.125
#   Best Cost (y):       12734072399.5248
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.533
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2868
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0398
#   Efficiency z (srs):  125.638 → 0.213 → 171.1552
#   Efficiency y (srs):  3.405 → 1.022 → 3.4012
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        57
#   Design Size (|D|):   395
#   Open set size:       597
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       23751.796
#   Best Cost (y):       12727250163.4642
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.36
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2892
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0404
#   Efficiency z (srs):  125.638 → 0.213 → 172.606
#   Efficiency y (srs):  3.405 → 1.022 → 3.403
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        57
#   Design Size (|D|):   395
#   Open set size:       598
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       23382.482
#   Best Cost (y):       12705863403.0418
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.094
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2938
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0421
#   Efficiency z (srs):  125.638 → 0.213 → 175.3322
#   Efficiency y (srs):  3.405 → 1.022 → 3.4087
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        67
#   Design Size (|D|):   415
#   Open set size:       684
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       23342.107
#   Best Cost (y):       12695157949.5884
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      13.094
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2943
#   Efficiency y (0→f):  1.041 → 1.022 → 1.043
#   Efficiency z (srs):  125.638 → 0.213 → 175.6355
#   Efficiency y (srs):  3.405 → 1.022 → 3.4116
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        67
#   Design Size (|D|):   415
#   Open set size:       687
#
# Progress: 4.5%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       23278.424
#   Best Cost (y):       12717829618.4426
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.991
#   Efficiency z (0→f):  0.21 → 0.213 → 0.2951
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0411
#   Efficiency z (srs):  125.638 → 0.213 → 176.116
#   Efficiency y (srs):  3.405 → 1.022 → 3.4055
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        75
#   Design Size (|D|):   431
#   Open set size:       771
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       22750.237
#   Best Cost (y):       12882966384.4627
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.753
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3019
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0278
#   Efficiency z (srs):  125.638 → 0.213 → 180.2048
#   Efficiency y (srs):  3.405 → 1.022 → 3.3619
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       854
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       22639.516
#   Best Cost (y):       12884690875.646
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.744
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3034
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0276
#   Efficiency z (srs):  125.638 → 0.213 → 181.0861
#   Efficiency y (srs):  3.405 → 1.022 → 3.3614
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       858
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       22675.524
#   Best Cost (y):       12884265314.57
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.735
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3029
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0277
#   Efficiency z (srs):  125.638 → 0.213 → 180.7986
#   Efficiency y (srs):  3.405 → 1.022 → 3.3616
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        85
#   Design Size (|D|):   451
#   Open set size:       859
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       21491.526
#   Best Cost (y):       12909030621.8981
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      12.336
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3196
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0257
#   Efficiency z (srs):  125.638 → 0.213 → 190.759
#   Efficiency y (srs):  3.405 → 1.022 → 3.3551
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        101
#   Design Size (|D|):   483
#   Open set size:       1027
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       21169.453
#   Best Cost (y):       12983908592.448
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.919
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3245
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0198
#   Efficiency z (srs):  125.638 → 0.213 → 193.6612
#   Efficiency y (srs):  3.405 → 1.022 → 3.3358
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        119
#   Design Size (|D|):   519
#   Open set size:       1190
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       21090.892
#   Best Cost (y):       13122888264.5065
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.914
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3257
#   Efficiency y (0→f):  1.041 → 1.022 → 1.009
#   Efficiency z (srs):  125.638 → 0.213 → 194.3826
#   Efficiency y (srs):  3.405 → 1.022 → 3.3004
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        119
#   Design Size (|D|):   519
#   Open set size:       1194
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       21098.96
#   Best Cost (y):       13074499995.9579
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.909
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3256
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0127
#   Efficiency z (srs):  125.638 → 0.213 → 194.3082
#   Efficiency y (srs):  3.405 → 1.022 → 3.3126
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        119
#   Design Size (|D|):   519
#   Open set size:       1195
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       21095.553
#   Best Cost (y):       13067842376.7329
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.908
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3256
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0132
#   Efficiency z (srs):  125.638 → 0.213 → 194.3396
#   Efficiency y (srs):  3.405 → 1.022 → 3.3143
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        119
#   Design Size (|D|):   519
#   Open set size:       1199
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       20032.288
#   Best Cost (y):       12930006657.1042
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.075
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3429
#   Efficiency y (0→f):  1.041 → 1.022 → 1.024
#   Efficiency z (srs):  125.638 → 0.213 → 204.6547
#   Efficiency y (srs):  3.405 → 1.022 → 3.3497
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        170
#   Design Size (|D|):   621
#   Open set size:       1700
#
# Progress: 10.5%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       19885.022
#   Best Cost (y):       13037410502.8996
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.006
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3454
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0156
#   Efficiency z (srs):  125.638 → 0.213 → 206.1703
#   Efficiency y (srs):  3.405 → 1.022 → 3.3221
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        179
#   Design Size (|D|):   639
#   Open set size:       1787
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       19877.999
#   Best Cost (y):       13057778767.2341
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      11.005
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3455
#   Efficiency y (0→f):  1.041 → 1.022 → 1.014
#   Efficiency z (srs):  125.638 → 0.213 → 206.2432
#   Efficiency y (srs):  3.405 → 1.022 → 3.3169
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        179
#   Design Size (|D|):   639
#   Open set size:       1795
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       20062.622
#   Best Cost (y):       13019419126.8009
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.743
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3424
#   Efficiency y (0→f):  1.041 → 1.022 → 1.017
#   Efficiency z (srs):  125.638 → 0.213 → 204.3453
#   Efficiency y (srs):  3.405 → 1.022 → 3.3267
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        202
#   Design Size (|D|):   685
#   Open set size:       2055
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       19932.659
#   Best Cost (y):       13041499306.1672
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.527
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3446
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0153
#   Efficiency z (srs):  125.638 → 0.213 → 205.6776
#   Efficiency y (srs):  3.405 → 1.022 → 3.321
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        222
#   Design Size (|D|):   725
#   Open set size:       2230
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       19402.19
#   Best Cost (y):       13087296199.7676
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.269
#   Efficiency z (0→f):  0.21 → 0.213 → 0.354
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0117
#   Efficiency z (srs):  125.638 → 0.213 → 211.301
#   Efficiency y (srs):  3.405 → 1.022 → 3.3094
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        236
#   Design Size (|D|):   753
#   Open set size:       2397
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       19376.987
#   Best Cost (y):       13072373600.5164
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.264
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3545
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0129
#   Efficiency z (srs):  125.638 → 0.213 → 211.5758
#   Efficiency y (srs):  3.405 → 1.022 → 3.3132
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        236
#   Design Size (|D|):   753
#   Open set size:       2398
#
# Progress: 14.5%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       19182.924
#   Best Cost (y):       13031427337.6821
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.148
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3581
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0161
#   Efficiency z (srs):  125.638 → 0.213 → 213.7162
#   Efficiency y (srs):  3.405 → 1.022 → 3.3236
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        246
#   Design Size (|D|):   773
#   Open set size:       2489
#
# Progress: 15.0%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       18965.227
#   Best Cost (y):       12793479415.3674
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      10.006
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3622
#   Efficiency y (0→f):  1.041 → 1.022 → 1.035
#   Efficiency z (srs):  125.638 → 0.213 → 216.1694
#   Efficiency y (srs):  3.405 → 1.022 → 3.3854
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        255
#   Design Size (|D|):   791
#   Open set size:       2577
#
# Progress: 16.5%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       18891.466
#   Best Cost (y):       12784316685.6127
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.885
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3636
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0357
#   Efficiency z (srs):  125.638 → 0.213 → 217.0134
#   Efficiency y (srs):  3.405 → 1.022 → 3.3878
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        275
#   Design Size (|D|):   831
#   Open set size:       2831
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       18868.872
#   Best Cost (y):       12705192927.3429
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.882
#   Efficiency z (0→f):  0.21 → 0.213 → 0.364
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0422
#   Efficiency z (srs):  125.638 → 0.213 → 217.2733
#   Efficiency y (srs):  3.405 → 1.022 → 3.4089
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        275
#   Design Size (|D|):   831
#   Open set size:       2833
#
# Progress: 22.5%
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       17233.306
#   Best Cost (y):       12804369360.5571
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      9.207
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3986
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0341
#   Efficiency z (srs):  125.638 → 0.213 → 237.8941
#   Efficiency y (srs):  3.405 → 1.022 → 3.3825
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        356
#   Design Size (|D|):   993
#   Open set size:       3848
#
# Progress: 24.0%
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       17266.386
#   Best Cost (y):       12914903209.0426
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.956
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3978
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0252
#   Efficiency z (srs):  125.638 → 0.213 → 237.4383
#   Efficiency y (srs):  3.405 → 1.022 → 3.3536
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        376
#   Design Size (|D|):   1033
#   Open set size:       4105
#
#
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       17234.942
#   Best Cost (y):       12946301839.6818
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.932
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3985
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0228
#   Efficiency z (srs):  125.638 → 0.213 → 237.8715
#   Efficiency y (srs):  3.405 → 1.022 → 3.3454
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        376
#   Design Size (|D|):   1033
#   Open set size:       4106
#
#
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       17218.048
#   Best Cost (y):       12936383874.2362
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.914
#   Efficiency z (0→f):  0.21 → 0.213 → 0.3989
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0235
#   Efficiency z (srs):  125.638 → 0.213 → 238.1049
#   Efficiency y (srs):  3.405 → 1.022 → 3.348
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        376
#   Design Size (|D|):   1033
#   Open set size:       4109
#
# Progress: 26.0%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       17009.102
#   Best Cost (y):       13034335436.7223
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.806
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4038
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0158
#   Efficiency z (srs):  125.638 → 0.213 → 241.0299
#   Efficiency y (srs):  3.405 → 1.022 → 3.3228
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        408
#   Design Size (|D|):   1097
#   Open set size:       4448
#
# Progress: 26.5%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       16921.544
#   Best Cost (y):       13336254772.6979
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.677
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4059
#   Efficiency y (0→f):  1.041 → 1.022 → 0.9928
#   Efficiency z (srs):  125.638 → 0.213 → 242.2771
#   Efficiency y (srs):  3.405 → 1.022 → 3.2476
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        416
#   Design Size (|D|):   1113
#   Open set size:       4529
#
#
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       16930.918
#   Best Cost (y):       13320076290.4245
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.675
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4057
#   Efficiency y (0→f):  1.041 → 1.022 → 0.9941
#   Efficiency z (srs):  125.638 → 0.213 → 242.1429
#   Efficiency y (srs):  3.405 → 1.022 → 3.2516
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        416
#   Design Size (|D|):   1113
#   Open set size:       4531
#
# Progress: 27.5%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       16616.65
#   Best Cost (y):       13118621937.5553
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.358
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4134
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0093
#   Efficiency z (srs):  125.638 → 0.213 → 246.7225
#   Efficiency y (srs):  3.405 → 1.022 → 3.3015
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        435
#   Design Size (|D|):   1151
#   Open set size:       4696
#
# Progress: 28.5%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       16426.067
#   Best Cost (y):       13145293654.7743
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.325
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4182
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0073
#   Efficiency z (srs):  125.638 → 0.213 → 249.5851
#   Efficiency y (srs):  3.405 → 1.022 → 3.2948
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        447
#   Design Size (|D|):   1175
#   Open set size:       4861
#
# Progress: 30.0%
# === Best Solution Updated at Iteration 600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15931.366
#   Best Cost (y):       13203632076.0917
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.122
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4311
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0028
#   Efficiency z (srs):  125.638 → 0.213 → 257.3352
#   Efficiency y (srs):  3.405 → 1.022 → 3.2802
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        467
#   Design Size (|D|):   1215
#   Open set size:       5122
#
# Progress: 30.5%
# === Best Solution Updated at Iteration 610 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15887.208
#   Best Cost (y):       13214721871.5493
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.116
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4323
#   Efficiency y (0→f):  1.041 → 1.022 → 1.002
#   Efficiency z (srs):  125.638 → 0.213 → 258.0505
#   Efficiency y (srs):  3.405 → 1.022 → 3.2775
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        473
#   Design Size (|D|):   1227
#   Open set size:       5199
#
#
# === Best Solution Updated at Iteration 610 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15889.302
#   Best Cost (y):       13212801695.9151
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.115
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4323
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0021
#   Efficiency z (srs):  125.638 → 0.213 → 258.0165
#   Efficiency y (srs):  3.405 → 1.022 → 3.278
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        473
#   Design Size (|D|):   1227
#   Open set size:       5202
#
# Progress: 31.5%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15834.027
#   Best Cost (y):       13097457970.9819
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.006
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4338
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0109
#   Efficiency z (srs):  125.638 → 0.213 → 258.9172
#   Efficiency y (srs):  3.405 → 1.022 → 3.3068
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        486
#   Design Size (|D|):   1253
#   Open set size:       5368
#
#
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15826.389
#   Best Cost (y):       12799750162.0289
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      8.004
#   Efficiency z (0→f):  0.21 → 0.213 → 0.434
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0345
#   Efficiency z (srs):  125.638 → 0.213 → 259.0422
#   Efficiency y (srs):  3.405 → 1.022 → 3.3837
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        486
#   Design Size (|D|):   1253
#   Open set size:       5370
#
# Progress: 32.0%
# === Best Solution Updated at Iteration 640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15815.399
#   Best Cost (y):       12525194453.1105
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.979
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4343
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0571
#   Efficiency z (srs):  125.638 → 0.213 → 259.2222
#   Efficiency y (srs):  3.405 → 1.022 → 3.4579
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        496
#   Design Size (|D|):   1273
#   Open set size:       5454
#
# Progress: 35.5%
# === Best Solution Updated at Iteration 710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15654.783
#   Best Cost (y):       12509030107.2086
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.848
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4388
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0585
#   Efficiency z (srs):  125.638 → 0.213 → 261.8818
#   Efficiency y (srs):  3.405 → 1.022 → 3.4624
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        530
#   Design Size (|D|):   1341
#   Open set size:       6040
#
# Progress: 36.0%
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15637.644
#   Best Cost (y):       12510005925.3161
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.841
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4392
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0584
#   Efficiency z (srs):  125.638 → 0.213 → 262.1688
#   Efficiency y (srs):  3.405 → 1.022 → 3.4621
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        539
#   Design Size (|D|):   1359
#   Open set size:       6125
#
#
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15630.646
#   Best Cost (y):       12510798403.8111
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.84
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4394
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0584
#   Efficiency z (srs):  125.638 → 0.213 → 262.2862
#   Efficiency y (srs):  3.405 → 1.022 → 3.4619
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        539
#   Design Size (|D|):   1359
#   Open set size:       6126
#
#
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15630.42
#   Best Cost (y):       12510933106.4511
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.84
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4395
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0583
#   Efficiency z (srs):  125.638 → 0.213 → 262.2899
#   Efficiency y (srs):  3.405 → 1.022 → 3.4619
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        539
#   Design Size (|D|):   1359
#   Open set size:       6129
#
# Progress: 38.0%
# === Best Solution Updated at Iteration 760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15599.355
#   Best Cost (y):       12676774810.8617
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.631
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4403
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0445
#   Efficiency z (srs):  125.638 → 0.213 → 262.8123
#   Efficiency y (srs):  3.405 → 1.022 → 3.4166
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        569
#   Design Size (|D|):   1419
#   Open set size:       6455
#
#
# === Best Solution Updated at Iteration 760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15580.81
#   Best Cost (y):       12671261038.4578
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.621
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4408
#   Efficiency y (0→f):  1.041 → 1.022 → 1.045
#   Efficiency z (srs):  125.638 → 0.213 → 263.1251
#   Efficiency y (srs):  3.405 → 1.022 → 3.4181
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        569
#   Design Size (|D|):   1419
#   Open set size:       6457
#
#
# === Best Solution Updated at Iteration 760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15561.135
#   Best Cost (y):       12664439966.8196
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.617
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4414
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0455
#   Efficiency z (srs):  125.638 → 0.213 → 263.4578
#   Efficiency y (srs):  3.405 → 1.022 → 3.4199
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        569
#   Design Size (|D|):   1419
#   Open set size:       6463
#
# Progress: 38.5%
# === Best Solution Updated at Iteration 770 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15437.323
#   Best Cost (y):       12764110420.4941
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.592
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4449
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0373
#   Efficiency z (srs):  125.638 → 0.213 → 265.5708
#   Efficiency y (srs):  3.405 → 1.022 → 3.3932
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        577
#   Design Size (|D|):   1435
#   Open set size:       6540
#
# Progress: 39.0%
# === Best Solution Updated at Iteration 780 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15332.879
#   Best Cost (y):       12813882611.2525
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.56
#   Efficiency z (0→f):  0.21 → 0.213 → 0.448
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0333
#   Efficiency z (srs):  125.638 → 0.213 → 267.3798
#   Efficiency y (srs):  3.405 → 1.022 → 3.38
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        586
#   Design Size (|D|):   1453
#   Open set size:       6628
#
# Progress: 39.5%
# === Best Solution Updated at Iteration 790 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15386.474
#   Best Cost (y):       12798209989.7971
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.542
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4464
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0346
#   Efficiency z (srs):  125.638 → 0.213 → 266.4484
#   Efficiency y (srs):  3.405 → 1.022 → 3.3842
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        594
#   Design Size (|D|):   1469
#   Open set size:       6712
#
# Progress: 40.0%
# === Best Solution Updated at Iteration 800 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       15013.038
#   Best Cost (y):       12847846899.9261
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.472
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4575
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0306
#   Efficiency z (srs):  125.638 → 0.213 → 273.0761
#   Efficiency y (srs):  3.405 → 1.022 → 3.3711
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        604
#   Design Size (|D|):   1489
#   Open set size:       6794
#
# Progress: 48.0%
# === Best Solution Updated at Iteration 960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14635.847
#   Best Cost (y):       13053681609.0666
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.352
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4693
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0143
#   Efficiency z (srs):  125.638 → 0.213 → 280.1137
#   Efficiency y (srs):  3.405 → 1.022 → 3.3179
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        672
#   Design Size (|D|):   1625
#   Open set size:       8164
#
# Progress: 49.5%
# === Best Solution Updated at Iteration 990 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14621.3
#   Best Cost (y):       13079956012.2008
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.341
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4698
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0123
#   Efficiency z (srs):  125.638 → 0.213 → 280.3924
#   Efficiency y (srs):  3.405 → 1.022 → 3.3113
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        682
#   Design Size (|D|):   1645
#   Open set size:       8423
#
# Progress: 50.0%
# === Best Solution Updated at Iteration 1000 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14686.098
#   Best Cost (y):       13079242760.7077
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.334
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4677
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0124
#   Efficiency z (srs):  125.638 → 0.213 → 279.1553
#   Efficiency y (srs):  3.405 → 1.022 → 3.3114
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        687
#   Design Size (|D|):   1655
#   Open set size:       8507
#
#
# === Best Solution Updated at Iteration 1000 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14696.69
#   Best Cost (y):       13095101320.7807
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.325
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4674
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0111
#   Efficiency z (srs):  125.638 → 0.213 → 278.9541
#   Efficiency y (srs):  3.405 → 1.022 → 3.3074
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        687
#   Design Size (|D|):   1655
#   Open set size:       8508
#
# Progress: 64.5%
# === Best Solution Updated at Iteration 1290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14732.541
#   Best Cost (y):       12994725358.2817
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.315
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4662
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0189
#   Efficiency z (srs):  125.638 → 0.213 → 278.2753
#   Efficiency y (srs):  3.405 → 1.022 → 3.333
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        714
#   Design Size (|D|):   1709
#   Open set size:       10981
#
#
# === Best Solution Updated at Iteration 1290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14735.561
#   Best Cost (y):       13017354415.8232
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.313
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4661
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0172
#   Efficiency z (srs):  125.638 → 0.213 → 278.2182
#   Efficiency y (srs):  3.405 → 1.022 → 3.3272
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        714
#   Design Size (|D|):   1709
#   Open set size:       10982
#
#
# === Best Solution Updated at Iteration 1290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14715.541
#   Best Cost (y):       13024552464.5268
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.31
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4668
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0166
#   Efficiency z (srs):  125.638 → 0.213 → 278.5967
#   Efficiency y (srs):  3.405 → 1.022 → 3.3253
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        714
#   Design Size (|D|):   1709
#   Open set size:       10983
#
#
# === Best Solution Updated at Iteration 1290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14713.971
#   Best Cost (y):       12997676038.325
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.307
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4668
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0187
#   Efficiency z (srs):  125.638 → 0.213 → 278.6265
#   Efficiency y (srs):  3.405 → 1.022 → 3.3322
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        714
#   Design Size (|D|):   1709
#   Open set size:       10987
#
# Progress: 65.0%
# === Best Solution Updated at Iteration 1300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14711.066
#   Best Cost (y):       13026353115.2869
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.306
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4669
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0165
#   Efficiency z (srs):  125.638 → 0.213 → 278.6815
#   Efficiency y (srs):  3.405 → 1.022 → 3.3249
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        720
#   Design Size (|D|):   1721
#   Open set size:       11073
#
# Progress: 66.0%
# === Best Solution Updated at Iteration 1320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14631.244
#   Best Cost (y):       12978093618.9522
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.289
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4695
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0202
#   Efficiency z (srs):  125.638 → 0.213 → 280.2019
#   Efficiency y (srs):  3.405 → 1.022 → 3.3372
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        730
#   Design Size (|D|):   1741
#   Open set size:       11232
#
# Progress: 66.5%
# === Best Solution Updated at Iteration 1330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14641.212
#   Best Cost (y):       12993958666.7569
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.274
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4691
#   Efficiency y (0→f):  1.041 → 1.022 → 1.019
#   Efficiency z (srs):  125.638 → 0.213 → 280.0111
#   Efficiency y (srs):  3.405 → 1.022 → 3.3332
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        737
#   Design Size (|D|):   1755
#   Open set size:       11320
#
# Progress: 67.0%
# === Best Solution Updated at Iteration 1340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14646.706
#   Best Cost (y):       12879363990.1743
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.263
#   Efficiency z (0→f):  0.21 → 0.213 → 0.469
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0281
#   Efficiency z (srs):  125.638 → 0.213 → 279.9061
#   Efficiency y (srs):  3.405 → 1.022 → 3.3628
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        745
#   Design Size (|D|):   1771
#   Open set size:       11407
#
# Progress: 67.5%
# === Best Solution Updated at Iteration 1350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14620.185
#   Best Cost (y):       12840787412.6226
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.246
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4698
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0312
#   Efficiency z (srs):  125.638 → 0.213 → 280.4138
#   Efficiency y (srs):  3.405 → 1.022 → 3.3729
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        753
#   Design Size (|D|):   1787
#   Open set size:       11490
#
# Progress: 69.5%
# === Best Solution Updated at Iteration 1390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14601.479
#   Best Cost (y):       12882934846.7018
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.223
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4704
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0278
#   Efficiency z (srs):  125.638 → 0.213 → 280.7731
#   Efficiency y (srs):  3.405 → 1.022 → 3.3619
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        768
#   Design Size (|D|):   1817
#   Open set size:       11824
#
# Progress: 70.5%
# === Best Solution Updated at Iteration 1410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14439.43
#   Best Cost (y):       12879188348.6023
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.193
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4757
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0281
#   Efficiency z (srs):  125.638 → 0.213 → 283.9241
#   Efficiency y (srs):  3.405 → 1.022 → 3.3629
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        784
#   Design Size (|D|):   1849
#   Open set size:       11993
#
# Progress: 74.0%
# === Best Solution Updated at Iteration 1480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14317.345
#   Best Cost (y):       12875735542.4126
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.11
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4798
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0284
#   Efficiency z (srs):  125.638 → 0.213 → 286.3451
#   Efficiency y (srs):  3.405 → 1.022 → 3.3638
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        810
#   Design Size (|D|):   1901
#   Open set size:       12575
#
#
# === Best Solution Updated at Iteration 1480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14322.728
#   Best Cost (y):       12876662780.9874
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.106
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4796
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0283
#   Efficiency z (srs):  125.638 → 0.213 → 286.2375
#   Efficiency y (srs):  3.405 → 1.022 → 3.3635
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        810
#   Design Size (|D|):   1901
#   Open set size:       12581
#
# Progress: 81.5%
# === Best Solution Updated at Iteration 1630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14449.767
#   Best Cost (y):       12562435429.0413
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      7.053
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4754
#   Efficiency y (0→f):  1.041 → 1.022 → 1.054
#   Efficiency z (srs):  125.638 → 0.213 → 283.721
#   Efficiency y (srs):  3.405 → 1.022 → 3.4477
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        864
#   Design Size (|D|):   2009
#   Open set size:       13853
#
# Progress: 86.0%
# === Best Solution Updated at Iteration 1720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14134.801
#   Best Cost (y):       12661853255.4616
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.987
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4859
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0457
#   Efficiency z (srs):  125.638 → 0.213 → 290.0431
#   Efficiency y (srs):  3.405 → 1.022 → 3.4206
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        907
#   Design Size (|D|):   2095
#   Open set size:       14602
#
#
# === Best Solution Updated at Iteration 1720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       14134.227
#   Best Cost (y):       12658464191.5333
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.987
#   Efficiency z (0→f):  0.21 → 0.213 → 0.486
#   Efficiency y (0→f):  1.041 → 1.022 → 1.046
#   Efficiency z (srs):  125.638 → 0.213 → 290.0549
#   Efficiency y (srs):  3.405 → 1.022 → 3.4215
#   Alpha:               0.9
#   Num changes:         1
#   Design Depth:        907
#   Design Size (|D|):   2095
#   Open set size:       14609
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 1999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   6818→6818.0, 757246→757246.01
#   Best Cost (z):       13975.891
#   Best Cost (y):       12752151531.8677
#   rho (z, y):          0.902
#   rho (z_hat, y_hat):  0.138
#   rho (p, y):          0.905
#   Criteria Value:      6.838
#   Efficiency z (0→f):  0.21 → 0.213 → 0.4915
#   Efficiency y (0→f):  1.041 → 1.022 → 1.0383
#   Efficiency z (srs):  125.638 → 0.213 → 293.341
#   Efficiency y (srs):  3.405 → 1.022 → 3.3964
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        989
#   Design Size (|D|):   2259
#   Open set size:       16994
#
# Best criteria value: 6.838218666964741
# Iterations run: 2000
# Best criteria value: 6.838218666964741
# Iterations run: 2000
