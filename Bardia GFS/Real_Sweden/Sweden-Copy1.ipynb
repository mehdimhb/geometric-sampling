# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 10

# %%
num_new_nodes          = 10

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# MU284 = MU284[MU284$P85<200,]
# #MU284 = MU284[-c(245,270),]
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 281
# [1] 0.03558719
# [1] 304952002.5    163382.8

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 2266.9209 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0453 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0170 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.1130297
# Variance of HT estimator via DSD formula_z:  54558.62
# Variance of HT estimator via DSD formula:  132393477
# Here is the Vincent Efficiency y:
#   DSD_y:  1.18125
#   DSD_z: 2.99463
# Monte Carlo variance of HT estimator for y:
#   DSD:  132317295.52917
#   Cube: 138365354.80914
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.18193
#   Cube: 1.13027
# Monte Carlo mean of HT estimator for y:
#   DSD:  53412.62333
#   Cube: 53387.76893
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  55805.96348
#   Cube: 77330.21460
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  2.92769
#   Cube: 2.11279
# Monte Carlo mean of HT estimator for z:
#   DSD:  2503.38578
#   Cube: 2514.21828
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        2.11        2.99        1.95        2.20        2.30

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# /tmp/ipykernel_852762/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639386
# [281] [10.] adsfa
# 4000 10 200000 0.7 0.9
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 18.89it/s]
# Initial design 0: method = Original, efficiency z = 0.5269, y=1.1044
# New best at idx=0: method = Original, efficiency z = 0.5269 and efficiency y = 1.1044
#
# Progress: 0.0%
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       99192.577
#   Best Cost (y):       113769238.1838
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      41.384
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.55→ cube 0.7796
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1637→ cube 1.2162
#   Efficiency z (srs):  1.572 → 0.527 → 1.6413
#   Efficiency y (srs):  2.535 → 1.104 → 2.6709
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        5
#   Design Size (|D|):   291
#   Open set size:       19
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       97152.236
#   Best Cost (y):       113312505.1546
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      40.532
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5616→ cube 0.796
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1684→ cube 1.2211
#   Efficiency z (srs):  1.572 → 0.527 → 1.6757
#   Efficiency y (srs):  2.535 → 1.104 → 2.6817
#   Alpha:               0.8645068984969455
#   Num changes:         1
#   Design Depth:        16
#   Design Size (|D|):   313
#   Open set size:       92
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       96940.719
#   Best Cost (y):       111365374.2931
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      40.448
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5628→ cube 0.7977
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1888→ cube 1.2424
#   Efficiency z (srs):  1.572 → 0.527 → 1.6794
#   Efficiency y (srs):  2.535 → 1.104 → 2.7286
#   Alpha:               0.8735728932938303
#   Num changes:         3
#   Design Depth:        18
#   Design Size (|D|):   317
#   Open set size:       93
#
# Progress: 0.5%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       93784.798
#   Best Cost (y):       109611302.4391
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      39.163
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.5817→ cube 0.8245
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2078→ cube 1.2623
#   Efficiency z (srs):  1.572 → 0.527 → 1.7359
#   Efficiency y (srs):  2.535 → 1.104 → 2.7722
#   Alpha:               0.8786607784892079
#   Num changes:         1
#   Design Depth:        33
#   Design Size (|D|):   347
#   Open set size:       181
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       89336.84
#   Best Cost (y):       108283745.9422
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      37.394
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6107→ cube 0.8656
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2227→ cube 1.2778
#   Efficiency z (srs):  1.572 → 0.527 → 1.8223
#   Efficiency y (srs):  2.535 → 1.104 → 2.8062
#   Alpha:               0.7931246412352946
#   Num changes:         1
#   Design Depth:        51
#   Design Size (|D|):   383
#   Open set size:       274
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       87240.756
#   Best Cost (y):       109637902.622
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.576
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6254→ cube 0.8864
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2076→ cube 1.262
#   Efficiency z (srs):  1.572 → 0.527 → 1.8661
#   Efficiency y (srs):  2.535 → 1.104 → 2.7715
#   Alpha:               0.875981157836262
#   Num changes:         2
#   Design Depth:        68
#   Design Size (|D|):   417
#   Open set size:       363
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       86667.943
#   Best Cost (y):       110170448.3651
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.35
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6295→ cube 0.8923
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2017→ cube 1.2559
#   Efficiency z (srs):  1.572 → 0.527 → 1.8784
#   Efficiency y (srs):  2.535 → 1.104 → 2.7582
#   Alpha:               0.77812884624739
#   Num changes:         3
#   Design Depth:        79
#   Design Size (|D|):   439
#   Open set size:       454
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       86557.815
#   Best Cost (y):       110327572.4954
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      36.312
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6303→ cube 0.8934
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2→ cube 1.2541
#   Efficiency z (srs):  1.572 → 0.527 → 1.8808
#   Efficiency y (srs):  2.535 → 1.104 → 2.7542
#   Alpha:               0.8268879579541386
#   Num changes:         2
#   Design Depth:        78
#   Design Size (|D|):   437
#   Open set size:       459
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       82636.477
#   Best Cost (y):       111237015.6379
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      34.739
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6602→ cube 0.9358
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.1902→ cube 1.2439
#   Efficiency z (srs):  1.572 → 0.527 → 1.9701
#   Efficiency y (srs):  2.535 → 1.104 → 2.7317
#   Alpha:               0.8198847346807813
#   Num changes:         1
#   Design Depth:        101
#   Design Size (|D|):   483
#   Open set size:       541
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       82553.463
#   Best Cost (y):       108867738.3038
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      34.704
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6609→ cube 0.9367
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2161→ cube 1.2709
#   Efficiency z (srs):  1.572 → 0.527 → 1.9721
#   Efficiency y (srs):  2.535 → 1.104 → 2.7912
#   Alpha:               0.887297394440371
#   Num changes:         1
#   Design Depth:        101
#   Design Size (|D|):   483
#   Open set size:       544
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       79574.811
#   Best Cost (y):       105497379.5284
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      33.61
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6856→ cube 0.9718
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2549→ cube 1.3116
#   Efficiency z (srs):  1.572 → 0.527 → 2.0459
#   Efficiency y (srs):  2.535 → 1.104 → 2.8803
#   Alpha:               0.7852594741769172
#   Num changes:         1
#   Design Depth:        125
#   Design Size (|D|):   531
#   Open set size:       637
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       78526.274
#   Best Cost (y):       105308963.1579
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      33.151
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.6948→ cube 0.9848
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2572→ cube 1.3139
#   Efficiency z (srs):  1.572 → 0.527 → 2.0732
#   Efficiency y (srs):  2.535 → 1.104 → 2.8855
#   Alpha:               0.8858524215572543
#   Num changes:         1
#   Design Depth:        138
#   Design Size (|D|):   557
#   Open set size:       724
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       77500.234
#   Best Cost (y):       102886498.5142
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.721
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.704→ cube 0.9978
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2868→ cube 1.3448
#   Efficiency z (srs):  1.572 → 0.527 → 2.1007
#   Efficiency y (srs):  2.535 → 1.104 → 2.9534
#   Alpha:               0.8135752719020392
#   Num changes:         2
#   Design Depth:        155
#   Design Size (|D|):   591
#   Open set size:       812
#
# Progress: 2.5%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       76052.455
#   Best Cost (y):       105578689.3073
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.135
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7174→ cube 1.0168
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.254→ cube 1.3105
#   Efficiency z (srs):  1.572 → 0.527 → 2.1406
#   Efficiency y (srs):  2.535 → 1.104 → 2.8781
#   Alpha:               0.7453582783253326
#   Num changes:         2
#   Design Depth:        170
#   Design Size (|D|):   621
#   Open set size:       902
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       75905.287
#   Best Cost (y):       105539088.5183
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.076
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7188→ cube 1.0188
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2544→ cube 1.311
#   Efficiency z (srs):  1.572 → 0.527 → 2.1448
#   Efficiency y (srs):  2.535 → 1.104 → 2.8792
#   Alpha:               0.7740891772761349
#   Num changes:         1
#   Design Depth:        169
#   Design Size (|D|):   619
#   Open set size:       906
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       75799.969
#   Best Cost (y):       105319408.7566
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      32.034
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7198→ cube 1.0202
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2571→ cube 1.3138
#   Efficiency z (srs):  1.572 → 0.527 → 2.1478
#   Efficiency y (srs):  2.535 → 1.104 → 2.8852
#   Alpha:               0.8446623015747411
#   Num changes:         3
#   Design Depth:        171
#   Design Size (|D|):   623
#   Open set size:       910
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       74511.459
#   Best Cost (y):       106272272.7457
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.525
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7322→ cube 1.0378
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2458→ cube 1.302
#   Efficiency z (srs):  1.572 → 0.527 → 2.1849
#   Efficiency y (srs):  2.535 → 1.104 → 2.8593
#   Alpha:               0.7790159502445274
#   Num changes:         1
#   Design Depth:        187
#   Design Size (|D|):   655
#   Open set size:       991
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       74281.91
#   Best Cost (y):       108117088.3923
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.392
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7345→ cube 1.041
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2245→ cube 1.2798
#   Efficiency z (srs):  1.572 → 0.527 → 2.1917
#   Efficiency y (srs):  2.535 → 1.104 → 2.8105
#   Alpha:               0.7362838500800459
#   Num changes:         1
#   Design Depth:        202
#   Design Size (|D|):   685
#   Open set size:       1088
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       73860.478
#   Best Cost (y):       107765153.7701
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      31.208
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7387→ cube 1.047
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2285→ cube 1.284
#   Efficiency z (srs):  1.572 → 0.527 → 2.2042
#   Efficiency y (srs):  2.535 → 1.104 → 2.8197
#   Alpha:               0.8206780467809522
#   Num changes:         1
#   Design Depth:        220
#   Design Size (|D|):   721
#   Open set size:       1180
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       70752.008
#   Best Cost (y):       107236749.9551
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      30.002
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7711→ cube 1.093
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2346→ cube 1.2903
#   Efficiency z (srs):  1.572 → 0.527 → 2.301
#   Efficiency y (srs):  2.535 → 1.104 → 2.8336
#   Alpha:               0.792308984031628
#   Num changes:         1
#   Design Depth:        255
#   Design Size (|D|):   791
#   Open set size:       1351
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       70625.7
#   Best Cost (y):       108346505.8277
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.948
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7725→ cube 1.0949
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2219→ cube 1.2771
#   Efficiency z (srs):  1.572 → 0.527 → 2.3051
#   Efficiency y (srs):  2.535 → 1.104 → 2.8046
#   Alpha:               0.8088246859457254
#   Num changes:         3
#   Design Depth:        257
#   Design Size (|D|):   795
#   Open set size:       1352
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       68506.695
#   Best Cost (y):       106726524.3641
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      29.105
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.7964→ cube 1.1288
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2405→ cube 1.2964
#   Efficiency z (srs):  1.572 → 0.527 → 2.3764
#   Efficiency y (srs):  2.535 → 1.104 → 2.8472
#   Alpha:               0.8337586858104646
#   Num changes:         2
#   Design Depth:        296
#   Design Size (|D|):   873
#   Open set size:       1801
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       68135.196
#   Best Cost (y):       107054772.8604
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      28.95
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8007→ cube 1.135
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2367→ cube 1.2925
#   Efficiency z (srs):  1.572 → 0.527 → 2.3894
#   Efficiency y (srs):  2.535 → 1.104 → 2.8384
#   Alpha:               0.8927465047783061
#   Num changes:         2
#   Design Depth:        296
#   Design Size (|D|):   873
#   Open set size:       1803
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       67445.128
#   Best Cost (y):       107249607.4795
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      28.67
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8089→ cube 1.1466
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2344→ cube 1.2901
#   Efficiency z (srs):  1.572 → 0.527 → 2.4138
#   Efficiency y (srs):  2.535 → 1.104 → 2.8333
#   Alpha:               0.738466316041508
#   Num changes:         1
#   Design Depth:        312
#   Design Size (|D|):   905
#   Open set size:       1892
#
# Progress: 5.5%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       65649.824
#   Best Cost (y):       106585064.2255
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.951
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8311→ cube 1.1779
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2421→ cube 1.2982
#   Efficiency z (srs):  1.572 → 0.527 → 2.4798
#   Efficiency y (srs):  2.535 → 1.104 → 2.8509
#   Alpha:               0.8098874818201411
#   Num changes:         3
#   Design Depth:        333
#   Design Size (|D|):   947
#   Open set size:       1987
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63882.036
#   Best Cost (y):       105662848.465
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.243
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8541→ cube 1.2105
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.253→ cube 1.3095
#   Efficiency z (srs):  1.572 → 0.527 → 2.5485
#   Efficiency y (srs):  2.535 → 1.104 → 2.8758
#   Alpha:               0.8824545427467712
#   Num changes:         1
#   Design Depth:        351
#   Design Size (|D|):   983
#   Open set size:       2073
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63854.736
#   Best Cost (y):       105690422.7014
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      27.231
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8544→ cube 1.211
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2527→ cube 1.3092
#   Efficiency z (srs):  1.572 → 0.527 → 2.5496
#   Efficiency y (srs):  2.535 → 1.104 → 2.8751
#   Alpha:               0.8658792502115449
#   Num changes:         2
#   Design Depth:        352
#   Design Size (|D|):   985
#   Open set size:       2077
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       63074.912
#   Best Cost (y):       106359365.2242
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.933
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.865→ cube 1.226
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2448→ cube 1.3009
#   Efficiency z (srs):  1.572 → 0.527 → 2.5811
#   Efficiency y (srs):  2.535 → 1.104 → 2.857
#   Alpha:               0.8504325749764058
#   Num changes:         3
#   Design Depth:        383
#   Design Size (|D|):   1047
#   Open set size:       2254
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61781.077
#   Best Cost (y):       105917642.2117
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.462
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8831→ cube 1.2517
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.25→ cube 1.3063
#   Efficiency z (srs):  1.572 → 0.527 → 2.6351
#   Efficiency y (srs):  2.535 → 1.104 → 2.8689
#   Alpha:               0.8355767208158896
#   Num changes:         1
#   Design Depth:        431
#   Design Size (|D|):   1143
#   Open set size:       2524
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61693.316
#   Best Cost (y):       105846984.2949
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.407
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8844→ cube 1.2535
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2508→ cube 1.3072
#   Efficiency z (srs):  1.572 → 0.527 → 2.6389
#   Efficiency y (srs):  2.535 → 1.104 → 2.8708
#   Alpha:               0.8819566608001386
#   Num changes:         2
#   Design Depth:        432
#   Design Size (|D|):   1145
#   Open set size:       2526
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61344.04
#   Best Cost (y):       105976856.8203
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.261
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8894→ cube 1.2606
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2493→ cube 1.3056
#   Efficiency z (srs):  1.572 → 0.527 → 2.6539
#   Efficiency y (srs):  2.535 → 1.104 → 2.8673
#   Alpha:               0.7550614262228944
#   Num changes:         1
#   Design Depth:        461
#   Design Size (|D|):   1203
#   Open set size:       2791
#
#
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       61331.228
#   Best Cost (y):       106071706.0418
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      26.26
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.8896→ cube 1.2609
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2482→ cube 1.3045
#   Efficiency z (srs):  1.572 → 0.527 → 2.6545
#   Efficiency y (srs):  2.535 → 1.104 → 2.8647
#   Alpha:               0.8268294996748182
#   Num changes:         1
#   Design Depth:        461
#   Design Size (|D|):   1203
#   Open set size:       2792
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59922.708
#   Best Cost (y):       105569774.5759
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.686
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9105→ cube 1.2905
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2541→ cube 1.3107
#   Efficiency z (srs):  1.572 → 0.527 → 2.7169
#   Efficiency y (srs):  2.535 → 1.104 → 2.8784
#   Alpha:               0.7935427467623395
#   Num changes:         3
#   Design Depth:        476
#   Design Size (|D|):   1233
#   Open set size:       2882
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59740.747
#   Best Cost (y):       106009674.0012
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.628
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9133→ cube 1.2944
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2489→ cube 1.3052
#   Efficiency z (srs):  1.572 → 0.527 → 2.7251
#   Efficiency y (srs):  2.535 → 1.104 → 2.8664
#   Alpha:               0.8052019161524466
#   Num changes:         1
#   Design Depth:        492
#   Design Size (|D|):   1265
#   Open set size:       2971
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59732.586
#   Best Cost (y):       105810296.5229
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.624
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9134→ cube 1.2946
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2512→ cube 1.3077
#   Efficiency z (srs):  1.572 → 0.527 → 2.7255
#   Efficiency y (srs):  2.535 → 1.104 → 2.8718
#   Alpha:               0.8534158280220225
#   Num changes:         1
#   Design Depth:        492
#   Design Size (|D|):   1265
#   Open set size:       2972
#
# Progress: 8.5%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59633.048
#   Best Cost (y):       104883500.8913
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.573
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9149→ cube 1.2968
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2623→ cube 1.3192
#   Efficiency z (srs):  1.572 → 0.527 → 2.7301
#   Efficiency y (srs):  2.535 → 1.104 → 2.8972
#   Alpha:               0.7834667695180035
#   Num changes:         3
#   Design Depth:        505
#   Design Size (|D|):   1291
#   Open set size:       3063
#
#
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59542.811
#   Best Cost (y):       105937578.0133
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.547
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9163→ cube 1.2987
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2497→ cube 1.3061
#   Efficiency z (srs):  1.572 → 0.527 → 2.7342
#   Efficiency y (srs):  2.535 → 1.104 → 2.8684
#   Alpha:               0.8830301613883341
#   Num changes:         2
#   Design Depth:        504
#   Design Size (|D|):   1289
#   Open set size:       3070
#
# Progress: 9.5%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       59008.246
#   Best Cost (y):       105442495.256
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.314
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9246→ cube 1.3105
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2556→ cube 1.3122
#   Efficiency z (srs):  1.572 → 0.527 → 2.759
#   Efficiency y (srs):  2.535 → 1.104 → 2.8818
#   Alpha:               0.8905667081164674
#   Num changes:         1
#   Design Depth:        537
#   Design Size (|D|):   1355
#   Open set size:       3427
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       58613.193
#   Best Cost (y):       105625119.2399
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.156
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9308→ cube 1.3193
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2534→ cube 1.31
#   Efficiency z (srs):  1.572 → 0.527 → 2.7776
#   Efficiency y (srs):  2.535 → 1.104 → 2.8768
#   Alpha:               0.7400510572849326
#   Num changes:         3
#   Design Depth:        572
#   Design Size (|D|):   1425
#   Open set size:       3693
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       58599.271
#   Best Cost (y):       105554383.1744
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      25.143
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.931→ cube 1.3196
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2543→ cube 1.3108
#   Efficiency z (srs):  1.572 → 0.527 → 2.7782
#   Efficiency y (srs):  2.535 → 1.104 → 2.8788
#   Alpha:               0.8639827654056722
#   Num changes:         2
#   Design Depth:        571
#   Design Size (|D|):   1423
#   Open set size:       3697
#
# Progress: 10.5%
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57991.712
#   Best Cost (y):       103967933.5919
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.883
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9408→ cube 1.3335
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2734→ cube 1.3308
#   Efficiency z (srs):  1.572 → 0.527 → 2.8073
#   Efficiency y (srs):  2.535 → 1.104 → 2.9227
#   Alpha:               0.7108481053077508
#   Num changes:         1
#   Design Depth:        587
#   Design Size (|D|):   1455
#   Open set size:       3781
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57925.009
#   Best Cost (y):       103806474.0727
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.855
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9419→ cube 1.335
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2754→ cube 1.3329
#   Efficiency z (srs):  1.572 → 0.527 → 2.8106
#   Efficiency y (srs):  2.535 → 1.104 → 2.9272
#   Alpha:               0.7197957253478469
#   Num changes:         1
#   Design Depth:        587
#   Design Size (|D|):   1455
#   Open set size:       3783
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57862.301
#   Best Cost (y):       104201770.4824
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.84
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9429→ cube 1.3365
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2705→ cube 1.3279
#   Efficiency z (srs):  1.572 → 0.527 → 2.8136
#   Efficiency y (srs):  2.535 → 1.104 → 2.9161
#   Alpha:               0.7523383155502198
#   Num changes:         3
#   Design Depth:        589
#   Design Size (|D|):   1459
#   Open set size:       3785
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57811.176
#   Best Cost (y):       103682090.0285
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.809
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9437→ cube 1.3376
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2769→ cube 1.3345
#   Efficiency z (srs):  1.572 → 0.527 → 2.8161
#   Efficiency y (srs):  2.535 → 1.104 → 2.9308
#   Alpha:               0.8406381939851617
#   Num changes:         3
#   Design Depth:        589
#   Design Size (|D|):   1459
#   Open set size:       3786
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57751.695
#   Best Cost (y):       103774867.1054
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.787
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9447→ cube 1.339
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2758→ cube 1.3333
#   Efficiency z (srs):  1.572 → 0.527 → 2.819
#   Efficiency y (srs):  2.535 → 1.104 → 2.9281
#   Alpha:               0.8360737626136909
#   Num changes:         2
#   Design Depth:        588
#   Design Size (|D|):   1457
#   Open set size:       3788
#
# Progress: 10.8%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57251.05
#   Best Cost (y):       104182446.447
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.591
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.953→ cube 1.3507
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2708→ cube 1.3281
#   Efficiency z (srs):  1.572 → 0.527 → 2.8436
#   Efficiency y (srs):  2.535 → 1.104 → 2.9167
#   Alpha:               0.8466853596275352
#   Num changes:         1
#   Design Depth:        605
#   Design Size (|D|):   1491
#   Open set size:       3873
#
# Progress: 11.2%
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       57162.609
#   Best Cost (y):       103051515.8236
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.541
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9544→ cube 1.3528
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2847→ cube 1.3427
#   Efficiency z (srs):  1.572 → 0.527 → 2.848
#   Efficiency y (srs):  2.535 → 1.104 → 2.9487
#   Alpha:               0.8738878584648829
#   Num changes:         1
#   Design Depth:        629
#   Design Size (|D|):   1539
#   Open set size:       4055
#
# Progress: 11.5%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56963.484
#   Best Cost (y):       102834188.7881
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.463
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9578→ cube 1.3575
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2874→ cube 1.3455
#   Efficiency z (srs):  1.572 → 0.527 → 2.858
#   Efficiency y (srs):  2.535 → 1.104 → 2.9549
#   Alpha:               0.7016182336148338
#   Num changes:         3
#   Design Depth:        645
#   Design Size (|D|):   1571
#   Open set size:       4148
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56904.238
#   Best Cost (y):       102104573.3906
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.423
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9588→ cube 1.359
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2966→ cube 1.3551
#   Efficiency z (srs):  1.572 → 0.527 → 2.861
#   Efficiency y (srs):  2.535 → 1.104 → 2.976
#   Alpha:               0.7509998528656076
#   Num changes:         1
#   Design Depth:        664
#   Design Size (|D|):   1609
#   Open set size:       4326
#
# Progress: 13.2%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56494.105
#   Best Cost (y):       101902400.4824
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.246
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9657→ cube 1.3688
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2992→ cube 1.3578
#   Efficiency z (srs):  1.572 → 0.527 → 2.8817
#   Efficiency y (srs):  2.535 → 1.104 → 2.9819
#   Alpha:               0.7478348818156245
#   Num changes:         2
#   Design Depth:        715
#   Design Size (|D|):   1711
#   Open set size:       4772
#
# Progress: 13.5%
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56358.231
#   Best Cost (y):       101810851.5504
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.198
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9681→ cube 1.3721
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3004→ cube 1.359
#   Efficiency z (srs):  1.572 → 0.527 → 2.8887
#   Efficiency y (srs):  2.535 → 1.104 → 2.9846
#   Alpha:               0.8382178772138833
#   Num changes:         2
#   Design Depth:        732
#   Design Size (|D|):   1745
#   Open set size:       4869
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       56077.215
#   Best Cost (y):       101863866.2078
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      24.08
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9729→ cube 1.379
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2997→ cube 1.3583
#   Efficiency z (srs):  1.572 → 0.527 → 2.9032
#   Efficiency y (srs):  2.535 → 1.104 → 2.9831
#   Alpha:               0.8539994512267024
#   Num changes:         3
#   Design Depth:        759
#   Design Size (|D|):   1799
#   Open set size:       5045
#
# Progress: 14.2%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55885.026
#   Best Cost (y):       101691530.3485
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.995
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9763→ cube 1.3837
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3019→ cube 1.3606
#   Efficiency z (srs):  1.572 → 0.527 → 2.9131
#   Efficiency y (srs):  2.535 → 1.104 → 2.9881
#   Alpha:               0.8682027272055731
#   Num changes:         2
#   Design Depth:        778
#   Design Size (|D|):   1837
#   Open set size:       5132
#
# Progress: 14.5%
# === Best Solution Updated at Iteration 580 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55299.593
#   Best Cost (y):       102024228.786
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.767
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9866→ cube 1.3984
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2977→ cube 1.3562
#   Efficiency z (srs):  1.572 → 0.527 → 2.944
#   Efficiency y (srs):  2.535 → 1.104 → 2.9784
#   Alpha:               0.8346640457428464
#   Num changes:         2
#   Design Depth:        793
#   Design Size (|D|):   1867
#   Open set size:       5227
#
# Progress: 14.8%
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55028.926
#   Best Cost (y):       101799796.7536
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.654
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9915→ cube 1.4053
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3005→ cube 1.3592
#   Efficiency z (srs):  1.572 → 0.527 → 2.9585
#   Efficiency y (srs):  2.535 → 1.104 → 2.9849
#   Alpha:               0.8198228630173673
#   Num changes:         1
#   Design Depth:        812
#   Design Size (|D|):   1905
#   Open set size:       5315
#
#
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       55021.823
#   Best Cost (y):       101998177.076
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.653
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9916→ cube 1.4054
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.298→ cube 1.3565
#   Efficiency z (srs):  1.572 → 0.527 → 2.9589
#   Efficiency y (srs):  2.535 → 1.104 → 2.9791
#   Alpha:               0.8948104937036154
#   Num changes:         1
#   Design Depth:        812
#   Design Size (|D|):   1905
#   Open set size:       5318
#
# Progress: 15.2%
# === Best Solution Updated at Iteration 610 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54610.303
#   Best Cost (y):       101831588.6905
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.49
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9991→ cube 1.416
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3001→ cube 1.3588
#   Efficiency z (srs):  1.572 → 0.527 → 2.9811
#   Efficiency y (srs):  2.535 → 1.104 → 2.984
#   Alpha:               0.8316619235782362
#   Num changes:         2
#   Design Depth:        842
#   Design Size (|D|):   1965
#   Open set size:       5497
#
#
# === Best Solution Updated at Iteration 610 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54578.286
#   Best Cost (y):       101941069.824
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.474
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 0.9996→ cube 1.4169
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2987→ cube 1.3573
#   Efficiency z (srs):  1.572 → 0.527 → 2.9829
#   Efficiency y (srs):  2.535 → 1.104 → 2.9808
#   Alpha:               0.7930387708949193
#   Num changes:         3
#   Design Depth:        843
#   Design Size (|D|):   1967
#   Open set size:       5499
#
#
# === Best Solution Updated at Iteration 610 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54541.582
#   Best Cost (y):       101822367.3811
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.465
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0003→ cube 1.4178
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3002→ cube 1.3589
#   Efficiency z (srs):  1.572 → 0.527 → 2.9849
#   Efficiency y (srs):  2.535 → 1.104 → 2.9843
#   Alpha:               0.7784532509407861
#   Num changes:         2
#   Design Depth:        842
#   Design Size (|D|):   1965
#   Open set size:       5500
#
# Progress: 15.5%
# === Best Solution Updated at Iteration 620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       54393.569
#   Best Cost (y):       102521585.3434
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      23.405
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.003→ cube 1.4217
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2914→ cube 1.3496
#   Efficiency z (srs):  1.572 → 0.527 → 2.993
#   Efficiency y (srs):  2.535 → 1.104 → 2.9639
#   Alpha:               0.7259076631125186
#   Num changes:         1
#   Design Depth:        858
#   Design Size (|D|):   1997
#   Open set size:       5584
#
# Progress: 16.2%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53137.342
#   Best Cost (y):       102387970.4685
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.889
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0267→ cube 1.4553
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2931→ cube 1.3514
#   Efficiency z (srs):  1.572 → 0.527 → 3.0638
#   Efficiency y (srs):  2.535 → 1.104 → 2.9678
#   Alpha:               0.8251789467991847
#   Num changes:         1
#   Design Depth:        903
#   Design Size (|D|):   2087
#   Open set size:       5857
#
#
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       53097.081
#   Best Cost (y):       102742059.1612
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.878
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0275→ cube 1.4564
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2886→ cube 1.3467
#   Efficiency z (srs):  1.572 → 0.527 → 3.0661
#   Efficiency y (srs):  2.535 → 1.104 → 2.9576
#   Alpha:               0.8500796984500789
#   Num changes:         3
#   Design Depth:        905
#   Design Size (|D|):   2091
#   Open set size:       5860
#
# Progress: 16.5%
# === Best Solution Updated at Iteration 660 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       52918.19
#   Best Cost (y):       102130408.1208
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.793
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.031→ cube 1.4613
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2963→ cube 1.3548
#   Efficiency z (srs):  1.572 → 0.527 → 3.0765
#   Efficiency y (srs):  2.535 → 1.104 → 2.9753
#   Alpha:               0.8941439106203233
#   Num changes:         2
#   Design Depth:        923
#   Design Size (|D|):   2127
#   Open set size:       5941
#
# Progress: 17.0%
# === Best Solution Updated at Iteration 680 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       52753.961
#   Best Cost (y):       101580133.7439
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.718
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0342→ cube 1.4659
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3033→ cube 1.3621
#   Efficiency z (srs):  1.572 → 0.527 → 3.0861
#   Efficiency y (srs):  2.535 → 1.104 → 2.9914
#   Alpha:               0.8304079844235255
#   Num changes:         1
#   Design Depth:        948
#   Design Size (|D|):   2177
#   Open set size:       6129
#
# Progress: 18.2%
# === Best Solution Updated at Iteration 730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       51842.228
#   Best Cost (y):       102631942.4981
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.344
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0524→ cube 1.4916
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.29→ cube 1.3482
#   Efficiency z (srs):  1.572 → 0.527 → 3.1403
#   Efficiency y (srs):  2.535 → 1.104 → 2.9607
#   Alpha:               0.8299509727662711
#   Num changes:         2
#   Design Depth:        1007
#   Design Size (|D|):   2295
#   Open set size:       6572
#
# Progress: 18.5%
# === Best Solution Updated at Iteration 740 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       51824.383
#   Best Cost (y):       102648167.6319
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      22.339
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.0528→ cube 1.4922
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.2898→ cube 1.348
#   Efficiency z (srs):  1.572 → 0.527 → 3.1414
# ...
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35065.027
#   Best Cost (y):       101110384.7134
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.494
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5559→ cube 2.2053
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3094→ cube 1.3685
#   Efficiency z (srs):  1.572 → 0.527 → 4.6428
#   Efficiency y (srs):  2.535 → 1.104 → 3.0053
#   Alpha:               0.7186622668021375
#   Num changes:         1
#   Design Depth:        4511
#   Design Size (|D|):   9303
#   Open set size:       32948
#
# Progress: 92.0%
# === Best Solution Updated at Iteration 3680 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35051.863
#   Best Cost (y):       101032361.5977
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.488
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5565→ cube 2.2062
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3104→ cube 1.3695
#   Efficiency z (srs):  1.572 → 0.527 → 4.6446
#   Efficiency y (srs):  2.535 → 1.104 → 3.0076
#   Alpha:               0.7988729493069462
#   Num changes:         3
#   Design Depth:        4525
#   Design Size (|D|):   9331
#   Open set size:       33123
#
# Progress: 94.0%
# === Best Solution Updated at Iteration 3760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35009.739
#   Best Cost (y):       101198757.5287
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.465
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5584→ cube 2.2088
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3083→ cube 1.3673
#   Efficiency z (srs):  1.572 → 0.527 → 4.6502
#   Efficiency y (srs):  2.535 → 1.104 → 3.0027
#   Alpha:               0.8063301936835465
#   Num changes:         1
#   Design Depth:        4605
#   Design Size (|D|):   9491
#   Open set size:       33845
#
#
# === Best Solution Updated at Iteration 3760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       35001.838
#   Best Cost (y):       101085614.3696
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.462
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5587→ cube 2.2093
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3097→ cube 1.3688
#   Efficiency z (srs):  1.572 → 0.527 → 4.6512
#   Efficiency y (srs):  2.535 → 1.104 → 3.006
#   Alpha:               0.8246608839004305
#   Num changes:         2
#   Design Depth:        4606
#   Design Size (|D|):   9493
#   Open set size:       33849
#
# Progress: 94.5%
# === Best Solution Updated at Iteration 3780 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34980.937
#   Best Cost (y):       101185227.4157
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.452
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5597→ cube 2.2106
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3084→ cube 1.3674
#   Efficiency z (srs):  1.572 → 0.527 → 4.654
#   Efficiency y (srs):  2.535 → 1.104 → 3.0031
#   Alpha:               0.8029637114882894
#   Num changes:         3
#   Design Depth:        4631
#   Design Size (|D|):   9543
#   Open set size:       34027
#
# Progress: 94.8%
# === Best Solution Updated at Iteration 3790 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34925.104
#   Best Cost (y):       101160840.2022
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.429
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5622→ cube 2.2142
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3087→ cube 1.3678
#   Efficiency z (srs):  1.572 → 0.527 → 4.6614
#   Efficiency y (srs):  2.535 → 1.104 → 3.0038
#   Alpha:               0.8280947054455892
#   Num changes:         3
#   Design Depth:        4649
#   Design Size (|D|):   9579
#   Open set size:       34119
#
# Progress: 95.0%
# === Best Solution Updated at Iteration 3800 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34913.049
#   Best Cost (y):       101178484.6382
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.423
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5627→ cube 2.2149
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3085→ cube 1.3675
#   Efficiency z (srs):  1.572 → 0.527 → 4.6631
#   Efficiency y (srs):  2.535 → 1.104 → 3.0033
#   Alpha:               0.7208589300480587
#   Num changes:         1
#   Design Depth:        4662
#   Design Size (|D|):   9605
#   Open set size:       34208
#
# Progress: 95.2%
# === Best Solution Updated at Iteration 3810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34879.141
#   Best Cost (y):       101221040.1338
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.409
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5642→ cube 2.2171
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.308→ cube 1.367
#   Efficiency z (srs):  1.572 → 0.527 → 4.6676
#   Efficiency y (srs):  2.535 → 1.104 → 3.002
#   Alpha:               0.8230073622611658
#   Num changes:         3
#   Design Depth:        4678
#   Design Size (|D|):   9637
#   Open set size:       34295
#
# Progress: 95.8%
# === Best Solution Updated at Iteration 3830 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34743.948
#   Best Cost (y):       101184167.745
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.354
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5703→ cube 2.2257
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3084→ cube 1.3675
#   Efficiency z (srs):  1.572 → 0.527 → 4.6857
#   Efficiency y (srs):  2.535 → 1.104 → 3.0031
#   Alpha:               0.7810994857197056
#   Num changes:         1
#   Design Depth:        4711
#   Design Size (|D|):   9703
#   Open set size:       34476
#
#
# === Best Solution Updated at Iteration 3830 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34743.565
#   Best Cost (y):       101172087.0626
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.354
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5703→ cube 2.2257
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3086→ cube 1.3676
#   Efficiency z (srs):  1.572 → 0.527 → 4.6858
#   Efficiency y (srs):  2.535 → 1.104 → 3.0035
#   Alpha:               0.7255515840951686
#   Num changes:         1
#   Design Depth:        4711
#   Design Size (|D|):   9703
#   Open set size:       34477
#
# Progress: 96.8%
# === Best Solution Updated at Iteration 3870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34673.414
#   Best Cost (y):       101013340.1074
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.323
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5735→ cube 2.2302
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3107→ cube 1.3698
#   Efficiency z (srs):  1.572 → 0.527 → 4.6953
#   Efficiency y (srs):  2.535 → 1.104 → 3.0082
#   Alpha:               0.7830937643640261
#   Num changes:         1
#   Design Depth:        4765
#   Design Size (|D|):   9811
#   Open set size:       34834
#
#
# === Best Solution Updated at Iteration 3870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34672.214
#   Best Cost (y):       101027430.2572
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.323
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5736→ cube 2.2303
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3105→ cube 1.3696
#   Efficiency z (srs):  1.572 → 0.527 → 4.6954
#   Efficiency y (srs):  2.535 → 1.104 → 3.0078
#   Alpha:               0.8245160953220504
#   Num changes:         2
#   Design Depth:        4766
#   Design Size (|D|):   9813
#   Open set size:       34840
#
# Progress: 97.5%
# === Best Solution Updated at Iteration 3900 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34490.23
#   Best Cost (y):       100742277.5734
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.253
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5819→ cube 2.2421
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3142→ cube 1.3735
#   Efficiency z (srs):  1.572 → 0.527 → 4.7202
#   Efficiency y (srs):  2.535 → 1.104 → 3.0163
#   Alpha:               0.8913748790643673
#   Num changes:         3
#   Design Depth:        4815
#   Design Size (|D|):   9911
#   Open set size:       35102
#
#
# === Best Solution Updated at Iteration 3900 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34488.657
#   Best Cost (y):       100741550.0944
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.253
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5819→ cube 2.2422
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3142→ cube 1.3735
#   Efficiency z (srs):  1.572 → 0.527 → 4.7204
#   Efficiency y (srs):  2.535 → 1.104 → 3.0163
#   Alpha:               0.8769237957402337
#   Num changes:         2
#   Design Depth:        4814
#   Design Size (|D|):   9909
#   Open set size:       35104
#
#
# === Best Solution Updated at Iteration 3900 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34484.092
#   Best Cost (y):       100753196.5526
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.25
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5821→ cube 2.2425
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.314→ cube 1.3733
#   Efficiency z (srs):  1.572 → 0.527 → 4.7211
#   Efficiency y (srs):  2.535 → 1.104 → 3.016
#   Alpha:               0.8902094824679939
#   Num changes:         1
#   Design Depth:        4813
#   Design Size (|D|):   9907
#   Open set size:       35105
#
# Progress: 97.8%
# === Best Solution Updated at Iteration 3910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34452.003
#   Best Cost (y):       100569889.1364
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.236
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5836→ cube 2.2446
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3164→ cube 1.3758
#   Efficiency z (srs):  1.572 → 0.527 → 4.7255
#   Efficiency y (srs):  2.535 → 1.104 → 3.0214
#   Alpha:               0.7303717265518289
#   Num changes:         1
#   Design Depth:        4828
#   Design Size (|D|):   9937
#   Open set size:       35196
#
# Progress: 99.0%
# === Best Solution Updated at Iteration 3960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34443.941
#   Best Cost (y):       100585616.9144
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.232
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.584→ cube 2.2451
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3162→ cube 1.3756
#   Efficiency z (srs):  1.572 → 0.527 → 4.7266
#   Efficiency y (srs):  2.535 → 1.104 → 3.021
#   Alpha:               0.7677947651762018
#   Num changes:         2
#   Design Depth:        4854
#   Design Size (|D|):   9989
#   Open set size:       35645
#
# Progress: 99.2%
# === Best Solution Updated at Iteration 3970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34419.683
#   Best Cost (y):       100576485.0301
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.223
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5851→ cube 2.2467
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3163→ cube 1.3757
#   Efficiency z (srs):  1.572 → 0.527 → 4.7299
#   Efficiency y (srs):  2.535 → 1.104 → 3.0213
#   Alpha:               0.7294306698969676
#   Num changes:         1
#   Design Depth:        4863
#   Design Size (|D|):   10007
#   Open set size:       35739
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34373.545
#   Best Cost (y):       100436289.5543
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.202
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5872→ cube 2.2497
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3182→ cube 1.3776
#   Efficiency z (srs):  1.572 → 0.527 → 4.7362
#   Efficiency y (srs):  2.535 → 1.104 → 3.0255
#   Alpha:               0.8795596964245417
#   Num changes:         2
#   Design Depth:        4895
#   Design Size (|D|):   10071
#   Open set size:       35994
#
#
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34372.038
#   Best Cost (y):       100425752.2697
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.201
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5873→ cube 2.2498
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3183→ cube 1.3778
#   Efficiency z (srs):  1.572 → 0.527 → 4.7364
#   Efficiency y (srs):  2.535 → 1.104 → 3.0258
#   Alpha:               0.7920206139921191
#   Num changes:         2
#   Design Depth:        4895
#   Design Size (|D|):   10071
#   Open set size:       35995
#
#
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34365.485
#   Best Cost (y):       100440503.923
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.198
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5876→ cube 2.2502
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3181→ cube 1.3776
#   Efficiency z (srs):  1.572 → 0.527 → 4.7374
#   Efficiency y (srs):  2.535 → 1.104 → 3.0253
#   Alpha:               0.8919265983760629
#   Num changes:         1
#   Design Depth:        4894
#   Design Size (|D|):   10069
#   Open set size:       35999
#
#
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       34365.485
#   Best Cost (y):       100440503.923
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      15.198
#   Efficiency z (0→f):  0.527 → 0.527 → dsd 1.5876→ cube 2.2502
#   Efficiency y (0→f):  1.104 → 1.104 → dsd 1.3181→ cube 1.3776
#   Efficiency z (srs):  1.572 → 0.527 → 4.7374
#   Efficiency y (srs):  2.535 → 1.104 → 3.0253
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4894
#   Design Size (|D|):   10069
#   Open set size:       36001
#
# Best criteria value: 15.198242528599799
# Iterations run: 4000
# Best criteria value: 15.198242528599799
# Iterations run: 4000

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
# Out:
# size of init design 281
# size of best design 10069
# 43.145499104315405
# 15.198242528599799
# /tmp/ipykernel_852762/1240027416.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# 1.0000000050000004
