# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Artificial"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmphBVD6F", R: "/tmp/RtmpSD4dr7"
#   warnings.warn(

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_7.5_py_9.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_7.5_py_9.5_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.7 0.9
# Generating initial designs:   0%|                      | 0/3000 [00:00<?, ?it/s]
# Initial design 0: method = Original, efficiency z = 0.1843, y=0.7838
# New best at idx=0: method = Original, efficiency z = 0.1843 and efficiency y = 0.7838
# New best at idx=2: method = z/pi, efficiency z = 0.1843 and efficiency y = 0.7838
# New best at idx=3: method = swap, efficiency z = 0.1997 and efficiency y = 0.7048
# New best at idx=4: method = swap, efficiency z = 0.2032 and efficiency y = 0.7575
# New best at idx=5: method = swap, efficiency z = 0.2155 and efficiency y = 0.7487
# Generating initial designs:   2%|▏           | 51/3000 [00:00<00:23, 126.28it/s]
# New best at idx=21: method = swap, efficiency z = 0.2159 and efficiency y = 0.5860
# New best at idx=23: method = swap, efficiency z = 0.2191 and efficiency y = 0.8001
# New best at idx=37: method = swap, efficiency z = 0.2267 and efficiency y = 0.9474
# New best at idx=42: method = swap, efficiency z = 0.2433 and efficiency y = 0.8376
# Generating initial designs:  18%|██▏         | 551/3000 [00:06<00:26, 93.78it/s]
# New best at idx=529: method = swap, efficiency z = 0.2917 and efficiency y = 0.9090
# Generating initial designs: 100%|███████████| 3000/3000 [00:44<00:00, 66.85it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       253968.803
#   Best Cost (y):       10440.6984
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      253968.803
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.2924→ cube 0.9644
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 0.9531→ cube 0.9871
#   Efficiency z (srs):  10.204 → 0.292 → 16.1889
#   Efficiency y (srs):  6.994 → 0.909 → 8.5057
#   Alpha:               0.7216944166255966
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       116
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       233238.805
#   Best Cost (y):       9791.5104
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      233238.805
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.3184→ cube 1.0501
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0163→ cube 1.0525
#   Efficiency z (srs):  10.204 → 0.292 → 17.6277
#   Efficiency y (srs):  6.994 → 0.909 → 9.0696
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        3
#   Design Size (|D|):   106
#   Open set size:       158
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       219613.696
#   Best Cost (y):       9273.0677
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      219613.696
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.3381→ cube 1.1153
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0732→ cube 1.1114
#   Efficiency z (srs):  10.204 → 0.292 → 18.7214
#   Efficiency y (srs):  6.994 → 0.909 → 9.5767
#   Alpha:               0.7488284752010471
#   Num changes:         1
#   Design Depth:        12
#   Design Size (|D|):   124
#   Open set size:       419
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       198184.278
#   Best Cost (y):       9351.2605
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      198184.278
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.3747→ cube 1.2359
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0642→ cube 1.1021
#   Efficiency z (srs):  10.204 → 0.292 → 20.7457
#   Efficiency y (srs):  6.994 → 0.909 → 9.4966
#   Alpha:               0.8809017408306737
#   Num changes:         2
#   Design Depth:        35
#   Design Size (|D|):   170
#   Open set size:       1261
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       169079.841
#   Best Cost (y):       9192.0218
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      169079.841
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.4392→ cube 1.4486
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0826→ cube 1.1212
#   Efficiency z (srs):  10.204 → 0.292 → 24.3167
#   Efficiency y (srs):  6.994 → 0.909 → 9.6612
#   Alpha:               0.8190450631293801
#   Num changes:         3
#   Design Depth:        54
#   Design Size (|D|):   208
#   Open set size:       1552
#
# Progress: 1.6%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       141750.549
#   Best Cost (y):       9000.812
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      141750.549
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5239→ cube 1.7279
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1056→ cube 1.145
#   Efficiency z (srs):  10.204 → 0.292 → 29.005
#   Efficiency y (srs):  6.994 → 0.909 → 9.8664
#   Alpha:               0.7991948411181617
#   Num changes:         2
#   Design Depth:        101
#   Design Size (|D|):   302
#   Open set size:       2422
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       140889.158
#   Best Cost (y):       8940.4239
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      140889.158
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5271→ cube 1.7385
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1131→ cube 1.1527
#   Efficiency z (srs):  10.204 → 0.292 → 29.1823
#   Efficiency y (srs):  6.994 → 0.909 → 9.933
#   Alpha:               0.7189481336613758
#   Num changes:         1
#   Design Depth:        100
#   Design Size (|D|):   300
#   Open set size:       2424
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       140608.484
#   Best Cost (y):       9068.1761
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      140608.484
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5281→ cube 1.742
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0974→ cube 1.1365
#   Efficiency z (srs):  10.204 → 0.292 → 29.2406
#   Efficiency y (srs):  6.994 → 0.909 → 9.7931
#   Alpha:               0.8983895433061306
#   Num changes:         2
#   Design Depth:        101
#   Design Size (|D|):   302
#   Open set size:       2432
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       137712.092
#   Best Cost (y):       8930.6379
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      137712.092
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5392→ cube 1.7786
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1143→ cube 1.154
#   Efficiency z (srs):  10.204 → 0.292 → 29.8556
#   Efficiency y (srs):  6.994 → 0.909 → 9.9439
#   Alpha:               0.8396702187944597
#   Num changes:         2
#   Design Depth:        115
#   Design Size (|D|):   330
#   Open set size:       2711
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       136749.789
#   Best Cost (y):       9140.3764
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      136749.789
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.543→ cube 1.7911
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0887→ cube 1.1275
#   Efficiency z (srs):  10.204 → 0.292 → 30.0656
#   Efficiency y (srs):  6.994 → 0.909 → 9.7157
#   Alpha:               0.87857321210859
#   Num changes:         3
#   Design Depth:        116
#   Design Size (|D|):   332
#   Open set size:       2718
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       132798.32
#   Best Cost (y):       9346.1514
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      132798.32
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5592→ cube 1.8444
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0648→ cube 1.1027
#   Efficiency z (srs):  10.204 → 0.292 → 30.9603
#   Efficiency y (srs):  6.994 → 0.909 → 9.5018
#   Alpha:               0.7063857343977062
#   Num changes:         1
#   Design Depth:        128
#   Design Size (|D|):   356
#   Open set size:       3003
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       132620.473
#   Best Cost (y):       9368.3147
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      132620.473
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5599→ cube 1.8469
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0623→ cube 1.1001
#   Efficiency z (srs):  10.204 → 0.292 → 31.0018
#   Efficiency y (srs):  6.994 → 0.909 → 9.4793
#   Alpha:               0.8629841831658593
#   Num changes:         1
#   Design Depth:        128
#   Design Size (|D|):   356
#   Open set size:       3020
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       125315.252
#   Best Cost (y):       9081.2517
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      125315.252
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.5926→ cube 1.9545
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0958→ cube 1.1348
#   Efficiency z (srs):  10.204 → 0.292 → 32.809
#   Efficiency y (srs):  6.994 → 0.909 → 9.779
#   Alpha:               0.8644163193111525
#   Num changes:         3
#   Design Depth:        144
#   Design Size (|D|):   388
#   Open set size:       3295
#
# Progress: 2.4%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       123551.043
#   Best Cost (y):       9041.1925
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      123551.043
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.601→ cube 1.9824
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1007→ cube 1.1399
#   Efficiency z (srs):  10.204 → 0.292 → 33.2775
#   Efficiency y (srs):  6.994 → 0.909 → 9.8223
#   Alpha:               0.7566184252232995
#   Num changes:         3
#   Design Depth:        157
#   Design Size (|D|):   414
#   Open set size:       3584
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       117745.298
#   Best Cost (y):       9264.2958
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      117745.298
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6307→ cube 2.0802
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0742→ cube 1.1124
#   Efficiency z (srs):  10.204 → 0.292 → 34.9183
#   Efficiency y (srs):  6.994 → 0.909 → 9.5858
#   Alpha:               0.739010455123423
#   Num changes:         1
#   Design Depth:        179
#   Design Size (|D|):   458
#   Open set size:       4163
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       117479.404
#   Best Cost (y):       9173.3557
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      117479.404
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6321→ cube 2.0849
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0848→ cube 1.1234
#   Efficiency z (srs):  10.204 → 0.292 → 34.9974
#   Efficiency y (srs):  6.994 → 0.909 → 9.6808
#   Alpha:               0.7340922757746692
#   Num changes:         2
#   Design Depth:        180
#   Design Size (|D|):   460
#   Open set size:       4189
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       115404.928
#   Best Cost (y):       9119.2992
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      115404.928
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6435→ cube 2.1224
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0913→ cube 1.1301
#   Efficiency z (srs):  10.204 → 0.292 → 35.6265
#   Efficiency y (srs):  6.994 → 0.909 → 9.7382
#   Alpha:               0.7478932762651179
#   Num changes:         1
#   Design Depth:        192
#   Design Size (|D|):   484
#   Open set size:       4459
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       115279.155
#   Best Cost (y):       9134.952
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      115279.155
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6442→ cube 2.1247
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0894→ cube 1.1282
#   Efficiency z (srs):  10.204 → 0.292 → 35.6653
#   Efficiency y (srs):  6.994 → 0.909 → 9.7215
#   Alpha:               0.7531128143579472
#   Num changes:         1
#   Design Depth:        192
#   Design Size (|D|):   484
#   Open set size:       4463
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       113424.862
#   Best Cost (y):       9050.539
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      113424.862
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6547→ cube 2.1594
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0996→ cube 1.1387
#   Efficiency z (srs):  10.204 → 0.292 → 36.2484
#   Efficiency y (srs):  6.994 → 0.909 → 9.8122
#   Alpha:               0.7522346961801741
#   Num changes:         1
#   Design Depth:        205
#   Design Size (|D|):   510
#   Open set size:       4755
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       109731.685
#   Best Cost (y):       9084.6474
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      109731.685
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6767→ cube 2.2321
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0954→ cube 1.1344
#   Efficiency z (srs):  10.204 → 0.292 → 37.4684
#   Efficiency y (srs):  6.994 → 0.909 → 9.7753
#   Alpha:               0.747704896186705
#   Num changes:         2
#   Design Depth:        243
#   Design Size (|D|):   586
#   Open set size:       5612
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       106745.976
#   Best Cost (y):       9025.4841
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      106745.976
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6956→ cube 2.2945
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1026→ cube 1.1419
#   Efficiency z (srs):  10.204 → 0.292 → 38.5164
#   Efficiency y (srs):  6.994 → 0.909 → 9.8394
#   Alpha:               0.8223241385914228
#   Num changes:         1
#   Design Depth:        256
#   Design Size (|D|):   612
#   Open set size:       5914
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       106719.129
#   Best Cost (y):       9030.2994
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      106719.129
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6958→ cube 2.2951
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.102→ cube 1.1412
#   Efficiency z (srs):  10.204 → 0.292 → 38.5261
#   Efficiency y (srs):  6.994 → 0.909 → 9.8342
#   Alpha:               0.8247589989305957
#   Num changes:         1
#   Design Depth:        256
#   Design Size (|D|):   612
#   Open set size:       5924
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       106246.119
#   Best Cost (y):       9040.365
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      106246.119
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.6989→ cube 2.3053
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1008→ cube 1.14
#   Efficiency z (srs):  10.204 → 0.292 → 38.6976
#   Efficiency y (srs):  6.994 → 0.909 → 9.8232
#   Alpha:               0.7720253562127329
#   Num changes:         2
#   Design Depth:        267
#   Design Size (|D|):   634
#   Open set size:       6197
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       105972.616
#   Best Cost (y):       8998.5338
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      105972.616
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7007→ cube 2.3113
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1059→ cube 1.1453
#   Efficiency z (srs):  10.204 → 0.292 → 38.7975
#   Efficiency y (srs):  6.994 → 0.909 → 9.8689
#   Alpha:               0.8952284008118456
#   Num changes:         1
#   Design Depth:        266
#   Design Size (|D|):   632
#   Open set size:       6200
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       105723.654
#   Best Cost (y):       8981.4774
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      105723.654
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7024→ cube 2.3167
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.108→ cube 1.1475
#   Efficiency z (srs):  10.204 → 0.292 → 38.8888
#   Efficiency y (srs):  6.994 → 0.909 → 9.8876
#   Alpha:               0.7591678006822642
#   Num changes:         1
#   Design Depth:        266
#   Design Size (|D|):   632
#   Open set size:       6219
#
# Progress: 4.4%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       105086.776
#   Best Cost (y):       8962.557
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      105086.776
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7066→ cube 2.3308
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1103→ cube 1.1499
#   Efficiency z (srs):  10.204 → 0.292 → 39.1245
#   Efficiency y (srs):  6.994 → 0.909 → 9.9085
#   Alpha:               0.8665588592431207
#   Num changes:         1
#   Design Depth:        275
#   Design Size (|D|):   650
#   Open set size:       6491
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       102244.968
#   Best Cost (y):       9000.669
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      102244.968
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7263→ cube 2.3956
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.1056→ cube 1.145
#   Efficiency z (srs):  10.204 → 0.292 → 40.212
#   Efficiency y (srs):  6.994 → 0.909 → 9.8665
#   Alpha:               0.8164997358959617
#   Num changes:         1
#   Design Depth:        305
#   Design Size (|D|):   710
#   Open set size:       7073
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       100359.747
#   Best Cost (y):       9118.7804
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      100359.747
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7399→ cube 2.4406
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0913→ cube 1.1302
#   Efficiency z (srs):  10.204 → 0.292 → 40.9673
#   Efficiency y (srs):  6.994 → 0.909 → 9.7387
#   Alpha:               0.7435633376693396
#   Num changes:         2
#   Design Depth:        329
#   Design Size (|D|):   758
#   Open set size:       7646
#
#
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       100344.666
#   Best Cost (y):       9092.965
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      100344.666
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.74→ cube 2.4409
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0944→ cube 1.1334
#   Efficiency z (srs):  10.204 → 0.292 → 40.9735
#   Efficiency y (srs):  6.994 → 0.909 → 9.7664
#   Alpha:               0.7805756341378018
#   Num changes:         2
#   Design Depth:        329
#   Design Size (|D|):   758
#   Open set size:       7648
#
# Progress: 5.4%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       97333.171
#   Best Cost (y):       9139.4929
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      97333.171
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7629→ cube 2.5164
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0888→ cube 1.1276
#   Efficiency z (srs):  10.204 → 0.292 → 42.2412
#   Efficiency y (srs):  6.994 → 0.909 → 9.7167
#   Alpha:               0.7107770542366614
#   Num changes:         3
#   Design Depth:        346
#   Design Size (|D|):   792
#   Open set size:       7933
#
# Progress: 5.6%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       95121.094
#   Best Cost (y):       9245.0542
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      95121.094
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7807→ cube 2.575
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0764→ cube 1.1147
#   Efficiency z (srs):  10.204 → 0.292 → 43.2235
#   Efficiency y (srs):  6.994 → 0.909 → 9.6057
#   Alpha:               0.7621814541141572
#   Num changes:         1
#   Design Depth:        362
#   Design Size (|D|):   824
#   Open set size:       8221
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       95109.108
#   Best Cost (y):       9263.8821
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      95109.108
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.7808→ cube 2.5753
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0742→ cube 1.1125
#   Efficiency z (srs):  10.204 → 0.292 → 43.229
#   Efficiency y (srs):  6.994 → 0.909 → 9.5862
#   Alpha:               0.8117452820502623
#   Num changes:         2
#   Design Depth:        363
#   Design Size (|D|):   826
#   Open set size:       8236
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       90240.684
#   Best Cost (y):       9596.4518
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      90240.684
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.8229→ cube 2.7142
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.037→ cube 1.0739
#   Efficiency z (srs):  10.204 → 0.292 → 45.5612
#   Efficiency y (srs):  6.994 → 0.909 → 9.254
#   Alpha:               0.8961335628960659
#   Num changes:         1
#   Design Depth:        433
#   Design Size (|D|):   966
#   Open set size:       10555
#
# Progress: 7.6%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       89770.152
#   Best Cost (y):       9628.9239
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      89770.152
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.8272→ cube 2.7284
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0335→ cube 1.0703
#   Efficiency z (srs):  10.204 → 0.292 → 45.8
#   Efficiency y (srs):  6.994 → 0.909 → 9.2228
#   Alpha:               0.7291887458082502
#   Num changes:         2
#   Design Depth:        453
#   Design Size (|D|):   1006
#   Open set size:       11139
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       88570.599
#   Best Cost (y):       9724.186
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      88570.599
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.8384→ cube 2.7654
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0234→ cube 1.0598
#   Efficiency z (srs):  10.204 → 0.292 → 46.4203
#   Efficiency y (srs):  6.994 → 0.909 → 9.1324
#   Alpha:               0.8236858097820546
#   Num changes:         1
#   Design Depth:        467
#   Design Size (|D|):   1034
#   Open set size:       11433
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       87720.653
#   Best Cost (y):       9813.3502
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      87720.653
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.8465→ cube 2.7922
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0141→ cube 1.0502
#   Efficiency z (srs):  10.204 → 0.292 → 46.87
#   Efficiency y (srs):  6.994 → 0.909 → 9.0495
#   Alpha:               0.8110256345875468
#   Num changes:         2
#   Design Depth:        480
#   Design Size (|D|):   1060
#   Open set size:       11719
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       86254.631
#   Best Cost (y):       9754.6179
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      86254.631
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.8609→ cube 2.8397
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0202→ cube 1.0565
#   Efficiency z (srs):  10.204 → 0.292 → 47.6667
#   Efficiency y (srs):  6.994 → 0.909 → 9.1039
#   Alpha:               0.7884896963063848
#   Num changes:         1
#   Design Depth:        495
#   Design Size (|D|):   1090
#   Open set size:       12003
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       86236.672
#   Best Cost (y):       9761.4114
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      86236.672
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.8611→ cube 2.8402
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0195→ cube 1.0558
#   Efficiency z (srs):  10.204 → 0.292 → 47.6766
#   Efficiency y (srs):  6.994 → 0.909 → 9.0976
#   Alpha:               0.8587470474922496
#   Num changes:         2
#   Design Depth:        496
#   Design Size (|D|):   1092
#   Open set size:       12014
#
# Progress: 9.8%
# === Best Solution Updated at Iteration 490 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       81390.423
#   Best Cost (y):       9466.8409
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      81390.423
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9124→ cube 3.0094
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0512→ cube 1.0886
#   Efficiency z (srs):  10.204 → 0.292 → 50.5154
#   Efficiency y (srs):  6.994 → 0.909 → 9.3807
#   Alpha:               0.7773968331693942
#   Num changes:         2
#   Design Depth:        583
#   Design Size (|D|):   1266
#   Open set size:       14323
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       79352.533
#   Best Cost (y):       9416.7292
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      79352.533
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9358→ cube 3.0866
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0568→ cube 1.0944
#   Efficiency z (srs):  10.204 → 0.292 → 51.8127
#   Efficiency y (srs):  6.994 → 0.909 → 9.4306
#   Alpha:               0.7300331419751798
#   Num changes:         1
#   Design Depth:        627
#   Design Size (|D|):   1354
#   Open set size:       16064
#
#
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       79334.63
#   Best Cost (y):       9403.7755
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      79334.63
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.936→ cube 3.0873
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0582→ cube 1.0959
#   Efficiency z (srs):  10.204 → 0.292 → 51.8244
#   Efficiency y (srs):  6.994 → 0.909 → 9.4436
#   Alpha:               0.7005579976517963
#   Num changes:         1
#   Design Depth:        627
#   Design Size (|D|):   1354
#   Open set size:       16072
#
#
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       79302.229
#   Best Cost (y):       9398.9643
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      79302.229
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9364→ cube 3.0886
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0588→ cube 1.0965
#   Efficiency z (srs):  10.204 → 0.292 → 51.8456
#   Efficiency y (srs):  6.994 → 0.909 → 9.4484
#   Alpha:               0.8514647330958962
#   Num changes:         2
#   Design Depth:        628
#   Design Size (|D|):   1356
#   Open set size:       16075
#
# Progress: 11.2%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       78169.915
#   Best Cost (y):       9358.2644
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      78169.915
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9499→ cube 3.1333
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0634→ cube 1.1013
#   Efficiency z (srs):  10.204 → 0.292 → 52.5966
#   Efficiency y (srs):  6.994 → 0.909 → 9.4895
#   Alpha:               0.8521219813788253
#   Num changes:         1
#   Design Depth:        641
#   Design Size (|D|):   1382
#   Open set size:       16351
#
# Progress: 11.4%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       77558.271
#   Best Cost (y):       9383.8199
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      77558.271
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9574→ cube 3.1581
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0605→ cube 1.0983
#   Efficiency z (srs):  10.204 → 0.292 → 53.0114
#   Efficiency y (srs):  6.994 → 0.909 → 9.4637
#   Alpha:               0.8291991529090088
#   Num changes:         2
#   Design Depth:        651
#   Design Size (|D|):   1402
#   Open set size:       16644
#
# Progress: 11.8%
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       76994.551
#   Best Cost (y):       9406.7795
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      76994.551
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9644→ cube 3.1812
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0579→ cube 1.0956
#   Efficiency z (srs):  10.204 → 0.292 → 53.3995
#   Efficiency y (srs):  6.994 → 0.909 → 9.4406
#   Alpha:               0.8480600471764648
#   Num changes:         1
#   Design Depth:        667
#   Design Size (|D|):   1434
#   Open set size:       17222
#
#
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       76993.983
#   Best Cost (y):       9425.033
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      76993.983
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9645→ cube 3.1812
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0559→ cube 1.0934
#   Efficiency z (srs):  10.204 → 0.292 → 53.3999
#   Efficiency y (srs):  6.994 → 0.909 → 9.4223
#   Alpha:               0.8997199317839866
#   Num changes:         1
#   Design Depth:        667
#   Design Size (|D|):   1434
#   Open set size:       17232
#
# Progress: 12.6%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       76545.058
#   Best Cost (y):       9477.8509
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      76545.058
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9701→ cube 3.1999
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.05→ cube 1.0874
#   Efficiency z (srs):  10.204 → 0.292 → 53.7131
#   Efficiency y (srs):  6.994 → 0.909 → 9.3698
#   Alpha:               0.8738867385348497
#   Num changes:         1
#   Design Depth:        688
#   Design Size (|D|):   1476
#   Open set size:       18381
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       75755.828
#   Best Cost (y):       9555.5074
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      75755.828
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9802→ cube 3.2332
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0414→ cube 1.0785
#   Efficiency z (srs):  10.204 → 0.292 → 54.2727
#   Efficiency y (srs):  6.994 → 0.909 → 9.2936
#   Alpha:               0.8586320947341972
#   Num changes:         1
#   Design Depth:        705
#   Design Size (|D|):   1510
#   Open set size:       18976
#
# Progress: 13.4%
# === Best Solution Updated at Iteration 670 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       74976.829
#   Best Cost (y):       9483.3923
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      74976.829
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9904→ cube 3.2668
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0494→ cube 1.0867
#   Efficiency z (srs):  10.204 → 0.292 → 54.8366
#   Efficiency y (srs):  6.994 → 0.909 → 9.3643
#   Alpha:               0.857507576458673
#   Num changes:         1
#   Design Depth:        725
#   Design Size (|D|):   1550
#   Open set size:       19542
#
#
# === Best Solution Updated at Iteration 670 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       74975.306
#   Best Cost (y):       9486.7531
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      74975.306
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 0.9904→ cube 3.2668
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.049→ cube 1.0863
#   Efficiency z (srs):  10.204 → 0.292 → 54.8377
#   Efficiency y (srs):  6.994 → 0.909 → 9.361
#   Alpha:               0.8797533298793788
#   Num changes:         1
#   Design Depth:        725
#   Design Size (|D|):   1550
#   Open set size:       19553
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 700 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       73658.836
#   Best Cost (y):       9539.5952
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      73658.836
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0081→ cube 3.3252
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0432→ cube 1.0803
#   Efficiency z (srs):  10.204 → 0.292 → 55.8178
#   Efficiency y (srs):  6.994 → 0.909 → 9.3091
#   Alpha:               0.8019115663850107
#   Num changes:         1
#   Design Depth:        754
#   Design Size (|D|):   1608
#   Open set size:       20402
#
# Progress: 14.4%
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       73120.273
#   Best Cost (y):       9591.3337
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      73120.273
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0156→ cube 3.3497
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0376→ cube 1.0745
#   Efficiency z (srs):  10.204 → 0.292 → 56.2289
#   Efficiency y (srs):  6.994 → 0.909 → 9.2589
#   Alpha:               0.705491351044832
#   Num changes:         1
#   Design Depth:        775
#   Design Size (|D|):   1650
#   Open set size:       20984
#
#
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       73106.295
#   Best Cost (y):       9592.4534
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      73106.295
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0157→ cube 3.3504
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0374→ cube 1.0744
#   Efficiency z (srs):  10.204 → 0.292 → 56.2396
#   Efficiency y (srs):  6.994 → 0.909 → 9.2579
#   Alpha:               0.8893053389670835
#   Num changes:         1
#   Design Depth:        775
#   Design Size (|D|):   1650
#   Open set size:       20990
#
# Progress: 14.6%
# === Best Solution Updated at Iteration 730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       72478.917
#   Best Cost (y):       9547.5049
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      72478.917
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0245→ cube 3.3794
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0423→ cube 1.0794
#   Efficiency z (srs):  10.204 → 0.292 → 56.7264
#   Efficiency y (srs):  6.994 → 0.909 → 9.3014
#   Alpha:               0.7582405970368362
#   Num changes:         1
#   Design Depth:        789
#   Design Size (|D|):   1678
#   Open set size:       21276
#
#
# === Best Solution Updated at Iteration 730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       72378.042
#   Best Cost (y):       9556.8842
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      72378.042
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.026→ cube 3.3841
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0413→ cube 1.0784
#   Efficiency z (srs):  10.204 → 0.292 → 56.8055
#   Efficiency y (srs):  6.994 → 0.909 → 9.2923
#   Alpha:               0.7134229982833812
#   Num changes:         2
#   Design Depth:        790
#   Design Size (|D|):   1680
#   Open set size:       21277
#
#
# === Best Solution Updated at Iteration 730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       72363.677
#   Best Cost (y):       9554.1457
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      72363.677
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0262→ cube 3.3848
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0416→ cube 1.0787
#   Efficiency z (srs):  10.204 → 0.292 → 56.8168
#   Efficiency y (srs):  6.994 → 0.909 → 9.295
#   Alpha:               0.8720222165795223
#   Num changes:         1
#   Design Depth:        789
#   Design Size (|D|):   1678
#   Open set size:       21292
#
# Progress: 15.0%
# === Best Solution Updated at Iteration 750 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       70682.815
#   Best Cost (y):       9476.7918
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      70682.815
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0506→ cube 3.4652
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0501→ cube 1.0875
#   Efficiency z (srs):  10.204 → 0.292 → 58.1679
#   Efficiency y (srs):  6.994 → 0.909 → 9.3708
#   Alpha:               0.8329862198503433
#   Num changes:         1
#   Design Depth:        814
#   Design Size (|D|):   1728
#   Open set size:       21871
#
# Progress: 15.2%
# === Best Solution Updated at Iteration 760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       70424.623
#   Best Cost (y):       9448.6698
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      70424.623
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0544→ cube 3.4779
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0532→ cube 1.0907
#   Efficiency z (srs):  10.204 → 0.292 → 58.3812
#   Efficiency y (srs):  6.994 → 0.909 → 9.3987
#   Alpha:               0.7138767355645745
#   Num changes:         2
#   Design Depth:        822
#   Design Size (|D|):   1744
#   Open set size:       22143
#
#
# === Best Solution Updated at Iteration 760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       70392.327
#   Best Cost (y):       9429.1456
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      70392.327
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0549→ cube 3.4795
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0554→ cube 1.093
#   Efficiency z (srs):  10.204 → 0.292 → 58.4079
#   Efficiency y (srs):  6.994 → 0.909 → 9.4182
#   Alpha:               0.8759911641476832
#   Num changes:         2
#   Design Depth:        822
#   Design Size (|D|):   1744
#   Open set size:       22148
#
# Progress: 15.8%
# === Best Solution Updated at Iteration 790 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       69546.076
#   Best Cost (y):       9433.6421
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      69546.076
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0677→ cube 3.5219
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0549→ cube 1.0925
#   Efficiency z (srs):  10.204 → 0.292 → 59.1187
#   Efficiency y (srs):  6.994 → 0.909 → 9.4137
#   Alpha:               0.8009894197448655
#   Num changes:         2
#   Design Depth:        846
#   Design Size (|D|):   1792
#   Open set size:       23018
#
#
# === Best Solution Updated at Iteration 790 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       69510.894
#   Best Cost (y):       9378.0115
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      69510.894
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0683→ cube 3.5237
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0612→ cube 1.0989
#   Efficiency z (srs):  10.204 → 0.292 → 59.1486
#   Efficiency y (srs):  6.994 → 0.909 → 9.4695
#   Alpha:               0.83400326817787
#   Num changes:         1
#   Design Depth:        845
#   Design Size (|D|):   1790
#   Open set size:       23032
#
# Progress: 16.0%
# === Best Solution Updated at Iteration 800 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       68550.518
#   Best Cost (y):       9439.1762
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      68550.518
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0833→ cube 3.573
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0543→ cube 1.0918
#   Efficiency z (srs):  10.204 → 0.292 → 59.9772
#   Efficiency y (srs):  6.994 → 0.909 → 9.4082
#   Alpha:               0.8111029988355374
#   Num changes:         2
#   Design Depth:        860
#   Design Size (|D|):   1820
#   Open set size:       23304
#
#
# === Best Solution Updated at Iteration 800 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       67968.671
#   Best Cost (y):       9428.875
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      67968.671
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.0925→ cube 3.6036
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0554→ cube 1.093
#   Efficiency z (srs):  10.204 → 0.292 → 60.4907
#   Efficiency y (srs):  6.994 → 0.909 → 9.4185
#   Alpha:               0.8886085638240867
#   Num changes:         3
#   Design Depth:        861
#   Design Size (|D|):   1822
#   Open set size:       23309
#
# Progress: 16.2%
# === Best Solution Updated at Iteration 810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       67200.059
#   Best Cost (y):       9345.4955
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      67200.059
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.105→ cube 3.6448
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0648→ cube 1.1028
#   Efficiency z (srs):  10.204 → 0.292 → 61.1826
#   Efficiency y (srs):  6.994 → 0.909 → 9.5025
#   Alpha:               0.8699467030305318
#   Num changes:         1
#   Design Depth:        875
#   Design Size (|D|):   1850
#   Open set size:       23591
#
#
# === Best Solution Updated at Iteration 810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       67162.806
#   Best Cost (y):       9340.6094
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      67162.806
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1056→ cube 3.6469
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0654→ cube 1.1033
#   Efficiency z (srs):  10.204 → 0.292 → 61.2165
#   Efficiency y (srs):  6.994 → 0.909 → 9.5075
#   Alpha:               0.8760930482573468
#   Num changes:         1
#   Design Depth:        875
#   Design Size (|D|):   1850
#   Open set size:       23608
#
#
# === Best Solution Updated at Iteration 810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       67016.495
#   Best Cost (y):       9342.1123
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      67016.495
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.108→ cube 3.6548
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0652→ cube 1.1032
#   Efficiency z (srs):  10.204 → 0.292 → 61.3501
#   Efficiency y (srs):  6.994 → 0.909 → 9.5059
#   Alpha:               0.8149604402196517
#   Num changes:         3
#   Design Depth:        877
#   Design Size (|D|):   1854
#   Open set size:       23609
#
# Progress: 17.0%
# === Best Solution Updated at Iteration 850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       66644.899
#   Best Cost (y):       9278.6319
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      66644.899
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1142→ cube 3.6752
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0725→ cube 1.1107
#   Efficiency z (srs):  10.204 → 0.292 → 61.6922
#   Efficiency y (srs):  6.994 → 0.909 → 9.571
#   Alpha:               0.8630501373342583
#   Num changes:         1
#   Design Depth:        898
#   Design Size (|D|):   1896
#   Open set size:       24754
#
#
# === Best Solution Updated at Iteration 850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       66631.305
#   Best Cost (y):       9276.1178
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      66631.305
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1145→ cube 3.6759
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0728→ cube 1.111
#   Efficiency z (srs):  10.204 → 0.292 → 61.7048
#   Efficiency y (srs):  6.994 → 0.909 → 9.5736
#   Alpha:               0.8503219011487725
#   Num changes:         1
#   Design Depth:        898
#   Design Size (|D|):   1896
#   Open set size:       24755
#
# Progress: 17.4%
# === Best Solution Updated at Iteration 870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       65941.33
#   Best Cost (y):       9273.6395
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      65941.33
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1261→ cube 3.7144
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0731→ cube 1.1113
#   Efficiency z (srs):  10.204 → 0.292 → 62.3504
#   Efficiency y (srs):  6.994 → 0.909 → 9.5761
#   Alpha:               0.7917395920056132
#   Num changes:         2
#   Design Depth:        924
#   Design Size (|D|):   1948
#   Open set size:       25340
#
# Progress: 17.6%
# === Best Solution Updated at Iteration 880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       65508.611
#   Best Cost (y):       9318.2213
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      65508.611
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1336→ cube 3.7389
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.068→ cube 1.106
#   Efficiency z (srs):  10.204 → 0.292 → 62.7623
#   Efficiency y (srs):  6.994 → 0.909 → 9.5303
#   Alpha:               0.7161440011204059
#   Num changes:         1
#   Design Depth:        937
#   Design Size (|D|):   1974
#   Open set size:       25625
#
#
# === Best Solution Updated at Iteration 880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       65339.455
#   Best Cost (y):       9324.1087
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      65339.455
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1365→ cube 3.7486
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0673→ cube 1.1053
#   Efficiency z (srs):  10.204 → 0.292 → 62.9248
#   Efficiency y (srs):  6.994 → 0.909 → 9.5243
#   Alpha:               0.7427563173975205
#   Num changes:         2
#   Design Depth:        938
#   Design Size (|D|):   1976
#   Open set size:       25637
#
# Progress: 18.2%
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       64944.851
#   Best Cost (y):       9458.4617
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      64944.851
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1434→ cube 3.7714
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0521→ cube 1.0896
#   Efficiency z (srs):  10.204 → 0.292 → 63.3071
#   Efficiency y (srs):  6.994 → 0.909 → 9.389
#   Alpha:               0.824524466309203
#   Num changes:         3
#   Design Depth:        963
#   Design Size (|D|):   2026
#   Open set size:       26502
#
# Progress: 19.0%
# === Best Solution Updated at Iteration 950 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       64528.325
#   Best Cost (y):       9454.9869
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      64528.325
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1508→ cube 3.7957
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0525→ cube 1.09
#   Efficiency z (srs):  10.204 → 0.292 → 63.7158
#   Efficiency y (srs):  6.994 → 0.909 → 9.3925
#   Alpha:               0.7964111381907338
#   Num changes:         1
#   Design Depth:        1001
#   Design Size (|D|):   2102
#   Open set size:       27658
#
# Progress: 19.2%
# === Best Solution Updated at Iteration 960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       64347.925
#   Best Cost (y):       9467.631
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      64347.925
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.154→ cube 3.8064
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0511→ cube 1.0885
#   Efficiency z (srs):  10.204 → 0.292 → 63.8944
#   Efficiency y (srs):  6.994 → 0.909 → 9.3799
#   Alpha:               0.8724813255357309
#   Num changes:         1
#   Design Depth:        1010
#   Design Size (|D|):   2120
#   Open set size:       27944
#
# Progress: 19.4%
# === Best Solution Updated at Iteration 970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       64310.034
#   Best Cost (y):       9491.8647
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      64310.034
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1547→ cube 3.8086
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0484→ cube 1.0858
#   Efficiency z (srs):  10.204 → 0.292 → 63.932
#   Efficiency y (srs):  6.994 → 0.909 → 9.356
#   Alpha:               0.799774793731764
#   Num changes:         1
#   Design Depth:        1014
#   Design Size (|D|):   2128
#   Open set size:       28248
#
# Progress: 20.6%
# === Best Solution Updated at Iteration 1030 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       64161.785
#   Best Cost (y):       9517.7611
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      64161.785
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1573→ cube 3.8174
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0456→ cube 1.0828
#   Efficiency z (srs):  10.204 → 0.292 → 64.0797
#   Efficiency y (srs):  6.994 → 0.909 → 9.3305
#   Alpha:               0.852746753201199
#   Num changes:         3
#   Design Depth:        1036
#   Design Size (|D|):   2172
#   Open set size:       29971
#
#
# === Best Solution Updated at Iteration 1030 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       63988.747
#   Best Cost (y):       9525.7545
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      63988.747
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1605→ cube 3.8278
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0447→ cube 1.0819
#   Efficiency z (srs):  10.204 → 0.292 → 64.253
#   Efficiency y (srs):  6.994 → 0.909 → 9.3227
#   Alpha:               0.7431695270951135
#   Num changes:         3
#   Design Depth:        1036
#   Design Size (|D|):   2172
#   Open set size:       29986
#
# Progress: 21.0%
# === Best Solution Updated at Iteration 1050 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       63548.277
#   Best Cost (y):       9461.6594
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      63548.277
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1685→ cube 3.8543
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0518→ cube 1.0892
#   Efficiency z (srs):  10.204 → 0.292 → 64.6984
#   Efficiency y (srs):  6.994 → 0.909 → 9.3858
#   Alpha:               0.7923078986295427
#   Num changes:         1
#   Design Depth:        1060
#   Design Size (|D|):   2220
#   Open set size:       30564
#
# Progress: 21.4%
# === Best Solution Updated at Iteration 1070 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       63300.315
#   Best Cost (y):       9445.4876
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.515
#   rho (p, y):          0.926
#   Criteria Value:      63300.315
#   Efficiency z (0→f):  0.184 → 0.292 → dsd 1.1731→ cube 3.8694
#   Efficiency y (0→f):  0.784 → 0.909 → dsd 1.0536→ cube 1.0911
#   Efficiency z (srs):  10.204 → 0.292 → 64.9518
#   Efficiency y (srs):  6.994 → 0.909 → 9.4019
#   Alpha:               0.7667285690992012
#   Num changes:         1
#   Design Depth:        1077
#   Design Size (|D|):   2254
#   Open set size:       31131
#
# Progress: 21.6%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 48
#      22 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      23                    inclusion_probability=inclusions, balance_method=bardia_balance_method)
#      25 astar = AStar(
#      26     inclusions              = inclusions,
#      27     num_initial_nodes       = num_initial_nodes,
#    (...)     45     rng                     = rng,
#      46 )
# ---> 48 result = astar.run(
#      49     max_iterations             = max_iterations,
#      50     num_new_nodes              = num_new_nodes,
#      51     max_open_set_size          = max_open_set_size,
#      52     random_restart_period      = random_restart_period,
#      53     random_injection_count     = random_injection_count,
#      54     prune_fraction             = prune_fraction,
#      55     num_top_restart_nodes      = num_top_restart_nodes,
#      56     stuck_fraction             = stuck_fraction,
#      57
#      58 )
#      60 print("Best criteria value:", astar.best_criteria_value)
#      61 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:19, in VarNHT.__call__(self, design)
#      12 ones = np.ones(N)
#      13 NHT_estimator_z = np.array([
#      14     np.sum(self.auxiliary_variable[list(sample.ids)] /
#      15            self.inclusion_probability[list(sample.ids)])
#      16     for sample in design
#      17 ])
#      18 NHT_estimator_z2 = np.array([
# ---> 19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
#      29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
# Out:
# size of init design 100
# size of best design 2268
# 254549.70661918845
# 63276.84269422789
# [100]
# /tmp/ipykernel_281102/683604881.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# sum of inclusions, last ini and original 10.000000020000005 10.000000020000005 10.0
# 1.0000000020000002
# n =  [10]
# 10043.617183059718 50480.78213352054 10043.617202861926 50480.782232546604
# 10043.617183059718 50480.78213352054 10043.617202861926 50480.782232546604
# var z estimates 63271.746
# var y estimates 9415.568
