# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Artificial"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmppERuCr", R: "/tmp/RtmpyFRfuj"
#   warnings.warn(

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_9.5_py_8.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_9.5_py_8.5_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.7 0.9
# Generating initial designs:   0%|                      | 0/3000 [00:00<?, ?it/s]
# Initial design 0: method = Original, efficiency z = 0.1996, y=0.5032
# New best at idx=0: method = Original, efficiency z = 0.1996 and efficiency y = 0.5032
# New best at idx=2: method = z/pi, efficiency z = 0.1996 and efficiency y = 0.5032
# New best at idx=3: method = swap, efficiency z = 0.2379 and efficiency y = 0.5439
# Generating initial designs:   1%|             | 19/3000 [00:00<01:10, 42.21it/s]
# New best at idx=7: method = swap, efficiency z = 0.2477 and efficiency y = 0.5428
# Generating initial designs:   7%|▊           | 217/3000 [00:03<00:42, 65.64it/s]
# New best at idx=207: method = swap, efficiency z = 0.2785 and efficiency y = 0.4693
# Generating initial designs:  12%|█▍          | 373/3000 [00:06<00:49, 53.14it/s]
# New best at idx=368: method = swap, efficiency z = 0.2871 and efficiency y = 0.5505
# Generating initial designs:  44%|████▊      | 1324/3000 [00:22<00:19, 84.64it/s]
# New best at idx=1310: method = swap, efficiency z = 0.2894 and efficiency y = 0.5857
# Generating initial designs: 100%|███████████| 3000/3000 [00:50<00:00, 59.50it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       210218.048
#   Best Cost (y):       13168.9265
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      210218.048
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.2995→ cube 0.7102
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.5898→ cube 0.676
#   Efficiency z (srs):  8.121 → 0.289 → 12.1868
#   Efficiency y (srs):  5.754 → 0.586 → 6.7436
#   Alpha:               0.8840781153433906
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       100
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       185523.567
#   Best Cost (y):       12709.7231
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      185523.567
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.3393→ cube 0.8048
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.6111→ cube 0.7004
#   Efficiency z (srs):  8.121 → 0.289 → 13.8089
#   Efficiency y (srs):  5.754 → 0.586 → 6.9872
#   Alpha:               0.8585486162691696
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       106
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       177542.157
#   Best Cost (y):       12642.7088
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      177542.157
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.3546→ cube 0.8409
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.6144→ cube 0.7041
#   Efficiency z (srs):  8.121 → 0.289 → 14.4297
#   Efficiency y (srs):  5.754 → 0.586 → 7.0242
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       158
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       131198.763
#   Best Cost (y):       10207.5352
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      131198.763
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.4798→ cube 1.138
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7609→ cube 0.8721
#   Efficiency z (srs):  8.121 → 0.289 → 19.5267
#   Efficiency y (srs):  5.754 → 0.586 → 8.7
#   Alpha:               0.805240661064028
#   Num changes:         2
#   Design Depth:        47
#   Design Size (|D|):   194
#   Open set size:       1261
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       127539.821
#   Best Cost (y):       9724.7148
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      127539.821
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.4936→ cube 1.1706
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7987→ cube 0.9154
#   Efficiency z (srs):  8.121 → 0.289 → 20.0869
#   Efficiency y (srs):  5.754 → 0.586 → 9.1319
#   Alpha:               0.7914097127072731
#   Num changes:         2
#   Design Depth:        63
#   Design Size (|D|):   226
#   Open set size:       1559
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       126239.005
#   Best Cost (y):       9678.2164
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      126239.005
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.4987→ cube 1.1827
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8025→ cube 0.9198
#   Efficiency z (srs):  8.121 → 0.289 → 20.2939
#   Efficiency y (srs):  5.754 → 0.586 → 9.1758
#   Alpha:               0.82831180118021
#   Num changes:         2
#   Design Depth:        63
#   Design Size (|D|):   226
#   Open set size:       1561
#
# Progress: 1.6%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       117473.91
#   Best Cost (y):       9593.8348
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      117473.91
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.5359→ cube 1.2709
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8096→ cube 0.9279
#   Efficiency z (srs):  8.121 → 0.289 → 21.8081
#   Efficiency y (srs):  5.754 → 0.586 → 9.2565
#   Alpha:               0.7096388364542816
#   Num changes:         2
#   Design Depth:        89
#   Design Size (|D|):   278
#   Open set size:       2441
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       117385.302
#   Best Cost (y):       9783.7703
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      117385.302
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.5363→ cube 1.2719
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7939→ cube 0.9099
#   Efficiency z (srs):  8.121 → 0.289 → 21.8246
#   Efficiency y (srs):  5.754 → 0.586 → 9.0768
#   Alpha:               0.7675657770510759
#   Num changes:         2
#   Design Depth:        89
#   Design Size (|D|):   278
#   Open set size:       2449
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       102165.758
#   Best Cost (y):       10001.58
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      102165.758
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6162→ cube 1.4614
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7766→ cube 0.8901
#   Efficiency z (srs):  8.121 → 0.289 → 25.0758
#   Efficiency y (srs):  5.754 → 0.586 → 8.8791
#   Alpha:               0.7100637958590146
#   Num changes:         2
#   Design Depth:        135
#   Design Size (|D|):   370
#   Open set size:       3290
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       102038.402
#   Best Cost (y):       9975.0679
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      102038.402
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.617→ cube 1.4632
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7787→ cube 0.8925
#   Efficiency z (srs):  8.121 → 0.289 → 25.1071
#   Efficiency y (srs):  5.754 → 0.586 → 8.9027
#   Alpha:               0.8865473835650017
#   Num changes:         1
#   Design Depth:        134
#   Design Size (|D|):   368
#   Open set size:       3298
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       102016.102
#   Best Cost (y):       9984.8182
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      102016.102
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6171→ cube 1.4635
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7779→ cube 0.8916
#   Efficiency z (srs):  8.121 → 0.289 → 25.1126
#   Efficiency y (srs):  5.754 → 0.586 → 8.8941
#   Alpha:               0.8999803384484777
#   Num changes:         1
#   Design Depth:        134
#   Design Size (|D|):   368
#   Open set size:       3299
#
# Progress: 2.4%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       100214.715
#   Best Cost (y):       9586.9666
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      100214.715
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6282→ cube 1.4898
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8102→ cube 0.9286
#   Efficiency z (srs):  8.121 → 0.289 → 25.564
#   Efficiency y (srs):  5.754 → 0.586 → 9.2631
#   Alpha:               0.7158967082908574
#   Num changes:         1
#   Design Depth:        150
#   Design Size (|D|):   400
#   Open set size:       3581
#
# Progress: 2.6%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       98314.944
#   Best Cost (y):       9600.7081
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      98314.944
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6403→ cube 1.5186
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.809→ cube 0.9273
#   Efficiency z (srs):  8.121 → 0.289 → 26.0579
#   Efficiency y (srs):  5.754 → 0.586 → 9.2499
#   Alpha:               0.8326614320779577
#   Num changes:         1
#   Design Depth:        161
#   Design Size (|D|):   422
#   Open set size:       3874
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       98128.189
#   Best Cost (y):       9606.3973
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      98128.189
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6416→ cube 1.5215
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8085→ cube 0.9267
#   Efficiency z (srs):  8.121 → 0.289 → 26.1075
#   Efficiency y (srs):  5.754 → 0.586 → 9.2444
#   Alpha:               0.8757967946640768
#   Num changes:         2
#   Design Depth:        162
#   Design Size (|D|):   424
#   Open set size:       3890
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       96931.839
#   Best Cost (y):       9656.4284
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      96931.839
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6495→ cube 1.5403
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8043→ cube 0.9219
#   Efficiency z (srs):  8.121 → 0.289 → 26.4298
#   Efficiency y (srs):  5.754 → 0.586 → 9.1965
#   Alpha:               0.7144577235143709
#   Num changes:         3
#   Design Depth:        176
#   Design Size (|D|):   452
#   Open set size:       4477
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       96471.623
#   Best Cost (y):       9642.9945
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      96471.623
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6526→ cube 1.5476
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8055→ cube 0.9232
#   Efficiency z (srs):  8.121 → 0.289 → 26.5558
#   Efficiency y (srs):  5.754 → 0.586 → 9.2093
#   Alpha:               0.7918156877982894
#   Num changes:         2
#   Design Depth:        185
#   Design Size (|D|):   470
#   Open set size:       4747
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       96383.477
#   Best Cost (y):       9623.8775
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      96383.477
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6532→ cube 1.549
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8071→ cube 0.925
#   Efficiency z (srs):  8.121 → 0.289 → 26.5801
#   Efficiency y (srs):  5.754 → 0.586 → 9.2276
#   Alpha:               0.7554343290246338
#   Num changes:         2
#   Design Depth:        185
#   Design Size (|D|):   470
#   Open set size:       4763
#
# Progress: 3.4%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       93995.239
#   Best Cost (y):       9608.4199
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      93995.239
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6698→ cube 1.5884
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8084→ cube 0.9265
#   Efficiency z (srs):  8.121 → 0.289 → 27.2555
#   Efficiency y (srs):  5.754 → 0.586 → 9.2425
#   Alpha:               0.7565876930636721
#   Num changes:         3
#   Design Depth:        202
#   Design Size (|D|):   504
#   Open set size:       5033
#
# Progress: 3.6%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       92286.154
#   Best Cost (y):       9716.0675
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      92286.154
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.6822→ cube 1.6178
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.7994→ cube 0.9163
#   Efficiency z (srs):  8.121 → 0.289 → 27.7602
#   Efficiency y (srs):  5.754 → 0.586 → 9.1401
#   Alpha:               0.8665473973750736
#   Num changes:         1
#   Design Depth:        217
#   Design Size (|D|):   534
#   Open set size:       5327
#
# Progress: 4.6%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       85613.094
#   Best Cost (y):       9043.0995
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      85613.094
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7353→ cube 1.7439
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8589→ cube 0.9844
#   Efficiency z (srs):  8.121 → 0.289 → 29.924
#   Efficiency y (srs):  5.754 → 0.586 → 9.8203
#   Alpha:               0.7684256630659226
#   Num changes:         3
#   Design Depth:        272
#   Design Size (|D|):   644
#   Open set size:       6772
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       85572.377
#   Best Cost (y):       9060.9033
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      85572.377
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7357→ cube 1.7447
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8572→ cube 0.9825
#   Efficiency z (srs):  8.121 → 0.289 → 29.9382
#   Efficiency y (srs):  5.754 → 0.586 → 9.801
#   Alpha:               0.867264767272419
#   Num changes:         1
#   Design Depth:        270
#   Design Size (|D|):   640
#   Open set size:       6780
#
#
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       85455.437
#   Best Cost (y):       9068.6971
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      85455.437
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7367→ cube 1.7471
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8565→ cube 0.9817
#   Efficiency z (srs):  8.121 → 0.289 → 29.9792
#   Efficiency y (srs):  5.754 → 0.586 → 9.7925
#   Alpha:               0.7349352864499625
#   Num changes:         3
#   Design Depth:        272
#   Design Size (|D|):   644
#   Open set size:       6793
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       83007.373
#   Best Cost (y):       9087.7014
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      83007.373
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7584→ cube 1.7987
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8547→ cube 0.9796
#   Efficiency z (srs):  8.121 → 0.289 → 30.8633
#   Efficiency y (srs):  5.754 → 0.586 → 9.7721
#   Alpha:               0.7317401890057167
#   Num changes:         2
#   Design Depth:        294
#   Design Size (|D|):   688
#   Open set size:       7357
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       82979.057
#   Best Cost (y):       9099.6941
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      82979.057
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7587→ cube 1.7993
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8536→ cube 0.9783
#   Efficiency z (srs):  8.121 → 0.289 → 30.8739
#   Efficiency y (srs):  5.754 → 0.586 → 9.7592
#   Alpha:               0.8636533910445715
#   Num changes:         1
#   Design Depth:        293
#   Design Size (|D|):   686
#   Open set size:       7365
#
# Progress: 5.4%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       81544.915
#   Best Cost (y):       9104.477
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      81544.915
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.772→ cube 1.8309
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8531→ cube 0.9778
#   Efficiency z (srs):  8.121 → 0.289 → 31.4169
#   Efficiency y (srs):  5.754 → 0.586 → 9.754
#   Alpha:               0.7615001225405267
#   Num changes:         2
#   Design Depth:        322
#   Design Size (|D|):   744
#   Open set size:       7942
#
# Progress: 5.6%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       80277.132
#   Best Cost (y):       8964.215
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      80277.132
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7842→ cube 1.8598
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8665→ cube 0.9931
#   Efficiency z (srs):  8.121 → 0.289 → 31.913
#   Efficiency y (srs):  5.754 → 0.586 → 9.9067
#   Alpha:               0.785091119137916
#   Num changes:         1
#   Design Depth:        335
#   Design Size (|D|):   770
#   Open set size:       8222
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       80275.833
#   Best Cost (y):       8965.5385
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      80275.833
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.7842→ cube 1.8599
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8663→ cube 0.993
#   Efficiency z (srs):  8.121 → 0.289 → 31.9135
#   Efficiency y (srs):  5.754 → 0.586 → 9.9052
#   Alpha:               0.8196633191828169
#   Num changes:         1
#   Design Depth:        335
#   Design Size (|D|):   770
#   Open set size:       8242
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       79193.145
#   Best Cost (y):       9026.8081
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      79193.145
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.795→ cube 1.8853
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8604→ cube 0.9862
#   Efficiency z (srs):  8.121 → 0.289 → 32.3498
#   Efficiency y (srs):  5.754 → 0.586 → 9.838
#   Alpha:               0.7708981093237989
#   Num changes:         1
#   Design Depth:        348
#   Design Size (|D|):   796
#   Open set size:       8512
#
# Progress: 6.4%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       77390.562
#   Best Cost (y):       9181.2229
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      77390.562
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8135→ cube 1.9292
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.846→ cube 0.9696
#   Efficiency z (srs):  8.121 → 0.289 → 33.1033
#   Efficiency y (srs):  5.754 → 0.586 → 9.6725
#   Alpha:               0.7882984309735837
#   Num changes:         2
#   Design Depth:        380
#   Design Size (|D|):   860
#   Open set size:       9380
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       77369.388
#   Best Cost (y):       9150.8117
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      77369.388
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8137→ cube 1.9297
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8488→ cube 0.9728
#   Efficiency z (srs):  8.121 → 0.289 → 33.1124
#   Efficiency y (srs):  5.754 → 0.586 → 9.7047
#   Alpha:               0.7480685945281259
#   Num changes:         2
#   Design Depth:        380
#   Design Size (|D|):   860
#   Open set size:       9401
#
# Progress: 6.6%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       76221.505
#   Best Cost (y):       9139.7684
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      76221.505
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.826→ cube 1.9588
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8498→ cube 0.974
#   Efficiency z (srs):  8.121 → 0.289 → 33.6111
#   Efficiency y (srs):  5.754 → 0.586 → 9.7164
#   Alpha:               0.7332644980227551
#   Num changes:         1
#   Design Depth:        392
#   Design Size (|D|):   884
#   Open set size:       9672
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       76210.92
#   Best Cost (y):       9125.2272
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      76210.92
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8261→ cube 1.9591
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8512→ cube 0.9756
#   Efficiency z (srs):  8.121 → 0.289 → 33.6157
#   Efficiency y (srs):  5.754 → 0.586 → 9.7319
#   Alpha:               0.7239935181625017
#   Num changes:         1
#   Design Depth:        392
#   Design Size (|D|):   884
#   Open set size:       9680
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       76202.431
#   Best Cost (y):       9122.2465
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      76202.431
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8262→ cube 1.9593
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8514→ cube 0.9759
#   Efficiency z (srs):  8.121 → 0.289 → 33.6195
#   Efficiency y (srs):  5.754 → 0.586 → 9.735
#   Alpha:               0.8501169513974127
#   Num changes:         1
#   Design Depth:        392
#   Design Size (|D|):   884
#   Open set size:       9697
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       75577.931
#   Best Cost (y):       9121.8955
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      75577.931
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.833→ cube 1.9755
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8515→ cube 0.9759
#   Efficiency z (srs):  8.121 → 0.289 → 33.8973
#   Efficiency y (srs):  5.754 → 0.586 → 9.7354
#   Alpha:               0.7404672191034439
#   Num changes:         1
#   Design Depth:        407
#   Design Size (|D|):   914
#   Open set size:       9980
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       75447.667
#   Best Cost (y):       9089.269
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      75447.667
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8344→ cube 1.9789
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8545→ cube 0.9794
#   Efficiency z (srs):  8.121 → 0.289 → 33.9558
#   Efficiency y (srs):  5.754 → 0.586 → 9.7704
#   Alpha:               0.8579149314375125
#   Num changes:         3
#   Design Depth:        415
#   Design Size (|D|):   930
#   Open set size:       10261
#
#
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       75394.652
#   Best Cost (y):       9102.3898
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      75394.652
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.835→ cube 1.9803
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8533→ cube 0.978
#   Efficiency z (srs):  8.121 → 0.289 → 33.9797
#   Efficiency y (srs):  5.754 → 0.586 → 9.7563
#   Alpha:               0.8498456327193493
#   Num changes:         3
#   Design Depth:        415
#   Design Size (|D|):   930
#   Open set size:       10267
#
# Progress: 8.4%
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       74349.276
#   Best Cost (y):       8994.6898
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      74349.276
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8467→ cube 2.0081
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8635→ cube 0.9897
#   Efficiency z (srs):  8.121 → 0.289 → 34.4574
#   Efficiency y (srs):  5.754 → 0.586 → 9.8731
#   Alpha:               0.7486035790806163
#   Num changes:         3
#   Design Depth:        446
#   Design Size (|D|):   992
#   Open set size:       12281
#
# Progress: 8.6%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       73744.708
#   Best Cost (y):       8986.1135
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      73744.708
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8537→ cube 2.0246
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8643→ cube 0.9907
#   Efficiency z (srs):  8.121 → 0.289 → 34.7399
#   Efficiency y (srs):  5.754 → 0.586 → 9.8825
#   Alpha:               0.7393483462681474
#   Num changes:         1
#   Design Depth:        454
#   Design Size (|D|):   1008
#   Open set size:       12578
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       72184.245
#   Best Cost (y):       8824.7473
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      72184.245
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8721→ cube 2.0683
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8802→ cube 1.0088
#   Efficiency z (srs):  8.121 → 0.289 → 35.4909
#   Efficiency y (srs):  5.754 → 0.586 → 10.0632
#   Alpha:               0.8291914073079656
#   Num changes:         1
#   Design Depth:        486
#   Design Size (|D|):   1072
#   Open set size:       13442
#
#
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       72084.457
#   Best Cost (y):       8807.478
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      72084.457
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8734→ cube 2.0712
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8819→ cube 1.0108
#   Efficiency z (srs):  8.121 → 0.289 → 35.5401
#   Efficiency y (srs):  5.754 → 0.586 → 10.083
#   Alpha:               0.8433960589366529
#   Num changes:         3
#   Design Depth:        488
#   Design Size (|D|):   1076
#   Open set size:       13463
#
# Progress: 9.6%
# === Best Solution Updated at Iteration 480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       71347.875
#   Best Cost (y):       8823.1909
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      71347.875
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8824→ cube 2.0926
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8803→ cube 1.009
#   Efficiency z (srs):  8.121 → 0.289 → 35.907
#   Efficiency y (srs):  5.754 → 0.586 → 10.065
#   Alpha:               0.8902913905019814
#   Num changes:         1
#   Design Depth:        509
#   Design Size (|D|):   1118
#   Open set size:       14022
#
# Progress: 9.8%
# === Best Solution Updated at Iteration 490 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       70675.736
#   Best Cost (y):       8716.7435
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      70675.736
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8908→ cube 2.1125
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8911→ cube 1.0213
#   Efficiency z (srs):  8.121 → 0.289 → 36.2484
#   Efficiency y (srs):  5.754 → 0.586 → 10.1879
#   Alpha:               0.703515102753531
#   Num changes:         1
#   Design Depth:        522
#   Design Size (|D|):   1144
#   Open set size:       14316
#
#
# === Best Solution Updated at Iteration 490 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       70293.326
#   Best Cost (y):       8687.215
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      70293.326
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.8956→ cube 2.124
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.8941→ cube 1.0248
#   Efficiency z (srs):  8.121 → 0.289 → 36.4456
#   Efficiency y (srs):  5.754 → 0.586 → 10.2226
#   Alpha:               0.8624935438800216
#   Num changes:         3
#   Design Depth:        524
#   Design Size (|D|):   1148
#   Open set size:       14339
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       68540.827
#   Best Cost (y):       8552.2999
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      68540.827
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9185→ cube 2.1783
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9082→ cube 1.0409
#   Efficiency z (srs):  8.121 → 0.289 → 37.3775
#   Efficiency y (srs):  5.754 → 0.586 → 10.3838
#   Alpha:               0.7286082905057019
#   Num changes:         3
#   Design Depth:        546
#   Design Size (|D|):   1192
#   Open set size:       14602
#
#
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       68302.289
#   Best Cost (y):       8524.8357
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      68302.289
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9217→ cube 2.1859
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9111→ cube 1.0443
#   Efficiency z (srs):  8.121 → 0.289 → 37.508
#   Efficiency y (srs):  5.754 → 0.586 → 10.4173
#   Alpha:               0.8766063295926166
#   Num changes:         2
#   Design Depth:        545
#   Design Size (|D|):   1190
#   Open set size:       14603
#
#
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       68283.176
#   Best Cost (y):       8539.0682
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      68283.176
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.922→ cube 2.1865
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9096→ cube 1.0425
#   Efficiency z (srs):  8.121 → 0.289 → 37.5185
#   Efficiency y (srs):  5.754 → 0.586 → 10.3999
#   Alpha:               0.7276175856638929
#   Num changes:         1
#   Design Depth:        544
#   Design Size (|D|):   1188
#   Open set size:       14610
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       67201.992
#   Best Cost (y):       8530.4873
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      67201.992
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9368→ cube 2.2217
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9105→ cube 1.0436
#   Efficiency z (srs):  8.121 → 0.289 → 38.1222
#   Efficiency y (srs):  5.754 → 0.586 → 10.4104
#   Alpha:               0.7283392491480842
#   Num changes:         1
#   Design Depth:        558
#   Design Size (|D|):   1216
#   Open set size:       14891
#
# Progress: 10.4%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       66466.718
#   Best Cost (y):       8518.6587
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      66466.718
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9472→ cube 2.2463
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9118→ cube 1.045
#   Efficiency z (srs):  8.121 → 0.289 → 38.5439
#   Efficiency y (srs):  5.754 → 0.586 → 10.4248
#   Alpha:               0.7943007125817355
#   Num changes:         1
#   Design Depth:        573
#   Design Size (|D|):   1246
#   Open set size:       15191
#
# Progress: 10.6%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       66450.75
#   Best Cost (y):       8490.4938
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      66450.75
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9474→ cube 2.2468
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9148→ cube 1.0485
#   Efficiency z (srs):  8.121 → 0.289 → 38.5531
#   Efficiency y (srs):  5.754 → 0.586 → 10.4594
#   Alpha:               0.8614051213496834
#   Num changes:         3
#   Design Depth:        578
#   Design Size (|D|):   1256
#   Open set size:       15493
#
# Progress: 10.8%
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       66297.732
#   Best Cost (y):       8483.186
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      66297.732
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9496→ cube 2.252
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9156→ cube 1.0494
#   Efficiency z (srs):  8.121 → 0.289 → 38.6421
#   Efficiency y (srs):  5.754 → 0.586 → 10.4684
#   Alpha:               0.7586547238127562
#   Num changes:         2
#   Design Depth:        584
#   Design Size (|D|):   1268
#   Open set size:       15766
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       65136.877
#   Best Cost (y):       8408.8015
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      65136.877
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9665→ cube 2.2921
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9237→ cube 1.0587
#   Efficiency z (srs):  8.121 → 0.289 → 39.3308
#   Efficiency y (srs):  5.754 → 0.586 → 10.561
#   Alpha:               0.7959963399893583
#   Num changes:         1
#   Design Depth:        599
#   Design Size (|D|):   1298
#   Open set size:       16055
#
# Progress: 11.2%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       64184.212
#   Best Cost (y):       8557.5769
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      64184.212
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9809→ cube 2.3261
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9076→ cube 1.0403
#   Efficiency z (srs):  8.121 → 0.289 → 39.9146
#   Efficiency y (srs):  5.754 → 0.586 → 10.3774
#   Alpha:               0.7068717397275244
#   Num changes:         1
#   Design Depth:        614
#   Design Size (|D|):   1328
#   Open set size:       16346
#
# Progress: 11.6%
# === Best Solution Updated at Iteration 580 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       63988.902
#   Best Cost (y):       8629.1177
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      63988.902
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 0.9838→ cube 2.3332
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9001→ cube 1.0317
#   Efficiency z (srs):  8.121 → 0.289 → 40.0364
#   Efficiency y (srs):  5.754 → 0.586 → 10.2914
#   Alpha:               0.864895430108782
#   Num changes:         1
#   Design Depth:        632
#   Design Size (|D|):   1364
#   Open set size:       16930
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       62608.741
#   Best Cost (y):       8591.488
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      62608.741
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0055→ cube 2.3847
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.904→ cube 1.0362
#   Efficiency z (srs):  8.121 → 0.289 → 40.919
#   Efficiency y (srs):  5.754 → 0.586 → 10.3365
#   Alpha:               0.8495740458894911
#   Num changes:         1
#   Design Depth:        660
#   Design Size (|D|):   1420
#   Open set size:       17512
#
# Progress: 12.6%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       59909.214
#   Best Cost (y):       8289.1988
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      59909.214
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0508→ cube 2.4921
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.937→ cube 1.074
#   Efficiency z (srs):  8.121 → 0.289 → 42.7628
#   Efficiency y (srs):  5.754 → 0.586 → 10.7134
#   Alpha:               0.7279429871669518
#   Num changes:         1
#   Design Depth:        712
#   Design Size (|D|):   1524
#   Open set size:       18373
#
#
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       59903.983
#   Best Cost (y):       8284.3767
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      59903.983
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0509→ cube 2.4923
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9376→ cube 1.0746
#   Efficiency z (srs):  8.121 → 0.289 → 42.7665
#   Efficiency y (srs):  5.754 → 0.586 → 10.7196
#   Alpha:               0.7679561773029232
#   Num changes:         2
#   Design Depth:        713
#   Design Size (|D|):   1526
#   Open set size:       18375
#
#
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       59854.219
#   Best Cost (y):       8310.5653
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      59854.219
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0518→ cube 2.4944
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9346→ cube 1.0712
#   Efficiency z (srs):  8.121 → 0.289 → 42.8021
#   Efficiency y (srs):  5.754 → 0.586 → 10.6859
#   Alpha:               0.8421995208245197
#   Num changes:         3
#   Design Depth:        714
#   Design Size (|D|):   1528
#   Open set size:       18382
#
#
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       59781.262
#   Best Cost (y):       8288.9152
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      59781.262
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0531→ cube 2.4975
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.937→ cube 1.074
#   Efficiency z (srs):  8.121 → 0.289 → 42.8543
#   Efficiency y (srs):  5.754 → 0.586 → 10.7138
#   Alpha:               0.8753986570449831
#   Num changes:         2
#   Design Depth:        713
#   Design Size (|D|):   1526
#   Open set size:       18393
#
# Progress: 12.8%
# === Best Solution Updated at Iteration 640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       58876.244
#   Best Cost (y):       8261.5011
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      58876.244
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0693→ cube 2.5359
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9402→ cube 1.0776
#   Efficiency z (srs):  8.121 → 0.289 → 43.5131
#   Efficiency y (srs):  5.754 → 0.586 → 10.7493
#   Alpha:               0.7748050089702633
#   Num changes:         2
#   Design Depth:        731
#   Design Size (|D|):   1562
#   Open set size:       18664
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       58604.09
#   Best Cost (y):       8306.3411
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      58604.09
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0742→ cube 2.5476
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9351→ cube 1.0718
#   Efficiency z (srs):  8.121 → 0.289 → 43.7151
#   Efficiency y (srs):  5.754 → 0.586 → 10.6913
#   Alpha:               0.7523304459200416
#   Num changes:         1
#   Design Depth:        744
#   Design Size (|D|):   1588
#   Open set size:       18977
#
# Progress: 13.8%
# === Best Solution Updated at Iteration 690 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       57868.857
#   Best Cost (y):       8354.1963
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      57868.857
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0879→ cube 2.58
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9297→ cube 1.0656
#   Efficiency z (srs):  8.121 → 0.289 → 44.2705
#   Efficiency y (srs):  5.754 → 0.586 → 10.63
#   Alpha:               0.7779101173371591
#   Num changes:         2
#   Design Depth:        785
#   Design Size (|D|):   1670
#   Open set size:       20118
#
#
# === Best Solution Updated at Iteration 690 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       57854.585
#   Best Cost (y):       8339.6069
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      57854.585
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0882→ cube 2.5806
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9314→ cube 1.0675
#   Efficiency z (srs):  8.121 → 0.289 → 44.2815
#   Efficiency y (srs):  5.754 → 0.586 → 10.6486
#   Alpha:               0.7215909698828677
#   Num changes:         2
#   Design Depth:        785
#   Design Size (|D|):   1670
#   Open set size:       20132
#
# Progress: 14.2%
# === Best Solution Updated at Iteration 710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       57610.49
#   Best Cost (y):       8280.954
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      57610.49
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0928→ cube 2.5916
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.9379→ cube 1.075
#   Efficiency z (srs):  8.121 → 0.289 → 44.4691
#   Efficiency y (srs):  5.754 → 0.586 → 10.7241
#   Alpha:               0.8429270785729068
#   Num changes:         1
#   Design Depth:        804
#   Design Size (|D|):   1708
#   Open set size:       20691
#
#
# === Best Solution Updated at Iteration 710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       57595.104
#   Best Cost (y):       8289.3216
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      57595.104
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.0931→ cube 2.5923
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 0.937→ cube 1.074
#   Efficiency z (srs):  8.121 → 0.289 → 44.481
#   Efficiency y (srs):  5.754 → 0.586 → 10.7132
#   Alpha:               0.859311992963375
#   Num changes:         1
#   Design Depth:        804
#   Design Size (|D|):   1708
#   Open set size:       20712
#
# Progress: 14.4%
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       57350.305
#   Best Cost (y):       8208.8885
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
# ...
#   Num changes:         1
#   Design Depth:        2901
#   Design Size (|D|):   5902
#   Open set size:       89139
#
# Progress: 62.2%
# === Best Solution Updated at Iteration 3110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37901.585
#   Best Cost (y):       7255.5871
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37901.585
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.661→ cube 3.9392
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0705→ cube 1.227
#   Efficiency z (srs):  8.121 → 0.289 → 67.5931
#   Efficiency y (srs):  5.754 → 0.586 → 12.2396
#   Alpha:               0.8966855492962454
#   Num changes:         1
#   Design Depth:        2938
#   Design Size (|D|):   5976
#   Open set size:       90305
#
# Progress: 62.6%
# === Best Solution Updated at Iteration 3130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37842.002
#   Best Cost (y):       7264.28
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37842.002
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6636→ cube 3.9454
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0692→ cube 1.2255
#   Efficiency z (srs):  8.121 → 0.289 → 67.6995
#   Efficiency y (srs):  5.754 → 0.586 → 12.225
#   Alpha:               0.7163417656800418
#   Num changes:         1
#   Design Depth:        2956
#   Design Size (|D|):   6012
#   Open set size:       90895
#
# Progress: 62.8%
# === Best Solution Updated at Iteration 3140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37723.659
#   Best Cost (y):       7256.0815
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37723.659
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6689→ cube 3.9578
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0704→ cube 1.2269
#   Efficiency z (srs):  8.121 → 0.289 → 67.9119
#   Efficiency y (srs):  5.754 → 0.586 → 12.2388
#   Alpha:               0.7796251538780691
#   Num changes:         2
#   Design Depth:        2969
#   Design Size (|D|):   6038
#   Open set size:       91164
#
# Progress: 63.0%
# === Best Solution Updated at Iteration 3150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37698.56
#   Best Cost (y):       7257.5859
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37698.56
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.67→ cube 3.9604
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0702→ cube 1.2266
#   Efficiency z (srs):  8.121 → 0.289 → 67.9571
#   Efficiency y (srs):  5.754 → 0.586 → 12.2362
#   Alpha:               0.8954881636153256
#   Num changes:         2
#   Design Depth:        2980
#   Design Size (|D|):   6060
#   Open set size:       91466
#
# Progress: 64.4%
# === Best Solution Updated at Iteration 3220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37610.05
#   Best Cost (y):       7245.0142
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37610.05
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6739→ cube 3.9697
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0721→ cube 1.2288
#   Efficiency z (srs):  8.121 → 0.289 → 68.117
#   Efficiency y (srs):  5.754 → 0.586 → 12.2575
#   Alpha:               0.7794614814103884
#   Num changes:         1
#   Design Depth:        3015
#   Design Size (|D|):   6130
#   Open set size:       93482
#
#
# === Best Solution Updated at Iteration 3220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37586.393
#   Best Cost (y):       7243.9569
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37586.393
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6749→ cube 3.9722
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0722→ cube 1.2289
#   Efficiency z (srs):  8.121 → 0.289 → 68.1599
#   Efficiency y (srs):  5.754 → 0.586 → 12.2593
#   Alpha:               0.7898285015287068
#   Num changes:         2
#   Design Depth:        3016
#   Design Size (|D|):   6132
#   Open set size:       93502
#
# Progress: 64.6%
# === Best Solution Updated at Iteration 3230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37465.604
#   Best Cost (y):       7252.5533
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37465.604
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6803→ cube 3.985
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0709→ cube 1.2275
#   Efficiency z (srs):  8.121 → 0.289 → 68.3797
#   Efficiency y (srs):  5.754 → 0.586 → 12.2447
#   Alpha:               0.7443819764944454
#   Num changes:         1
#   Design Depth:        3028
#   Design Size (|D|):   6156
#   Open set size:       93778
#
#
# === Best Solution Updated at Iteration 3230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37456.838
#   Best Cost (y):       7251.7038
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37456.838
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6807→ cube 3.986
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0711→ cube 1.2276
#   Efficiency z (srs):  8.121 → 0.289 → 68.3957
#   Efficiency y (srs):  5.754 → 0.586 → 12.2462
#   Alpha:               0.8232030189816166
#   Num changes:         1
#   Design Depth:        3028
#   Design Size (|D|):   6156
#   Open set size:       93799
#
# Progress: 65.0%
# === Best Solution Updated at Iteration 3250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37329.026
#   Best Cost (y):       7240.6616
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37329.026
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6865→ cube 3.9996
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0727→ cube 1.2295
#   Efficiency z (srs):  8.121 → 0.289 → 68.6298
#   Efficiency y (srs):  5.754 → 0.586 → 12.2648
#   Alpha:               0.8618945478961073
#   Num changes:         1
#   Design Depth:        3048
#   Design Size (|D|):   6196
#   Open set size:       94377
#
# Progress: 65.6%
# === Best Solution Updated at Iteration 3280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37266.289
#   Best Cost (y):       7227.0802
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37266.289
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6893→ cube 4.0063
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0747→ cube 1.2318
#   Efficiency z (srs):  8.121 → 0.289 → 68.7454
#   Efficiency y (srs):  5.754 → 0.586 → 12.2879
#   Alpha:               0.7992311125150173
#   Num changes:         3
#   Design Depth:        3079
#   Design Size (|D|):   6258
#   Open set size:       95236
#
# Progress: 65.8%
# === Best Solution Updated at Iteration 3290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37254.468
#   Best Cost (y):       7224.4566
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37254.468
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6899→ cube 4.0076
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0751→ cube 1.2323
#   Efficiency z (srs):  8.121 → 0.289 → 68.7672
#   Efficiency y (srs):  5.754 → 0.586 → 12.2923
#   Alpha:               0.7577653077125389
#   Num changes:         3
#   Design Depth:        3088
#   Design Size (|D|):   6276
#   Open set size:       95533
#
# Progress: 68.2%
# === Best Solution Updated at Iteration 3410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37185.831
#   Best Cost (y):       7243.9881
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37185.831
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.693→ cube 4.015
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0722→ cube 1.2289
#   Efficiency z (srs):  8.121 → 0.289 → 68.8941
#   Efficiency y (srs):  5.754 → 0.586 → 12.2592
#   Alpha:               0.7669048562104378
#   Num changes:         2
#   Design Depth:        3130
#   Design Size (|D|):   6360
#   Open set size:       99001
#
# Progress: 69.0%
# === Best Solution Updated at Iteration 3450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37066.534
#   Best Cost (y):       7226.2108
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37066.534
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6984→ cube 4.0279
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0749→ cube 1.232
#   Efficiency z (srs):  8.121 → 0.289 → 69.1159
#   Efficiency y (srs):  5.754 → 0.586 → 12.2894
#   Alpha:               0.885091220212828
#   Num changes:         1
#   Design Depth:        3159
#   Design Size (|D|):   6418
#   Open set size:       100175
#
#
# === Best Solution Updated at Iteration 3450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37065.033
#   Best Cost (y):       7228.2742
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      37065.033
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.6985→ cube 4.0281
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0745→ cube 1.2316
#   Efficiency z (srs):  8.121 → 0.289 → 69.1187
#   Efficiency y (srs):  5.754 → 0.586 → 12.2859
#   Alpha:               0.8477443630668373
#   Num changes:         1
#   Design Depth:        3159
#   Design Size (|D|):   6418
#   Open set size:       100176
#
# Progress: 70.2%
# === Best Solution Updated at Iteration 3510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       36964.224
#   Best Cost (y):       7218.3592
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      36964.224
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.7031→ cube 4.0391
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.076→ cube 1.2333
#   Efficiency z (srs):  8.121 → 0.289 → 69.3072
#   Efficiency y (srs):  5.754 → 0.586 → 12.3027
#   Alpha:               0.7680763310104604
#   Num changes:         1
#   Design Depth:        3209
#   Design Size (|D|):   6518
#   Open set size:       101892
#
# Progress: 72.0%
# === Best Solution Updated at Iteration 3600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       36833.934
#   Best Cost (y):       7219.1982
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      36833.934
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.7092→ cube 4.0534
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0759→ cube 1.2332
#   Efficiency z (srs):  8.121 → 0.289 → 69.5523
#   Efficiency y (srs):  5.754 → 0.586 → 12.3013
#   Alpha:               0.7917222075444448
#   Num changes:         1
#   Design Depth:        3257
#   Design Size (|D|):   6614
#   Open set size:       104512
#
# Progress: 73.4%
# === Best Solution Updated at Iteration 3670 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       36708.796
#   Best Cost (y):       7223.8067
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      36708.796
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.715→ cube 4.0672
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0752→ cube 1.2324
#   Efficiency z (srs):  8.121 → 0.289 → 69.7894
#   Efficiency y (srs):  5.754 → 0.586 → 12.2934
#   Alpha:               0.8404631438070682
#   Num changes:         2
#   Design Depth:        3315
#   Design Size (|D|):   6730
#   Open set size:       106546
#
# Progress: 73.6%
# === Best Solution Updated at Iteration 3680 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       36620.538
#   Best Cost (y):       7217.2203
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.902
#   rho (p, y):          0.88
#   Criteria Value:      36620.538
#   Efficiency z (0→f):  0.2 → 0.289 → dsd 1.7191→ cube 4.077
#   Efficiency y (0→f):  0.503 → 0.586 → dsd 1.0762→ cube 1.2335
#   Efficiency z (srs):  8.121 → 0.289 → 69.9576
#   Efficiency y (srs):  5.754 → 0.586 → 12.3047
#   Alpha:               0.8966299592789134
#   Num changes:         1
#   Design Depth:        3330
#   Design Size (|D|):   6760
#   Open set size:       106834
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 48
#      22 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      23                    inclusion_probability=inclusions, balance_method=bardia_balance_method)
#      25 astar = AStar(
#      26     inclusions              = inclusions,
#      27     num_initial_nodes       = num_initial_nodes,
#    (...)     45     rng                     = rng,
#      46 )
# ---> 48 result = astar.run(
#      49     max_iterations             = max_iterations,
#      50     num_new_nodes              = num_new_nodes,
#      51     max_open_set_size          = max_open_set_size,
#      52     random_restart_period      = random_restart_period,
#      53     random_injection_count     = random_injection_count,
#      54     prune_fraction             = prune_fraction,
#      55     num_top_restart_nodes      = num_top_restart_nodes,
#      56     stuck_fraction             = stuck_fraction,
#      57
#      58 )
#      60 print("Best criteria value:", astar.best_criteria_value)
#      61 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:20, in VarNHT.__call__(self, design)
#      12 ones = np.ones(N)
#      13 NHT_estimator_z = np.array([
#      14     np.sum(self.auxiliary_variable[list(sample.ids)] /
#      15            self.inclusion_probability[list(sample.ids)])
#      16     for sample in design
#      17 ])
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
# ---> 20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
#      29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#
# KeyboardInterrupt:

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
# Out:
# size of init design 100
# size of best design 6760
# 217545.6805640883
# 36620.537778885
# [100]
# /tmp/ipykernel_280748/683604881.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# sum of inclusions, last ini and original 9.999999969999994 9.999999970000001 10.000000000000004
# 0.9999999970000023
# n =  [10]
# 10043.617183059718 50171.044381539425 10043.617152912433 50171.044230787724
# 10043.617183059718 50171.044381539425 10043.617152912433 50171.044230787724
# var z estimates 36628.089
# var y estimates 7217.523
