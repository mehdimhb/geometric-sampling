# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_8.5_py_8.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_7_py_7_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.7 0.9
# Generating initial designs:   0%|                      | 0/3000 [00:00<?, ?it/s]
# Initial design 0: method = Original, efficiency z = 0.2145, y=0.3669
# New best at idx=0: method = Original, efficiency z = 0.2145 and efficiency y = 0.3669
# New best at idx=2: method = z/pi, efficiency z = 0.2145 and efficiency y = 0.3669
# New best at idx=4: method = swap, efficiency z = 0.2147 and efficiency y = 0.4066
# Generating initial designs:   0%|              | 6/3000 [00:00<00:59, 50.48it/s]
# New best at idx=6: method = swap, efficiency z = 0.2274 and efficiency y = 0.3923
# New best at idx=8: method = swap, efficiency z = 0.2435 and efficiency y = 0.6179
# Generating initial designs:   2%|▏            | 49/3000 [00:01<00:58, 50.54it/s]
# New best at idx=42: method = swap, efficiency z = 0.2615 and efficiency y = 0.3786
# Generating initial designs:   7%|▊           | 203/3000 [00:03<00:40, 69.37it/s]
# New best at idx=189: method = swap, efficiency z = 0.2636 and efficiency y = 0.4145
# Generating initial designs:  18%|██          | 530/3000 [00:09<00:44, 55.07it/s]
# New best at idx=520: method = swap, efficiency z = 0.2680 and efficiency y = 0.5043
# Generating initial designs:  24%|██▉         | 724/3000 [00:11<00:29, 75.90it/s]
# New best at idx=708: method = swap, efficiency z = 0.2729 and efficiency y = 0.4145
# Generating initial designs:  69%|███████▌   | 2077/3000 [00:31<00:12, 74.79it/s]
# New best at idx=2059: method = swap, efficiency z = 0.2741 and efficiency y = 0.5071
# Generating initial designs: 100%|███████████| 3000/3000 [00:44<00:00, 66.67it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       765904.025
#   Best Cost (y):       62744.6366
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      765904.025
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.2743→ cube 0.7112
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.5058→ cube 0.5133
#   Efficiency z (srs):  3.526 → 0.274 → 4.5087
#   Efficiency y (srs):  0.771 → 0.507 → 1.0628
#   Alpha:               0.7771396447883352
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       109
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       677370.735
#   Best Cost (y):       61995.1704
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      677370.735
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.3101→ cube 0.8041
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.5119→ cube 0.5195
#   Efficiency z (srs):  3.526 → 0.274 → 5.0979
#   Efficiency y (srs):  0.771 → 0.507 → 1.0756
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        5
#   Design Size (|D|):   110
#   Open set size:       158
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       593145.139
#   Best Cost (y):       55200.4824
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      593145.139
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.3542→ cube 0.9183
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.5749→ cube 0.5834
#   Efficiency z (srs):  3.526 → 0.274 → 5.8218
#   Efficiency y (srs):  0.771 → 0.507 → 1.208
#   Alpha:               0.8936549529233633
#   Num changes:         1
#   Design Depth:        21
#   Design Size (|D|):   142
#   Open set size:       390
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       587963.587
#   Best Cost (y):       56959.5125
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      587963.587
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.3573→ cube 0.9264
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.5572→ cube 0.5654
#   Efficiency z (srs):  3.526 → 0.274 → 5.8731
#   Efficiency y (srs):  0.771 → 0.507 → 1.1707
#   Alpha:               0.7986076528846952
#   Num changes:         2
#   Design Depth:        22
#   Design Size (|D|):   144
#   Open set size:       391
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       586567.349
#   Best Cost (y):       58793.5654
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      586567.349
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.3581→ cube 0.9286
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.5398→ cube 0.5478
#   Efficiency z (srs):  3.526 → 0.274 → 5.8871
#   Efficiency y (srs):  0.771 → 0.507 → 1.1342
#   Alpha:               0.8453833637573513
#   Num changes:         2
#   Design Depth:        22
#   Design Size (|D|):   144
#   Open set size:       393
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       582954.535
#   Best Cost (y):       57072.4712
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      582954.535
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.3604→ cube 0.9344
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.5561→ cube 0.5643
#   Efficiency z (srs):  3.526 → 0.274 → 5.9236
#   Efficiency y (srs):  0.771 → 0.507 → 1.1684
#   Alpha:               0.7121294270559273
#   Num changes:         3
#   Design Depth:        23
#   Design Size (|D|):   146
#   Open set size:       408
#
# Progress: 0.6%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       474371.836
#   Best Cost (y):       49607.8289
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      474371.836
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.4428→ cube 1.1482
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6398→ cube 0.6492
#   Efficiency z (srs):  3.526 → 0.274 → 7.2795
#   Efficiency y (srs):  0.771 → 0.507 → 1.3442
#   Alpha:               0.7352670041445117
#   Num changes:         3
#   Design Depth:        57
#   Design Size (|D|):   214
#   Open set size:       993
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       448432.323
#   Best Cost (y):       50862.9837
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      448432.323
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.4685→ cube 1.2147
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.624→ cube 0.6332
#   Efficiency z (srs):  3.526 → 0.274 → 7.7006
#   Efficiency y (srs):  0.771 → 0.507 → 1.311
#   Alpha:               0.8503681154967497
#   Num changes:         1
#   Design Depth:        86
#   Design Size (|D|):   272
#   Open set size:       1567
#
# Progress: 1.4%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       428905.525
#   Best Cost (y):       49963.6709
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      428905.525
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.4898→ cube 1.27
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6352→ cube 0.6446
#   Efficiency z (srs):  3.526 → 0.274 → 8.0512
#   Efficiency y (srs):  0.771 → 0.507 → 1.3346
#   Alpha:               0.8417373389226311
#   Num changes:         3
#   Design Depth:        108
#   Design Size (|D|):   316
#   Open set size:       2137
#
# Progress: 1.6%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       426235.792
#   Best Cost (y):       49728.1007
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      426235.792
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.4928→ cube 1.2779
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6382→ cube 0.6476
#   Efficiency z (srs):  3.526 → 0.274 → 8.1016
#   Efficiency y (srs):  0.771 → 0.507 → 1.341
#   Alpha:               0.7557416945946522
#   Num changes:         2
#   Design Depth:        113
#   Design Size (|D|):   326
#   Open set size:       2438
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       426163.789
#   Best Cost (y):       49716.339
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      426163.789
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.4929→ cube 1.2781
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6384→ cube 0.6478
#   Efficiency z (srs):  3.526 → 0.274 → 8.103
#   Efficiency y (srs):  0.771 → 0.507 → 1.3413
#   Alpha:               0.8242029119009214
#   Num changes:         1
#   Design Depth:        113
#   Design Size (|D|):   326
#   Open set size:       2739
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       422597.553
#   Best Cost (y):       48742.4565
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      422597.553
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.4971→ cube 1.2889
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6511→ cube 0.6607
#   Efficiency z (srs):  3.526 → 0.274 → 8.1714
#   Efficiency y (srs):  0.771 → 0.507 → 1.3681
#   Alpha:               0.762410920099234
#   Num changes:         2
#   Design Depth:        128
#   Design Size (|D|):   356
#   Open set size:       3015
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       391340.81
#   Best Cost (y):       48533.6401
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      391340.81
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.5368→ cube 1.3919
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6539→ cube 0.6636
#   Efficiency z (srs):  3.526 → 0.274 → 8.824
#   Efficiency y (srs):  0.771 → 0.507 → 1.374
#   Alpha:               0.8937274497678358
#   Num changes:         2
#   Design Depth:        149
#   Design Size (|D|):   398
#   Open set size:       3292
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       389685.134
#   Best Cost (y):       49103.4728
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      389685.134
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.5391→ cube 1.3978
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6463→ cube 0.6559
#   Efficiency z (srs):  3.526 → 0.274 → 8.8615
#   Efficiency y (srs):  0.771 → 0.507 → 1.358
#   Alpha:               0.81643004750745
#   Num changes:         3
#   Design Depth:        150
#   Design Size (|D|):   400
#   Open set size:       3317
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       366510.323
#   Best Cost (y):       48698.8318
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      366510.323
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.5732→ cube 1.4862
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6517→ cube 0.6613
#   Efficiency z (srs):  3.526 → 0.274 → 9.4218
#   Efficiency y (srs):  0.771 → 0.507 → 1.3693
#   Alpha:               0.7613184785976346
#   Num changes:         1
#   Design Depth:        191
#   Design Size (|D|):   482
#   Open set size:       4170
#
# Progress: 3.4%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       348241.589
#   Best Cost (y):       46907.174
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      348241.589
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6032→ cube 1.5641
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6766→ cube 0.6866
#   Efficiency z (srs):  3.526 → 0.274 → 9.9161
#   Efficiency y (srs):  0.771 → 0.507 → 1.4216
#   Alpha:               0.8565386589823005
#   Num changes:         1
#   Design Depth:        228
#   Design Size (|D|):   556
#   Open set size:       5038
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       340847.643
#   Best Cost (y):       45491.2016
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      340847.643
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6163→ cube 1.5981
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.6976→ cube 0.708
#   Efficiency z (srs):  3.526 → 0.274 → 10.1312
#   Efficiency y (srs):  0.771 → 0.507 → 1.4659
#   Alpha:               0.7783182703051732
#   Num changes:         3
#   Design Depth:        261
#   Design Size (|D|):   622
#   Open set size:       5901
#
# Progress: 4.4%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       330570.302
#   Best Cost (y):       45019.4257
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      330570.302
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6355→ cube 1.6477
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.705→ cube 0.7154
#   Efficiency z (srs):  3.526 → 0.274 → 10.4462
#   Efficiency y (srs):  0.771 → 0.507 → 1.4812
#   Alpha:               0.8188321520038994
#   Num changes:         2
#   Design Depth:        286
#   Design Size (|D|):   672
#   Open set size:       6482
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       330113.352
#   Best Cost (y):       44743.3015
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      330113.352
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6364→ cube 1.65
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7093→ cube 0.7198
#   Efficiency z (srs):  3.526 → 0.274 → 10.4606
#   Efficiency y (srs):  0.771 → 0.507 → 1.4904
#   Alpha:               0.8671937228453047
#   Num changes:         1
#   Design Depth:        285
#   Design Size (|D|):   670
#   Open set size:       6484
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       328334.929
#   Best Cost (y):       44971.1331
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      328334.929
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6398→ cube 1.659
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7057→ cube 0.7161
#   Efficiency z (srs):  3.526 → 0.274 → 10.5173
#   Efficiency y (srs):  0.771 → 0.507 → 1.4828
#   Alpha:               0.8838148370974387
#   Num changes:         3
#   Design Depth:        287
#   Design Size (|D|):   674
#   Open set size:       6485
#
# Progress: 4.6%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       320207.696
#   Best Cost (y):       44272.5002
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      320207.696
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.656→ cube 1.7011
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7168→ cube 0.7274
#   Efficiency z (srs):  3.526 → 0.274 → 10.7842
#   Efficiency y (srs):  0.771 → 0.507 → 1.5062
#   Alpha:               0.7895545035531287
#   Num changes:         1
#   Design Depth:        303
#   Design Size (|D|):   706
#   Open set size:       6773
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       308317.018
#   Best Cost (y):       43092.2274
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      308317.018
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6813→ cube 1.7667
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7365→ cube 0.7474
#   Efficiency z (srs):  3.526 → 0.274 → 11.2002
#   Efficiency y (srs):  0.771 → 0.507 → 1.5475
#   Alpha:               0.8978211456486399
#   Num changes:         1
#   Design Depth:        345
#   Design Size (|D|):   790
#   Open set size:       7650
#
#
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       307814.187
#   Best Cost (y):       43141.3634
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      307814.187
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6825→ cube 1.7695
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7356→ cube 0.7465
#   Efficiency z (srs):  3.526 → 0.274 → 11.2185
#   Efficiency y (srs):  0.771 → 0.507 → 1.5457
#   Alpha:               0.8954080864821592
#   Num changes:         2
#   Design Depth:        346
#   Design Size (|D|):   792
#   Open set size:       7666
#
# Progress: 5.6%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       302134.712
#   Best Cost (y):       43222.8783
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      302134.712
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.6953→ cube 1.8028
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7343→ cube 0.7451
#   Efficiency z (srs):  3.526 → 0.274 → 11.4293
#   Efficiency y (srs):  0.771 → 0.507 → 1.5428
#   Alpha:               0.7572571102992227
#   Num changes:         3
#   Design Depth:        375
#   Design Size (|D|):   850
#   Open set size:       8223
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       294181.712
#   Best Cost (y):       43210.8682
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      294181.712
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7141→ cube 1.8516
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7345→ cube 0.7453
#   Efficiency z (srs):  3.526 → 0.274 → 11.7383
#   Efficiency y (srs):  0.771 → 0.507 → 1.5432
#   Alpha:               0.8483108017812679
#   Num changes:         2
#   Design Depth:        408
#   Design Size (|D|):   916
#   Open set size:       8829
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       293436.566
#   Best Cost (y):       43258.429
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      293436.566
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7159→ cube 1.8563
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7337→ cube 0.7445
#   Efficiency z (srs):  3.526 → 0.274 → 11.7681
#   Efficiency y (srs):  0.771 → 0.507 → 1.5415
#   Alpha:               0.7232833468096903
#   Num changes:         3
#   Design Depth:        425
#   Design Size (|D|):   950
#   Open set size:       9092
#
# Progress: 6.4%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       291006.204
#   Best Cost (y):       43132.0551
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      291006.204
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7219→ cube 1.8718
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7358→ cube 0.7467
#   Efficiency z (srs):  3.526 → 0.274 → 11.8664
#   Efficiency y (srs):  0.771 → 0.507 → 1.546
#   Alpha:               0.8326583840599424
#   Num changes:         1
#   Design Depth:        443
#   Design Size (|D|):   986
#   Open set size:       9399
#
# Progress: 6.6%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       284956.093
#   Best Cost (y):       42219.8303
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      284956.093
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7372→ cube 1.9115
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7517→ cube 0.7628
#   Efficiency z (srs):  3.526 → 0.274 → 12.1184
#   Efficiency y (srs):  0.771 → 0.507 → 1.5794
#   Alpha:               0.7983907577317458
#   Num changes:         1
#   Design Depth:        463
#   Design Size (|D|):   1026
#   Open set size:       9675
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       284938.909
#   Best Cost (y):       42317.0161
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      284938.909
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7372→ cube 1.9116
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.75→ cube 0.7611
#   Efficiency z (srs):  3.526 → 0.274 → 12.1191
#   Efficiency y (srs):  0.771 → 0.507 → 1.5758
#   Alpha:               0.8169171969959643
#   Num changes:         1
#   Design Depth:        463
#   Design Size (|D|):   1026
#   Open set size:       9685
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       282488.198
#   Best Cost (y):       42201.0136
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      282488.198
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7436→ cube 1.9282
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.752→ cube 0.7631
#   Efficiency z (srs):  3.526 → 0.274 → 12.2242
#   Efficiency y (srs):  0.771 → 0.507 → 1.5801
#   Alpha:               0.8609724241695466
#   Num changes:         1
#   Design Depth:        474
#   Design Size (|D|):   1048
#   Open set size:       9964
#
#
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       282004.085
#   Best Cost (y):       42192.216
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      282004.085
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7449→ cube 1.9315
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7522→ cube 0.7633
#   Efficiency z (srs):  3.526 → 0.274 → 12.2452
#   Efficiency y (srs):  0.771 → 0.507 → 1.5805
#   Alpha:               0.7630669290718901
#   Num changes:         1
#   Design Depth:        474
#   Design Size (|D|):   1048
#   Open set size:       9974
#
#
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       281676.09
#   Best Cost (y):       42205.3472
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      281676.09
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7458→ cube 1.9338
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.752→ cube 0.7631
#   Efficiency z (srs):  3.526 → 0.274 → 12.2595
#   Efficiency y (srs):  0.771 → 0.507 → 1.58
#   Alpha:               0.7782806810736442
#   Num changes:         2
#   Design Depth:        475
#   Design Size (|D|):   1050
#   Open set size:       9985
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       281216.33
#   Best Cost (y):       41969.1876
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      281216.33
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.747→ cube 1.9369
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7562→ cube 0.7674
#   Efficiency z (srs):  3.526 → 0.274 → 12.2795
#   Efficiency y (srs):  0.771 → 0.507 → 1.5889
#   Alpha:               0.8538268590188218
#   Num changes:         1
#   Design Depth:        486
#   Design Size (|D|):   1072
#   Open set size:       10278
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       280522.92
#   Best Cost (y):       41675.1003
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      280522.92
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7489→ cube 1.9417
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7615→ cube 0.7728
#   Efficiency z (srs):  3.526 → 0.274 → 12.3099
#   Efficiency y (srs):  0.771 → 0.507 → 1.6001
#   Alpha:               0.7888176779070188
#   Num changes:         1
#   Design Depth:        493
#   Design Size (|D|):   1086
#   Open set size:       10559
#
# Progress: 7.4%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       275979.724
#   Best Cost (y):       41059.5745
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      275979.724
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7612→ cube 1.9737
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7729→ cube 0.7844
#   Efficiency z (srs):  3.526 → 0.274 → 12.5125
#   Efficiency y (srs):  0.771 → 0.507 → 1.6241
#   Alpha:               0.8707933091564011
#   Num changes:         2
#   Design Depth:        510
#   Design Size (|D|):   1120
#   Open set size:       10830
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       266121.525
#   Best Cost (y):       40509.0208
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      266121.525
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7894→ cube 2.0468
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7834→ cube 0.795
#   Efficiency z (srs):  3.526 → 0.274 → 12.976
#   Efficiency y (srs):  0.771 → 0.507 → 1.6461
#   Alpha:               0.745080935491702
#   Num changes:         1
#   Design Depth:        564
#   Design Size (|D|):   1228
#   Open set size:       11996
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       265522.865
#   Best Cost (y):       40470.2438
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      265522.865
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7912→ cube 2.0514
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7842→ cube 0.7958
#   Efficiency z (srs):  3.526 → 0.274 → 13.0053
#   Efficiency y (srs):  0.771 → 0.507 → 1.6477
#   Alpha:               0.8807329489700998
#   Num changes:         3
#   Design Depth:        566
#   Design Size (|D|):   1232
#   Open set size:       11997
#
#
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       265283.005
#   Best Cost (y):       40427.9611
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      265283.005
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7919→ cube 2.0532
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.785→ cube 0.7966
#   Efficiency z (srs):  3.526 → 0.274 → 13.017
#   Efficiency y (srs):  0.771 → 0.507 → 1.6494
#   Alpha:               0.8182632206864422
#   Num changes:         3
#   Design Depth:        566
#   Design Size (|D|):   1232
#   Open set size:       12003
#
# Progress: 8.4%
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       263770.646
#   Best Cost (y):       40342.1277
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      263770.646
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.7964→ cube 2.065
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7867→ cube 0.7983
#   Efficiency z (srs):  3.526 → 0.274 → 13.0917
#   Efficiency y (srs):  0.771 → 0.507 → 1.6529
#   Alpha:               0.8301324234984481
#   Num changes:         1
#   Design Depth:        581
#   Design Size (|D|):   1262
#   Open set size:       12280
#
# Progress: 8.6%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       261443.763
#   Best Cost (y):       40661.6099
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      261443.763
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8035→ cube 2.0834
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7805→ cube 0.792
#   Efficiency z (srs):  3.526 → 0.274 → 13.2082
#   Efficiency y (srs):  0.771 → 0.507 → 1.64
#   Alpha:               0.7532878532630853
#   Num changes:         1
#   Design Depth:        597
#   Design Size (|D|):   1294
#   Open set size:       12573
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       261284.448
#   Best Cost (y):       40675.8454
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      261284.448
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.804→ cube 2.0847
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7802→ cube 0.7918
#   Efficiency z (srs):  3.526 → 0.274 → 13.2162
#   Efficiency y (srs):  0.771 → 0.507 → 1.6394
#   Alpha:               0.8075250936793597
#   Num changes:         3
#   Design Depth:        599
#   Design Size (|D|):   1298
#   Open set size:       12594
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       256900.805
#   Best Cost (y):       40314.2968
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      256900.805
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8177→ cube 2.1202
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7872→ cube 0.7989
#   Efficiency z (srs):  3.526 → 0.274 → 13.4418
#   Efficiency y (srs):  0.771 → 0.507 → 1.6541
#   Alpha:               0.7567995708992935
#   Num changes:         1
#   Design Depth:        632
#   Design Size (|D|):   1364
#   Open set size:       13441
#
# Progress: 9.8%
# === Best Solution Updated at Iteration 490 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       254703.55
#   Best Cost (y):       40817.0862
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      254703.55
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8248→ cube 2.1385
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7775→ cube 0.789
#   Efficiency z (srs):  3.526 → 0.274 → 13.5577
#   Efficiency y (srs):  0.771 → 0.507 → 1.6337
#   Alpha:               0.7097298403762486
#   Num changes:         1
#   Design Depth:        657
#   Design Size (|D|):   1414
#   Open set size:       14324
#
#
# === Best Solution Updated at Iteration 490 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       254435.315
#   Best Cost (y):       40885.1783
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      254435.315
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8256→ cube 2.1408
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7762→ cube 0.7877
#   Efficiency z (srs):  3.526 → 0.274 → 13.572
#   Efficiency y (srs):  0.771 → 0.507 → 1.631
#   Alpha:               0.8171494332285132
#   Num changes:         2
#   Design Depth:        658
#   Design Size (|D|):   1416
#   Open set size:       14326
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       253295.939
#   Best Cost (y):       40612.486
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      253295.939
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8293→ cube 2.1504
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7815→ cube 0.793
#   Efficiency z (srs):  3.526 → 0.274 → 13.6331
#   Efficiency y (srs):  0.771 → 0.507 → 1.6419
#   Alpha:               0.7332560212558008
#   Num changes:         1
#   Design Depth:        666
#   Design Size (|D|):   1432
#   Open set size:       14628
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       251339.492
#   Best Cost (y):       40578.4216
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      251339.492
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8358→ cube 2.1672
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7821→ cube 0.7937
#   Efficiency z (srs):  3.526 → 0.274 → 13.7392
#   Efficiency y (srs):  0.771 → 0.507 → 1.6433
#   Alpha:               0.8411094223994848
#   Num changes:         1
#   Design Depth:        679
#   Design Size (|D|):   1458
#   Open set size:       14890
#
# Progress: 10.4%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       251137.694
#   Best Cost (y):       40547.1355
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      251137.694
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8365→ cube 2.1689
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7827→ cube 0.7943
#   Efficiency z (srs):  3.526 → 0.274 → 13.7502
#   Efficiency y (srs):  0.771 → 0.507 → 1.6446
#   Alpha:               0.7396371171555464
#   Num changes:         1
#   Design Depth:        688
#   Design Size (|D|):   1476
#   Open set size:       15183
#
#
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       251123.335
#   Best Cost (y):       40547.1649
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      251123.335
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8365→ cube 2.169
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7827→ cube 0.7943
#   Efficiency z (srs):  3.526 → 0.274 → 13.751
#   Efficiency y (srs):  0.771 → 0.507 → 1.6446
#   Alpha:               0.8564987194259316
#   Num changes:         1
#   Design Depth:        688
#   Design Size (|D|):   1476
#   Open set size:       15186
#
#
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       251104.307
#   Best Cost (y):       40543.8965
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      251104.307
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8366→ cube 2.1692
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7828→ cube 0.7943
#   Efficiency z (srs):  3.526 → 0.274 → 13.752
#   Efficiency y (srs):  0.771 → 0.507 → 1.6447
#   Alpha:               0.8266962652207228
#   Num changes:         3
#   Design Depth:        690
#   Design Size (|D|):   1480
#   Open set size:       15196
#
# Progress: 10.6%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       250593.906
#   Best Cost (y):       40446.0325
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      250593.906
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8383→ cube 2.1736
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7847→ cube 0.7963
#   Efficiency z (srs):  3.526 → 0.274 → 13.7801
#   Efficiency y (srs):  0.771 → 0.507 → 1.6487
#   Alpha:               0.7098852170504972
#   Num changes:         3
#   Design Depth:        697
#   Design Size (|D|):   1494
#   Open set size:       15499
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       249878.114
#   Best Cost (y):       40331.3778
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      249878.114
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8407→ cube 2.1798
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7869→ cube 0.7985
#   Efficiency z (srs):  3.526 → 0.274 → 13.8195
#   Efficiency y (srs):  0.771 → 0.507 → 1.6534
#   Alpha:               0.7791844650708332
#   Num changes:         3
#   Design Depth:        714
#   Design Size (|D|):   1528
#   Open set size:       16078
#
# Progress: 11.2%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       244285.428
#   Best Cost (y):       39954.0611
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      244285.428
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8599→ cube 2.2297
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7943→ cube 0.8061
#   Efficiency z (srs):  3.526 → 0.274 → 14.1359
#   Efficiency y (srs):  0.771 → 0.507 → 1.669
#   Alpha:               0.7737701447288818
#   Num changes:         1
#   Design Depth:        733
#   Design Size (|D|):   1566
#   Open set size:       16351
#
#
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       243717.562
#   Best Cost (y):       39933.5385
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      243717.562
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8619→ cube 2.2349
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7947→ cube 0.8065
#   Efficiency z (srs):  3.526 → 0.274 → 14.1689
#   Efficiency y (srs):  0.771 → 0.507 → 1.6699
#   Alpha:               0.8289644233570027
#   Num changes:         2
#   Design Depth:        734
#   Design Size (|D|):   1568
#   Open set size:       16367
#
# Progress: 11.4%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       243013.053
#   Best Cost (y):       40038.7911
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      243013.053
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8644→ cube 2.2414
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7926→ cube 0.8044
#   Efficiency z (srs):  3.526 → 0.274 → 14.2099
#   Efficiency y (srs):  0.771 → 0.507 → 1.6655
#   Alpha:               0.8209556827224631
#   Num changes:         3
#   Design Depth:        749
#   Design Size (|D|):   1598
#   Open set size:       16632
#
# Progress: 11.6%
# === Best Solution Updated at Iteration 580 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       241093.633
#   Best Cost (y):       39976.6074
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      241093.633
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8713→ cube 2.2593
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7939→ cube 0.8056
#   Efficiency z (srs):  3.526 → 0.274 → 14.3231
#   Efficiency y (srs):  0.771 → 0.507 → 1.6681
#   Alpha:               0.7917612967908004
#   Num changes:         1
#   Design Depth:        764
#   Design Size (|D|):   1628
#   Open set size:       16926
#
# Progress: 11.8%
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       240952.306
#   Best Cost (y):       39916.0185
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      240952.306
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8718→ cube 2.2606
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.7951→ cube 0.8068
#   Efficiency z (srs):  3.526 → 0.274 → 14.3315
#   Efficiency y (srs):  0.771 → 0.507 → 1.6706
#   Alpha:               0.7439514660964603
#   Num changes:         1
#   Design Depth:        774
#   Design Size (|D|):   1648
#   Open set size:       17220
#
# Progress: 12.6%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       238280.55
#   Best Cost (y):       39498.1655
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      238280.55
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8816→ cube 2.2859
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.8035→ cube 0.8154
#   Efficiency z (srs):  3.526 → 0.274 → 14.4922
#   Efficiency y (srs):  0.771 → 0.507 → 1.6883
#   Alpha:               0.7972537752807435
#   Num changes:         1
#   Design Depth:        804
#   Design Size (|D|):   1708
#   Open set size:       18371
#
#
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       238258.537
#   Best Cost (y):       39504.3176
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      238258.537
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8817→ cube 2.2861
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.8034→ cube 0.8152
#   Efficiency z (srs):  3.526 → 0.274 → 14.4935
#   Efficiency y (srs):  0.771 → 0.507 → 1.688
#   Alpha:               0.869715387985154
#   Num changes:         1
#   Design Depth:        804
#   Design Size (|D|):   1708
#   Open set size:       18387
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       236646.357
#   Best Cost (y):       39449.7292
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      236646.357
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.8877→ cube 2.3017
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.8045→ cube 0.8164
#   Efficiency z (srs):  3.526 → 0.274 → 14.5922
#   Efficiency y (srs):  0.771 → 0.507 → 1.6903
#   Alpha:               0.8776908704674989
#   Num changes:         3
#   Design Depth:        830
#   Design Size (|D|):   1760
#   Open set size:       18957
#
# Progress: 13.8%
# === Best Solution Updated at Iteration 690 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       231274.777
#   Best Cost (y):       39165.5699
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      231274.777
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.9083→ cube 2.3552
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.8103→ cube 0.8223
#   Efficiency z (srs):  3.526 → 0.274 → 14.9311
#   Efficiency y (srs):  0.771 → 0.507 → 1.7026
#   Alpha:               0.7499263077423489
#   Num changes:         1
#   Design Depth:        873
#   Design Size (|D|):   1846
#   Open set size:       20121
#
#
# === Best Solution Updated at Iteration 690 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       231269.924
#   Best Cost (y):       39173.1514
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      231269.924
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.9083→ cube 2.3552
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.8102→ cube 0.8221
#   Efficiency z (srs):  3.526 → 0.274 → 14.9315
#   Efficiency y (srs):  0.771 → 0.507 → 1.7023
#   Alpha:               0.7842280016772005
#   Num changes:         1
#   Design Depth:        873
#   Design Size (|D|):   1846
#   Open set size:       20129
#
# Progress: 14.2%
# === Best Solution Updated at Iteration 710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       229471.944
#   Best Cost (y):       39199.7247
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      229471.944
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.9154→ cube 2.3737
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.8096→ cube 0.8216
#   Efficiency z (srs):  3.526 → 0.274 → 15.0485
#   Efficiency y (srs):  0.771 → 0.507 → 1.7011
#   Alpha:               0.7009326081041293
#   Num changes:         2
#   Design Depth:        892
#   Design Size (|D|):   1884
#   Open set size:       20693
#
#
# === Best Solution Updated at Iteration 710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       229464.866
#   Best Cost (y):       39227.4953
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      229464.866
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 0.9155→ cube 2.3738
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.809→ cube 0.821
#   Efficiency z (srs):  3.526 → 0.274 → 15.0489
#   Efficiency y (srs):  0.771 → 0.507 → 1.6999
#   Alpha:               0.820786739886806
#   Num changes:         1
#   Design Depth:        891
#   Design Size (|D|):   1882
#   Open set size:       20707
#
# Progress: 14.4%
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       228418.801
#   Best Cost (y):       39201.6793
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      228418.801
# ...
#   Best Cost (y):       34692.4553
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      143946.377
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4594→ cube 3.784
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9148→ cube 0.9283
#   Efficiency z (srs):  3.526 → 0.274 → 23.9895
#   Efficiency y (srs):  0.771 → 0.507 → 1.9221
#   Alpha:               0.8546509786264271
#   Num changes:         2
#   Design Depth:        4014
#   Design Size (|D|):   8128
#   Open set size:       126848
#
# Progress: 87.6%
# === Best Solution Updated at Iteration 4380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       143646.309
#   Best Cost (y):       34688.8726
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      143646.309
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4624→ cube 3.7919
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9149→ cube 0.9284
#   Efficiency z (srs):  3.526 → 0.274 → 24.0396
#   Efficiency y (srs):  0.771 → 0.507 → 1.9223
#   Alpha:               0.848420039869132
#   Num changes:         1
#   Design Depth:        4029
#   Design Size (|D|):   8158
#   Open set size:       127146
#
# Progress: 87.8%
# === Best Solution Updated at Iteration 4390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       143609.765
#   Best Cost (y):       34694.9927
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      143609.765
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4628→ cube 3.7929
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9147→ cube 0.9282
#   Efficiency z (srs):  3.526 → 0.274 → 24.0457
#   Efficiency y (srs):  0.771 → 0.507 → 1.922
#   Alpha:               0.815721868330468
#   Num changes:         1
#   Design Depth:        4038
#   Design Size (|D|):   8176
#   Open set size:       127411
#
# Progress: 88.4%
# === Best Solution Updated at Iteration 4420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       143445.582
#   Best Cost (y):       34689.101
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      143445.582
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4645→ cube 3.7972
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9149→ cube 0.9284
#   Efficiency z (srs):  3.526 → 0.274 → 24.0732
#   Efficiency y (srs):  0.771 → 0.507 → 1.9223
#   Alpha:               0.8582498478924185
#   Num changes:         3
#   Design Depth:        4059
#   Design Size (|D|):   8218
#   Open set size:       128286
#
# Progress: 88.6%
# === Best Solution Updated at Iteration 4430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       143118.791
#   Best Cost (y):       34674.0177
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      143118.791
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4678→ cube 3.8059
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9153→ cube 0.9288
#   Efficiency z (srs):  3.526 → 0.274 → 24.1282
#   Efficiency y (srs):  0.771 → 0.507 → 1.9232
#   Alpha:               0.7793743372183561
#   Num changes:         1
#   Design Depth:        4072
#   Design Size (|D|):   8244
#   Open set size:       128596
#
# Progress: 89.2%
# === Best Solution Updated at Iteration 4460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       142200.671
#   Best Cost (y):       34600.3888
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      142200.671
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4773→ cube 3.8304
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9172→ cube 0.9308
#   Efficiency z (srs):  3.526 → 0.274 → 24.284
#   Efficiency y (srs):  0.771 → 0.507 → 1.9272
#   Alpha:               0.7338003625735219
#   Num changes:         1
#   Design Depth:        4115
#   Design Size (|D|):   8330
#   Open set size:       129468
#
# Progress: 89.4%
# === Best Solution Updated at Iteration 4470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       141852.739
#   Best Cost (y):       34597.5511
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      141852.739
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4809→ cube 3.8398
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9173→ cube 0.9309
#   Efficiency z (srs):  3.526 → 0.274 → 24.3435
#   Efficiency y (srs):  0.771 → 0.507 → 1.9274
#   Alpha:               0.7008847818413768
#   Num changes:         3
#   Design Depth:        4129
#   Design Size (|D|):   8358
#   Open set size:       129732
#
#
# === Best Solution Updated at Iteration 4470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       141852.549
#   Best Cost (y):       34585.0693
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      141852.549
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4809→ cube 3.8398
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9176→ cube 0.9312
#   Efficiency z (srs):  3.526 → 0.274 → 24.3436
#   Efficiency y (srs):  0.771 → 0.507 → 1.9281
#   Alpha:               0.7832262615354157
#   Num changes:         1
#   Design Depth:        4127
#   Design Size (|D|):   8354
#   Open set size:       129741
#
# Progress: 89.6%
# === Best Solution Updated at Iteration 4480 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       141793.731
#   Best Cost (y):       34563.0061
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      141793.731
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4815→ cube 3.8414
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9182→ cube 0.9318
#   Efficiency z (srs):  3.526 → 0.274 → 24.3537
#   Efficiency y (srs):  0.771 → 0.507 → 1.9293
#   Alpha:               0.8023307585819005
#   Num changes:         1
#   Design Depth:        4136
#   Design Size (|D|):   8372
#   Open set size:       130049
#
# Progress: 89.8%
# === Best Solution Updated at Iteration 4490 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       141716.303
#   Best Cost (y):       34551.1447
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      141716.303
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4823→ cube 3.8435
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9185→ cube 0.9321
#   Efficiency z (srs):  3.526 → 0.274 → 24.367
#   Efficiency y (srs):  0.771 → 0.507 → 1.93
#   Alpha:               0.8740791069245212
#   Num changes:         3
#   Design Depth:        4146
#   Design Size (|D|):   8392
#   Open set size:       130323
#
# Progress: 90.2%
# === Best Solution Updated at Iteration 4510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       141425.105
#   Best Cost (y):       34534.9481
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      141425.105
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4854→ cube 3.8515
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.919→ cube 0.9326
#   Efficiency z (srs):  3.526 → 0.274 → 24.4172
#   Efficiency y (srs):  0.771 → 0.507 → 1.9309
#   Alpha:               0.7995079007162151
#   Num changes:         3
#   Design Depth:        4176
#   Design Size (|D|):   8452
#   Open set size:       130908
#
# Progress: 91.2%
# === Best Solution Updated at Iteration 4560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140782.264
#   Best Cost (y):       34496.446
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140782.264
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4922→ cube 3.869
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.92→ cube 0.9336
#   Efficiency z (srs):  3.526 → 0.274 → 24.5286
#   Efficiency y (srs):  0.771 → 0.507 → 1.9331
#   Alpha:               0.741497319856337
#   Num changes:         1
#   Design Depth:        4208
#   Design Size (|D|):   8516
#   Open set size:       132342
#
#
# === Best Solution Updated at Iteration 4560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140753.243
#   Best Cost (y):       34467.3068
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140753.243
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4925→ cube 3.8698
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9208→ cube 0.9344
#   Efficiency z (srs):  3.526 → 0.274 → 24.5337
#   Efficiency y (srs):  0.771 → 0.507 → 1.9347
#   Alpha:               0.8878962093454241
#   Num changes:         1
#   Design Depth:        4208
#   Design Size (|D|):   8516
#   Open set size:       132368
#
#
# === Best Solution Updated at Iteration 4560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140749.29
#   Best Cost (y):       34468.0108
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140749.29
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4925→ cube 3.8699
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9208→ cube 0.9344
#   Efficiency z (srs):  3.526 → 0.274 → 24.5344
#   Efficiency y (srs):  0.771 → 0.507 → 1.9346
#   Alpha:               0.7573320576410291
#   Num changes:         1
#   Design Depth:        4208
#   Design Size (|D|):   8516
#   Open set size:       132369
#
# Progress: 91.4%
# === Best Solution Updated at Iteration 4570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140703.999
#   Best Cost (y):       34501.2526
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140703.999
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.493→ cube 3.8712
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9199→ cube 0.9335
#   Efficiency z (srs):  3.526 → 0.274 → 24.5423
#   Efficiency y (srs):  0.771 → 0.507 → 1.9328
#   Alpha:               0.8849895807022472
#   Num changes:         2
#   Design Depth:        4220
#   Design Size (|D|):   8540
#   Open set size:       132632
#
#
# === Best Solution Updated at Iteration 4570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140701.519
#   Best Cost (y):       34475.7636
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140701.519
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.493→ cube 3.8713
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9205→ cube 0.9342
#   Efficiency z (srs):  3.526 → 0.274 → 24.5427
#   Efficiency y (srs):  0.771 → 0.507 → 1.9342
#   Alpha:               0.827541725564243
#   Num changes:         2
#   Design Depth:        4220
#   Design Size (|D|):   8540
#   Open set size:       132646
#
# Progress: 92.2%
# === Best Solution Updated at Iteration 4610 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140400.29
#   Best Cost (y):       34414.4541
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140400.29
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4962→ cube 3.8796
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9222→ cube 0.9358
#   Efficiency z (srs):  3.526 → 0.274 → 24.5954
#   Efficiency y (srs):  0.771 → 0.507 → 1.9377
#   Alpha:               0.8121685718619828
#   Num changes:         1
#   Design Depth:        4262
#   Design Size (|D|):   8624
#   Open set size:       133802
#
# Progress: 92.4%
# === Best Solution Updated at Iteration 4620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140121.269
#   Best Cost (y):       34413.4448
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140121.269
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4992→ cube 3.8873
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9222→ cube 0.9358
#   Efficiency z (srs):  3.526 → 0.274 → 24.6444
#   Efficiency y (srs):  0.771 → 0.507 → 1.9377
#   Alpha:               0.7128932340995439
#   Num changes:         1
#   Design Depth:        4278
#   Design Size (|D|):   8656
#   Open set size:       134081
#
#
# === Best Solution Updated at Iteration 4620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       140117.749
#   Best Cost (y):       34431.9941
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      140117.749
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.4992→ cube 3.8874
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9217→ cube 0.9353
#   Efficiency z (srs):  3.526 → 0.274 → 24.645
#   Efficiency y (srs):  0.771 → 0.507 → 1.9367
#   Alpha:               0.8989276501043169
#   Num changes:         1
#   Design Depth:        4278
#   Design Size (|D|):   8656
#   Open set size:       134100
#
# Progress: 92.8%
# === Best Solution Updated at Iteration 4640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       139794.211
#   Best Cost (y):       34474.5097
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      139794.211
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.5027→ cube 3.8964
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9206→ cube 0.9342
#   Efficiency z (srs):  3.526 → 0.274 → 24.702
#   Efficiency y (srs):  0.771 → 0.507 → 1.9343
#   Alpha:               0.8192966384210252
#   Num changes:         2
#   Design Depth:        4307
#   Design Size (|D|):   8714
#   Open set size:       134660
#
#
# === Best Solution Updated at Iteration 4640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       139791.111
#   Best Cost (y):       34480.7579
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      139791.111
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.5027→ cube 3.8965
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9204→ cube 0.934
#   Efficiency z (srs):  3.526 → 0.274 → 24.7026
#   Efficiency y (srs):  0.771 → 0.507 → 1.9339
#   Alpha:               0.8676519947933227
#   Num changes:         1
#   Design Depth:        4306
#   Design Size (|D|):   8712
#   Open set size:       134663
#
#
# === Best Solution Updated at Iteration 4640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   49886.93→49886.93, 9968.83→9968.83
#   Best Cost (z):       139739.36
#   Best Cost (y):       34479.7566
#   number of new noded: 30
#   rho (z, y):          0.706
#   rho (z_hat, y_hat):  0.763
#   rho (p, y):          0.668
#   Criteria Value:      139739.36
#   Efficiency z (0→f):  0.214 → 0.274 → dsd 1.5033→ cube 3.8979
#   Efficiency y (0→f):  0.367 → 0.507 → dsd 0.9204→ cube 0.934
#   Efficiency z (srs):  3.526 → 0.274 → 24.7117
#   Efficiency y (srs):  0.771 → 0.507 → 1.934
#   Alpha:               0.7542326657177209
#   Num changes:         3
#   Design Depth:        4308
#   Design Size (|D|):   8716
#   Open set size:       134681

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
