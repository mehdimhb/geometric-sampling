# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Artificial"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmpEG6yp1", R: "/tmp/RtmpTNlk8f"
#   warnings.warn(

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_8.5_py_9.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_8.5_py_9.5_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.7 0.9
# Generating initial designs:   0%|                      | 0/3000 [00:00<?, ?it/s]
# Initial design 0: method = Original, efficiency z = 0.1340, y=0.4433
# New best at idx=0: method = Original, efficiency z = 0.1340 and efficiency y = 0.4433
# New best at idx=2: method = z/pi, efficiency z = 0.1340 and efficiency y = 0.4433
# New best at idx=3: method = swap, efficiency z = 0.1503 and efficiency y = 0.5621
# Generating initial designs:   1%|▏            | 39/3000 [00:00<00:51, 57.59it/s]
# New best at idx=28: method = swap, efficiency z = 0.1531 and efficiency y = 0.7340
# New best at idx=35: method = swap, efficiency z = 0.1646 and efficiency y = 0.4788
# Generating initial designs:   3%|▍            | 91/3000 [00:01<00:32, 90.16it/s]
# New best at idx=77: method = swap, efficiency z = 0.1658 and efficiency y = 0.4715
# Generating initial designs:   5%|▌           | 152/3000 [00:02<00:33, 85.17it/s]
# New best at idx=137: method = swap, efficiency z = 0.1796 and efficiency y = 1.1795
# Generating initial designs:  44%|████▊      | 1327/3000 [00:22<00:23, 70.62it/s]
# New best at idx=1314: method = swap, efficiency z = 0.1913 and efficiency y = 1.2622
# Generating initial designs: 100%|███████████| 3000/3000 [00:50<00:00, 58.97it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       123094.885
#   Best Cost (y):       6829.8717
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      123094.885
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.1919→ cube 0.9505
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.2211→ cube 1.1491
#   Efficiency z (srs):  16.552 → 0.191 → 23.6999
#   Efficiency y (srs):  4.72 → 1.262 → 13.0025
#   Alpha:               0.7950954767950369
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       111
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       122738.324
#   Best Cost (y):       7344.8809
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      122738.324
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.1924→ cube 0.9532
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1355→ cube 1.0686
#   Efficiency z (srs):  16.552 → 0.191 → 23.7688
#   Efficiency y (srs):  4.72 → 1.262 → 12.0908
#   Alpha:               0.8269685923629133
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       114
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       122528.809
#   Best Cost (y):       7850.2766
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      122528.809
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.1928→ cube 0.9549
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0624→ cube 0.9998
#   Efficiency z (srs):  16.552 → 0.191 → 23.8094
#   Efficiency y (srs):  4.72 → 1.262 → 11.3124
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        3
#   Design Size (|D|):   106
#   Open set size:       158
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       95824.273
#   Best Cost (y):       7770.4794
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      95824.273
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.2465→ cube 1.221
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0733→ cube 1.01
#   Efficiency z (srs):  16.552 → 0.191 → 30.4447
#   Efficiency y (srs):  4.72 → 1.262 → 11.4286
#   Alpha:               0.7406748674905504
#   Num changes:         1
#   Design Depth:        19
#   Design Size (|D|):   138
#   Open set size:       393
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       95663.939
#   Best Cost (y):       8129.5117
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      95663.939
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.2469→ cube 1.223
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0259→ cube 0.9654
#   Efficiency z (srs):  16.552 → 0.191 → 30.4957
#   Efficiency y (srs):  4.72 → 1.262 → 10.9238
#   Alpha:               0.8319005796907779
#   Num changes:         1
#   Design Depth:        19
#   Design Size (|D|):   138
#   Open set size:       403
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       86453.297
#   Best Cost (y):       8377.7521
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      86453.297
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.2732→ cube 1.3533
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 0.9955→ cube 0.9368
#   Efficiency z (srs):  16.552 → 0.191 → 33.7447
#   Efficiency y (srs):  4.72 → 1.262 → 10.6002
#   Alpha:               0.7894383306079946
#   Num changes:         1
#   Design Depth:        54
#   Design Size (|D|):   208
#   Open set size:       1272
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       86269.427
#   Best Cost (y):       8520.6657
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      86269.427
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.2738→ cube 1.3562
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 0.9788→ cube 0.9211
#   Efficiency z (srs):  16.552 → 0.191 → 33.8166
#   Efficiency y (srs):  4.72 → 1.262 → 10.4224
#   Alpha:               0.8770060689873987
#   Num changes:         2
#   Design Depth:        55
#   Design Size (|D|):   210
#   Open set size:       1283
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       80315.614
#   Best Cost (y):       8226.6603
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      80315.614
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.2941→ cube 1.4567
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0138→ cube 0.954
#   Efficiency z (srs):  16.552 → 0.191 → 36.3235
#   Efficiency y (srs):  4.72 → 1.262 → 10.7948
#   Alpha:               0.8186769899739277
#   Num changes:         1
#   Design Depth:        72
#   Design Size (|D|):   244
#   Open set size:       1571
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       73593.68
#   Best Cost (y):       8101.4595
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      73593.68
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3209→ cube 1.5898
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0295→ cube 0.9688
#   Efficiency z (srs):  16.552 → 0.191 → 39.6412
#   Efficiency y (srs):  4.72 → 1.262 → 10.9617
#   Alpha:               0.8642624273037813
#   Num changes:         1
#   Design Depth:        89
#   Design Size (|D|):   278
#   Open set size:       1843
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       73505.183
#   Best Cost (y):       7983.4205
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      73505.183
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3213→ cube 1.5917
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0447→ cube 0.9831
#   Efficiency z (srs):  16.552 → 0.191 → 39.6889
#   Efficiency y (srs):  4.72 → 1.262 → 11.1237
#   Alpha:               0.898868502599689
#   Num changes:         1
#   Design Depth:        89
#   Design Size (|D|):   278
#   Open set size:       1865
#
# Progress: 1.4%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       70685.781
#   Best Cost (y):       7937.4732
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      70685.781
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3341→ cube 1.6552
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0507→ cube 0.9888
#   Efficiency z (srs):  16.552 → 0.191 → 41.272
#   Efficiency y (srs):  4.72 → 1.262 → 11.1881
#   Alpha:               0.8093153202189814
#   Num changes:         2
#   Design Depth:        100
#   Design Size (|D|):   300
#   Open set size:       2149
#
# Progress: 1.6%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       66369.287
#   Best Cost (y):       8236.1436
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      66369.287
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3559→ cube 1.7628
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0126→ cube 0.9529
#   Efficiency z (srs):  16.552 → 0.191 → 43.9562
#   Efficiency y (srs):  4.72 → 1.262 → 10.7824
#   Alpha:               0.7832713199197614
#   Num changes:         1
#   Design Depth:        114
#   Design Size (|D|):   328
#   Open set size:       2425
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       66357.579
#   Best Cost (y):       8227.4855
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      66357.579
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3559→ cube 1.7631
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0137→ cube 0.9539
#   Efficiency z (srs):  16.552 → 0.191 → 43.9639
#   Efficiency y (srs):  4.72 → 1.262 → 10.7938
#   Alpha:               0.8923870000577552
#   Num changes:         1
#   Design Depth:        114
#   Design Size (|D|):   328
#   Open set size:       2448
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       65801.359
#   Best Cost (y):       8005.525
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      65801.359
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.359→ cube 1.778
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0418→ cube 0.9804
#   Efficiency z (srs):  16.552 → 0.191 → 44.3356
#   Efficiency y (srs):  4.72 → 1.262 → 11.093
#   Alpha:               0.7940324518648378
#   Num changes:         2
#   Design Depth:        123
#   Design Size (|D|):   346
#   Open set size:       2720
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       64198.734
#   Best Cost (y):       8056.7469
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      64198.734
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3679→ cube 1.8224
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0352→ cube 0.9742
#   Efficiency z (srs):  16.552 → 0.191 → 45.4423
#   Efficiency y (srs):  4.72 → 1.262 → 11.0225
#   Alpha:               0.8530005934375635
#   Num changes:         1
#   Design Depth:        136
#   Design Size (|D|):   372
#   Open set size:       3012
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       61201.3
#   Best Cost (y):       7700.791
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      61201.3
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.3859→ cube 1.9117
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.083→ cube 1.0192
#   Efficiency z (srs):  16.552 → 0.191 → 47.6679
#   Efficiency y (srs):  4.72 → 1.262 → 11.532
#   Alpha:               0.7587947038764121
#   Num changes:         1
#   Design Depth:        150
#   Design Size (|D|):   400
#   Open set size:       3302
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       61194.427
#   Best Cost (y):       7752.2597
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      61194.427
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.386→ cube 1.9119
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0759→ cube 1.0124
#   Efficiency z (srs):  16.552 → 0.191 → 47.6733
#   Efficiency y (srs):  4.72 → 1.262 → 11.4554
#   Alpha:               0.7743312214119057
#   Num changes:         2
#   Design Depth:        151
#   Design Size (|D|):   402
#   Open set size:       3308
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       58552.28
#   Best Cost (y):       7677.3467
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      58552.28
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4034→ cube 1.9982
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0863→ cube 1.0223
#   Efficiency z (srs):  16.552 → 0.191 → 49.8245
#   Efficiency y (srs):  4.72 → 1.262 → 11.5672
#   Alpha:               0.7686126424895982
#   Num changes:         1
#   Design Depth:        188
#   Design Size (|D|):   476
#   Open set size:       4173
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       58543.228
#   Best Cost (y):       7742.8501
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      58543.228
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4035→ cube 1.9985
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0772→ cube 1.0136
#   Efficiency z (srs):  16.552 → 0.191 → 49.8322
#   Efficiency y (srs):  4.72 → 1.262 → 11.4694
#   Alpha:               0.8710217588766577
#   Num changes:         1
#   Design Depth:        188
#   Design Size (|D|):   476
#   Open set size:       4182
#
# Progress: 3.6%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       57263.23
#   Best Cost (y):       7757.1526
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      57263.23
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4125→ cube 2.0432
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0752→ cube 1.0118
#   Efficiency z (srs):  16.552 → 0.191 → 50.9461
#   Efficiency y (srs):  4.72 → 1.262 → 11.4482
#   Alpha:               0.7154479619257664
#   Num changes:         1
#   Design Depth:        219
#   Design Size (|D|):   538
#   Open set size:       5327
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       57238.132
#   Best Cost (y):       7729.411
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      57238.132
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4127→ cube 2.0441
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.079→ cube 1.0154
#   Efficiency z (srs):  16.552 → 0.191 → 50.9685
#   Efficiency y (srs):  4.72 → 1.262 → 11.4893
#   Alpha:               0.773670301185291
#   Num changes:         2
#   Design Depth:        220
#   Design Size (|D|):   540
#   Open set size:       5337
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       55966.08
#   Best Cost (y):       7301.1802
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      55966.08
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.422→ cube 2.0905
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1423→ cube 1.075
#   Efficiency z (srs):  16.552 → 0.191 → 52.1269
#   Efficiency y (srs):  4.72 → 1.262 → 12.1632
#   Alpha:               0.8464897167312346
#   Num changes:         3
#   Design Depth:        240
#   Design Size (|D|):   580
#   Open set size:       6196
#
# Progress: 4.4%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       55369.606
#   Best Cost (y):       7298.7408
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      55369.606
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4266→ cube 2.113
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1427→ cube 1.0753
#   Efficiency z (srs):  16.552 → 0.191 → 52.6885
#   Efficiency y (srs):  4.72 → 1.262 → 12.1672
#   Alpha:               0.7936458182325798
#   Num changes:         1
#   Design Depth:        252
#   Design Size (|D|):   604
#   Open set size:       6481
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       55101.108
#   Best Cost (y):       7298.0559
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      55101.108
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4287→ cube 2.1233
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1428→ cube 1.0754
#   Efficiency z (srs):  16.552 → 0.191 → 52.9452
#   Efficiency y (srs):  4.72 → 1.262 → 12.1684
#   Alpha:               0.7198987823456816
#   Num changes:         2
#   Design Depth:        253
#   Design Size (|D|):   606
#   Open set size:       6493
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53585.995
#   Best Cost (y):       7328.8397
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      53585.995
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4408→ cube 2.1834
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.138→ cube 1.0709
#   Efficiency z (srs):  16.552 → 0.191 → 54.4422
#   Efficiency y (srs):  4.72 → 1.262 → 12.1173
#   Alpha:               0.8051613866429106
#   Num changes:         1
#   Design Depth:        281
#   Design Size (|D|):   662
#   Open set size:       7350
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53140.6
#   Best Cost (y):       7358.3438
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      53140.6
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4445→ cube 2.2017
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1334→ cube 1.0666
#   Efficiency z (srs):  16.552 → 0.191 → 54.8985
#   Efficiency y (srs):  4.72 → 1.262 → 12.0687
#   Alpha:               0.8646147424669189
#   Num changes:         1
#   Design Depth:        296
#   Design Size (|D|):   692
#   Open set size:       7644
#
#
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53039.1
#   Best Cost (y):       7366.0137
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      53039.1
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4453→ cube 2.2059
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1323→ cube 1.0655
#   Efficiency z (srs):  16.552 → 0.191 → 55.0036
#   Efficiency y (srs):  4.72 → 1.262 → 12.0561
#   Alpha:               0.747129756886303
#   Num changes:         1
#   Design Depth:        296
#   Design Size (|D|):   692
#   Open set size:       7646
#
#
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       52806.395
#   Best Cost (y):       7369.742
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      52806.395
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4473→ cube 2.2156
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1317→ cube 1.065
#   Efficiency z (srs):  16.552 → 0.191 → 55.246
#   Efficiency y (srs):  4.72 → 1.262 → 12.05
#   Alpha:               0.7061645125039325
#   Num changes:         2
#   Design Depth:        297
#   Design Size (|D|):   694
#   Open set size:       7662
#
# Progress: 5.4%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       52629.994
#   Best Cost (y):       7458.3217
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      52629.994
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4488→ cube 2.223
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1183→ cube 1.0523
#   Efficiency z (srs):  16.552 → 0.191 → 55.4311
#   Efficiency y (srs):  4.72 → 1.262 → 11.9069
#   Alpha:               0.7671629535261257
#   Num changes:         1
#   Design Depth:        306
#   Design Size (|D|):   712
#   Open set size:       7933
#
# Progress: 5.6%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       51558.258
#   Best Cost (y):       7421.7784
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      51558.258
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4581→ cube 2.2692
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1238→ cube 1.0575
#   Efficiency z (srs):  16.552 → 0.191 → 56.5834
#   Efficiency y (srs):  4.72 → 1.262 → 11.9655
#   Alpha:               0.7491811333625439
#   Num changes:         1
#   Design Depth:        317
#   Design Size (|D|):   734
#   Open set size:       8227
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       51557.63
#   Best Cost (y):       7422.4996
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      51557.63
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4581→ cube 2.2693
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1236→ cube 1.0574
#   Efficiency z (srs):  16.552 → 0.191 → 56.5841
#   Efficiency y (srs):  4.72 → 1.262 → 11.9644
#   Alpha:               0.8306614540249031
#   Num changes:         1
#   Design Depth:        317
#   Design Size (|D|):   734
#   Open set size:       8235
#
# Progress: 6.4%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       51012.005
#   Best Cost (y):       7343.3297
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      51012.005
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.463→ cube 2.2935
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1358→ cube 1.0688
#   Efficiency z (srs):  16.552 → 0.191 → 57.1893
#   Efficiency y (srs):  4.72 → 1.262 → 12.0934
#   Alpha:               0.7404430935520471
#   Num changes:         2
#   Design Depth:        351
#   Design Size (|D|):   802
#   Open set size:       9402
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       50606.578
#   Best Cost (y):       7337.4337
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      50606.578
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4667→ cube 2.3119
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1367→ cube 1.0696
#   Efficiency z (srs):  16.552 → 0.191 → 57.6475
#   Efficiency y (srs):  4.72 → 1.262 → 12.1031
#   Alpha:               0.8615793716652231
#   Num changes:         3
#   Design Depth:        375
#   Design Size (|D|):   850
#   Open set size:       10267
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       49233.73
#   Best Cost (y):       7400.204
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      49233.73
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.4797→ cube 2.3764
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.127→ cube 1.0606
#   Efficiency z (srs):  16.552 → 0.191 → 59.2549
#   Efficiency y (srs):  4.72 → 1.262 → 12.0004
#   Alpha:               0.8440554582268578
#   Num changes:         1
#   Design Depth:        391
#   Design Size (|D|):   882
#   Open set size:       10546
#
#
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       49205.214
#   Best Cost (y):       7327.6183
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      49205.214
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.48→ cube 2.3778
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1382→ cube 1.0711
#   Efficiency z (srs):  16.552 → 0.191 → 59.2893
#   Efficiency y (srs):  4.72 → 1.262 → 12.1193
#   Alpha:               0.7780444995895658
#   Num changes:         3
#   Design Depth:        393
#   Design Size (|D|):   886
#   Open set size:       10568
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       46846.237
#   Best Cost (y):       7141.5628
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      46846.237
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5042→ cube 2.4975
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1679→ cube 1.099
#   Efficiency z (srs):  16.552 → 0.191 → 62.2748
#   Efficiency y (srs):  4.72 → 1.262 → 12.435
#   Alpha:               0.858365852316932
#   Num changes:         2
#   Design Depth:        451
#   Design Size (|D|):   1002
#   Open set size:       11990
#
# Progress: 8.6%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       45864.695
#   Best Cost (y):       7131.0709
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      45864.695
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.515→ cube 2.5509
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1696→ cube 1.1006
#   Efficiency z (srs):  16.552 → 0.191 → 63.6075
#   Efficiency y (srs):  4.72 → 1.262 → 12.4533
#   Alpha:               0.8035941962248503
#   Num changes:         3
#   Design Depth:        482
#   Design Size (|D|):   1064
#   Open set size:       12589
#
# Progress: 8.8%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       45263.007
#   Best Cost (y):       7196.8792
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      45263.007
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5218→ cube 2.5848
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1589→ cube 1.0905
#   Efficiency z (srs):  16.552 → 0.191 → 64.4531
#   Efficiency y (srs):  4.72 → 1.262 → 12.3394
#   Alpha:               0.7877310964140039
#   Num changes:         2
#   Design Depth:        494
#   Design Size (|D|):   1088
#   Open set size:       12870
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       44941.015
#   Best Cost (y):       7223.4278
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      44941.015
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5256→ cube 2.6034
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1546→ cube 1.0865
#   Efficiency z (srs):  16.552 → 0.191 → 64.9149
#   Efficiency y (srs):  4.72 → 1.262 → 12.2941
#   Alpha:               0.8538352152789989
#   Num changes:         1
#   Design Depth:        505
#   Design Size (|D|):   1110
#   Open set size:       13158
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       44728.126
#   Best Cost (y):       7234.0973
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      44728.126
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5281→ cube 2.6158
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1529→ cube 1.0849
#   Efficiency z (srs):  16.552 → 0.191 → 65.2238
#   Efficiency y (srs):  4.72 → 1.262 → 12.276
#   Alpha:               0.80276436028433
#   Num changes:         1
#   Design Depth:        516
#   Design Size (|D|):   1132
#   Open set size:       13457
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       44448.744
#   Best Cost (y):       7262.6211
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      44448.744
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5314→ cube 2.6322
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1484→ cube 1.0807
#   Efficiency z (srs):  16.552 → 0.191 → 65.6338
#   Efficiency y (srs):  4.72 → 1.262 → 12.2277
#   Alpha:               0.8438628751446813
#   Num changes:         3
#   Design Depth:        538
#   Design Size (|D|):   1176
#   Open set size:       14624
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       44182.246
#   Best Cost (y):       7273.8282
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      44182.246
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5346→ cube 2.6481
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1466→ cube 1.079
#   Efficiency z (srs):  16.552 → 0.191 → 66.0297
#   Efficiency y (srs):  4.72 → 1.262 → 12.2089
#   Alpha:               0.8016962116593238
#   Num changes:         1
#   Design Depth:        554
#   Design Size (|D|):   1208
#   Open set size:       14891
#
#
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       44161.478
#   Best Cost (y):       7294.1996
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      44161.478
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5348→ cube 2.6493
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1434→ cube 1.076
#   Efficiency z (srs):  16.552 → 0.191 → 66.0607
#   Efficiency y (srs):  4.72 → 1.262 → 12.1748
#   Alpha:               0.8157228488751349
#   Num changes:         1
#   Design Depth:        554
#   Design Size (|D|):   1208
#   Open set size:       14900
#
# Progress: 11.4%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       43751.415
#   Best Cost (y):       7371.8241
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      43751.415
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5399→ cube 2.6742
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1314→ cube 1.0647
#   Efficiency z (srs):  16.552 → 0.191 → 66.6799
#   Efficiency y (srs):  4.72 → 1.262 → 12.0466
#   Alpha:               0.7453731973376666
#   Num changes:         1
#   Design Depth:        602
#   Design Size (|D|):   1304
#   Open set size:       16645
#
#
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       43731.163
#   Best Cost (y):       7387.7643
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      43731.163
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5401→ cube 2.6754
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1289→ cube 1.0624
#   Efficiency z (srs):  16.552 → 0.191 → 66.7108
#   Efficiency y (srs):  4.72 → 1.262 → 12.0206
#   Alpha:               0.757310033250193
#   Num changes:         1
#   Design Depth:        602
#   Design Size (|D|):   1304
#   Open set size:       16658
#
# Progress: 12.6%
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       40955.643
#   Best Cost (y):       7387.5137
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      40955.643
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5767→ cube 2.8567
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.129→ cube 1.0624
#   Efficiency z (srs):  16.552 → 0.191 → 71.2317
#   Efficiency y (srs):  4.72 → 1.262 → 12.021
#   Alpha:               0.7523800703347738
#   Num changes:         1
#   Design Depth:        675
#   Design Size (|D|):   1450
#   Open set size:       18373
#
#
# === Best Solution Updated at Iteration 630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       40950.478
#   Best Cost (y):       7386.8565
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      40950.478
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5768→ cube 2.8571
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1291→ cube 1.0625
#   Efficiency z (srs):  16.552 → 0.191 → 71.2407
#   Efficiency y (srs):  4.72 → 1.262 → 12.0221
#   Alpha:               0.8228221396758832
#   Num changes:         1
#   Design Depth:        675
#   Design Size (|D|):   1450
#   Open set size:       18383
#
# Progress: 12.8%
# === Best Solution Updated at Iteration 640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       40443.283
#   Best Cost (y):       7358.0904
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      40443.283
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.584→ cube 2.8929
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1335→ cube 1.0666
#   Efficiency z (srs):  16.552 → 0.191 → 72.1341
#   Efficiency y (srs):  4.72 → 1.262 → 12.0691
#   Alpha:               0.8165144864250284
#   Num changes:         1
#   Design Depth:        692
#   Design Size (|D|):   1484
#   Open set size:       18662
#
#
# === Best Solution Updated at Iteration 640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       40250.037
#   Best Cost (y):       7296.3151
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      40250.037
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5868→ cube 2.9068
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1431→ cube 1.0757
#   Efficiency z (srs):  16.552 → 0.191 → 72.4804
#   Efficiency y (srs):  4.72 → 1.262 → 12.1713
#   Alpha:               0.8667666809766812
#   Num changes:         2
#   Design Depth:        693
#   Design Size (|D|):   1486
#   Open set size:       18667
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       39848.876
#   Best Cost (y):       7293.2435
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      39848.876
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.5927→ cube 2.936
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1436→ cube 1.0761
#   Efficiency z (srs):  16.552 → 0.191 → 73.2101
#   Efficiency y (srs):  4.72 → 1.262 → 12.1764
#   Alpha:               0.7522858860615778
#   Num changes:         3
#   Design Depth:        708
#   Design Size (|D|):   1516
#   Open set size:       18964
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 700 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38948.552
#   Best Cost (y):       7322.0031
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38948.552
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6064→ cube 3.0039
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1391→ cube 1.0719
#   Efficiency z (srs):  16.552 → 0.191 → 74.9024
#   Efficiency y (srs):  4.72 → 1.262 → 12.1286
#   Alpha:               0.8112786715823639
#   Num changes:         2
#   Design Depth:        755
#   Design Size (|D|):   1610
#   Open set size:       20416
#
#
# === Best Solution Updated at Iteration 700 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38833.578
#   Best Cost (y):       7323.1042
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38833.578
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6082→ cube 3.0128
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1389→ cube 1.0717
#   Efficiency z (srs):  16.552 → 0.191 → 75.1242
#   Efficiency y (srs):  4.72 → 1.262 → 12.1268
#   Alpha:               0.8983036287868991
#   Num changes:         2
#   Design Depth:        755
#   Design Size (|D|):   1610
#   Open set size:       20421
#
# Progress: 14.4%
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38394.61
#   Best Cost (y):       7365.4002
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38394.61
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6152→ cube 3.0472
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1324→ cube 1.0656
#   Efficiency z (srs):  16.552 → 0.191 → 75.9831
#   Efficiency y (srs):  4.72 → 1.262 → 12.0571
#   Alpha:               0.8819372971816447
#   Num changes:         2
#   Design Depth:        778
#   Design Size (|D|):   1656
#   Open set size:       20993
#
#
# === Best Solution Updated at Iteration 720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38371.224
#   Best Cost (y):       7336.7371
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38371.224
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6156→ cube 3.0491
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1368→ cube 1.0698
#   Efficiency z (srs):  16.552 → 0.191 → 76.0294
#   Efficiency y (srs):  4.72 → 1.262 → 12.1042
#   Alpha:               0.7738275583142941
#   Num changes:         1
#   Design Depth:        777
#   Design Size (|D|):   1654
#   Open set size:       21005
#
# Progress: 14.6%
# === Best Solution Updated at Iteration 730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38204.793
#   Best Cost (y):       7315.209
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38204.793
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6182→ cube 3.0624
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1401→ cube 1.0729
#   Efficiency z (srs):  16.552 → 0.191 → 76.3606
#   Efficiency y (srs):  4.72 → 1.262 → 12.1398
#   Alpha:               0.8932100998565999
#   Num changes:         1
#   Design Depth:        789
#   Design Size (|D|):   1678
#   Open set size:       21280
#
#
# === Best Solution Updated at Iteration 730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38204.714
#   Best Cost (y):       7312.5291
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38204.714
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6182→ cube 3.0624
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1405→ cube 1.0733
#   Efficiency z (srs):  16.552 → 0.191 → 76.3607
#   Efficiency y (srs):  4.72 → 1.262 → 12.1443
#   Alpha:               0.8630428086084706
#   Num changes:         1
#   Design Depth:        789
#   Design Size (|D|):   1678
#   Open set size:       21296
#
# Progress: 15.2%
# === Best Solution Updated at Iteration 760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       38111.594
#   Best Cost (y):       7314.9556
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      38111.594
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6197→ cube 3.0699
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1402→ cube 1.0729
#   Efficiency z (srs):  16.552 → 0.191 → 76.5473
#   Efficiency y (srs):  4.72 → 1.262 → 12.1403
#   Alpha:               0.8810726072015069
#   Num changes:         2
#   Design Depth:        812
#   Design Size (|D|):   1724
#   Open set size:       22141
#
# Progress: 15.6%
# === Best Solution Updated at Iteration 780 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       37919.498
#   Best Cost (y):       7321.171
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      37919.498
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6229→ cube 3.0854
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1392→ cube 1.072
#   Efficiency z (srs):  16.552 → 0.191 → 76.9351
#   Efficiency y (srs):  4.72 → 1.262 → 12.13
#   Alpha:               0.7650921668284917
#   Num changes:         1
#   Design Depth:        829
#   Design Size (|D|):   1758
#   Open set size:       22732
#
# Progress: 17.2%
# === Best Solution Updated at Iteration 860 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       37111.493
#   Best Cost (y):       7350.5298
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      37111.493
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6365→ cube 3.1526
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1347→ cube 1.0677
#   Efficiency z (srs):  16.552 → 0.191 → 78.6102
#   Efficiency y (srs):  4.72 → 1.262 → 12.0815
#   Alpha:               0.838440141558126
#   Num changes:         2
#   Design Depth:        892
#   Design Size (|D|):   1884
#   Open set size:       25044
#
# Progress: 17.4%
# === Best Solution Updated at Iteration 870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       37074.728
#   Best Cost (y):       7328.4266
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      37074.728
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6371→ cube 3.1557
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1381→ cube 1.071
#   Efficiency z (srs):  16.552 → 0.191 → 78.6881
#   Efficiency y (srs):  4.72 → 1.262 → 12.1179
#   Alpha:               0.762052699461815
#   Num changes:         1
#   Design Depth:        900
#   Design Size (|D|):   1900
#   Open set size:       25334
#
#
# === Best Solution Updated at Iteration 870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       37069.881
#   Best Cost (y):       7302.6582
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      37069.881
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6372→ cube 3.1561
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1421→ cube 1.0747
#   Efficiency z (srs):  16.552 → 0.191 → 78.6984
#   Efficiency y (srs):  4.72 → 1.262 → 12.1607
#   Alpha:               0.8697058991751848
#   Num changes:         1
#   Design Depth:        900
#   Design Size (|D|):   1900
#   Open set size:       25347
#
#
# === Best Solution Updated at Iteration 870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       37069.135
#   Best Cost (y):       7293.7646
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      37069.135
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6372→ cube 3.1562
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1435→ cube 1.0761
#   Efficiency z (srs):  16.552 → 0.191 → 78.7
#   Efficiency y (srs):  4.72 → 1.262 → 12.1755
#   Alpha:               0.8553502023723762
#   Num changes:         1
#   Design Depth:        900
#   Design Size (|D|):   1900
#   Open set size:       25355
#
# Progress: 18.2%
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       36489.874
#   Best Cost (y):       7375.5098
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      36489.874
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6473→ cube 3.2063
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1308→ cube 1.0641
#   Efficiency z (srs):  16.552 → 0.191 → 79.9493
#   Efficiency y (srs):  4.72 → 1.262 → 12.0406
#   Alpha:               0.7165723560587682
#   Num changes:         1
#   Design Depth:        930
#   Design Size (|D|):   1960
#   Open set size:       26493
#
#
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       36470.404
#   Best Cost (y):       7375.5238
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      36470.404
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.6476→ cube 3.208
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.1308→ cube 1.0641
#   Efficiency z (srs):  16.552 → 0.191 → 79.992
#   Efficiency y (srs):  4.72 → 1.262 → 12.0406
#   Alpha:               0.7866420690268723
#   Num changes:         2
#   Design Depth:        931
#   Design Size (|D|):   1962
#   Open set size:       26496
#
#
# ...
#   rho (p, y):          0.926
#   Criteria Value:      24133.995
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9787→ cube 4.8478
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0966→ cube 1.0319
#   Efficiency z (srs):  16.552 → 0.191 → 120.8809
#   Efficiency y (srs):  4.72 → 1.262 → 11.6763
#   Alpha:               0.8282982278768576
#   Num changes:         1
#   Design Depth:        3674
#   Design Size (|D|):   7448
#   Open set size:       134371
#
# Progress: 92.8%
# === Best Solution Updated at Iteration 4640 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       24129.347
#   Best Cost (y):       7618.6811
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      24129.347
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9789→ cube 4.8488
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0947→ cube 1.0302
#   Efficiency z (srs):  16.552 → 0.191 → 120.9042
#   Efficiency y (srs):  4.72 → 1.262 → 11.6563
#   Alpha:               0.8255994440187379
#   Num changes:         1
#   Design Depth:        3682
#   Design Size (|D|):   7464
#   Open set size:       134673
#
# Progress: 93.2%
# === Best Solution Updated at Iteration 4660 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       24018.693
#   Best Cost (y):       7626.8417
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      24018.693
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9834→ cube 4.8711
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0935→ cube 1.0291
#   Efficiency z (srs):  16.552 → 0.191 → 121.4612
#   Efficiency y (srs):  4.72 → 1.262 → 11.6438
#   Alpha:               0.7487198047496838
#   Num changes:         1
#   Design Depth:        3707
#   Design Size (|D|):   7514
#   Open set size:       135251
#
#
# === Best Solution Updated at Iteration 4660 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       24018.574
#   Best Cost (y):       7626.4234
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      24018.574
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9834→ cube 4.8711
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0936→ cube 1.0291
#   Efficiency z (srs):  16.552 → 0.191 → 121.4618
#   Efficiency y (srs):  4.72 → 1.262 → 11.6445
#   Alpha:               0.7070716856716136
#   Num changes:         1
#   Design Depth:        3707
#   Design Size (|D|):   7514
#   Open set size:       135257
#
#
# === Best Solution Updated at Iteration 4660 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       24017.209
#   Best Cost (y):       7625.8505
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      24017.209
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9834→ cube 4.8714
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0937→ cube 1.0292
#   Efficiency z (srs):  16.552 → 0.191 → 121.4687
#   Efficiency y (srs):  4.72 → 1.262 → 11.6453
#   Alpha:               0.883334155218401
#   Num changes:         2
#   Design Depth:        3708
#   Design Size (|D|):   7516
#   Open set size:       135260
#
# Progress: 94.4%
# === Best Solution Updated at Iteration 4720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       24008.242
#   Best Cost (y):       7620.994
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      24008.242
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9838→ cube 4.8732
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0944→ cube 1.0299
#   Efficiency z (srs):  16.552 → 0.191 → 121.5141
#   Efficiency y (srs):  4.72 → 1.262 → 11.6527
#   Alpha:               0.770884569616928
#   Num changes:         1
#   Design Depth:        3730
#   Design Size (|D|):   7560
#   Open set size:       136985
#
#
# === Best Solution Updated at Iteration 4720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       24006.874
#   Best Cost (y):       7622.9739
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      24006.874
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9839→ cube 4.8735
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0941→ cube 1.0296
#   Efficiency z (srs):  16.552 → 0.191 → 121.521
#   Efficiency y (srs):  4.72 → 1.262 → 11.6497
#   Alpha:               0.8124071239041751
#   Num changes:         1
#   Design Depth:        3730
#   Design Size (|D|):   7560
#   Open set size:       137005
#
# Progress: 96.0%
# === Best Solution Updated at Iteration 4800 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23957.733
#   Best Cost (y):       7637.6085
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23957.733
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9859→ cube 4.8835
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.092→ cube 1.0276
#   Efficiency z (srs):  16.552 → 0.191 → 121.7703
#   Efficiency y (srs):  4.72 → 1.262 → 11.6274
#   Alpha:               0.7380881921075665
#   Num changes:         3
#   Design Depth:        3778
#   Design Size (|D|):   7656
#   Open set size:       139310
#
# Progress: 96.2%
# === Best Solution Updated at Iteration 4810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23941.683
#   Best Cost (y):       7625.8542
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23941.683
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9865→ cube 4.8868
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0937→ cube 1.0292
#   Efficiency z (srs):  16.552 → 0.191 → 121.8519
#   Efficiency y (srs):  4.72 → 1.262 → 11.6453
#   Alpha:               0.8924060648117067
#   Num changes:         1
#   Design Depth:        3785
#   Design Size (|D|):   7670
#   Open set size:       139594
#
#
# === Best Solution Updated at Iteration 4810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23940.283
#   Best Cost (y):       7629.3179
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23940.283
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9866→ cube 4.8871
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0932→ cube 1.0287
#   Efficiency z (srs):  16.552 → 0.191 → 121.8591
#   Efficiency y (srs):  4.72 → 1.262 → 11.64
#   Alpha:               0.8986779213189096
#   Num changes:         1
#   Design Depth:        3785
#   Design Size (|D|):   7670
#   Open set size:       139603
#
#
# === Best Solution Updated at Iteration 4810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23939.819
#   Best Cost (y):       7629.6625
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23939.819
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9866→ cube 4.8872
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0931→ cube 1.0287
#   Efficiency z (srs):  16.552 → 0.191 → 121.8614
#   Efficiency y (srs):  4.72 → 1.262 → 11.6395
#   Alpha:               0.750187542319857
#   Num changes:         2
#   Design Depth:        3786
#   Design Size (|D|):   7672
#   Open set size:       139608
#
# Progress: 96.8%
# === Best Solution Updated at Iteration 4840 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23920.987
#   Best Cost (y):       7633.3441
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23920.987
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9874→ cube 4.891
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0926→ cube 1.0282
#   Efficiency z (srs):  16.552 → 0.191 → 121.9573
#   Efficiency y (srs):  4.72 → 1.262 → 11.6339
#   Alpha:               0.78610884476971
#   Num changes:         1
#   Design Depth:        3797
#   Design Size (|D|):   7694
#   Open set size:       140460
#
#
# === Best Solution Updated at Iteration 4840 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23920.69
#   Best Cost (y):       7632.9966
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23920.69
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9874→ cube 4.8911
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0927→ cube 1.0282
#   Efficiency z (srs):  16.552 → 0.191 → 121.9589
#   Efficiency y (srs):  4.72 → 1.262 → 11.6344
#   Alpha:               0.7479154635515536
#   Num changes:         1
#   Design Depth:        3797
#   Design Size (|D|):   7694
#   Open set size:       140481
#
# Progress: 97.0%
# === Best Solution Updated at Iteration 4850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23919.802
#   Best Cost (y):       7628.6676
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23919.802
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9875→ cube 4.8913
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0933→ cube 1.0288
#   Efficiency z (srs):  16.552 → 0.191 → 121.9634
#   Efficiency y (srs):  4.72 → 1.262 → 11.641
#   Alpha:               0.7095542296011547
#   Num changes:         1
#   Design Depth:        3804
#   Design Size (|D|):   7708
#   Open set size:       140750
#
# Progress: 97.6%
# === Best Solution Updated at Iteration 4880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23879.847
#   Best Cost (y):       7628.2756
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23879.847
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9891→ cube 4.8994
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0933→ cube 1.0289
#   Efficiency z (srs):  16.552 → 0.191 → 122.1675
#   Efficiency y (srs):  4.72 → 1.262 → 11.6416
#   Alpha:               0.7712383493406214
#   Num changes:         2
#   Design Depth:        3825
#   Design Size (|D|):   7750
#   Open set size:       141621
#
# Progress: 97.8%
# === Best Solution Updated at Iteration 4890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23858.386
#   Best Cost (y):       7627.5159
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23858.386
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.99→ cube 4.9038
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0934→ cube 1.029
#   Efficiency z (srs):  16.552 → 0.191 → 122.2774
#   Efficiency y (srs):  4.72 → 1.262 → 11.6428
#   Alpha:               0.8489405056890802
#   Num changes:         1
#   Design Depth:        3836
#   Design Size (|D|):   7772
#   Open set size:       141928
#
#
# === Best Solution Updated at Iteration 4890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23856.862
#   Best Cost (y):       7630.2164
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23856.862
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9901→ cube 4.9042
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0931→ cube 1.0286
#   Efficiency z (srs):  16.552 → 0.191 → 122.2852
#   Efficiency y (srs):  4.72 → 1.262 → 11.6387
#   Alpha:               0.8330622378809871
#   Num changes:         1
#   Design Depth:        3836
#   Design Size (|D|):   7772
#   Open set size:       141930
#
# Progress: 99.2%
# === Best Solution Updated at Iteration 4960 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23820.764
#   Best Cost (y):       7641.7718
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23820.764
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9916→ cube 4.9116
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0914→ cube 1.0271
#   Efficiency z (srs):  16.552 → 0.191 → 122.4705
#   Efficiency y (srs):  4.72 → 1.262 → 11.6211
#   Alpha:               0.8028603430804684
#   Num changes:         1
#   Design Depth:        3860
#   Design Size (|D|):   7820
#   Open set size:       143964
#
# Progress: 99.4%
# === Best Solution Updated at Iteration 4970 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23801.499
#   Best Cost (y):       7634.5991
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23801.499
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9924→ cube 4.9156
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0924→ cube 1.028
#   Efficiency z (srs):  16.552 → 0.191 → 122.5696
#   Efficiency y (srs):  4.72 → 1.262 → 11.632
#   Alpha:               0.729376497992069
#   Num changes:         3
#   Design Depth:        3872
#   Design Size (|D|):   7844
#   Open set size:       144241
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 4999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23770.779
#   Best Cost (y):       7635.7121
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23770.779
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9936→ cube 4.9219
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0923→ cube 1.0279
#   Efficiency z (srs):  16.552 → 0.191 → 122.728
#   Efficiency y (srs):  4.72 → 1.262 → 11.6303
#   Alpha:               0.765858164672455
#   Num changes:         1
#   Design Depth:        3899
#   Design Size (|D|):   7898
#   Open set size:       145072
#
#
# === Best Solution Updated at Iteration 4999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23770.233
#   Best Cost (y):       7633.2102
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23770.233
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9937→ cube 4.922
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0926→ cube 1.0282
#   Efficiency z (srs):  16.552 → 0.191 → 122.7308
#   Efficiency y (srs):  4.72 → 1.262 → 11.6341
#   Alpha:               0.733435307859476
#   Num changes:         2
#   Design Depth:        3900
#   Design Size (|D|):   7900
#   Open set size:       145075
#
#
# === Best Solution Updated at Iteration 4999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       23770.233
#   Best Cost (y):       7633.2102
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.645
#   rho (p, y):          0.926
#   Criteria Value:      23770.233
#   Efficiency z (0→f):  0.134 → 0.191 → dsd 0.9937→ cube 4.922
#   Efficiency y (0→f):  0.443 → 1.262 → dsd 1.0926→ cube 1.0282
#   Efficiency z (srs):  16.552 → 0.191 → 122.7308
#   Efficiency y (srs):  4.72 → 1.262 → 11.6341
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        3900
#   Design Size (|D|):   7900
#   Open set size:       145100
#
# Best criteria value: 23770.233172677225
# Iterations run: 5000
# Best criteria value: 23770.233172677225
# Iterations run: 5000

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
# Out:
# size of init design 100
# size of best design 7900
# 123483.99144738668
# 23770.233172677225
# [100]
# /tmp/ipykernel_280834/683604881.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# sum of inclusions, last ini and original 10.000000049999988 10.000000049999995 10.000000000000007
# 1.0000000049999986
# n =  [10]
# 10043.617183059716 50611.540232179024 10043.617233467989 50611.54048605065
# 10043.617183059716 50611.540232179024 10043.617233467989 50611.54048605065
# var z estimates 23757.426
# var y estimates 7632.706
