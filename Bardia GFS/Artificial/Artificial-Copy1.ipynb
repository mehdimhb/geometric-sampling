# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_7.5_py_8.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_7.5_py_8.5_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.7 0.9
# Generating initial designs:   0%|                      | 0/3000 [00:00<?, ?it/s]
# Initial design 0: method = Original, efficiency z = 0.2154, y=0.5113
# New best at idx=0: method = Original, efficiency z = 0.2154 and efficiency y = 0.5113
# New best at idx=2: method = z/pi, efficiency z = 0.2154 and efficiency y = 0.5113
# Generating initial designs:   0%|              | 6/3000 [00:00<00:54, 54.56it/s]
# New best at idx=3: method = swap, efficiency z = 0.2186 and efficiency y = 0.7745
# New best at idx=5: method = swap, efficiency z = 0.2233 and efficiency y = 0.6101
# New best at idx=6: method = swap, efficiency z = 0.2348 and efficiency y = 0.9834
# New best at idx=7: method = swap, efficiency z = 0.2556 and efficiency y = 0.7065
# Generating initial designs:   1%|▏            | 33/3000 [00:00<00:35, 83.21it/s]
# New best at idx=19: method = swap, efficiency z = 0.2749 and efficiency y = 0.7395
# Generating initial designs:   3%|▍           | 104/3000 [00:01<00:33, 86.21it/s]
# New best at idx=90: method = swap, efficiency z = 0.2827 and efficiency y = 0.8630
# Generating initial designs:  10%|█▏          | 299/3000 [00:04<00:27, 98.21it/s]
# New best at idx=283: method = swap, efficiency z = 0.2956 and efficiency y = 0.8513
# Generating initial designs: 100%|███████████| 3000/3000 [00:50<00:00, 59.93it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       499821.085
#   Best Cost (y):       25308.7424
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      499821.085
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3009→ cube 0.6323
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 0.9138→ cube 0.8474
#   Efficiency z (srs):  5.89 → 0.296 → 8.2259
#   Efficiency y (srs):  1.963 → 0.851 → 3.5089
#   Alpha:               0.8948768499966523
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       103
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       496656.403
#   Best Cost (y):       27205.2105
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      496656.403
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3028→ cube 0.6364
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 0.8501→ cube 0.7884
#   Efficiency z (srs):  5.89 → 0.296 → 8.2783
#   Efficiency y (srs):  1.963 → 0.851 → 3.2643
#   Alpha:               0.7696161980307682
#   Num changes:         2
#   Design Depth:        2
#   Design Size (|D|):   104
#   Open set size:       121
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       493313.487
#   Best Cost (y):       25797.1029
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      493313.487
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3049→ cube 0.6407
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 0.8965→ cube 0.8314
#   Efficiency z (srs):  5.89 → 0.296 → 8.3344
#   Efficiency y (srs):  1.963 → 0.851 → 3.4425
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4
#   Design Size (|D|):   108
#   Open set size:       158
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       454149.926
#   Best Cost (y):       21669.1554
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      454149.926
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3311→ cube 0.6959
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0673→ cube 0.9898
#   Efficiency z (srs):  5.89 → 0.296 → 9.0531
#   Efficiency y (srs):  1.963 → 0.851 → 4.0982
#   Alpha:               0.7247907454509663
#   Num changes:         3
#   Design Depth:        18
#   Design Size (|D|):   136
#   Open set size:       390
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       451615.227
#   Best Cost (y):       21895.6831
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      451615.227
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.333→ cube 0.6998
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0562→ cube 0.9795
#   Efficiency z (srs):  5.89 → 0.296 → 9.1039
#   Efficiency y (srs):  1.963 → 0.851 → 4.0558
#   Alpha:               0.7135561999816161
#   Num changes:         1
#   Design Depth:        16
#   Design Size (|D|):   132
#   Open set size:       396
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       451614.466
#   Best Cost (y):       21740.5786
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      451614.466
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.333→ cube 0.6998
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0638→ cube 0.9865
#   Efficiency z (srs):  5.89 → 0.296 → 9.1039
#   Efficiency y (srs):  1.963 → 0.851 → 4.0848
#   Alpha:               0.8008326011238847
#   Num changes:         1
#   Design Depth:        16
#   Design Size (|D|):   132
#   Open set size:       403
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       450622.164
#   Best Cost (y):       21783.1782
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      450622.164
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3337→ cube 0.7014
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0617→ cube 0.9846
#   Efficiency z (srs):  5.89 → 0.296 → 9.124
#   Efficiency y (srs):  1.963 → 0.851 → 4.0768
#   Alpha:               0.8449457195241149
#   Num changes:         1
#   Design Depth:        16
#   Design Size (|D|):   132
#   Open set size:       413
#
# Progress: 0.4%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       380272.609
#   Best Cost (y):       22009.8271
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      380272.609
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3955→ cube 0.8311
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0507→ cube 0.9745
#   Efficiency z (srs):  5.89 → 0.296 → 10.8119
#   Efficiency y (srs):  1.963 → 0.851 → 4.0348
#   Alpha:               0.7751519722407331
#   Num changes:         2
#   Design Depth:        36
#   Design Size (|D|):   172
#   Open set size:       681
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       378286.747
#   Best Cost (y):       23019.6322
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      378286.747
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.3976→ cube 0.8355
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0047→ cube 0.9317
#   Efficiency z (srs):  5.89 → 0.296 → 10.8687
#   Efficiency y (srs):  1.963 → 0.851 → 3.8578
#   Alpha:               0.8087699111550535
#   Num changes:         3
#   Design Depth:        37
#   Design Size (|D|):   174
#   Open set size:       708
#
# Progress: 0.6%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       339480.984
#   Best Cost (y):       21763.5353
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      339480.984
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.443→ cube 0.931
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0626→ cube 0.9855
#   Efficiency z (srs):  5.89 → 0.296 → 12.111
#   Efficiency y (srs):  1.963 → 0.851 → 4.0805
#   Alpha:               0.7508338629321308
#   Num changes:         2
#   Design Depth:        53
#   Design Size (|D|):   206
#   Open set size:       974
#
#
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       337352.422
#   Best Cost (y):       22538.7033
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      337352.422
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.4458→ cube 0.9369
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0261→ cube 0.9516
#   Efficiency z (srs):  5.89 → 0.296 → 12.1875
#   Efficiency y (srs):  1.963 → 0.851 → 3.9401
#   Alpha:               0.8064077006398238
#   Num changes:         2
#   Design Depth:        53
#   Design Size (|D|):   206
#   Open set size:       999
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       307400.75
#   Best Cost (y):       22986.9202
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      307400.75
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.4892→ cube 1.0282
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0061→ cube 0.933
#   Efficiency z (srs):  5.89 → 0.296 → 13.375
#   Efficiency y (srs):  1.963 → 0.851 → 3.8633
#   Alpha:               0.7126993284964531
#   Num changes:         2
#   Design Depth:        91
#   Design Size (|D|):   282
#   Open set size:       1857
#
# Progress: 1.4%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       283554.279
#   Best Cost (y):       21804.4842
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      283554.279
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.5304→ cube 1.1146
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0606→ cube 0.9836
#   Efficiency z (srs):  5.89 → 0.296 → 14.4998
#   Efficiency y (srs):  1.963 → 0.851 → 4.0728
#   Alpha:               0.7903036860526095
#   Num changes:         3
#   Design Depth:        114
#   Design Size (|D|):   328
#   Open set size:       2131
#
# Progress: 1.6%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       261475.161
#   Best Cost (y):       21454.0259
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      261475.161
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.5752→ cube 1.2087
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.078→ cube 0.9997
#   Efficiency z (srs):  5.89 → 0.296 → 15.7241
#   Efficiency y (srs):  1.963 → 0.851 → 4.1393
#   Alpha:               0.741350140274432
#   Num changes:         3
#   Design Depth:        134
#   Design Size (|D|):   368
#   Open set size:       2444
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       261471.525
#   Best Cost (y):       21346.8442
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      261471.525
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.5752→ cube 1.2088
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0834→ cube 1.0047
#   Efficiency z (srs):  5.89 → 0.296 → 15.7244
#   Efficiency y (srs):  1.963 → 0.851 → 4.1601
#   Alpha:               0.8806748118417812
#   Num changes:         2
#   Design Depth:        133
#   Design Size (|D|):   366
#   Open set size:       2445
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       260317.173
#   Best Cost (y):       21113.2095
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      260317.173
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.5777→ cube 1.2141
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.0954→ cube 1.0158
#   Efficiency z (srs):  5.89 → 0.296 → 15.7941
#   Efficiency y (srs):  1.963 → 0.851 → 4.2062
#   Alpha:               0.7586585582085742
#   Num changes:         1
#   Design Depth:        146
#   Design Size (|D|):   392
#   Open set size:       2729
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       252438.982
#   Best Cost (y):       20117.576
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      252438.982
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.5957→ cube 1.252
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1496→ cube 1.0661
#   Efficiency z (srs):  5.89 → 0.296 → 16.287
#   Efficiency y (srs):  1.963 → 0.851 → 4.4143
#   Alpha:               0.7574208242113615
#   Num changes:         1
#   Design Depth:        165
#   Design Size (|D|):   430
#   Open set size:       3002
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       251513.219
#   Best Cost (y):       20229.6144
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      251513.219
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.5979→ cube 1.2566
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1432→ cube 1.0602
#   Efficiency z (srs):  5.89 → 0.296 → 16.3469
#   Efficiency y (srs):  1.963 → 0.851 → 4.3899
#   Alpha:               0.8671177385340896
#   Num changes:         1
#   Design Depth:        165
#   Design Size (|D|):   430
#   Open set size:       3006
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       248120.525
#   Best Cost (y):       19910.7036
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      248120.525
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6061→ cube 1.2738
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1615→ cube 1.0772
#   Efficiency z (srs):  5.89 → 0.296 → 16.5705
#   Efficiency y (srs):  1.963 → 0.851 → 4.4602
#   Alpha:               0.8748182717463041
#   Num changes:         3
#   Design Depth:        179
#   Design Size (|D|):   458
#   Open set size:       3298
#
# Progress: 2.6%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       242202.815
#   Best Cost (y):       19833.7089
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      242202.815
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6209→ cube 1.3049
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.166→ cube 1.0814
#   Efficiency z (srs):  5.89 → 0.296 → 16.9753
#   Efficiency y (srs):  1.963 → 0.851 → 4.4775
#   Alpha:               0.8341341254393493
#   Num changes:         1
#   Design Depth:        197
#   Design Size (|D|):   494
#   Open set size:       3872
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       242178.475
#   Best Cost (y):       19818.4178
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      242178.475
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.621→ cube 1.3051
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1669→ cube 1.0822
#   Efficiency z (srs):  5.89 → 0.296 → 16.977
#   Efficiency y (srs):  1.963 → 0.851 → 4.481
#   Alpha:               0.8769805415955993
#   Num changes:         1
#   Design Depth:        197
#   Design Size (|D|):   494
#   Open set size:       3893
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       241497.881
#   Best Cost (y):       20131.4988
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      241497.881
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6227→ cube 1.3087
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1488→ cube 1.0654
#   Efficiency z (srs):  5.89 → 0.296 → 17.0249
#   Efficiency y (srs):  1.963 → 0.851 → 4.4113
#   Alpha:               0.7408536204299325
#   Num changes:         3
#   Design Depth:        210
#   Design Size (|D|):   520
#   Open set size:       4168
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       240387.573
#   Best Cost (y):       20020.6804
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      240387.573
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6256→ cube 1.3148
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1551→ cube 1.0713
#   Efficiency z (srs):  5.89 → 0.296 → 17.1035
#   Efficiency y (srs):  1.963 → 0.851 → 4.4357
#   Alpha:               0.8646417329697201
#   Num changes:         1
#   Design Depth:        208
#   Design Size (|D|):   516
#   Open set size:       4177
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       240383.215
#   Best Cost (y):       20184.4654
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      240383.215
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6256→ cube 1.3148
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1458→ cube 1.0626
#   Efficiency z (srs):  5.89 → 0.296 → 17.1038
#   Efficiency y (srs):  1.963 → 0.851 → 4.3997
#   Alpha:               0.8421388066394953
#   Num changes:         1
#   Design Depth:        208
#   Design Size (|D|):   516
#   Open set size:       4184
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       239602.914
#   Best Cost (y):       20113.6931
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      239602.914
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6277→ cube 1.3191
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1498→ cube 1.0663
#   Efficiency z (srs):  5.89 → 0.296 → 17.1595
#   Efficiency y (srs):  1.963 → 0.851 → 4.4152
#   Alpha:               0.8901121084384938
#   Num changes:         1
#   Design Depth:        224
#   Design Size (|D|):   548
#   Open set size:       4768
#
# Progress: 3.6%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       233668.45
#   Best Cost (y):       20169.9106
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      233668.45
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6436→ cube 1.3526
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1466→ cube 1.0633
#   Efficiency z (srs):  5.89 → 0.296 → 17.5953
#   Efficiency y (srs):  1.963 → 0.851 → 4.4029
#   Alpha:               0.7269234206497591
#   Num changes:         2
#   Design Depth:        248
#   Design Size (|D|):   596
#   Open set size:       5326
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       232921.082
#   Best Cost (y):       20398.1627
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      232921.082
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6457→ cube 1.3569
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1338→ cube 1.0514
#   Efficiency z (srs):  5.89 → 0.296 → 17.6518
#   Efficiency y (srs):  1.963 → 0.851 → 4.3536
#   Alpha:               0.7972549646915967
#   Num changes:         3
#   Design Depth:        249
#   Design Size (|D|):   598
#   Open set size:       5349
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       231746.897
#   Best Cost (y):       19967.9613
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      231746.897
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6489→ cube 1.3638
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1582→ cube 1.0741
#   Efficiency z (srs):  5.89 → 0.296 → 17.7412
#   Efficiency y (srs):  1.963 → 0.851 → 4.4474
#   Alpha:               0.8751938696973329
#   Num changes:         2
#   Design Depth:        265
#   Design Size (|D|):   630
#   Open set size:       5638
#
# Progress: 4.4%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       227645.163
#   Best Cost (y):       19779.9166
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      227645.163
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6606→ cube 1.3884
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1692→ cube 1.0843
#   Efficiency z (srs):  5.89 → 0.296 → 18.0609
#   Efficiency y (srs):  1.963 → 0.851 → 4.4897
#   Alpha:               0.7435478161168855
#   Num changes:         1
#   Design Depth:        287
#   Design Size (|D|):   674
#   Open set size:       6487
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       227505.028
#   Best Cost (y):       19765.6685
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      227505.028
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.661→ cube 1.3892
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1701→ cube 1.0851
#   Efficiency z (srs):  5.89 → 0.296 → 18.072
#   Efficiency y (srs):  1.963 → 0.851 → 4.4929
#   Alpha:               0.7861167278090335
#   Num changes:         1
#   Design Depth:        287
#   Design Size (|D|):   674
#   Open set size:       6493
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       227271.849
#   Best Cost (y):       19787.8246
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      227271.849
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6617→ cube 1.3906
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1687→ cube 1.0839
#   Efficiency z (srs):  5.89 → 0.296 → 18.0905
#   Efficiency y (srs):  1.963 → 0.851 → 4.4879
#   Alpha:               0.8112320649754201
#   Num changes:         2
#   Design Depth:        288
#   Design Size (|D|):   676
#   Open set size:       6495
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       227146.193
#   Best Cost (y):       19788.7314
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      227146.193
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6621→ cube 1.3914
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1687→ cube 1.0838
#   Efficiency z (srs):  5.89 → 0.296 → 18.1006
#   Efficiency y (srs):  1.963 → 0.851 → 4.4877
#   Alpha:               0.7401385835965416
#   Num changes:         2
#   Design Depth:        288
#   Design Size (|D|):   676
#   Open set size:       6502
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       218287.012
#   Best Cost (y):       19496.5434
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      218287.012
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.6889→ cube 1.4479
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1862→ cube 1.1001
#   Efficiency z (srs):  5.89 → 0.296 → 18.8352
#   Efficiency y (srs):  1.963 → 0.851 → 4.5549
#   Alpha:               0.776858688726555
#   Num changes:         3
#   Design Depth:        336
#   Design Size (|D|):   772
#   Open set size:       7359
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       218276.952
#   Best Cost (y):       19561.1825
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      218276.952
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.689→ cube 1.448
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1823→ cube 1.0964
#   Efficiency z (srs):  5.89 → 0.296 → 18.836
#   Efficiency y (srs):  1.963 → 0.851 → 4.5399
#   Alpha:               0.819276582746769
#   Num changes:         1
#   Design Depth:        334
#   Design Size (|D|):   768
#   Open set size:       7371
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       214823.354
#   Best Cost (y):       19566.8273
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      214823.354
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7001→ cube 1.4712
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1819→ cube 1.0961
#   Efficiency z (srs):  5.89 → 0.296 → 19.1388
#   Efficiency y (srs):  1.963 → 0.851 → 4.5386
#   Alpha:               0.8665918885619394
#   Num changes:         1
#   Design Depth:        348
#   Design Size (|D|):   796
#   Open set size:       7641
#
#
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       214810.479
#   Best Cost (y):       19541.4615
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      214810.479
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7001→ cube 1.4713
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1835→ cube 1.0975
#   Efficiency z (srs):  5.89 → 0.296 → 19.14
#   Efficiency y (srs):  1.963 → 0.851 → 4.5445
#   Alpha:               0.723427380906886
#   Num changes:         1
#   Design Depth:        348
#   Design Size (|D|):   796
#   Open set size:       7647
#
# Progress: 5.4%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       211267.661
#   Best Cost (y):       19730.2465
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      211267.661
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7118→ cube 1.496
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1722→ cube 1.087
#   Efficiency z (srs):  5.89 → 0.296 → 19.461
#   Efficiency y (srs):  1.963 → 0.851 → 4.501
#   Alpha:               0.8767115410822
#   Num changes:         1
#   Design Depth:        360
#   Design Size (|D|):   820
#   Open set size:       7930
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       211122.677
#   Best Cost (y):       19664.4305
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      211122.677
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7123→ cube 1.497
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1761→ cube 1.0907
#   Efficiency z (srs):  5.89 → 0.296 → 19.4743
#   Efficiency y (srs):  1.963 → 0.851 → 4.516
#   Alpha:               0.7414457547067186
#   Num changes:         1
#   Design Depth:        360
#   Design Size (|D|):   820
#   Open set size:       7932
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       210965.624
#   Best Cost (y):       19676.5896
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      210965.624
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7129→ cube 1.4981
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1753→ cube 1.09
#   Efficiency z (srs):  5.89 → 0.296 → 19.4888
#   Efficiency y (srs):  1.963 → 0.851 → 4.5133
#   Alpha:               0.8537003646907062
#   Num changes:         1
#   Design Depth:        360
#   Design Size (|D|):   820
#   Open set size:       7936
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       210503.915
#   Best Cost (y):       19695.3154
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      210503.915
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7144→ cube 1.5014
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1742→ cube 1.089
#   Efficiency z (srs):  5.89 → 0.296 → 19.5316
#   Efficiency y (srs):  1.963 → 0.851 → 4.509
#   Alpha:               0.8234442853065387
#   Num changes:         2
#   Design Depth:        361
#   Design Size (|D|):   822
#   Open set size:       7953
#
# Progress: 5.6%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       207963.517
#   Best Cost (y):       20002.3164
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      207963.517
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7231→ cube 1.5198
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1562→ cube 1.0723
#   Efficiency z (srs):  5.89 → 0.296 → 19.7702
#   Efficiency y (srs):  1.963 → 0.851 → 4.4398
#   Alpha:               0.8588615367620249
#   Num changes:         1
#   Design Depth:        375
#   Design Size (|D|):   850
#   Open set size:       8239
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       195711.842
#   Best Cost (y):       19841.8348
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      195711.842
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7684→ cube 1.6149
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1656→ cube 1.0809
#   Efficiency z (srs):  5.89 → 0.296 → 21.0078
#   Efficiency y (srs):  1.963 → 0.851 → 4.4757
#   Alpha:               0.7389142077648297
#   Num changes:         1
#   Design Depth:        411
#   Design Size (|D|):   922
#   Open set size:       8804
#
#
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       195480.402
#   Best Cost (y):       19836.643
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      195480.402
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7693→ cube 1.6168
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1659→ cube 1.0812
#   Efficiency z (srs):  5.89 → 0.296 → 21.0327
#   Efficiency y (srs):  1.963 → 0.851 → 4.4768
#   Alpha:               0.8311942455641672
#   Num changes:         2
#   Design Depth:        412
#   Design Size (|D|):   924
#   Open set size:       8813
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       194679.868
#   Best Cost (y):       19998.5069
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      194679.868
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7725→ cube 1.6235
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1564→ cube 1.0725
#   Efficiency z (srs):  5.89 → 0.296 → 21.1191
#   Efficiency y (srs):  1.963 → 0.851 → 4.4406
#   Alpha:               0.7558678864405162
#   Num changes:         1
#   Design Depth:        422
#   Design Size (|D|):   944
#   Open set size:       9110
#
# Progress: 6.4%
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       192989.626
#   Best Cost (y):       19937.3243
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      192989.626
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7793→ cube 1.6377
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.16→ cube 1.0758
#   Efficiency z (srs):  5.89 → 0.296 → 21.3041
#   Efficiency y (srs):  1.963 → 0.851 → 4.4542
#   Alpha:               0.8750402188201153
#   Num changes:         1
#   Design Depth:        436
#   Design Size (|D|):   972
#   Open set size:       9393
#
#
# === Best Solution Updated at Iteration 320 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       192988.802
#   Best Cost (y):       19939.9939
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      192988.802
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7793→ cube 1.6377
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1598→ cube 1.0756
#   Efficiency z (srs):  5.89 → 0.296 → 21.3042
#   Efficiency y (srs):  1.963 → 0.851 → 4.4536
#   Alpha:               0.8465018577463268
#   Num changes:         1
#   Design Depth:        436
#   Design Size (|D|):   972
#   Open set size:       9408
#
# Progress: 6.6%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       190527.773
#   Best Cost (y):       19922.011
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      190527.773
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.7893→ cube 1.6588
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1609→ cube 1.0766
#   Efficiency z (srs):  5.89 → 0.296 → 21.5794
#   Efficiency y (srs):  1.963 → 0.851 → 4.4577
#   Alpha:               0.853367712823559
#   Num changes:         2
#   Design Depth:        449
#   Design Size (|D|):   998
#   Open set size:       9676
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       185532.618
#   Best Cost (y):       19756.8033
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      185532.618
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8106→ cube 1.7035
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1706→ cube 1.0856
#   Efficiency z (srs):  5.89 → 0.296 → 22.1604
#   Efficiency y (srs):  1.963 → 0.851 → 4.4949
#   Alpha:               0.8774066360914022
#   Num changes:         1
#   Design Depth:        479
#   Design Size (|D|):   1058
#   Open set size:       10257
#
#
# === Best Solution Updated at Iteration 350 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       184975.239
#   Best Cost (y):       19789.1483
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      184975.239
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.813→ cube 1.7086
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1687→ cube 1.0838
#   Efficiency z (srs):  5.89 → 0.296 → 22.2271
#   Efficiency y (srs):  1.963 → 0.851 → 4.4876
#   Alpha:               0.7309907649592932
#   Num changes:         3
#   Design Depth:        481
#   Design Size (|D|):   1062
#   Open set size:       10265
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       181749.691
#   Best Cost (y):       19549.3503
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      181749.691
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8274→ cube 1.739
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.183→ cube 1.0971
#   Efficiency z (srs):  5.89 → 0.296 → 22.6216
#   Efficiency y (srs):  1.963 → 0.851 → 4.5426
#   Alpha:               0.7065653723574046
#   Num changes:         3
#   Design Depth:        499
#   Design Size (|D|):   1098
#   Open set size:       10566
#
# Progress: 7.6%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       180234.477
#   Best Cost (y):       19744.4276
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      180234.477
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8344→ cube 1.7536
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1713→ cube 1.0863
#   Efficiency z (srs):  5.89 → 0.296 → 22.8118
#   Efficiency y (srs):  1.963 → 0.851 → 4.4978
#   Alpha:               0.7798506627416333
#   Num changes:         2
#   Design Depth:        521
#   Design Size (|D|):   1142
#   Open set size:       11135
#
# Progress: 8.2%
# === Best Solution Updated at Iteration 410 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       176714.39
#   Best Cost (y):       19450.4222
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      176714.39
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.851→ cube 1.7885
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.189→ cube 1.1027
#   Efficiency z (srs):  5.89 → 0.296 → 23.2662
#   Efficiency y (srs):  1.963 → 0.851 → 4.5657
#   Alpha:               0.8194192794273376
#   Num changes:         2
#   Design Depth:        556
#   Design Size (|D|):   1212
#   Open set size:       12006
#
# Progress: 8.6%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       172794.653
#   Best Cost (y):       19523.7102
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      172794.653
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8703→ cube 1.8291
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1846→ cube 1.0985
#   Efficiency z (srs):  5.89 → 0.296 → 23.794
#   Efficiency y (srs):  1.963 → 0.851 → 4.5486
#   Alpha:               0.7637658755140269
#   Num changes:         2
#   Design Depth:        592
#   Design Size (|D|):   1284
#   Open set size:       12586
#
# Progress: 8.8%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       169925.267
#   Best Cost (y):       19410.7924
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      169925.267
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.885→ cube 1.86
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1914→ cube 1.1049
#   Efficiency z (srs):  5.89 → 0.296 → 24.1958
#   Efficiency y (srs):  1.963 → 0.851 → 4.5751
#   Alpha:               0.812743297135218
#   Num changes:         1
#   Design Depth:        610
#   Design Size (|D|):   1320
#   Open set size:       12861
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       169902.358
#   Best Cost (y):       19414.9207
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      169902.358
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8851→ cube 1.8602
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1912→ cube 1.1047
#   Efficiency z (srs):  5.89 → 0.296 → 24.199
#   Efficiency y (srs):  1.963 → 0.851 → 4.5741
#   Alpha:               0.8537245383365447
#   Num changes:         1
#   Design Depth:        610
#   Design Size (|D|):   1320
#   Open set size:       12873
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       169896.449
#   Best Cost (y):       19412.456
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      169896.449
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8852→ cube 1.8603
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1913→ cube 1.1048
#   Efficiency z (srs):  5.89 → 0.296 → 24.1999
#   Efficiency y (srs):  1.963 → 0.851 → 4.5747
#   Alpha:               0.8985459070658883
#   Num changes:         1
#   Design Depth:        610
#   Design Size (|D|):   1320
#   Open set size:       12878
#
#
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       169838.575
#   Best Cost (y):       19465.2085
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      169838.575
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8855→ cube 1.8609
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1881→ cube 1.1018
#   Efficiency z (srs):  5.89 → 0.296 → 24.2081
#   Efficiency y (srs):  1.963 → 0.851 → 4.5623
#   Alpha:               0.8397219033981911
#   Num changes:         2
#   Design Depth:        611
#   Design Size (|D|):   1322
#   Open set size:       12883
#
# Progress: 9.4%
# === Best Solution Updated at Iteration 470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       168370.899
#   Best Cost (y):       19277.271
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      168370.899
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.8932→ cube 1.8771
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1997→ cube 1.1126
#   Efficiency z (srs):  5.89 → 0.296 → 24.4191
#   Efficiency y (srs):  1.963 → 0.851 → 4.6067
#   Alpha:               0.767248735171287
#   Num changes:         2
#   Design Depth:        633
#   Design Size (|D|):   1366
#   Open set size:       13759
#
# Progress: 10.0%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       166084.5
#   Best Cost (y):       19060.717
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      166084.5
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.9055→ cube 1.903
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2133→ cube 1.1252
#   Efficiency z (srs):  5.89 → 0.296 → 24.7553
#   Efficiency y (srs):  1.963 → 0.851 → 4.6591
#   Alpha:               0.7268560326397849
#   Num changes:         3
#   Design Depth:        678
#   Design Size (|D|):   1456
#   Open set size:       14605
#
#
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       165950.268
#   Best Cost (y):       19053.1353
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      165950.268
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.9062→ cube 1.9045
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2138→ cube 1.1257
#   Efficiency z (srs):  5.89 → 0.296 → 24.7753
#   Efficiency y (srs):  1.963 → 0.851 → 4.6609
#   Alpha:               0.8071565456521697
#   Num changes:         2
#   Design Depth:        677
#   Design Size (|D|):   1454
#   Open set size:       14623
#
# Progress: 10.2%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       165217.182
#   Best Cost (y):       18982.2965
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      165217.182
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.9102→ cube 1.913
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2183→ cube 1.1299
#   Efficiency z (srs):  5.89 → 0.296 → 24.8853
#   Efficiency y (srs):  1.963 → 0.851 → 4.6783
#   Alpha:               0.8335160310885927
#   Num changes:         1
#   Design Depth:        691
#   Design Size (|D|):   1482
#   Open set size:       14900
#
# Progress: 11.4%
# === Best Solution Updated at Iteration 570 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       160933.666
#   Best Cost (y):       18952.8308
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      160933.666
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.9345→ cube 1.9639
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2202→ cube 1.1316
#   Efficiency z (srs):  5.89 → 0.296 → 25.5476
#   Efficiency y (srs):  1.963 → 0.851 → 4.6856
#   Alpha:               0.8318399215708235
#   Num changes:         1
#   Design Depth:        733
#   Design Size (|D|):   1566
#   Open set size:       16635
#
# Progress: 11.8%
# === Best Solution Updated at Iteration 590 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       159603.403
#   Best Cost (y):       18938.6719
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      159603.403
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.9423→ cube 1.9803
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2211→ cube 1.1325
#   Efficiency z (srs):  5.89 → 0.296 → 25.7605
#   Efficiency y (srs):  1.963 → 0.851 → 4.6891
#   Alpha:               0.7972090774121328
#   Num changes:         1
#   Design Depth:        754
#   Design Size (|D|):   1608
#   Open set size:       17220
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       158640.917
#   Best Cost (y):       18884.756
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      158640.917
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 0.948→ cube 1.9923
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2246→ cube 1.1357
#   Efficiency z (srs):  5.89 → 0.296 → 25.9168
#   Efficiency y (srs):  1.963 → 0.851 → 4.7025
#   Alpha:               0.8130952029388788
#   Num changes:         3
#   Design Depth:        770
#   Design Size (|D|):   1640
#   Open set size:       17501
#
# Progress: 12.2%
# === Best Solution Updated at Iteration 610 ===
# ...
#   Efficiency z (srs):  5.89 → 0.296 → 28.074
#   Efficiency y (srs):  1.963 → 0.851 → 4.6336
#   Alpha:               0.7838328009557529
#   Num changes:         2
#   Design Depth:        1020
#   Design Size (|D|):   2140
#   Open set size:       23590
#
#
# === Best Solution Updated at Iteration 810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       146413.969
#   Best Cost (y):       19224.1379
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      146413.969
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0271→ cube 2.1586
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.203→ cube 1.1157
#   Efficiency z (srs):  5.89 → 0.296 → 28.0811
#   Efficiency y (srs):  1.963 → 0.851 → 4.6195
#   Alpha:               0.724948250430293
#   Num changes:         3
#   Design Depth:        1021
#   Design Size (|D|):   2142
#   Open set size:       23596
#
#
# === Best Solution Updated at Iteration 810 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       146406.338
#   Best Cost (y):       19197.2803
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      146406.338
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0272→ cube 2.1588
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2047→ cube 1.1172
#   Efficiency z (srs):  5.89 → 0.296 → 28.0826
#   Efficiency y (srs):  1.963 → 0.851 → 4.6259
#   Alpha:               0.8149751914219543
#   Num changes:         2
#   Design Depth:        1020
#   Design Size (|D|):   2140
#   Open set size:       23598
#
# Progress: 16.6%
# === Best Solution Updated at Iteration 830 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       145844.429
#   Best Cost (y):       19129.8743
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      145844.429
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0312→ cube 2.1671
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2089→ cube 1.1212
#   Efficiency z (srs):  5.89 → 0.296 → 28.1908
#   Efficiency y (srs):  1.963 → 0.851 → 4.6422
#   Alpha:               0.8692628002170338
#   Num changes:         1
#   Design Depth:        1039
#   Design Size (|D|):   2178
#   Open set size:       24175
#
# Progress: 16.8%
# === Best Solution Updated at Iteration 840 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       145209.97
#   Best Cost (y):       19234.298
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      145209.97
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0357→ cube 2.1765
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2024→ cube 1.1151
#   Efficiency z (srs):  5.89 → 0.296 → 28.314
#   Efficiency y (srs):  1.963 → 0.851 → 4.617
#   Alpha:               0.8225347276648541
#   Num changes:         1
#   Design Depth:        1054
#   Design Size (|D|):   2208
#   Open set size:       24471
#
# Progress: 17.0%
# === Best Solution Updated at Iteration 850 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       144665.11
#   Best Cost (y):       19283.1435
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      144665.11
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0396→ cube 2.1847
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1993→ cube 1.1122
#   Efficiency z (srs):  5.89 → 0.296 → 28.4206
#   Efficiency y (srs):  1.963 → 0.851 → 4.6053
#   Alpha:               0.8780456934172689
#   Num changes:         1
#   Design Depth:        1070
#   Design Size (|D|):   2240
#   Open set size:       24751
#
# Progress: 17.2%
# === Best Solution Updated at Iteration 860 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       144620.999
#   Best Cost (y):       19336.1422
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      144620.999
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0399→ cube 2.1854
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.196→ cube 1.1092
#   Efficiency z (srs):  5.89 → 0.296 → 28.4293
#   Efficiency y (srs):  1.963 → 0.851 → 4.5927
#   Alpha:               0.8407803739553766
#   Num changes:         1
#   Design Depth:        1077
#   Design Size (|D|):   2254
#   Open set size:       25053
#
# Progress: 17.4%
# === Best Solution Updated at Iteration 870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       144009.376
#   Best Cost (y):       19357.6896
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      144009.376
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0443→ cube 2.1947
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1947→ cube 1.108
#   Efficiency z (srs):  5.89 → 0.296 → 28.55
#   Efficiency y (srs):  1.963 → 0.851 → 4.5876
#   Alpha:               0.8941804767695172
#   Num changes:         1
#   Design Depth:        1092
#   Design Size (|D|):   2284
#   Open set size:       25357
#
# Progress: 17.6%
# === Best Solution Updated at Iteration 880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       142992.557
#   Best Cost (y):       19395.3985
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      142992.557
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0517→ cube 2.2103
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1924→ cube 1.1058
#   Efficiency z (srs):  5.89 → 0.296 → 28.753
#   Efficiency y (srs):  1.963 → 0.851 → 4.5787
#   Alpha:               0.7572135292218222
#   Num changes:         1
#   Design Depth:        1109
#   Design Size (|D|):   2318
#   Open set size:       25632
#
#
# === Best Solution Updated at Iteration 880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       142936.473
#   Best Cost (y):       19429.0988
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      142936.473
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0521→ cube 2.2112
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1903→ cube 1.1039
#   Efficiency z (srs):  5.89 → 0.296 → 28.7643
#   Efficiency y (srs):  1.963 → 0.851 → 4.5707
#   Alpha:               0.8214402121252113
#   Num changes:         2
#   Design Depth:        1110
#   Design Size (|D|):   2320
#   Open set size:       25634
#
#
# === Best Solution Updated at Iteration 880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       142928.134
#   Best Cost (y):       19389.0639
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      142928.134
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0522→ cube 2.2113
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.1928→ cube 1.1062
#   Efficiency z (srs):  5.89 → 0.296 → 28.766
#   Efficiency y (srs):  1.963 → 0.851 → 4.5802
#   Alpha:               0.8415692591291588
#   Num changes:         2
#   Design Depth:        1110
#   Design Size (|D|):   2320
#   Open set size:       25640
#
# Progress: 17.8%
# === Best Solution Updated at Iteration 890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       142393.878
#   Best Cost (y):       19263.5989
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      142393.878
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0561→ cube 2.2196
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2005→ cube 1.1134
#   Efficiency z (srs):  5.89 → 0.296 → 28.8739
#   Efficiency y (srs):  1.963 → 0.851 → 4.61
#   Alpha:               0.7818895954797997
#   Num changes:         2
#   Design Depth:        1125
#   Design Size (|D|):   2350
#   Open set size:       25923
#
#
# === Best Solution Updated at Iteration 890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       142378.847
#   Best Cost (y):       19228.7852
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      142378.847
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0563→ cube 2.2198
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2027→ cube 1.1154
#   Efficiency z (srs):  5.89 → 0.296 → 28.877
#   Efficiency y (srs):  1.963 → 0.851 → 4.6184
#   Alpha:               0.7920659823350211
#   Num changes:         2
#   Design Depth:        1125
#   Design Size (|D|):   2350
#   Open set size:       25938
#
# Progress: 18.0%
# === Best Solution Updated at Iteration 900 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       141227.981
#   Best Cost (y):       19211.1224
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      141227.981
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0649→ cube 2.2379
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2038→ cube 1.1164
#   Efficiency z (srs):  5.89 → 0.296 → 29.1123
#   Efficiency y (srs):  1.963 → 0.851 → 4.6226
#   Alpha:               0.770041765412718
#   Num changes:         1
#   Design Depth:        1140
#   Design Size (|D|):   2380
#   Open set size:       26207
#
# Progress: 18.2%
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       141029.262
#   Best Cost (y):       19131.0352
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      141029.262
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0664→ cube 2.2411
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2089→ cube 1.1211
#   Efficiency z (srs):  5.89 → 0.296 → 29.1533
#   Efficiency y (srs):  1.963 → 0.851 → 4.642
#   Alpha:               0.829429962091067
#   Num changes:         1
#   Design Depth:        1151
#   Design Size (|D|):   2402
#   Open set size:       26495
#
#
# === Best Solution Updated at Iteration 910 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       140965.851
#   Best Cost (y):       19164.6279
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      140965.851
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0668→ cube 2.2421
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2067→ cube 1.1191
#   Efficiency z (srs):  5.89 → 0.296 → 29.1664
#   Efficiency y (srs):  1.963 → 0.851 → 4.6338
#   Alpha:               0.8334619761314302
#   Num changes:         2
#   Design Depth:        1152
#   Design Size (|D|):   2404
#   Open set size:       26502
#
# Progress: 18.6%
# === Best Solution Updated at Iteration 930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       140766.055
#   Best Cost (y):       19038.9376
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      140766.055
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0684→ cube 2.2453
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2147→ cube 1.1265
#   Efficiency z (srs):  5.89 → 0.296 → 29.2078
#   Efficiency y (srs):  1.963 → 0.851 → 4.6644
#   Alpha:               0.7824710157861198
#   Num changes:         1
#   Design Depth:        1171
#   Design Size (|D|):   2442
#   Open set size:       27079
#
#
# === Best Solution Updated at Iteration 930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50480.78→50480.78, 10043.62→10043.62
#   Best Cost (z):       140765.988
#   Best Cost (y):       19040.2819
#   number of new noded: 30
#   rho (z, y):          0.792
#   rho (z_hat, y_hat):  0.586
#   rho (p, y):          0.88
#   Criteria Value:      140765.988
#   Efficiency z (0→f):  0.215 → 0.296 → dsd 1.0684→ cube 2.2453
#   Efficiency y (0→f):  0.511 → 0.851 → dsd 1.2146→ cube 1.1264
#   Efficiency z (srs):  5.89 → 0.296 → 29.2078
#   Efficiency y (srs):  1.963 → 0.851 → 4.6641
#   Alpha:               0.7780845677159077
#   Num changes:         1
#   Design Depth:        1171
#   Design Size (|D|):   2442
#   Open set size:       27085
#
# Progress: 18.8%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 48
#      22 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      23                    inclusion_probability=inclusions, balance_method=bardia_balance_method)
#      25 astar = AStar(
#      26     inclusions              = inclusions,
#      27     num_initial_nodes       = num_initial_nodes,
#    (...)     45     rng                     = rng,
#      46 )
# ---> 48 result = astar.run(
#      49     max_iterations             = max_iterations,
#      50     num_new_nodes              = num_new_nodes,
#      51     max_open_set_size          = max_open_set_size,
#      52     random_restart_period      = random_restart_period,
#      53     random_injection_count     = random_injection_count,
#      54     prune_fraction             = prune_fraction,
#      55     num_top_restart_nodes      = num_top_restart_nodes,
#      56     stuck_fraction             = stuck_fraction,
#      57
#      58 )
#      60 print("Best criteria value:", astar.best_criteria_value)
#      61 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:29, in VarNHT.__call__(self, design)
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
# ---> 29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#      33 samples_probabilities = np.array([sample.probability for sample in design])
#      34 var_NHT_z = np.sum((NHT_estimator_z - np.sum(self.auxiliary_variable)) ** 2 * samples_probabilities)
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
# Out:
# size of init design 100
# size of best design 2460
# 508714.0503327147
# 140694.58459271688
# [100]
# /tmp/ipykernel_281134/683604881.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# sum of inclusions, last ini and original 10.000000029999994 10.000000029999997 10.000000000000004
# 1.0000000030000002
# n =  [10]
# 10043.617183059718 50480.78213352054 10043.61721393518 50480.78228639465
# 10043.617183059718 50480.78213352054 10043.61721393518 50480.78228639465
# var z estimates 140686.94
# var y estimates 19093.333
