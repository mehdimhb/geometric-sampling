# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_8.5_py_8.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_8.5_py_8.5_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.1 0.9
# Generating initial designs:   0%|              | 6/3000 [00:00<00:57, 51.84it/s]
# Initial design 0: method = Original, efficiency z = 0.2024, y=0.9439
# New best at idx=0: method = Original, efficiency z = 0.2024 and efficiency y = 0.9439
# New best at idx=2: method = z/pi, efficiency z = 0.2024 and efficiency y = 0.9439
# New best at idx=7: method = swap, efficiency z = 0.2039 and efficiency y = 1.2857
# Generating initial designs:   1%|             | 18/3000 [00:00<00:58, 51.09it/s]
# New best at idx=16: method = swap, efficiency z = 0.2189 and efficiency y = 0.6779
# Generating initial designs:   1%|             | 24/3000 [00:00<00:57, 51.54it/s]
# New best at idx=27: method = swap, efficiency z = 0.2504 and efficiency y = 0.8714
# Generating initial designs:   3%|▎            | 76/3000 [00:01<00:49, 58.77it/s]
# New best at idx=62: method = swap, efficiency z = 0.2663 and efficiency y = 0.9863
# Generating initial designs:  16%|█▉          | 485/3000 [00:10<00:42, 59.44it/s]
# New best at idx=474: method = swap, efficiency z = 0.2733 and efficiency y = 1.1820
# Generating initial designs:  69%|███████▌   | 2071/3000 [00:33<00:11, 83.74it/s]
# New best at idx=2057: method = swap, efficiency z = 0.2770 and efficiency y = 1.1167
# Generating initial designs: 100%|███████████| 3000/3000 [00:46<00:00, 65.12it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       200341.654
#   Best Cost (y):       14041.0191
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      200341.654
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.2865→ cube 0.7783
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 1.1191→ cube 1.2753
#   Efficiency z (srs):  10.285 → 0.277 → 14.5618
#   Efficiency y (srs):  5.335 → 1.117 → 6.3247
#   Alpha:               0.5230987358071829
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       100
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       200069.562
#   Best Cost (y):       14043.2443
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      200069.562
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.2869→ cube 0.7794
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 1.1189→ cube 1.2751
#   Efficiency z (srs):  10.285 → 0.277 → 14.5816
#   Efficiency y (srs):  5.335 → 1.117 → 6.3237
#   Alpha:               0.7156164392317401
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       115
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       198396.551
#   Best Cost (y):       14769.1419
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      198396.551
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.2893→ cube 0.786
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 1.0639→ cube 1.2124
#   Efficiency z (srs):  10.285 → 0.277 → 14.7046
#   Efficiency y (srs):  5.335 → 1.117 → 6.0129
#   Alpha:               0.5086887874846328
#   Num changes:         3
#   Design Depth:        3
#   Design Size (|D|):   106
#   Open set size:       126
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       197180.987
#   Best Cost (y):       14761.3783
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      197180.987
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.2911→ cube 0.7908
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 1.0645→ cube 1.2131
#   Efficiency z (srs):  10.285 → 0.277 → 14.7952
#   Efficiency y (srs):  5.335 → 1.117 → 6.0161
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4
#   Design Size (|D|):   108
#   Open set size:       158
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       174960.895
#   Best Cost (y):       16134.8117
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      174960.895
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.3281→ cube 0.8913
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9739→ cube 1.1098
#   Efficiency z (srs):  10.285 → 0.277 → 16.6742
#   Efficiency y (srs):  5.335 → 1.117 → 5.504
#   Alpha:               0.4112704869146373
#   Num changes:         1
#   Design Depth:        19
#   Design Size (|D|):   138
#   Open set size:       392
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       174086.871
#   Best Cost (y):       16138.3724
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      174086.871
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.3297→ cube 0.8957
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9737→ cube 1.1096
#   Efficiency z (srs):  10.285 → 0.277 → 16.758
#   Efficiency y (srs):  5.335 → 1.117 → 5.5028
#   Alpha:               0.5221102286231223
#   Num changes:         2
#   Design Depth:        20
#   Design Size (|D|):   140
#   Open set size:       405
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       174053.978
#   Best Cost (y):       16151.2083
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      174053.978
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.3298→ cube 0.8959
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9729→ cube 1.1087
#   Efficiency z (srs):  10.285 → 0.277 → 16.7611
#   Efficiency y (srs):  5.335 → 1.117 → 5.4984
#   Alpha:               0.5489397690361302
#   Num changes:         1
#   Design Depth:        19
#   Design Size (|D|):   138
#   Open set size:       418
#
# Progress: 0.4%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       154618.424
#   Best Cost (y):       16829.9793
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      154618.424
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.3713→ cube 1.0085
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9337→ cube 1.064
#   Efficiency z (srs):  10.285 → 0.277 → 18.868
#   Efficiency y (srs):  5.335 → 1.117 → 5.2766
#   Alpha:               0.43154354590605404
#   Num changes:         2
#   Design Depth:        39
#   Design Size (|D|):   178
#   Open set size:       686
#
#
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       154457.393
#   Best Cost (y):       16903.5687
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      154457.393
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.3716→ cube 1.0096
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9296→ cube 1.0593
#   Efficiency z (srs):  10.285 → 0.277 → 18.8877
#   Efficiency y (srs):  5.335 → 1.117 → 5.2537
#   Alpha:               0.5329946479655261
#   Num changes:         2
#   Design Depth:        39
#   Design Size (|D|):   178
#   Open set size:       701
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       142582.972
#   Best Cost (y):       17110.9253
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      142582.972
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4026→ cube 1.0936
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9183→ cube 1.0465
#   Efficiency z (srs):  10.285 → 0.277 → 20.4606
#   Efficiency y (srs):  5.335 → 1.117 → 5.19
#   Alpha:               0.543919806491767
#   Num changes:         2
#   Design Depth:        72
#   Design Size (|D|):   244
#   Open set size:       1262
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       137697.402
#   Best Cost (y):       17120.6783
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      137697.402
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4169→ cube 1.1325
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9178→ cube 1.0459
#   Efficiency z (srs):  10.285 → 0.277 → 21.1866
#   Efficiency y (srs):  5.335 → 1.117 → 5.187
#   Alpha:               0.8507470920264465
#   Num changes:         3
#   Design Depth:        92
#   Design Size (|D|):   284
#   Open set size:       1561
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       132484.097
#   Best Cost (y):       17300.1173
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      132484.097
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4333→ cube 1.177
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9083→ cube 1.035
#   Efficiency z (srs):  10.285 → 0.277 → 22.0203
#   Efficiency y (srs):  5.335 → 1.117 → 5.1332
#   Alpha:               0.8491027873714406
#   Num changes:         1
#   Design Depth:        107
#   Design Size (|D|):   314
#   Open set size:       1843
#
# Progress: 1.4%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       130553.415
#   Best Cost (y):       17431.5716
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      130553.415
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4397→ cube 1.1944
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9014→ cube 1.0272
#   Efficiency z (srs):  10.285 → 0.277 → 22.346
#   Efficiency y (srs):  5.335 → 1.117 → 5.0945
#   Alpha:               0.1166164046580077
#   Num changes:         3
#   Design Depth:        125
#   Design Size (|D|):   350
#   Open set size:       2130
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       128952.45
#   Best Cost (y):       17614.486
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      128952.45
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4452→ cube 1.2092
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.8921→ cube 1.0166
#   Efficiency z (srs):  10.285 → 0.277 → 22.6234
#   Efficiency y (srs):  5.335 → 1.117 → 5.0416
#   Alpha:               0.44663083352587873
#   Num changes:         3
#   Design Depth:        125
#   Design Size (|D|):   350
#   Open set size:       2135
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       127239.571
#   Best Cost (y):       17405.621
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      127239.571
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4511→ cube 1.2255
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9028→ cube 1.0288
#   Efficiency z (srs):  10.285 → 0.277 → 22.9279
#   Efficiency y (srs):  5.335 → 1.117 → 5.1021
#   Alpha:               0.8685351506491422
#   Num changes:         1
#   Design Depth:        123
#   Design Size (|D|):   346
#   Open set size:       2138
#
# Progress: 1.6%
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       121187.37
#   Best Cost (y):       17274.6576
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      121187.37
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4737→ cube 1.2867
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9096→ cube 1.0366
#   Efficiency z (srs):  10.285 → 0.277 → 24.073
#   Efficiency y (srs):  5.335 → 1.117 → 5.1408
#   Alpha:               0.6926743153921722
#   Num changes:         2
#   Design Depth:        139
#   Design Size (|D|):   378
#   Open set size:       2430
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       121173.697
#   Best Cost (y):       17429.362
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      121173.697
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4737→ cube 1.2869
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9015→ cube 1.0274
#   Efficiency z (srs):  10.285 → 0.277 → 24.0757
#   Efficiency y (srs):  5.335 → 1.117 → 5.0952
#   Alpha:               0.3507662971232829
#   Num changes:         2
#   Design Depth:        139
#   Design Size (|D|):   378
#   Open set size:       2438
#
#
# === Best Solution Updated at Iteration 80 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       120404.752
#   Best Cost (y):       17293.1748
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      120404.752
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4768→ cube 1.2951
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9086→ cube 1.0355
#   Efficiency z (srs):  10.285 → 0.277 → 24.2294
#   Efficiency y (srs):  5.335 → 1.117 → 5.1353
#   Alpha:               0.6479186028656405
#   Num changes:         3
#   Design Depth:        140
#   Design Size (|D|):   380
#   Open set size:       2446
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       119326.326
#   Best Cost (y):       16955.5472
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      119326.326
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4811→ cube 1.3068
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9267→ cube 1.0561
#   Efficiency z (srs):  10.285 → 0.277 → 24.4484
#   Efficiency y (srs):  5.335 → 1.117 → 5.2375
#   Alpha:               0.8615765732566943
#   Num changes:         1
#   Design Depth:        158
#   Design Size (|D|):   416
#   Open set size:       2728
#
# Progress: 2.0%
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       117104.266
#   Best Cost (y):       17126.1556
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      117104.266
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4902→ cube 1.3316
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9175→ cube 1.0456
#   Efficiency z (srs):  10.285 → 0.277 → 24.9123
#   Efficiency y (srs):  5.335 → 1.117 → 5.1854
#   Alpha:               0.2537127962839912
#   Num changes:         3
#   Design Depth:        176
#   Design Size (|D|):   452
#   Open set size:       3022
#
#
# === Best Solution Updated at Iteration 100 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       117065.357
#   Best Cost (y):       17166.6139
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      117065.357
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.4904→ cube 1.332
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9153→ cube 1.0431
#   Efficiency z (srs):  10.285 → 0.277 → 24.9206
#   Efficiency y (srs):  5.335 → 1.117 → 5.1732
#   Alpha:               0.22556031784894615
#   Num changes:         3
#   Design Depth:        176
#   Design Size (|D|):   452
#   Open set size:       3023
#
# Progress: 2.4%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       111549.546
#   Best Cost (y):       16863.747
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      111549.546
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5146→ cube 1.3979
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9318→ cube 1.0618
#   Efficiency z (srs):  10.285 → 0.277 → 26.1529
#   Efficiency y (srs):  5.335 → 1.117 → 5.2661
#   Alpha:               0.2568475319747142
#   Num changes:         1
#   Design Depth:        206
#   Design Size (|D|):   512
#   Open set size:       3602
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       110439.913
#   Best Cost (y):       16979.2574
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      110439.913
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5198→ cube 1.4119
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9254→ cube 1.0546
#   Efficiency z (srs):  10.285 → 0.277 → 26.4156
#   Efficiency y (srs):  5.335 → 1.117 → 5.2302
#   Alpha:               0.2010470514794033
#   Num changes:         1
#   Design Depth:        229
#   Design Size (|D|):   558
#   Open set size:       4179
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       108794.421
#   Best Cost (y):       17013.4461
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      108794.421
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5276→ cube 1.4333
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9236→ cube 1.0525
#   Efficiency z (srs):  10.285 → 0.277 → 26.8152
#   Efficiency y (srs):  5.335 → 1.117 → 5.2197
#   Alpha:               0.3460451843928748
#   Num changes:         1
#   Design Depth:        247
#   Design Size (|D|):   594
#   Open set size:       4453
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       108776.786
#   Best Cost (y):       17011.4545
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      108776.786
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5277→ cube 1.4335
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9237→ cube 1.0526
#   Efficiency z (srs):  10.285 → 0.277 → 26.8195
#   Efficiency y (srs):  5.335 → 1.117 → 5.2203
#   Alpha:               0.11705211179382582
#   Num changes:         3
#   Design Depth:        249
#   Design Size (|D|):   598
#   Open set size:       4461
#
#
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       108741.829
#   Best Cost (y):       16996.4194
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      108741.829
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5279→ cube 1.434
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9245→ cube 1.0535
#   Efficiency z (srs):  10.285 → 0.277 → 26.8281
#   Efficiency y (srs):  5.335 → 1.117 → 5.225
#   Alpha:               0.14056438943447427
#   Num changes:         3
#   Design Depth:        249
#   Design Size (|D|):   598
#   Open set size:       4466
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       108116.674
#   Best Cost (y):       16882.9084
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      108116.674
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5309→ cube 1.4423
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9307→ cube 1.0606
#   Efficiency z (srs):  10.285 → 0.277 → 26.9833
#   Efficiency y (srs):  5.335 → 1.117 → 5.2601
#   Alpha:               0.2523907351662348
#   Num changes:         2
#   Design Depth:        268
#   Design Size (|D|):   636
#   Open set size:       4746
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       108068.372
#   Best Cost (y):       16887.4302
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      108068.372
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5312→ cube 1.4429
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9305→ cube 1.0603
#   Efficiency z (srs):  10.285 → 0.277 → 26.9953
#   Efficiency y (srs):  5.335 → 1.117 → 5.2587
#   Alpha:               0.25321208518050575
#   Num changes:         1
#   Design Depth:        267
#   Design Size (|D|):   634
#   Open set size:       4752
#
#
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       107753.789
#   Best Cost (y):       16888.5063
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      107753.789
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5327→ cube 1.4471
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9304→ cube 1.0603
#   Efficiency z (srs):  10.285 → 0.277 → 27.0741
#   Efficiency y (srs):  5.335 → 1.117 → 5.2583
#   Alpha:               0.7737395137553548
#   Num changes:         1
#   Design Depth:        267
#   Design Size (|D|):   634
#   Open set size:       4756
#
# Progress: 3.4%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       107102.214
#   Best Cost (y):       16890.771
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      107102.214
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.536→ cube 1.456
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9303→ cube 1.0601
#   Efficiency z (srs):  10.285 → 0.277 → 27.2388
#   Efficiency y (srs):  5.335 → 1.117 → 5.2576
#   Alpha:               0.47714228872387243
#   Num changes:         1
#   Design Depth:        282
#   Design Size (|D|):   664
#   Open set size:       5033
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       106969.538
#   Best Cost (y):       16905.6648
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      106969.538
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5366→ cube 1.4578
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9295→ cube 1.0592
#   Efficiency z (srs):  10.285 → 0.277 → 27.2726
#   Efficiency y (srs):  5.335 → 1.117 → 5.253
#   Alpha:               0.6501060929935463
#   Num changes:         2
#   Design Depth:        283
#   Design Size (|D|):   666
#   Open set size:       5039
#
#
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       106829.114
#   Best Cost (y):       16880.4433
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      106829.114
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5373→ cube 1.4597
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9309→ cube 1.0608
#   Efficiency z (srs):  10.285 → 0.277 → 27.3085
#   Efficiency y (srs):  5.335 → 1.117 → 5.2609
#   Alpha:               0.881386082987331
#   Num changes:         1
#   Design Depth:        282
#   Design Size (|D|):   664
#   Open set size:       5053
#
# Progress: 3.6%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       105518.248
#   Best Cost (y):       16821.7671
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      105518.248
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.544→ cube 1.4778
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9341→ cube 1.0645
#   Efficiency z (srs):  10.285 → 0.277 → 27.6477
#   Efficiency y (srs):  5.335 → 1.117 → 5.2792
#   Alpha:               0.7332653371459618
#   Num changes:         1
#   Design Depth:        298
#   Design Size (|D|):   696
#   Open set size:       5342
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       105414.326
#   Best Cost (y):       16812.4532
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      105414.326
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5446→ cube 1.4793
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9346→ cube 1.0651
#   Efficiency z (srs):  10.285 → 0.277 → 27.675
#   Efficiency y (srs):  5.335 → 1.117 → 5.2821
#   Alpha:               0.8020117858313157
#   Num changes:         2
#   Design Depth:        299
#   Design Size (|D|):   698
#   Open set size:       5345
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       104652.303
#   Best Cost (y):       16913.0726
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      104652.303
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5485→ cube 1.49
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9291→ cube 1.0587
#   Efficiency z (srs):  10.285 → 0.277 → 27.8765
#   Efficiency y (srs):  5.335 → 1.117 → 5.2507
#   Alpha:               0.5049614649302258
#   Num changes:         2
#   Design Depth:        315
#   Design Size (|D|):   730
#   Open set size:       5620
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       102230.924
#   Best Cost (y):       16812.6114
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      102230.924
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5615→ cube 1.5253
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9346→ cube 1.0651
#   Efficiency z (srs):  10.285 → 0.277 → 28.5368
#   Efficiency y (srs):  5.335 → 1.117 → 5.2821
#   Alpha:               0.28756240126613497
#   Num changes:         2
#   Design Depth:        329
#   Design Size (|D|):   758
#   Open set size:       5900
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       102150.296
#   Best Cost (y):       16809.3806
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      102150.296
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.562→ cube 1.5265
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9348→ cube 1.0653
#   Efficiency z (srs):  10.285 → 0.277 → 28.5593
#   Efficiency y (srs):  5.335 → 1.117 → 5.2831
#   Alpha:               0.1397408858789434
#   Num changes:         3
#   Design Depth:        330
#   Design Size (|D|):   760
#   Open set size:       5909
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       102071.999
#   Best Cost (y):       16821.9822
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      102071.999
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5624→ cube 1.5277
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9341→ cube 1.0645
#   Efficiency z (srs):  10.285 → 0.277 → 28.5812
#   Efficiency y (srs):  5.335 → 1.117 → 5.2791
#   Alpha:               0.45034864177907863
#   Num changes:         2
#   Design Depth:        329
#   Design Size (|D|):   758
#   Open set size:       5923
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       98883.558
#   Best Cost (y):       16786.1624
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      98883.558
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5805→ cube 1.577
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9361→ cube 1.0667
#   Efficiency z (srs):  10.285 → 0.277 → 29.5028
#   Efficiency y (srs):  5.335 → 1.117 → 5.2904
#   Alpha:               0.7635121407184567
#   Num changes:         1
#   Design Depth:        345
#   Design Size (|D|):   790
#   Open set size:       6199
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       98872.815
#   Best Cost (y):       16815.2302
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      98872.815
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5806→ cube 1.5771
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9345→ cube 1.0649
#   Efficiency z (srs):  10.285 → 0.277 → 29.506
#   Efficiency y (srs):  5.335 → 1.117 → 5.2813
#   Alpha:               0.8676855825721578
#   Num changes:         1
#   Design Depth:        345
#   Design Size (|D|):   790
#   Open set size:       6219
#
# Progress: 4.4%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       97957.844
#   Best Cost (y):       16750.6578
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      97957.844
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.586→ cube 1.5919
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9381→ cube 1.069
#   Efficiency z (srs):  10.285 → 0.277 → 29.7816
#   Efficiency y (srs):  5.335 → 1.117 → 5.3016
#   Alpha:               0.6997877436508941
#   Num changes:         1
#   Design Depth:        360
#   Design Size (|D|):   820
#   Open set size:       6491
#
#
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       97917.445
#   Best Cost (y):       16734.9246
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      97917.445
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5862→ cube 1.5925
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.939→ cube 1.07
#   Efficiency z (srs):  10.285 → 0.277 → 29.7939
#   Efficiency y (srs):  5.335 → 1.117 → 5.3066
#   Alpha:               0.7672176492478142
#   Num changes:         1
#   Design Depth:        360
#   Design Size (|D|):   820
#   Open set size:       6499
#
# Progress: 4.6%
# === Best Solution Updated at Iteration 230 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       96674.593
#   Best Cost (y):       16710.0268
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      96674.593
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5938→ cube 1.613
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9404→ cube 1.0716
#   Efficiency z (srs):  10.285 → 0.277 → 30.1769
#   Efficiency y (srs):  5.335 → 1.117 → 5.3145
#   Alpha:               0.20575484595299642
#   Num changes:         3
#   Design Depth:        375
#   Design Size (|D|):   850
#   Open set size:       6780
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       96353.529
#   Best Cost (y):       16663.3056
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      96353.529
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.5958→ cube 1.6184
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.943→ cube 1.0746
#   Efficiency z (srs):  10.285 → 0.277 → 30.2775
#   Efficiency y (srs):  5.335 → 1.117 → 5.3294
#   Alpha:               0.2841552354595767
#   Num changes:         1
#   Design Depth:        389
#   Design Size (|D|):   878
#   Open set size:       7073
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       95081.046
#   Best Cost (y):       16665.8883
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      95081.046
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6037→ cube 1.64
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9428→ cube 1.0744
#   Efficiency z (srs):  10.285 → 0.277 → 30.6827
#   Efficiency y (srs):  5.335 → 1.117 → 5.3286
#   Alpha:               0.44292634428019073
#   Num changes:         2
#   Design Depth:        408
#   Design Size (|D|):   916
#   Open set size:       7351
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       94984.082
#   Best Cost (y):       16614.3637
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      94984.082
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6044→ cube 1.6417
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9458→ cube 1.0778
#   Efficiency z (srs):  10.285 → 0.277 → 30.714
#   Efficiency y (srs):  5.335 → 1.117 → 5.3451
#   Alpha:               0.8129765428806969
#   Num changes:         1
#   Design Depth:        407
#   Design Size (|D|):   914
#   Open set size:       7368
#
# Progress: 5.2%
# === Best Solution Updated at Iteration 260 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       93918.809
#   Best Cost (y):       16440.3871
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      93918.809
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6112→ cube 1.6603
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9558→ cube 1.0892
#   Efficiency z (srs):  10.285 → 0.277 → 31.0624
#   Efficiency y (srs):  5.335 → 1.117 → 5.4017
#   Alpha:               0.6295261019523524
#   Num changes:         2
#   Design Depth:        420
#   Design Size (|D|):   940
#   Open set size:       7644
#
# Progress: 5.8%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       92631.547
#   Best Cost (y):       16268.9005
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      92631.547
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6197→ cube 1.6834
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9659→ cube 1.1006
#   Efficiency z (srs):  10.285 → 0.277 → 31.494
#   Efficiency y (srs):  5.335 → 1.117 → 5.4586
#   Alpha:               0.6038454422862326
#   Num changes:         1
#   Design Depth:        452
#   Design Size (|D|):   1004
#   Open set size:       8510
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       92562.685
#   Best Cost (y):       16272.8895
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      92562.685
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6202→ cube 1.6846
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9656→ cube 1.1004
#   Efficiency z (srs):  10.285 → 0.277 → 31.5175
#   Efficiency y (srs):  5.335 → 1.117 → 5.4573
#   Alpha:               0.7822389699234261
#   Num changes:         2
#   Design Depth:        453
#   Design Size (|D|):   1006
#   Open set size:       8519
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       91168.371
#   Best Cost (y):       16137.5752
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      91168.371
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6296→ cube 1.7104
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9737→ cube 1.1096
#   Efficiency z (srs):  10.285 → 0.277 → 31.9995
#   Efficiency y (srs):  5.335 → 1.117 → 5.503
#   Alpha:               0.5883869551187088
#   Num changes:         1
#   Design Depth:        470
#   Design Size (|D|):   1040
#   Open set size:       8802
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 310 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       90454.34
#   Best Cost (y):       16242.3876
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      90454.34
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6346→ cube 1.7239
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9674→ cube 1.1024
#   Efficiency z (srs):  10.285 → 0.277 → 32.2521
#   Efficiency y (srs):  5.335 → 1.117 → 5.4675
#   Alpha:               0.6717696017063459
#   Num changes:         3
#   Design Depth:        486
#   Design Size (|D|):   1072
#   Open set size:       9098
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 340 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       87977.408
#   Best Cost (y):       16150.6764
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      87977.408
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6525→ cube 1.7724
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9729→ cube 1.1087
#   Efficiency z (srs):  10.285 → 0.277 → 33.1601
#   Efficiency y (srs):  5.335 → 1.117 → 5.4986
#   Alpha:               0.5922811438902265
#   Num changes:         2
#   Design Depth:        544
#   Design Size (|D|):   1188
#   Open set size:       9965
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       86380.2
#   Best Cost (y):       16195.9218
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      86380.2
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6645→ cube 1.8052
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9702→ cube 1.1056
#   Efficiency z (srs):  10.285 → 0.277 → 33.7733
#   Efficiency y (srs):  5.335 → 1.117 → 5.4832
#   Alpha:               0.7941390714349817
#   Num changes:         1
#   Design Depth:        574
#   Design Size (|D|):   1248
#   Open set size:       10542
#
# Progress: 7.4%
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       85779.068
#   Best Cost (y):       16229.5304
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      85779.068
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6692→ cube 1.8179
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9682→ cube 1.1033
#   Efficiency z (srs):  10.285 → 0.277 → 34.0099
#   Efficiency y (srs):  5.335 → 1.117 → 5.4718
#   Alpha:               0.6597912478396563
#   Num changes:         2
#   Design Depth:        591
#   Design Size (|D|):   1282
#   Open set size:       10830
#
#
# === Best Solution Updated at Iteration 370 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       85722.699
#   Best Cost (y):       16251.0704
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      85722.699
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6696→ cube 1.8191
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9669→ cube 1.1019
#   Efficiency z (srs):  10.285 → 0.277 → 34.0323
#   Efficiency y (srs):  5.335 → 1.117 → 5.4646
#   Alpha:               0.4182139707946706
#   Num changes:         3
#   Design Depth:        592
#   Design Size (|D|):   1284
#   Open set size:       10846
#
# Progress: 7.6%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       84606.197
#   Best Cost (y):       16214.2676
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      84606.197
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6785→ cube 1.8431
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9691→ cube 1.1044
#   Efficiency z (srs):  10.285 → 0.277 → 34.4814
#   Efficiency y (srs):  5.335 → 1.117 → 5.477
#   Alpha:               0.7915352804279161
#   Num changes:         1
#   Design Depth:        609
#   Design Size (|D|):   1318
#   Open set size:       11148
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       84267.609
#   Best Cost (y):       16300.9769
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      84267.609
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6812→ cube 1.8505
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.964→ cube 1.0985
#   Efficiency z (srs):  10.285 → 0.277 → 34.6199
#   Efficiency y (srs):  5.335 → 1.117 → 5.4479
#   Alpha:               0.5527247539812374
#   Num changes:         1
#   Design Depth:        622
#   Design Size (|D|):   1344
#   Open set size:       11413
#
#
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       84249.874
#   Best Cost (y):       16277.7643
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      84249.874
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6814→ cube 1.8509
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9653→ cube 1.1
#   Efficiency z (srs):  10.285 → 0.277 → 34.6272
#   Efficiency y (srs):  5.335 → 1.117 → 5.4556
#   Alpha:               0.8863046569813491
#   Num changes:         1
#   Design Depth:        622
#   Design Size (|D|):   1344
#   Open set size:       11421
#
#
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       84247.857
#   Best Cost (y):       16317.5738
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      84247.857
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6814→ cube 1.8509
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.963→ cube 1.0974
#   Efficiency z (srs):  10.285 → 0.277 → 34.6281
#   Efficiency y (srs):  5.335 → 1.117 → 5.4423
#   Alpha:               0.6199789966835895
#   Num changes:         1
#   Design Depth:        622
#   Design Size (|D|):   1344
#   Open set size:       11424
#
#
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       84234.737
#   Best Cost (y):       16295.2564
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      84234.737
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6815→ cube 1.8512
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9643→ cube 1.0989
#   Efficiency z (srs):  10.285 → 0.277 → 34.6335
#   Efficiency y (srs):  5.335 → 1.117 → 5.4498
#   Alpha:               0.8249390785358705
#   Num changes:         1
#   Design Depth:        622
#   Design Size (|D|):   1344
#   Open set size:       11434
#
# Progress: 8.0%
# === Best Solution Updated at Iteration 400 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       83956.36
#   Best Cost (y):       16283.8063
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      83956.36
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6837→ cube 1.8573
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.965→ cube 1.0996
#   Efficiency z (srs):  10.285 → 0.277 → 34.7483
#   Efficiency y (srs):  5.335 → 1.117 → 5.4536
#   Alpha:               0.8835990018667284
#   Num changes:         1
#   Design Depth:        632
#   Design Size (|D|):   1364
#   Open set size:       11722
#
# Progress: 8.4%
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       82575.045
#   Best Cost (y):       16358.6324
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      82575.045
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6952→ cube 1.8884
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9606→ cube 1.0946
#   Efficiency z (srs):  10.285 → 0.277 → 35.3296
#   Efficiency y (srs):  5.335 → 1.117 → 5.4287
#   Alpha:               0.12714267554755887
#   Num changes:         3
#   Design Depth:        665
#   Design Size (|D|):   1430
#   Open set size:       12295
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       82499.61
#   Best Cost (y):       16356.2024
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      82499.61
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6958→ cube 1.8901
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9607→ cube 1.0948
#   Efficiency z (srs):  10.285 → 0.277 → 35.3619
#   Efficiency y (srs):  5.335 → 1.117 → 5.4295
#   Alpha:               0.2593010892130777
#   Num changes:         3
#   Design Depth:        665
#   Design Size (|D|):   1430
#   Open set size:       12301
#
#
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       82338.131
#   Best Cost (y):       16372.7102
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      82338.131
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 0.6972→ cube 1.8938
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9597→ cube 1.0937
#   Efficiency z (srs):  10.285 → 0.277 → 35.4312
#   Efficiency y (srs):  5.335 → 1.117 → 5.424
#   Alpha:               0.6633619750395009
#   Num changes:         3
#   Design Depth:        665
#   Design Size (|D|):   1430
#   Open set size:       12305
#
# ...
#   Best Cost (y):       16088.8397
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54581.025
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0517→ cube 2.857
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9767→ cube 1.113
#   Efficiency z (srs):  10.285 → 0.277 → 53.4497
#   Efficiency y (srs):  5.335 → 1.117 → 5.5197
#   Alpha:               0.6006579606693684
#   Num changes:         3
#   Design Depth:        3365
#   Design Size (|D|):   6830
#   Open set size:       76087
#
# Progress: 52.6%
# === Best Solution Updated at Iteration 2630 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54494.993
#   Best Cost (y):       16084.5523
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54494.993
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0534→ cube 2.8615
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9769→ cube 1.1133
#   Efficiency z (srs):  10.285 → 0.277 → 53.5341
#   Efficiency y (srs):  5.335 → 1.117 → 5.5212
#   Alpha:               0.27334507206859093
#   Num changes:         2
#   Design Depth:        3379
#   Design Size (|D|):   6858
#   Open set size:       76399
#
# Progress: 53.0%
# === Best Solution Updated at Iteration 2650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54447.331
#   Best Cost (y):       16074.3571
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54447.331
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0543→ cube 2.864
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9775→ cube 1.114
#   Efficiency z (srs):  10.285 → 0.277 → 53.581
#   Efficiency y (srs):  5.335 → 1.117 → 5.5247
#   Alpha:               0.43301712320037866
#   Num changes:         1
#   Design Depth:        3397
#   Design Size (|D|):   6894
#   Open set size:       76963
#
#
# === Best Solution Updated at Iteration 2650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54446.981
#   Best Cost (y):       16074.0022
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54446.981
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0543→ cube 2.864
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9776→ cube 1.114
#   Efficiency z (srs):  10.285 → 0.277 → 53.5813
#   Efficiency y (srs):  5.335 → 1.117 → 5.5248
#   Alpha:               0.3877918134031805
#   Num changes:         1
#   Design Depth:        3397
#   Design Size (|D|):   6894
#   Open set size:       76964
#
#
# === Best Solution Updated at Iteration 2650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54446.189
#   Best Cost (y):       16074.5337
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54446.189
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0543→ cube 2.864
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9775→ cube 1.114
#   Efficiency z (srs):  10.285 → 0.277 → 53.5821
#   Efficiency y (srs):  5.335 → 1.117 → 5.5246
#   Alpha:               0.2605052128371435
#   Num changes:         1
#   Design Depth:        3397
#   Design Size (|D|):   6894
#   Open set size:       76972
#
#
# === Best Solution Updated at Iteration 2650 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54439.193
#   Best Cost (y):       16075.8843
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54439.193
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0545→ cube 2.8644
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9774→ cube 1.1139
#   Efficiency z (srs):  10.285 → 0.277 → 53.589
#   Efficiency y (srs):  5.335 → 1.117 → 5.5241
#   Alpha:               0.7715434915407678
#   Num changes:         1
#   Design Depth:        3397
#   Design Size (|D|):   6894
#   Open set size:       76979
#
# Progress: 53.2%
# === Best Solution Updated at Iteration 2660 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54381.133
#   Best Cost (y):       16068.4104
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54381.133
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0556→ cube 2.8675
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9779→ cube 1.1144
#   Efficiency z (srs):  10.285 → 0.277 → 53.6462
#   Efficiency y (srs):  5.335 → 1.117 → 5.5267
#   Alpha:               0.21281521164577885
#   Num changes:         1
#   Design Depth:        3409
#   Design Size (|D|):   6918
#   Open set size:       77253
#
#
# === Best Solution Updated at Iteration 2660 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54374.18
#   Best Cost (y):       16067.5908
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54374.18
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0557→ cube 2.8678
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.978→ cube 1.1144
#   Efficiency z (srs):  10.285 → 0.277 → 53.653
#   Efficiency y (srs):  5.335 → 1.117 → 5.527
#   Alpha:               0.8451188605401248
#   Num changes:         1
#   Design Depth:        3409
#   Design Size (|D|):   6918
#   Open set size:       77258
#
# Progress: 53.6%
# === Best Solution Updated at Iteration 2680 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54308.081
#   Best Cost (y):       16072.9417
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54308.081
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.057→ cube 2.8713
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9776→ cube 1.1141
#   Efficiency z (srs):  10.285 → 0.277 → 53.7183
#   Efficiency y (srs):  5.335 → 1.117 → 5.5252
#   Alpha:               0.693732855041626
#   Num changes:         3
#   Design Depth:        3436
#   Design Size (|D|):   6972
#   Open set size:       77821
#
# Progress: 54.2%
# === Best Solution Updated at Iteration 2710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54201.618
#   Best Cost (y):       16054.3025
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54201.618
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0591→ cube 2.877
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9788→ cube 1.1154
#   Efficiency z (srs):  10.285 → 0.277 → 53.8239
#   Efficiency y (srs):  5.335 → 1.117 → 5.5316
#   Alpha:               0.5570667700493186
#   Num changes:         1
#   Design Depth:        3471
#   Design Size (|D|):   7042
#   Open set size:       78691
#
#
# === Best Solution Updated at Iteration 2710 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54159.997
#   Best Cost (y):       16054.2843
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54159.997
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0599→ cube 2.8792
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9788→ cube 1.1154
#   Efficiency z (srs):  10.285 → 0.277 → 53.8652
#   Efficiency y (srs):  5.335 → 1.117 → 5.5316
#   Alpha:               0.5198028835059246
#   Num changes:         1
#   Design Depth:        3471
#   Design Size (|D|):   7042
#   Open set size:       78692
#
# Progress: 54.4%
# === Best Solution Updated at Iteration 2720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54157.063
#   Best Cost (y):       16055.1151
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54157.063
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0599→ cube 2.8793
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9787→ cube 1.1153
#   Efficiency z (srs):  10.285 → 0.277 → 53.8681
#   Efficiency y (srs):  5.335 → 1.117 → 5.5313
#   Alpha:               0.1666867529087589
#   Num changes:         1
#   Design Depth:        3477
#   Design Size (|D|):   7054
#   Open set size:       78984
#
#
# === Best Solution Updated at Iteration 2720 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54153.568
#   Best Cost (y):       16055.3874
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54153.568
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.06→ cube 2.8795
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9787→ cube 1.1153
#   Efficiency z (srs):  10.285 → 0.277 → 53.8716
#   Efficiency y (srs):  5.335 → 1.117 → 5.5312
#   Alpha:               0.4060569242003691
#   Num changes:         1
#   Design Depth:        3477
#   Design Size (|D|):   7054
#   Open set size:       78990
#
# Progress: 54.6%
# === Best Solution Updated at Iteration 2730 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54110.074
#   Best Cost (y):       16045.7033
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54110.074
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0609→ cube 2.8818
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9793→ cube 1.116
#   Efficiency z (srs):  10.285 → 0.277 → 53.9149
#   Efficiency y (srs):  5.335 → 1.117 → 5.5345
#   Alpha:               0.7008538224770894
#   Num changes:         1
#   Design Depth:        3490
#   Design Size (|D|):   7080
#   Open set size:       79286
#
# Progress: 54.8%
# === Best Solution Updated at Iteration 2740 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54096.643
#   Best Cost (y):       16050.4406
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54096.643
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0611→ cube 2.8825
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.979→ cube 1.1156
#   Efficiency z (srs):  10.285 → 0.277 → 53.9283
#   Efficiency y (srs):  5.335 → 1.117 → 5.5329
#   Alpha:               0.21568067015383435
#   Num changes:         1
#   Design Depth:        3499
#   Design Size (|D|):   7098
#   Open set size:       79566
#
# Progress: 55.2%
# === Best Solution Updated at Iteration 2760 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       54065.477
#   Best Cost (y):       16040.2948
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      54065.477
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0617→ cube 2.8842
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9796→ cube 1.1163
#   Efficiency z (srs):  10.285 → 0.277 → 53.9594
#   Efficiency y (srs):  5.335 → 1.117 → 5.5364
#   Alpha:               0.44053782657691287
#   Num changes:         2
#   Design Depth:        3517
#   Design Size (|D|):   7134
#   Open set size:       80160
#
# Progress: 56.6%
# === Best Solution Updated at Iteration 2830 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53908.448
#   Best Cost (y):       15978.6055
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      53908.448
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0648→ cube 2.8926
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9834→ cube 1.1206
#   Efficiency z (srs):  10.285 → 0.277 → 54.1166
#   Efficiency y (srs):  5.335 → 1.117 → 5.5578
#   Alpha:               0.3069810284703085
#   Num changes:         3
#   Design Depth:        3596
#   Design Size (|D|):   7292
#   Open set size:       82175
#
# Progress: 56.8%
# === Best Solution Updated at Iteration 2840 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53831.847
#   Best Cost (y):       15974.03
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      53831.847
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0664→ cube 2.8967
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9837→ cube 1.121
#   Efficiency z (srs):  10.285 → 0.277 → 54.1936
#   Efficiency y (srs):  5.335 → 1.117 → 5.5594
#   Alpha:               0.5511300899431361
#   Num changes:         2
#   Design Depth:        3613
#   Design Size (|D|):   7326
#   Open set size:       82484
#
# Progress: 57.2%
# === Best Solution Updated at Iteration 2860 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53780.207
#   Best Cost (y):       15957.8308
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      53780.207
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0674→ cube 2.8995
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9847→ cube 1.1221
#   Efficiency z (srs):  10.285 → 0.277 → 54.2456
#   Efficiency y (srs):  5.335 → 1.117 → 5.565
#   Alpha:               0.3672900358366413
#   Num changes:         2
#   Design Depth:        3638
#   Design Size (|D|):   7376
#   Open set size:       83041
#
#
# === Best Solution Updated at Iteration 2860 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53775.253
#   Best Cost (y):       15955.2829
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      53775.253
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0675→ cube 2.8998
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9848→ cube 1.1223
#   Efficiency z (srs):  10.285 → 0.277 → 54.2506
#   Efficiency y (srs):  5.335 → 1.117 → 5.5659
#   Alpha:               0.788863442912926
#   Num changes:         1
#   Design Depth:        3637
#   Design Size (|D|):   7374
#   Open set size:       83059
#
# Progress: 57.4%
# === Best Solution Updated at Iteration 2870 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53763.644
#   Best Cost (y):       15957.4492
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      53763.644
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0677→ cube 2.9004
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9847→ cube 1.1221
#   Efficiency z (srs):  10.285 → 0.277 → 54.2623
#   Efficiency y (srs):  5.335 → 1.117 → 5.5651
#   Alpha:               0.765770936334374
#   Num changes:         2
#   Design Depth:        3643
#   Design Size (|D|):   7386
#   Open set size:       83335
#
# Progress: 57.6%
# === Best Solution Updated at Iteration 2880 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50611.54→50611.54, 10043.62→10043.62
#   Best Cost (z):       53726.113
#   Best Cost (y):       15965.7269
#   number of new noded: 30
#   rho (z, y):          0.885
#   rho (z_hat, y_hat):  0.718
#   rho (p, y):          0.88
#   Criteria Value:      53726.113
#   Efficiency z (0→f):  0.202 → 0.277 → dsd 1.0685→ cube 2.9024
#   Efficiency y (0→f):  0.944 → 1.117 → dsd 0.9842→ cube 1.1215
#   Efficiency z (srs):  10.285 → 0.277 → 54.3002
#   Efficiency y (srs):  5.335 → 1.117 → 5.5623
#   Alpha:               0.24784180375401788
#   Num changes:         1
#   Design Depth:        3660
#   Design Size (|D|):   7420
#   Open set size:       83620

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
