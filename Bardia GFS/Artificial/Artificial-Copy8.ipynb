# %% [markdown]
# # Packages

# %%
import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython


import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT
# Out:
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "PWD" redefined by R and overriding existing variable. Current: "/home/divar/projects/geometric-sampling", R: "/home/divar/projects/geometric-sampling/Bardia GFS/Artificial"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "LD_LIBRARY_PATH" redefined by R and overriding existing variable. Current: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server", R: "/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server:/usr/lib/R/lib:/usr/lib/x86_64-linux-gnu:/usr/lib/jvm/default-java/lib/server"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_LIBS_SITE" redefined by R and overriding existing variable. Current: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library", R: "/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library/:/usr/local/lib/R/site-library:/usr/lib/R/site-library:/usr/lib/R/library:/usr/lib/R/library:/usr/lib/R/library"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_PAPERSIZE_USER" redefined by R and overriding existing variable. Current: "a4", R: "letter"
#   warnings.warn(
# /home/divar/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/rpy2/rinterface/__init__.py:1211: UserWarning: Environment variable "R_SESSION_TMPDIR" redefined by R and overriding existing variable. Current: "/tmp/RtmpqZomVt", R: "/tmp/RtmpgSVqn3"
#   warnings.warn(

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Reading Data

# %%
# Python cell ----

import pandas as pd

# Read config file
params = pd.read_csv("config_origin.csv")

# Extract all columns as regular Python variables (from row 0)
for col in params.columns:
    globals()[col] = params.at[0, col]

# Now you have: bardia_balance_method, num_new_nodes, ... etc. as plain Python variables

# %%
# %%R
# # Read regular data (returns data.frame)
#
# df <- read.csv("cor_zy_9.5_py_9.5.csv")
#
# y   <- df$y
# z   <- df$z
# pik <- df$pik
#
# # Read "extra" data (returns data.frame of one row; use as.list to extract)
# extra <- read.csv("cor_zy_9.5_py_9.5_extra.csv")
#  list2env(extra, .GlobalEnv)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# # Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])

inclusions = np.array(ro.r['pik'])

threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht_y'][0])

threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])

inclusions = np.array(inclusions)



rng = np.random.default_rng()  # Recommended for controlled/stable random runs

print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method=bardia_balance_method)

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
    threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# 5000 30 200000 0.7 0.9
# Generating initial designs:   0%|                      | 0/3000 [00:00<?, ?it/s]
# Initial design 0: method = Original, efficiency z = 0.2523, y=1.0293
# New best at idx=0: method = Original, efficiency z = 0.2523 and efficiency y = 1.0293
# New best at idx=2: method = z/pi, efficiency z = 0.2523 and efficiency y = 1.0293
# New best at idx=3: method = swap, efficiency z = 0.2659 and efficiency y = 0.7536
# Generating initial designs:   1%|             | 23/3000 [00:00<00:56, 52.82it/s]
# New best at idx=6: method = swap, efficiency z = 0.2738 and efficiency y = 1.2302
# New best at idx=12: method = swap, efficiency z = 0.2832 and efficiency y = 1.1019
# New best at idx=17: method = swap, efficiency z = 0.2841 and efficiency y = 0.6509
# New best at idx=27: method = swap, efficiency z = 0.2907 and efficiency y = 1.6004
# Generating initial designs:   1%|▏            | 40/3000 [00:00<00:48, 60.99it/s]
# New best at idx=32: method = swap, efficiency z = 0.3704 and efficiency y = 0.6209
# Generating initial designs:  26%|███         | 770/3000 [00:12<00:40, 55.36it/s]
# New best at idx=762: method = swap, efficiency z = 0.4181 and efficiency y = 0.9086
# Generating initial designs:  49%|█████▍     | 1477/3000 [00:25<00:28, 53.74it/s]
# New best at idx=1470: method = swap, efficiency z = 0.4556 and efficiency y = 1.3140
# Generating initial designs: 100%|███████████| 3000/3000 [00:51<00:00, 58.77it/s]
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       62644.221
#   Best Cost (y):       4092.0394
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      62644.221
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.4559→ cube 1.1782
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.4332→ cube 1.5992
#   Efficiency z (srs):  22.636 → 0.456 → 40.8958
#   Efficiency y (srs):  15.585 → 1.314 → 21.702
#   Alpha:               0.7699889233946461
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       100
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       61769.533
#   Best Cost (y):       4230.8673
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      61769.533
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.4623→ cube 1.1949
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.3862→ cube 1.5467
#   Efficiency z (srs):  22.636 → 0.456 → 41.4749
#   Efficiency y (srs):  15.585 → 1.314 → 20.9899
#   Alpha:               0.7049953049823467
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       105
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       61709.234
#   Best Cost (y):       4215.3946
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      61709.234
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.4628→ cube 1.196
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.3913→ cube 1.5524
#   Efficiency z (srs):  22.636 → 0.456 → 41.5154
#   Efficiency y (srs):  15.585 → 1.314 → 21.0669
#   Alpha:               0.751934238182586
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       110
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       61664.02
#   Best Cost (y):       4042.7815
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      61664.02
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.4631→ cube 1.1969
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.4507→ cube 1.6187
#   Efficiency z (srs):  22.636 → 0.456 → 41.5459
#   Efficiency y (srs):  15.585 → 1.314 → 21.9664
#   Alpha:               0.7701285770259628
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       111
#
#
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       61133.173
#   Best Cost (y):       4066.7572
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      61133.173
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.4671→ cube 1.2073
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.4421→ cube 1.6091
#   Efficiency z (srs):  22.636 → 0.456 → 41.9066
#   Efficiency y (srs):  15.585 → 1.314 → 21.8369
#   Alpha:               0.8547745998565427
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   102
#   Open set size:       127
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       59142.25
#   Best Cost (y):       3878.9546
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      59142.25
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.4828→ cube 1.2479
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.5119→ cube 1.687
#   Efficiency z (srs):  22.636 → 0.456 → 43.3173
#   Efficiency y (srs):  15.585 → 1.314 → 22.8942
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        3
#   Design Size (|D|):   106
#   Open set size:       158
#
# Progress: 0.2%
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       45147.563
#   Best Cost (y):       3767.3147
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      45147.563
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.6325→ cube 1.6348
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.5567→ cube 1.737
#   Efficiency z (srs):  22.636 → 0.456 → 56.7447
#   Efficiency y (srs):  15.585 → 1.314 → 23.5726
#   Alpha:               0.7298672397954344
#   Num changes:         1
#   Design Depth:        19
#   Design Size (|D|):   138
#   Open set size:       394
#
#
# === Best Solution Updated at Iteration 10 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       45095.838
#   Best Cost (y):       3918.5318
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      45095.838
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.6332→ cube 1.6366
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.4967→ cube 1.67
#   Efficiency z (srs):  22.636 → 0.456 → 56.8098
#   Efficiency y (srs):  15.585 → 1.314 → 22.663
#   Alpha:               0.8244273707435813
#   Num changes:         1
#   Design Depth:        19
#   Design Size (|D|):   138
#   Open set size:       415
#
# Progress: 0.4%
# === Best Solution Updated at Iteration 20 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       44216.357
#   Best Cost (y):       3676.9842
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      44216.357
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.6458→ cube 1.6692
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.595→ cube 1.7797
#   Efficiency z (srs):  22.636 → 0.456 → 57.9398
#   Efficiency y (srs):  15.585 → 1.314 → 24.1517
#   Alpha:               0.7191839509302084
#   Num changes:         1
#   Design Depth:        30
#   Design Size (|D|):   160
#   Open set size:       683
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37515.079
#   Best Cost (y):       4276.4398
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      37515.079
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.7612→ cube 1.9674
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.3714→ cube 1.5302
#   Efficiency z (srs):  22.636 → 0.456 → 68.2895
#   Efficiency y (srs):  15.585 → 1.314 → 20.7662
#   Alpha:               0.7355483955257743
#   Num changes:         1
#   Design Depth:        68
#   Design Size (|D|):   236
#   Open set size:       1552
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37205.993
#   Best Cost (y):       4305.288
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      37205.993
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.7675→ cube 1.9837
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.3622→ cube 1.52
#   Efficiency z (srs):  22.636 → 0.456 → 68.8568
#   Efficiency y (srs):  15.585 → 1.314 → 20.6271
#   Alpha:               0.7434629634325498
#   Num changes:         3
#   Design Depth:        70
#   Design Size (|D|):   240
#   Open set size:       1569
#
#
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       37098.245
#   Best Cost (y):       4322.9112
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      37098.245
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.7698→ cube 1.9895
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.3567→ cube 1.5138
#   Efficiency z (srs):  22.636 → 0.456 → 69.0568
#   Efficiency y (srs):  15.585 → 1.314 → 20.543
#   Alpha:               0.8248539718138787
#   Num changes:         3
#   Design Depth:        70
#   Design Size (|D|):   240
#   Open set size:       1574
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       36338.613
#   Best Cost (y):       4031.8288
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      36338.613
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.7858→ cube 2.0311
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.4546→ cube 1.6231
#   Efficiency z (srs):  22.636 → 0.456 → 70.5004
#   Efficiency y (srs):  15.585 → 1.314 → 22.0261
#   Alpha:               0.8912910989325855
#   Num changes:         1
#   Design Depth:        83
#   Design Size (|D|):   266
#   Open set size:       1846
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       36268.937
#   Best Cost (y):       4151.4055
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      36268.937
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.7874→ cube 2.035
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.4127→ cube 1.5763
#   Efficiency z (srs):  22.636 → 0.456 → 70.6358
#   Efficiency y (srs):  15.585 → 1.314 → 21.3917
#   Alpha:               0.8151099145769966
#   Num changes:         3
#   Design Depth:        85
#   Design Size (|D|):   270
#   Open set size:       1850
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       31394.716
#   Best Cost (y):       4579.4276
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      31394.716
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.9096→ cube 2.3509
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2807→ cube 1.429
#   Efficiency z (srs):  22.636 → 0.456 → 81.6024
#   Efficiency y (srs):  15.585 → 1.314 → 19.3923
#   Alpha:               0.7975704527666574
#   Num changes:         2
#   Design Depth:        140
#   Design Size (|D|):   380
#   Open set size:       3293
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       31346.488
#   Best Cost (y):       4547.9505
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      31346.488
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.911→ cube 2.3545
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2895→ cube 1.4389
#   Efficiency z (srs):  22.636 → 0.456 → 81.728
#   Efficiency y (srs):  15.585 → 1.314 → 19.5265
#   Alpha:               0.7904715332953228
#   Num changes:         2
#   Design Depth:        140
#   Design Size (|D|):   380
#   Open set size:       3306
#
#
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       30961.648
#   Best Cost (y):       4537.5996
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      30961.648
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.9223→ cube 2.3838
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2925→ cube 1.4422
#   Efficiency z (srs):  22.636 → 0.456 → 82.7438
#   Efficiency y (srs):  15.585 → 1.314 → 19.571
#   Alpha:               0.746199719941108
#   Num changes:         3
#   Design Depth:        141
#   Design Size (|D|):   382
#   Open set size:       3307
#
# Progress: 2.4%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       29608.252
#   Best Cost (y):       4501.0678
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      29608.252
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.9645→ cube 2.4927
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.303→ cube 1.4539
#   Efficiency z (srs):  22.636 → 0.456 → 86.5261
#   Efficiency y (srs):  15.585 → 1.314 → 19.7299
#   Alpha:               0.8489984103137435
#   Num changes:         1
#   Design Depth:        150
#   Design Size (|D|):   400
#   Open set size:       3601
#
# Progress: 2.6%
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       29415.189
#   Best Cost (y):       4516.4099
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      29415.189
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.9708→ cube 2.5091
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2985→ cube 1.4489
#   Efficiency z (srs):  22.636 → 0.456 → 87.094
#   Efficiency y (srs):  15.585 → 1.314 → 19.6629
#   Alpha:               0.8931703979718548
#   Num changes:         3
#   Design Depth:        161
#   Design Size (|D|):   422
#   Open set size:       3871
#
#
# === Best Solution Updated at Iteration 130 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       29096.098
#   Best Cost (y):       4555.1087
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      29096.098
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.9815→ cube 2.5366
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2875→ cube 1.4366
#   Efficiency z (srs):  22.636 → 0.456 → 88.0491
#   Efficiency y (srs):  15.585 → 1.314 → 19.4958
#   Alpha:               0.8705288349005914
#   Num changes:         2
#   Design Depth:        160
#   Design Size (|D|):   420
#   Open set size:       3883
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       28573.658
#   Best Cost (y):       4552.3193
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      28573.658
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 0.9994→ cube 2.583
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2883→ cube 1.4375
#   Efficiency z (srs):  22.636 → 0.456 → 89.659
#   Efficiency y (srs):  15.585 → 1.314 → 19.5077
#   Alpha:               0.8496969175190422
#   Num changes:         3
#   Design Depth:        176
#   Design Size (|D|):   452
#   Open set size:       4161
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       28540.849
#   Best Cost (y):       4561.8042
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      28540.849
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.0005→ cube 2.586
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2856→ cube 1.4345
#   Efficiency z (srs):  22.636 → 0.456 → 89.7621
#   Efficiency y (srs):  15.585 → 1.314 → 19.4672
#   Alpha:               0.7397078757962574
#   Num changes:         1
#   Design Depth:        174
#   Design Size (|D|):   448
#   Open set size:       4163
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       28276.386
#   Best Cost (y):       4561.5419
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      28276.386
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.0099→ cube 2.6102
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2857→ cube 1.4346
#   Efficiency z (srs):  22.636 → 0.456 → 90.6016
#   Efficiency y (srs):  15.585 → 1.314 → 19.4683
#   Alpha:               0.7511350738460578
#   Num changes:         2
#   Design Depth:        175
#   Design Size (|D|):   450
#   Open set size:       4164
#
#
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       28080.079
#   Best Cost (y):       4594.0512
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      28080.079
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.017→ cube 2.6284
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2766→ cube 1.4244
#   Efficiency z (srs):  22.636 → 0.456 → 91.235
#   Efficiency y (srs):  15.585 → 1.314 → 19.3305
#   Alpha:               0.7914608200684387
#   Num changes:         2
#   Design Depth:        175
#   Design Size (|D|):   450
#   Open set size:       4176
#
# Progress: 3.2%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       27399.23
#   Best Cost (y):       4647.467
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      27399.23
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.0422→ cube 2.6937
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2619→ cube 1.4081
#   Efficiency z (srs):  22.636 → 0.456 → 93.5021
#   Efficiency y (srs):  15.585 → 1.314 → 19.1084
#   Alpha:               0.794271890170249
#   Num changes:         2
#   Design Depth:        193
#   Design Size (|D|):   486
#   Open set size:       4757
#
# Progress: 3.4%
# === Best Solution Updated at Iteration 170 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       26206.654
#   Best Cost (y):       4574.3872
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      26206.654
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.0897→ cube 2.8163
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2821→ cube 1.4306
#   Efficiency z (srs):  22.636 → 0.456 → 97.7571
#   Efficiency y (srs):  15.585 → 1.314 → 19.4136
#   Alpha:               0.7936579725590287
#   Num changes:         1
#   Design Depth:        209
#   Design Size (|D|):   518
#   Open set size:       5040
#
# Progress: 3.6%
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       26002.456
#   Best Cost (y):       4577.8736
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      26002.456
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.0982→ cube 2.8384
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2811→ cube 1.4295
#   Efficiency z (srs):  22.636 → 0.456 → 98.5247
#   Efficiency y (srs):  15.585 → 1.314 → 19.3989
#   Alpha:               0.7570005980051373
#   Num changes:         1
#   Design Depth:        221
#   Design Size (|D|):   542
#   Open set size:       5320
#
#
# === Best Solution Updated at Iteration 180 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       26001.547
#   Best Cost (y):       4718.3827
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      26001.547
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.0983→ cube 2.8385
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.243→ cube 1.3869
#   Efficiency z (srs):  22.636 → 0.456 → 98.5282
#   Efficiency y (srs):  15.585 → 1.314 → 18.8212
#   Alpha:               0.852549574566172
#   Num changes:         1
#   Design Depth:        221
#   Design Size (|D|):   542
#   Open set size:       5321
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       25524.253
#   Best Cost (y):       4726.4257
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      25524.253
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1188→ cube 2.8916
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2408→ cube 1.3845
#   Efficiency z (srs):  22.636 → 0.456 → 100.3706
#   Efficiency y (srs):  15.585 → 1.314 → 18.7891
#   Alpha:               0.8933857082356873
#   Num changes:         1
#   Design Depth:        239
#   Design Size (|D|):   578
#   Open set size:       5901
#
#
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       25411.754
#   Best Cost (y):       4732.0849
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      25411.754
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1238→ cube 2.9044
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2394→ cube 1.3829
#   Efficiency z (srs):  22.636 → 0.456 → 100.815
#   Efficiency y (srs):  15.585 → 1.314 → 18.7667
#   Alpha:               0.8865610131076511
#   Num changes:         1
#   Design Depth:        239
#   Design Size (|D|):   578
#   Open set size:       5914
#
# Progress: 4.2%
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       25213.529
#   Best Cost (y):       4782.6036
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      25213.529
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1326→ cube 2.9272
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2263→ cube 1.3683
#   Efficiency z (srs):  22.636 → 0.456 → 101.6076
#   Efficiency y (srs):  15.585 → 1.314 → 18.5684
#   Alpha:               0.740878178233003
#   Num changes:         1
#   Design Depth:        251
#   Design Size (|D|):   602
#   Open set size:       6196
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       25197.643
#   Best Cost (y):       4789.6434
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      25197.643
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1333→ cube 2.9291
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2245→ cube 1.3663
#   Efficiency z (srs):  22.636 → 0.456 → 101.6716
#   Efficiency y (srs):  15.585 → 1.314 → 18.5412
#   Alpha:               0.7754658750589274
#   Num changes:         1
#   Design Depth:        251
#   Design Size (|D|):   602
#   Open set size:       6206
#
#
# === Best Solution Updated at Iteration 210 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       25176.85
#   Best Cost (y):       4732.0453
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      25176.85
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1342→ cube 2.9315
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2394→ cube 1.3829
#   Efficiency z (srs):  22.636 → 0.456 → 101.7556
#   Efficiency y (srs):  15.585 → 1.314 → 18.7668
#   Alpha:               0.7889228634319077
#   Num changes:         1
#   Design Depth:        251
#   Design Size (|D|):   602
#   Open set size:       6218
#
# Progress: 4.4%
# === Best Solution Updated at Iteration 220 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       25059.947
#   Best Cost (y):       4657.0348
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      25059.947
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1395→ cube 2.9452
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2593→ cube 1.4052
#   Efficiency z (srs):  22.636 → 0.456 → 102.2303
#   Efficiency y (srs):  15.585 → 1.314 → 19.0691
#   Alpha:               0.8340487696498233
#   Num changes:         1
#   Design Depth:        262
#   Design Size (|D|):   624
#   Open set size:       6500
#
# Progress: 4.8%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24963.337
#   Best Cost (y):       4825.9185
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24963.337
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1439→ cube 2.9566
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2153→ cube 1.356
#   Efficiency z (srs):  22.636 → 0.456 → 102.6259
#   Efficiency y (srs):  15.585 → 1.314 → 18.4018
#   Alpha:               0.8966529831362884
#   Num changes:         2
#   Design Depth:        278
#   Design Size (|D|):   656
#   Open set size:       7060
#
#
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24956.548
#   Best Cost (y):       4830.3655
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24956.548
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1443→ cube 2.9574
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2141→ cube 1.3548
#   Efficiency z (srs):  22.636 → 0.456 → 102.6538
#   Efficiency y (srs):  15.585 → 1.314 → 18.3848
#   Alpha:               0.8817533591478774
#   Num changes:         1
#   Design Depth:        277
#   Design Size (|D|):   654
#   Open set size:       7066
#
#
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24955.042
#   Best Cost (y):       4818.1234
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24955.042
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1443→ cube 2.9575
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2172→ cube 1.3582
#   Efficiency z (srs):  22.636 → 0.456 → 102.66
#   Efficiency y (srs):  15.585 → 1.314 → 18.4316
#   Alpha:               0.8373030176583786
#   Num changes:         1
#   Design Depth:        277
#   Design Size (|D|):   654
#   Open set size:       7087
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24823.287
#   Best Cost (y):       4812.2892
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24823.287
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1504→ cube 2.9732
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2187→ cube 1.3598
#   Efficiency z (srs):  22.636 → 0.456 → 103.2049
#   Efficiency y (srs):  15.585 → 1.314 → 18.4539
#   Alpha:               0.8810917347362958
#   Num changes:         1
#   Design Depth:        291
#   Design Size (|D|):   682
#   Open set size:       7350
#
# Progress: 6.6%
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24092.225
#   Best Cost (y):       4866.8159
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24092.225
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1853→ cube 3.0635
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2051→ cube 1.3446
#   Efficiency z (srs):  22.636 → 0.456 → 106.3366
#   Efficiency y (srs):  15.585 → 1.314 → 18.2471
#   Alpha:               0.8197295785088992
#   Num changes:         3
#   Design Depth:        331
#   Design Size (|D|):   762
#   Open set size:       9682
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24089.766
#   Best Cost (y):       4861.535
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24089.766
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1854→ cube 3.0638
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2064→ cube 1.3461
#   Efficiency z (srs):  22.636 → 0.456 → 106.3475
#   Efficiency y (srs):  15.585 → 1.314 → 18.267
#   Alpha:               0.7491907902677882
#   Num changes:         1
#   Design Depth:        329
#   Design Size (|D|):   758
#   Open set size:       9691
#
#
# === Best Solution Updated at Iteration 330 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       24089.066
#   Best Cost (y):       4860.5876
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      24089.066
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1855→ cube 3.0639
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.2066→ cube 1.3463
#   Efficiency z (srs):  22.636 → 0.456 → 106.3505
#   Efficiency y (srs):  15.585 → 1.314 → 18.2705
#   Alpha:               0.8654169275933341
#   Num changes:         1
#   Design Depth:        329
#   Design Size (|D|):   758
#   Open set size:       9698
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 360 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       23901.698
#   Best Cost (y):       4909.6271
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      23901.698
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.1947→ cube 3.0879
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1945→ cube 1.3329
#   Efficiency z (srs):  22.636 → 0.456 → 107.1842
#   Efficiency y (srs):  15.585 → 1.314 → 18.088
#   Alpha:               0.7681309261951883
#   Num changes:         3
#   Design Depth:        341
#   Design Size (|D|):   782
#   Open set size:       10568
#
# Progress: 7.6%
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       22739.132
#   Best Cost (y):       4963.7586
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      22739.132
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.2558→ cube 3.2458
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1815→ cube 1.3183
#   Efficiency z (srs):  22.636 → 0.456 → 112.6642
#   Efficiency y (srs):  15.585 → 1.314 → 17.8908
#   Alpha:               0.8428280549176553
#   Num changes:         1
#   Design Depth:        374
#   Design Size (|D|):   848
#   Open set size:       11144
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       22708.974
#   Best Cost (y):       4973.1957
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      22708.974
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.2575→ cube 3.2501
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1793→ cube 1.3158
#   Efficiency z (srs):  22.636 → 0.456 → 112.8138
#   Efficiency y (srs):  15.585 → 1.314 → 17.8568
#   Alpha:               0.8850085188066892
#   Num changes:         2
#   Design Depth:        375
#   Design Size (|D|):   850
#   Open set size:       11145
#
#
# === Best Solution Updated at Iteration 380 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       22703.223
#   Best Cost (y):       4975.284
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      22703.223
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.2578→ cube 3.2509
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1788→ cube 1.3153
#   Efficiency z (srs):  22.636 → 0.456 → 112.8424
#   Efficiency y (srs):  15.585 → 1.314 → 17.8493
#   Alpha:               0.8828255767200052
#   Num changes:         2
#   Design Depth:        375
#   Design Size (|D|):   850
#   Open set size:       11147
#
# Progress: 7.8%
# === Best Solution Updated at Iteration 390 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       22673.379
#   Best Cost (y):       4984.4586
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      22673.379
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.2595→ cube 3.2552
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1766→ cube 1.3129
#   Efficiency z (srs):  22.636 → 0.456 → 112.9909
#   Efficiency y (srs):  15.585 → 1.314 → 17.8165
#   Alpha:               0.7376370199881815
#   Num changes:         1
#   Design Depth:        381
#   Design Size (|D|):   862
#   Open set size:       11434
#
# Progress: 8.6%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21603.662
#   Best Cost (y):       5123.0794
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21603.662
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3218→ cube 3.4164
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1448→ cube 1.2773
#   Efficiency z (srs):  22.636 → 0.456 → 118.5857
#   Efficiency y (srs):  15.585 → 1.314 → 17.3344
#   Alpha:               0.8545586174904232
#   Num changes:         2
#   Design Depth:        427
#   Design Size (|D|):   954
#   Open set size:       12576
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21602.631
#   Best Cost (y):       5120.8784
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21602.631
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3219→ cube 3.4165
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1453→ cube 1.2779
#   Efficiency z (srs):  22.636 → 0.456 → 118.5914
#   Efficiency y (srs):  15.585 → 1.314 → 17.3419
#   Alpha:               0.7380691875605211
#   Num changes:         2
#   Design Depth:        427
#   Design Size (|D|):   954
#   Open set size:       12580
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21579.185
#   Best Cost (y):       5117.1841
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21579.185
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3233→ cube 3.4202
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1461→ cube 1.2788
#   Efficiency z (srs):  22.636 → 0.456 → 118.7202
#   Efficiency y (srs):  15.585 → 1.314 → 17.3544
#   Alpha:               0.7924347734553536
#   Num changes:         1
#   Design Depth:        426
#   Design Size (|D|):   952
#   Open set size:       12588
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21574.826
#   Best Cost (y):       5122.7087
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21574.826
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3236→ cube 3.4209
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1449→ cube 1.2774
#   Efficiency z (srs):  22.636 → 0.456 → 118.7442
#   Efficiency y (srs):  15.585 → 1.314 → 17.3357
#   Alpha:               0.8430277206689185
#   Num changes:         1
#   Design Depth:        426
#   Design Size (|D|):   952
#   Open set size:       12596
#
# Progress: 9.0%
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21274.046
#   Best Cost (y):       5165.69
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21274.046
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3423→ cube 3.4693
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1353→ cube 1.2668
#   Efficiency z (srs):  22.636 → 0.456 → 120.423
#   Efficiency y (srs):  15.585 → 1.314 → 17.1914
#   Alpha:               0.8166149007665262
#   Num changes:         1
#   Design Depth:        448
#   Design Size (|D|):   996
#   Open set size:       13164
#
#
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21236.364
#   Best Cost (y):       5170.7204
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21236.364
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3447→ cube 3.4754
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1342→ cube 1.2656
#   Efficiency z (srs):  22.636 → 0.456 → 120.6367
#   Efficiency y (srs):  15.585 → 1.314 → 17.1747
#   Alpha:               0.8294254332457749
#   Num changes:         1
#   Design Depth:        448
#   Design Size (|D|):   996
#   Open set size:       13174
#
#
# === Best Solution Updated at Iteration 450 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       21215.508
#   Best Cost (y):       5100.2872
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      21215.508
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.346→ cube 3.4789
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1499→ cube 1.2831
#   Efficiency z (srs):  22.636 → 0.456 → 120.7553
#   Efficiency y (srs):  15.585 → 1.314 → 17.4119
#   Alpha:               0.8918627274426834
#   Num changes:         1
#   Design Depth:        448
#   Design Size (|D|):   996
#   Open set size:       13175
#
# Progress: 9.2%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       20994.368
#   Best Cost (y):       5187.9412
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      20994.368
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3602→ cube 3.5155
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1305→ cube 1.2614
#   Efficiency z (srs):  22.636 → 0.456 → 122.0273
#   Efficiency y (srs):  15.585 → 1.314 → 17.1177
#   Alpha:               0.8335139869469197
#   Num changes:         1
#   Design Depth:        462
#   Design Size (|D|):   1024
#   Open set size:       13469
#
# Progress: 9.4%
# === Best Solution Updated at Iteration 470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       20671.663
#   Best Cost (y):       5261.9638
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      20671.663
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.3814→ cube 3.5704
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1146→ cube 1.2436
#   Efficiency z (srs):  22.636 → 0.456 → 123.9322
#   Efficiency y (srs):  15.585 → 1.314 → 16.8769
#   Alpha:               0.7841294556476743
#   Num changes:         2
#   Design Depth:        477
#   Design Size (|D|):   1054
#   Open set size:       13749
#
# Progress: 10.4%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       20354.391
#   Best Cost (y):       5225.7771
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      20354.391
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.403→ cube 3.626
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1223→ cube 1.2522
#   Efficiency z (srs):  22.636 → 0.456 → 125.864
#   Efficiency y (srs):  15.585 → 1.314 → 16.9937
#   Alpha:               0.8000089509357512
#   Num changes:         1
#   Design Depth:        509
#   Design Size (|D|):   1118
#   Open set size:       15185
#
# Progress: 10.6%
# === Best Solution Updated at Iteration 530 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       20334.779
#   Best Cost (y):       5222.8977
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      20334.779
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.4043→ cube 3.6295
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1229→ cube 1.2529
#   Efficiency z (srs):  22.636 → 0.456 → 125.9854
#   Efficiency y (srs):  15.585 → 1.314 → 17.0031
#   Alpha:               0.7373323922302221
#   Num changes:         1
#   Design Depth:        517
#   Design Size (|D|):   1134
#   Open set size:       15474
#
# Progress: 10.8%
# === Best Solution Updated at Iteration 540 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       19886.616
#   Best Cost (y):       5245.2134
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      19886.616
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.436→ cube 3.7113
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1181→ cube 1.2476
#   Efficiency z (srs):  22.636 → 0.456 → 128.8246
#   Efficiency y (srs):  15.585 → 1.314 → 16.9308
#   Alpha:               0.8466621918071363
#   Num changes:         3
#   Design Depth:        532
#   Design Size (|D|):   1164
#   Open set size:       15771
#
# Progress: 11.2%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       19651.194
#   Best Cost (y):       5288.3541
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      19651.194
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.4532→ cube 3.7558
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.109→ cube 1.2374
#   Efficiency z (srs):  22.636 → 0.456 → 130.3679
#   Efficiency y (srs):  15.585 → 1.314 → 16.7927
#   Alpha:               0.7429343248884164
#   Num changes:         1
#   Design Depth:        549
#   Design Size (|D|):   1198
#   Open set size:       16358
#
# Progress: 12.0%
# === Best Solution Updated at Iteration 600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       19224.336
#   Best Cost (y):       5431.4077
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      19224.336
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.4854→ cube 3.8392
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0798→ cube 1.2048
#   Efficiency z (srs):  22.636 → 0.456 → 133.2626
#   Efficiency y (srs):  15.585 → 1.314 → 16.3504
#   Alpha:               0.8705095206338437
#   Num changes:         2
#   Design Depth:        590
#   Design Size (|D|):   1280
#   Open set size:       17504
#
#
# === Best Solution Updated at Iteration 600 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       19218.133
#   Best Cost (y):       5417.8929
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      19218.133
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.4859→ cube 3.8404
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0825→ cube 1.2078
#   Efficiency z (srs):  22.636 → 0.456 → 133.3056
#   Efficiency y (srs):  15.585 → 1.314 → 16.3912
#   Alpha:               0.7297706588483818
#   Num changes:         1
#   Design Depth:        589
#   Design Size (|D|):   1278
#   Open set size:       17509
#
# Progress: 12.4%
# === Best Solution Updated at Iteration 620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       19087.388
#   Best Cost (y):       5413.8225
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      19087.388
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.4961→ cube 3.8667
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0833→ cube 1.2088
#   Efficiency z (srs):  22.636 → 0.456 → 134.2187
#   Efficiency y (srs):  15.585 → 1.314 → 16.4035
#   Alpha:               0.7459707284428282
#   Num changes:         1
#   Design Depth:        609
#   Design Size (|D|):   1318
#   Open set size:       18086
#
#
# === Best Solution Updated at Iteration 620 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       19085.886
#   Best Cost (y):       5416.6373
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      19085.886
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.4962→ cube 3.867
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0827→ cube 1.2081
#   Efficiency z (srs):  22.636 → 0.456 → 134.2293
#   Efficiency y (srs):  15.585 → 1.314 → 16.395
#   Alpha:               0.7148506740569859
#   Num changes:         1
#   Design Depth:        609
#   Design Size (|D|):   1318
#   Open set size:       18091
#
# Progress: 13.4%
# === Best Solution Updated at Iteration 670 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       18870.503
#   Best Cost (y):       5447.9101
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      18870.503
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.5133→ cube 3.9112
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0765→ cube 1.2012
#   Efficiency z (srs):  22.636 → 0.456 → 135.7614
#   Efficiency y (srs):  15.585 → 1.314 → 16.3008
# ...
#   Alpha:               0.7870287824928118
#   Num changes:         1
#   Design Depth:        851
#   Design Size (|D|):   1802
#   Open set size:       25927
#
#
# === Best Solution Updated at Iteration 890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       17192.684
#   Best Cost (y):       5405.5659
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      17192.684
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.661→ cube 4.2929
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0849→ cube 1.2106
#   Efficiency z (srs):  22.636 → 0.456 → 149.0102
#   Efficiency y (srs):  15.585 → 1.314 → 16.4285
#   Alpha:               0.78249553040652
#   Num changes:         1
#   Design Depth:        851
#   Design Size (|D|):   1802
#   Open set size:       25929
#
#
# === Best Solution Updated at Iteration 890 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       17191.95
#   Best Cost (y):       5387.2752
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      17191.95
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.661→ cube 4.293
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0886→ cube 1.2147
#   Efficiency z (srs):  22.636 → 0.456 → 149.0166
#   Efficiency y (srs):  15.585 → 1.314 → 16.4843
#   Alpha:               0.8962488181699709
#   Num changes:         1
#   Design Depth:        851
#   Design Size (|D|):   1802
#   Open set size:       25932
#
# Progress: 18.6%
# === Best Solution Updated at Iteration 930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       17109.075
#   Best Cost (y):       5354.622
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      17109.075
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6691→ cube 4.3138
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0953→ cube 1.2221
#   Efficiency z (srs):  22.636 → 0.456 → 149.7384
#   Efficiency y (srs):  15.585 → 1.314 → 16.5848
#   Alpha:               0.8203194031386358
#   Num changes:         1
#   Design Depth:        884
#   Design Size (|D|):   1868
#   Open set size:       27073
#
#
# === Best Solution Updated at Iteration 930 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       17108.84
#   Best Cost (y):       5351.9885
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      17108.84
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6691→ cube 4.3139
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0958→ cube 1.2227
#   Efficiency z (srs):  22.636 → 0.456 → 149.7404
#   Efficiency y (srs):  15.585 → 1.314 → 16.593
#   Alpha:               0.8926975502204628
#   Num changes:         1
#   Design Depth:        884
#   Design Size (|D|):   1868
#   Open set size:       27081
#
# Progress: 21.4%
# === Best Solution Updated at Iteration 1070 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       17054.707
#   Best Cost (y):       5356.2385
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      17054.707
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6744→ cube 4.3276
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0949→ cube 1.2217
#   Efficiency z (srs):  22.636 → 0.456 → 150.2157
#   Efficiency y (srs):  15.585 → 1.314 → 16.5798
#   Alpha:               0.7426737138691912
#   Num changes:         2
#   Design Depth:        903
#   Design Size (|D|):   1906
#   Open set size:       31147
#
# Progress: 21.6%
# === Best Solution Updated at Iteration 1080 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16973.466
#   Best Cost (y):       5326.0029
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16973.466
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6824→ cube 4.3483
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1012→ cube 1.2287
#   Efficiency z (srs):  22.636 → 0.456 → 150.9347
#   Efficiency y (srs):  15.585 → 1.314 → 16.6739
#   Alpha:               0.8814198202406831
#   Num changes:         1
#   Design Depth:        916
#   Design Size (|D|):   1932
#   Open set size:       31424
#
#
# === Best Solution Updated at Iteration 1080 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16972.37
#   Best Cost (y):       5324.9063
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16972.37
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6825→ cube 4.3486
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1014→ cube 1.2289
#   Efficiency z (srs):  22.636 → 0.456 → 150.9445
#   Efficiency y (srs):  15.585 → 1.314 → 16.6774
#   Alpha:               0.8992735953089515
#   Num changes:         1
#   Design Depth:        916
#   Design Size (|D|):   1932
#   Open set size:       31428
#
#
# === Best Solution Updated at Iteration 1080 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16964.525
#   Best Cost (y):       5325.0839
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16964.525
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6833→ cube 4.3506
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1013→ cube 1.2289
#   Efficiency z (srs):  22.636 → 0.456 → 151.0143
#   Efficiency y (srs):  15.585 → 1.314 → 16.6768
#   Alpha:               0.8311916012248254
#   Num changes:         1
#   Design Depth:        916
#   Design Size (|D|):   1932
#   Open set size:       31442
#
# Progress: 22.2%
# === Best Solution Updated at Iteration 1110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16813.62
#   Best Cost (y):       5343.4789
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16813.62
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.6984→ cube 4.3896
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0976→ cube 1.2247
#   Efficiency z (srs):  22.636 → 0.456 → 152.3696
#   Efficiency y (srs):  15.585 → 1.314 → 16.6194
#   Alpha:               0.7032049296716445
#   Num changes:         1
#   Design Depth:        941
#   Design Size (|D|):   1982
#   Open set size:       32312
#
# Progress: 22.4%
# === Best Solution Updated at Iteration 1120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16731.407
#   Best Cost (y):       5372.5853
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16731.407
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7068→ cube 4.4112
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0916→ cube 1.218
#   Efficiency z (srs):  22.636 → 0.456 → 153.1183
#   Efficiency y (srs):  15.585 → 1.314 → 16.5294
#   Alpha:               0.7049574881634533
#   Num changes:         2
#   Design Depth:        953
#   Design Size (|D|):   2006
#   Open set size:       32590
#
#
# === Best Solution Updated at Iteration 1120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16707.916
#   Best Cost (y):       5374.6626
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16707.916
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7092→ cube 4.4174
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0912→ cube 1.2176
#   Efficiency z (srs):  22.636 → 0.456 → 153.3336
#   Efficiency y (srs):  15.585 → 1.314 → 16.523
#   Alpha:               0.7715558356339098
#   Num changes:         1
#   Design Depth:        952
#   Design Size (|D|):   2004
#   Open set size:       32591
#
# Progress: 22.8%
# === Best Solution Updated at Iteration 1140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16563.459
#   Best Cost (y):       5377.3504
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16563.459
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7241→ cube 4.4559
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0906→ cube 1.2169
#   Efficiency z (srs):  22.636 → 0.456 → 154.6709
#   Efficiency y (srs):  15.585 → 1.314 → 16.5147
#   Alpha:               0.8541273426184081
#   Num changes:         1
#   Design Depth:        971
#   Design Size (|D|):   2042
#   Open set size:       33160
#
# Progress: 23.2%
# === Best Solution Updated at Iteration 1160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16351.253
#   Best Cost (y):       5307.1596
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16351.253
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7464→ cube 4.5138
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1051→ cube 1.233
#   Efficiency z (srs):  22.636 → 0.456 → 156.6782
#   Efficiency y (srs):  15.585 → 1.314 → 16.7332
#   Alpha:               0.8051053381899655
#   Num changes:         1
#   Design Depth:        991
#   Design Size (|D|):   2082
#   Open set size:       33741
#
#
# === Best Solution Updated at Iteration 1160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16350.226
#   Best Cost (y):       5316.003
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16350.226
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7466→ cube 4.514
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.1032→ cube 1.231
#   Efficiency z (srs):  22.636 → 0.456 → 156.6881
#   Efficiency y (srs):  15.585 → 1.314 → 16.7053
#   Alpha:               0.781357251383425
#   Num changes:         1
#   Design Depth:        991
#   Design Size (|D|):   2082
#   Open set size:       33766
#
# Progress: 23.8%
# === Best Solution Updated at Iteration 1190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16159.869
#   Best Cost (y):       5339.7063
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16159.869
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7671→ cube 4.5672
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0983→ cube 1.2255
#   Efficiency z (srs):  22.636 → 0.456 → 158.5338
#   Efficiency y (srs):  15.585 → 1.314 → 16.6312
#   Alpha:               0.8104419499980511
#   Num changes:         1
#   Design Depth:        1021
#   Design Size (|D|):   2142
#   Open set size:       34613
#
#
# === Best Solution Updated at Iteration 1190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16159.824
#   Best Cost (y):       5339.8587
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16159.824
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7671→ cube 4.5672
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0983→ cube 1.2255
#   Efficiency z (srs):  22.636 → 0.456 → 158.5342
#   Efficiency y (srs):  15.585 → 1.314 → 16.6307
#   Alpha:               0.8672474310056507
#   Num changes:         1
#   Design Depth:        1021
#   Design Size (|D|):   2142
#   Open set size:       34628
#
#
# === Best Solution Updated at Iteration 1190 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   50171.04→50171.04, 10043.62→10043.62
#   Best Cost (z):       16159.303
#   Best Cost (y):       5345.1066
#   number of new noded: 30
#   rho (z, y):          0.951
#   rho (z_hat, y_hat):  0.755
#   rho (p, y):          0.926
#   Criteria Value:      16159.303
#   Efficiency z (0→f):  0.252 → 0.456 → dsd 1.7672→ cube 4.5674
#   Efficiency y (0→f):  1.029 → 1.314 → dsd 1.0972→ cube 1.2243
#   Efficiency z (srs):  22.636 → 0.456 → 158.5393
#   Efficiency y (srs):  15.585 → 1.314 → 16.6144
#   Alpha:               0.763501881540346
#   Num changes:         2
#   Design Depth:        1022
#   Design Size (|D|):   2144
#   Open set size:       34639
#
# Progress: 23.9%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 48
#      22 criterion = VarNHT(main_variable=y, auxiliary_variable=z,
#      23                    inclusion_probability=inclusions, balance_method=bardia_balance_method)
#      25 astar = AStar(
#      26     inclusions              = inclusions,
#      27     num_initial_nodes       = num_initial_nodes,
#    (...)     45     rng                     = rng,
#      46 )
# ---> 48 result = astar.run(
#      49     max_iterations             = max_iterations,
#      50     num_new_nodes              = num_new_nodes,
#      51     max_open_set_size          = max_open_set_size,
#      52     random_restart_period      = random_restart_period,
#      53     random_injection_count     = random_injection_count,
#      54     prune_fraction             = prune_fraction,
#      55     num_top_restart_nodes      = num_top_restart_nodes,
#      56     stuck_fraction             = stuck_fraction,
#      57
#      58 )
#      60 print("Best criteria value:", astar.best_criteria_value)
#      61 print("Iterations run:", result)
#
# File ~/projects/geometric-sampling/geometric_sampling/search/astar.py:274, in AStar.run(self, max_iterations, num_new_nodes, max_open_set_size, show_results, random_restart_period, random_injection_count, prune_fraction, num_top_restart_nodes, stuck_fraction)
#     271 if new_design in closed_set or new_design in open_set:
#     272     continue
# --> 274 _ = self.criteria(new_design)
#     275 new_criteria_value = self.criteria.var_NHT
#     276 new_var_NHT = self.criteria.var_NHT
#
# File ~/projects/geometric-sampling/geometric_sampling/criteria/var_nht.py:29, in VarNHT.__call__(self, design)
#      18 NHT_estimator_z2 = np.array([
#      19     np.sum(self.auxiliary_variable[list(sample.ids)]**2 /
#      20            self.inclusion_probability[list(sample.ids)])
#      21     for sample in design
#      22 ])
#      23 NHT_estimator_ones = np.array([
#      24     np.sum(ones[list(sample.ids)] /
#      25            self.inclusion_probability[list(sample.ids)])
#      26     for sample in design
#      27 ])
#      28 NHT_estimator_y = np.array([
# ---> 29     np.sum(self.main_variable[list(sample.ids)] /
#      30            self.inclusion_probability[list(sample.ids)])
#      31     for sample in design
#      32 ])
#      33 samples_probabilities = np.array([sample.probability for sample in design])
#      34 var_NHT_z = np.sum((NHT_estimator_z - np.sum(self.auxiliary_variable)) ** 2 * samples_probabilities)
#
# File ~/projects/geometric-sampling/jupenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2333, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2327         raise ValueError("Passing `min` or `max` keyword argument when "
#    2328                          "`a_min` and `a_max` are provided is forbidden.")
#    2330     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2333 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2334                     initial=None, where=None):
#    2335     return (a, out)
#    2338 @array_function_dispatch(_sum_dispatcher)
#    2339 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2340         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
import pandas as pd
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
print(N)
sum_inclusion_last = 0
sum_inclusion_init = 0
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    z_ests = []
    y_ests = []
    probs  = []
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        probs.append(item.probability)
        ids = np.array(list(item.ids), dtype=int)
        z_ests.append(np.sum(z[ids]/inclusions[ids]))
        y_ests.append(np.sum(y[ids]/inclusions[ids]))
            
        if k in item.ids:
            
            #print(np.round(np.sum(y[ids]/inclusions[ids])), np.round(np.sum(z[ids]/inclusions[ids])))
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
    sum_inclusion_last += prob_last
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            #print(item.probability)
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
    sum_inclusion_init += prob_ini
    
        #print(item)
    #print(np.round(prob_last, 3), np.round(prob_ini, 3), np.round(inclusions[k], 3))
    if  not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yessssss')
print('sum of inclusions, last ini and original', sum_inclusion_last, sum_inclusion_init, sum(inclusions))
print(prob)
print('n = ', n)
#print(pd.concat([pd.Series(z_ests), pd.Series(y_ests), pd.Series(probs)], axis=1))
y_ests = np.array(y_ests)
z_ests = np.array(z_ests)
probs = np.array(probs)
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print(np.sum(y), np.sum(z), np.sum(y_ests*probs), np.sum(z_ests*probs))
print('var z estimates', np.round(np.sum(z_ests**2*probs)-np.sum(z_ests*probs)**2, 3))
print('var y estimates', np.round(np.sum(y_ests**2*probs)-np.sum(y_ests*probs)**2, 3))
# Out:
# size of init design 100
# size of best design 2150
# 62675.19812545414
# 16149.744664962844
# [100]
# /tmp/ipykernel_280702/683604881.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# sum of inclusions, last ini and original 10.000000010000008 10.000000010000006 10.0
# 1.000000000999997
# n =  [10]
# 10043.617183059718 50171.04438153942 10043.617193015132 50171.04443165533
# 10043.617183059718 50171.04438153942 10043.617193015132 50171.04443165533
# var z estimates 16147.228
# var y estimates 5336.008
